# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime
import math
import gc
import os

from sklearn.metrics import roc_auc_score

import lightgbm as lgbm

import pickle
def dump_pkl(data, filename):
  with open(filename, 'wb') as handle:
    pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)

def load_pkl(filename):
  with open(filename, 'rb') as handle:
    data = pickle.load(handle)
  return data

# %%
stocks = [elem.split('.')[0] for elem in os.listdir('./data/preproc/1hour/')]
#stocks
len(stocks)
# Out:
# 380

# %%
df = load_pkl('./data/lgbm/data_1hour.pkl')

# %%
df.shape
# Out:
# (5321140, 319)

# %%
df.rename(columns={'close_1hour' : 'close'}, inplace=True)
df.head()
# Out:
#                  time  ticker1  ticker2     close              ticker  \
# 0 2023-10-01 00:00:00    8.125  1674.34  0.004853  LINK-USDT_ETH-USDT
# 1 2023-10-01 01:00:00    8.182  1675.00  0.004885  LINK-USDT_ETH-USDT
# 2 2023-10-01 02:00:00    8.189  1670.88  0.004901  LINK-USDT_ETH-USDT
# 3 2023-10-01 03:00:00    8.248  1673.97  0.004927  LINK-USDT_ETH-USDT
# 4 2023-10-01 04:00:00    8.163  1673.85  0.004877  LINK-USDT_ETH-USDT
#
#    close_1hour_w1_roc  close_1hour_w5_norm_std  close_1hour_w5_mean_abs_pct  \
# 0           -0.000212                 0.001655                     0.001952
# 1            0.006618                 0.002966                     0.003229
# 2            0.003323                 0.004249                     0.003463
# 3            0.005345                 0.006522                     0.003794
# 4           -0.010234                 0.005686                     0.005147
#
#    close_1hour_w5_alpha  close_1hour_w5_rsi  ...  \
# 0         -76809.179688           37.773579  ...
# 1          55649.933594           63.815258  ...
# 2          53617.660156           78.713341  ...
# 3          48150.113281           80.617393  ...
# 4          29338.947266           59.163799  ...
#
#    close_1hour_w200_ma_up_2std/close_1hour  \
# 0                                 1.017613
# 1                                 1.010994
# 2                                 1.007771
# 3                                 1.002625
# 4                                 1.013116
#
#    close_1hour_w200_ma_low_3std/close_1hour  \
# 0                                  0.858567
# 1                                  0.854461
# 2                                  0.853115
# 3                                  0.849995
# 4                                  0.860112
#
#    close_1hour_w200_ma_up_3std/close_1hour  \
# 0                                 1.049422
# 1                                 1.042301
# 2                                 1.038703
# 3                                 1.033151
# 4                                 1.043716
#
#    close_1hour_w5_min/close_1hour_w5_max  \
# 0                               0.996295
# 1                               0.993400
# 2                               0.990110
# 3                               0.984846
# 4                               0.984846
#
#    close_1hour_w10_min/close_1hour_w10_max  \
# 0                                 0.992175
# 1                                 0.992175
# 2                                 0.989161
# 3                                 0.984845
# 4                                 0.984845
#
#    close_1hour_w20_min/close_1hour_w20_max  \
# 0                                 0.979237
# 1                                 0.979237
# 2                                 0.977100
# 3                                 0.971905
# 4                                 0.971905
#
#    close_1hour_w30_min/close_1hour_w30_max  \
# 0                                 0.957690
# 1                                 0.957690
# 2                                 0.972409
# 3                                 0.967239
# 4                                 0.967239
#
#    close_1hour_w60_min/close_1hour_w60_max  \
# 0                                 0.941715
# 1                                 0.941715
# 2                                 0.939660
# 3                                 0.934664
# 4                                 0.934664
#
#    close_1hour_w120_min/close_1hour_w120_max  \
# 0                                   0.935259
# 1                                   0.935259
# 2                                   0.933219
# 3                                   0.928257
# 4                                   0.928257
#
#    close_1hour_w200_min/close_1hour_w200_max
# 0                                   0.867259
# 1                                   0.867780
# 2                                   0.865887
# 3                                   0.869934
# 4                                   0.876473
#
# [5 rows x 319 columns]

# %% [markdown]
# ## CHANGE TARGET

# %%
def get_income_rate(x_start, x_end, y_start, y_end):
    #вкладываешь M, M/2 в X, M/2 в Y
    #Income_rate от M
    
    #close_x 
    income_rate_x = x_end / x_start
    #close_y
    income_rate_y = (2*y_start - y_end) / y_start    
    income_rate =  1 + ((income_rate_x - 1) + (income_rate_y - 1))/2

    #fee
    income_rate -= 0.001
    
    return income_rate


def get_target(df_all, ind, val_first, val_second, points_to_wait):
    #цель - достичь val_second, не достигнув val_first
    #short game не существует

    ind_end = min(ind+points_to_wait+1, df_all.shape[0])
    
    df = df_all.iloc[ind:ind_end].copy()
    
    mask_stock = np.array(df['ticker'] == df['ticker'].iloc[0])
    df = df.loc[mask_stock, :]

    start_price = df['close'].iloc[0]

    x_start = df['ticker1'].iloc[0]
    y_start = df['ticker2'].iloc[0]
    
    
    if val_first < val_second:                                 
        mask_val_first = np.array(df['close'] < val_first)
        mask_val_second = np.array(df['close'] > val_second)
    else: #short game
        assert 1 == 0, 'Error: short game'
        mask_val_first = np.array(df['close'] > val_first)
        mask_val_second = np.array(df['close'] < val_second)

    
    if (mask_val_first.sum() == 0) & (mask_val_second.sum() == 0):

        ind_end = df.shape[0]-1
        delta_time = df['time'].iloc[ind_end] - df['time'].iloc[0]
        res_price = df['close'].iloc[ind_end]
        if val_first < val_second:
            #income_rate = res_price/start_price
            x_end = df['ticker1'].iloc[ind_end]
            y_end = df['ticker2'].iloc[ind_end]
            income_rate = get_income_rate(x_start, x_end, y_start, y_end)
        else: #short game
            assert 1 == 0, 'Error: short game'
            #income_rate = (2*start_price-res_price)/start_price
        return 'DNF', delta_time, income_rate, res_price, ind_end+ind
        
    if (mask_val_first.sum() == 0) & (mask_val_second.sum() != 0):
        ind_val_second = np.argwhere(mask_val_second).ravel()[0]
        delta_time = df['time'].iloc[ind_val_second] - df['time'].iloc[0]
        res_price = df['close'].iloc[ind_val_second]
        if val_first < val_second:
            #income_rate = res_price/start_price
            x_end = df['ticker1'].iloc[ind_val_second]
            y_end = df['ticker2'].iloc[ind_val_second]
            income_rate = get_income_rate(x_start, x_end, y_start, y_end)
        else: #short game
            assert 1 == 0, 'Error: short game'
            #income_rate = (2*start_price-res_price)/start_price
        return 'WIN', delta_time, income_rate, res_price, ind_val_second+ind
        
    if (mask_val_first.sum() != 0) & (mask_val_second.sum() == 0):
        ind_val_first = np.argwhere(mask_val_first).ravel()[0]
        delta_time = df['time'].iloc[ind_val_first] - df['time'].iloc[0]
        res_price = df['close'].iloc[ind_val_first]
        if val_first < val_second:
            #income_rate = res_price/start_price
            x_end = df['ticker1'].iloc[ind_val_first]
            y_end = df['ticker2'].iloc[ind_val_first]
            income_rate = get_income_rate(x_start, x_end, y_start, y_end)
        else: #short game
            assert 1 == 0, 'Error: short game'
            #income_rate = (2*start_price-res_price)/start_price
        return 'LOSE', delta_time, income_rate, res_price, ind_val_first+ind

    if (mask_val_first.sum() != 0) & (mask_val_second.sum() != 0):
        ind_val_first = np.argwhere(mask_val_first).ravel()[0]
        ind_val_second = np.argwhere(mask_val_second).ravel()[0]
        if ind_val_first < ind_val_second:
            delta_time = df['time'].iloc[ind_val_first] - df['time'].iloc[0]
            res_price = df['close'].iloc[ind_val_first]
            if val_first < val_second:
                #income_rate = res_price/start_price
                x_end = df['ticker1'].iloc[ind_val_first]
                y_end = df['ticker2'].iloc[ind_val_first]
                income_rate = get_income_rate(x_start, x_end, y_start, y_end)
            else: #short game
                assert 1 == 0, 'Error: short game'
                #income_rate = (2*start_price-res_price)/start_price
            return 'LOSE', delta_time, income_rate, res_price, ind_val_first+ind
        if ind_val_first > ind_val_second:
            delta_time = df['time'].iloc[ind_val_second] - df['time'].iloc[0]
            res_price = df['close'].iloc[ind_val_second]
            if val_first < val_second:
                #income_rate = res_price/start_price
                x_end = df['ticker1'].iloc[ind_val_second]
                y_end = df['ticker2'].iloc[ind_val_second]
                income_rate = get_income_rate(x_start, x_end, y_start, y_end)
            else:  #short game
                assert 1 == 0, 'Error: short game'
                #income_rate = (2*start_price-res_price)/start_price
            return 'WIN', delta_time, income_rate, res_price, ind_val_second+ind


def get_df_target(df, indx, percent_first=None, percent_second=None, points_to_wait=None):
    times = []
    results = []
    delta_times = []
    income_rates = []
    closes = []
    tickers = []
    res_prices = []
    res_inds = []
    
    #for ind in indx:
    for ind in tqdm(indx):
        time = df['time'].iloc[ind]
        close = df['close'].iloc[ind]
        ticker = df['ticker'].iloc[ind]
        
        val_first = df['close'].iloc[ind] * percent_first
        val_second = df['close'].iloc[ind] * percent_second
        result, delta_time, income_rate, res_price, res_ind = get_target(df, ind, val_first, val_second, points_to_wait)
        
        times += [time]
        closes += [close]
        tickers += [ticker]
        results += [result]
        delta_times += [delta_time]
        income_rates += [income_rate]
        res_prices += [res_price]
        res_inds += [res_ind]
        

    df_result = pd.DataFrame({'ind' : indx,
                              'time' : times,
                              'close' : closes,
                              'result' : results,
                              'ticker' : tickers, 
                              'delta_time' : delta_times,
                              'income_rate' : income_rates,
                              'res_price' : res_prices,
                              'res_ind' : res_inds
                             })

    # #макс выигрыш и потери
    # if percent_first < percent_second:  
    #     df_result["income_rate"] = np.maximum(df_result["income_rate"], percent_first) #макс потери
    #     df_result["income_rate"] = np.minimum(df_result["income_rate"], percent_second) #макс выигрыш
    # else:
    #     df_result["income_rate"] = np.maximum(df_result["income_rate"], 2-percent_first) #макс потери
    #     df_result["income_rate"] = np.minimum(df_result["income_rate"], 2-percent_second) #макс выигрыш
    
    # df_result['income_rate'] -= 0.001
    
    return df_result

# %%
inds = np.arange(df.shape[0])
inds.shape
# Out:
# (5321140,)

# %%
df_result = get_df_target(df[['time', 'close', 'ticker', 'ticker1', 'ticker2']], inds, percent_first=0.97, percent_second=1.03, points_to_wait=24*10)
df_result

# %%
# dump_pkl(df_result, './data/lgbm/target_5to3_10days.pkl')
# dump_pkl(df_result, './data/lgbm/target_3to5_10days.pkl')
# dump_pkl(df_result, './data/lgbm/target_3to3_10days.pkl')
# dump_pkl(df_result, './data/lgbm/target_5to5_10days.pkl')
# dump_pkl(df_result, './data/lgbm/target_1.5to1.5_10days.pkl')
# dump_pkl(df_result, './data/lgbm/target_3to3_2days.pkl')


df_result = load_pkl('./data/lgbm/target_5to5_10days.pkl')

# %%
df_result.loc[:, 'result'].value_counts(normalize=True)
# Out:
# result
# WIN     0.475879
# LOSE    0.453739
# DNF     0.070383
# Name: proportion, dtype: float64

# %%
df_result.loc[:, 'income_rate'].quantile(q=[0, 0.01]+np.arange(0.1, 1, 0.1).tolist()+[0.99, 1])
# Out:
# 0.00    0.711900
# 0.01    0.952790
# 0.10    0.967783
# 0.20    0.970557
# 0.30    0.972108
# 0.40    0.973765
# 0.50    1.003366
# 0.60    1.023432
# 0.70    1.024811
# 0.80    1.026302
# 0.90    1.029050
# 0.99    1.044034
# 1.00    1.286100
# Name: income_rate, dtype: float64

# %%
#распределение времени (в днях)
(df_result.loc[:, 'delta_time']/ pd.Timedelta('24 hour')).quantile(q=[0, 0.01]+np.arange(0.1, 1, 0.1).tolist()+[0.99, 1])
# Out:
# 0.00     0.000000
# 0.01     0.125000
# 0.10     0.458333
# 0.20     0.833333
# 0.30     1.208333
# 0.40     1.625000
# 0.50     2.208333
# 0.60     2.875000
# 0.70     3.833333
# 0.80     5.250000
# 0.90     7.958333
# 0.99    10.000000
# 1.00    10.000000
# Name: delta_time, dtype: float64

# %%
(df['close'].values == df_result['close'].values).all(), (df['time'].values == df_result['time'].values).all()
# Out:
# (True, True)

# %%
df_result.head()
# Out:
#    ind                time     close result              ticker  \
# 0    0 2023-10-01 00:00:00  0.004853   LOSE  LINK-USDT_ETH-USDT
# 1    1 2023-10-01 01:00:00  0.004885   LOSE  LINK-USDT_ETH-USDT
# 2    2 2023-10-01 02:00:00  0.004901   LOSE  LINK-USDT_ETH-USDT
# 3    3 2023-10-01 03:00:00  0.004927   LOSE  LINK-USDT_ETH-USDT
# 4    4 2023-10-01 04:00:00  0.004877   LOSE  LINK-USDT_ETH-USDT
#
#        delta_time  income_rate  res_price  res_ind
# 0 1 days 03:00:00     0.972209   0.004600       27
# 1 1 days 02:00:00     0.969011   0.004600       27
# 2 1 days 00:00:00     0.971785   0.004644       26
# 3 0 days 17:00:00     0.973479   0.004676       20
# 4 0 days 23:00:00     0.969785   0.004600       27

# %%
df.head()
# Out:
#                  time  ticker1  ticker2     close              ticker  \
# 0 2023-10-01 00:00:00    8.125  1674.34  0.004853  LINK-USDT_ETH-USDT
# 1 2023-10-01 01:00:00    8.182  1675.00  0.004885  LINK-USDT_ETH-USDT
# 2 2023-10-01 02:00:00    8.189  1670.88  0.004901  LINK-USDT_ETH-USDT
# 3 2023-10-01 03:00:00    8.248  1673.97  0.004927  LINK-USDT_ETH-USDT
# 4 2023-10-01 04:00:00    8.163  1673.85  0.004877  LINK-USDT_ETH-USDT
#
#    close_1hour_w1_roc  close_1hour_w5_norm_std  close_1hour_w5_mean_abs_pct  \
# 0           -0.000212                 0.001655                     0.001952
# 1            0.006618                 0.002966                     0.003229
# 2            0.003323                 0.004249                     0.003463
# 3            0.005345                 0.006522                     0.003794
# 4           -0.010234                 0.005686                     0.005147
#
#    close_1hour_w5_alpha  close_1hour_w5_rsi  ...  \
# 0         -76809.179688           37.773579  ...
# 1          55649.933594           63.815258  ...
# 2          53617.660156           78.713341  ...
# 3          48150.113281           80.617393  ...
# 4          29338.947266           59.163799  ...
#
#    close_1hour_w200_ma_up_2std/close_1hour  \
# 0                                 1.017613
# 1                                 1.010994
# 2                                 1.007771
# 3                                 1.002625
# 4                                 1.013116
#
#    close_1hour_w200_ma_low_3std/close_1hour  \
# 0                                  0.858567
# 1                                  0.854461
# 2                                  0.853115
# 3                                  0.849995
# 4                                  0.860112
#
#    close_1hour_w200_ma_up_3std/close_1hour  \
# 0                                 1.049422
# 1                                 1.042301
# 2                                 1.038703
# 3                                 1.033151
# 4                                 1.043716
#
#    close_1hour_w5_min/close_1hour_w5_max  \
# 0                               0.996295
# 1                               0.993400
# 2                               0.990110
# 3                               0.984846
# 4                               0.984846
#
#    close_1hour_w10_min/close_1hour_w10_max  \
# 0                                 0.992175
# 1                                 0.992175
# 2                                 0.989161
# 3                                 0.984845
# 4                                 0.984845
#
#    close_1hour_w20_min/close_1hour_w20_max  \
# 0                                 0.979237
# 1                                 0.979237
# 2                                 0.977100
# 3                                 0.971905
# 4                                 0.971905
#
#    close_1hour_w30_min/close_1hour_w30_max  \
# 0                                 0.957690
# 1                                 0.957690
# 2                                 0.972409
# 3                                 0.967239
# 4                                 0.967239
#
#    close_1hour_w60_min/close_1hour_w60_max  \
# 0                                 0.941715
# 1                                 0.941715
# 2                                 0.939660
# 3                                 0.934664
# 4                                 0.934664
#
#    close_1hour_w120_min/close_1hour_w120_max  \
# 0                                   0.935259
# 1                                   0.935259
# 2                                   0.933219
# 3                                   0.928257
# 4                                   0.928257
#
#    close_1hour_w200_min/close_1hour_w200_max
# 0                                   0.867259
# 1                                   0.867780
# 2                                   0.865887
# 3                                   0.869934
# 4                                   0.876473
#
# [5 rows x 319 columns]

# %%
df[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']] = df_result[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']].values
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_40449/2704779713.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']] = df_result[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']].values
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_40449/2704779713.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']] = df_result[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']].values
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_40449/2704779713.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']] = df_result[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']].values
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_40449/2704779713.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']] = df_result[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']].values
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_40449/2704779713.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']] = df_result[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']].values
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_40449/2704779713.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']] = df_result[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']].values

# %%
df.head()
# Out:
#                  time  ticker1  ticker2     close              ticker  \
# 0 2023-10-01 00:00:00    8.125  1674.34  0.004853  LINK-USDT_ETH-USDT
# 1 2023-10-01 01:00:00    8.182  1675.00  0.004885  LINK-USDT_ETH-USDT
# 2 2023-10-01 02:00:00    8.189  1670.88  0.004901  LINK-USDT_ETH-USDT
# 3 2023-10-01 03:00:00    8.248  1673.97  0.004927  LINK-USDT_ETH-USDT
# 4 2023-10-01 04:00:00    8.163  1673.85  0.004877  LINK-USDT_ETH-USDT
#
#    close_1hour_w1_roc  close_1hour_w5_norm_std  close_1hour_w5_mean_abs_pct  \
# 0           -0.000212                 0.001655                     0.001952
# 1            0.006618                 0.002966                     0.003229
# 2            0.003323                 0.004249                     0.003463
# 3            0.005345                 0.006522                     0.003794
# 4           -0.010234                 0.005686                     0.005147
#
#    close_1hour_w5_alpha  close_1hour_w5_rsi  ...  \
# 0         -76809.179688           37.773579  ...
# 1          55649.933594           63.815258  ...
# 2          53617.660156           78.713341  ...
# 3          48150.113281           80.617393  ...
# 4          29338.947266           59.163799  ...
#
#    close_1hour_w30_min/close_1hour_w30_max  \
# 0                                 0.957690
# 1                                 0.957690
# 2                                 0.972409
# 3                                 0.967239
# 4                                 0.967239
#
#    close_1hour_w60_min/close_1hour_w60_max  \
# 0                                 0.941715
# 1                                 0.941715
# 2                                 0.939660
# 3                                 0.934664
# 4                                 0.934664
#
#    close_1hour_w120_min/close_1hour_w120_max  \
# 0                                   0.935259
# 1                                   0.935259
# 2                                   0.933219
# 3                                   0.928257
# 4                                   0.928257
#
#    close_1hour_w200_min/close_1hour_w200_max  ind  result      delta_time  \
# 0                                   0.867259    0    LOSE 1 days 03:00:00
# 1                                   0.867780    1    LOSE 1 days 02:00:00
# 2                                   0.865887    2    LOSE 1 days 00:00:00
# 3                                   0.869934    3    LOSE 0 days 17:00:00
# 4                                   0.876473    4    LOSE 0 days 23:00:00
#
#    income_rate  res_price  res_ind
# 0     0.972209     0.0046       27
# 1     0.969011     0.0046       27
# 2     0.971785   0.004644       26
# 3     0.973479   0.004676       20
# 4     0.969785     0.0046       27
#
# [5 rows x 325 columns]

# %%
#проверить данные

#mask = df['time'] >= pd.Timestamp('2025-02-01')


i = 4781 	
cols = ['ticker', 'time', 'ticker1', 'ticker2', 'close', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']
df.loc[:, cols].iloc[i:i+12]
# Out:
#                   ticker                time  ticker1  ticker2     close  \
# 4781  LINK-USDT_ETH-USDT 2024-04-17 05:00:00   13.381  3085.58  0.004337
# 4782  LINK-USDT_ETH-USDT 2024-04-17 06:00:00   13.413  3095.21  0.004333
# 4783  LINK-USDT_ETH-USDT 2024-04-17 07:00:00   13.546  3112.64  0.004352
# 4784  LINK-USDT_ETH-USDT 2024-04-17 08:00:00   13.414  3089.54  0.004342
# 4785  LINK-USDT_ETH-USDT 2024-04-17 09:00:00   13.452  3091.24  0.004352
# 4786  LINK-USDT_ETH-USDT 2024-04-17 10:00:00   13.467  3077.11  0.004377
# 4787  LINK-USDT_ETH-USDT 2024-04-17 11:00:00   13.445  3073.69  0.004374
# 4788  LINK-USDT_ETH-USDT 2024-04-17 12:00:00   13.587  3079.01  0.004413
# 4789  LINK-USDT_ETH-USDT 2024-04-17 13:00:00   13.464  3059.67  0.004400
# 4790  LINK-USDT_ETH-USDT 2024-04-17 14:00:00   13.234  3040.21  0.004353
# 4791  LINK-USDT_ETH-USDT 2024-04-17 15:00:00   13.217  3031.61  0.004360
# 4792  LINK-USDT_ETH-USDT 2024-04-17 16:00:00   13.301  3043.30  0.004371
#
#      result      delta_time income_rate res_price res_ind
# 4781    WIN 2 days 20:00:00    1.024755  0.004561    4849
# 4782    WIN 2 days 19:00:00    1.025054  0.004561    4849
# 4783    WIN 2 days 21:00:00    1.029331  0.004621    4852
# 4784    WIN 2 days 17:00:00    1.024106  0.004561    4849
# 4785    WIN 2 days 19:00:00    1.029575  0.004621    4852
# 4786    WIN 2 days 18:00:00    1.026725  0.004621    4852
# 4787    WIN 2 days 17:00:00     1.02703  0.004621    4852
# 4788    WIN 3 days 02:00:00    1.025499  0.004649    4862
# 4789    WIN 2 days 15:00:00    1.024016  0.004621    4852
# 4790    WIN 2 days 14:00:00    1.029924  0.004621    4852
# 4791    WIN 2 days 13:00:00    1.029186  0.004621    4852
# 4792    WIN 2 days 12:00:00    1.027751  0.004621    4852

# %% [markdown]
# ### 1. train/valid/test/test2 split

# %%
#subsample

coeff_subsample = 0.3 #0.3

inds = np.arange(df.shape[0], dtype=int)
inds_subsample = np.random.RandomState(seed=42).permutation(inds)[:int(len(inds)*coeff_subsample)]

mask_subsample = np.zeros(df.shape[0]).astype(bool)
mask_subsample[inds_subsample] = True


mask_subsample.sum(), mask_subsample.mean()
# Out:
# (1596342, 0.3)

# %%
# mask_time
mask = df['time'] < pd.Timestamp('2025-04-26')
mask_subsample &= mask

mask_subsample.sum(), mask_subsample.mean()
# Out:
# (1567655, 0.29460886201077213)

# %%
df = df.loc[mask_subsample, :]
gc.collect()

df.shape
# Out:
# (1567655, 325)

# %%
df['target'] = (df['result'] == 'WIN').astype(int)
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_40449/162261981.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['target'] = (df['result'] == 'WIN').astype(int)

# %%
df.loc[:, ['time', 'target']].groupby(pd.Grouper(key='time', freq='ME')).target.mean().plot.bar()
# Out:
# <Axes: xlabel='time'>

# %%
(df.loc[:, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq='ME')).income_rate.mean()-1).plot.bar()
# Out:
# <Axes: xlabel='time'>

# %%
pd.set_option('display.max_rows', 150)
df.loc[:, ['ticker', 'target']].groupby('ticker').target.mean().sort_values()
# Out:
# ticker
# ETH-USDT_BTC-USDT     0.240973
# ETC-USDT_BTC-USDT     0.337518
# LTC-USDT_BTC-USDT     0.337617
# DOT-USDT_BTC-USDT     0.338271
# DOT-USDT_ADA-USDT     0.338317
#                         ...
# BTC-USDT_DOT-USDT     0.616591
# BTC-USDT_ATOM-USDT    0.617052
# BTC-USDT_ARB-USDT     0.618559
# SOL-USDT_ARB-USDT     0.628663
# BTC-USDT_OP-USDT      0.637166
# Name: target, Length: 380, dtype: float64

# %%
df.loc[:, ['ticker', 'income_rate']].groupby('ticker').income_rate.mean().sort_values()
# Out:
# ticker
# ARB-USDT_SOL-USDT     0.990839
# DOT-USDT_BTC-USDT     0.991514
# ETH-USDT_BTC-USDT     0.991825
# ATOM-USDT_BTC-USDT     0.99272
# ARB-USDT_BTC-USDT     0.992995
#                         ...
# DOT-USDT_ARB-USDT     1.005369
# BTC-USDT_ATOM-USDT    1.005403
# BTC-USDT_ETH-USDT     1.005612
# BTC-USDT_DOT-USDT     1.005778
# SOL-USDT_ARB-USDT     1.006749
# Name: income_rate, Length: 380, dtype: object

# %%
df['time'].min(), df['time'].max()
# Out:
# (Timestamp('2023-10-01 00:00:00'), Timestamp('2025-04-25 23:00:00'))

# %%
mask_train = np.array(df['time'] < pd.Timestamp('2024-10-01'))
mask_valid = np.array((pd.Timestamp('2024-10-01') <= df['time']) & (df['time'] < pd.Timestamp('2025-01-01')))
mask_test = np.array((pd.Timestamp('2025-01-01') <= df['time']) & (df['time'] < pd.Timestamp('2025-04-01')))
mask_test2 = np.array(pd.Timestamp('2025-04-01') <= df['time'])

# %%
# mask_train = mask_train|mask_valid
# mask_valid = mask_test
# mask_test = mask_test2
# mask_test2 = mask_test

# %%
mask_train.sum(), mask_valid.sum(), mask_test.sum(), mask_test2.sum()
# Out:
# (1001559, 251100, 246276, 68720)

# %%
#mask_test3.sum()

# %%
mask_data = mask_train|mask_valid|mask_test|mask_test2
(mask_data).sum()
# Out:
# 1567655

# %%
mask_train.sum()/(mask_data).sum(), mask_valid.sum()/(mask_data).sum(), mask_test.sum()/(mask_data).sum(), mask_test2.sum()/(mask_data).sum()
# Out:
# (0.6388899343286629,
#  0.16017554882930238,
#  0.15709834115286844,
#  0.043836175689166305)

# %%
df.loc[mask_train, 'target'].mean(), df.loc[mask_valid, 'target'].mean(), df.loc[mask_test, 'target'].mean(), df.loc[mask_test2, 'target'].mean()
# Out:
# (0.47767031198361753,
#  0.4867184388689765,
#  0.4915257678377105,
#  0.4645954598370198)

# %%
#df.loc[mask_test3, 'target'].mean()

# %%
df.loc[mask_train, 'income_rate'].mean(), df.loc[mask_valid, 'income_rate'].mean(), df.loc[mask_test, 'income_rate'].mean(), df.loc[mask_test2, 'income_rate'].mean()
# Out:
# (0.999052829850874, 0.9990670305249186, 0.9989896531175313, 0.999099835508286)

# %%
#df.loc[mask_test3, 'income_rate'].mean()

# %%
#проверки

# %%
(mask_train.sum()+mask_valid.sum()+mask_test.sum()+mask_test2.sum()) ==(mask_data).sum()

#(mask_train.sum()+mask_valid.sum()+mask_test.sum()) ==(mask_data).sum()
# Out:
# True

# %% [markdown]
# ## 3. Model

# %% [markdown]
# ### 3.1 Base model

# %%
df['ticker_code'] = df['ticker'].astype('category').cat.codes
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_40449/153766446.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['ticker_code'] = df['ticker'].astype('category').cat.codes

# %%
df['ticker_code'].nunique()
# Out:
# 380

# %%
df.loc[mask_train, 'ticker_code'].nunique()
# Out:
# 380

# %%
drop_cols = [
 'time',
 'close',
    
 'ticker1', 'ticker2',
 'ticker',

    
 'ind',
 'result',
 'delta_time',
 'income_rate',
 'res_price',
 'res_ind',


    
             'target',
             'y_pred']


features_all = df.columns[~df.columns.isin(drop_cols)].tolist()

cat_features_all = ['ticker_code',
                'hour', 'day', 'weekday',
]
cat_features = cat_features_all

target = 'target'

# %%
# def get_useful_features(feature):
#     # if ('1day' not in feature) and ('1hour' not in feature):
#     #     return False
#     # if 'roc' in feature:
#     #     return False
    
#     for elem in ['expma']: #, 'alpha'
#         if elem in feature:
#             return True
#     return False

# mask_useful_features = np.array([get_useful_features(feature) for feature in features_all])
# features_useful = np.array(features_all)[mask_useful_features].tolist()
# len(features_useful), features_useful

# %%
# features_all = features_useful
# cat_features_all = []
# cat_features = []

# %%
len(features_all), len(cat_features)
# Out:
# (315, 4)

# %%
features_all
# Out:
# ['close_1hour_w1_roc',
#  'close_1hour_w5_norm_std',
#  'close_1hour_w5_mean_abs_pct',
#  'close_1hour_w5_alpha',
#  'close_1hour_w5_rsi',
#  'close_1hour_w5_roc',
#  'close_1hour_w10_norm_std',
#  'close_1hour_w10_mean_abs_pct',
#  'close_1hour_w10_alpha',
#  'close_1hour_w10_rsi',
#  'close_1hour_w10_roc',
#  'close_1hour_w20_norm_std',
#  'close_1hour_w20_mean_abs_pct',
#  'close_1hour_w20_alpha',
#  'close_1hour_w20_rsi',
#  'close_1hour_w20_roc',
#  'close_1hour_w30_norm_std',
#  'close_1hour_w30_mean_abs_pct',
#  'close_1hour_w30_alpha',
#  'close_1hour_w30_rsi',
#  'close_1hour_w30_roc',
#  'close_1hour_w30_lvl_1-1.02',
#  'close_1hour_w30_lvl_-0.98-1',
#  'close_1hour_w30_lvl_1.02-1.03',
#  'close_1hour_w30_lvl_-0.97-0.98',
#  'close_1hour_w30_lvl_1.03-1.05',
#  'close_1hour_w30_lvl_-0.95-0.97',
#  'close_1hour_w30_lvl_1.05-1.08',
#  'close_1hour_w30_lvl_-0.92-0.95',
#  'close_1hour_w30_lvl_1.08-1.1',
#  'close_1hour_w30_lvl_-0.9-0.92',
#  'close_1hour_w60_norm_std',
#  'close_1hour_w60_mean_abs_pct',
#  'close_1hour_w60_alpha',
#  'close_1hour_w60_rsi',
#  'close_1hour_w60_roc',
#  'close_1hour_w120_norm_std',
#  'close_1hour_w120_mean_abs_pct',
#  'close_1hour_w120_alpha',
#  'close_1hour_w120_rsi',
#  'close_1hour_w120_roc',
#  'close_1hour_w120_lvl_1-1.02',
#  'close_1hour_w120_lvl_-0.98-1',
#  'close_1hour_w120_lvl_1.02-1.03',
#  'close_1hour_w120_lvl_-0.97-0.98',
#  'close_1hour_w120_lvl_1.03-1.05',
#  'close_1hour_w120_lvl_-0.95-0.97',
#  'close_1hour_w120_lvl_1.05-1.08',
#  'close_1hour_w120_lvl_-0.92-0.95',
#  'close_1hour_w120_lvl_1.08-1.1',
#  'close_1hour_w120_lvl_-0.9-0.92',
#  'close_1hour_w200_norm_std',
#  'close_1hour_w200_mean_abs_pct',
#  'close_1hour_w200_alpha',
#  'close_1hour_w200_rsi',
#  'close_1hour_w200_roc',
#  'close_1hour_w200_lvl_1-1.02',
#  'close_1hour_w200_lvl_-0.98-1',
#  'close_1hour_w200_lvl_1.02-1.03',
#  'close_1hour_w200_lvl_-0.97-0.98',
#  'close_1hour_w200_lvl_1.03-1.05',
#  'close_1hour_w200_lvl_-0.95-0.97',
#  'close_1hour_w200_lvl_1.05-1.08',
#  'close_1hour_w200_lvl_-0.92-0.95',
#  'close_1hour_w200_lvl_1.08-1.1',
#  'close_1hour_w200_lvl_-0.9-0.92',
#  'hour',
#  'day',
#  'weekday',
#  'close_1hour_w1_roc/close_1hour_w5_alpha',
#  'close_1hour_w1_roc/close_1hour_w10_alpha',
#  'close_1hour_w1_roc/close_1hour_w20_alpha',
#  'close_1hour_w1_roc/close_1hour_w30_alpha',
#  'close_1hour_w1_roc/close_1hour_w60_alpha',
#  'close_1hour_w1_roc/close_1hour_w120_alpha',
#  'close_1hour_w1_roc/close_1hour_w200_alpha',
#  'close_1hour_w5_alpha/close_1hour_w10_alpha',
#  'close_1hour_w5_alpha/close_1hour_w20_alpha',
#  'close_1hour_w5_alpha/close_1hour_w30_alpha',
#  'close_1hour_w5_alpha/close_1hour_w60_alpha',
#  'close_1hour_w5_alpha/close_1hour_w120_alpha',
#  'close_1hour_w5_alpha/close_1hour_w200_alpha',
#  'close_1hour_w10_alpha/close_1hour_w20_alpha',
#  'close_1hour_w10_alpha/close_1hour_w30_alpha',
#  'close_1hour_w10_alpha/close_1hour_w60_alpha',
#  'close_1hour_w10_alpha/close_1hour_w120_alpha',
#  'close_1hour_w10_alpha/close_1hour_w200_alpha',
#  'close_1hour_w20_alpha/close_1hour_w30_alpha',
#  'close_1hour_w20_alpha/close_1hour_w60_alpha',
#  'close_1hour_w20_alpha/close_1hour_w120_alpha',
#  'close_1hour_w20_alpha/close_1hour_w200_alpha',
#  'close_1hour_w30_alpha/close_1hour_w60_alpha',
#  'close_1hour_w30_alpha/close_1hour_w120_alpha',
#  'close_1hour_w30_alpha/close_1hour_w200_alpha',
#  'close_1hour_w60_alpha/close_1hour_w120_alpha',
#  'close_1hour_w60_alpha/close_1hour_w200_alpha',
#  'close_1hour_w120_alpha/close_1hour_w200_alpha',
#  'close_1hour_w1_roc/close_1hour_w5_roc',
#  'close_1hour_w1_roc/close_1hour_w10_roc',
#  'close_1hour_w1_roc/close_1hour_w20_roc',
#  'close_1hour_w1_roc/close_1hour_w30_roc',
#  'close_1hour_w1_roc/close_1hour_w60_roc',
#  'close_1hour_w1_roc/close_1hour_w120_roc',
#  'close_1hour_w1_roc/close_1hour_w200_roc',
#  'close_1hour_w5_roc/close_1hour_w10_roc',
#  'close_1hour_w5_roc/close_1hour_w20_roc',
#  'close_1hour_w5_roc/close_1hour_w30_roc',
#  'close_1hour_w5_roc/close_1hour_w60_roc',
#  'close_1hour_w5_roc/close_1hour_w120_roc',
#  'close_1hour_w5_roc/close_1hour_w200_roc',
#  'close_1hour_w10_roc/close_1hour_w20_roc',
#  'close_1hour_w10_roc/close_1hour_w30_roc',
#  'close_1hour_w10_roc/close_1hour_w60_roc',
#  'close_1hour_w10_roc/close_1hour_w120_roc',
#  'close_1hour_w10_roc/close_1hour_w200_roc',
#  'close_1hour_w20_roc/close_1hour_w30_roc',
#  'close_1hour_w20_roc/close_1hour_w60_roc',
#  'close_1hour_w20_roc/close_1hour_w120_roc',
#  'close_1hour_w20_roc/close_1hour_w200_roc',
#  'close_1hour_w30_roc/close_1hour_w60_roc',
#  'close_1hour_w30_roc/close_1hour_w120_roc',
#  'close_1hour_w30_roc/close_1hour_w200_roc',
#  'close_1hour_w60_roc/close_1hour_w120_roc',
#  'close_1hour_w60_roc/close_1hour_w200_roc',
#  'close_1hour_w120_roc/close_1hour_w200_roc',
#  'close_1hour_w5_mean_abs_pct/close_1hour_w10_mean_abs_pct',
#  'close_1hour_w5_mean_abs_pct/close_1hour_w20_mean_abs_pct',
#  'close_1hour_w5_mean_abs_pct/close_1hour_w30_mean_abs_pct',
#  'close_1hour_w5_mean_abs_pct/close_1hour_w60_mean_abs_pct',
#  'close_1hour_w5_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#  'close_1hour_w5_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#  'close_1hour_w10_mean_abs_pct/close_1hour_w20_mean_abs_pct',
#  'close_1hour_w10_mean_abs_pct/close_1hour_w30_mean_abs_pct',
#  'close_1hour_w10_mean_abs_pct/close_1hour_w60_mean_abs_pct',
#  'close_1hour_w10_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#  'close_1hour_w10_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#  'close_1hour_w20_mean_abs_pct/close_1hour_w30_mean_abs_pct',
#  'close_1hour_w20_mean_abs_pct/close_1hour_w60_mean_abs_pct',
#  'close_1hour_w20_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#  'close_1hour_w20_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#  'close_1hour_w30_mean_abs_pct/close_1hour_w60_mean_abs_pct',
#  'close_1hour_w30_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#  'close_1hour_w30_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#  'close_1hour_w60_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#  'close_1hour_w60_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#  'close_1hour_w120_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#  'close_1hour_w5_std/close_1hour_w10_std',
#  'close_1hour_w5_std/close_1hour_w20_std',
#  'close_1hour_w5_std/close_1hour_w30_std',
#  'close_1hour_w5_std/close_1hour_w60_std',
#  'close_1hour_w5_std/close_1hour_w120_std',
#  'close_1hour_w5_std/close_1hour_w200_std',
#  'close_1hour_w10_std/close_1hour_w20_std',
#  'close_1hour_w10_std/close_1hour_w30_std',
#  'close_1hour_w10_std/close_1hour_w60_std',
#  'close_1hour_w10_std/close_1hour_w120_std',
#  'close_1hour_w10_std/close_1hour_w200_std',
#  'close_1hour_w20_std/close_1hour_w30_std',
#  'close_1hour_w20_std/close_1hour_w60_std',
#  'close_1hour_w20_std/close_1hour_w120_std',
#  'close_1hour_w20_std/close_1hour_w200_std',
#  'close_1hour_w30_std/close_1hour_w60_std',
#  'close_1hour_w30_std/close_1hour_w120_std',
#  'close_1hour_w30_std/close_1hour_w200_std',
#  'close_1hour_w60_std/close_1hour_w120_std',
#  'close_1hour_w60_std/close_1hour_w200_std',
#  'close_1hour_w120_std/close_1hour_w200_std',
#  'close_1hour_w5_norm_std/close_1hour_w10_norm_std',
#  'close_1hour_w5_norm_std/close_1hour_w20_norm_std',
#  'close_1hour_w5_norm_std/close_1hour_w30_norm_std',
#  'close_1hour_w5_norm_std/close_1hour_w60_norm_std',
#  'close_1hour_w5_norm_std/close_1hour_w120_norm_std',
#  'close_1hour_w5_norm_std/close_1hour_w200_norm_std',
#  'close_1hour_w10_norm_std/close_1hour_w20_norm_std',
#  'close_1hour_w10_norm_std/close_1hour_w30_norm_std',
#  'close_1hour_w10_norm_std/close_1hour_w60_norm_std',
#  'close_1hour_w10_norm_std/close_1hour_w120_norm_std',
#  'close_1hour_w10_norm_std/close_1hour_w200_norm_std',
#  'close_1hour_w20_norm_std/close_1hour_w30_norm_std',
#  'close_1hour_w20_norm_std/close_1hour_w60_norm_std',
#  'close_1hour_w20_norm_std/close_1hour_w120_norm_std',
#  'close_1hour_w20_norm_std/close_1hour_w200_norm_std',
#  'close_1hour_w30_norm_std/close_1hour_w60_norm_std',
#  'close_1hour_w30_norm_std/close_1hour_w120_norm_std',
#  'close_1hour_w30_norm_std/close_1hour_w200_norm_std',
#  'close_1hour_w60_norm_std/close_1hour_w120_norm_std',
#  'close_1hour_w60_norm_std/close_1hour_w200_norm_std',
#  'close_1hour_w120_norm_std/close_1hour_w200_norm_std',
#  'close_1hour_w5_rsi/close_1hour_w10_rsi',
#  'close_1hour_w5_rsi/close_1hour_w20_rsi',
#  'close_1hour_w5_rsi/close_1hour_w30_rsi',
#  'close_1hour_w5_rsi/close_1hour_w60_rsi',
#  'close_1hour_w5_rsi/close_1hour_w120_rsi',
#  'close_1hour_w5_rsi/close_1hour_w200_rsi',
#  'close_1hour_w10_rsi/close_1hour_w20_rsi',
#  'close_1hour_w10_rsi/close_1hour_w30_rsi',
#  'close_1hour_w10_rsi/close_1hour_w60_rsi',
#  'close_1hour_w10_rsi/close_1hour_w120_rsi',
#  'close_1hour_w10_rsi/close_1hour_w200_rsi',
#  'close_1hour_w20_rsi/close_1hour_w30_rsi',
#  'close_1hour_w20_rsi/close_1hour_w60_rsi',
#  'close_1hour_w20_rsi/close_1hour_w120_rsi',
#  'close_1hour_w20_rsi/close_1hour_w200_rsi',
#  'close_1hour_w30_rsi/close_1hour_w60_rsi',
#  'close_1hour_w30_rsi/close_1hour_w120_rsi',
#  'close_1hour_w30_rsi/close_1hour_w200_rsi',
#  'close_1hour_w60_rsi/close_1hour_w120_rsi',
#  'close_1hour_w60_rsi/close_1hour_w200_rsi',
#  'close_1hour_w120_rsi/close_1hour_w200_rsi',
#  'close_1hour/close_1hour_w5_ma',
#  'close_1hour/close_1hour_w10_ma',
#  'close_1hour/close_1hour_w20_ma',
#  'close_1hour/close_1hour_w30_ma',
#  'close_1hour/close_1hour_w60_ma',
#  'close_1hour/close_1hour_w120_ma',
#  'close_1hour/close_1hour_w200_ma',
#  'close_1hour_w5_ma/close_1hour_w10_ma',
#  'close_1hour_w5_ma/close_1hour_w20_ma',
#  'close_1hour_w5_ma/close_1hour_w30_ma',
#  'close_1hour_w5_ma/close_1hour_w60_ma',
#  'close_1hour_w5_ma/close_1hour_w120_ma',
#  'close_1hour_w5_ma/close_1hour_w200_ma',
#  'close_1hour_w10_ma/close_1hour_w20_ma',
#  'close_1hour_w10_ma/close_1hour_w30_ma',
#  'close_1hour_w10_ma/close_1hour_w60_ma',
#  'close_1hour_w10_ma/close_1hour_w120_ma',
#  'close_1hour_w10_ma/close_1hour_w200_ma',
#  'close_1hour_w20_ma/close_1hour_w30_ma',
#  'close_1hour_w20_ma/close_1hour_w60_ma',
#  'close_1hour_w20_ma/close_1hour_w120_ma',
#  'close_1hour_w20_ma/close_1hour_w200_ma',
#  'close_1hour_w30_ma/close_1hour_w60_ma',
#  'close_1hour_w30_ma/close_1hour_w120_ma',
#  'close_1hour_w30_ma/close_1hour_w200_ma',
#  'close_1hour_w60_ma/close_1hour_w120_ma',
#  'close_1hour_w60_ma/close_1hour_w200_ma',
#  'close_1hour_w120_ma/close_1hour_w200_ma',
#  'close_1hour/close_1hour_w5_expma',
#  'close_1hour/close_1hour_w10_expma',
#  'close_1hour/close_1hour_w20_expma',
#  'close_1hour/close_1hour_w30_expma',
#  'close_1hour/close_1hour_w60_expma',
#  'close_1hour/close_1hour_w120_expma',
#  'close_1hour/close_1hour_w200_expma',
#  'close_1hour_w5_expma/close_1hour_w10_expma',
#  'close_1hour_w5_expma/close_1hour_w20_expma',
#  'close_1hour_w5_expma/close_1hour_w30_expma',
#  'close_1hour_w5_expma/close_1hour_w60_expma',
#  'close_1hour_w5_expma/close_1hour_w120_expma',
#  'close_1hour_w5_expma/close_1hour_w200_expma',
#  'close_1hour_w10_expma/close_1hour_w20_expma',
#  'close_1hour_w10_expma/close_1hour_w30_expma',
#  'close_1hour_w10_expma/close_1hour_w60_expma',
#  'close_1hour_w10_expma/close_1hour_w120_expma',
#  'close_1hour_w10_expma/close_1hour_w200_expma',
#  'close_1hour_w20_expma/close_1hour_w30_expma',
#  'close_1hour_w20_expma/close_1hour_w60_expma',
#  'close_1hour_w20_expma/close_1hour_w120_expma',
#  'close_1hour_w20_expma/close_1hour_w200_expma',
#  'close_1hour_w30_expma/close_1hour_w60_expma',
#  'close_1hour_w30_expma/close_1hour_w120_expma',
#  'close_1hour_w30_expma/close_1hour_w200_expma',
#  'close_1hour_w60_expma/close_1hour_w120_expma',
#  'close_1hour_w60_expma/close_1hour_w200_expma',
#  'close_1hour_w120_expma/close_1hour_w200_expma',
#  'close_1hour_w5_min/close_1hour',
#  'close_1hour_w10_min/close_1hour',
#  'close_1hour_w20_min/close_1hour',
#  'close_1hour_w30_min/close_1hour',
#  'close_1hour_w60_min/close_1hour',
#  'close_1hour_w120_min/close_1hour',
#  'close_1hour_w200_min/close_1hour',
#  'close_1hour_w5_max/close_1hour',
#  'close_1hour_w10_max/close_1hour',
#  'close_1hour_w20_max/close_1hour',
#  'close_1hour_w30_max/close_1hour',
#  'close_1hour_w60_max/close_1hour',
#  'close_1hour_w120_max/close_1hour',
#  'close_1hour_w200_max/close_1hour',
#  'close_1hour_w5_ma_low_2std/close_1hour',
#  'close_1hour_w5_ma_up_2std/close_1hour',
#  'close_1hour_w5_ma_low_3std/close_1hour',
#  'close_1hour_w5_ma_up_3std/close_1hour',
#  'close_1hour_w10_ma_low_2std/close_1hour',
#  'close_1hour_w10_ma_up_2std/close_1hour',
#  'close_1hour_w10_ma_low_3std/close_1hour',
#  'close_1hour_w10_ma_up_3std/close_1hour',
#  'close_1hour_w20_ma_low_2std/close_1hour',
#  'close_1hour_w20_ma_up_2std/close_1hour',
#  'close_1hour_w20_ma_low_3std/close_1hour',
#  'close_1hour_w20_ma_up_3std/close_1hour',
#  'close_1hour_w30_ma_low_2std/close_1hour',
#  'close_1hour_w30_ma_up_2std/close_1hour',
#  'close_1hour_w30_ma_low_3std/close_1hour',
#  'close_1hour_w30_ma_up_3std/close_1hour',
#  'close_1hour_w60_ma_low_2std/close_1hour',
#  'close_1hour_w60_ma_up_2std/close_1hour',
#  'close_1hour_w60_ma_low_3std/close_1hour',
#  'close_1hour_w60_ma_up_3std/close_1hour',
#  'close_1hour_w120_ma_low_2std/close_1hour',
#  'close_1hour_w120_ma_up_2std/close_1hour',
#  'close_1hour_w120_ma_low_3std/close_1hour',
#  'close_1hour_w120_ma_up_3std/close_1hour',
#  'close_1hour_w200_ma_low_2std/close_1hour',
#  'close_1hour_w200_ma_up_2std/close_1hour',
#  'close_1hour_w200_ma_low_3std/close_1hour',
#  'close_1hour_w200_ma_up_3std/close_1hour',
#  'close_1hour_w5_min/close_1hour_w5_max',
#  'close_1hour_w10_min/close_1hour_w10_max',
#  'close_1hour_w20_min/close_1hour_w20_max',
#  'close_1hour_w30_min/close_1hour_w30_max',
#  'close_1hour_w60_min/close_1hour_w60_max',
#  'close_1hour_w120_min/close_1hour_w120_max',
#  'close_1hour_w200_min/close_1hour_w200_max',
#  'ticker_code']

# %% [markdown]
# ### 1. PSI

# %%
def psi(expected: np.ndarray, actual: np.ndarray, bucket_type: str = "bins", n_bins: int = 10) -> float:
    """Calculate PSI metric for two arrays.
    
    Parameters
    ----------
        expected : list-like
            Array of expected values
        actual : list-like
            Array of actual values
        bucket_type : str
            Binning strategy. Accepts two options: 'bins' and 'quantiles'. Defaults to 'bins'.
            'bins': input arrays are splitted into bins with equal
                and fixed steps based on 'expected' array
            'quantiles': input arrays are binned according to 'expected' array
                with given number of n_bins
        n_bins : int
            Number of buckets for binning. Defaults to 10.

    Returns
    -------
        A single float number
    """
    breakpoints = np.arange(0, n_bins + 1) / (n_bins) * 100
    if bucket_type == "bins":
        breakpoints = np.histogram(expected, n_bins)[1]
    elif bucket_type == "quantiles":
        breakpoints = np.percentile(expected, breakpoints)

    # Calculate frequencies
    expected_percents = np.histogram(expected, breakpoints)[0] / len(expected)
    actual_percents = np.histogram(actual, breakpoints)[0] / len(actual)
    # Clip freaquencies to avoid zero division
    expected_percents = np.clip(expected_percents, a_min=0.0001, a_max=None)
    actual_percents = np.clip(actual_percents, a_min=0.0001, a_max=None)
    # Calculate PSI
    psi_value = (expected_percents - actual_percents) * np.log(expected_percents / actual_percents)
    psi_value = sum(psi_value)

    return psi_value

# %%
psi_features = {'feature' : [],
                
               'psi_valid' : [],
               'psi_test' : [],
               'psi_test2' : [],

               'psi_neg_valid' : [],
               'psi_neg_test' : [],
               'psi_neg_test2' : [],

               'psi_pos_valid' : [],
               'psi_pos_test' : [],
               'psi_pos_test2' : [],
               }

for feature in tqdm(features_all):

    mask_pos = df['target'] == 1
    mask_neg = ~mask_pos

    psi_features['feature'] += [feature]
    
    psi_features['psi_valid'] += [psi(df.loc[mask_train, feature].values, df.loc[mask_valid, feature].values)]
    psi_features['psi_test'] += [psi(df.loc[mask_train, feature].values, df.loc[mask_test, feature].values)]
    psi_features['psi_test2'] += [psi(df.loc[mask_train, feature].values, df.loc[mask_test2, feature].values)]

    psi_features['psi_neg_valid'] += [psi(df.loc[mask_train&mask_neg, feature].values, df.loc[mask_valid&mask_neg, feature].values)]
    psi_features['psi_neg_test'] += [psi(df.loc[mask_train&mask_neg, feature].values, df.loc[mask_test&mask_neg, feature].values)]
    psi_features['psi_neg_test2'] += [psi(df.loc[mask_train&mask_neg, feature].values, df.loc[mask_test2&mask_neg, feature].values)]

    psi_features['psi_pos_valid'] += [psi(df.loc[mask_train&mask_pos, feature].values, df.loc[mask_valid&mask_pos, feature].values)]
    psi_features['psi_pos_test'] += [psi(df.loc[mask_train&mask_pos, feature].values, df.loc[mask_test&mask_pos, feature].values)]
    psi_features['psi_pos_test2'] += [psi(df.loc[mask_train&mask_pos, feature].values, df.loc[mask_test2&mask_pos, feature].values)]

df_psi = pd.DataFrame(psi_features)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 315/315 [02:34<00:00,  2.04it/s]

# %%
# pd.set_option('display.max_rows', 800)
# df_psi

# %%
# - 0.1 - 0.25 -
psi_threshold = 0.1
mask_psi_pos_neg = (df_psi['psi_valid'] < psi_threshold) & (df_psi['psi_test'] < psi_threshold) & (df_psi['psi_test2'] < psi_threshold)
mask_psi_neg = (df_psi['psi_neg_valid'] < psi_threshold) & (df_psi['psi_neg_test'] < psi_threshold) & (df_psi['psi_neg_test2'] < psi_threshold)
mask_psi_pos = (df_psi['psi_pos_valid'] < psi_threshold) & (df_psi['psi_pos_test'] < psi_threshold) & (df_psi['psi_pos_test2'] < psi_threshold)

# %%
len(features_all)
# Out:
# 315

# %%
mask_psi_pos_neg.sum(), (mask_psi_pos_neg & mask_psi_neg & mask_psi_pos).sum()
# Out:
# (298, 297)

# %%
mask_psi = mask_psi_pos_neg# & mask_psi_neg & mask_psi_pos

# %%
np.array(features_all)[~mask_psi]
# Out:
# array(['close_1hour_w10_mean_abs_pct', 'close_1hour_w20_mean_abs_pct',
#        'close_1hour_w30_mean_abs_pct', 'close_1hour_w60_norm_std',
#        'close_1hour_w60_mean_abs_pct', 'close_1hour_w120_norm_std',
#        'close_1hour_w120_mean_abs_pct', 'close_1hour_w200_norm_std',
#        'close_1hour_w200_mean_abs_pct', 'day',
#        'close_1hour_w30_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#        'close_1hour_w60_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#        'close_1hour_w120_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#        'close_1hour_w30_min/close_1hour_w30_max',
#        'close_1hour_w60_min/close_1hour_w60_max',
#        'close_1hour_w120_min/close_1hour_w120_max',
#        'close_1hour_w200_min/close_1hour_w200_max'], dtype='<U59')

# %%
np.array(features_all)[mask_psi]
# Out:
# array(['close_1hour_w1_roc', 'close_1hour_w5_norm_std',
#        'close_1hour_w5_mean_abs_pct', 'close_1hour_w5_alpha',
#        'close_1hour_w5_rsi', 'close_1hour_w5_roc',
#        'close_1hour_w10_norm_std', 'close_1hour_w10_alpha',
#        'close_1hour_w10_rsi', 'close_1hour_w10_roc',
#        'close_1hour_w20_norm_std', 'close_1hour_w20_alpha',
#        'close_1hour_w20_rsi', 'close_1hour_w20_roc',
#        'close_1hour_w30_norm_std', 'close_1hour_w30_alpha',
#        'close_1hour_w30_rsi', 'close_1hour_w30_roc',
#        'close_1hour_w30_lvl_1-1.02', 'close_1hour_w30_lvl_-0.98-1',
#        'close_1hour_w30_lvl_1.02-1.03', 'close_1hour_w30_lvl_-0.97-0.98',
#        'close_1hour_w30_lvl_1.03-1.05', 'close_1hour_w30_lvl_-0.95-0.97',
#        'close_1hour_w30_lvl_1.05-1.08', 'close_1hour_w30_lvl_-0.92-0.95',
#        'close_1hour_w30_lvl_1.08-1.1', 'close_1hour_w30_lvl_-0.9-0.92',
#        'close_1hour_w60_alpha', 'close_1hour_w60_rsi',
#        'close_1hour_w60_roc', 'close_1hour_w120_alpha',
#        'close_1hour_w120_rsi', 'close_1hour_w120_roc',
#        'close_1hour_w120_lvl_1-1.02', 'close_1hour_w120_lvl_-0.98-1',
#        'close_1hour_w120_lvl_1.02-1.03',
#        'close_1hour_w120_lvl_-0.97-0.98',
#        'close_1hour_w120_lvl_1.03-1.05',
#        'close_1hour_w120_lvl_-0.95-0.97',
#        'close_1hour_w120_lvl_1.05-1.08',
#        'close_1hour_w120_lvl_-0.92-0.95', 'close_1hour_w120_lvl_1.08-1.1',
#        'close_1hour_w120_lvl_-0.9-0.92', 'close_1hour_w200_alpha',
#        'close_1hour_w200_rsi', 'close_1hour_w200_roc',
#        'close_1hour_w200_lvl_1-1.02', 'close_1hour_w200_lvl_-0.98-1',
#        'close_1hour_w200_lvl_1.02-1.03',
#        'close_1hour_w200_lvl_-0.97-0.98',
#        'close_1hour_w200_lvl_1.03-1.05',
#        'close_1hour_w200_lvl_-0.95-0.97',
#        'close_1hour_w200_lvl_1.05-1.08',
#        'close_1hour_w200_lvl_-0.92-0.95', 'close_1hour_w200_lvl_1.08-1.1',
#        'close_1hour_w200_lvl_-0.9-0.92', 'hour', 'weekday',
#        'close_1hour_w1_roc/close_1hour_w5_alpha',
#        'close_1hour_w1_roc/close_1hour_w10_alpha',
#        'close_1hour_w1_roc/close_1hour_w20_alpha',
#        'close_1hour_w1_roc/close_1hour_w30_alpha',
#        'close_1hour_w1_roc/close_1hour_w60_alpha',
#        'close_1hour_w1_roc/close_1hour_w120_alpha',
#        'close_1hour_w1_roc/close_1hour_w200_alpha',
#        'close_1hour_w5_alpha/close_1hour_w10_alpha',
#        'close_1hour_w5_alpha/close_1hour_w20_alpha',
#        'close_1hour_w5_alpha/close_1hour_w30_alpha',
#        'close_1hour_w5_alpha/close_1hour_w60_alpha',
#        'close_1hour_w5_alpha/close_1hour_w120_alpha',
#        'close_1hour_w5_alpha/close_1hour_w200_alpha',
#        'close_1hour_w10_alpha/close_1hour_w20_alpha',
#        'close_1hour_w10_alpha/close_1hour_w30_alpha',
#        'close_1hour_w10_alpha/close_1hour_w60_alpha',
#        'close_1hour_w10_alpha/close_1hour_w120_alpha',
#        'close_1hour_w10_alpha/close_1hour_w200_alpha',
#        'close_1hour_w20_alpha/close_1hour_w30_alpha',
#        'close_1hour_w20_alpha/close_1hour_w60_alpha',
#        'close_1hour_w20_alpha/close_1hour_w120_alpha',
#        'close_1hour_w20_alpha/close_1hour_w200_alpha',
#        'close_1hour_w30_alpha/close_1hour_w60_alpha',
#        'close_1hour_w30_alpha/close_1hour_w120_alpha',
#        'close_1hour_w30_alpha/close_1hour_w200_alpha',
#        'close_1hour_w60_alpha/close_1hour_w120_alpha',
#        'close_1hour_w60_alpha/close_1hour_w200_alpha',
#        'close_1hour_w120_alpha/close_1hour_w200_alpha',
#        'close_1hour_w1_roc/close_1hour_w5_roc',
#        'close_1hour_w1_roc/close_1hour_w10_roc',
#        'close_1hour_w1_roc/close_1hour_w20_roc',
#        'close_1hour_w1_roc/close_1hour_w30_roc',
#        'close_1hour_w1_roc/close_1hour_w60_roc',
#        'close_1hour_w1_roc/close_1hour_w120_roc',
#        'close_1hour_w1_roc/close_1hour_w200_roc',
#        'close_1hour_w5_roc/close_1hour_w10_roc',
#        'close_1hour_w5_roc/close_1hour_w20_roc',
#        'close_1hour_w5_roc/close_1hour_w30_roc',
#        'close_1hour_w5_roc/close_1hour_w60_roc',
#        'close_1hour_w5_roc/close_1hour_w120_roc',
#        'close_1hour_w5_roc/close_1hour_w200_roc',
#        'close_1hour_w10_roc/close_1hour_w20_roc',
#        'close_1hour_w10_roc/close_1hour_w30_roc',
#        'close_1hour_w10_roc/close_1hour_w60_roc',
#        'close_1hour_w10_roc/close_1hour_w120_roc',
#        'close_1hour_w10_roc/close_1hour_w200_roc',
#        'close_1hour_w20_roc/close_1hour_w30_roc',
#        'close_1hour_w20_roc/close_1hour_w60_roc',
#        'close_1hour_w20_roc/close_1hour_w120_roc',
#        'close_1hour_w20_roc/close_1hour_w200_roc',
#        'close_1hour_w30_roc/close_1hour_w60_roc',
#        'close_1hour_w30_roc/close_1hour_w120_roc',
#        'close_1hour_w30_roc/close_1hour_w200_roc',
#        'close_1hour_w60_roc/close_1hour_w120_roc',
#        'close_1hour_w60_roc/close_1hour_w200_roc',
#        'close_1hour_w120_roc/close_1hour_w200_roc',
#        'close_1hour_w5_mean_abs_pct/close_1hour_w10_mean_abs_pct',
#        'close_1hour_w5_mean_abs_pct/close_1hour_w20_mean_abs_pct',
#        'close_1hour_w5_mean_abs_pct/close_1hour_w30_mean_abs_pct',
#        'close_1hour_w5_mean_abs_pct/close_1hour_w60_mean_abs_pct',
#        'close_1hour_w5_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#        'close_1hour_w5_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#        'close_1hour_w10_mean_abs_pct/close_1hour_w20_mean_abs_pct',
#        'close_1hour_w10_mean_abs_pct/close_1hour_w30_mean_abs_pct',
#        'close_1hour_w10_mean_abs_pct/close_1hour_w60_mean_abs_pct',
#        'close_1hour_w10_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#        'close_1hour_w10_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#        'close_1hour_w20_mean_abs_pct/close_1hour_w30_mean_abs_pct',
#        'close_1hour_w20_mean_abs_pct/close_1hour_w60_mean_abs_pct',
#        'close_1hour_w20_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#        'close_1hour_w20_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#        'close_1hour_w30_mean_abs_pct/close_1hour_w60_mean_abs_pct',
#        'close_1hour_w30_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#        'close_1hour_w60_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#        'close_1hour_w5_std/close_1hour_w10_std',
#        'close_1hour_w5_std/close_1hour_w20_std',
#        'close_1hour_w5_std/close_1hour_w30_std',
#        'close_1hour_w5_std/close_1hour_w60_std',
#        'close_1hour_w5_std/close_1hour_w120_std',
#        'close_1hour_w5_std/close_1hour_w200_std',
#        'close_1hour_w10_std/close_1hour_w20_std',
#        'close_1hour_w10_std/close_1hour_w30_std',
#        'close_1hour_w10_std/close_1hour_w60_std',
#        'close_1hour_w10_std/close_1hour_w120_std',
#        'close_1hour_w10_std/close_1hour_w200_std',
#        'close_1hour_w20_std/close_1hour_w30_std',
#        'close_1hour_w20_std/close_1hour_w60_std',
#        'close_1hour_w20_std/close_1hour_w120_std',
#        'close_1hour_w20_std/close_1hour_w200_std',
#        'close_1hour_w30_std/close_1hour_w60_std',
#        'close_1hour_w30_std/close_1hour_w120_std',
#        'close_1hour_w30_std/close_1hour_w200_std',
#        'close_1hour_w60_std/close_1hour_w120_std',
#        'close_1hour_w60_std/close_1hour_w200_std',
#        'close_1hour_w120_std/close_1hour_w200_std',
#        'close_1hour_w5_norm_std/close_1hour_w10_norm_std',
#        'close_1hour_w5_norm_std/close_1hour_w20_norm_std',
#        'close_1hour_w5_norm_std/close_1hour_w30_norm_std',
#        'close_1hour_w5_norm_std/close_1hour_w60_norm_std',
#        'close_1hour_w5_norm_std/close_1hour_w120_norm_std',
#        'close_1hour_w5_norm_std/close_1hour_w200_norm_std',
#        'close_1hour_w10_norm_std/close_1hour_w20_norm_std',
#        'close_1hour_w10_norm_std/close_1hour_w30_norm_std',
#        'close_1hour_w10_norm_std/close_1hour_w60_norm_std',
#        'close_1hour_w10_norm_std/close_1hour_w120_norm_std',
#        'close_1hour_w10_norm_std/close_1hour_w200_norm_std',
#        'close_1hour_w20_norm_std/close_1hour_w30_norm_std',
#        'close_1hour_w20_norm_std/close_1hour_w60_norm_std',
#        'close_1hour_w20_norm_std/close_1hour_w120_norm_std',
#        'close_1hour_w20_norm_std/close_1hour_w200_norm_std',
#        'close_1hour_w30_norm_std/close_1hour_w60_norm_std',
#        'close_1hour_w30_norm_std/close_1hour_w120_norm_std',
#        'close_1hour_w30_norm_std/close_1hour_w200_norm_std',
#        'close_1hour_w60_norm_std/close_1hour_w120_norm_std',
#        'close_1hour_w60_norm_std/close_1hour_w200_norm_std',
#        'close_1hour_w120_norm_std/close_1hour_w200_norm_std',
#        'close_1hour_w5_rsi/close_1hour_w10_rsi',
#        'close_1hour_w5_rsi/close_1hour_w20_rsi',
#        'close_1hour_w5_rsi/close_1hour_w30_rsi',
#        'close_1hour_w5_rsi/close_1hour_w60_rsi',
#        'close_1hour_w5_rsi/close_1hour_w120_rsi',
#        'close_1hour_w5_rsi/close_1hour_w200_rsi',
#        'close_1hour_w10_rsi/close_1hour_w20_rsi',
#        'close_1hour_w10_rsi/close_1hour_w30_rsi',
#        'close_1hour_w10_rsi/close_1hour_w60_rsi',
#        'close_1hour_w10_rsi/close_1hour_w120_rsi',
#        'close_1hour_w10_rsi/close_1hour_w200_rsi',
#        'close_1hour_w20_rsi/close_1hour_w30_rsi',
#        'close_1hour_w20_rsi/close_1hour_w60_rsi',
#        'close_1hour_w20_rsi/close_1hour_w120_rsi',
#        'close_1hour_w20_rsi/close_1hour_w200_rsi',
#        'close_1hour_w30_rsi/close_1hour_w60_rsi',
#        'close_1hour_w30_rsi/close_1hour_w120_rsi',
#        'close_1hour_w30_rsi/close_1hour_w200_rsi',
#        'close_1hour_w60_rsi/close_1hour_w120_rsi',
#        'close_1hour_w60_rsi/close_1hour_w200_rsi',
#        'close_1hour_w120_rsi/close_1hour_w200_rsi',
#        'close_1hour/close_1hour_w5_ma', 'close_1hour/close_1hour_w10_ma',
#        'close_1hour/close_1hour_w20_ma', 'close_1hour/close_1hour_w30_ma',
#        'close_1hour/close_1hour_w60_ma',
#        'close_1hour/close_1hour_w120_ma',
#        'close_1hour/close_1hour_w200_ma',
#        'close_1hour_w5_ma/close_1hour_w10_ma',
#        'close_1hour_w5_ma/close_1hour_w20_ma',
#        'close_1hour_w5_ma/close_1hour_w30_ma',
#        'close_1hour_w5_ma/close_1hour_w60_ma',
#        'close_1hour_w5_ma/close_1hour_w120_ma',
#        'close_1hour_w5_ma/close_1hour_w200_ma',
#        'close_1hour_w10_ma/close_1hour_w20_ma',
#        'close_1hour_w10_ma/close_1hour_w30_ma',
#        'close_1hour_w10_ma/close_1hour_w60_ma',
#        'close_1hour_w10_ma/close_1hour_w120_ma',
#        'close_1hour_w10_ma/close_1hour_w200_ma',
#        'close_1hour_w20_ma/close_1hour_w30_ma',
#        'close_1hour_w20_ma/close_1hour_w60_ma',
#        'close_1hour_w20_ma/close_1hour_w120_ma',
#        'close_1hour_w20_ma/close_1hour_w200_ma',
#        'close_1hour_w30_ma/close_1hour_w60_ma',
#        'close_1hour_w30_ma/close_1hour_w120_ma',
#        'close_1hour_w30_ma/close_1hour_w200_ma',
#        'close_1hour_w60_ma/close_1hour_w120_ma',
#        'close_1hour_w60_ma/close_1hour_w200_ma',
#        'close_1hour_w120_ma/close_1hour_w200_ma',
#        'close_1hour/close_1hour_w5_expma',
#        'close_1hour/close_1hour_w10_expma',
#        'close_1hour/close_1hour_w20_expma',
#        'close_1hour/close_1hour_w30_expma',
#        'close_1hour/close_1hour_w60_expma',
#        'close_1hour/close_1hour_w120_expma',
#        'close_1hour/close_1hour_w200_expma',
#        'close_1hour_w5_expma/close_1hour_w10_expma',
#        'close_1hour_w5_expma/close_1hour_w20_expma',
#        'close_1hour_w5_expma/close_1hour_w30_expma',
#        'close_1hour_w5_expma/close_1hour_w60_expma',
#        'close_1hour_w5_expma/close_1hour_w120_expma',
#        'close_1hour_w5_expma/close_1hour_w200_expma',
#        'close_1hour_w10_expma/close_1hour_w20_expma',
#        'close_1hour_w10_expma/close_1hour_w30_expma',
#        'close_1hour_w10_expma/close_1hour_w60_expma',
#        'close_1hour_w10_expma/close_1hour_w120_expma',
#        'close_1hour_w10_expma/close_1hour_w200_expma',
#        'close_1hour_w20_expma/close_1hour_w30_expma',
#        'close_1hour_w20_expma/close_1hour_w60_expma',
#        'close_1hour_w20_expma/close_1hour_w120_expma',
#        'close_1hour_w20_expma/close_1hour_w200_expma',
#        'close_1hour_w30_expma/close_1hour_w60_expma',
#        'close_1hour_w30_expma/close_1hour_w120_expma',
#        'close_1hour_w30_expma/close_1hour_w200_expma',
#        'close_1hour_w60_expma/close_1hour_w120_expma',
#        'close_1hour_w60_expma/close_1hour_w200_expma',
#        'close_1hour_w120_expma/close_1hour_w200_expma',
#        'close_1hour_w5_min/close_1hour',
#        'close_1hour_w10_min/close_1hour',
#        'close_1hour_w20_min/close_1hour',
#        'close_1hour_w30_min/close_1hour',
#        'close_1hour_w60_min/close_1hour',
#        'close_1hour_w120_min/close_1hour',
#        'close_1hour_w200_min/close_1hour',
#        'close_1hour_w5_max/close_1hour',
#        'close_1hour_w10_max/close_1hour',
#        'close_1hour_w20_max/close_1hour',
#        'close_1hour_w30_max/close_1hour',
#        'close_1hour_w60_max/close_1hour',
#        'close_1hour_w120_max/close_1hour',
#        'close_1hour_w200_max/close_1hour',
#        'close_1hour_w5_ma_low_2std/close_1hour',
#        'close_1hour_w5_ma_up_2std/close_1hour',
#        'close_1hour_w5_ma_low_3std/close_1hour',
#        'close_1hour_w5_ma_up_3std/close_1hour',
#        'close_1hour_w10_ma_low_2std/close_1hour',
#        'close_1hour_w10_ma_up_2std/close_1hour',
#        'close_1hour_w10_ma_low_3std/close_1hour',
#        'close_1hour_w10_ma_up_3std/close_1hour',
#        'close_1hour_w20_ma_low_2std/close_1hour',
#        'close_1hour_w20_ma_up_2std/close_1hour',
#        'close_1hour_w20_ma_low_3std/close_1hour',
#        'close_1hour_w20_ma_up_3std/close_1hour',
#        'close_1hour_w30_ma_low_2std/close_1hour',
#        'close_1hour_w30_ma_up_2std/close_1hour',
#        'close_1hour_w30_ma_low_3std/close_1hour',
#        'close_1hour_w30_ma_up_3std/close_1hour',
#        'close_1hour_w60_ma_low_2std/close_1hour',
#        'close_1hour_w60_ma_up_2std/close_1hour',
#        'close_1hour_w60_ma_low_3std/close_1hour',
#        'close_1hour_w60_ma_up_3std/close_1hour',
#        'close_1hour_w120_ma_low_2std/close_1hour',
#        'close_1hour_w120_ma_up_2std/close_1hour',
#        'close_1hour_w120_ma_low_3std/close_1hour',
#        'close_1hour_w120_ma_up_3std/close_1hour',
#        'close_1hour_w200_ma_low_2std/close_1hour',
#        'close_1hour_w200_ma_up_2std/close_1hour',
#        'close_1hour_w200_ma_low_3std/close_1hour',
#        'close_1hour_w200_ma_up_3std/close_1hour',
#        'close_1hour_w5_min/close_1hour_w5_max',
#        'close_1hour_w10_min/close_1hour_w10_max',
#        'close_1hour_w20_min/close_1hour_w20_max', 'ticker_code'],
#       dtype='<U59')

# %%
features_psi = np.array(features_all)[mask_psi]
len(features_psi)
# Out:
# 298

# %% [markdown]
# ### 2. Correlation

# %%
mask_train.sum(), mask_valid.sum(), mask_test.sum(), mask_test2.sum()
# Out:
# (1334928, 335137, 328552, 91494)

# %%
#subsample_train

coeff_subsample = 0.4

inds_train = np.argwhere(mask_train).ravel()
inds_train_subsample = np.random.RandomState(seed=42).permutation(inds_train)[:int(len(inds_train)*coeff_subsample)]

mask_train_subsample = np.zeros_like(mask_train).astype(bool)
mask_train_subsample[inds_train_subsample] = True

mask_train_subsample.sum()
# Out:
# 667464

# %%
features = features_psi.copy()
len(features)
# Out:
# 298

# %%
mask_corr = np.ones_like(features).astype(bool)
#mask_corr

# %%
corr_threshold = 0.99

for i in tqdm(range(len(features) - 1)):
    if mask_corr[i]:
        for j in range(i+1, len(features)):
            if mask_corr[j]:        
                corr = abs(np.corrcoef(df.loc[mask_train_subsample, features[i]], df.loc[mask_train_subsample, features[j]])[0,1])
                if corr > corr_threshold:
                    mask_corr[j] = False
mask_corr.sum()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 297/297 [05:11<00:00,  1.05s/it]
# 235

# %%
np.array(features)[~mask_corr]
# Out:
# array(['close_1hour_w30_alpha/close_1hour_w60_alpha',
#        'close_1hour_w60_alpha/close_1hour_w120_alpha',
#        'close_1hour_w5_roc/close_1hour_w20_roc',
#        'close_1hour_w10_roc/close_1hour_w20_roc',
#        'close_1hour/close_1hour_w10_ma', 'close_1hour/close_1hour_w30_ma',
#        'close_1hour_w5_ma/close_1hour_w10_ma',
#        'close_1hour_w5_ma/close_1hour_w20_ma',
#        'close_1hour_w5_ma/close_1hour_w30_ma',
#        'close_1hour_w5_ma/close_1hour_w60_ma',
#        'close_1hour_w5_ma/close_1hour_w120_ma',
#        'close_1hour_w5_ma/close_1hour_w200_ma',
#        'close_1hour_w10_ma/close_1hour_w20_ma',
#        'close_1hour_w10_ma/close_1hour_w120_ma',
#        'close_1hour_w10_ma/close_1hour_w200_ma',
#        'close_1hour_w20_ma/close_1hour_w30_ma',
#        'close_1hour_w20_ma/close_1hour_w60_ma',
#        'close_1hour_w30_ma/close_1hour_w120_ma',
#        'close_1hour_w30_ma/close_1hour_w200_ma',
#        'close_1hour/close_1hour_w5_expma',
#        'close_1hour/close_1hour_w10_expma',
#        'close_1hour/close_1hour_w20_expma',
#        'close_1hour/close_1hour_w30_expma',
#        'close_1hour/close_1hour_w60_expma',
#        'close_1hour/close_1hour_w120_expma',
#        'close_1hour/close_1hour_w200_expma',
#        'close_1hour_w5_expma/close_1hour_w10_expma',
#        'close_1hour_w5_expma/close_1hour_w20_expma',
#        'close_1hour_w5_expma/close_1hour_w30_expma',
#        'close_1hour_w5_expma/close_1hour_w60_expma',
#        'close_1hour_w5_expma/close_1hour_w120_expma',
#        'close_1hour_w5_expma/close_1hour_w200_expma',
#        'close_1hour_w10_expma/close_1hour_w20_expma',
#        'close_1hour_w10_expma/close_1hour_w30_expma',
#        'close_1hour_w10_expma/close_1hour_w60_expma',
#        'close_1hour_w10_expma/close_1hour_w120_expma',
#        'close_1hour_w20_expma/close_1hour_w30_expma',
#        'close_1hour_w20_expma/close_1hour_w60_expma',
#        'close_1hour_w20_expma/close_1hour_w120_expma',
#        'close_1hour_w20_expma/close_1hour_w200_expma',
#        'close_1hour_w30_expma/close_1hour_w60_expma',
#        'close_1hour_w30_expma/close_1hour_w120_expma',
#        'close_1hour_w30_expma/close_1hour_w200_expma',
#        'close_1hour_w60_expma/close_1hour_w120_expma',
#        'close_1hour_w60_expma/close_1hour_w200_expma',
#        'close_1hour_w120_expma/close_1hour_w200_expma',
#        'close_1hour_w10_min/close_1hour',
#        'close_1hour_w30_min/close_1hour',
#        'close_1hour_w10_max/close_1hour',
#        'close_1hour_w5_ma_low_2std/close_1hour',
#        'close_1hour_w5_ma_up_2std/close_1hour',
#        'close_1hour_w5_ma_low_3std/close_1hour',
#        'close_1hour_w5_ma_up_3std/close_1hour',
#        'close_1hour_w10_ma_low_2std/close_1hour',
#        'close_1hour_w10_ma_up_3std/close_1hour',
#        'close_1hour_w20_ma_low_2std/close_1hour',
#        'close_1hour_w20_ma_up_2std/close_1hour',
#        'close_1hour_w30_ma_up_2std/close_1hour',
#        'close_1hour_w30_ma_low_3std/close_1hour',
#        'close_1hour_w60_ma_up_2std/close_1hour',
#        'close_1hour_w120_ma_up_3std/close_1hour',
#        'close_1hour_w200_ma_up_3std/close_1hour',
#        'close_1hour_w5_min/close_1hour_w5_max'], dtype='<U59')

# %%
features_corr = np.array(features)[mask_corr]
len(features_corr)
# Out:
# 235

# %%
features_corr
# Out:
# array(['close_1hour_w1_roc', 'close_1hour_w5_norm_std',
#        'close_1hour_w5_mean_abs_pct', 'close_1hour_w5_alpha',
#        'close_1hour_w5_rsi', 'close_1hour_w5_roc',
#        'close_1hour_w10_norm_std', 'close_1hour_w10_alpha',
#        'close_1hour_w10_rsi', 'close_1hour_w10_roc',
#        'close_1hour_w20_norm_std', 'close_1hour_w20_alpha',
#        'close_1hour_w20_rsi', 'close_1hour_w20_roc',
#        'close_1hour_w30_norm_std', 'close_1hour_w30_alpha',
#        'close_1hour_w30_rsi', 'close_1hour_w30_roc',
#        'close_1hour_w30_lvl_1-1.02', 'close_1hour_w30_lvl_-0.98-1',
#        'close_1hour_w30_lvl_1.02-1.03', 'close_1hour_w30_lvl_-0.97-0.98',
#        'close_1hour_w30_lvl_1.03-1.05', 'close_1hour_w30_lvl_-0.95-0.97',
#        'close_1hour_w30_lvl_1.05-1.08', 'close_1hour_w30_lvl_-0.92-0.95',
#        'close_1hour_w30_lvl_1.08-1.1', 'close_1hour_w30_lvl_-0.9-0.92',
#        'close_1hour_w60_alpha', 'close_1hour_w60_rsi',
#        'close_1hour_w60_roc', 'close_1hour_w120_alpha',
#        'close_1hour_w120_rsi', 'close_1hour_w120_roc',
#        'close_1hour_w120_lvl_1-1.02', 'close_1hour_w120_lvl_-0.98-1',
#        'close_1hour_w120_lvl_1.02-1.03',
#        'close_1hour_w120_lvl_-0.97-0.98',
#        'close_1hour_w120_lvl_1.03-1.05',
#        'close_1hour_w120_lvl_-0.95-0.97',
#        'close_1hour_w120_lvl_1.05-1.08',
#        'close_1hour_w120_lvl_-0.92-0.95', 'close_1hour_w120_lvl_1.08-1.1',
#        'close_1hour_w120_lvl_-0.9-0.92', 'close_1hour_w200_alpha',
#        'close_1hour_w200_rsi', 'close_1hour_w200_roc',
#        'close_1hour_w200_lvl_1-1.02', 'close_1hour_w200_lvl_-0.98-1',
#        'close_1hour_w200_lvl_1.02-1.03',
#        'close_1hour_w200_lvl_-0.97-0.98',
#        'close_1hour_w200_lvl_1.03-1.05',
#        'close_1hour_w200_lvl_-0.95-0.97',
#        'close_1hour_w200_lvl_1.05-1.08',
#        'close_1hour_w200_lvl_-0.92-0.95', 'close_1hour_w200_lvl_1.08-1.1',
#        'close_1hour_w200_lvl_-0.9-0.92', 'hour', 'weekday',
#        'close_1hour_w1_roc/close_1hour_w5_alpha',
#        'close_1hour_w1_roc/close_1hour_w10_alpha',
#        'close_1hour_w1_roc/close_1hour_w20_alpha',
#        'close_1hour_w1_roc/close_1hour_w30_alpha',
#        'close_1hour_w1_roc/close_1hour_w60_alpha',
#        'close_1hour_w1_roc/close_1hour_w120_alpha',
#        'close_1hour_w1_roc/close_1hour_w200_alpha',
#        'close_1hour_w5_alpha/close_1hour_w10_alpha',
#        'close_1hour_w5_alpha/close_1hour_w20_alpha',
#        'close_1hour_w5_alpha/close_1hour_w30_alpha',
#        'close_1hour_w5_alpha/close_1hour_w60_alpha',
#        'close_1hour_w5_alpha/close_1hour_w120_alpha',
#        'close_1hour_w5_alpha/close_1hour_w200_alpha',
#        'close_1hour_w10_alpha/close_1hour_w20_alpha',
#        'close_1hour_w10_alpha/close_1hour_w30_alpha',
#        'close_1hour_w10_alpha/close_1hour_w60_alpha',
#        'close_1hour_w10_alpha/close_1hour_w120_alpha',
#        'close_1hour_w10_alpha/close_1hour_w200_alpha',
#        'close_1hour_w20_alpha/close_1hour_w30_alpha',
#        'close_1hour_w20_alpha/close_1hour_w60_alpha',
#        'close_1hour_w20_alpha/close_1hour_w120_alpha',
#        'close_1hour_w20_alpha/close_1hour_w200_alpha',
#        'close_1hour_w30_alpha/close_1hour_w120_alpha',
#        'close_1hour_w30_alpha/close_1hour_w200_alpha',
#        'close_1hour_w60_alpha/close_1hour_w200_alpha',
#        'close_1hour_w120_alpha/close_1hour_w200_alpha',
#        'close_1hour_w1_roc/close_1hour_w5_roc',
#        'close_1hour_w1_roc/close_1hour_w10_roc',
#        'close_1hour_w1_roc/close_1hour_w20_roc',
#        'close_1hour_w1_roc/close_1hour_w30_roc',
#        'close_1hour_w1_roc/close_1hour_w60_roc',
#        'close_1hour_w1_roc/close_1hour_w120_roc',
#        'close_1hour_w1_roc/close_1hour_w200_roc',
#        'close_1hour_w5_roc/close_1hour_w10_roc',
#        'close_1hour_w5_roc/close_1hour_w30_roc',
#        'close_1hour_w5_roc/close_1hour_w60_roc',
#        'close_1hour_w5_roc/close_1hour_w120_roc',
#        'close_1hour_w5_roc/close_1hour_w200_roc',
#        'close_1hour_w10_roc/close_1hour_w30_roc',
#        'close_1hour_w10_roc/close_1hour_w60_roc',
#        'close_1hour_w10_roc/close_1hour_w120_roc',
#        'close_1hour_w10_roc/close_1hour_w200_roc',
#        'close_1hour_w20_roc/close_1hour_w30_roc',
#        'close_1hour_w20_roc/close_1hour_w60_roc',
#        'close_1hour_w20_roc/close_1hour_w120_roc',
#        'close_1hour_w20_roc/close_1hour_w200_roc',
#        'close_1hour_w30_roc/close_1hour_w60_roc',
#        'close_1hour_w30_roc/close_1hour_w120_roc',
#        'close_1hour_w30_roc/close_1hour_w200_roc',
#        'close_1hour_w60_roc/close_1hour_w120_roc',
#        'close_1hour_w60_roc/close_1hour_w200_roc',
#        'close_1hour_w120_roc/close_1hour_w200_roc',
#        'close_1hour_w5_mean_abs_pct/close_1hour_w10_mean_abs_pct',
#        'close_1hour_w5_mean_abs_pct/close_1hour_w20_mean_abs_pct',
#        'close_1hour_w5_mean_abs_pct/close_1hour_w30_mean_abs_pct',
#        'close_1hour_w5_mean_abs_pct/close_1hour_w60_mean_abs_pct',
#        'close_1hour_w5_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#        'close_1hour_w5_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#        'close_1hour_w10_mean_abs_pct/close_1hour_w20_mean_abs_pct',
#        'close_1hour_w10_mean_abs_pct/close_1hour_w30_mean_abs_pct',
#        'close_1hour_w10_mean_abs_pct/close_1hour_w60_mean_abs_pct',
#        'close_1hour_w10_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#        'close_1hour_w10_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#        'close_1hour_w20_mean_abs_pct/close_1hour_w30_mean_abs_pct',
#        'close_1hour_w20_mean_abs_pct/close_1hour_w60_mean_abs_pct',
#        'close_1hour_w20_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#        'close_1hour_w20_mean_abs_pct/close_1hour_w200_mean_abs_pct',
#        'close_1hour_w30_mean_abs_pct/close_1hour_w60_mean_abs_pct',
#        'close_1hour_w30_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#        'close_1hour_w60_mean_abs_pct/close_1hour_w120_mean_abs_pct',
#        'close_1hour_w5_std/close_1hour_w10_std',
#        'close_1hour_w5_std/close_1hour_w20_std',
#        'close_1hour_w5_std/close_1hour_w30_std',
#        'close_1hour_w5_std/close_1hour_w60_std',
#        'close_1hour_w5_std/close_1hour_w120_std',
#        'close_1hour_w5_std/close_1hour_w200_std',
#        'close_1hour_w10_std/close_1hour_w20_std',
#        'close_1hour_w10_std/close_1hour_w30_std',
#        'close_1hour_w10_std/close_1hour_w60_std',
#        'close_1hour_w10_std/close_1hour_w120_std',
#        'close_1hour_w10_std/close_1hour_w200_std',
#        'close_1hour_w20_std/close_1hour_w30_std',
#        'close_1hour_w20_std/close_1hour_w60_std',
#        'close_1hour_w20_std/close_1hour_w120_std',
#        'close_1hour_w20_std/close_1hour_w200_std',
#        'close_1hour_w30_std/close_1hour_w60_std',
#        'close_1hour_w30_std/close_1hour_w120_std',
#        'close_1hour_w30_std/close_1hour_w200_std',
#        'close_1hour_w60_std/close_1hour_w120_std',
#        'close_1hour_w60_std/close_1hour_w200_std',
#        'close_1hour_w120_std/close_1hour_w200_std',
#        'close_1hour_w5_norm_std/close_1hour_w10_norm_std',
#        'close_1hour_w5_norm_std/close_1hour_w20_norm_std',
#        'close_1hour_w5_norm_std/close_1hour_w30_norm_std',
#        'close_1hour_w5_norm_std/close_1hour_w60_norm_std',
#        'close_1hour_w5_norm_std/close_1hour_w120_norm_std',
#        'close_1hour_w5_norm_std/close_1hour_w200_norm_std',
#        'close_1hour_w10_norm_std/close_1hour_w20_norm_std',
#        'close_1hour_w10_norm_std/close_1hour_w30_norm_std',
#        'close_1hour_w10_norm_std/close_1hour_w60_norm_std',
#        'close_1hour_w10_norm_std/close_1hour_w120_norm_std',
#        'close_1hour_w10_norm_std/close_1hour_w200_norm_std',
#        'close_1hour_w20_norm_std/close_1hour_w30_norm_std',
#        'close_1hour_w20_norm_std/close_1hour_w60_norm_std',
#        'close_1hour_w20_norm_std/close_1hour_w120_norm_std',
#        'close_1hour_w20_norm_std/close_1hour_w200_norm_std',
#        'close_1hour_w30_norm_std/close_1hour_w60_norm_std',
#        'close_1hour_w30_norm_std/close_1hour_w120_norm_std',
#        'close_1hour_w30_norm_std/close_1hour_w200_norm_std',
#        'close_1hour_w60_norm_std/close_1hour_w120_norm_std',
#        'close_1hour_w60_norm_std/close_1hour_w200_norm_std',
#        'close_1hour_w120_norm_std/close_1hour_w200_norm_std',
#        'close_1hour_w5_rsi/close_1hour_w10_rsi',
#        'close_1hour_w5_rsi/close_1hour_w20_rsi',
#        'close_1hour_w5_rsi/close_1hour_w30_rsi',
#        'close_1hour_w5_rsi/close_1hour_w60_rsi',
#        'close_1hour_w5_rsi/close_1hour_w120_rsi',
#        'close_1hour_w5_rsi/close_1hour_w200_rsi',
#        'close_1hour_w10_rsi/close_1hour_w20_rsi',
#        'close_1hour_w10_rsi/close_1hour_w30_rsi',
#        'close_1hour_w10_rsi/close_1hour_w60_rsi',
#        'close_1hour_w10_rsi/close_1hour_w120_rsi',
#        'close_1hour_w10_rsi/close_1hour_w200_rsi',
#        'close_1hour_w20_rsi/close_1hour_w30_rsi',
#        'close_1hour_w20_rsi/close_1hour_w60_rsi',
#        'close_1hour_w20_rsi/close_1hour_w120_rsi',
#        'close_1hour_w20_rsi/close_1hour_w200_rsi',
#        'close_1hour_w30_rsi/close_1hour_w60_rsi',
#        'close_1hour_w30_rsi/close_1hour_w120_rsi',
#        'close_1hour_w30_rsi/close_1hour_w200_rsi',
#        'close_1hour_w60_rsi/close_1hour_w120_rsi',
#        'close_1hour_w60_rsi/close_1hour_w200_rsi',
#        'close_1hour_w120_rsi/close_1hour_w200_rsi',
#        'close_1hour/close_1hour_w5_ma', 'close_1hour/close_1hour_w20_ma',
#        'close_1hour/close_1hour_w60_ma',
#        'close_1hour/close_1hour_w120_ma',
#        'close_1hour/close_1hour_w200_ma',
#        'close_1hour_w10_ma/close_1hour_w30_ma',
#        'close_1hour_w10_ma/close_1hour_w60_ma',
#        'close_1hour_w20_ma/close_1hour_w120_ma',
#        'close_1hour_w20_ma/close_1hour_w200_ma',
#        'close_1hour_w30_ma/close_1hour_w60_ma',
#        'close_1hour_w60_ma/close_1hour_w120_ma',
#        'close_1hour_w60_ma/close_1hour_w200_ma',
#        'close_1hour_w120_ma/close_1hour_w200_ma',
#        'close_1hour_w10_expma/close_1hour_w200_expma',
#        'close_1hour_w5_min/close_1hour',
#        'close_1hour_w20_min/close_1hour',
#        'close_1hour_w60_min/close_1hour',
#        'close_1hour_w120_min/close_1hour',
#        'close_1hour_w200_min/close_1hour',
#        'close_1hour_w5_max/close_1hour',
#        'close_1hour_w20_max/close_1hour',
#        'close_1hour_w30_max/close_1hour',
#        'close_1hour_w60_max/close_1hour',
#        'close_1hour_w120_max/close_1hour',
#        'close_1hour_w200_max/close_1hour',
#        'close_1hour_w10_ma_up_2std/close_1hour',
#        'close_1hour_w10_ma_low_3std/close_1hour',
#        'close_1hour_w20_ma_low_3std/close_1hour',
#        'close_1hour_w20_ma_up_3std/close_1hour',
#        'close_1hour_w30_ma_low_2std/close_1hour',
#        'close_1hour_w30_ma_up_3std/close_1hour',
#        'close_1hour_w60_ma_low_2std/close_1hour',
#        'close_1hour_w60_ma_low_3std/close_1hour',
#        'close_1hour_w60_ma_up_3std/close_1hour',
#        'close_1hour_w120_ma_low_2std/close_1hour',
#        'close_1hour_w120_ma_up_2std/close_1hour',
#        'close_1hour_w120_ma_low_3std/close_1hour',
#        'close_1hour_w200_ma_low_2std/close_1hour',
#        'close_1hour_w200_ma_up_2std/close_1hour',
#        'close_1hour_w200_ma_low_3std/close_1hour',
#        'close_1hour_w10_min/close_1hour_w10_max',
#        'close_1hour_w20_min/close_1hour_w20_max', 'ticker_code'],
#       dtype='<U59')

# %% [markdown]
# #### 2. Useful features

# %%
# def get_useful_features(feature):
#     for elem in ['volume', 'std', 'pct', 'rsi/', 'roc', 'ticker_code']:
#         if elem in feature:
#             return False
#     return True

# mask_useful_features = np.array([get_useful_features(feature) for feature in features_psi])
# features_useful = np.array(features_psi)[mask_useful_features].tolist()
# len(features_useful), features_useful

# %%
#features = features_corr.copy()
# features = features_useful
# len(features)
# Out:
# 63

# %% [markdown]
# ### 3. Get stability features

# %%
features = features_corr.copy()
len(features)
# Out:
# 235

# %%
def mean_win_rate_point(D_sample, y_pred, threshold=None):
    mask = y_pred >= threshold
    score = np.mean(D_sample.label[mask])
    
    return score




def mean_income_rate_point(D_sample, y_pred, threshold=None):
    # q=threshold
    # mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    score = np.mean(D_sample.income_rate[mask]) - 1
    
    return score

def mean_income_rate_tick(D_sample, y_pred, threshold=None):
    # q=threshold
    # mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup[mask].groupby('time').income_rate.mean()-1).mean()
    
    return score



def mean_income_rate_day(D_sample, y_pred, threshold=None):
    # q=threshold
    # mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup[mask].groupby('time').income_rate.mean()-1).reset_index().groupby(pd.Grouper(key='time', freq='D')).income_rate.mean().mean()

    return score
    
def mean_income_rate_month(D_sample, y_pred, threshold=None):
    # q=threshold
    # mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup[mask].groupby('time').income_rate.mean()-1).reset_index().groupby(pd.Grouper(key='time', freq='D')).income_rate.mean().mean() * df_sup.loc[mask, 'time'].dt.date.nunique() 
    score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month
    
    return score


def mean_income_rate(y_pred, D_sample):
    q = 0.99
    mask = y_pred >= np.quantile(y_pred, q)
    #mask = y_pred >= threshold
    
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    # month
    # score = (df_sup[mask].groupby('time').income_rate.mean()-1).reset_index().groupby(pd.Grouper(key='time', freq='D')).income_rate.mean().mean() * df_sup.loc[mask, 'time'].dt.date.nunique() 
    # score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month

    # tick
    score = (df_sup[mask].groupby('time').income_rate.mean()-1).mean()
    
    # point
    # score = np.mean(D_sample.income_rate[mask]) - 1

    #point win_rate
    # score = np.mean(D_sample.label[mask])

    score = round(score, 5)
    return 'mean_income_rate', score, True#is_higher_better

# %%
params = {
    "boosting_type": "gbdt",
    "objective": "binary",
    
    "num_leaves": 2,

     "bagging_fraction": 0.8,
     "bagging_freq": 1,
     "verbose": -1,
    #"metric": "auc",
    "metric": "mean_income_rate",   
    "early_stopping" : 10, 
    
    
}

auc_features = {'feature' : [],
                
               'auc_train' : [],
               'auc_valid' : [],
               'auc_test' : [],
               'auc_test2' : [],
           
           'mir_point@1_train' : [],
           'mir_point@1_valid' : [],
           'mir_point@1_test' : [],
           'mir_point@1_test2' : [],

           'mir_tick@1_train' : [],
           'mir_tick@1_valid' : [],
           'mir_tick@1_test' : [],
           'mir_tick@1_test2' : [],


           'mir_day@1_train' : [],
           'mir_day@1_valid' : [],
           'mir_day@1_test' : [],
           'mir_day@1_test2' : [],

           'mir_month@1_train' : [],
           'mir_month@1_valid' : [],
           'mir_month@1_test' : [],
           'mir_month@1_test2' : [],

           'mean_win_rate_point@1_train' : [],
           'mean_win_rate_point@1_valid' : [],
           'mean_win_rate_point@1_test' : [],
           'mean_win_rate_point@1_test2' : [],

        
               }

for feature in tqdm(features):
    stab_features = [feature]
    stab_cat_features = [feature] if feature in cat_features else []
    
    D_train = lgbm.Dataset(df.loc[mask_train_subsample, stab_features], label=df.loc[mask_train_subsample, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
    D_valid = lgbm.Dataset(df.loc[mask_valid, stab_features], label=df.loc[mask_valid, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
    D_test = lgbm.Dataset(df.loc[mask_test, stab_features], label=df.loc[mask_test, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
    D_test2 = lgbm.Dataset(df.loc[mask_test2, stab_features], label=df.loc[mask_test2, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)

    D_train.income_rate = df.loc[mask_train_subsample, 'income_rate'].values
    D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
    D_test.income_rate = df.loc[mask_test, 'income_rate'].values
    D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values
    
    D_train.time = df.loc[mask_train_subsample, 'time'].values
    D_valid.time = df.loc[mask_valid, 'time'].values
    D_test.time = df.loc[mask_test, 'time'].values
    D_test2.time = df.loc[mask_test2, 'time'].values


    
    model = lgbm.train(params, num_boost_round=1000, train_set=D_train, valid_sets=[D_valid], feval=mean_income_rate)
    
    y_pred_train = model.predict(D_train.data)
    y_pred_valid = model.predict(D_valid.data)
    y_pred_test = model.predict(D_test.data)
    y_pred_test2 = model.predict(D_test2.data)

    auc_features['feature'] += [feature]
    auc_features['auc_train'] += [roc_auc_score(D_train.label, y_pred_train)]
    auc_features['auc_valid'] += [roc_auc_score(D_valid.label, y_pred_valid)]
    auc_features['auc_test'] += [roc_auc_score(D_test.label, y_pred_test)]
    auc_features['auc_test2'] += [roc_auc_score(D_test2.label, y_pred_test2)]

    
    threshold = np.quantile(y_pred_valid, q=0.99) #в feval тоже нужно менять
    
    auc_features['mir_point@1_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold)]
    auc_features['mir_point@1_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold)]
    auc_features['mir_point@1_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold)]
    auc_features['mir_point@1_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)]

    auc_features['mir_tick@1_train'] += [mean_income_rate_tick(D_train, y_pred_train, threshold=threshold)]
    auc_features['mir_tick@1_valid'] += [mean_income_rate_tick(D_valid, y_pred_valid, threshold=threshold)]
    auc_features['mir_tick@1_test'] += [mean_income_rate_tick(D_test, y_pred_test, threshold=threshold)]
    auc_features['mir_tick@1_test2'] += [mean_income_rate_tick(D_test2, y_pred_test2, threshold=threshold)]

    auc_features['mir_day@1_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold)]
    auc_features['mir_day@1_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold)]
    auc_features['mir_day@1_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold)]
    auc_features['mir_day@1_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)]

    
    auc_features['mir_month@1_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold)]
    auc_features['mir_month@1_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold)]
    auc_features['mir_month@1_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold)]
    auc_features['mir_month@1_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)]

    auc_features['mean_win_rate_point@1_train'] += [mean_win_rate_point(D_train, y_pred_train, threshold=threshold)]
    auc_features['mean_win_rate_point@1_valid'] += [mean_win_rate_point(D_valid, y_pred_valid, threshold=threshold)]
    auc_features['mean_win_rate_point@1_test'] += [mean_win_rate_point(D_test, y_pred_test, threshold=threshold)]
    auc_features['mean_win_rate_point@1_test2'] += [mean_win_rate_point(D_test2, y_pred_test2, threshold=threshold)]

df_auc = pd.DataFrame(auc_features)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [08:02<00:00,  2.05s/it]

# %%
pd.set_option('display.max_columns', 100)
df_auc = pd.DataFrame(auc_features)
df_auc
# Out:
#                                       feature  auc_train  auc_valid  auc_test  \
# 0                          close_1hour_w1_roc   0.514520   0.511780  0.508436
# 1                     close_1hour_w5_norm_std   0.515638   0.511898  0.507324
# 2                 close_1hour_w5_mean_abs_pct   0.517948   0.513474  0.507209
# 3                        close_1hour_w5_alpha   0.525290   0.518514  0.537228
# 4                          close_1hour_w5_rsi   0.506574   0.494296  0.502149
# ..                                        ...        ...        ...       ...
# 230   close_1hour_w200_ma_up_2std/close_1hour   0.516381   0.511191  0.506333
# 231  close_1hour_w200_ma_low_3std/close_1hour   0.515972   0.502757  0.496296
# 232   close_1hour_w10_min/close_1hour_w10_max   0.520306   0.518994  0.508025
# 233   close_1hour_w20_min/close_1hour_w20_max   0.524376   0.524552  0.509576
# 234                               ticker_code   0.561536   0.522863  0.543906
#
#      auc_test2  mir_point@1_train  mir_point@1_valid  mir_point@1_test  \
# 0     0.500330          -0.000390          -0.000721         -0.002654
# 1     0.504236          -0.001034          -0.000984         -0.001003
# 2     0.503835          -0.001002          -0.000951         -0.001011
# 3     0.491389          -0.000385          -0.000641          0.000226
# 4     0.491953           0.000300          -0.000930         -0.000981
# ..         ...                ...                ...               ...
# 230   0.487410          -0.000633          -0.001223         -0.000777
# 231   0.508527          -0.000806          -0.001239         -0.001270
# 232   0.511462          -0.001056          -0.000858         -0.001111
# 233   0.516588          -0.001011          -0.000679         -0.000980
# 234   0.522511           0.006173           0.002651          0.005238
#
#      mir_point@1_test2  mir_tick@1_train  mir_tick@1_valid  mir_tick@1_test  \
# 0             0.000693         -0.000417          0.000373        -0.001125
# 1            -0.001096         -0.001041         -0.000991        -0.000993
# 2            -0.001104         -0.000985         -0.000935        -0.001005
# 3            -0.001465         -0.000360         -0.000585         0.000239
# 4            -0.001765          0.000206         -0.000853        -0.001082
# ..                 ...               ...               ...              ...
# 230          -0.003575         -0.000660          0.000051        -0.000891
# 231          -0.000909         -0.000808         -0.001325        -0.001332
# 232          -0.000957         -0.001216         -0.000680        -0.001129
# 233           0.000114         -0.001382          0.000634        -0.000989
# 234           0.003247          0.006240          0.002882         0.005335
#
#      mir_tick@1_test2  mir_day@1_train  mir_day@1_valid  mir_day@1_test  \
# 0           -0.000750        -0.000409         0.000903       -0.003460
# 1           -0.001114        -0.001041        -0.000991       -0.000993
# 2           -0.001106        -0.000985        -0.000935       -0.001005
# 3           -0.001479        -0.000360        -0.000585        0.000239
# 4           -0.002419         0.000209        -0.000881       -0.001081
# ..                ...              ...              ...             ...
# 230         -0.002906        -0.000572         0.000016       -0.000892
# 231         -0.000897        -0.000808        -0.001325       -0.001332
# 232         -0.000793        -0.001217        -0.000680       -0.001129
# 233          0.001979        -0.001420         0.000653       -0.000992
# 234          0.003801         0.006349         0.002877        0.005482
#
#      mir_day@1_test2  mir_month@1_train  mir_month@1_valid  mir_month@1_test  \
# 0           0.000971          -0.007589           0.017279         -0.070190
# 1          -0.001114          -0.022894          -0.021795         -0.021854
# 2          -0.001106          -0.021675          -0.020565         -0.022116
# 3          -0.001479          -0.007911          -0.012864          0.005256
# 4          -0.002464           0.004588          -0.019377         -0.023786
# ..               ...                ...                ...               ...
# 230        -0.003206          -0.012375           0.000344         -0.019634
# 231        -0.000897          -0.017786          -0.029160         -0.029301
# 232        -0.000793          -0.026782          -0.014968         -0.024840
# 233         0.001995          -0.031238           0.014362         -0.021814
# 234         0.003944           0.139673           0.063296          0.120612
#
#      mir_month@1_test2  mean_win_rate_point@1_train  \
# 0             0.014531                     0.531884
# 1            -0.024509                     0.487952
# 2            -0.024335                     0.488909
# 3            -0.032530                     0.495318
# 4            -0.054203                     0.498129
# ..                 ...                          ...
# 230          -0.070524                     0.521993
# 231          -0.019742                     0.487861
# 232          -0.017438                     0.493354
# 233           0.043896                     0.500735
# 234           0.086764                     0.630590
#
#      mean_win_rate_point@1_valid  mean_win_rate_point@1_test  \
# 0                       0.530043                    0.494211
# 1                       0.494309                    0.496115
# 2                       0.494886                    0.495722
# 3                       0.500504                    0.520652
# 4                       0.481048                    0.491493
# ..                           ...                         ...
# 230                     0.511715                    0.509867
# 231                     0.488130                    0.488588
# 232                     0.500893                    0.496538
# 233                     0.508930                    0.503443
# 234                     0.590991                    0.631321
#
#      mean_win_rate_point@1_test2
# 0                       0.524510
# 1                       0.467339
# 2                       0.466861
# 3                       0.458096
# 4                       0.452078
# ..                           ...
# 230                     0.435465
# 231                     0.470827
# 232                     0.475531
# 233                     0.503370
# 234                     0.598993
#
# [235 rows x 25 columns]

# %% [markdown]
# #### auc <=0.525

# %%
auc_treshold = 0.51

# %%
mask_auc  = (df_auc['auc_train'] > auc_treshold) & (df_auc['auc_valid'] > auc_treshold)
mask_auc.sum()
# Out:
# 48

# %%
(mask_auc & (df_auc['auc_test'] > auc_treshold)).sum()
# Out:
# 35

# %%
mask_auc = mask_auc & (df_auc['auc_test'] > auc_treshold)
mask_auc.sum()
# Out:
# 35

# %%
features_auc = list(features_corr[mask_auc])
len(features_auc)
# Out:
# 35

# %%
features_auc
# Out:
# ['close_1hour_w5_norm_std',
#  'close_1hour_w5_mean_abs_pct',
#  'close_1hour_w5_alpha',
#  'close_1hour_w10_norm_std',
#  'close_1hour_w10_alpha',
#  'close_1hour_w20_norm_std',
#  'close_1hour_w20_alpha',
#  'close_1hour_w30_norm_std',
#  'close_1hour_w30_alpha',
#  'close_1hour_w60_alpha',
#  'close_1hour_w120_alpha',
#  'close_1hour_w200_alpha',
#  'close_1hour_w200_roc',
#  'close_1hour_w200_lvl_-0.98-1',
#  'close_1hour_w200_lvl_1.05-1.08',
#  'close_1hour_w1_roc/close_1hour_w5_alpha',
#  'close_1hour_w1_roc/close_1hour_w10_alpha',
#  'close_1hour_w1_roc/close_1hour_w20_alpha',
#  'close_1hour_w1_roc/close_1hour_w30_alpha',
#  'close_1hour_w1_roc/close_1hour_w60_alpha',
#  'close_1hour_w1_roc/close_1hour_w120_alpha',
#  'close_1hour_w1_roc/close_1hour_w200_alpha',
#  'close_1hour/close_1hour_w200_ma',
#  'close_1hour_w20_ma/close_1hour_w200_ma',
#  'close_1hour_w60_ma/close_1hour_w120_ma',
#  'close_1hour_w60_ma/close_1hour_w200_ma',
#  'close_1hour_w10_expma/close_1hour_w200_expma',
#  'close_1hour_w5_min/close_1hour',
#  'close_1hour_w5_max/close_1hour',
#  'close_1hour_w120_max/close_1hour',
#  'close_1hour_w200_max/close_1hour',
#  'close_1hour_w30_ma_up_3std/close_1hour',
#  'close_1hour_w60_ma_up_3std/close_1hour',
#  'close_1hour_w120_ma_up_2std/close_1hour',
#  'ticker_code']

# %% [markdown]
# #### delta_auc > 0.05

# %%
auc_delta_treshold  = 0.05

# %%
mask_auc_delta= (df_auc['auc_train'] - df_auc['auc_valid']).abs() < auc_delta_treshold
mask_auc_delta.sum()
# Out:
# 174

# %%
(mask_auc_delta & ((df_auc['auc_train'] - df_auc['auc_test']).abs() < auc_delta_treshold)).sum()
# Out:
# 128

# %% [markdown]
# #### union criterias

# %%
mask_criterias = mask_auc & mask_auc_delta
mask_criterias.sum()
# Out:
# 118

# %%
features_criteria = df_auc['feature'].values[mask_criterias]
len(features_criteria), features_criteria
# Out:
# (118,
#  array(['close_w10_rsi', 'close_w30_lvl_1.02-1.04',
#         'close_w30_lvl_1.04-1.06', 'close_w120_lvl_1-1.02',
#         'close_w120_lvl_-0.96-0.98', 'close_w120_lvl_1.04-1.06',
#         'close_w120_lvl_1.06-1.08', 'hour', 'close_1hour_w1_roc',
#         'close_1hour_w30_rsi', 'close_1hour_w30_lvl_1-1.02',
#         'close_1hour_w30_lvl_1.02-1.04', 'close_1hour_w30_lvl_-0.96-0.98',
#         'close_1hour_w30_lvl_-0.94-0.96', 'close_1hour_w120_lvl_1-1.02',
#         'close_1hour_w120_lvl_1.02-1.04',
#         'close_1hour_w120_lvl_-0.94-0.96',
#         'close_w5_alpha/close_w120_alpha',
#         'close_w10_alpha/close_w120_alpha',
#         'close_w20_alpha/close_w120_alpha',
#         'close_w30_alpha/close_w120_alpha',
#         'close_w60_alpha/close_w120_alpha', 'close_w1_roc/close_w10_roc',
#         'close_w1_roc/close_w20_roc', 'close_w1_roc/close_w30_roc',
#         'close_w1_roc/close_w60_roc', 'close_w5_roc/close_w60_roc',
#         'close_w10_roc/close_w20_roc', 'close_w10_roc/close_w30_roc',
#         'close_w10_roc/close_w60_roc', 'close_w20_roc/close_w60_roc',
#         'close_w30_roc/close_w60_roc', 'close_w30_roc/close_w120_roc',
#         'close_w60_roc/close_w120_roc',
#         'close_w5_mean_abs_pct/close_w10_mean_abs_pct',
#         'close_w5_mean_abs_pct/close_w20_mean_abs_pct',
#         'close_w10_mean_abs_pct/close_w20_mean_abs_pct',
#         'close_w20_mean_abs_pct/close_w30_mean_abs_pct',
#         'close_w20_mean_abs_pct/close_w60_mean_abs_pct',
#         'close_w30_mean_abs_pct/close_w60_mean_abs_pct',
#         'close_w60_mean_abs_pct/close_w120_mean_abs_pct',
#         'close_w5_std/close_w10_std', 'close_w5_std/close_w20_std',
#         'close_w5_std/close_w30_std', 'close_w5_std/close_w60_std',
#         'close_w5_std/close_w120_std', 'close_w10_std/close_w30_std',
#         'close_w10_std/close_w60_std', 'close_w10_std/close_w120_std',
#         'close_w20_std/close_w30_std', 'close_w20_std/close_w60_std',
#         'close_w20_std/close_w120_std', 'close_w30_std/close_w60_std',
#         'close_w60_std/close_w120_std', 'close_w5_rsi/close_w10_rsi',
#         'close_w5_rsi/close_w20_rsi', 'close_w5_rsi/close_w30_rsi',
#         'close_w5_rsi/close_w60_rsi', 'close_w5_rsi/close_w120_rsi',
#         'close_w10_rsi/close_w20_rsi', 'close_w10_rsi/close_w30_rsi',
#         'close_w10_rsi/close_w60_rsi', 'close_w10_rsi/close_w120_rsi',
#         'close_w20_rsi/close_w30_rsi', 'close_w20_rsi/close_w60_rsi',
#         'close_w20_rsi/close_w120_rsi', 'close_w30_rsi/close_w60_rsi',
#         'close_w30_rsi/close_w120_rsi', 'close_w60_rsi/close_w120_rsi',
#         'close/close_w120_ma', 'close_w5_ma/close_w120_ma',
#         'close_w10_ma/close_w120_ma', 'close_w60_ma/close_w120_ma',
#         'close_w20_expma/close_w30_expma',
#         'close_w60_expma/close_w120_expma',
#         'close_1hour_w1_roc/close_1hour_w60_alpha',
#         'close_1hour_w5_alpha/close_1hour_w10_alpha',
#         'close_1hour_w1_roc/close_1hour_w20_roc',
#         'close_1hour_w1_roc/close_1hour_w30_roc',
#         'close_1hour_w1_roc/close_1hour_w60_roc',
#         'close_1hour_w5_roc/close_1hour_w10_roc',
#         'close_1hour_w5_roc/close_1hour_w20_roc',
#         'close_1hour_w5_roc/close_1hour_w30_roc',
#         'close_1hour_w5_roc/close_1hour_w60_roc',
#         'close_1hour_w10_roc/close_1hour_w20_roc',
#         'close_1hour_w10_roc/close_1hour_w30_roc',
#         'close_1hour_w10_roc/close_1hour_w60_roc',
#         'close_1hour_w10_mean_abs_pct/close_1hour_w20_mean_abs_pct',
#         'close_1hour_w10_mean_abs_pct/close_1hour_w30_mean_abs_pct',
#         'close_1hour_w20_mean_abs_pct/close_1hour_w30_mean_abs_pct',
#         'close_1hour_w5_std/close_1hour_w10_std',
#         'close_1hour_w5_std/close_1hour_w20_std',
#         'close_1hour_w5_std/close_1hour_w30_std',
#         'close_1hour_w5_std/close_1hour_w60_std',
#         'close_1hour_w10_std/close_1hour_w20_std',
#         'close_1hour_w10_std/close_1hour_w30_std',
#         'close_1hour_w10_std/close_1hour_w60_std',
#         'close_1hour_w10_std/close_1hour_w120_std',
#         'close_1hour_w20_std/close_1hour_w30_std',
#         'close_1hour_w20_std/close_1hour_w60_std',
#         'close_1hour_w30_std/close_1hour_w60_std',
#         'close_1hour_w5_rsi/close_1hour_w10_rsi',
#         'close_1hour_w5_rsi/close_1hour_w20_rsi',
#         'close_1hour_w5_rsi/close_1hour_w30_rsi',
#         'close_1hour_w5_rsi/close_1hour_w60_rsi',
#         'close_1hour_w5_rsi/close_1hour_w120_rsi',
#         'close_1hour_w10_rsi/close_1hour_w20_rsi',
#         'close_1hour_w10_rsi/close_1hour_w30_rsi',
#         'close_1hour_w10_rsi/close_1hour_w120_rsi',
#         'close_1hour_w20_rsi/close_1hour_w30_rsi',
#         'close_1hour_w20_rsi/close_1hour_w120_rsi',
#         'close_1hour_w30_rsi/close_1hour_w60_rsi',
#         'close_1hour_w30_rsi/close_1hour_w120_rsi',
#         'close/close_1hour_w5_ma', 'close/close_1hour_w10_expma',
#         'close/close_1hour_w20_expma', 'close_1hour_w20_min/close',
#         'close_1day_w5_roc/close_1day_w10_roc'], dtype=object))

# %%
df_auc.loc[df_auc['feature'].isin(features_criteria)].sort_values('auc_valid', ascending=False)
# Out:
#                                                feature  auc_train  auc_valid  \
# 283            close_1hour_w10_std/close_1hour_w60_std   0.656657   0.696106
# 71                     close_1hour_w120_lvl_-0.94-0.96   0.648640   0.650663
# 284           close_1hour_w10_std/close_1hour_w120_std   0.672997   0.646249
# 282            close_1hour_w10_std/close_1hour_w30_std   0.613856   0.637918
# 57                                 close_1hour_w30_rsi   0.671489   0.633410
# 290             close_1hour_w5_rsi/close_1hour_w10_rsi   0.601215   0.633321
# 286            close_1hour_w20_std/close_1hour_w60_std   0.604975   0.628739
# 281            close_1hour_w10_std/close_1hour_w20_std   0.608287   0.627546
# 234           close_1hour_w1_roc/close_1hour_w60_alpha   0.642474   0.623895
# 159                       close_w60_rsi/close_w120_rsi   0.608939   0.621284
# 279             close_1hour_w5_std/close_1hour_w60_std   0.628708   0.611176
# 39                            close_w120_lvl_1.04-1.06   0.579375   0.610459
# 249             close_1hour_w1_roc/close_1hour_w30_roc   0.575085   0.609152
# 61                      close_1hour_w30_lvl_-0.96-0.98   0.603459   0.607796
# 307                        close/close_1hour_w20_expma   0.653478   0.606241
# 288            close_1hour_w30_std/close_1hour_w60_std   0.604982   0.604464
# 275  close_1hour_w20_mean_abs_pct/close_1hour_w30_m...   0.639059   0.603097
# 303           close_1hour_w30_rsi/close_1hour_w120_rsi   0.638098   0.602948
# 311                          close_1hour_w20_min/close   0.558855   0.601014
# 69                         close_1hour_w120_lvl_1-1.02   0.568286   0.598094
# 302            close_1hour_w30_rsi/close_1hour_w60_rsi   0.630587   0.593540
# 114                       close_w60_roc/close_w120_roc   0.557140   0.593147
# 258            close_1hour_w10_roc/close_1hour_w30_roc   0.553913   0.587801
# 272  close_1hour_w10_mean_abs_pct/close_1hour_w30_m...   0.601322   0.587616
# 193                   close_w60_expma/close_w120_expma   0.591543   0.585376
# 259            close_1hour_w10_roc/close_1hour_w60_roc   0.572588   0.581880
# 252             close_1hour_w5_roc/close_1hour_w10_roc   0.577425   0.580938
# 158                       close_w30_rsi/close_w120_rsi   0.573874   0.579164
# 63                      close_1hour_w30_lvl_-0.94-0.96   0.538313   0.579038
# 60                       close_1hour_w30_lvl_1.02-1.04   0.612187   0.575884
# 322               close_1day_w5_roc/close_1day_w10_roc   0.544805   0.574304
# 129     close_w60_mean_abs_pct/close_w120_mean_abs_pct   0.546317   0.573125
# 165                                close/close_w120_ma   0.607482   0.572262
# 294            close_1hour_w5_rsi/close_1hour_w120_rsi   0.601942   0.569355
# 47                                                hour   0.565857   0.568144
# 306                        close/close_1hour_w10_expma   0.607398   0.568004
# 140                        close_w20_std/close_w60_std   0.543586   0.567639
# 170                          close_w5_ma/close_w120_ma   0.613119   0.565754
# 174                         close_w10_ma/close_w120_ma   0.610935   0.565405
# 250             close_1hour_w1_roc/close_1hour_w60_roc   0.592376   0.563887
# 278             close_1hour_w5_std/close_1hour_w30_std   0.574228   0.563279
# 255             close_1hour_w5_roc/close_1hour_w60_roc   0.552263   0.562945
# 277             close_1hour_w5_std/close_1hour_w20_std   0.542479   0.562772
# 153                       close_w10_rsi/close_w120_rsi   0.542633   0.562391
# 298           close_1hour_w10_rsi/close_1hour_w120_rsi   0.597934   0.562369
# 236         close_1hour_w5_alpha/close_1hour_w10_alpha   0.550566   0.562098
# 271  close_1hour_w10_mean_abs_pct/close_1hour_w20_m...   0.609837   0.560999
# 134                        close_w5_std/close_w120_std   0.519212   0.560418
# 180                         close_w60_ma/close_w120_ma   0.602513   0.560115
# 94                    close_w30_alpha/close_w120_alpha   0.541264   0.559945
# 285            close_1hour_w20_std/close_1hour_w30_std   0.590494   0.559485
# 291             close_1hour_w5_rsi/close_1hour_w20_rsi   0.575241   0.559148
# 293             close_1hour_w5_rsi/close_1hour_w60_rsi   0.576796   0.558400
# 292             close_1hour_w5_rsi/close_1hour_w30_rsi   0.574380   0.556765
# 141                       close_w20_std/close_w120_std   0.537210   0.555552
# 41                            close_w120_lvl_1.06-1.08   0.547249   0.555388
# 70                      close_1hour_w120_lvl_1.02-1.04   0.591503   0.553436
# 301           close_1hour_w20_rsi/close_1hour_w120_rsi   0.603292   0.553353
# 138                       close_w10_std/close_w120_std   0.523899   0.552600
# 58                          close_1hour_w30_lvl_1-1.02   0.530397   0.549343
# 304                            close/close_1hour_w5_ma   0.573073   0.548533
# 295            close_1hour_w10_rsi/close_1hour_w20_rsi   0.568241   0.547268
# 125      close_w20_mean_abs_pct/close_w60_mean_abs_pct   0.542922   0.544358
# 253             close_1hour_w5_roc/close_1hour_w20_roc   0.550636   0.543510
# 85                     close_w5_alpha/close_w120_alpha   0.522797   0.542851
# 299            close_1hour_w20_rsi/close_1hour_w30_rsi   0.545995   0.542444
# 149                        close_w5_rsi/close_w120_rsi   0.519015   0.541660
# 112                        close_w30_roc/close_w60_roc   0.517240   0.541313
# 115       close_w5_mean_abs_pct/close_w10_mean_abs_pct   0.519320   0.540846
# 248             close_1hour_w1_roc/close_1hour_w20_roc   0.547678   0.540271
# 144                       close_w60_std/close_w120_std   0.556102   0.539894
# 35                               close_w120_lvl_1-1.02   0.584338   0.539384
# 20                             close_w30_lvl_1.02-1.04   0.576119   0.538212
# 148                         close_w5_rsi/close_w60_rsi   0.532791   0.537948
# 157                        close_w30_rsi/close_w60_rsi   0.538923   0.537780
# 137                        close_w10_std/close_w60_std   0.534695   0.537441
# 257            close_1hour_w10_roc/close_1hour_w20_roc   0.581045   0.537388
# 147                         close_w5_rsi/close_w30_rsi   0.533515   0.537143
# 95                    close_w60_alpha/close_w120_alpha   0.547252   0.536089
# 127      close_w30_mean_abs_pct/close_w60_mean_abs_pct   0.535627   0.535655
# 116       close_w5_mean_abs_pct/close_w20_mean_abs_pct   0.532003   0.535543
# 92                    close_w20_alpha/close_w120_alpha   0.536245   0.535390
# 152                        close_w10_rsi/close_w60_rsi   0.544030   0.535305
# 146                         close_w5_rsi/close_w20_rsi   0.536457   0.535116
# 38                           close_w120_lvl_-0.96-0.98   0.519449   0.534997
# 145                         close_w5_rsi/close_w10_rsi   0.528454   0.534866
# 97                          close_w1_roc/close_w10_roc   0.527474   0.533796
# 132                         close_w5_std/close_w30_std   0.532159   0.533239
# 113                       close_w30_roc/close_w120_roc   0.556081   0.532531
# 108                        close_w10_roc/close_w60_roc   0.525429   0.530684
# 254             close_1hour_w5_roc/close_1hour_w30_roc   0.529942   0.530215
# 120      close_w10_mean_abs_pct/close_w20_mean_abs_pct   0.527322   0.529820
# 131                         close_w5_std/close_w20_std   0.510578   0.529587
# 133                         close_w5_std/close_w60_std   0.530148   0.529154
# 150                        close_w10_rsi/close_w20_rsi   0.535937   0.528722
# 139                        close_w20_std/close_w30_std   0.541582   0.526783
# 89                    close_w10_alpha/close_w120_alpha   0.525378   0.526500
# 276             close_1hour_w5_std/close_1hour_w10_std   0.553167   0.525583
# 154                        close_w20_rsi/close_w30_rsi   0.537279   0.525458
# 142                        close_w30_std/close_w60_std   0.543036   0.525408
# 156                       close_w20_rsi/close_w120_rsi   0.544891   0.525255
# 296            close_1hour_w10_rsi/close_1hour_w30_rsi   0.540281   0.525046
# 100                         close_w1_roc/close_w60_roc   0.525213   0.524097
# 22                             close_w30_lvl_1.04-1.06   0.513582   0.523731
# 8                                        close_w10_rsi   0.550019   0.523216
# 98                          close_w1_roc/close_w20_roc   0.533612   0.523118
# 124      close_w20_mean_abs_pct/close_w30_mean_abs_pct   0.521280   0.522310
# 188                    close_w20_expma/close_w30_expma   0.571543   0.522267
# 110                        close_w20_roc/close_w60_roc   0.520662   0.521979
# 136                        close_w10_std/close_w30_std   0.532793   0.518578
# 130                         close_w5_std/close_w10_std   0.517224   0.518357
# 107                        close_w10_roc/close_w30_roc   0.517392   0.517956
# 106                        close_w10_roc/close_w20_roc   0.514831   0.517589
# 50                                  close_1hour_w1_roc   0.555474   0.517201
# 155                        close_w20_rsi/close_w60_rsi   0.527183   0.515488
# 104                         close_w5_roc/close_w60_roc   0.519349   0.514557
# 151                        close_w10_rsi/close_w30_rsi   0.533553   0.513066
# 99                          close_w1_roc/close_w30_roc   0.516301   0.512142
#
#      auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 283  0.490618   0.490618           0.001939           0.003461
# 71   0.601854   0.601854           0.007332          -0.001604
# 284  0.494935   0.494935           0.010095           0.001865
# 282  0.390924   0.390924           0.002067           0.002114
# 57   0.524221   0.524221           0.005892          -0.001117
# 290  0.626611   0.626611           0.002988           0.004255
# 286  0.548201   0.548201           0.000852          -0.000814
# 281  0.369703   0.369703           0.003154           0.002520
# 234  0.498990   0.498990          -0.000990           0.008507
# 159  0.530123   0.530123           0.003794           0.006980
# 279  0.471250   0.471250           0.000641           0.002496
# 39   0.561541   0.561541          -0.000513           0.015496
# 249  0.445798   0.445798           0.002944           0.002798
# 61   0.522883   0.522883           0.001371           0.000193
# 307  0.655920   0.655920           0.002468           0.003374
# 288  0.616146   0.616146           0.000679          -0.001647
# 275  0.558811   0.558811           0.017807          -0.011353
# 303  0.454097   0.454097           0.004088           0.001756
# 311  0.568926   0.568926           0.001957           0.000031
# 69   0.544621   0.544621           0.008446          -0.000524
# 302  0.462552   0.462552           0.001404           0.001378
# 114  0.493219   0.493219           0.002347           0.000345
# 258  0.442686   0.442686           0.002434           0.001971
# 272  0.490322   0.490322           0.003637           0.003253
# 193  0.655948   0.655948           0.001899           0.002241
# 259  0.447873   0.447873           0.002647           0.005385
# 252  0.519142   0.519142           0.002708          -0.001316
# 158  0.505696   0.505696           0.001180           0.004810
# 63   0.545358   0.545358           0.001057          -0.001985
# 60   0.631091   0.631091           0.007490           0.005145
# 322  0.500000   0.500000           0.001033          -0.001337
# 129  0.579839   0.579839           0.004446           0.001648
# 165  0.600080   0.600080           0.001576           0.001674
# 294  0.566550   0.566550          -0.000087           0.006534
# 47   0.548287   0.548287           0.002755          -0.000056
# 306  0.594711   0.594711           0.000981           0.003686
# 140  0.485709   0.485709           0.002415          -0.002141
# 170  0.596268   0.596268           0.001964           0.000784
# 174  0.603538   0.603538           0.001890           0.000605
# 250  0.421712   0.421712           0.006038           0.002957
# 278  0.462616   0.462616           0.000195           0.011886
# 255  0.442059   0.442059           0.005216           0.011044
# 277  0.437650   0.437650           0.000633           0.007667
# 153  0.497930   0.497930           0.002163          -0.000168
# 298  0.627694   0.627694           0.001857           0.001899
# 236  0.495267   0.495267           0.001125           0.006335
# 271  0.500490   0.500490           0.002282           0.000754
# 134  0.485757   0.485757           0.001084           0.001841
# 180  0.656777   0.656777           0.001207          -0.001836
# 94   0.525632   0.525632           0.002397           0.004099
# 285  0.480251   0.480251           0.002832          -0.000169
# 291  0.577483   0.577483           0.000961           0.001842
# 293  0.548608   0.548608           0.000901           0.002551
# 292  0.636492   0.636492          -0.000054           0.002983
# 141  0.503687   0.503687           0.001966           0.008497
# 41   0.510926   0.510926           0.001033          -0.001337
# 70   0.538075   0.538075           0.003857          -0.003863
# 301  0.545972   0.545972           0.002425          -0.000999
# 138  0.496721   0.496721          -0.000900           0.004037
# 58   0.555769   0.555769           0.001298          -0.001129
# 304  0.529029   0.529029           0.001692           0.006913
# 295  0.577837   0.577837           0.001856          -0.001879
# 125  0.543698   0.543698           0.001367           0.002472
# 253  0.444513   0.444513           0.001033           0.000331
# 85   0.469064   0.469064           0.003058           0.003632
# 299  0.518867   0.518867           0.000808          -0.000059
# 149  0.534434   0.534434           0.002537           0.003552
# 112  0.522980   0.522980           0.001214           0.000329
# 115  0.496949   0.496949           0.002473           0.002412
# 248  0.420089   0.420089           0.001181           0.000891
# 144  0.503815   0.503815           0.001446          -0.002723
# 35   0.591230   0.591230           0.001539          -0.000094
# 20   0.535888   0.535888           0.001899           0.010790
# 148  0.529992   0.529992           0.001556           0.003793
# 157  0.505788   0.505788           0.002668           0.000123
# 137  0.483408   0.483408           0.001501           0.001466
# 257  0.442831   0.442831           0.003458           0.001509
# 147  0.497359   0.497359           0.002056           0.004658
# 95   0.485269   0.485269           0.002620           0.000135
# 127  0.517403   0.517403           0.000524           0.003418
# 116  0.545422   0.545422           0.001138           0.001284
# 92   0.510328   0.510328           0.002334           0.002771
# 152  0.513692   0.513692           0.002512           0.001968
# 146  0.501299   0.501299           0.003251           0.002563
# 38   0.531551   0.531551           0.001418          -0.000950
# 145  0.511377   0.511377           0.001677           0.004574
# 97   0.482094   0.482094           0.001218          -0.000284
# 132  0.486940   0.486940           0.001696           0.001565
# 113  0.480250   0.480250           0.003187          -0.002977
# 108  0.511803   0.511803           0.003735          -0.000314
# 254  0.489919   0.489919           0.004800           0.005779
# 120  0.519542   0.519542           0.001087           0.000998
# 131  0.493916   0.493916           0.001632           0.002818
# 133  0.475611   0.475611           0.000564           0.003040
# 150  0.493815   0.493815           0.003861           0.001491
# 139  0.512088   0.512088           0.003291           0.001112
# 89   0.481834   0.481834           0.002261           0.005235
# 276  0.529598   0.529598           0.001657          -0.002638
# 154  0.483484   0.483484           0.002739          -0.003627
# 142  0.485721   0.485721           0.003121           0.000345
# 156  0.471407   0.471407           0.003024          -0.000417
# 296  0.622196   0.622196           0.000256          -0.000358
# 100  0.516859   0.516859           0.000860          -0.001281
# 22   0.510619   0.510619           0.001033          -0.001337
# 8    0.518115   0.518115           0.002208          -0.000285
# 98   0.486852   0.486852           0.002179           0.000405
# 124  0.503047   0.503047           0.001115           0.000138
# 188  0.532300   0.532300           0.001648           0.004299
# 110  0.497240   0.497240           0.001116          -0.000109
# 136  0.497068   0.497068           0.002445          -0.001554
# 130  0.481808   0.481808           0.002200           0.001990
# 107  0.489537   0.489537           0.002109           0.003061
# 106  0.510916   0.510916           0.001195          -0.000582
# 50   0.530348   0.530348           0.003816           0.004067
# 155  0.488418   0.488418           0.002595          -0.000536
# 104  0.514327   0.514327           0.002590           0.000686
# 151  0.485137   0.485137           0.002372          -0.000529
# 99   0.486491   0.486491           0.001659          -0.000731
#
#      mir_point@1_test  mir_point@1_test2  mir_tick@1_train  mir_tick@1_valid  \
# 283          0.001089           0.001089          0.001939          0.003461
# 71           0.003598           0.003598          0.007332         -0.001604
# 284          0.005440           0.005440          0.010095          0.001865
# 282         -0.013528          -0.013528          0.002067          0.002114
# 57          -0.003474          -0.003474          0.005892         -0.001117
# 290         -0.001047          -0.001047          0.002988          0.004255
# 286          0.002093           0.002093          0.000852         -0.000814
# 281         -0.003595          -0.003595          0.003154          0.002520
# 234          0.002761           0.002761         -0.000990          0.008507
# 159         -0.005451          -0.005451          0.003794          0.006980
# 279          0.001495           0.001495          0.000641          0.002496
# 39          -0.003305          -0.003305         -0.000513          0.015496
# 249         -0.001527          -0.001527          0.002944          0.002798
# 61          -0.001722          -0.001722          0.001371          0.000193
# 307          0.009626           0.009626          0.002468          0.003374
# 288          0.003167           0.003167          0.000679         -0.001647
# 275         -0.004863          -0.004863          0.017807         -0.011353
# 303         -0.004729          -0.004729          0.004088          0.001756
# 311          0.005836           0.005836          0.001957          0.000031
# 69           0.003188           0.003188          0.008446         -0.000524
# 302         -0.004842          -0.004842          0.001404          0.001378
# 114         -0.000831          -0.000831          0.002347          0.000345
# 258          0.003810           0.003810          0.002434          0.001971
# 272         -0.004064          -0.004064          0.003637          0.003253
# 193          0.005692           0.005692          0.001899          0.002241
# 259          0.000864           0.000864          0.002647          0.005385
# 252          0.000257           0.000257          0.002708         -0.001316
# 158         -0.006634          -0.006634          0.001180          0.004810
# 63          -0.000073          -0.000073          0.001057         -0.001985
# 60           0.005829           0.005829          0.007490          0.005145
# 322         -0.000338          -0.000338          0.001033         -0.001337
# 129         -0.003883          -0.003883          0.004446          0.001648
# 165          0.001359           0.001359          0.001576          0.001674
# 294          0.001023           0.001023         -0.000087          0.006534
# 47           0.005158           0.005158          0.002755         -0.000056
# 306          0.001688           0.001688          0.000981          0.003686
# 140          0.005067           0.005067          0.002415         -0.002141
# 170          0.000307           0.000307          0.001964          0.000784
# 174          0.000979           0.000979          0.001890          0.000605
# 250         -0.007336          -0.007336          0.006038          0.002957
# 278         -0.017879          -0.017879          0.000195          0.011886
# 255         -0.004131          -0.004131          0.005216          0.011044
# 277         -0.007201          -0.007201          0.000633          0.007667
# 153          0.001526           0.001526          0.002163         -0.000168
# 298         -0.000886          -0.000886          0.001857          0.001899
# 236         -0.000085          -0.000085          0.001125          0.006335
# 271         -0.001374          -0.001374          0.002282          0.000754
# 134         -0.003841          -0.003841          0.001084          0.001841
# 180          0.003800           0.003800          0.001207         -0.001836
# 94          -0.000139          -0.000139          0.002397          0.004099
# 285         -0.000135          -0.000135          0.002832         -0.000169
# 291          0.002039           0.002039          0.000961          0.001842
# 293         -0.001529          -0.001529          0.000901          0.002551
# 292          0.004200           0.004200         -0.000054          0.002983
# 141          0.003436           0.003436          0.001966          0.008497
# 41          -0.000338          -0.000338          0.001033         -0.001337
# 70          -0.000863          -0.000863          0.003857         -0.003863
# 301          0.000774           0.000774          0.002425         -0.000999
# 138         -0.001383          -0.001383         -0.000900          0.004037
# 58           0.000042           0.000042          0.001298         -0.001129
# 304         -0.001575          -0.001575          0.001692          0.006913
# 295         -0.000457          -0.000457          0.001856         -0.001879
# 125          0.003395           0.003395          0.001367          0.002472
# 253         -0.004095          -0.004095          0.001033          0.000331
# 85          -0.001202          -0.001202          0.003058          0.003632
# 299          0.002375           0.002375          0.000808         -0.000059
# 149          0.001194           0.001194          0.002537          0.003552
# 112          0.000026           0.000026          0.001214          0.000329
# 115         -0.002640          -0.002640          0.002473          0.002412
# 248         -0.002354          -0.002354          0.001181          0.000891
# 144          0.001044           0.001044          0.001446         -0.002723
# 35           0.000946           0.000946          0.001539         -0.000094
# 20           0.006227           0.006227          0.001899          0.010790
# 148          0.000348           0.000348          0.001556          0.003793
# 157          0.001867           0.001867          0.002668          0.000123
# 137         -0.000720          -0.000720          0.001501          0.001466
# 257         -0.002490          -0.002490          0.003458          0.001509
# 147          0.000751           0.000751          0.002056          0.004658
# 95           0.003366           0.003366          0.002620          0.000135
# 127          0.001568           0.001568          0.000524          0.003418
# 116          0.001573           0.001573          0.001138          0.001284
# 92          -0.001207          -0.001207          0.002334          0.002771
# 152         -0.001510          -0.001510          0.002512          0.001968
# 146         -0.000098          -0.000098          0.003251          0.002563
# 38          -0.000298          -0.000298          0.001418         -0.000950
# 145         -0.000079          -0.000079          0.001677          0.004574
# 97           0.002011           0.002011          0.001218         -0.000284
# 132         -0.001596          -0.001596          0.001696          0.001565
# 113         -0.001398          -0.001398          0.003187         -0.002977
# 108         -0.000589          -0.000589          0.003735         -0.000314
# 254          0.005073           0.005073          0.004800          0.005779
# 120         -0.002960          -0.002960          0.001087          0.000998
# 131         -0.000716          -0.000716          0.001632          0.002818
# 133         -0.000716          -0.000716          0.000564          0.003040
# 150         -0.002936          -0.002936          0.003861          0.001491
# 139          0.001850           0.001850          0.003291          0.001112
# 89          -0.000908          -0.000908          0.002261          0.005235
# 276          0.002406           0.002406          0.001657         -0.002638
# 154         -0.003535          -0.003535          0.002739         -0.003627
# 142          0.000287           0.000287          0.003121          0.000345
# 156         -0.002745          -0.002745          0.003024         -0.000417
# 296          0.002244           0.002244          0.000256         -0.000358
# 100         -0.000108          -0.000108          0.000860         -0.001281
# 22          -0.000338          -0.000338          0.001033         -0.001337
# 8           -0.000133          -0.000133          0.002208         -0.000285
# 98           0.000285           0.000285          0.002179          0.000405
# 124          0.000213           0.000213          0.001115          0.000138
# 188          0.000345           0.000345          0.001648          0.004299
# 110         -0.000412          -0.000412          0.001116         -0.000109
# 136          0.002038           0.002038          0.002445         -0.001554
# 130         -0.000294          -0.000294          0.002200          0.001990
# 107         -0.003839          -0.003839          0.002109          0.003061
# 106          0.001315           0.001315          0.001195         -0.000582
# 50           0.002254           0.002254          0.003816          0.004067
# 155          0.000124           0.000124          0.002595         -0.000536
# 104          0.000734           0.000734          0.002590          0.000686
# 151          0.000208           0.000208          0.002372         -0.000529
# 99          -0.000058          -0.000058          0.001659         -0.000731
#
#      mir_tick@1_test  mir_tick@1_test2  mir_day@1_train  mir_day@1_valid  \
# 283         0.001089          0.001089         0.003159         0.001022
# 71          0.003598          0.003598         0.009136         0.003915
# 284         0.005440          0.005440         0.014401         0.007377
# 282        -0.013528         -0.013528         0.003064         0.002052
# 57         -0.003474         -0.003474         0.011461         0.008536
# 290        -0.001047         -0.001047         0.007448         0.005626
# 286         0.002093          0.002093         0.000889         0.001739
# 281        -0.003595         -0.003595         0.001946         0.000485
# 234         0.002761          0.002761         0.003482         0.003116
# 159        -0.005451         -0.005451         0.008004         0.007800
# 279         0.001495          0.001495         0.001489         0.002454
# 39         -0.003305         -0.003305         0.011766         0.013651
# 249        -0.001527         -0.001527         0.002957         0.002108
# 61         -0.001722         -0.001722         0.005169         0.003616
# 307         0.009626          0.009626         0.012674         0.014042
# 288         0.003167          0.003167         0.001841         0.001341
# 275        -0.004863         -0.004863         0.011138        -0.004307
# 303        -0.004729         -0.004729         0.007533         0.005568
# 311         0.005836          0.005836         0.012371         0.012006
# 69          0.003188          0.003188         0.006760         0.007583
# 302        -0.004842         -0.004842         0.005863         0.005054
# 114        -0.000831         -0.000831         0.002459        -0.001082
# 258         0.003810          0.003810         0.003287         0.000516
# 272        -0.004064         -0.004064         0.003721        -0.000753
# 193         0.005692          0.005692         0.009881         0.006158
# 259         0.000864          0.000864         0.001996         0.009141
# 252         0.000257          0.000257         0.003060        -0.001303
# 158        -0.006634         -0.006634         0.005919         0.007431
# 63         -0.000073         -0.000073         0.004561         0.003138
# 60          0.005829          0.005829         0.008083         0.006328
# 322        -0.000338         -0.000338         0.001035        -0.001337
# 129        -0.003883         -0.003883         0.001200         0.002504
# 165         0.001359          0.001359         0.011922         0.011011
# 294         0.001023          0.001023         0.004630         0.007695
# 47          0.005158          0.005158         0.002755        -0.000056
# 306         0.001688          0.001688         0.011333         0.009571
# 140         0.005067          0.005067         0.005423         0.000584
# 170         0.000307          0.000307         0.011488         0.009508
# 174         0.000979          0.000979         0.010071         0.006106
# 250        -0.007336         -0.007336         0.005535         0.006613
# 278        -0.017879         -0.017879        -0.000974         0.012469
# 255        -0.004131         -0.004131         0.005171         0.013333
# 277        -0.007201         -0.007201         0.000839         0.006331
# 153         0.001526          0.001526         0.003698         0.001146
# 298        -0.000886         -0.000886         0.007885         0.005889
# 236        -0.000085         -0.000085        -0.001154        -0.000568
# 271        -0.001374         -0.001374         0.002434        -0.000163
# 134        -0.003841         -0.003841         0.000308         0.000505
# 180         0.003800          0.003800         0.009026         0.003504
# 94         -0.000139         -0.000139         0.001068         0.003042
# 285        -0.000135         -0.000135         0.004588         0.001985
# 291         0.002039          0.002039         0.008236         0.004128
# 293        -0.001529         -0.001529         0.008713         0.006471
# 292         0.004200          0.004200         0.006928         0.004731
# 141         0.003436          0.003436         0.004094         0.004363
# 41         -0.000338         -0.000338         0.001035        -0.001337
# 70         -0.000863         -0.000863         0.007497         0.003296
# 301         0.000774          0.000774         0.004858         0.002392
# 138        -0.001383         -0.001383         0.001437         0.002126
# 58          0.000042          0.000042         0.003459         0.001498
# 304        -0.001575         -0.001575         0.010571         0.009294
# 295        -0.000457         -0.000457         0.006166         0.001996
# 125         0.003395          0.003395         0.002007         0.001506
# 253        -0.004095         -0.004095         0.001802        -0.000835
# 85         -0.001202         -0.001202         0.001837         0.002410
# 299         0.002375          0.002375         0.002893         0.000254
# 149         0.001194          0.001194         0.004447         0.003963
# 112         0.000026          0.000026         0.001714        -0.000125
# 115        -0.002640         -0.002640         0.001786         0.002494
# 248        -0.002354         -0.002354         0.000314        -0.000480
# 144         0.001044          0.001044         0.000989        -0.001047
# 35          0.000946          0.000946         0.002515         0.000110
# 20          0.006227          0.006227         0.009801         0.008329
# 148         0.000348          0.000348         0.005668         0.004445
# 157         0.001867          0.001867         0.004359         0.000588
# 137        -0.000720         -0.000720         0.003836        -0.000076
# 257        -0.002490         -0.002490         0.001968         0.002524
# 147         0.000751          0.000751         0.003909         0.004722
# 95          0.003366          0.003366         0.002586         0.003025
# 127         0.001568          0.001568         0.002007         0.003649
# 116         0.001573          0.001573         0.000632         0.002401
# 92         -0.001207         -0.001207         0.000753         0.003821
# 152        -0.001510         -0.001510         0.003290         0.003193
# 146        -0.000098         -0.000098         0.004624         0.003820
# 38         -0.000298         -0.000298         0.002615         0.000895
# 145        -0.000079         -0.000079         0.004327         0.004128
# 97          0.002011          0.002011         0.001965        -0.001035
# 132        -0.001596         -0.001596         0.000801         0.000567
# 113        -0.001398         -0.001398         0.003059        -0.002610
# 108        -0.000589         -0.000589         0.003361        -0.001413
# 254         0.005073          0.005073         0.001780         0.002894
# 120        -0.002960         -0.002960         0.000924         0.005988
# 131        -0.000716         -0.000716         0.000976         0.001524
# 133        -0.000716         -0.000716         0.001806         0.001427
# 150        -0.002936         -0.002936         0.004356         0.002309
# 139         0.001850          0.001850         0.003316         0.001203
# 89         -0.000908         -0.000908         0.002473         0.000939
# 276         0.002406          0.002406         0.004196        -0.001729
# 154        -0.003535         -0.003535         0.003295         0.000209
# 142         0.000287          0.000287         0.003666         0.000815
# 156        -0.002745         -0.002745         0.004360         0.001189
# 296         0.002244          0.002244         0.003860         0.004733
# 100        -0.000108         -0.000108         0.000419        -0.001055
# 22         -0.000338         -0.000338         0.001035        -0.001337
# 8          -0.000133         -0.000133         0.005482         0.003309
# 98          0.000285          0.000285         0.001585        -0.000356
# 124         0.000213          0.000213         0.001816         0.004162
# 188         0.000345          0.000345         0.008225         0.005636
# 110        -0.000412         -0.000412         0.001586        -0.000627
# 136         0.002038          0.002038         0.003581        -0.001153
# 130        -0.000294         -0.000294         0.001704         0.000456
# 107        -0.003839         -0.003839         0.000649         0.001861
# 106         0.001315          0.001315         0.001544        -0.000909
# 50          0.002254          0.002254         0.007049         0.005525
# 155         0.000124          0.000124         0.002814         0.000386
# 104         0.000734          0.000734         0.002276        -0.000718
# 151         0.000208          0.000208         0.002583         0.001509
# 99         -0.000058         -0.000058         0.001064        -0.000957
#
#      mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 283       -0.003241        -0.003241           0.038529           0.012329
# 71         0.007107         0.007107           0.170407           0.075022
# 284        0.003278         0.003278           0.092983           0.036645
# 282       -0.012881        -0.012881           0.031510           0.026208
# 57         0.002341         0.002341           0.186371           0.145396
# 290        0.006522         0.006522           0.160296           0.115784
# 286       -0.001149        -0.001149           0.016154           0.034566
# 281       -0.003084        -0.003084           0.042818           0.010669
# 234        0.000721         0.000721           0.057458           0.044222
# 159        0.002524         0.002524           0.176091           0.171605
# 279       -0.005702        -0.005702           0.019945           0.029610
# 39         0.002819         0.002819           0.140684           0.135630
# 249       -0.000498        -0.000498           0.064339           0.044872
# 61         0.003999         0.003999           0.103824           0.076985
# 307        0.019164         0.019164           0.145480           0.159442
# 288        0.003062         0.003062           0.038747           0.029496
# 275       -0.007064        -0.007064           0.079905          -0.027508
# 303       -0.001958        -0.001958           0.102675           0.071132
# 311        0.017757         0.017757           0.189326           0.195969
# 69         0.004276         0.004276           0.098605           0.102251
# 302        0.002034         0.002034           0.112167           0.104015
# 114        0.002435         0.002435           0.054087          -0.023803
# 258       -0.003626        -0.003626           0.062874           0.010249
# 272       -0.006781        -0.006781           0.064061          -0.014958
# 193        0.000287         0.000287           0.160670           0.100519
# 259       -0.006946        -0.006946           0.035320           0.149202
# 252        0.002616         0.002616           0.067319          -0.028672
# 158        0.004834         0.004834           0.121731           0.152928
# 63         0.004466         0.004466           0.098154           0.066809
# 60         0.005876         0.005876           0.094706           0.071849
# 322       -0.000338        -0.000338           0.022767          -0.029421
# 129       -0.002658        -0.002658           0.020081           0.039093
# 165        0.007242         0.007242           0.213824           0.218790
# 294        0.006754         0.006754           0.074175           0.120141
# 47         0.005158         0.005158           0.060599          -0.001226
# 306        0.006614         0.006614           0.200553           0.176600
# 140        0.005622         0.005622           0.112828           0.012433
# 170        0.004789         0.004789           0.211522           0.188940
# 174        0.003731         0.003731           0.173389           0.104007
# 250       -0.000807        -0.000807           0.072800           0.079786
# 278       -0.016017        -0.016017          -0.008385           0.123884
# 255       -0.001837        -0.001837           0.069243           0.113545
# 277       -0.007919        -0.007919           0.014851           0.107828
# 153        0.003351         0.003351           0.081354           0.025206
# 298        0.000859         0.000859           0.152725           0.121200
# 236       -0.003763        -0.003763          -0.024566          -0.012093
# 271       -0.002776        -0.002776           0.053541          -0.003581
# 134       -0.004026        -0.004026           0.006766           0.011119
# 180        0.000328         0.000328           0.155406           0.062162
# 94         0.004955         0.004955           0.023492           0.066932
# 285       -0.005880        -0.005880           0.088872           0.036623
# 291        0.009153         0.009153           0.171349           0.084958
# 293        0.008083         0.008083           0.185426           0.133174
# 292        0.013528         0.013528           0.137507           0.090651
# 141        0.001684         0.001684           0.076354           0.089785
# 41        -0.000338        -0.000338           0.022767          -0.029421
# 70         0.003493         0.003493           0.143422           0.058484
# 301        0.006290         0.006290           0.104560           0.050933
# 138       -0.002918        -0.002918           0.030927           0.045265
# 58         0.003449         0.003449           0.076094           0.032965
# 304        0.007076         0.007076           0.204750           0.184680
# 295        0.003467         0.003467           0.117954           0.038249
# 125        0.004192         0.004192           0.044163           0.033129
# 253       -0.005259        -0.005259           0.037499          -0.017785
# 85         0.000025         0.000025           0.040407           0.053027
# 299        0.003722         0.003722           0.063655           0.005583
# 149        0.003580         0.003580           0.097842           0.087178
# 112       -0.000287        -0.000287           0.037708          -0.002753
# 115       -0.000461        -0.000461           0.039288           0.054872
# 248       -0.003214        -0.003214           0.006899          -0.010559
# 144       -0.003542        -0.003542           0.020578          -0.023041
# 35         0.001988         0.001988           0.055339           0.002414
# 20         0.005634         0.005634           0.154690           0.147779
# 148        0.004170         0.004170           0.123338           0.094632
# 157        0.002607         0.002607           0.095895           0.012933
# 137        0.002422         0.002422           0.084399          -0.001664
# 257       -0.004988        -0.004988           0.043292           0.055533
# 147        0.003374         0.003374           0.085995           0.103890
# 95         0.006328         0.006328           0.056895           0.066555
# 127        0.004617         0.004617           0.043677           0.080281
# 116        0.001475         0.001475           0.013910           0.052817
# 92         0.000828         0.000828           0.016566           0.084067
# 152        0.000582         0.000582           0.072381           0.070235
# 146        0.002432         0.002432           0.101732           0.084035
# 38         0.001558         0.001558           0.057539           0.019701
# 145        0.002684         0.002684           0.095189           0.090817
# 97         0.002008         0.002008           0.043240          -0.022781
# 132       -0.002071        -0.002071           0.017619           0.012464
# 113        0.002525         0.002525           0.067300          -0.057421
# 108        0.002347         0.002347           0.073944          -0.031081
# 254        0.001228         0.001228           0.020853           0.034919
# 120       -0.000494        -0.000494           0.020318           0.131744
# 131       -0.001654        -0.001654           0.021465           0.033529
# 133       -0.000081        -0.000081           0.039724           0.031393
# 150       -0.000447        -0.000447           0.095837           0.050800
# 139        0.000997         0.000997           0.072950           0.026456
# 89         0.000277         0.000277           0.054400           0.020654
# 276       -0.000496        -0.000496           0.091318          -0.036807
# 154       -0.001291        -0.001291           0.072483           0.004590
# 142        0.001530         0.001530           0.078889           0.017931
# 156        0.000841         0.000841           0.095917           0.026153
# 296        0.001304         0.001304           0.079382           0.097407
# 100       -0.001099        -0.001099           0.009225          -0.023200
# 22        -0.000338        -0.000338           0.022767          -0.029421
# 8          0.004155         0.004155           0.120605           0.072801
# 98        -0.000333        -0.000333           0.034876          -0.007834
# 124        0.001624         0.001624           0.039957           0.091564
# 188        0.005743         0.005743           0.165212           0.115990
# 110        0.000280         0.000280           0.034894          -0.013799
# 136        0.003275         0.003275           0.078793          -0.025358
# 130       -0.000748        -0.000748           0.037488           0.010021
# 107       -0.002102        -0.002102           0.014287           0.040940
# 106        0.001131         0.001131           0.033968          -0.019994
# 50         0.000064         0.000064           0.114624           0.098029
# 155        0.001626         0.001626           0.061914           0.008482
# 104        0.003293         0.003293           0.050062          -0.015787
# 151        0.001126         0.001126           0.056817           0.033197
# 99        -0.000745        -0.000745           0.023416          -0.021061
#
#      mir_month@1_test  mir_month@1_test2  mean_win_rate_point@1_train  \
# 283         -0.037196          -0.037196                     0.163147
# 71           0.135959           0.135959                     0.131482
# 284          0.025086           0.025086                     0.248095
# 282         -0.135534          -0.135534                     0.157364
# 57           0.033594           0.033594                     0.154733
# 290          0.137250           0.137250                     0.146868
# 286         -0.024176          -0.024176                     0.118849
# 281         -0.067846          -0.067846                     0.119470
# 234          0.012421           0.012421                     0.148451
# 159          0.053116           0.053116                     0.169728
# 279         -0.065445          -0.065445                     0.154427
# 39           0.037755           0.037755                     0.194586
# 249         -0.010474          -0.010474                     0.110875
# 61           0.076508           0.076508                     0.113987
# 307          0.256636           0.256636                     0.212571
# 288          0.064429           0.064429                     0.112243
# 275         -0.047299          -0.047299                     0.287660
# 303         -0.022472          -0.022472                     0.140625
# 311          0.254768           0.254768                     0.145766
# 69           0.061347           0.061347                     0.131143
# 302          0.033079           0.033079                     0.125779
# 114          0.053573           0.053573                     0.106650
# 258         -0.072838          -0.072838                     0.114621
# 272         -0.123242          -0.123242                     0.154277
# 193          0.004123           0.004123                     0.158532
# 259         -0.139529          -0.139529                     0.129661
# 252          0.057546           0.057546                     0.109505
# 158          0.101720           0.101720                     0.147253
# 63           0.093990           0.093990                     0.095539
# 60           0.061822           0.061822                     0.162462
# 322         -0.007430          -0.007430                     0.087564
# 129         -0.035593          -0.035593                     0.125385
# 165          0.131611           0.131611                     0.167460
# 294          0.096900           0.096900                     0.147266
# 47           0.113475           0.113475                     0.115338
# 306          0.120205           0.120205                     0.167944
# 140          0.123690           0.123690                     0.132692
# ...
# 295          0.063010           0.063010                     0.118392
# 125          0.092228           0.092228                     0.115705
# 253         -0.115703          -0.115703                     0.116047
# 85           0.000553           0.000553                     0.106077
# 299          0.081890           0.081890                     0.102908
# 149          0.078760           0.078760                     0.107387
# 112         -0.006309          -0.006309                     0.092636
# 115         -0.010142          -0.010142                     0.107611
# 248         -0.070714          -0.070714                     0.102264
# 144         -0.071149          -0.071149                     0.110606
# 35           0.043743           0.043743                     0.110786
# 20           0.091611           0.091611                     0.230196
# 148          0.091732           0.091732                     0.111345
# 157          0.057362           0.057362                     0.123810
# 137          0.053289           0.053289                     0.109295
# 257         -0.109727          -0.109727                     0.117965
# 147          0.074233           0.074233                     0.111408
# 95           0.133171           0.133171                     0.126655
# 127          0.101577           0.101577                     0.128111
# 116          0.032461           0.032461                     0.105637
# 92           0.018226           0.018226                     0.108123
# 152          0.012806           0.012806                     0.122768
# 146          0.053503           0.053503                     0.119403
# 38           0.034268           0.034268                     0.091010
# 145          0.059056           0.059056                     0.114630
# 97           0.044170           0.044170                     0.103941
# 132         -0.045552          -0.045552                     0.103309
# 113          0.055547           0.055547                     0.109341
# 108          0.051631           0.051631                     0.113431
# 254          0.016439           0.016439                     0.146396
# 120         -0.010861          -0.010861                     0.115385
# 131         -0.036391          -0.036391                     0.100893
# 133         -0.001787          -0.001787                     0.110646
# 150         -0.009823          -0.009823                     0.125154
# 139          0.021933           0.021933                     0.105530
# 89           0.006086           0.006086                     0.104326
# 276         -0.010904          -0.010904                     0.112222
# 154         -0.027165          -0.027165                     0.113507
# 142          0.033651           0.033651                     0.112981
# 156          0.018492           0.018492                     0.120653
# 296          0.024944           0.024944                     0.110742
# 100         -0.024188          -0.024188                     0.095572
# 22          -0.007430          -0.007430                     0.087564
# 8            0.091408           0.091408                     0.125000
# 98          -0.007331          -0.007331                     0.104283
# 124          0.035727           0.035727                     0.116923
# 188          0.120856           0.120856                     0.180590
# 110          0.006155           0.006155                     0.091605
# 136          0.072042           0.072042                     0.101331
# 130         -0.016460          -0.016460                     0.099499
# 107         -0.046255          -0.046255                     0.097959
# 106          0.024886           0.024886                     0.092033
# 50           0.001097           0.001097                     0.196296
# 155          0.035776           0.035776                     0.111910
# 104          0.072436           0.072436                     0.097113
# 151          0.024771           0.024771                     0.114108
# 99          -0.016386          -0.016386                     0.093707
#
#      mean_win_rate_point@1_valid  mean_win_rate_point@1_test  \
# 283                     0.199850                    0.106164
# 71                      0.124256                    0.142181
# 284                     0.073643                    0.152381
# 282                     0.159639                    0.102941
# 57                      0.118116                    0.105911
# 290                     0.149038                    0.159110
# 286                     0.120957                    0.118210
# 281                     0.127308                    0.053738
# 234                     0.206468                    0.106771
# 159                     0.162791                    0.086397
# 279                     0.180095                    0.074074
# 39                      0.327044                    0.208108
# 249                     0.145425                    0.098624
# 61                      0.110276                    0.108941
# 307                     0.159363                    0.303987
# 288                     0.108118                    0.136016
# 275                     0.078947                    0.166667
# 303                     0.128717                    0.148897
# 311                     0.119205                    0.212844
# 69                      0.161111                    0.146396
# 302                     0.112825                    0.107937
# 114                     0.116629                    0.113032
# 258                     0.134366                    0.077551
# 272                     0.144310                    0.098343
# 193                     0.153306                    0.236413
# 259                     0.141243                    0.071429
# 252                     0.111064                    0.117309
# 158                     0.139113                    0.073077
# 63                      0.100314                    0.115063
# 60                      0.170455                    0.115023
# 322                     0.085237                    0.104771
# 129                     0.150888                    0.166253
# 165                     0.142692                    0.193020
# 294                     0.193503                    0.194726
# 47                      0.106631                    0.150966
# 306                     0.156635                    0.195940
# 140                     0.101664                    0.112219
# 170                     0.128941                    0.177547
# 174                     0.135035                    0.187119
# 250                     0.122449                    0.041667
# 278                     0.174797                    0.004651
# 255                     0.189614                    0.004630
# 277                     0.149123                    0.023983
# 153                     0.094752                    0.127016
# 298                     0.103556                    0.170635
# 236                     0.140411                    0.107639
# 271                     0.101490                    0.107990
# 134                     0.142283                    0.071429
# 180                     0.118100                    0.217153
# 94                      0.116360                    0.110204
# 285                     0.116175                    0.091821
# 291                     0.120773                    0.185813
# 293                     0.116250                    0.142143
# 292                     0.126389                    0.198612
# 141                     0.137615                    0.129310
# 41                      0.085237                    0.104771
# 70                      0.096696                    0.104995
# 301                     0.096368                    0.115683
# 138                     0.134043                    0.087079
# 58                      0.094265                    0.117374
# 304                     0.165871                    0.158050
# 295                     0.100198                    0.154661
# 125                     0.114464                    0.141169
# 253                     0.118839                    0.061441
# 85                      0.103072                    0.107717
# 299                     0.096508                    0.138889
# 149                     0.140449                    0.153846
# 112                     0.098843                    0.112315
# 115                     0.106870                    0.103079
# 248                     0.107210                    0.063472
# 144                     0.115926                    0.125108
# 35                      0.105606                    0.133398
# 20                      0.192641                    0.202326
# 148                     0.148810                    0.140056
# 157                     0.089924                    0.096910
# 137                     0.102378                    0.105978
# 257                     0.102923                    0.072279
# 147                     0.125316                    0.129758
# 95                      0.057604                    0.116832
# 127                     0.127350                    0.133676
# 116                     0.106040                    0.139905
# 92                      0.090580                    0.108247
# 152                     0.111453                    0.121212
# 146                     0.117998                    0.108271
# 38                      0.091270                    0.111802
# 145                     0.145570                    0.110193
# 97                      0.095406                    0.118534
# 132                     0.104471                    0.092866
# 113                     0.079599                    0.107642
# 108                     0.101027                    0.083146
# 254                     0.146296                    0.115591
# 120                     0.123106                    0.096070
# 131                     0.121886                    0.096305
# 133                     0.126894                    0.115479
# 150                     0.099886                    0.102564
# 139                     0.110475                    0.119024
# 89                      0.098274                    0.095477
# 276                     0.094181                    0.123950
# 154                     0.087751                    0.071605
# 142                     0.105263                    0.082682
# 156                     0.105780                    0.078493
# 296                     0.100309                    0.185029
# 100                     0.092814                    0.109195
# 22                      0.085237                    0.104771
# 8                       0.098214                    0.120280
# 98                      0.106218                    0.117647
# 124                     0.123171                    0.110749
# 188                     0.117464                    0.154321
# 110                     0.097902                    0.098462
# 136                     0.103926                    0.118871
# 130                     0.099003                    0.094357
# 107                     0.086598                    0.078880
# 106                     0.097119                    0.121622
# 50                      0.128623                    0.183333
# 155                     0.099222                    0.093117
# 104                     0.095732                    0.120415
# 151                     0.088372                    0.120163
# 99                      0.091154                    0.105573
#
#      mean_win_rate_point@1_test2
# 283                     0.106164
# 71                      0.142181
# 284                     0.152381
# 282                     0.102941
# 57                      0.105911
# 290                     0.159110
# 286                     0.118210
# 281                     0.053738
# 234                     0.106771
# 159                     0.086397
# 279                     0.074074
# 39                      0.208108
# 249                     0.098624
# 61                      0.108941
# 307                     0.303987
# 288                     0.136016
# 275                     0.166667
# 303                     0.148897
# 311                     0.212844
# 69                      0.146396
# 302                     0.107937
# 114                     0.113032
# 258                     0.077551
# 272                     0.098343
# 193                     0.236413
# 259                     0.071429
# 252                     0.117309
# 158                     0.073077
# 63                      0.115063
# 60                      0.115023
# 322                     0.104771
# 129                     0.166253
# 165                     0.193020
# 294                     0.194726
# 47                      0.150966
# 306                     0.195940
# 140                     0.112219
# 170                     0.177547
# 174                     0.187119
# 250                     0.041667
# 278                     0.004651
# 255                     0.004630
# 277                     0.023983
# 153                     0.127016
# 298                     0.170635
# 236                     0.107639
# 271                     0.107990
# 134                     0.071429
# 180                     0.217153
# 94                      0.110204
# 285                     0.091821
# 291                     0.185813
# 293                     0.142143
# 292                     0.198612
# 141                     0.129310
# 41                      0.104771
# 70                      0.104995
# 301                     0.115683
# 138                     0.087079
# 58                      0.117374
# 304                     0.158050
# 295                     0.154661
# 125                     0.141169
# 253                     0.061441
# 85                      0.107717
# 299                     0.138889
# 149                     0.153846
# 112                     0.112315
# 115                     0.103079
# 248                     0.063472
# 144                     0.125108
# 35                      0.133398
# 20                      0.202326
# 148                     0.140056
# 157                     0.096910
# 137                     0.105978
# 257                     0.072279
# 147                     0.129758
# 95                      0.116832
# 127                     0.133676
# 116                     0.139905
# 92                      0.108247
# 152                     0.121212
# 146                     0.108271
# 38                      0.111802
# 145                     0.110193
# 97                      0.118534
# 132                     0.092866
# 113                     0.107642
# 108                     0.083146
# 254                     0.115591
# 120                     0.096070
# 131                     0.096305
# 133                     0.115479
# 150                     0.102564
# 139                     0.119024
# 89                      0.095477
# 276                     0.123950
# 154                     0.071605
# 142                     0.082682
# 156                     0.078493
# 296                     0.185029
# 100                     0.109195
# 22                      0.104771
# 8                       0.120280
# 98                      0.117647
# 124                     0.110749
# 188                     0.154321
# 110                     0.098462
# 136                     0.118871
# 130                     0.094357
# 107                     0.078880
# 106                     0.121622
# 50                      0.183333
# 155                     0.093117
# 104                     0.120415
# 151                     0.120163
# 99                      0.105573

# %% [markdown]
# ### mask3

# %% [markdown]
# #### #1

# %%
col = 'mir_tick@1'
threshold = 0.0000 #.004 - хотя бы что-то показывает

mask_ir_train = df_auc[f'{col}_train'] >=  threshold
mask_ir_valid = df_auc[f'{col}_valid'] >=  threshold
mask_ir_test = df_auc[f'{col}_test'] >= threshold
mask_ir_test2 = df_auc[f'{col}_test2'] >=  threshold


mask_ir_train.sum(), mask_ir_valid.sum(), mask_ir_test.sum(), mask_ir_test2.sum()
# Out:
# (9, 30, 15, 19)

# %%
mask_ir= mask_ir_valid&mask_ir_test

#mask_ir= mask_ir_train&mask_ir_valid&mask_ir_test&mask_ir_test2

mask_ir = mask_ir_test

mask_ir.sum()
# Out:
# 15

# %% [markdown]
# #### #2

# %%
col = 'mir_tick@1'
threshold = 0.01

mask_ir2_test = np.abs(df_auc[f'{col}_valid'] - df_auc[f'{col}_test']) < threshold
mask_ir2_test2 = np.abs(df_auc[f'{col}_valid'] - df_auc[f'{col}_test2']) < threshold


mask_ir2_test.sum(), mask_ir2_test2.sum()
# Out:
# (235, 235)

# %%
mask_ir2= mask_ir2_test&mask_ir2_test2
mask_ir2.sum()
# Out:
# 235

# %%
(mask_ir&mask_ir2).sum()
# Out:
# 15

# %%
mask_criteria3 = mask_ir#&mask_ir2
features_criteria3 = df_auc['feature'].values[mask_criteria3]
len(features_criteria3), features_criteria3
# Out:
# (15,
#  array(['close_1hour_w5_alpha', 'close_1hour_w10_alpha',
#         'close_1hour_w20_alpha', 'close_1hour_w60_alpha',
#         'close_1hour_w60_roc', 'close_1hour_w200_alpha',
#         'close_1hour_w1_roc/close_1hour_w5_alpha',
#         'close_1hour_w1_roc/close_1hour_w10_alpha',
#         'close_1hour_w1_roc/close_1hour_w20_alpha',
#         'close_1hour_w1_roc/close_1hour_w30_alpha',
#         'close_1hour_w1_roc/close_1hour_w60_alpha',
#         'close_1hour_w1_roc/close_1hour_w120_alpha',
#         'close_1hour_w1_roc/close_1hour_w200_alpha',
#         'close_1hour_w120_norm_std/close_1hour_w200_norm_std',
#         'ticker_code'], dtype=object))

# %%
pd.set_option('display.max_rows', 160)
df_auc.loc[df_auc['feature'].isin(features_criteria3)].sort_values('auc_valid', ascending=False)
# Out:
#                                                feature  auc_train  auc_valid  \
# 234                                        ticker_code   0.561536   0.522863
# 61            close_1hour_w1_roc/close_1hour_w20_alpha   0.526098   0.522044
# 65           close_1hour_w1_roc/close_1hour_w200_alpha   0.524035   0.521413
# 62            close_1hour_w1_roc/close_1hour_w30_alpha   0.524317   0.519891
# 44                              close_1hour_w200_alpha   0.528635   0.519888
# 7                                close_1hour_w10_alpha   0.526147   0.519189
# 60            close_1hour_w1_roc/close_1hour_w10_alpha   0.522445   0.519053
# 3                                 close_1hour_w5_alpha   0.525290   0.518514
# 28                               close_1hour_w60_alpha   0.525645   0.518155
# 11                               close_1hour_w20_alpha   0.525899   0.517998
# 59             close_1hour_w1_roc/close_1hour_w5_alpha   0.514722   0.511326
# 63            close_1hour_w1_roc/close_1hour_w60_alpha   0.511449   0.509726
# 64           close_1hour_w1_roc/close_1hour_w120_alpha   0.511331   0.508788
# 30                                 close_1hour_w60_roc   0.515851   0.504412
# 170  close_1hour_w120_norm_std/close_1hour_w200_nor...   0.500421   0.500221
#
#      auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 234  0.543906   0.522511           0.006173           0.002651
# 61   0.540911   0.492600           0.000200          -0.000555
# 65   0.538308   0.494386          -0.000136          -0.000392
# 62   0.538278   0.493836          -0.000210          -0.000668
# 44   0.545344   0.485195          -0.000185          -0.000387
# 7    0.539105   0.489182          -0.000322          -0.000613
# 60   0.535562   0.493783          -0.000317          -0.000647
# 3    0.537228   0.491389          -0.000385          -0.000641
# 28   0.536749   0.490002          -0.000342          -0.000663
# 11   0.537896   0.488260          -0.000306          -0.000624
# 59   0.522159   0.496768          -0.000273          -0.000625
# 63   0.516634   0.497730          -0.000219          -0.000594
# 64   0.517167   0.498686          -0.000353          -0.000687
# 30   0.506147   0.499260          -0.001633          -0.000488
# 170  0.500136   0.499684           0.000016          -0.000646
#
#      mir_point@1_test  mir_point@1_test2  mir_tick@1_train  mir_tick@1_valid  \
# 234          0.005238           0.003247          0.006240          0.002882
# 61           0.001045          -0.002373          0.000493         -0.000162
# 65           0.000423          -0.001983         -0.000094         -0.000271
# 62           0.000465          -0.001449         -0.000143         -0.000554
# 44           0.000805          -0.001701         -0.000198         -0.000277
# 7            0.000400          -0.001604         -0.000303         -0.000551
# 60           0.000330          -0.001532         -0.000264         -0.000505
# 3            0.000226          -0.001465         -0.000360         -0.000585
# 28           0.000286          -0.001604         -0.000330         -0.000621
# 11           0.000348          -0.001600         -0.000291         -0.000552
# 59           0.000409          -0.001609         -0.000169         -0.000516
# 63           0.000333          -0.001487         -0.000132         -0.000518
# 64           0.000336          -0.001361         -0.000289         -0.000556
# 30           0.001253           0.002847         -0.001349         -0.000731
# 170         -0.000867          -0.001597          0.000176         -0.000351
#
#      mir_tick@1_test  mir_tick@1_test2  mir_day@1_train  mir_day@1_valid  \
# 234         0.005335          0.003801         0.006349         0.002877
# 61          0.001044         -0.002520         0.000505        -0.000162
# 65          0.000420         -0.001878        -0.000094        -0.000271
# 62          0.000556         -0.001511        -0.000143        -0.000554
# 44          0.000794         -0.001709        -0.000198        -0.000277
# 7           0.000422         -0.001641        -0.000303        -0.000551
# 60          0.000358         -0.001600        -0.000265        -0.000505
# 3           0.000239         -0.001479        -0.000360        -0.000585
# 28          0.000296         -0.001634        -0.000330        -0.000621
# 11          0.000375         -0.001632        -0.000291        -0.000552
# 59          0.000416         -0.001710        -0.000169        -0.000516
# 63          0.000410         -0.001733        -0.000132        -0.000518
# 64          0.000437         -0.001552        -0.000289        -0.000556
# 30          0.000210         -0.000596        -0.000395         0.002414
# 170         0.000529         -0.002013        -0.000015        -0.000203
#
#      mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 234        0.005482         0.003944           0.139673           0.063296
# 61         0.001041        -0.002520           0.011100          -0.003575
# 65         0.000420        -0.001878          -0.002079          -0.005957
# 62         0.000556        -0.001511          -0.003154          -0.012192
# 44         0.000794        -0.001709          -0.004363          -0.006098
# 7          0.000422        -0.001641          -0.006668          -0.012127
# 60         0.000358        -0.001600          -0.005839          -0.011101
# 3          0.000239        -0.001479          -0.007911          -0.012864
# 28         0.000296        -0.001634          -0.007260          -0.013665
# 11         0.000375        -0.001632          -0.006409          -0.012136
# 59         0.000416        -0.001710          -0.003712          -0.011357
# 63         0.000410        -0.001733          -0.002907          -0.011402
# 64         0.000437        -0.001552          -0.006365          -0.012238
# 30         0.000972         0.001549          -0.007998           0.050799
# 170        0.001817        -0.001413          -0.000247          -0.003591
#
#      mir_month@1_test  mir_month@1_test2  mean_win_rate_point@1_train  \
# 234          0.120612           0.086764                     0.630590
# 61           0.022897          -0.055442                     0.508461
# 65           0.009246          -0.041306                     0.501602
# 62           0.012242          -0.033252                     0.500507
# 44           0.017472          -0.037607                     0.501534
# 7            0.009279          -0.036105                     0.496641
# 60           0.007878          -0.035190                     0.499366
# 3            0.005256          -0.032530                     0.495318
# 28           0.006520          -0.035948                     0.496268
# 11           0.008243          -0.035901                     0.496718
# 59           0.009142          -0.037611                     0.499692
# 63           0.009029          -0.038134                     0.499579
# 64           0.009605          -0.034135                     0.497955
# 30           0.021138           0.028622                     0.518411
# 170          0.031092          -0.019892                     0.503576
#
#      mean_win_rate_point@1_valid  mean_win_rate_point@1_test  \
# 234                     0.590991                    0.631321
# 61                      0.516963                    0.542698
# 65                      0.512912                    0.530106
# 62                      0.505165                    0.528912
# 44                      0.509575                    0.533440
# 7                       0.502193                    0.524203
# 60                      0.504681                    0.525913
# 3                       0.500504                    0.520652
# 28                      0.500894                    0.521600
# 11                      0.501931                    0.523315
# 59                      0.505016                    0.526340
# 63                      0.505416                    0.524283
# 64                      0.502686                    0.523633
# 30                      0.535557                    0.554096
# 170                     0.496281                    0.499625
#
#      mean_win_rate_point@1_test2
# 234                     0.598993
# 61                      0.452764
# 65                      0.453589
# 62                      0.460833
# 44                      0.454113
# 7                       0.455415
# 60                      0.457481
# 3                       0.458096
# 28                      0.455206
# 11                      0.455617
# 59                      0.456788
# 63                      0.459554
# 64                      0.461691
# 30                      0.560861
# 170                     0.407843

# %% [markdown]
# ### model

# %%
# def get_useful_features(feature):
#     # if ('1day' not in feature) and ('1hour' not in feature):
#     #     return False
#     # if 'roc' in feature:
#     #     return False
    
#     for elem in ['expma']: #, 'alpha' , 'lvl'
#         if elem in feature:
#             return True
#     return False

# mask_useful_features = np.array([get_useful_features(feature) for feature in features_all])
# features_useful = np.array(features_all)[mask_useful_features].tolist()
# len(features_useful), features_useful

# %%
#features = features_criteria.tolist()# + ['ticker_code']

#features = features_criteria3.tolist()

#features = ['close/close_w30_expma']
features = features_all
#features.remove('ticker_code')

#features = features_corr.tolist()
cat_features = [feature for feature in features if feature in cat_features_all]

# %%
len(features), len(cat_features)
# Out:
# (315, 4)

# %%
# del D_train, D_valid, D_test, D_test2
# gc.collect()

# %%
#features

# %%
cat_features
# Out:
# ['hour', 'day', 'weekday', 'ticker_code']

# %%
'ticker_code' in features
# Out:
# True

# %%
D_train = lgbm.Dataset(df.loc[mask_train, features], label=df.loc[mask_train, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, features], label=df.loc[mask_valid, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, features], label=df.loc[mask_test, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, features], label=df.loc[mask_test2, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)


D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
1
# Out:
# 1

# %%
# D_test3 = lgbm.Dataset(df.loc[mask_test3, features], label=df.loc[mask_test3, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
# D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
# D_test3.time = df.loc[mask_test3, 'time'].values

# %%
def mean_income_rate(y_pred, D_sample):
    q = 0.99
    mask = y_pred >= np.quantile(y_pred, q)
    #mask = y_pred >= threshold
    
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    # # # month
    score = (df_sup[mask].groupby('time').income_rate.mean()-1).reset_index().groupby(pd.Grouper(key='time', freq='D')).income_rate.mean().mean() * df_sup.loc[mask, 'time'].dt.date.nunique() 
    score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month

    # #tick <----
    # score = (df_sup[mask].groupby('time').income_rate.mean()-1).mean()

    #day
    #score = (df_sup[mask].groupby('time').income_rate.mean()-1).reset_index().groupby(pd.Grouper(key='time', freq='D')).income_rate.mean().mean()
    
    #point
    # score = np.mean(D_sample.income_rate[mask]) - 1

    # #point win_rate
    # score = np.mean(D_sample.label[mask])

    score = round(score, 4)

    return 'mean_income_rate', score, True#is_higher_better





params = {
    "boosting_type": "gbdt",
    "objective": "binary",
    
    
    # "num_boost_round" : 30,

    
    "num_leaves": 2,
    #"learning_rate": 0.001,
     "feature_fraction": 0.7,
     "bagging_fraction": 0.7,
     "bagging_freq": 1,
     'lambda_l1' : 1,
     'lambda_l2' : 1,
    #"verbose": 0,

    #'max_bin' : 100000,
    
    
     #"metric": "auc",
     "metric" : 'mean_income_rate',
    "early_stopping" : 10,



    
}


    

model = lgbm.train(params, train_set=D_train, valid_sets=[D_valid], feval=mean_income_rate, )
# Out:
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Info] Number of positive: 478415, number of negative: 523144
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.322166 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 74854
# [LightGBM] [Info] Number of data points in the train set: 1001559, number of used features: 315
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.477670 -> initscore=-0.089378
# [LightGBM] [Info] Start training from score -0.089378
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [36]	valid_0's mean_income_rate: 0.0849

# %%
model.num_trees()
# Out:
# 36

# %%
y_pred_train = model.predict(D_train.data)
y_pred_valid = model.predict(D_valid.data)
y_pred_test = model.predict(D_test.data)
y_pred_test2 = model.predict(D_test2.data)


df["y_pred"] = None
df.loc[mask_train, 'y_pred'] = y_pred_train
df.loc[mask_valid, 'y_pred'] = y_pred_valid
df.loc[mask_test, 'y_pred'] = y_pred_test
df.loc[mask_test2, 'y_pred'] = y_pred_test2


roc_auc_score(D_train.label, y_pred_train), roc_auc_score(D_valid.label, y_pred_valid), roc_auc_score(D_test.label, y_pred_test), roc_auc_score(D_test2.label, y_pred_test2)
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_40449/3355591214.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["y_pred"] = None
# (0.573261012438175, 0.5353346340062124, 0.5496015930443259, 0.5204471011333814)

# %%
#свой threshold

q = 0.99

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest')
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# Valid
# result
# WIN     0.562305
# LOSE    0.425200
# DNF     0.012496
# Name: proportion, dtype: float64
# 1.0005924383613045
#
# Test
# result
# WIN     0.606284
# LOSE    0.380140
# DNF     0.013576
# Name: proportion, dtype: float64
# 1.0042026107194542
#
# Test2
# result
# WIN     0.587927
# LOSE    0.401575
# DNF     0.010499
# Name: proportion, dtype: float64
# 1.0027936870843703

# %%
#общий threshold

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
print(f'threshokd = {threshold}')

mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print("\nTest")
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print('\nTetst2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# threshokd = 0.5720316639356564
#
# Valid
# result
# WIN     0.562305
# LOSE    0.425200
# DNF     0.012496
# Name: proportion, dtype: float64
# 1.0005924383613045
#
# Test
# result
# WIN     0.619370
# LOSE    0.370327
# DNF     0.010303
# Name: proportion, dtype: float64
# 1.0047103020080066
#
# Tetst2
# result
# WIN     0.587927
# LOSE    0.401575
# DNF     0.010499
# Name: proportion, dtype: float64
# 1.0027936870843703

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold

mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_point(D_test, y_pred_test, threshold=threshold), mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0005924383613045148, 0.004710302008006595, 0.002793687084370333)

# %%
df.loc[mask_valid, 'income_rate'].mean(), df.loc[mask_test, 'income_rate'].mean(), df.loc[mask_test2, 'income_rate'].mean()
# Out:
# (0.9990670305249186, 0.9989896531175313, 0.999099835508286)

# %%
mean_income_rate_tick(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_tick(D_test, y_pred_test, threshold=threshold), mean_income_rate_tick(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.001957016624684391, 0.004973339616124952, 0.003632272382613872)

# %%
mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_day(D_test, y_pred_test, threshold=threshold), mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0038572900069094957, 0.005151376643196214, 0.004662187131353151)

# %%
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0848603801520089, 0.1133302861503167, 0.10256811688976933)

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('1 days 07:00:00'),
#  Timedelta('2 days 00:00:00'),
#  Timedelta('2 days 07:00:00'))

# %%
mask_win = df['target'] == 1
df.loc[mask_valid&mask&mask_win, 'delta_time'].median(), df.loc[mask_test&mask&mask_win, 'delta_time'].median(), df.loc[mask_test2&mask&mask_win, 'delta_time'].median()
# Out:
# (Timedelta('1 days 10:00:00'),
#  Timedelta('2 days 02:00:00'),
#  Timedelta('2 days 07:00:00'))

# %%
(mask_valid&mask).sum(), (mask_test&mask).sum(), (mask_test2&mask).sum()
# Out:
# (2881, 3397, 762)

# %%
df.loc[mask_valid&mask, 'time'].dt.date.nunique(), df.loc[mask_test&mask, 'time'].dt.date.nunique(), df.loc[mask_test2&mask, 'time'].dt.date.nunique()
# Out:
# (92, 90, 25)

# %%
df.loc[mask_test2&mask, 'ticker'].unique()
# Out:
# array(['BTC-USDT_OP-USDT', 'BTC-USDT_ARB-USDT', 'SOL-USDT_ARB-USDT',
#        'BTC-USDT_DOT-USDT', 'BTC-USDT_ATOM-USDT'], dtype=object)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_40449/859047173.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#                     count  income_rate
# ticker
# DOT-USDT_ARB-USDT    10.0     1.023083
# LINK-USDT_OP-USDT    47.0     1.009560
# SOL-USDT_ETC-USDT   197.0     0.999708
# SOL-USDT_ARB-USDT   597.0     1.001811
# BTC-USDT_ARB-USDT   613.0     1.005243
# BTC-USDT_DOT-USDT   619.0     1.003862
# BTC-USDT_OP-USDT    629.0     1.009659
# BTC-USDT_ATOM-USDT  685.0     1.003820

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_40449/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#                     count  income_rate
# ticker
# BTC-USDT_DOT-USDT   145.0     0.997717
# BTC-USDT_ATOM-USDT  147.0     1.015511
# BTC-USDT_ARB-USDT   152.0     0.997394
# BTC-USDT_OP-USDT    159.0     0.998391
# SOL-USDT_ARB-USDT   159.0     1.005231

# %%
df.loc[mask_valid|mask_test|mask_test2, ['time', 'y_pred']].groupby(pd.Grouper(key='time', freq='D'))['y_pred'].mean().plot()
# Out:
# <Axes: xlabel='time'>

# %%
df.loc[mask_valid|mask_test|mask_test2, ['time', 'target']].groupby(pd.Grouper(key='time', freq='D'))['target'].mean().plot()
# Out:
# <Axes: xlabel='time'>

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: -x[1])
# Out:
# [('ticker_code', 75.63),
#  ('close_1hour_w200_mean_abs_pct', 10.57),
#  ('close_1hour_w120_mean_abs_pct', 3.94),
#  ('close_1hour_w200_max/close_1hour', 2.63),
#  ('close_1hour_w200_ma_up_3std/close_1hour', 2.62),
#  ('close_1hour_w200_alpha', 2.39),
#  ('close_1hour_w30_mean_abs_pct', 1.23),
#  ('close_1hour_w60_mean_abs_pct', 1.0),
#  ('close_1hour_w1_roc', 0.0),
#  ('close_1hour_w5_norm_std', 0.0),
#  ('close_1hour_w5_mean_abs_pct', 0.0),
#  ('close_1hour_w5_alpha', 0.0),
#  ('close_1hour_w5_rsi', 0.0),
#  ('close_1hour_w5_roc', 0.0),
#  ('close_1hour_w10_norm_std', 0.0),
#  ('close_1hour_w10_mean_abs_pct', 0.0),
#  ('close_1hour_w10_alpha', 0.0),
#  ('close_1hour_w10_rsi', 0.0),
#  ('close_1hour_w10_roc', 0.0),
#  ('close_1hour_w20_norm_std', 0.0),
#  ('close_1hour_w20_mean_abs_pct', 0.0),
#  ('close_1hour_w20_alpha', 0.0),
#  ('close_1hour_w20_rsi', 0.0),
#  ('close_1hour_w20_roc', 0.0),
#  ('close_1hour_w30_norm_std', 0.0),
#  ('close_1hour_w30_alpha', 0.0),
#  ('close_1hour_w30_rsi', 0.0),
#  ('close_1hour_w30_roc', 0.0),
#  ('close_1hour_w30_lvl_1-1.02', 0.0),
#  ('close_1hour_w30_lvl_-0.98-1', 0.0),
#  ('close_1hour_w30_lvl_1.02-1.03', 0.0),
#  ('close_1hour_w30_lvl_-0.97-0.98', 0.0),
#  ('close_1hour_w30_lvl_1.03-1.05', 0.0),
#  ('close_1hour_w30_lvl_-0.95-0.97', 0.0),
#  ('close_1hour_w30_lvl_1.05-1.08', 0.0),
#  ('close_1hour_w30_lvl_-0.92-0.95', 0.0),
#  ('close_1hour_w30_lvl_1.08-1.1', 0.0),
#  ('close_1hour_w30_lvl_-0.9-0.92', 0.0),
#  ('close_1hour_w60_norm_std', 0.0),
#  ('close_1hour_w60_alpha', 0.0),
#  ('close_1hour_w60_rsi', 0.0),
#  ('close_1hour_w60_roc', 0.0),
#  ('close_1hour_w120_norm_std', 0.0),
#  ('close_1hour_w120_alpha', 0.0),
#  ('close_1hour_w120_rsi', 0.0),
#  ('close_1hour_w120_roc', 0.0),
#  ('close_1hour_w120_lvl_1-1.02', 0.0),
#  ('close_1hour_w120_lvl_-0.98-1', 0.0),
#  ('close_1hour_w120_lvl_1.02-1.03', 0.0),
#  ('close_1hour_w120_lvl_-0.97-0.98', 0.0),
#  ('close_1hour_w120_lvl_1.03-1.05', 0.0),
#  ('close_1hour_w120_lvl_-0.95-0.97', 0.0),
#  ('close_1hour_w120_lvl_1.05-1.08', 0.0),
#  ('close_1hour_w120_lvl_-0.92-0.95', 0.0),
#  ('close_1hour_w120_lvl_1.08-1.1', 0.0),
#  ('close_1hour_w120_lvl_-0.9-0.92', 0.0),
#  ('close_1hour_w200_norm_std', 0.0),
#  ('close_1hour_w200_rsi', 0.0),
#  ('close_1hour_w200_roc', 0.0),
#  ('close_1hour_w200_lvl_1-1.02', 0.0),
#  ('close_1hour_w200_lvl_-0.98-1', 0.0),
#  ('close_1hour_w200_lvl_1.02-1.03', 0.0),
#  ('close_1hour_w200_lvl_-0.97-0.98', 0.0),
#  ('close_1hour_w200_lvl_1.03-1.05', 0.0),
#  ('close_1hour_w200_lvl_-0.95-0.97', 0.0),
#  ('close_1hour_w200_lvl_1.05-1.08', 0.0),
#  ('close_1hour_w200_lvl_-0.92-0.95', 0.0),
#  ('close_1hour_w200_lvl_1.08-1.1', 0.0),
#  ('close_1hour_w200_lvl_-0.9-0.92', 0.0),
#  ('hour', 0.0),
#  ('day', 0.0),
#  ('weekday', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w5_alpha', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w10_alpha', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w20_alpha', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w30_alpha', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w60_alpha', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w120_alpha', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w200_alpha', 0.0),
#  ('close_1hour_w5_alpha/close_1hour_w10_alpha', 0.0),
#  ('close_1hour_w5_alpha/close_1hour_w20_alpha', 0.0),
#  ('close_1hour_w5_alpha/close_1hour_w30_alpha', 0.0),
#  ('close_1hour_w5_alpha/close_1hour_w60_alpha', 0.0),
#  ('close_1hour_w5_alpha/close_1hour_w120_alpha', 0.0),
#  ('close_1hour_w5_alpha/close_1hour_w200_alpha', 0.0),
#  ('close_1hour_w10_alpha/close_1hour_w20_alpha', 0.0),
#  ('close_1hour_w10_alpha/close_1hour_w30_alpha', 0.0),
#  ('close_1hour_w10_alpha/close_1hour_w60_alpha', 0.0),
#  ('close_1hour_w10_alpha/close_1hour_w120_alpha', 0.0),
#  ('close_1hour_w10_alpha/close_1hour_w200_alpha', 0.0),
#  ('close_1hour_w20_alpha/close_1hour_w30_alpha', 0.0),
#  ('close_1hour_w20_alpha/close_1hour_w60_alpha', 0.0),
#  ('close_1hour_w20_alpha/close_1hour_w120_alpha', 0.0),
#  ('close_1hour_w20_alpha/close_1hour_w200_alpha', 0.0),
#  ('close_1hour_w30_alpha/close_1hour_w60_alpha', 0.0),
#  ('close_1hour_w30_alpha/close_1hour_w120_alpha', 0.0),
#  ('close_1hour_w30_alpha/close_1hour_w200_alpha', 0.0),
#  ('close_1hour_w60_alpha/close_1hour_w120_alpha', 0.0),
#  ('close_1hour_w60_alpha/close_1hour_w200_alpha', 0.0),
#  ('close_1hour_w120_alpha/close_1hour_w200_alpha', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w5_roc', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w10_roc', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w20_roc', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w30_roc', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w60_roc', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w120_roc', 0.0),
#  ('close_1hour_w1_roc/close_1hour_w200_roc', 0.0),
#  ('close_1hour_w5_roc/close_1hour_w10_roc', 0.0),
#  ('close_1hour_w5_roc/close_1hour_w20_roc', 0.0),
#  ('close_1hour_w5_roc/close_1hour_w30_roc', 0.0),
#  ('close_1hour_w5_roc/close_1hour_w60_roc', 0.0),
#  ('close_1hour_w5_roc/close_1hour_w120_roc', 0.0),
#  ('close_1hour_w5_roc/close_1hour_w200_roc', 0.0),
#  ('close_1hour_w10_roc/close_1hour_w20_roc', 0.0),
#  ('close_1hour_w10_roc/close_1hour_w30_roc', 0.0),
#  ('close_1hour_w10_roc/close_1hour_w60_roc', 0.0),
#  ('close_1hour_w10_roc/close_1hour_w120_roc', 0.0),
#  ('close_1hour_w10_roc/close_1hour_w200_roc', 0.0),
#  ('close_1hour_w20_roc/close_1hour_w30_roc', 0.0),
#  ('close_1hour_w20_roc/close_1hour_w60_roc', 0.0),
#  ('close_1hour_w20_roc/close_1hour_w120_roc', 0.0),
#  ('close_1hour_w20_roc/close_1hour_w200_roc', 0.0),
#  ('close_1hour_w30_roc/close_1hour_w60_roc', 0.0),
#  ('close_1hour_w30_roc/close_1hour_w120_roc', 0.0),
#  ('close_1hour_w30_roc/close_1hour_w200_roc', 0.0),
#  ('close_1hour_w60_roc/close_1hour_w120_roc', 0.0),
#  ('close_1hour_w60_roc/close_1hour_w200_roc', 0.0),
#  ('close_1hour_w120_roc/close_1hour_w200_roc', 0.0),
#  ('close_1hour_w5_mean_abs_pct/close_1hour_w10_mean_abs_pct', 0.0),
#  ('close_1hour_w5_mean_abs_pct/close_1hour_w20_mean_abs_pct', 0.0),
#  ('close_1hour_w5_mean_abs_pct/close_1hour_w30_mean_abs_pct', 0.0),
#  ('close_1hour_w5_mean_abs_pct/close_1hour_w60_mean_abs_pct', 0.0),
#  ('close_1hour_w5_mean_abs_pct/close_1hour_w120_mean_abs_pct', 0.0),
#  ('close_1hour_w5_mean_abs_pct/close_1hour_w200_mean_abs_pct', 0.0),
#  ('close_1hour_w10_mean_abs_pct/close_1hour_w20_mean_abs_pct', 0.0),
#  ('close_1hour_w10_mean_abs_pct/close_1hour_w30_mean_abs_pct', 0.0),
#  ('close_1hour_w10_mean_abs_pct/close_1hour_w60_mean_abs_pct', 0.0),
#  ('close_1hour_w10_mean_abs_pct/close_1hour_w120_mean_abs_pct', 0.0),
#  ('close_1hour_w10_mean_abs_pct/close_1hour_w200_mean_abs_pct', 0.0),
#  ('close_1hour_w20_mean_abs_pct/close_1hour_w30_mean_abs_pct', 0.0),
#  ('close_1hour_w20_mean_abs_pct/close_1hour_w60_mean_abs_pct', 0.0),
#  ('close_1hour_w20_mean_abs_pct/close_1hour_w120_mean_abs_pct', 0.0),
#  ('close_1hour_w20_mean_abs_pct/close_1hour_w200_mean_abs_pct', 0.0),
#  ('close_1hour_w30_mean_abs_pct/close_1hour_w60_mean_abs_pct', 0.0),
#  ('close_1hour_w30_mean_abs_pct/close_1hour_w120_mean_abs_pct', 0.0),
#  ('close_1hour_w30_mean_abs_pct/close_1hour_w200_mean_abs_pct', 0.0),
#  ('close_1hour_w60_mean_abs_pct/close_1hour_w120_mean_abs_pct', 0.0),
#  ('close_1hour_w60_mean_abs_pct/close_1hour_w200_mean_abs_pct', 0.0),
#  ('close_1hour_w120_mean_abs_pct/close_1hour_w200_mean_abs_pct', 0.0),
#  ('close_1hour_w5_std/close_1hour_w10_std', 0.0),
#  ('close_1hour_w5_std/close_1hour_w20_std', 0.0),
#  ('close_1hour_w5_std/close_1hour_w30_std', 0.0),
#  ('close_1hour_w5_std/close_1hour_w60_std', 0.0),
#  ('close_1hour_w5_std/close_1hour_w120_std', 0.0),
#  ('close_1hour_w5_std/close_1hour_w200_std', 0.0),
#  ('close_1hour_w10_std/close_1hour_w20_std', 0.0),
#  ('close_1hour_w10_std/close_1hour_w30_std', 0.0),
#  ('close_1hour_w10_std/close_1hour_w60_std', 0.0),
#  ('close_1hour_w10_std/close_1hour_w120_std', 0.0),
#  ('close_1hour_w10_std/close_1hour_w200_std', 0.0),
#  ('close_1hour_w20_std/close_1hour_w30_std', 0.0),
#  ('close_1hour_w20_std/close_1hour_w60_std', 0.0),
#  ('close_1hour_w20_std/close_1hour_w120_std', 0.0),
#  ('close_1hour_w20_std/close_1hour_w200_std', 0.0),
#  ('close_1hour_w30_std/close_1hour_w60_std', 0.0),
#  ('close_1hour_w30_std/close_1hour_w120_std', 0.0),
#  ('close_1hour_w30_std/close_1hour_w200_std', 0.0),
#  ('close_1hour_w60_std/close_1hour_w120_std', 0.0),
#  ('close_1hour_w60_std/close_1hour_w200_std', 0.0),
#  ('close_1hour_w120_std/close_1hour_w200_std', 0.0),
#  ('close_1hour_w5_norm_std/close_1hour_w10_norm_std', 0.0),
#  ('close_1hour_w5_norm_std/close_1hour_w20_norm_std', 0.0),
#  ('close_1hour_w5_norm_std/close_1hour_w30_norm_std', 0.0),
#  ('close_1hour_w5_norm_std/close_1hour_w60_norm_std', 0.0),
#  ('close_1hour_w5_norm_std/close_1hour_w120_norm_std', 0.0),
#  ('close_1hour_w5_norm_std/close_1hour_w200_norm_std', 0.0),
#  ('close_1hour_w10_norm_std/close_1hour_w20_norm_std', 0.0),
#  ('close_1hour_w10_norm_std/close_1hour_w30_norm_std', 0.0),
#  ('close_1hour_w10_norm_std/close_1hour_w60_norm_std', 0.0),
#  ('close_1hour_w10_norm_std/close_1hour_w120_norm_std', 0.0),
#  ('close_1hour_w10_norm_std/close_1hour_w200_norm_std', 0.0),
#  ('close_1hour_w20_norm_std/close_1hour_w30_norm_std', 0.0),
#  ('close_1hour_w20_norm_std/close_1hour_w60_norm_std', 0.0),
#  ('close_1hour_w20_norm_std/close_1hour_w120_norm_std', 0.0),
#  ('close_1hour_w20_norm_std/close_1hour_w200_norm_std', 0.0),
#  ('close_1hour_w30_norm_std/close_1hour_w60_norm_std', 0.0),
#  ('close_1hour_w30_norm_std/close_1hour_w120_norm_std', 0.0),
#  ('close_1hour_w30_norm_std/close_1hour_w200_norm_std', 0.0),
#  ('close_1hour_w60_norm_std/close_1hour_w120_norm_std', 0.0),
#  ('close_1hour_w60_norm_std/close_1hour_w200_norm_std', 0.0),
#  ('close_1hour_w120_norm_std/close_1hour_w200_norm_std', 0.0),
#  ('close_1hour_w5_rsi/close_1hour_w10_rsi', 0.0),
#  ('close_1hour_w5_rsi/close_1hour_w20_rsi', 0.0),
#  ('close_1hour_w5_rsi/close_1hour_w30_rsi', 0.0),
#  ('close_1hour_w5_rsi/close_1hour_w60_rsi', 0.0),
#  ('close_1hour_w5_rsi/close_1hour_w120_rsi', 0.0),
#  ('close_1hour_w5_rsi/close_1hour_w200_rsi', 0.0),
#  ('close_1hour_w10_rsi/close_1hour_w20_rsi', 0.0),
#  ('close_1hour_w10_rsi/close_1hour_w30_rsi', 0.0),
#  ('close_1hour_w10_rsi/close_1hour_w60_rsi', 0.0),
#  ('close_1hour_w10_rsi/close_1hour_w120_rsi', 0.0),
#  ('close_1hour_w10_rsi/close_1hour_w200_rsi', 0.0),
#  ('close_1hour_w20_rsi/close_1hour_w30_rsi', 0.0),
#  ('close_1hour_w20_rsi/close_1hour_w60_rsi', 0.0),
#  ('close_1hour_w20_rsi/close_1hour_w120_rsi', 0.0),
#  ('close_1hour_w20_rsi/close_1hour_w200_rsi', 0.0),
#  ('close_1hour_w30_rsi/close_1hour_w60_rsi', 0.0),
#  ('close_1hour_w30_rsi/close_1hour_w120_rsi', 0.0),
#  ('close_1hour_w30_rsi/close_1hour_w200_rsi', 0.0),
#  ('close_1hour_w60_rsi/close_1hour_w120_rsi', 0.0),
#  ('close_1hour_w60_rsi/close_1hour_w200_rsi', 0.0),
#  ('close_1hour_w120_rsi/close_1hour_w200_rsi', 0.0),
#  ('close_1hour/close_1hour_w5_ma', 0.0),
#  ('close_1hour/close_1hour_w10_ma', 0.0),
#  ('close_1hour/close_1hour_w20_ma', 0.0),
#  ('close_1hour/close_1hour_w30_ma', 0.0),
#  ('close_1hour/close_1hour_w60_ma', 0.0),
#  ('close_1hour/close_1hour_w120_ma', 0.0),
#  ('close_1hour/close_1hour_w200_ma', 0.0),
#  ('close_1hour_w5_ma/close_1hour_w10_ma', 0.0),
#  ('close_1hour_w5_ma/close_1hour_w20_ma', 0.0),
#  ('close_1hour_w5_ma/close_1hour_w30_ma', 0.0),
#  ('close_1hour_w5_ma/close_1hour_w60_ma', 0.0),
#  ('close_1hour_w5_ma/close_1hour_w120_ma', 0.0),
#  ('close_1hour_w5_ma/close_1hour_w200_ma', 0.0),
#  ('close_1hour_w10_ma/close_1hour_w20_ma', 0.0),
#  ('close_1hour_w10_ma/close_1hour_w30_ma', 0.0),
#  ('close_1hour_w10_ma/close_1hour_w60_ma', 0.0),
#  ('close_1hour_w10_ma/close_1hour_w120_ma', 0.0),
#  ('close_1hour_w10_ma/close_1hour_w200_ma', 0.0),
#  ('close_1hour_w20_ma/close_1hour_w30_ma', 0.0),
#  ('close_1hour_w20_ma/close_1hour_w60_ma', 0.0),
#  ('close_1hour_w20_ma/close_1hour_w120_ma', 0.0),
#  ('close_1hour_w20_ma/close_1hour_w200_ma', 0.0),
#  ('close_1hour_w30_ma/close_1hour_w60_ma', 0.0),
#  ('close_1hour_w30_ma/close_1hour_w120_ma', 0.0),
#  ('close_1hour_w30_ma/close_1hour_w200_ma', 0.0),
#  ('close_1hour_w60_ma/close_1hour_w120_ma', 0.0),
#  ('close_1hour_w60_ma/close_1hour_w200_ma', 0.0),
#  ('close_1hour_w120_ma/close_1hour_w200_ma', 0.0),
#  ('close_1hour/close_1hour_w5_expma', 0.0),
#  ('close_1hour/close_1hour_w10_expma', 0.0),
#  ('close_1hour/close_1hour_w20_expma', 0.0),
#  ('close_1hour/close_1hour_w30_expma', 0.0),
#  ('close_1hour/close_1hour_w60_expma', 0.0),
#  ('close_1hour/close_1hour_w120_expma', 0.0),
#  ('close_1hour/close_1hour_w200_expma', 0.0),
#  ('close_1hour_w5_expma/close_1hour_w10_expma', 0.0),
#  ('close_1hour_w5_expma/close_1hour_w20_expma', 0.0),
#  ('close_1hour_w5_expma/close_1hour_w30_expma', 0.0),
#  ('close_1hour_w5_expma/close_1hour_w60_expma', 0.0),
#  ('close_1hour_w5_expma/close_1hour_w120_expma', 0.0),
#  ('close_1hour_w5_expma/close_1hour_w200_expma', 0.0),
#  ('close_1hour_w10_expma/close_1hour_w20_expma', 0.0),
#  ('close_1hour_w10_expma/close_1hour_w30_expma', 0.0),
#  ('close_1hour_w10_expma/close_1hour_w60_expma', 0.0),
#  ('close_1hour_w10_expma/close_1hour_w120_expma', 0.0),
#  ('close_1hour_w10_expma/close_1hour_w200_expma', 0.0),
#  ('close_1hour_w20_expma/close_1hour_w30_expma', 0.0),
#  ('close_1hour_w20_expma/close_1hour_w60_expma', 0.0),
#  ('close_1hour_w20_expma/close_1hour_w120_expma', 0.0),
#  ('close_1hour_w20_expma/close_1hour_w200_expma', 0.0),
#  ('close_1hour_w30_expma/close_1hour_w60_expma', 0.0),
#  ('close_1hour_w30_expma/close_1hour_w120_expma', 0.0),
#  ('close_1hour_w30_expma/close_1hour_w200_expma', 0.0),
#  ('close_1hour_w60_expma/close_1hour_w120_expma', 0.0),
#  ('close_1hour_w60_expma/close_1hour_w200_expma', 0.0),
#  ('close_1hour_w120_expma/close_1hour_w200_expma', 0.0),
#  ('close_1hour_w5_min/close_1hour', 0.0),
#  ('close_1hour_w10_min/close_1hour', 0.0),
#  ('close_1hour_w20_min/close_1hour', 0.0),
#  ('close_1hour_w30_min/close_1hour', 0.0),
#  ('close_1hour_w60_min/close_1hour', 0.0),
#  ('close_1hour_w120_min/close_1hour', 0.0),
#  ('close_1hour_w200_min/close_1hour', 0.0),
#  ('close_1hour_w5_max/close_1hour', 0.0),
#  ('close_1hour_w10_max/close_1hour', 0.0),
#  ('close_1hour_w20_max/close_1hour', 0.0),
#  ('close_1hour_w30_max/close_1hour', 0.0),
#  ('close_1hour_w60_max/close_1hour', 0.0),
#  ('close_1hour_w120_max/close_1hour', 0.0),
#  ('close_1hour_w5_ma_low_2std/close_1hour', 0.0),
#  ('close_1hour_w5_ma_up_2std/close_1hour', 0.0),
#  ('close_1hour_w5_ma_low_3std/close_1hour', 0.0),
#  ('close_1hour_w5_ma_up_3std/close_1hour', 0.0),
#  ('close_1hour_w10_ma_low_2std/close_1hour', 0.0),
#  ('close_1hour_w10_ma_up_2std/close_1hour', 0.0),
#  ('close_1hour_w10_ma_low_3std/close_1hour', 0.0),
#  ('close_1hour_w10_ma_up_3std/close_1hour', 0.0),
#  ('close_1hour_w20_ma_low_2std/close_1hour', 0.0),
#  ('close_1hour_w20_ma_up_2std/close_1hour', 0.0),
#  ('close_1hour_w20_ma_low_3std/close_1hour', 0.0),
#  ('close_1hour_w20_ma_up_3std/close_1hour', 0.0),
#  ('close_1hour_w30_ma_low_2std/close_1hour', 0.0),
#  ('close_1hour_w30_ma_up_2std/close_1hour', 0.0),
#  ('close_1hour_w30_ma_low_3std/close_1hour', 0.0),
#  ('close_1hour_w30_ma_up_3std/close_1hour', 0.0),
#  ('close_1hour_w60_ma_low_2std/close_1hour', 0.0),
#  ('close_1hour_w60_ma_up_2std/close_1hour', 0.0),
#  ('close_1hour_w60_ma_low_3std/close_1hour', 0.0),
#  ('close_1hour_w60_ma_up_3std/close_1hour', 0.0),
#  ('close_1hour_w120_ma_low_2std/close_1hour', 0.0),
#  ('close_1hour_w120_ma_up_2std/close_1hour', 0.0),
#  ('close_1hour_w120_ma_low_3std/close_1hour', 0.0),
#  ('close_1hour_w120_ma_up_3std/close_1hour', 0.0),
#  ('close_1hour_w200_ma_low_2std/close_1hour', 0.0),
#  ('close_1hour_w200_ma_up_2std/close_1hour', 0.0),
#  ('close_1hour_w200_ma_low_3std/close_1hour', 0.0),
#  ('close_1hour_w5_min/close_1hour_w5_max', 0.0),
#  ('close_1hour_w10_min/close_1hour_w10_max', 0.0),
#  ('close_1hour_w20_min/close_1hour_w20_max', 0.0),
#  ('close_1hour_w30_min/close_1hour_w30_max', 0.0),
#  ('close_1hour_w60_min/close_1hour_w60_max', 0.0),
#  ('close_1hour_w120_min/close_1hour_w120_max', 0.0),
#  ('close_1hour_w200_min/close_1hour_w200_max', 0.0)]

# %%
# ('ticker_code', 75.63),
#  ('close_1hour_w200_mean_abs_pct', 10.57),
#  ('close_1hour_w120_mean_abs_pct', 3.94),
#  ('close_1hour_w200_max/close_1hour', 2.63),
#  ('close_1hour_w200_ma_up_3std/close_1hour', 2.62),
#  ('close_1hour_w200_alpha', 2.39),
#  ('close_1hour_w30_mean_abs_pct', 1.23),
#  ('close_1hour_w60_mean_abs_pct', 1.0),

# %%
y_pred_test3 = model.predict(D_test3.data)
df.loc[mask_test3, 'y_pred'] = y_pred_test3
roc_auc_score(D_test3.label, y_pred_test3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[198], line 1
# ----> 1 y_pred_test3 = model.predict(D_test3.data)
#       2 df.loc[mask_test3, 'y_pred'] = y_pred_test3
#       3 roc_auc_score(D_test3.label, y_pred_test3)
#
# NameError: name 'D_test3' is not defined

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.995)
mask = df['y_pred'] >= threshold

# %%
mean_income_rate_point(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.0019180774688720703

# %%
#0.0022104875426873782

# %%
mean_income_rate_tick(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.0019181581

# %%
#0.0018932624582072178

# %%
mean_income_rate_day(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.006865464

# %%
#0.002840009902855707

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.02797040950368952

# %%
#0.055903352824633386

# %%
(mask&mask_test3).sum()
# Out:
# 51

# %%
df.loc[mask&mask_test3, 'time'].dt.date.nunique(), df.loc[mask_test3, 'time'].dt.date.nunique(),
# Out:
# (10, 54)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_93253/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#         count  income_rate
# ticker
# TATNP     1.0     1.014000
# SNGS      1.0     1.014000
# GMKN      2.0     1.014000
# AQUA      2.0     1.005000
# PLZL      2.0     0.996000
# LENT      2.0     0.999206
# TATN      3.0     1.002000
# PHOR      3.0     1.008000
# ROSN      4.0     1.005000
# UPRO      4.0     1.003262
# SFIN      4.0     1.000500
# HEAD      5.0     1.004703
# RENI      5.0     1.006800
# NVTK      5.0     1.003679
# FESH      5.0     1.006800
# BSPB      5.0     1.003200
# BANEP     5.0     1.009098
# VTBR      5.0     0.999600
# ALRS      6.0     0.996000
# AFLT      6.0     0.999000
# HYDR      6.0     1.003998
# SNGSP     6.0     1.006909
# MGNT      7.0     1.001143
# NLMK      7.0     1.000431
# GAZP      7.0     0.996000
# T         7.0     1.001485
# RUAL      9.0     1.006000
# ENPG      9.0     1.004352
# RTKM      9.0     1.004000
# YDEX      9.0     0.996000
# NMTP     10.0     1.009906
# MAGN     10.0     1.002704
# FLOT     10.0     1.009725
# SPBE     11.0     1.004511
# CHMF     13.0     0.998769
# MOEX     13.0     1.004389
# FEES     13.0     1.000154
# TRNFP    13.0     1.005692
# TRMK     14.0     1.000380
# OGKB     14.0     1.005000
# RTKMP    14.0     1.001143
# BELU     15.0     1.003200
# LSRG     17.0     0.997059
# KMAZ     18.0     1.000320
# MTSS     21.0     1.003911
# AFKS     21.0     1.002269
# VSMO     24.0     1.003729
# APTK     26.0     1.002923
# RASP     28.0     0.999250
# SELG     30.0     1.001160
# MTLR     31.0     1.001577
# WUSH     33.0     0.998182
# CBOM     34.0     1.004121
# RNFT     34.0     0.998647
# VKCO     37.0     1.001351
# MTLRP    39.0     1.001285
# LIFE     42.0     1.003482
# UNAC     42.0     1.001571
# SVAV     43.0     1.001085
# MVID     43.0     1.003726
# ABIO     53.0     0.999606
# POSI     62.0     0.998175
# BANE     65.0     1.000377
# PIKK     69.0     0.998959
# UWGN     72.0     1.002500
# IRKT     76.0     1.000970
# TGKN     98.0     1.001110
# SGZH    104.0     1.000846
# GTRK    105.0     1.001767
# SMLT    106.0     0.998571

# %%
i = 320
df.loc[mask&mask_test3, ['time', 'ticker','close', 'target', 'income_rate', 'delta_time']].iloc[i:i+20]
# Out:
#                        time ticker       close  target income_rate  \
# 2053675 2025-01-17 18:07:00   MVID  106.599998       1       1.014
# 2053782 2025-01-20 12:56:00   MVID  103.300003       0       0.996
# 2053784 2025-01-20 13:06:00   MVID  102.199997       0       0.996
# 2053785 2025-01-20 13:10:00   MVID  101.900002       1       1.014
# 2054160 2025-01-22 20:04:00   MVID  101.699997       0       0.996
# 2054162 2025-01-22 20:07:00   MVID  101.099998       1       1.014
# 2054163 2025-01-22 20:09:00   MVID  101.099998       1       1.014
# 2054164 2025-01-22 20:11:00   MVID  101.099998       1       1.014
# 2054448 2025-01-24 16:52:00   MVID  102.599998       0    1.009721
# 2056497 2025-02-14 12:18:00   MVID  115.099998       0       0.996
# 2056498 2025-02-14 12:19:00   MVID  114.449997       0       0.996
# 2056501 2025-02-14 12:32:00   MVID  114.400002       0       0.996
# 2056508 2025-02-14 13:06:00   MVID  114.650002       0       0.996
# 2056515 2025-02-14 13:35:00   MVID  113.250000       0       0.996
# 2056516 2025-02-14 13:49:00   MVID  110.550003       0       0.996
# 2056517 2025-02-14 13:54:00   MVID  110.800003       0       0.996
# 2056518 2025-02-14 13:56:00   MVID  110.650002       0       0.996
# 2056519 2025-02-14 13:58:00   MVID  109.000000       1       1.014
# 2056545 2025-02-14 16:08:00   MVID  108.650002       1       1.014
# 2056546 2025-02-14 16:10:00   MVID  108.750000       0       0.996
#
#              delta_time
# 2053675 0 days 01:39:00
# 2053782 0 days 00:05:00
# 2053784 0 days 00:05:00
# 2053785 0 days 01:14:00
# 2054160 0 days 00:02:00
# 2054162 0 days 00:52:00
# 2054163 0 days 00:50:00
# 2054164 0 days 00:48:00
# 2054448 0 days 03:00:00
# 2056497 0 days 00:01:00
# 2056498 0 days 00:15:00
# 2056501 0 days 00:02:00
# 2056508 0 days 00:24:00
# 2056515 0 days 00:01:00
# 2056516 0 days 00:08:00
# 2056517 0 days 00:03:00
# 2056518 0 days 00:01:00
# 2056519 0 days 00:13:00
# 2056545 0 days 01:00:00
# 2056546 0 days 00:27:00

# %% [markdown]
# # 3.2 Tuning hyperparams

# %%
top_features = [elem[0] for elem in zip(features, model.feature_importance(importance_type='gain')) if elem[1] > 0]
top_cat_features = [elem for elem in top_features if elem in cat_features]

# %%
len(top_features), len(top_cat_features)
# Out:
# (6, 0)

# %%
top_features
# Out:
# ['close/close_w10_ma',
#  'close/close_w30_ma',
#  'close/close_w10_expma',
#  'close/close_w30_expma',
#  'close_w10_max/close',
#  'close/close_1hour_w10_expma']

# %%
D_train = lgbm.Dataset(df.loc[mask_train, top_features], label=df.loc[mask_train, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, top_features], label=df.loc[mask_valid, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, top_features], label=df.loc[mask_test, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, top_features], label=df.loc[mask_test2, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)

D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
#D_train.data

# %%
D_train.data.shape
# Out:
# (1446127, 6)

# %%
params
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_boost_round': 1000,
#  'num_leaves': 5,
#  'feature_fraction': 0.3,
#  'bagging_fraction': 0.3,
#  'bagging_freq': 1,
#  'lambda_l1': 100,
#  'lambda_l2': 100,
#  'metric': 'mean_income_rate',
#  'early_stopping': 10}

# %%
from IPython.display import clear_output

history = {'params' : [],
           'num_trees' : [],

          
           'auc_train' : [],
           'auc_valid' : [],
           'auc_test' : [],
           'auc_test2' : [],

          
           'mir_point@1_train' : [],
           'mir_point@1_valid' : [],
           'mir_point@1_test' : [],
           'mir_point@1_test2' : [],

           'mir_day@1_train' : [],
           'mir_day@1_valid' : [],
           'mir_day@1_test' : [],
           'mir_day@1_test2' : [],

           'mir_month@1_train' : [],
           'mir_month@1_valid' : [],
           'mir_month@1_test' : [],
           'mir_month@1_test2' : [],
           
           'mir_point@2_train' : [],
           'mir_point@2_valid' : [],
           'mir_point@2_test' : [],
           'mir_point@2_test2' : [],
          
           
           'mir_day@2_train' : [],
           'mir_day@2_valid' : [],
           'mir_day@2_test' : [],
           'mir_day@2_test2' : [],


           'mir_month@2_train' : [],
           'mir_month@2_valid' : [],
           'mir_month@2_test' : [],
           'mir_month@2_test2' : [],
          
          }



pbar = tqdm(total=4*1*3*8*8)
# for lambda_x in [0.001, 0.01, 0.1, 1]:
#     for learning_rate in [0.1, 0.01, 0.001]:
#         for num_leaves in [2, 4, 8, 16, 32]:
#             for feature_fraction in np.arange(1, 0, -0.1):
#                 for bagging_fraction in np.arange(1, 0, -0.1):
for lambda_x in [1, 10, 100, 1000]:
    for learning_rate in [0.1]:
        for num_leaves in [2, 5, 8]:
            for feature_fraction in np.arange(0.3, 1.1, 0.1)[::-1]:
                for bagging_fraction in np.arange(0.3, 1.1, 0.1)[::-1]:
                    feature_fraction = min(feature_fraction, 1)
                    bagging_fraction = min(bagging_fraction, 1)

                    
                    params = {
                                "boosting_type": "gbdt",
                                "objective": "binary",
                            
                                
                                 "num_leaves": num_leaves,
                                 "learning_rate": learning_rate,
                                 "feature_fraction": feature_fraction,
                                 "bagging_fraction": bagging_fraction,
                                 "bagging_freq": 1,
                                 'lambda_l1' : lambda_x,
                                 'lambda_l2' : lambda_x,
                                
                                "verbose": -1,
                                    
                                "metric": 'mean_income_rate',
                                "early_stopping" : 10,
                            }
                    model = lgbm.train(params, num_boost_round=1_000, train_set=D_train, valid_sets=[D_valid], feval=mean_income_rate)
                    
                    y_pred_train = model.predict(D_train.data)
                    y_pred_valid = model.predict(D_valid.data)
                    y_pred_test = model.predict(D_test.data)
                    y_pred_test2 = model.predict(D_test2.data)
                    
                    #history
                    history['params'] += [params.copy()]
                    history['num_trees'] += [model.num_trees()]
        
                    history['auc_train'] += [roc_auc_score(D_train.label, y_pred_train)]
                    history['auc_valid'] += [roc_auc_score(D_valid.label, y_pred_valid)]
                    history['auc_test'] += [roc_auc_score(D_test.label, y_pred_test)]
                    history['auc_test2'] += [roc_auc_score(D_test2.label, y_pred_test2)]


                    threshold1 = np.quantile(y_pred_valid, q=0.99)
                    threshold2 = np.quantile(y_pred_valid, q=0.95)
                    
                    history['mir_point@1_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold1)]
                    history['mir_point@1_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold1)]
                    history['mir_point@1_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold1)]
                    history['mir_point@1_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold1)]

                    history['mir_day@1_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold1)]
                    history['mir_day@1_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold1)]
                    history['mir_day@1_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold1)]
                    history['mir_day@1_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold1)]
                    
                    history['mir_month@1_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold1)]
                    history['mir_month@1_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold1)]
                    history['mir_month@1_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold1)]
                    history['mir_month@1_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold1)]


                    

                    history['mir_point@2_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold2)]
                    history['mir_point@2_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold2)]
                    history['mir_point@2_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold2)]
                    history['mir_point@2_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold2)]

                    history['mir_day@2_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold2)]
                    history['mir_day@2_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold2)]
                    history['mir_day@2_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold2)]
                    history['mir_day@2_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold2)]
                   
                    history['mir_month@2_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold2)]
                    history['mir_month@2_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold2)]
                    history['mir_month@2_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold2)]
                    history['mir_month@2_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold2)]


                    
                    clear_output()
                    pbar.update(1)
                    
pbar.close()
                    

history_cp = history.copy()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 768/768 [24:24<00:00,  1.91s/it]

# %%
dump_pkl(history, './hst_-0.5_+1.5_4hour.pkl')

# %%
history = load_pkl('./hst_-0.5_+1.5_4hour.pkl')

# %%
pd.set_option('display.max_columns', 100)
order_cols = ['params', 'num_trees', 'auc_train', 'auc_valid', 'auc_test', 'auc_test2', 'mir_point@1_train', 'mir_point@1_valid', 'mir_point@1_test', 'mir_point@1_test2', 'mir_day@1_train', 'mir_day@1_valid', 'mir_day@1_test', 'mir_day@1_test2', 'mir_month@1_train', 'mir_month@1_valid', 'mir_month@1_test', 'mir_month@1_test2', 'mir_point@2_train', 'mir_point@2_valid', 'mir_point@2_test', 'mir_point@2_test2', 'mir_day@2_train', 'mir_day@2_valid', 'mir_day@2_test', 'mir_day@2_test2', 'mir_month@2_train', 'mir_month@2_valid', 'mir_month@2_test', 'mir_month@2_test2']
df_hst = pd.DataFrame(history)[order_cols]
df_hst
# Out:
#                                                 params  num_trees  auc_train  \
# 0    {'boosting_type': 'gbdt', 'objective': 'binary...         32   0.642828
# 1    {'boosting_type': 'gbdt', 'objective': 'binary...         12   0.624520
# 2    {'boosting_type': 'gbdt', 'objective': 'binary...         14   0.626674
# 3    {'boosting_type': 'gbdt', 'objective': 'binary...         32   0.642618
# 4    {'boosting_type': 'gbdt', 'objective': 'binary...         10   0.617723
# ..                                                 ...        ...        ...
# 763  {'boosting_type': 'gbdt', 'objective': 'binary...         38   0.650277
# 764  {'boosting_type': 'gbdt', 'objective': 'binary...         44   0.650052
# 765  {'boosting_type': 'gbdt', 'objective': 'binary...         40   0.649431
# 766  {'boosting_type': 'gbdt', 'objective': 'binary...         21   0.646752
# 767  {'boosting_type': 'gbdt', 'objective': 'binary...         19   0.645776
#
#      auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 0     0.601831  0.604062   0.573098           0.001818           0.000462
# 1     0.594835  0.593708   0.566168           0.001578          -0.000001
# 2     0.595243  0.594842   0.567469           0.001568           0.000011
# 3     0.602215  0.604165   0.573116           0.001816           0.000462
# 4     0.591128  0.589091   0.565039           0.001502          -0.000055
# ..         ...       ...        ...                ...                ...
# 763   0.609061  0.604311   0.571548           0.002125           0.000098
# 764   0.608623  0.604188   0.571333           0.002126           0.000098
# 765   0.608804  0.603635   0.570874           0.002059           0.000033
# 766   0.605981  0.599423   0.567547           0.001376          -0.000296
# 767   0.604977  0.598369   0.566505           0.001142          -0.000468
#
#      mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 0            0.001205           0.001078         0.002228         0.002875
# 1            0.000883           0.000358         0.002120         0.002219
# 2            0.000855           0.000352         0.002111         0.002228
# 3            0.001205           0.001078         0.002225         0.002875
# 4            0.000962           0.000699         0.002023         0.001818
# ..                ...                ...              ...              ...
# 763          0.001321           0.000950         0.003508         0.002798
# 764          0.001321           0.000950         0.003510         0.002798
# 765          0.001234           0.000853         0.003516         0.002778
# 766          0.000865           0.000257         0.002461         0.001897
# 767          0.000744           0.000080         0.002314         0.001610
#
#      mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 0          0.001664         0.002351           0.044984           0.061846
# 1          0.001986         0.001947           0.044832           0.048824
# 2          0.001943         0.002014           0.044649           0.049007
# 3          0.001664         0.002351           0.044917           0.061846
# 4          0.001698         0.002219           0.042888           0.039997
# ..              ...              ...                ...                ...
# 763        0.002544         0.003683           0.068550           0.061556
# 764        0.002544         0.003683           0.068583           0.061556
# 765        0.002727         0.003524           0.071165           0.061117
# 766        0.002538         0.002551           0.051788           0.041732
# 767        0.002587         0.002188           0.049285           0.035426
#
#      mir_month@1_test  mir_month@1_test2  mir_point@2_train  \
# 0            0.035775           0.048117           0.001045
# 1            0.043693           0.041837           0.001107
# 2            0.042757           0.043287           0.001086
# 3            0.035775           0.048117           0.001112
# 4            0.037346           0.047687           0.001042
# ..                ...                ...                ...
# 763          0.053415           0.077247           0.001283
# 764          0.053415           0.077247           0.001260
# 765          0.058629           0.073929           0.001275
# 766          0.055830           0.054815           0.001235
# 767          0.056903           0.048139           0.001142
#
#      mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@2_train  \
# 0            -0.000154          0.000716           0.000442         0.001309
# 1            -0.000167          0.000726           0.000363         0.001488
# 2            -0.000149          0.000659           0.000397         0.001341
# 3            -0.000048          0.000661           0.000482         0.001318
# 4            -0.000244          0.000668           0.000324         0.001368
# ..                 ...               ...                ...              ...
# 763          -0.000278          0.000774           0.000358         0.001904
# 764          -0.000284          0.000732           0.000358         0.001782
# 765          -0.000337          0.000775           0.000346         0.001907
# 766          -0.000389          0.000775           0.000211         0.002470
# 767          -0.000468          0.000744           0.000080         0.002314
#
#      mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@2_train  \
# 0           0.001190        0.001221         0.001036           0.028273
# 1           0.001371        0.001372         0.001344           0.032136
# 2           0.001297        0.001263         0.001173           0.028894
# 3           0.001354        0.001199         0.001266           0.028341
# 4           0.001185        0.001246         0.001124           0.029548
# ..               ...             ...              ...                ...
# 763         0.001339        0.001942         0.001856           0.041122
# 764         0.001320        0.001809         0.001645           0.038478
# 765         0.001209        0.001973         0.001705           0.041279
# 766         0.001610        0.002609         0.002466           0.052599
# 767         0.001610        0.002587         0.002188           0.049285
#
#      mir_month@2_valid  mir_month@2_test  mir_month@2_test2
# 0             0.026170          0.026858           0.022253
# 1             0.030159          0.030182           0.028872
# 2             0.028533          0.027776           0.025214
# 3             0.029791          0.026379           0.027208
# 4             0.026070          0.027405           0.024147
# ..                 ...               ...                ...
# 763           0.029459          0.042714           0.040831
# 764           0.029041          0.039788           0.035356
# 765           0.026590          0.043408           0.036640
# 766           0.035425          0.057401           0.052998
# 767           0.035426          0.056903           0.048139
#
# [768 rows x 30 columns]

# %% [markdown]
# ### threshold delta AUC

# %%
threshold = 0.03
mask_model_valid = (df_hst['auc_train'] - df_hst['auc_valid']) < threshold
mask_model_test = (df_hst['auc_train'] - df_hst['auc_test']) < threshold
mask_model_test2 = (df_hst['auc_train'] - df_hst['auc_test2']) < threshold
mask_model_valid.sum(), mask_model_test.sum(), mask_model_test2.sum()
# Out:
# (115, 15, 0)

# %%
(mask_model_valid&mask_model_test).sum(), (mask_model_valid&mask_model_test&mask_model_test2).sum()
# Out:
# (14, 0)

# %%
mask_auc = mask_model_valid&mask_model_test#&mask_model_test2
df_hst.loc[mask_auc].sort_values(by='auc_valid', ascending=False).iloc[:5]
#df_hst.loc[mask_model_valid&mask_model_test].sort_values(by='income_rate@1_valid', ascending=False).iloc[:5]
# Out:
#                                                 params  num_trees  auc_train  \
# 4    {'boosting_type': 'gbdt', 'objective': 'binary...         10   0.617723
# 397  {'boosting_type': 'gbdt', 'objective': 'binary...          9   0.614175
# 405  {'boosting_type': 'gbdt', 'objective': 'binary...          9   0.614175
# 438  {'boosting_type': 'gbdt', 'objective': 'binary...          7   0.605522
# 446  {'boosting_type': 'gbdt', 'objective': 'binary...          7   0.605522
#
#      auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 4     0.591128  0.589091   0.565039           0.001502          -0.000055
# 397   0.587564  0.585836   0.563168           0.001278          -0.000181
# 405   0.587564  0.585836   0.563168           0.001278          -0.000181
# 438   0.581058  0.576780   0.559037           0.001577          -0.000232
# 446   0.581058  0.576780   0.559037           0.001577          -0.000232
#
#      mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 4            0.000962           0.000699         0.002023         0.001818
# 397          0.000702           0.000324         0.001749         0.001526
# 405          0.000702           0.000324         0.001749         0.001526
# 438          0.001056           0.000449         0.002718         0.001906
# 446          0.001056           0.000449         0.002718         0.001906
#
#      mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 4          0.001698         0.002219           0.042888           0.039997
# 397        0.001452         0.001659           0.037608           0.033570
# 405        0.001452         0.001659           0.037608           0.033570
# 438        0.002462         0.002499           0.057609           0.041942
# 446        0.002462         0.002499           0.057609           0.041942
#
#      mir_month@1_test  mir_month@1_test2  mir_point@2_train  \
# 4            0.037346           0.047687           0.001042
# 397          0.031938           0.035656           0.001076
# 405          0.031938           0.035656           0.001076
# 438          0.054162           0.053689           0.001260
# 446          0.054162           0.053689           0.001260
#
#      mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@2_train  \
# 4            -0.000244          0.000668           0.000324         0.001368
# 397          -0.000260          0.000797           0.000329         0.001434
# 405          -0.000260          0.000797           0.000329         0.001434
# 438          -0.000342          0.000763           0.000244         0.001968
# 446          -0.000342          0.000763           0.000244         0.001968
#
#      mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@2_train  \
# 4           0.001185        0.001246         0.001124           0.029548
# 397         0.001156        0.001319         0.001193           0.031036
# 405         0.001156        0.001319         0.001193           0.031036
# 438         0.001341        0.002034         0.001641           0.042499
# 446         0.001341        0.002034         0.001641           0.042499
#
#      mir_month@2_valid  mir_month@2_test  mir_month@2_test2
# 4             0.026070          0.027405           0.024147
# 397           0.025436          0.029018           0.025635
# 405           0.025436          0.029018           0.025635
# 438           0.029511          0.044758           0.035265
# 446           0.029511          0.044758           0.035265

# %%
#df_hst['params'].iloc[1033]

# %% [markdown]
# ### threshold income_rate

# %%
col = 'mir_month@1'
threshold = 0.06
# mask_ir_valid = (df_hst[f'{col}_train'] - df_hst[f'{col}_valid']).abs() < threshold
# mask_ir_test = (df_hst[f'{col}_train'] - df_hst[f'{col}_test']).abs() < threshold
# mask_ir_test2 = (df_hst[f'{col}_train'] - df_hst[f'{col}_test2']).abs() < threshold

mask_ir_valid = df_hst[f'{col}_valid'] >=  threshold
mask_ir_test = df_hst[f'{col}_test'] >= threshold
mask_ir_test2 = df_hst[f'{col}_test2'] >=  threshold


mask_ir_valid.sum(), mask_ir_test.sum(), mask_ir_test2.sum()
# Out:
# (495, 251, 480)

# %%
(mask_ir_valid&mask_ir_test).sum(), (mask_ir_valid&mask_ir_test&mask_ir_test2).sum()
# Out:
# (240, 197)

# %%
mask_ir= mask_ir_valid&mask_ir_test&mask_ir_test2
mask_ir.sum()
# Out:
# 197

# %%
#(mask_ir&mask_auc).sum()

# %%
col = 'mir_day@1'
threshold = 0.003

# mask2_ir_valid = (df_hst[f'{col}_train'] - df_hst[f'{col}_valid']).abs() < threshold
# mask2_ir_test = (df_hst[f'{col}_train'] - df_hst[f'{col}_test']).abs() < threshold
# mask2_ir_test2 = (df_hst[f'{col}_train'] - df_hst[f'{col}_test2']).abs() < threshold

mask2_ir_valid = df_hst[f'{col}_valid'] >=  threshold
mask2_ir_test = df_hst[f'{col}_test'] >= threshold
mask2_ir_test2 = df_hst[f'{col}_test2'] >=  threshold


mask2_ir_valid.sum(), mask2_ir_test.sum(), mask2_ir_test2.sum()
# Out:
# (378, 237, 524)

# %%
(mask2_ir_valid&mask2_ir_test).sum(), (mask2_ir_valid&mask2_ir_test&mask2_ir_test2).sum()
# Out:
# (231, 231)

# %%
mask2_ir = mask2_ir_valid&mask2_ir_test&mask2_ir_test2
mask2_ir.sum()
# Out:
# 231

# %%
(mask_ir&mask2_ir).sum()
# Out:
# 173

# %%
# col = 'mir_point@1'
# threshold = 0.003

# # mask2_ir_valid = (df_hst[f'{col}_train'] - df_hst[f'{col}_valid']).abs() < threshold
# # mask2_ir_test = (df_hst[f'{col}_train'] - df_hst[f'{col}_test']).abs() < threshold
# # mask2_ir_test2 = (df_hst[f'{col}_train'] - df_hst[f'{col}_test2']).abs() < threshold

# mask3_ir_valid = df_hst[f'{col}_valid'] >=  threshold
# mask3_ir_test = df_hst[f'{col}_test'] >= threshold
# mask3_ir_test2 = df_hst[f'{col}_test2'] >=  threshold


# mask3_ir_valid.sum(), mask3_ir_test.sum(), mask3_ir_test2.sum()

# %%
# (mask3_ir_valid&mask3_ir_test).sum(), (mask3_ir_valid&mask3_ir_test&mask3_ir_test2).sum()

# %%
# mask3_ir = mask3_ir_valid&mask3_ir_test&mask3_ir_test2
# mask3_ir.sum()

# %%
# (mask_ir&mask2_ir&mask3_ir).sum()

# %%
mask = mask_ir&mask2_ir#&mask3_ir
df_hst.loc[mask].sort_values(by=f'mir_day@1_valid', ascending=False).iloc[:10]
# Out:
#                                                 params  num_trees  auc_train  \
# 149  {'boosting_type': 'gbdt', 'objective': 'binary...         27   0.662656
# 141  {'boosting_type': 'gbdt', 'objective': 'binary...         27   0.662656
# 133  {'boosting_type': 'gbdt', 'objective': 'binary...         19   0.660552
# 132  {'boosting_type': 'gbdt', 'objective': 'binary...         13   0.657334
# 323  {'boosting_type': 'gbdt', 'objective': 'binary...         14   0.658119
# 350  {'boosting_type': 'gbdt', 'objective': 'binary...         14   0.656749
# 358  {'boosting_type': 'gbdt', 'objective': 'binary...         14   0.656749
# 115  {'boosting_type': 'gbdt', 'objective': 'binary...         23   0.650355
# 123  {'boosting_type': 'gbdt', 'objective': 'binary...         23   0.650355
# 317  {'boosting_type': 'gbdt', 'objective': 'binary...         21   0.649381
#
#      auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 149   0.620916  0.618368   0.580464           0.002764           0.000832
# 141   0.620916  0.618368   0.580464           0.002764           0.000832
# 133   0.619019  0.616073   0.578822           0.002484           0.000758
# 132   0.615430  0.614047   0.578545           0.002492           0.000723
# 323   0.615756  0.613767   0.578116           0.002305           0.000698
# 350   0.614607  0.610878   0.576726           0.002317           0.000736
# 358   0.614607  0.610878   0.576726           0.002317           0.000736
# 115   0.610127  0.604407   0.573714           0.002512           0.000719
# 123   0.610127  0.604407   0.573714           0.002512           0.000719
# 317   0.608174  0.603421   0.572557           0.002337           0.000733
#
#      mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 149          0.002166           0.001638         0.004270         0.004005
# 141          0.002166           0.001638         0.004270         0.004005
# 133          0.001836           0.001296         0.004033         0.003848
# 132          0.001822           0.001298         0.004081         0.003830
# 323          0.001816           0.001323         0.003856         0.003826
# 350          0.001861           0.001322         0.003801         0.003800
# 358          0.001861           0.001322         0.003801         0.003800
# 115          0.002395           0.001489         0.004042         0.003798
# 123          0.002395           0.001489         0.004042         0.003798
# 317          0.002015           0.001329         0.003703         0.003793
#
#      mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 149        0.003285         0.003697           0.075058           0.078319
# 141        0.003285         0.003697           0.075058           0.078319
# 133        0.003362         0.003461           0.069286           0.073378
# 132        0.003400         0.003451           0.067848           0.073021
# 323        0.003341         0.003497           0.066235           0.072947
# 350        0.003095         0.003476           0.066637           0.072459
# 358        0.003095         0.003476           0.066637           0.072459
# 115        0.003668         0.003387           0.071464           0.074269
# 123        0.003668         0.003387           0.071464           0.074269
# 317        0.003041         0.003508           0.065663           0.072323
#
#      mir_month@1_test  mir_month@1_test2  mir_point@2_train  \
# 149          0.064053           0.068101           0.000965
# 141          0.064053           0.068101           0.000965
# 133          0.063875           0.063739           0.000957
# 132          0.064603           0.061791           0.000953
# 323          0.063472           0.062622           0.000924
# 350          0.061893           0.064015           0.001042
# 358          0.061893           0.064015           0.001042
# 115          0.075190           0.064125           0.000980
# 123          0.075190           0.064125           0.000980
# 317          0.060829           0.064621           0.001178
#
#      mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@2_train  \
# 149          -0.000080          0.000294           0.001144         0.000768
# 141          -0.000080          0.000294           0.001144         0.000768
# 133          -0.000045          0.000408           0.001078         0.000726
# 132          -0.000063          0.000454           0.000925         0.000759
# 323          -0.000072          0.000363           0.000958         0.000699
# 350          -0.000034          0.000460           0.000640         0.000973
# 358          -0.000034          0.000460           0.000640         0.000973
# 115          -0.000166          0.000454           0.000533         0.000939
# 123          -0.000166          0.000454           0.000533         0.000939
# 317          -0.000119          0.000655           0.000379         0.001424
#
#      mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@2_train  \
# 149         0.000749        0.000319         0.000508           0.016664
# 141         0.000749        0.000319         0.000508           0.016664
# 133         0.000841        0.000432         0.000549           0.015754
# 132         0.000765        0.000467         0.000626           0.016514
# 323         0.000743        0.000403         0.000465           0.015164
# 350         0.000975        0.000752         0.000678           0.020968
# 358         0.000975        0.000752         0.000678           0.020968
# 115         0.000735        0.000927         0.000615           0.020278
# 123         0.000735        0.000927         0.000615           0.020278
# 317         0.001118        0.001489         0.000903           0.030691
#
#      mir_month@2_valid  mir_month@2_test  mir_month@2_test2
# 149           0.016485          0.007026           0.011167
# 141           0.016485          0.007026           0.011167
# 133           0.018499          0.009496           0.012070
# 132           0.016826          0.010268           0.013777
# 323           0.016346          0.008875           0.010224
# 350           0.021449          0.016542           0.014906
# 358           0.021449          0.016542           0.014906
# 115           0.016178          0.020397           0.013528
# 123           0.016178          0.020397           0.013528
# 317           0.024589          0.032765           0.019869

# %%
df_hst.iloc[[111, 149]]
# Out:
#                                                 params  num_trees  auc_train  \
# 111  {'boosting_type': 'gbdt', 'objective': 'binary...         17   0.652944
# 149  {'boosting_type': 'gbdt', 'objective': 'binary...         27   0.662656
#
#      auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 111   0.610673  0.608529   0.576003           0.002316           0.000534
# 149   0.620916  0.618368   0.580464           0.002764           0.000832
#
#      mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 111          0.001741           0.001280         0.003945         0.003393
# 149          0.002166           0.001638         0.004270         0.004005
#
#      mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 111        0.003930         0.003674           0.069954           0.069660
# 149        0.003285         0.003697           0.075058           0.078319
#
#      mir_month@1_test  mir_month@1_test2  mir_point@2_train  \
# 111          0.082540           0.073317           0.001126
# 149          0.064053           0.068101           0.000965
#
#      mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@2_train  \
# 111          -0.000135          0.000515           0.000352         0.001299
# 149          -0.000080          0.000294           0.001144         0.000768
#
#      mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@2_train  \
# 111         0.001204        0.001439         0.000930           0.027986
# 149         0.000749        0.000319         0.000508           0.016664
#
#      mir_month@2_valid  mir_month@2_test  mir_month@2_test2
# 111           0.026483          0.031652           0.020449
# 149           0.016485          0.007026           0.011167

# %%
df_hst['params'].iloc[149]
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 8,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.8000000000000002,
#  'bagging_fraction': 0.5,
#  'bagging_freq': 1,
#  'lambda_l1': 1,
#  'lambda_l2': 1,
#  'verbose': -1,
#  'metric': 'mean_income_rate',
#  'early_stopping': 10}

# %% [markdown]
# # Feature selection

# %%
len(top_features), top_features
# Out:
# (6,
#  ['close/close_w10_ma',
#   'close/close_w30_ma',
#   'close/close_w10_expma',
#   'close/close_w30_expma',
#   'close_w10_max/close',
#   'close/close_1hour_w10_expma'])

# %%
top_features = ['close/close_w10_ma',
  'close/close_w30_ma',
  'close/close_w10_expma',
  'close/close_w30_expma',
  'close_w10_max/close',
  'close/close_1hour_w10_expma']

# %%
#features = features_criteria2.tolist()
features = top_features


cat_features = [elem for elem in features if elem in cat_features_all]

# %%
len(features), len(cat_features)
# Out:
# (6, 0)

# %%
'ticker_code' in features
# Out:
# False

# %%
target = 'target'

# %%
D_train = lgbm.Dataset(df.loc[mask_train, features], label=df.loc[mask_train, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, features], label=df.loc[mask_valid, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, features], label=df.loc[mask_test, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, features], label=df.loc[mask_test2, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)


D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
D_test2.data
# Out:
#          close/close_w10_ma  close/close_w30_ma  close/close_w10_expma  \
# 34250              1.004638            1.011641               1.005106
# 34251              1.002253            1.009579               1.002815
# 34252              1.004541            1.011769               1.004415
# 34253              0.997600            1.004561               0.997873
# 34254              0.995200            1.001970               0.996293
# ...                     ...                 ...                    ...
# 2338926            1.001332            1.001260               1.000852
# 2338927            1.001014            1.001202               1.000697
# 2338928            0.998173            0.998298               0.998102
# 2338929            1.000872            1.001328               1.000916
# 2338930            0.996564            0.996845               0.996945
#
#          close/close_w30_expma  close_w10_max/close  \
# 34250                 1.008195             1.000000
# 34251                 1.006102             1.001658
# 34252                 1.008132             1.000000
# 34253                 1.001022             1.007032
# 34254                 0.998703             1.009460
# ...                        ...                  ...
# 2338926               1.001409             1.000190
# 2338927               1.001318             1.000190
# 2338928               0.998409             1.003214
# 2338929               1.001335             1.000190
# 2338930               0.996899             1.004856
#
#          close/close_1hour_w10_expma
# 34250                       1.007999
# 34251                       1.006331
# 34252                       1.008926
# 34253                       1.001539
# 34254                       0.999129
# ...                              ...
# 2338926                     1.002039
# 2338927                     1.002039
# 2338928                     0.998649
# 2338929                     1.001668
# 2338930                     0.997558
#
# [157454 rows x 6 columns]

# %%
params = { 'boosting_type': 'gbdt',
 'objective': 'binary',
 'num_leaves': 5,
 'learning_rate': 0.1,
 'feature_fraction': 0.5,
 'bagging_fraction': 0.3,
 'bagging_freq': 1,
 'lambda_l1': 1,
 'lambda_l2': 1,
 'verbose': -1,
 'metric': 'mean_income_rate',
 'early_stopping': 10}

# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 8,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.8,
#  'bagging_fraction': 0.5,
#  'bagging_freq': 1,
#  'lambda_l1': 1,
#  'lambda_l2': 1,
#  'verbose': -1,
#  'metric': 'mean_income_rate',
#  'early_stopping': 10}

# #111 - num_trees=17
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 5,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.5,
#  'bagging_fraction': 0.3,
#  'bagging_freq': 1,
#  'lambda_l1': 1,
#  'lambda_l2': 1,
#  'verbose': -1,
#  'metric': 'mean_income_rate',
#  'early_stopping': 10}

model = lgbm.train(params,  num_boost_round=2_000, train_set=D_train, valid_sets=[D_valid], feval=mean_income_rate)

# %%
model.num_trees()
# Out:
# 17

# %%
y_pred_train = model.predict(D_train.data)
y_pred_valid = model.predict(D_valid.data)
y_pred_test = model.predict(D_test.data)
y_pred_test2 = model.predict(D_test2.data)


df["y_pred"] = None
df.loc[mask_train, 'y_pred'] = y_pred_train
df.loc[mask_valid, 'y_pred'] = y_pred_valid
df.loc[mask_test, 'y_pred'] = y_pred_test
df.loc[mask_test2, 'y_pred'] = y_pred_test2

roc_auc_score(D_train.label, y_pred_train), roc_auc_score(D_valid.label, y_pred_valid), roc_auc_score(D_test.label, y_pred_test), roc_auc_score(D_test2.label, y_pred_test2)
# Out:
# (0.652944363854863, 0.6106727017819044, 0.6085286847042677, 0.5760034988223279)

# %%
#свой threshold

q = 0.99

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest')
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# Valid
# result
# LOSE    0.602980
# WIN     0.266631
# DNF     0.130389
# Name: proportion, dtype: float64
# 1.0005339
#
# Test
# result
# LOSE    0.534453
# WIN     0.280834
# DNF     0.184713
# Name: proportion, dtype: float64
# 1.0013725
#
# Test2
# result
# LOSE    0.532609
# WIN     0.292271
# DNF     0.175121
# Name: proportion, dtype: float64
# 1.0013669

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 01:00:00'),
#  Timedelta('0 days 01:15:00'),
#  Timedelta('0 days 01:00:00'))

# %%
#общий threshold

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
print(f'threshokd = {threshold}')

mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print("\nTest")
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print('\nTetst2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# threshokd = 0.2591240486482249
#
# Valid
# result
# LOSE    0.602980
# WIN     0.266631
# DNF     0.130389
# Name: proportion, dtype: float64
# 1.0005339
#
# Test
# result
# LOSE    0.530280
# WIN     0.310559
# DNF     0.159161
# Name: proportion, dtype: float64
# 1.0017412
#
# Tetst2
# result
# LOSE    0.543643
# WIN     0.296907
# DNF     0.159450
# Name: proportion, dtype: float64
# 1.0012803

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 01:00:00'),
#  Timedelta('0 days 01:00:00'),
#  Timedelta('0 days 01:00:00'))

# %%
(mask_valid&mask).sum(), (mask_test&mask).sum(), (mask_test2&mask).sum()
# Out:
# (1879, 1288, 1455)

# %%
df.loc[mask_valid&mask, 'time'].dt.date.nunique(), df.loc[mask_test&mask, 'time'].dt.date.nunique(), df.loc[mask_test2&mask, 'time'].dt.date.nunique()
# Out:
# (42, 42, 39)

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.99)

# %%
mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_point(D_test, y_pred_test, threshold=threshold), mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0005339384078979492, 0.001741170883178711, 0.0012803077697753906)

# %%
mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_day(D_test, y_pred_test, threshold=threshold), mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0033925232, 0.0039304667, 0.0036743742)

# %%
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.06965980877478917, 0.08253980102017522, 0.07331658277097483)

# %%
df.loc[mask_test2&mask, 'ticker'].unique()
# Out:
# array(['AFLT', 'IRAO', 'MVID', 'SPBE', 'MTLRP', 'SFIN', 'FEES', 'LKOH',
#        'FESH', 'MDMG', 'VKCO', 'SELG', 'SGZH', 'ENPG', 'LSRG', 'NMTP',
#        'PLZL', 'TATN', 'AFKS', 'GMKN', 'RNFT', 'YDEX', 'UWGN', 'TGKN',
#        'HYDR', 'ABIO', 'WUSH', 'GTRK', 'NLMK', 'TATNP', 'ALRS', 'VSMO',
#        'TRNFP', 'MGNT', 'IRKT', 'MTLR', 'HEAD', 'RUAL', 'SNGS', 'NVTK',
#        'RASP', 'VTBR', 'PHOR', 'T', 'TRMK', 'MOEX', 'CHMF', 'RTKM',
#        'SMLT', 'UNAC', 'GAZP', 'ROSN', 'BELU', 'FLOT', 'PIKK', 'SVAV',
#        'POSI', 'SNGSP', 'MTSS', 'MAGN', 'BANEP', 'BSPB'], dtype=object)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#         count  income_rate
# ticker
# PHOR      1.0     1.009423
# ROSN      2.0     0.997834
# NLMK      2.0     1.014000
# MDMG      2.0     1.008354
# GMKN      2.0     0.998990
# SNGSP     3.0     1.007333
# SNGS      3.0     0.996834
# NVTK      3.0     1.003587
# IRAO      3.0     1.014000
# YDEX      4.0     1.004000
# ALRS      5.0     0.996159
# ENPG      5.0     0.998000
# MOEX      5.0     1.012264
# HYDR      5.0     1.008806
# TATNP     6.0     1.008331
# TATN      6.0     1.008229
# NMTP      6.0     1.007333
# BANEP     8.0     0.998949
# VTBR      9.0     0.996350
# LKOH      9.0     0.998244
# AFLT     10.0     0.997125
# GAZP     10.0     0.999520
# FLOT     10.0     1.012000
# PLZL     10.0     0.997831
# MAGN     11.0     1.007939
# FEES     11.0     1.003708
# MTSS     12.0     1.003953
# HEAD     13.0     0.997205
# T        14.0     0.998712
# MGNT     14.0     1.001143
# CHMF     14.0     1.001284
# RUAL     15.0     0.997130
# FESH     16.0     1.000393
# SPBE     16.0     1.004799
# VSMO     16.0     1.001230
# TRMK     17.0     1.000000
# BSPB     19.0     0.999083
# SFIN     20.0     0.999913
# RTKM     20.0     1.001132
# ABIO     23.0     1.000399
# SELG     25.0     1.001951
# AFKS     25.0     0.999087
# UNAC     27.0     1.005049
# VKCO     28.0     0.999000
# MTLR     29.0     1.001803
# MTLRP    31.0     1.001545
# LSRG     31.0     0.997938
# RASP     34.0     0.997281
# BELU     35.0     1.001691
# SVAV     39.0     0.999979
# TRNFP    39.0     1.003442
# WUSH     43.0     1.001484
# RNFT     49.0     0.998683
# POSI     50.0     1.002260
# MVID     57.0     1.004219
# IRKT     58.0     1.000908
# PIKK     60.0     1.000531
# UWGN     60.0     1.003016
# TGKN     79.0     1.000277
# SMLT     90.0     1.000218
# SGZH     93.0     1.003514
# GTRK     93.0     1.000233

# %% [markdown]
# # Drop weak features

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1])
# Out:
# [('close/close_w30_ma', 1.57),
#  ('close/close_w10_ma', 2.25),
#  ('close/close_w10_expma', 2.79),
#  ('close_w10_max/close', 19.1),
#  ('close/close_w30_expma', 24.83),
#  ('close/close_1hour_w10_expma', 49.47)]

# %%
#Не использовал

# %%
features_order_to_drop = []
for elem in sorted(zip(features, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1]):
    if elem[1] > 0:
        features_order_to_drop += [elem[0]]
features_order_to_drop
# Out:
# ['close/close_w10_ma',
#  'close/close_w30_expma',
#  'close/close_w10_expma',
#  'close/close_w30_ma',
#  'close_w10_max/close',
#  'close/close_1hour_w10_expma']

# %%
cat_features = [elem for elem in features_order_to_drop if elem in cat_features_all]
len(cat_features)
# Out:
# 0

# %%
params
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 8,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.8,
#  'bagging_fraction': 0.5,
#  'bagging_freq': 1,
#  'lambda_l1': 1,
#  'lambda_l2': 1,
#  'verbose': -1,
#  'metric': 'mean_income_rate',
#  'early_stopping': 10}

# %%
from IPython.display import clear_output

history_fe = {'features' : [],
           'num_trees' : [],

           'auc_train' : [],
           'auc_valid' : [],
           'auc_test' : [],
           'auc_test2' : [],
           
           'mir_point@1_train' : [],
           'mir_point@1_valid' : [],
           'mir_point@1_test' : [],
           'mir_point@1_test2' : [],
              
           'mir_day@1_train' : [],
           'mir_day@1_valid' : [],
           'mir_day@1_test' : [],
           'mir_day@1_test2' : [],
              
           'mir_month@1_train' : [],
           'mir_month@1_valid' : [],
           'mir_month@1_test' : [],
           'mir_month@1_test2' : [],
          
          }
    
for i in tqdm(range(len(features_order_to_drop))):
    features_fe = features_order_to_drop[i:]
    cat_features = [elem for elem in features_fe if elem in cat_features_all]

    D_train = lgbm.Dataset(df.loc[mask_train, features_fe], label=df.loc[mask_train, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    D_valid = lgbm.Dataset(df.loc[mask_valid, features_fe], label=df.loc[mask_valid, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    D_test = lgbm.Dataset(df.loc[mask_test, features_fe], label=df.loc[mask_test, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    D_test2 = lgbm.Dataset(df.loc[mask_test2, features_fe], label=df.loc[mask_test2, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    
    D_train.income_rate = df.loc[mask_train, 'income_rate'].values
    D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
    D_test.income_rate = df.loc[mask_test, 'income_rate'].values
    D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

    D_train.time = df.loc[mask_train, 'time'].values
    D_valid.time = df.loc[mask_valid, 'time'].values
    D_test.time = df.loc[mask_test, 'time'].values
    D_test2.time = df.loc[mask_test2, 'time'].values

    model = lgbm.train(params, num_boost_round=2_000, train_set=D_train, valid_sets=[D_valid])
                    
    y_pred_train = model.predict(D_train.data)
    y_pred_valid = model.predict(D_valid.data)
    y_pred_test = model.predict(D_test.data)
    y_pred_test2 = model.predict(D_test2.data)
    
    #history_fe
    history_fe['features'] += [features_fe.copy()]
    history_fe['num_trees'] += [model.num_trees()]

    history_fe['auc_train'] += [roc_auc_score(D_train.label, y_pred_train)]
    history_fe['auc_valid'] += [roc_auc_score(D_valid.label, y_pred_valid)]
    history_fe['auc_test'] += [roc_auc_score(D_test.label, y_pred_test)]
    history_fe['auc_test2'] += [roc_auc_score(D_test2.label, y_pred_test2)]

    threshold1 = np.quantile(y_pred_valid, q=0.95)
      
    history_fe['mir_point@1_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold1)]
    history_fe['mir_point@1_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold1)]
    history_fe['mir_point@1_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold1)]
    history_fe['mir_point@1_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold1)]
    
    history_fe['mir_day@1_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold1)]
    history_fe['mir_day@1_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold1)]
    history_fe['mir_day@1_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold1)]
    history_fe['mir_day@1_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold1)]
    
    history_fe['mir_month@1_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold1)]
    history_fe['mir_month@1_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold1)]
    history_fe['mir_month@1_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold1)]
    history_fe['mir_month@1_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold1)]
                   



    #clear_output()

# %%
df_hst_fe = pd.DataFrame(history_fe)
df_hst_fe
# Out:
#                                              features  num_trees  auc_train  \
# 0   [sin_time_hour, volume_w5_min/volume, volume_w...        198   0.733658
# 1   [volume_w5_min/volume, volume_w5_min/volume_w5...          8   0.626349
# 2   [volume_w5_min/volume_w5_max, close_1day_w3_ro...          5   0.617089
# 3   [close_1day_w3_roc/close_1day_w20_roc, tmos_cl...          4   0.612161
# 4   [tmos_close_w1_roc, tmos_close_w70_lvl_1.005-1...         19   0.643543
# 5   [tmos_close_w70_lvl_1.005-1.01, volume_w5_std/...        155   0.725221
# 6   [volume_w5_std/volume_w14_std, volume_w5_norm_...         27   0.655332
# 7   [volume_w5_norm_std, tmos_close_w14_roc, tmos_...         14   0.635161
# 8   [tmos_close_w14_roc, tmos_close_w14_rsi, tmos_...         18   0.645007
# 9   [tmos_close_w14_rsi, tmos_close_w70_lvl_1.01-1...        171   0.727386
# 10  [tmos_close_w70_lvl_1.01-1.015, tmos_close_w70...          4   0.610072
# 11  [tmos_close_w70_lvl_-0.985-0.99, tmos_close_1d...          2   0.598932
# 12  [tmos_close_1day_w20_lvl_1.005-1.01, tmos_clos...         16   0.638584
# 13  [tmos_close_1day_w100_lvl_1.04-1.05, tmos_clos...         11   0.630843
# 14  [tmos_close_w70_rsi, tmos_close_w70_roc, close...         62   0.679490
# 15  [tmos_close_w70_roc, close_w70_rsi, hour, tmos...         15   0.640389
# 16  [close_w70_rsi, hour, tmos_close_w70_ma_up_2st...         16   0.638406
# 17  [hour, tmos_close_w70_ma_up_2std/tmos_close, t...         45   0.663421
# 18  [tmos_close_w70_ma_up_2std/tmos_close, tmos_cl...          5   0.611144
# 19  [tmos_close_w14_ma/tmos_close_w70_ma, close_w7...          5   0.613305
# 20  [close_w70_lvl_-0.98-0.99, tmos_close_w5_ma/tm...         92   0.687420
# 21  [tmos_close_w5_ma/tmos_close_w70_ma, tmos_clos...         15   0.630530
# 22  [tmos_close_w14_max/tmos_close, tmos_close_1da...          2   0.598729
# 23  [tmos_close_1day_w100_lvl_1.015-1.02, tmos_clo...         57   0.669771
# 24  [tmos_close_1day_w20_lvl_1.015-1.02, tmos_clos...         91   0.687240
# 25  [tmos_close_w5_max/tmos_close, close_w1_roc, t...         10   0.613478
# 26  [close_w1_roc, tmos_close_1day_w3_mean_abs_pct...          2   0.583995
# 27  [tmos_close_1day_w3_mean_abs_pct/tmos_close_1d...         53   0.656068
# 28   [tmos_close_1day_w5_ma_low_2std/tmos_close_1day]         79   0.635685
#
#     auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 0    0.605363  0.588251   0.566186           0.005320           0.002203
# 1    0.592369  0.567153   0.544459           0.002744           0.002199
# 2    0.597449  0.563820   0.540159           0.002400           0.002699
# 3    0.581042  0.571640   0.539485           0.002089           0.002281
# 4    0.584569  0.576878   0.551086           0.003359           0.003056
# 5    0.581633  0.578709   0.551594           0.004945           0.001972
# 6    0.591613  0.587970   0.541675           0.003341           0.002632
# 7    0.584168  0.562551   0.540024           0.002796           0.001442
# 8    0.593090  0.577566   0.549284           0.002760           0.002264
# 9    0.603621  0.576106   0.561384           0.005111           0.002727
# 10   0.587565  0.568763   0.535223           0.001725           0.001660
# 11   0.576465  0.558644   0.539835           0.001851           0.001592
# 12   0.584375  0.579817   0.547017           0.003074           0.002370
# 13   0.595853  0.574546   0.559451           0.002674           0.002554
# 14   0.593048  0.578862   0.553060           0.004394           0.002576
# 15   0.598035  0.574202   0.546889           0.003221           0.002758
# 16   0.580452  0.580025   0.555406           0.003105           0.001885
# 17   0.581921  0.584261   0.546988           0.004559           0.002132
# 18   0.587364  0.565582   0.552388           0.001639           0.001775
# 19   0.590429  0.564605   0.547468           0.002289           0.002475
# 20   0.590689  0.572401   0.543948           0.004636           0.002094
# 21   0.584839  0.575258   0.551246           0.002616           0.003143
# 22   0.582269  0.568956   0.535589           0.002431           0.002140
# 23   0.580974  0.602528   0.537651           0.004408           0.001834
# 24   0.590844  0.595105   0.537035           0.004595           0.002099
# 25   0.582474  0.573837   0.551870           0.002075           0.001890
# 26   0.556212  0.529639   0.545565           0.002608           0.003344
# 27   0.535823  0.514837   0.550336           0.004090           0.001200
# 28   0.555491  0.505207   0.514943           0.002850           0.001606
#
#     mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 0           0.003810           0.003521         0.004375         0.003251
# 1           0.002413           0.002320         0.002435         0.002864
# 2           0.002609           0.002344         0.002444         0.003178
# 3           0.002165           0.001655         0.002047         0.002570
# 4           0.003245           0.002576         0.002848         0.003406
# 5           0.003755           0.003535         0.003968         0.003743
# 6           0.002640           0.002069         0.002874         0.003287
# 7           0.002697           0.001501         0.002647         0.003120
# 8           0.002785           0.002028         0.002737         0.003247
# 9           0.003434           0.004079         0.003959         0.003684
# 10          0.001907           0.001775         0.001914         0.002491
# 11          0.001977           0.001627         0.001342         0.001862
# 12          0.002606           0.002299         0.002624         0.003271
# 13          0.002701           0.002582         0.002544         0.003087
# 14          0.003232           0.002651         0.003071         0.003256
# 15          0.002576           0.001596         0.002898         0.003264
# 16          0.002947           0.002214         0.002683         0.002889
# 17          0.003274           0.002969         0.003493         0.003719
# 18          0.001918           0.001858         0.001897         0.002516
# 19          0.002993           0.001611         0.002578         0.003328
# 20          0.003755           0.003596         0.003752         0.004036
# 21          0.002759           0.002008         0.002581         0.003412
# 22          0.002666           0.001889         0.002503         0.002869
# 23          0.004077           0.004148         0.003644         0.003281
# 24          0.003005           0.002345         0.003354         0.003980
# 25          0.002089           0.001886         0.002068         0.002940
# 26          0.002690           0.002212         0.002562         0.003552
# 27         -0.003321                NaN         0.003708         0.001184
# 28         -0.000479          -0.000816         0.002648        -0.000126
#
#     mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 0         0.004013         0.003654           0.071424           0.058214
# 1         0.002869         0.003028           0.053090           0.063001
# 2         0.003085         0.003197           0.053271           0.069918
# 3         0.002515         0.002428           0.044729           0.056542
# 4         0.003572         0.003038           0.061091           0.074934
# 5         0.003683         0.003398           0.067759           0.070853
# 6         0.003355         0.003183           0.061353           0.072307
# 7         0.003235         0.003293           0.057429           0.068640
# 8         0.003388         0.003200           0.059535           0.071441
# 9         0.005079         0.003918           0.058854           0.067851
# 10        0.002559         0.002664           0.042098           0.054813
# 11        0.001758         0.001642           0.021375           0.037146
# 12        0.003273         0.003333           0.057079           0.071959
# 13        0.003214         0.003446           0.055448           0.067923
# 14        0.003148         0.003141           0.059997           0.071641
# 15        0.003335         0.002862           0.056477           0.070132
# 16        0.003227         0.003072           0.058228           0.063561
# 17        0.003844         0.003183           0.061412           0.081808
# 18        0.002492         0.002671           0.041742           0.055347
# 19        0.003192         0.003377           0.056079           0.073223
# 20        0.003248         0.004099           0.062191           0.076407
# 21        0.003260         0.003419           0.056266           0.075069
# 22        0.003014         0.002812           0.054566           0.063118
# 23        0.003698         0.003882           0.058395           0.062112
# 24        0.003049         0.003990           0.063676           0.075339
# 25        0.002740         0.003000           0.045503           0.064674
# 26        0.003268         0.003478           0.055711           0.078138
# 27       -0.003321              NaN           0.005774           0.001817
# 28       -0.000368        -0.000807           0.007848          -0.000322
#
#     mir_month@1_test  mir_month@1_test2
# 0           0.069799           0.065403
# 1           0.063114           0.066627
# 2           0.067865           0.070329
# 3           0.055324           0.053420
# 4           0.078575           0.064562
# 5           0.067836           0.067163
# 6           0.073818           0.070019
# 7           0.071168           0.072437
# 8           0.074547           0.070403
# 9           0.080552           0.067209
# 10          0.056293           0.058601
# 11          0.038670           0.035514
# 12          0.071996           0.073315
# 13          0.070719           0.075814
# 14          0.064423           0.067928
# 15          0.069964           0.059765
# 16          0.070997           0.067581
# 17          0.066876           0.066457
# 18          0.054824           0.058754
# 19          0.070221           0.074289
# 20          0.061478           0.079486
# 21          0.071711           0.075209
# 22          0.066310           0.061870
# 23          0.071892           0.079612
# 24          0.062404           0.080350
# 25          0.060282           0.066003
# 26          0.071890           0.076515
# 27         -0.001699                NaN
# 28         -0.001319          -0.001505

# %%
df_hst_fe['features'].loc[5]
# Out:
# ['tmos_close_w70_lvl_1.005-1.01',
#  'volume_w5_std/volume_w14_std',
#  'volume_w5_norm_std',
#  'tmos_close_w14_roc',
#  'tmos_close_w14_rsi',
#  'tmos_close_w70_lvl_1.01-1.015',
#  'tmos_close_w70_lvl_-0.985-0.99',
#  'tmos_close_1day_w20_lvl_1.005-1.01',
#  'tmos_close_1day_w100_lvl_1.04-1.05',
#  'tmos_close_w70_rsi',
#  'tmos_close_w70_roc',
#  'close_w70_rsi',
#  'hour',
#  'tmos_close_w70_ma_up_2std/tmos_close',
#  'tmos_close_w14_ma/tmos_close_w70_ma',
#  'close_w70_lvl_-0.98-0.99',
#  'tmos_close_w5_ma/tmos_close_w70_ma',
#  'tmos_close_w14_max/tmos_close',
#  'tmos_close_1day_w100_lvl_1.015-1.02',
#  'tmos_close_1day_w20_lvl_1.015-1.02',
#  'tmos_close_w5_max/tmos_close',
#  'close_w1_roc',
#  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
#  'tmos_close_1day_w5_ma_low_2std/tmos_close_1day']

# %% [markdown]
# # BEST

# %%
features_fe = features
features
# Out:
# ['close/close_w10_ma',
#  'close/close_w30_ma',
#  'close/close_w10_expma',
#  'close/close_w30_expma',
#  'close_w10_max/close',
#  'close/close_1hour_w10_expma']

# %%
params
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 5,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.5,
#  'bagging_fraction': 0.3,
#  'bagging_freq': 1,
#  'lambda_l1': 1,
#  'lambda_l2': 1,
#  'verbose': -1,
#  'metric': 'mean_income_rate',
#  'early_stopping': 10}

# %%
params = {'boosting_type': 'gbdt',
 'objective': 'binary',
 'num_leaves': 5,
 'learning_rate': 0.1,
 'feature_fraction': 0.5,
 'bagging_fraction': 0.3,
 'bagging_freq': 1,
 'lambda_l1': 1,
 'lambda_l2': 1,
 'verbose': -1,
 'metric': 'mean_income_rate',
 'early_stopping': 10}

# %%
target = 'target'
cat_features = [elem for elem in features_fe if elem in cat_features_all]
len(cat_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[283], line 2
#       1 target = 'target'
# ----> 2 cat_features = [elem for elem in features_fe if elem in cat_features_all]
#       3 len(cat_features)
#
# NameError: name 'features_fe' is not defined

# %%
D_train = lgbm.Dataset(df.loc[mask_train, features_fe], label=df.loc[mask_train, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, features_fe], label=df.loc[mask_valid, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, features_fe], label=df.loc[mask_test, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, features_fe], label=df.loc[mask_test2, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)


D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
D_test3 = lgbm.Dataset(df.loc[mask_test3, features_fe], label=df.loc[mask_test3, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
D_test3.time = df.loc[mask_test3, 'time'].values

# %% [markdown]
# # INCORPORATION

# %%
# D_test3 = lgbm.Dataset(df.loc[mask_test3, features], label=df.loc[mask_test3, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
# D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
# D_test3.time = df.loc[mask_test3, 'time'].values

# %%
model = lgbm.train(params,  num_boost_round=1_000, train_set=D_train, valid_sets=[D_valid], feval=mean_income_rate)

# %%
#dump_pkl(model, './model.pkl')

# %%
#model = load_pkl('./model.pkl')

# %%
model.num_trees()
# Out:
# 17

# %%
(model.predict(D_test2.data) == model.predict(df.loc[mask_test2, features_fe])).all()
# Out:
# True

# %%
y_pred_train = model.predict(D_train.data)
y_pred_valid = model.predict(D_valid.data)
y_pred_test = model.predict(D_test.data)
y_pred_test2 = model.predict(D_test2.data)


df["y_pred"] = None
df.loc[mask_train, 'y_pred'] = y_pred_train
df.loc[mask_valid, 'y_pred'] = y_pred_valid
df.loc[mask_test, 'y_pred'] = y_pred_test
df.loc[mask_test2, 'y_pred'] = y_pred_test2

roc_auc_score(D_train.label, y_pred_train), roc_auc_score(D_valid.label, y_pred_valid), roc_auc_score(D_test.label, y_pred_test), roc_auc_score(D_test2.label, y_pred_test2)
# Out:
# (0.652944363854863, 0.6106727017819044, 0.6085286847042677, 0.5760034988223279)

# %%
y_pred_test3 = model.predict(D_test3.data)
df.loc[mask_test3, 'y_pred'] = y_pred_test3
roc_auc_score(D_test3.label, y_pred_test3)
# Out:
# 0.6078107687204396

# %%
#свой threshold

q = 0.99

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest')
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# Valid
# result
# LOSE    0.602980
# WIN     0.266631
# DNF     0.130389
# Name: proportion, dtype: float64
# 1.0005339
#
# Test
# result
# LOSE    0.534453
# WIN     0.280834
# DNF     0.184713
# Name: proportion, dtype: float64
# 1.0013725
#
# Test2
# result
# LOSE    0.532609
# WIN     0.292271
# DNF     0.175121
# Name: proportion, dtype: float64
# 1.0013669

# %%
threshold = np.quantile(df.loc[mask_test3, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest3')
print(df.loc[mask_test3&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test3&mask, 'income_rate'].mean())
# Out:
# Test3
# result
# LOSE    0.548298
# DNF     0.250230
# WIN     0.201472
# Name: proportion, dtype: float64
# 1.0003227

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 01:00:00'),
#  Timedelta('0 days 01:15:00'),
#  Timedelta('0 days 01:15:00'))

# %%
df.loc[mask_test3&mask, 'delta_time'].median()
# Out:
# Timedelta('0 days 01:30:00')

# %%
#общий threshold

q = 0.99

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
print(f'threshokd = {threshold}')

mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print("\nTest")
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print('\nTetst2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# threshokd = 0.2591240486482249
#
# Valid
# result
# LOSE    0.602980
# WIN     0.266631
# DNF     0.130389
# Name: proportion, dtype: float64
# 1.0005339
#
# Test
# result
# LOSE    0.530280
# WIN     0.310559
# DNF     0.159161
# Name: proportion, dtype: float64
# 1.0017412
#
# Tetst2
# result
# LOSE    0.543643
# WIN     0.296907
# DNF     0.159450
# Name: proportion, dtype: float64
# 1.0012803

# %%
df.loc[mask_valid&mask, 'time'].dt.date.nunique(), df.loc[mask_test&mask, 'time'].dt.date.nunique(),  df.loc[mask_test2&mask, 'time'].dt.date.nunique()
# Out:
# (42, 42, 39)

# %%
df.loc[mask_test3&mask, 'time'].dt.date.nunique(), df.loc[mask_test3, 'time'].dt.date.nunique()
# Out:
# (22, 27)

# %%
print('\nTetst3')
print(df.loc[mask_test3&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test3&mask, 'income_rate'].mean())
# Out:
# Tetst3
# result
# LOSE    0.551661
# DNF     0.232472
# WIN     0.215867
# Name: proportion, dtype: float64
# 1.000421

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 01:00:00'),
#  Timedelta('0 days 01:00:00'),
#  Timedelta('0 days 01:00:00'))

# %%
df.loc[mask_test3&mask, 'delta_time'].median()
# Out:
# Timedelta('0 days 01:22:30')

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.99)
mask = df['y_pred'] >= threshold
threshold
# Out:
# 0.2591240486482249

# %%
mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_point(D_test, y_pred_test, threshold=threshold), mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0005339384078979492, 0.001741170883178711, 0.0012803077697753906)

# %%
mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_day(D_test, y_pred_test, threshold=threshold), mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0033925232, 0.0039304667, 0.0036743742)

# %%
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.06965980877478917, 0.08253980102017522, 0.07331658277097483)

# %%
mean_income_rate_point(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.0004210472106933594

# %%
mean_income_rate_day(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.0019698576

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.035311521548363894

# %%
df.loc[mask_test2&mask, 'ticker'].unique()
# Out:
# array(['AFLT', 'IRAO', 'MVID', 'SPBE', 'MTLRP', 'SFIN', 'FEES', 'LKOH',
#        'FESH', 'MDMG', 'VKCO', 'SELG', 'SGZH', 'ENPG', 'LSRG', 'NMTP',
#        'PLZL', 'TATN', 'AFKS', 'GMKN', 'RNFT', 'YDEX', 'UWGN', 'TGKN',
#        'HYDR', 'ABIO', 'WUSH', 'GTRK', 'NLMK', 'TATNP', 'ALRS', 'VSMO',
#        'TRNFP', 'MGNT', 'IRKT', 'MTLR', 'HEAD', 'RUAL', 'SNGS', 'NVTK',
#        'RASP', 'VTBR', 'PHOR', 'T', 'TRMK', 'MOEX', 'CHMF', 'RTKM',
#        'SMLT', 'UNAC', 'GAZP', 'ROSN', 'BELU', 'FLOT', 'PIKK', 'SVAV',
#        'POSI', 'SNGSP', 'MTSS', 'MAGN', 'BANEP', 'BSPB'], dtype=object)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#         count  income_rate
# ticker
# PHOR      1.0     1.009423
# ROSN      2.0     0.997834
# NLMK      2.0     1.014000
# MDMG      2.0     1.008354
# GMKN      2.0     0.998990
# SNGSP     3.0     1.007333
# SNGS      3.0     0.996834
# NVTK      3.0     1.003587
# IRAO      3.0     1.014000
# YDEX      4.0     1.004000
# ALRS      5.0     0.996159
# ENPG      5.0     0.998000
# MOEX      5.0     1.012264
# HYDR      5.0     1.008806
# TATNP     6.0     1.008331
# TATN      6.0     1.008229
# NMTP      6.0     1.007333
# BANEP     8.0     0.998949
# VTBR      9.0     0.996350
# LKOH      9.0     0.998244
# AFLT     10.0     0.997125
# GAZP     10.0     0.999520
# FLOT     10.0     1.012000
# PLZL     10.0     0.997831
# MAGN     11.0     1.007939
# FEES     11.0     1.003708
# MTSS     12.0     1.003953
# HEAD     13.0     0.997205
# T        14.0     0.998712
# MGNT     14.0     1.001143
# CHMF     14.0     1.001284
# RUAL     15.0     0.997130
# FESH     16.0     1.000393
# SPBE     16.0     1.004799
# VSMO     16.0     1.001230
# TRMK     17.0     1.000000
# BSPB     19.0     0.999083
# SFIN     20.0     0.999913
# RTKM     20.0     1.001132
# ABIO     23.0     1.000399
# SELG     25.0     1.001951
# AFKS     25.0     0.999087
# UNAC     27.0     1.005049
# VKCO     28.0     0.999000
# MTLR     29.0     1.001803
# MTLRP    31.0     1.001545
# LSRG     31.0     0.997938
# RASP     34.0     0.997281
# BELU     35.0     1.001691
# SVAV     39.0     0.999979
# TRNFP    39.0     1.003442
# WUSH     43.0     1.001484
# RNFT     49.0     0.998683
# POSI     50.0     1.002260
# MVID     57.0     1.004219
# IRKT     58.0     1.000908
# PIKK     60.0     1.000531
# UWGN     60.0     1.003016
# TGKN     79.0     1.000277
# SMLT     90.0     1.000218
# SGZH     93.0     1.003514
# GTRK     93.0     1.000233

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test3&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/2708990562.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test3&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#         count  income_rate
# ticker
# YDEX      1.0     1.007534
# AFLT      1.0     0.999853
# SVAV      1.0     1.005644
# MTSS      1.0     0.994000
# LSRG      1.0     1.001535
# ALRS      2.0     1.008884
# UPRO      2.0     1.006774
# UWGN      2.0     1.006500
# VTBR      2.0     0.994000
# GMKN      2.0     0.996667
# HEAD      2.0     0.999965
# MGNT      2.0     1.000397
# BANEP     3.0     1.006573
# SNGSP     3.0     1.008367
# VSMO      3.0     1.007872
# TATNP     4.0     0.998806
# MVID      4.0     1.006928
# MAGN      4.0     0.997561
# IRKT      5.0     1.000050
# TATN      5.0     0.995876
# NLMK      5.0     0.994000
# X5        5.0     1.014000
# WUSH      6.0     1.001547
# HYDR      7.0     1.001321
# ENPG      8.0     1.002908
# SGZH      8.0     1.006500
# VKCO      8.0     1.001709
# RTKM      9.0     0.999936
# SIBN      9.0     1.002045
# MDMG      9.0     1.006231
# SNGS      9.0     1.006641
# FEES      9.0     0.999609
# NVTK      9.0     0.995025
# SPBE     10.0     1.007323
# TRNFP    10.0     0.996000
# GTRK     11.0     0.998638
# RNFT     12.0     0.999605
# AFKS     13.0     0.998884
# RASP     14.0     0.999183
# NMTP     14.0     1.004572
# RUAL     14.0     0.997524
# TGKN     15.0     1.001654
# MTLR     15.0     0.996948
# CHMF     16.0     0.994975
# ROSN     16.0     1.006374
# ABIO     17.0     0.999225
# UNAC     17.0     1.003159
# SELG     19.0     1.001473
# PIKK     20.0     0.999585
# FLOT     22.0     1.001303
# SMLT     33.0     0.999526
# POSI     33.0     0.996672
# FESH     34.0     1.001596
# MTLRP    36.0     0.996222

# %%
#df[mask_test3&mask&(df['ticker'] == 'SMLT')]

# %%
# dump_pkl(y_pred_valid, './bst_mdl/y_pred_valid.pkl')
# dump_pkl(y_pred_test, './bst_mdl/y_pred_test.pkl')
# dump_pkl(y_pred_test2, './bst_mdl/y_pred_test2.pkl')

# dump_pkl(y_pred_test3, './bst_mdl/y_pred_test3.pkl')

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features_fe, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1])
# Out:
# [('close/close_w30_ma', 1.57),
#  ('close/close_w10_ma', 2.25),
#  ('close/close_w10_expma', 2.79),
#  ('close_w10_max/close', 19.1),
#  ('close/close_w30_expma', 24.83),
#  ('close/close_1hour_w10_expma', 49.47)]

# %% [markdown]
# ### -1. TMP

# %% [markdown]
# #### 1. AUC

# %%
mask_data = df['y_pred'].notnull()
plt.figure(figsize=(10, 3))
(df.loc[mask_data, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
                                                                            roc_auc_score(x['target'], x['y_pred'])
                                                                                                          ) - 0.5).plot.bar()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_74448/266340296.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_data, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
# <Axes: xlabel='time'>

# %% [markdown]
# #### 2. WIN

# %%
np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
# Out:
# 0.13445166352208648

# %%
q = 0.9
col_target = 'target'

mask_last_bin = df['y_pred'] >= np.quantile(df.loc[mask_valid, 'y_pred'], q=q)

mask_data = df['y_pred'].notnull()
plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
                                                                            x[col_target].mean()).plot.bar()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_74448/2056057339.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
# <Axes: xlabel='time'>

# %% [markdown]
# #### 3. income_rate

# %%
q = 0.9
col_target = 'income_rate'

mask_last_bin = df['y_pred'] >= np.quantile(df.loc[mask_valid, 'y_pred'], q=q)

mask_data = df['y_pred'].notnull()
plt.figure(figsize=(10, 3))
(df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
                                                                            x[col_target].mean()) -1).plot.bar()
plt.grid()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_74448/1220509864.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:

# %% [markdown]
# #### 4. Отложенная выборка

# %%
#distibution in time
#win
col_pred = 'y_pred'
q = 0.9
freq='D'

mask_data = mask_valid|mask_test|mask_test2#|mask_test3

threshold = np.quantile(df.loc[mask_valid, col_pred], q=q)
mask_last_bin = df[col_pred] >= threshold


plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.mean().plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='Success Rate')
plt.legend()
plt.show()


#distibution in time
#income_rate
print('INCOME_RATE')

plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='INCOME_RATE')
plt.legend()
plt.show()
# Out:
# INCOME_RATE

# %%
#y_test3

# %%
#distibution in time
#win
col_pred = 'y_pred'
q = 0.9
freq='D'


mask_data = mask_test2


threshold = np.quantile(df.loc[mask_valid, col_pred], q=q)
mask_last_bin = df[col_pred] >= threshold


plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.mean().plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='Success Rate')
plt.legend()
plt.show()


#distibution in time
#income_rate
print('INCOME_RATE')

plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='INCOME_RATE')
plt.legend()
plt.show()
# Out:
# INCOME_RATE

# %%
#mean_income_rate_by_day
(df.loc[mask_valid&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean(), (df.loc[mask_test&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean(), (df.loc[mask_test2&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean()
# Out:
# (0.02200709729474894, 0.023863343211569032, 0.02024511593516703)

# %%
df.loc[mask_valid&mask_last_bin, 'time'].dt.date.nunique(), df.loc[mask_test&mask_last_bin, 'time'].dt.date.nunique(),  df.loc[mask_test2&mask_last_bin, 'time'].dt.date.nunique()
# Out:
# (12, 11, 15)

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.9)

# %%
#sum_income_rate
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.06049424306550394, 0.049778267425649315, 0.05359498661153247)

# %%
#test3
(df.loc[mask_test3&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean()
# Out:
# 0.0030187571083587226

# %%
df.loc[mask_test3&mask_last_bin, 'time'].dt.date.nunique()
# Out:
# 33

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.055606090705674446

# %%
mask_data = mask_valid | mask_test | mask_test2

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_74448/1640586492.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_data&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.013450404335823504

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_valid&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_74448/1656526771.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_valid&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.0008238830775141315

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_test&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_74448/192763211.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_test&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.011175368162590753

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_test2&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_74448/1559495362.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_test2&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.013450404335823504

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_test3&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_93253/2683039865.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_test3&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.0012062589327494304

# %% [markdown]
# #### Points in life

# %%
threshold
# Out:
# 0.22686240875366323

# %%
mask_dev = df['time'] > pd.Timestamp('2025-01-20')
df.loc[mask_dev, 'y_pred'] = model.predict(df.loc[mask_dev, features_fe]) #feratures_fe

#threshold = 0.5695387939626755
df.loc[mask_dev, ['time', 'y_pred']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: (x['y_pred'] >= threshold).sum())

# %% [markdown]
# ### Обучить на всем

# %%
features
# Out:
# ['close_w30_lvl_1.015-1.02',
#  'close_w30_lvl_1.02-1.03',
#  'close_w120_lvl_1.02-1.03',
#  'close/close_w5_expma',
#  'close/close_w10_expma',
#  'close/close_w20_expma',
#  'close/close_w30_expma',
#  'close/close_w60_expma',
#  'close/close_w120_expma',
#  'close_w5_expma/close_w20_expma',
#  'close_w5_expma/close_w30_expma',
#  'close_w5_expma/close_w60_expma',
#  'close_w5_expma/close_w120_expma',
#  'close_w10_expma/close_w30_expma',
#  'close_w10_expma/close_w60_expma',
#  'close_w10_expma/close_w120_expma',
#  'close_w20_expma/close_w60_expma',
#  'close_w20_expma/close_w120_expma',
#  'close_w30_expma/close_w60_expma',
#  'close_w30_expma/close_w120_expma']

# %%
features_fe = features
cat_features = []
target = 'target'

# %%
mask_data = mask_train | mask_valid | mask_test | mask_test2
#mask_data = (pd.Timestamp('2024-01-01') <= df['time']) &  (df['time'] < pd.Timestamp('2025-01-01'))
#print(mask_data.sum())
#mask_data = mask_valid | mask_test | mask_test2
#mask_data = mask_test2

D_data = lgbm.Dataset(df.loc[mask_data, features_fe], label=df.loc[mask_data, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)


D_data.income_rate = df.loc[mask_data, 'income_rate'].values

D_data.time = df.loc[mask_data, 'time'].values

# %%
D_test3 = lgbm.Dataset(df.loc[mask_test3, features_fe], label=df.loc[mask_test3, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
D_test3.time = df.loc[mask_test3, 'time'].values

# %%
params = {
    "boosting_type": "gbdt",
    "objective": "binary",
    
    
    "num_boost_round" : 100,

    
    "num_leaves": 31,
    #"learning_rate": 0.001,
     "feature_fraction": 0.5,
     "bagging_fraction": 0.5,
     "bagging_freq": 1,
     'lambda_l1' : 1,
     'lambda_l2' : 1,
    #"verbose": 0,

    #'max_bin' : 100000,
    
    
    # "metric": "auc",
      "metric" : 'mean_income_rate',
     "early_stopping" : 10,



    
}

# %%
#model.num_trees()

# %%
#del params['metric'], params['early_stopping']

# %%
#params['num_boost_round'] = 40

# %%
model = lgbm.train(params, train_set=D_data, valid_sets=[D_test3], feval=mean_income_rate)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [13]	valid_0's mean_income_rate: 0.00141

# %%
model.num_trees()
# Out:
# 13

# %%
#dump_pkl(model, 'model_-0.5_+1.5_4hour.pkl')

# %%
#model = load_pkl('model_-0.5_+1.5_4hour.pkl')
#model.num_trees()

# %%
y_pred_data= model.predict(D_data.data)


df["y_pred"] = None
df.loc[mask_data, 'y_pred'] = y_pred_data

roc_auc_score(D_data.label, y_pred_data)
# Out:
# 0.6770638965364955

# %%
y_pred_test3 = model.predict(D_test3.data)
df.loc[mask_test3, 'y_pred'] = y_pred_test3
roc_auc_score(D_test3.label, y_pred_test3)
# Out:
# 0.6090700984894337

# %%
THREHOLD = np.quantile(y_pred_test3, q=0.995)
#THRESHOLD = threshold
THRESHOLD
# Out:
# 0.22686240875366323

# %%
mean_income_rate_point(D_data, y_pred_data, threshold=THRESHOLD)
# Out:
# 0.0026379170347794467

# %%
mean_income_rate_day(D_data, y_pred_data, threshold=THRESHOLD)
# Out:
# 0.0036637617789679307

# %%
mean_income_rate_month(D_data, y_pred_data, threshold=THRESHOLD)
# Out:
# 0.05208178282717489

# %%
mean_income_rate_point(D_test3, y_pred_test3, threshold=THRESHOLD)
# Out:
# 0.0026117390072024627

# %%
mean_income_rate_tick(D_test3, y_pred_test3, threshold=THRESHOLD)
# Out:
# 0.0026933455751055775

# %%
mean_income_rate_day(D_test3, y_pred_test3, threshold=THRESHOLD)
# Out:
# 0.004326890513360705

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=THRESHOLD)
# Out:
# 0.05260587939928016

# %%
# Стало лучше, но тут я обучался под valid

# %%
# +-

# %%
#distibution in time
#win
col_pred = 'y_pred'
freq='D'


mask_data = mask_test3


#threshold = np.quantile(df.loc[mask_valid, col_pred], q=q)
mask_last_bin = df[col_pred] > THRESHOLD


plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.mean().plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='Success Rate')
plt.legend()
plt.show()


#distibution in time
#income_rate
print('INCOME_RATE')

plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='INCOME_RATE')
plt.legend()
plt.show()
# Out:
# INCOME_RATE

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features_fe, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: -x[1])
# Out:
# [('close_w20_expma/close_w120_expma', 18.4),
#  ('close_w120_lvl_1.02-1.03', 16.46),
#  ('close_w30_expma/close_w120_expma', 13.64),
#  ('close/close_w5_expma', 8.8),
#  ('close_w10_expma/close_w120_expma', 7.4),
#  ('close/close_w10_expma', 5.55),
#  ('close_w30_expma/close_w60_expma', 4.48),
#  ('close_w5_expma/close_w120_expma', 3.96),
#  ('close_w10_expma/close_w30_expma', 3.36),
#  ('close/close_w30_expma', 2.44),
#  ('close_w20_expma/close_w60_expma', 2.33),
#  ('close/close_w120_expma', 2.16),
#  ('close_w5_expma/close_w30_expma', 2.16),
#  ('close_w10_expma/close_w60_expma', 2.1),
#  ('close_w5_expma/close_w20_expma', 1.76),
#  ('close_w5_expma/close_w60_expma', 1.74),
#  ('close/close_w60_expma', 1.48),
#  ('close_w30_lvl_1.015-1.02', 0.83),
#  ('close/close_w20_expma', 0.8),
#  ('close_w30_lvl_1.02-1.03', 0.12)]
