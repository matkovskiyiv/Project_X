# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime
import math
import gc

from sklearn.metrics import roc_auc_score

import lightgbm as lgbm

import pickle
def dump_pkl(data, filename):
  with open(filename, 'wb') as handle:
    pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)

def load_pkl(filename):
  with open(filename, 'rb') as handle:
    data = pickle.load(handle)
  return data

# %%
stocks = ['ABIO',
 'AFKS',
 'AFLT',
 'ALRS',
 'APTK',
 'AQUA',
 'BANE',
 'BANEP',
 'BELU',
 'BSPB',
 'CBOM',
 'CHMF',
 'ENPG',
 'FEES',
 'FESH',
 'FLOT',
 'GAZP',
 'GMKN',
 'GTRK',
 'HEAD',
 'HYDR',
 'IRAO',
 'IRKT',
 'KMAZ',
 'LENT',
 'LIFE',
 'LKOH',
 'LSRG',
 'MAGN',
 'MDMG',
 'MGNT',
 'MOEX',
 'MTLR',
 'MTLRP',
 'MTSS',
 'MVID',
 'NLMK',
 'NMTP',
 'NVTK',
 'OGKB',
 'PHOR',
 'PIKK',
 'PLZL',
 'POSI',
 'RASP',
 'RENI',
 'RNFT',
 'ROSN',
 'RTKM',
 'RTKMP',
 'RUAL',
 'SBER',
 'SBERP',
 'SELG',
 'SFIN',
 'SGZH',
 'SIBN',
 'SMLT',
 'SNGS',
 'SNGSP',
 'SPBE',
 'SVAV',
 'T',
 'TATN',
 'TATNP',
 'TGKN',
 'TRMK',
 'TRNFP',
 'UNAC',
 'UPRO',
 'UWGN',
 'VKCO',
 'VSMO',
 'VTBR',
 'WUSH',
 'YDEX',


#'TMOS',
]

len(stocks)
# Out:
# 76

# %%
df = load_pkl('./data/feat_engin/lgbm/data_1min.pkl')

# %%
df.shape
# Out:
# (4436580, 700)

# %%
df.head()
# Out:
#    index                time       close  volume ticker  tmos_close  \
# 0    409 2023-07-04 10:03:00  105.120003   498.0   ABIO        5.52
# 1    411 2023-07-04 10:05:00  104.699997   864.0   ABIO        5.51
# 2    417 2023-07-04 10:11:00  104.599998   438.0   ABIO        5.50
# 3    427 2023-07-04 10:22:00  104.599998    24.0   ABIO        5.50
# 4    436 2023-07-04 10:31:00  104.300003   336.0   ABIO        5.49
#
#    close_w1_roc  volume_w1_roc  tmos_close_w1_roc  close_w5_norm_std  ...  \
# 0     -0.000760       0.099338           0.000000           0.002112  ...
# 1     -0.002667      -0.711712          -0.001812           0.002266  ...
# 2     -0.004568       1.354839          -0.001815           0.003970  ...
# 3      0.000000       7.000000           0.000000           0.000331  ...
# 4     -0.001340      -0.404255          -0.001818           0.001112  ...
#
#    tmos_close_w20_min/tmos_close_w20_max  close_w30_min/close_w30_max  \
# 0                               0.998192                     0.993567
# 1                               0.996383                     0.990539
# 2                               0.994575                     0.984863
# 3                               0.996377                     0.984863
# 4                               0.996370                     0.988416
#
#    volume_w30_min/volume_w30_max  tmos_close_w30_min/tmos_close_w30_max  \
# 0                       0.002849                               0.998192
# 1                       0.001001                               0.996383
# 2                       0.001001                               0.994575
# 3                       0.001001                               0.994575
# 4                       0.001001                               0.992767
#
#    close_w60_min/close_w60_max  volume_w60_min/volume_w60_max  \
# 0                     0.993567                       0.002469
# 1                     0.990539                       0.001001
# 2                     0.984863                       0.001001
# 3                     0.984863                       0.001001
# 4                     0.984863                       0.001001
#
#    tmos_close_w60_min/tmos_close_w60_max  close_w120_min/close_w120_max  \
# 0                               0.998192                       0.993567
# 1                               0.996383                       0.990539
# 2                               0.994575                       0.984863
# 3                               0.994575                       0.984863
# 4                               0.992767                       0.984863
#
#    volume_w120_min/volume_w120_max  tmos_close_w120_min/tmos_close_w120_max
# 0                         0.000755                                 0.998192
# 1                         0.000755                                 0.996383
# 2                         0.000755                                 0.994575
# 3                         0.000755                                 0.994575
# 4                         0.000755                                 0.992767
#
# [5 rows x 700 columns]

# %% [markdown]
# ## CHANGE TARGET

# %%
def get_target(df_all, ind, val_first, val_second, time_to_wait, time_tick):
    #цель - достичь val_second, не достигнув val_first

    max_points_to_wait = time_to_wait // time_tick
    ind_end = min(ind+max_points_to_wait+1, df_all.shape[0])
    df = df_all.iloc[ind:ind_end].copy()
    
    #mask_time - автоматически и маска на тек. день (10 часов разница между концом и началом осн сессии)
    mask_time = np.array(df['time'] <= df['time'].iloc[0] + time_to_wait)
    df = df.loc[mask_time, :]

    # #mask_stock - работаем внутри одного ticker в тек. версии
    # mask_stock = np.array(df['ticker'] == df['ticker'].iloc[0])
    # df = df.loc[mask_stock, :]


    start_price = df['close'].iloc[0]
    
    if val_first < val_second:                                 
        mask_val_first = np.array(df['close'] < val_first)
        mask_val_second = np.array(df['close'] > val_second)
    else: #short game
        mask_val_first = np.array(df['close'] > val_first)
        mask_val_second = np.array(df['close'] < val_second)

    
    if (mask_val_first.sum() == 0) & (mask_val_second.sum() == 0):

        ind_end = df.shape[0]-1
        delta_time = df['time'].iloc[ind_end] - df['time'].iloc[0]
        res_price = df['close'].iloc[ind_end]
        if val_first < val_second:
            income_rate = res_price/start_price
        else: #short game
            income_rate = (2*start_price-res_price)/start_price
        return 'DNF', delta_time, income_rate, res_price, ind_end+ind
        
    if (mask_val_first.sum() == 0) & (mask_val_second.sum() != 0):
        ind_val_second = np.argwhere(mask_val_second).ravel()[0]
        delta_time = df['time'].iloc[ind_val_second] - df['time'].iloc[0]
        res_price = df['close'].iloc[ind_val_second]
        if val_first < val_second:
            income_rate = res_price/start_price
        else: #short game
            income_rate = (2*start_price-res_price)/start_price
        return 'WIN', delta_time, income_rate, res_price, ind_val_second+ind
        
    if (mask_val_first.sum() != 0) & (mask_val_second.sum() == 0):
        ind_val_first = np.argwhere(mask_val_first).ravel()[0]
        delta_time = df['time'].iloc[ind_val_first] - df['time'].iloc[0]
        res_price = df['close'].iloc[ind_val_first]
        if val_first < val_second:
            income_rate = res_price/start_price
        else: #short game
            income_rate = (2*start_price-res_price)/start_price
        return 'LOSE', delta_time, income_rate, res_price, ind_val_first+ind

    if (mask_val_first.sum() != 0) & (mask_val_second.sum() != 0):
        ind_val_first = np.argwhere(mask_val_first).ravel()[0]
        ind_val_second = np.argwhere(mask_val_second).ravel()[0]
        if ind_val_first < ind_val_second:
            delta_time = df['time'].iloc[ind_val_first] - df['time'].iloc[0]
            res_price = df['close'].iloc[ind_val_first]
            if val_first < val_second:
                income_rate = res_price/start_price
            else: #short game
                income_rate = (2*start_price-res_price)/start_price
            return 'LOSE', delta_time, income_rate, res_price, ind_val_first+ind
        if ind_val_first > ind_val_second:
            delta_time = df['time'].iloc[ind_val_second] - df['time'].iloc[0]
            res_price = df['close'].iloc[ind_val_second]
            if val_first < val_second:
                income_rate = res_price/start_price
            else:  #short game
                income_rate = (2*start_price-res_price)/start_price
            return 'WIN', delta_time, income_rate, res_price, ind_val_second+ind


def get_df_target(df, indx, percent_first, percent_second, time_to_wait, time_tick):
    times = []
    results = []
    delta_times = []
    income_rates = []
    closes = []
    tickers = []
    res_prices = []
    res_inds = []
    
    for ind in indx:
    #for ind in tqdm(indx):
        time = df['time'].iloc[ind]
        close = df['close'].iloc[ind]
        ticker = df['ticker'].iloc[ind]
        
        val_first = df['close'].iloc[ind] * percent_first
        val_second = df['close'].iloc[ind] * percent_second
        result, delta_time, income_rate, res_price, res_ind = get_target(df, ind, val_first, val_second, time_to_wait, time_tick)
        
        times += [time]
        closes += [close]
        tickers += [ticker]
        results += [result]
        delta_times += [delta_time]
        income_rates += [income_rate]
        res_prices += [res_price]
        res_inds += [res_ind]
        

    df_result = pd.DataFrame({'ind' : indx,
                              'time' : times,
                              'close' : closes,
                              'result' : results,
                              'ticker' : tickers, 
                              'delta_time' : delta_times,
                              'income_rate' : income_rates,
                              'res_price' : res_prices,
                              'res_ind' : res_inds
                             })

    #макс выигрыш и потери
    if percent_first < percent_second:  
        df_result["income_rate"] = np.maximum(df_result["income_rate"], percent_first) #макс потери
        df_result["income_rate"] = np.minimum(df_result["income_rate"], percent_second) #макс выигрыш
    else:
        df_result["income_rate"] = np.maximum(df_result["income_rate"], 2-percent_first) #макс потери
        df_result["income_rate"] = np.minimum(df_result["income_rate"], 2-percent_second) #макс выигрыш
    
    df_result['income_rate'] -= 0.001
    
    return df_result

# %%
time_wait = pd.Timedelta(hours=3)
time_tick = pd.Timedelta(minutes=1)

df_result = []
for ticker in tqdm(stocks):
    df_target_ticker = load_pkl(f'./tmp/{ticker}.pkl')[['time', 'close', 'ticker']]
    
    mask_ticker = np.array(df['ticker'] == ticker)
    inds_ticker = df.loc[mask_ticker, 'index'].values
    assert (df.loc[mask_ticker, 'time'].values == df_target_ticker.loc[inds_ticker, 'time'].values).all(), 'Error_1'
    
    df_result_ticker = get_df_target(df_target_ticker, inds_ticker, percent_first=0.997, percent_second=1.015,\
                                     time_to_wait=time_wait, time_tick=time_tick)


    assert (df.loc[mask_ticker, 'time'].values == df_result_ticker['time'].values).all(), 'Error_2'
    
    df_result += [df_result_ticker.copy()]

df_result = pd.concat(df_result)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 76/76 [16:37<00:00, 13.12s/it]

# %%
df_result

# %%
dump_pkl(df_result, './data/feat_engin/lgbm/df_result_-0.3_+1.5_3hour.pkl')

# %%
df_result = load_pkl('./data/feat_engin/lgbm/df_result_-0.3_+1.5_3hour.pkl')
df_result
# Out:
#           ind                time        close result ticker      delta_time  \
# 0         409 2023-07-04 10:03:00   105.120003   LOSE   ABIO 0 days 00:02:00
# 1         411 2023-07-04 10:05:00   104.699997   LOSE   ABIO 0 days 00:01:00
# 2         417 2023-07-04 10:11:00   104.599998   LOSE   ABIO 0 days 00:23:00
# 3         427 2023-07-04 10:22:00   104.599998   LOSE   ABIO 0 days 00:12:00
# 4         436 2023-07-04 10:31:00   104.300003   LOSE   ABIO 0 days 00:03:00
# ...       ...                 ...          ...    ...    ...             ...
# 64190  321746 2025-02-24 23:11:00  4668.000000    DNF   YDEX 0 days 00:38:00
# 64191  321750 2025-02-24 23:15:00  4662.500000    DNF   YDEX 0 days 00:34:00
# 64192  321765 2025-02-24 23:30:00  4669.000000    DNF   YDEX 0 days 00:19:00
# 64193  321782 2025-02-24 23:47:00  4664.000000    DNF   YDEX 0 days 00:02:00
# 64194  321784 2025-02-24 23:49:00  4671.000000    DNF   YDEX 0 days 00:00:00
#
#        income_rate    res_price  res_ind
# 0         0.996000   104.699997      411
# 1         0.996000   104.180000      412
# 2         0.996000   103.500000      439
# 3         0.996000   103.500000      439
# 4         0.996000   103.500000      439
# ...            ...          ...      ...
# 64190     0.999643  4671.000000   321784
# 64191     1.000823  4671.000000   321784
# 64192     0.999428  4671.000000   321784
# 64193     1.000501  4671.000000   321784
# 64194     0.999000  4671.000000   321784
#
# [4436580 rows x 9 columns]

# %%
hour_wait = 3
mask_time = np.array((datetime.time(12, 0) <= df['time'].dt.time) & (df['time'].dt.time < datetime.time(23-hour_wait, 30)))
mask_time.mean(), mask_time.sum()
# Out:
# (0.6321387194640917, 2804534)

# %%
df_result.loc[mask_time, 'result'].value_counts(normalize=True)
# Out:
# result
# LOSE    0.566035
# DNF     0.376515
# WIN     0.057450
# Name: proportion, dtype: float64

# %%
# df_result_-0.5_+2_4hour.pkl
# result
# DNF     0.493912
# LOSE    0.455227
# WIN     0.050861
# Name: proportion, dtype: float64

# df_result_-0.5_+1.3_4hour.pkl
# result
# DNF     0.439086
# LOSE    0.448482
# WIN     0.112432
# Name: proportion, dtype: float64

# df_result_-0.5_+1.3_2hour.pkl
# result
# DNF     0.618353
# LOSE    0.317999
# WIN     0.063647
# Name: proportion, dtype: float64

# df_result_-1_+1.3_4hour.pkl
# result
# DNF     0.648653
# LOSE    0.218750
# WIN     0.132597
# Name: proportion, dtype: float64

# %%
df_result.loc[mask_time, 'income_rate'].quantile(q=[0, 0.01]+np.arange(0.1, 1, 0.1).tolist()+[0.99, 1])
# Out:
# 0.00    0.996000
# 0.01    0.996000
# 0.10    0.996000
# 0.20    0.996000
# 0.30    0.996000
# 0.40    0.996000
# 0.50    0.996000
# 0.60    0.997862
# 0.70    0.999780
# 0.80    1.001956
# 0.90    1.006214
# 0.99    1.014000
# 1.00    1.014000
# Name: income_rate, dtype: float64

# %%
#распределение времени в часах
(df_result.loc[mask_time, 'delta_time']/ pd.Timedelta('1 hour')).quantile(q=[0, 0.01]+np.arange(0.1, 1, 0.1).tolist()+[0.99, 1])
# Out:
# 0.00    0.000000
# 0.01    0.016667
# 0.10    0.133333
# 0.20    0.300000
# 0.30    0.533333
# 0.40    0.883333
# 0.50    1.416667
# 0.60    2.333333
# 0.70    3.000000
# 0.80    3.000000
# 0.90    3.000000
# 0.99    3.000000
# 1.00    3.000000
# Name: delta_time, dtype: float64

# %%
(df['index'].values == df_result['ind'].values).all(), (df['close'].values == df_result['close'].values).all(), (df['time'].values == df_result['time'].values).all()
# Out:
# (True, True, True)

# %%
df_result.head()
# Out:
#    ind                time       close result ticker      delta_time  \
# 0  409 2023-07-04 10:03:00  105.120003   LOSE   ABIO 0 days 00:02:00
# 1  411 2023-07-04 10:05:00  104.699997   LOSE   ABIO 0 days 00:01:00
# 2  417 2023-07-04 10:11:00  104.599998   LOSE   ABIO 0 days 00:23:00
# 3  427 2023-07-04 10:22:00  104.599998   LOSE   ABIO 0 days 00:12:00
# 4  436 2023-07-04 10:31:00  104.300003   LOSE   ABIO 0 days 00:03:00
#
#    income_rate   res_price  res_ind
# 0        0.996  104.699997      411
# 1        0.996  104.180000      412
# 2        0.996  103.500000      439
# 3        0.996  103.500000      439
# 4        0.996  103.500000      439

# %%
df.head()
# Out:
#    index                time       close  volume ticker  tmos_close  \
# 0    409 2023-07-04 10:03:00  105.120003   498.0   ABIO        5.52
# 1    411 2023-07-04 10:05:00  104.699997   864.0   ABIO        5.51
# 2    417 2023-07-04 10:11:00  104.599998   438.0   ABIO        5.50
# 3    427 2023-07-04 10:22:00  104.599998    24.0   ABIO        5.50
# 4    436 2023-07-04 10:31:00  104.300003   336.0   ABIO        5.49
#
#    close_w1_roc  volume_w1_roc  tmos_close_w1_roc  close_w5_norm_std  \
# 0     -0.000760       0.099338           0.000000           0.002112
# 1     -0.002667      -0.711712          -0.001812           0.002266
# 2     -0.004568       1.354839          -0.001815           0.003970
# 3      0.000000       7.000000           0.000000           0.000331
# 4     -0.001340      -0.404255          -0.001818           0.001112
#
#    close_w5_mean_abs_pct  close_w5_alpha  close_w5_rsi  close_w5_roc  \
# 0               0.002241       -6.568335     50.847645      0.000190
# 1               0.001218       -6.439630      0.000000     -0.006076
# 2               0.002946        2.816486     63.636227      0.004031
# 3               0.000306        4.165777     50.000000      0.000000
# 4               0.001570       -3.338176     31.707590     -0.002868
#
#    volume_w5_norm_std  volume_w5_mean_abs_pct  volume_w5_alpha  volume_w5_rsi  \
# 0            0.724442                9.541154        -0.002155      59.166668
# 1            1.212911                4.931128         0.000767      53.308231
# 2            0.970556                1.585749        -0.000490      45.918934
# 3            1.067696                1.914954        -0.024363      10.191083
# 4            0.705060                5.428173        -0.002473      55.769230
#
#    volume_w5_roc  tmos_close_w5_norm_std  tmos_close_w5_mean_abs_pct  \
# 0      12.833333                0.000991                    0.000362
# 1       0.745455                0.001281                    0.000724
# 2      -0.501706                0.000995                    0.001090
# 3      -0.939850                0.000995                    0.001090
# 4       6.000000                0.000813                    0.000364
#
#    tmos_close_w5_alpha  tmos_close_w5_rsi  tmos_close_w5_roc  \
# 0        -2.499943e+02           0.000000          -0.001808
# 1        -2.000002e+02           0.000000          -0.003617
# 2        -4.053869e-14          33.333332          -0.001815
# 3        -8.333143e+01          33.333332          -0.001815
# 4        -2.499943e+02           0.000000          -0.001818
#
#    close_w10_norm_std  close_w10_mean_abs_pct  close_w10_alpha  close_w10_rsi  \
# 0            0.001840                0.001139         4.893894      50.000000
# 1            0.002470                0.001520        -4.825096      37.499939
# 2            0.004054                0.002559        -2.757288      36.567181
# 3            0.000755                0.000651        12.107415      50.000000
# 4            0.001461                0.001091       -15.193442      36.842213
#
#    close_w10_roc  volume_w10_norm_std  volume_w10_mean_abs_pct  \
# 0       0.000000             0.899397                 7.236273
# 1      -0.003806             1.315785                 5.697942
# 2      -0.006836             0.896560                 3.165023
# 3       0.000000             1.661298                14.560894
# 4      -0.002868             1.186850                 5.683180
#
#    volume_w10_alpha  volume_w10_rsi  volume_w10_roc  tmos_close_w10_norm_std  \
# 0          0.000923       56.086632       54.333332                 0.000874
# 1          0.001827       50.739475        0.156627                 0.001280
# 2         -0.000097       51.966934       17.250000                 0.001339
# 3         -0.005644       42.123287       -0.945205                 0.000957
# 4          0.004593       55.799374      111.000000                 0.001150
#
#    tmos_close_w10_mean_abs_pct  tmos_close_w10_alpha  tmos_close_w10_rsi  \
# 0                     0.000543           -166.662857           33.333332
# 1                     0.000362           -366.665161            0.000000
# 2                     0.000907           -316.325684           20.000191
# 3                     0.001090            -99.997711           50.000000
# 4                     0.000545           -333.325714           33.333332
#
#    tmos_close_w10_roc  close_w20_norm_std  close_w20_mean_abs_pct  \
# 0           -0.001808            0.001466                0.000751
# 1           -0.003617            0.001776                0.000931
# 2           -0.005425            0.004007                0.001802
# 3            0.000000            0.002887                0.001605
# 4           -0.001818            0.001144                0.001099
#
#    close_w20_alpha  close_w20_rsi  close_w20_roc  volume_w20_norm_std  \
# 0        17.983786      50.633041       0.000190             1.175322
# 1         2.717369      38.775574      -0.004185             1.471711
# 2        -8.077396      44.444489      -0.003999             1.197766
# 3        -5.243742      39.285748      -0.006836             1.313707
# 4       -16.513590      33.043526      -0.007423             1.252311
#
#    volume_w20_mean_abs_pct  volume_w20_alpha  volume_w20_rsi  volume_w20_roc  \
# 0                12.766082          0.006964       53.558395       15.600000
# 1                13.007571          0.004115       53.850281      287.000000
# 2                 4.389439          0.003040       48.778519       -0.453184
# 3                 8.862958         -0.003579       50.000000        0.000000
# 4                 9.839779         -0.000840       51.308899        0.806452
#
#    tmos_close_w20_norm_std  ...  close_w60_ma_up_2std/close  \
# 0                 0.000851  ...                    1.004836
# 1                 0.001095  ...                    1.008814
# 2                 0.001902  ...                    1.011160
# 3                 0.001263  ...                    1.010424
# 4                 0.001067  ...                    1.012119
#
#    close_w60_ma_low_3std/close  close_w60_ma_up_3std/close  \
# 0                     0.995941                    1.006615
# 1                     0.999467                    1.010683
# 2                     0.996270                    1.014138
# 3                     0.993997                    1.013709
# 4                     0.995683                    1.015406
#
#    volume_w60_ma_low_2std/volume  volume_w60_ma_up_2std/volume  \
# 0                      -0.696165                      1.578896
# 1                      -0.750207                      1.381920
# 2                      -1.906004                      3.496187
# 3                     -35.372337                     63.789005
# 4                      -2.495768                      4.645173
#
#    volume_w60_ma_low_3std/volume  volume_w60_ma_up_3std/volume  \
# 0                      -1.264930                      2.147661
# 1                      -1.283238                      1.914951
# 2                      -3.256552                      4.846735
# 3                     -60.162674                     88.579338
# 4                      -4.281003                      6.430408
#
#    tmos_close_w60_ma_low_2std/tmos_close  \
# 0                               0.999652
# 1                               1.001226
# 2                               1.001636
# 3                               0.999925
# 4                               1.000486
#
#    tmos_close_w60_ma_up_2std/tmos_close  \
# 0                              1.002945
# 1                              1.004884
# 2                              1.007394
# 3                              1.007651
# 4                              1.009472
#
#    tmos_close_w60_ma_low_3std/tmos_close  \
# 0                               0.998829
# 1                               1.000311
# 2                               1.000197
# 3                               0.997993
# 4                               0.998240
#
#    tmos_close_w60_ma_up_3std/tmos_close  close_w120_ma_low_2std/close  \
# 0                              1.003768                      0.998386
# 1                              1.005799                      1.002103
# 2                              1.008834                      1.001076
# 3                              1.009582                      0.999388
# 4                              1.011718                      1.000845
#
#    close_w120_ma_up_2std/close  close_w120_ma_low_3std/close  \
# 0                     1.005423                      0.996626
# 1                     1.009543                      1.000244
# 2                     1.011741                      0.998409
# 3                     1.012406                      0.996134
# 4                     1.015493                      0.997183
#
#    close_w120_ma_up_3std/close  volume_w120_ma_low_2std/volume  \
# 0                     1.007182                       -1.382318
# 1                     1.011402                       -0.927374
# 2                     1.014408                       -2.012220
# 3                     1.015661                      -36.485645
# 4                     1.019155                       -2.565924
#
#    volume_w120_ma_up_2std/volume  volume_w120_ma_low_3std/volume  \
# 0                       2.175189                       -2.271694
# 1                       1.454457                       -1.522832
# 2                       3.185165                       -3.311566
# 3                      59.058559                      -60.371693
# 4                       4.283483                       -4.278275
#
#    volume_w120_ma_up_3std/volume  tmos_close_w120_ma_low_2std/tmos_close  \
# 0                       3.064566                                0.999783
# 1                       2.049915                                1.001436
# 2                       4.484511                                1.002392
# 3                      82.944611                                1.001236
# 4                       5.995835                                1.002060
#
#    tmos_close_w120_ma_up_2std/tmos_close  \
# 0                               1.002934
# 1                               1.004825
# 2                               1.007123
# 3                               1.007612
# 4                               1.009719
#
#    tmos_close_w120_ma_low_3std/tmos_close  \
# 0                                0.998995
# 1                                1.000589
# 2                                1.001209
# 3                                0.999642
# 4                                1.000146
#
#    tmos_close_w120_ma_up_3std/tmos_close  close_w5_min/close_w5_max  \
# 0                               1.003722                   0.994513
# 1                               1.005672                   0.994113
# 2                               1.008306                   0.990674
# 3                               1.009206                   0.999235
# 4                               1.011633                   0.997132
#
#    volume_w5_min/volume_w5_max  tmos_close_w5_min/tmos_close_w5_max  \
# 0                     0.022792                             0.998192
# 1                     0.008008                             0.996383
# 2                     0.069429                             0.998185
# 3                     0.027778                             0.998185
# 4                     0.078864                             0.998182
#
#    close_w10_min/close_w10_max  volume_w10_min/volume_w10_max  \
# 0                     0.994324                       0.011396
# 1                     0.990539                       0.004004
# 2                     0.989544                       0.062062
# 3                     0.997516                       0.002725
# 4                     0.995799                       0.003155
#
#    tmos_close_w10_min/tmos_close_w10_max  close_w20_min/close_w20_max  \
# 0                               0.998192                     0.993567
# 1                               0.996383                     0.990539
# 2                               0.996377                     0.984863
# 3                               0.998185                     0.989544
# 4                               0.996370                     0.995799
#
#    volume_w20_min/volume_w20_max  tmos_close_w20_min/tmos_close_w20_max  \
# 0                       0.002849                               0.998192
# 1                       0.003003                               0.996383
# 2                       0.003003                               0.994575
# 3                       0.001001                               0.996377
# 4                       0.002725                               0.996370
#
#    close_w30_min/close_w30_max  volume_w30_min/volume_w30_max  \
# 0                     0.993567                       0.002849
# 1                     0.990539                       0.001001
# 2                     0.984863                       0.001001
# 3                     0.984863                       0.001001
# 4                     0.988416                       0.001001
#
#    tmos_close_w30_min/tmos_close_w30_max  close_w60_min/close_w60_max  \
# 0                               0.998192                     0.993567
# 1                               0.996383                     0.990539
# 2                               0.994575                     0.984863
# 3                               0.994575                     0.984863
# 4                               0.992767                     0.984863
#
#    volume_w60_min/volume_w60_max  tmos_close_w60_min/tmos_close_w60_max  \
# 0                       0.002469                               0.998192
# 1                       0.001001                               0.996383
# 2                       0.001001                               0.994575
# 3                       0.001001                               0.994575
# 4                       0.001001                               0.992767
#
#    close_w120_min/close_w120_max  volume_w120_min/volume_w120_max  \
# 0                       0.993567                         0.000755
# 1                       0.990539                         0.000755
# 2                       0.984863                         0.000755
# 3                       0.984863                         0.000755
# 4                       0.984863                         0.000755
#
#    tmos_close_w120_min/tmos_close_w120_max  ind  result      delta_time  \
# 0                                 0.998192  409    LOSE 0 days 00:03:00
# 1                                 0.996383  411    LOSE 0 days 00:02:00
# 2                                 0.994575  417    LOSE 0 days 00:23:00
# 3                                 0.994575  427    LOSE 0 days 00:12:00
# 4                                 0.992767  436    LOSE 0 days 00:03:00
#
#    income_rate   res_price  res_ind  target  ticker_code  y_pred
# 0        0.994      104.18      412       0            0    None
# 1        0.994  104.120003      413       0            0    None
# 2        0.994       103.5      439       0            0    None
# 3        0.994       103.5      439       0            0    None
# 4        0.994       103.5      439       0            0    None
#
# [5 rows x 709 columns]

# %%
df[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']] = df_result[['ind', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']].values

# %%
df
# Out:
#           index                time        close  volume ticker  tmos_close  \
# 0           409 2023-07-04 10:03:00   105.120003   498.0   ABIO        5.52
# 1           411 2023-07-04 10:05:00   104.699997   864.0   ABIO        5.51
# 2           417 2023-07-04 10:11:00   104.599998   438.0   ABIO        5.50
# 3           427 2023-07-04 10:22:00   104.599998    24.0   ABIO        5.50
# 4           436 2023-07-04 10:31:00   104.300003   336.0   ABIO        5.49
# ...         ...                 ...          ...     ...    ...         ...
# 4436575  321746 2025-02-24 23:11:00  4668.000000    58.0   YDEX        7.29
# 4436576  321750 2025-02-24 23:15:00  4662.500000   251.0   YDEX        7.30
# 4436577  321765 2025-02-24 23:30:00  4669.000000   107.0   YDEX        7.31
# 4436578  321782 2025-02-24 23:47:00  4664.000000   559.0   YDEX        7.33
# 4436579  321784 2025-02-24 23:49:00  4671.000000   951.0   YDEX        7.33
#
#          close_w1_roc  volume_w1_roc  tmos_close_w1_roc  close_w5_norm_std  \
# 0           -0.000760       0.099338           0.000000           0.002112
# 1           -0.002667      -0.711712          -0.001812           0.002266
# 2           -0.004568       1.354839          -0.001815           0.003970
# 3            0.000000       7.000000           0.000000           0.000331
# 4           -0.001340      -0.404255          -0.001818           0.001112
# ...               ...            ...                ...                ...
# 4436575      0.000321      -0.576642           0.001374           0.000287
# 4436576     -0.000536       0.845588           0.001372           0.000435
# 4436577      0.000107      -0.339506           0.001370           0.000096
# 4436578      0.000000       0.757862           0.000000           0.000565
# 4436579      0.001716      12.985294           0.001366           0.000701
#
#          close_w5_mean_abs_pct  close_w5_alpha  close_w5_rsi  close_w5_roc  \
# 0                     0.002241       -6.568335     50.847645      0.000190
# 1                     0.001218       -6.439630      0.000000     -0.006076
# 2                     0.002946        2.816486     63.636227      0.004031
# 3                     0.000306        4.165777     50.000000      0.000000
# 4                     0.001570       -3.338176     31.707590     -0.002868
# ...                        ...             ...           ...           ...
# 4436575               0.000343        0.069444     56.250000      0.000214
# 4436576               0.000300       -0.757576     21.428572     -0.000857
# 4436577               0.000107        1.875000     60.000000      0.000107
# 4436578               0.000257       -0.449640      0.000000     -0.001285
# 4436579               0.000407        0.303738     84.210526      0.001394
#
#          volume_w5_norm_std  volume_w5_mean_abs_pct  volume_w5_alpha  \
# 0                  0.724442                9.541154        -0.002155
# 1                  1.212911                4.931128         0.000767
# 2                  0.970556                1.585749        -0.000490
# 3                  1.067696                1.914954        -0.024363
# 4                  0.705060                5.428173        -0.002473
# ...                     ...                     ...              ...
# 4436575            1.077206                1.974295        -0.000951
# 4436576            0.887187                2.204243         0.013296
# 4436577            0.687663                2.115913         0.005946
# 4436578            0.492031                0.815577         0.002580
# 4436579            0.758640                3.040115         0.002329
#
#          volume_w5_rsi  volume_w5_roc  tmos_close_w5_norm_std  \
# 0            59.166668      12.833333                0.000991
# 1            53.308231       0.745455                0.001281
# 2            45.918934      -0.501706                0.000995
# 3            10.191083      -0.939850                0.000995
# 4            55.769230       6.000000                0.000813
# ...                ...            ...                     ...
# 4436575      48.713909      -0.457944                0.001228
# 4436576      65.322578       0.832117                0.000613
# 4436577      51.254478       0.150538                0.000612
# 4436578      67.511314       2.250000                0.000610
# 4436579      57.200401       0.430075                0.000610
#
#          tmos_close_w5_mean_abs_pct  tmos_close_w5_alpha  tmos_close_w5_rsi  \
# 0                          0.000362        -2.499943e+02           0.000000
# 1                          0.000724        -2.000002e+02           0.000000
# 2                          0.001090        -4.053869e-14          33.333332
# 3                          0.001090        -8.333143e+01          33.333332
# 4                          0.000364        -2.499943e+02           0.000000
# ...                             ...                  ...                ...
# 4436575                    0.001374         9.375140e+01          59.999809
# 4436576                    0.000549         2.499943e+02         100.000000
# 4436577                    0.000822        -1.250031e+02          66.666664
# 4436578                    0.000273         2.500062e+02         100.000000
# 4436579                    0.000546        -1.250031e+02          50.000000
#
#          tmos_close_w5_roc  close_w10_norm_std  close_w10_mean_abs_pct  \
# 0                -0.001808            0.001840                0.001139
# 1                -0.003617            0.002470                0.001520
# 2                -0.001815            0.004054                0.002559
# 3                -0.001815            0.000755                0.000651
# 4                -0.001818            0.001461                0.001091
# ...                    ...                 ...                     ...
# 4436575           0.001374            0.000565                0.000354
# 4436576           0.002747            0.000431                0.000289
# 4436577           0.001370            0.000208                0.000268
# 4436578           0.001366            0.000589                0.000225
# 4436579           0.000000            0.000701                0.000343
#
#          close_w10_alpha  close_w10_rsi  close_w10_roc  volume_w10_norm_std  \
# 0               4.893894      50.000000       0.000000             0.899397
# 1              -4.825096      37.499939      -0.003806             1.315785
# 2              -2.757288      36.567181      -0.006836             0.896560
# 3              12.107415      50.000000       0.000000             1.661298
# 4             -15.193442      36.842213      -0.002868             1.186850
# ...                  ...            ...            ...                  ...
# 4436575         0.907637      66.666664       0.001180             2.596400
# 4436576        -1.043956      33.333332      -0.000964             1.337235
# 4436577         1.085044      64.000000       0.000750             0.901055
# 4436578        -0.792952      23.809525      -0.001178             0.640026
# 4436579        -0.413094      56.250000       0.000428             0.794408
#
#          volume_w10_mean_abs_pct  volume_w10_alpha  volume_w10_rsi  \
# 0                       7.236273          0.000923       56.086632
# 1                       5.697942          0.001827       50.739475
# 2                       3.165023         -0.000097       51.966934
# 3                      14.560894         -0.005644       42.123287
# 4                       5.683180          0.004593       55.799374
# ...                          ...               ...             ...
# 4436575                47.691620         -0.000099       47.025002
# 4436576                 2.130902         -0.002362        6.757849
# 4436577                 1.523224         -0.009697       34.232559
# 4436578                 0.606927          0.005613       51.495602
# 4436579                 1.904694          0.005882       66.564415
#
#          volume_w10_roc  tmos_close_w10_norm_std  tmos_close_w10_mean_abs_pct  \
# 0             54.333332                 0.000874                     0.000543
# 1              0.156627                 0.001280                     0.000362
# 2             17.250000                 0.001339                     0.000907
# 3             -0.945205                 0.000957                     0.001090
# 4            111.000000                 0.001150                     0.000545
# ...                 ...                      ...                          ...
# 4436575       -0.972872                 0.000960                     0.001099
# 4436576       -0.983527                 0.001130                     0.000824
# 4436577       -0.863694                 0.000661                     0.000821
# 4436578        0.100394                 0.000922                     0.000410
# 4436579        9.931034                 0.000955                     0.000683
#
#          tmos_close_w10_alpha  tmos_close_w10_rsi  tmos_close_w10_roc  \
# 0                 -166.662857           33.333332           -0.001808
# 1                 -366.665161            0.000000           -0.003617
# 2                 -316.325684           20.000191           -0.005425
# 3                  -99.997711           50.000000            0.000000
# 4                 -333.325714           33.333332           -0.001818
# ...                       ...                 ...                 ...
# 4436575             45.453751           50.000000            0.000000
# 4436576            270.492065           66.666664            0.002747
# 4436577             71.430344           50.000000            0.000000
# 4436578            353.659515           66.666138            0.001366
# 4436579            295.457794           59.999809            0.001366
#
#          close_w20_norm_std  close_w20_mean_abs_pct  close_w20_alpha  \
# 0                  0.001466                0.000751        17.983786
# 1                  0.001776                0.000931         2.717369
# 2                  0.004007                0.001802        -8.077396
# 3                  0.002887                0.001605        -5.243742
# 4                  0.001144                0.001099       -16.513590
# ...                     ...                     ...              ...
# 4436575            0.000477                0.000300         1.520468
# 4436576            0.000463                0.000311         0.638418
# 4436577            0.000394                0.000305         2.037325
# 4436578            0.000454                0.000246        -1.408451
# 4436579            0.000529                0.000337        -0.942318
#
#          close_w20_rsi  close_w20_roc  volume_w20_norm_std  \
# 0            50.633041       0.000190             1.175322
# 1            38.775574      -0.004185             1.471711
# 2            44.444489      -0.003999             1.197766
# 3            39.285748      -0.006836             1.313707
# 4            33.043526      -0.007423             1.252311
# ...                ...            ...                  ...
# 4436575      58.928570       0.001072             2.920815
# 4436576      43.103447      -0.000857             2.974819
# 4436577      54.385963       0.000536             1.298146
# 4436578      39.130436      -0.001071             0.702192
# 4436579      53.968254       0.000536             0.766041
#
#          volume_w20_mean_abs_pct  volume_w20_alpha  volume_w20_rsi  \
# 0                      12.766082          0.006964       53.558395
# 1                      13.007571          0.004115       53.850281
# 2                       4.389439          0.003040       48.778519
# 3                       8.862958         -0.003579       50.000000
# 4                       9.839779         -0.000840       51.308899
# ...                          ...               ...             ...
# 4436575                26.307011          0.000268       49.637791
# 4436576                25.043882         -0.000099       49.463375
# 4436577                 1.951538         -0.000301       49.653580
# 4436578                 0.852316          0.013123       55.522297
# 4436579                 1.323281          0.009080       58.899166
#
#          volume_w20_roc  tmos_close_w20_norm_std  ...  \
# 0             15.600000                 0.000851  ...
# 1            287.000000                 0.001095  ...
# 2             -0.453184                 0.001902  ...
# 3              0.000000                 0.001263  ...
# 4              0.806452                 0.001067  ...
# ...                 ...                      ...  ...
# 4436575       -0.830409                 0.001023  ...
# 4436576       -0.620846                 0.000921  ...
# 4436577       -0.218978                 0.001051  ...
# 4436578        1.942105                 0.001262  ...
# 4436579        4.870370                 0.001164  ...
#
#          close_w60_ma_up_2std/close  close_w60_ma_low_3std/close  \
# 0                          1.004836                     0.995941
# 1                          1.008814                     0.999467
# 2                          1.011160                     0.996270
# 3                          1.010424                     0.993997
# 4                          1.012119                     0.995683
# ...                             ...                          ...
# 4436575                    0.999901                     0.997256
# 4436576                    1.001160                     0.998439
# 4436577                    1.000294                     0.997199
# 4436578                    1.001529                     0.998998
# 4436579                    1.000075                     0.997493
#
#          close_w60_ma_up_3std/close  volume_w60_ma_low_2std/volume  \
# 0                          1.006615                      -0.696165
# 1                          1.010683                      -0.750207
# 2                          1.014138                      -1.906004
# 3                          1.013709                     -35.372337
# 4                          1.015406                      -2.495768
# ...                             ...                            ...
# 4436575                    1.000430                     -59.079967
# 4436576                    1.001704                     -13.664067
# 4436577                    1.000913                     -31.987665
# 4436578                    1.002035                      -6.014614
# 4436579                    1.000591                      -3.520538
#
#          volume_w60_ma_up_2std/volume  volume_w60_ma_low_3std/volume  \
# 0                            1.578896                      -1.264930
# 1                            1.381920                      -1.283238
# 2                            3.496187                      -3.256552
# 3                           63.789005                     -60.162674
# 4                            4.645173                      -4.281003
# ...                               ...                            ...
# 4436575                     77.451813                     -93.212914
# 4436576                     17.892487                     -21.553207
# 4436577                     41.542496                     -50.370205
# 4436578                      8.012825                      -9.521473
# 4436579                      4.724008                      -5.581674
#
#          volume_w60_ma_up_3std/volume  tmos_close_w60_ma_low_2std/tmos_close  \
# 0                            2.147661                               0.999652
# 1                            1.914951                               1.001226
# 2                            4.846735                               1.001636
# 3                           88.579338                               0.999925
# 4                            6.430408                               1.000486
#          close_w30_min/close_w30_max  volume_w30_min/volume_w30_max  \
# 0                           0.993567                       0.002849
# 1                           0.990539                       0.001001
# 2                           0.984863                       0.001001
# 3                           0.984863                       0.001001
# 4                           0.988416                       0.001001
# ...                              ...                            ...
# 4436575                     0.998073                       0.000788
# 4436576                     0.998180                       0.000788
# 4436577                     0.998180                       0.000919
# 4436578                     0.998715                       0.024860
# 4436579                     0.998287                       0.032597
#
#          tmos_close_w30_min/tmos_close_w30_max  close_w60_min/close_w60_max  \
# 0                                     0.998192                     0.993567
# 1                                     0.996383                     0.990539
# 2                                     0.994575                     0.984863
# 3                                     0.994575                     0.984863
# 4                                     0.992767                     0.984863
# ...                                        ...                          ...
# 4436575                               0.997257                     0.997859
# 4436576                               0.995890                     0.997859
# 4436577                               0.994528                     0.997859
# 4436578                               0.995907                     0.998180
# 4436579                               0.995907                     0.997966
#
#          volume_w60_min/volume_w60_max  tmos_close_w60_min/tmos_close_w60_max  \
# 0                             0.002469                               0.998192
# 1                             0.001001                               0.996383
# 2                             0.001001                               0.994575
# 3                             0.001001                               0.994575
# 4                             0.001001                               0.992767
# ...                                ...                                    ...
# 4436575                       0.000197                               0.995885
# 4436576                       0.000197                               0.994521
# 4436577                       0.000197                               0.994528
# 4436578                       0.000919                               0.991814
# 4436579                       0.000919                               0.991814
#
#          close_w120_min/close_w120_max  volume_w120_min/volume_w120_max  \
# 0                             0.993567                         0.000755
# 1                             0.990539                         0.000755
# 2                             0.984863                         0.000755
# 3                             0.984863                         0.000755
# 4                             0.984863                         0.000755
# ...                                ...                              ...
# 4436575                       0.995717                         0.000197
# 4436576                       0.997002                         0.000197
# 4436577                       0.997859                         0.000197
# 4436578                       0.997859                         0.000197
# 4436579                       0.997645                         0.000197
#
#          tmos_close_w120_min/tmos_close_w120_max     ind  result  \
# 0                                       0.998192     409    LOSE
# 1                                       0.996383     411    LOSE
# 2                                       0.994575     417    LOSE
# 3                                       0.994575     427    LOSE
# 4                                       0.992767     436    LOSE
# ...                                          ...     ...     ...
# 4436575                                 0.994521  321746     DNF
# 4436576                                 0.994521  321750     DNF
# 4436577                                 0.993160  321765     DNF
# 4436578                                 0.990450  321782     DNF
# 4436579                                 0.990450  321784     DNF
#
#              delta_time  income_rate   res_price  res_ind  target  \
# 0       0 days 00:02:00        0.996  104.699997      411       0
# 1       0 days 00:01:00        0.996      104.18      412       0
# 2       0 days 00:23:00        0.996       103.5      439       0
# 3       0 days 00:12:00        0.996       103.5      439       0
# 4       0 days 00:03:00        0.996       103.5      439       0
# ...                 ...          ...         ...      ...     ...
# 4436575 0 days 00:38:00     0.999643      4671.0   321784       0
# 4436576 0 days 00:34:00     1.000823      4671.0   321784       0
# 4436577 0 days 00:19:00     0.999428      4671.0   321784       0
# 4436578 0 days 00:02:00     1.000501      4671.0   321784       0
# 4436579 0 days 00:00:00        0.999      4671.0   321784       0
#
#          ticker_code  y_pred
# 0                  0    None
# 1                  0    None
# 2                  0    None
# 3                  0    None
# 4                  0    None
# ...              ...     ...
# 4436575           75    None
# 4436576           75    None
# 4436577           75    None
# 4436578           75    None
# 4436579           75    None
#
# [4436580 rows x 709 columns]

# %%
assert (df['index'] == df['ind']).all(), 'Error'

# %%
#проверить данные

mask = df['time'] >= pd.Timestamp('2025-02-01')


i = 3730
cols = ['ticker', 'time', 'close', 'result', 'delta_time', 'income_rate', 'res_price', 'res_ind']
df.loc[mask&mask_time, cols].iloc[i:i+10]
# Out:
#        ticker                time      close result      delta_time  \
# 173250   AFLT 2025-02-18 12:15:00  72.330002    WIN 0 days 00:53:00
# 173251   AFLT 2025-02-18 12:17:00  72.639999   LOSE 0 days 00:03:00
# 173252   AFLT 2025-02-18 12:29:00  72.309998    WIN 0 days 00:39:00
# 173253   AFLT 2025-02-18 12:30:00  72.309998    WIN 0 days 00:38:00
# 173254   AFLT 2025-02-18 12:31:00  72.339996    WIN 0 days 02:27:00
# 173255   AFLT 2025-02-18 12:32:00  72.389999    WIN 0 days 02:26:00
# 173256   AFLT 2025-02-18 12:48:00  73.190002   LOSE 0 days 00:06:00
# 173257   AFLT 2025-02-18 12:52:00  73.000000   LOSE 0 days 00:05:00
# 173258   AFLT 2025-02-18 12:53:00  73.080002   LOSE 0 days 00:01:00
# 173259   AFLT 2025-02-18 12:54:00  72.830002    WIN 0 days 02:06:00
#
#        income_rate  res_price res_ind
# 173250       1.014  73.419998  337566
# 173251       0.996  72.419998  337518
# 173252       1.014  73.419998  337566
# 173253       1.014  73.419998  337566
# 173254       1.014  73.639999  337676
# 173255       1.014  73.639999  337676
# 173256       0.996  72.830002  337552
# 173257       0.996  72.720001  337555
# 173258       0.996  72.830002  337552
# 173259       1.014  74.269997  337678

# %% [markdown]
# ### 1. train/valid/test/test2 split

# %%
df['target'] = (df['result'] == 'WIN').astype(int)

# %%
df.loc[mask_time, ['time', 'target']].groupby(pd.Grouper(key='time', freq='ME')).target.mean().plot.bar()
# Out:
# <Axes: xlabel='time'>

# %%
(df.loc[mask_time, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq='ME')).income_rate.mean()-1).plot.bar()
# Out:
# <Axes: xlabel='time'>

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_time, ['ticker', 'target']].groupby('ticker').target.mean().sort_values()
# Out:
# ticker
# SBERP    0.014935
# SBER     0.017029
# LKOH     0.020053
# IRAO     0.020803
# MTSS     0.024734
# TATNP    0.024851
# ROSN     0.025678
# TATN     0.026644
# PHOR     0.029179
# PLZL     0.029267
# NVTK     0.033395
# TRNFP    0.034996
# GAZP     0.035483
# SIBN     0.037374
# HYDR     0.037498
# SNGSP    0.038217
# MAGN     0.039137
# BELU     0.039382
# GMKN     0.039817
# MOEX     0.041657
# CHMF     0.042347
# VTBR     0.042712
# T        0.043004
# ALRS     0.043690
# AQUA     0.044557
# RTKMP    0.046452
# POSI     0.047427
# SNGS     0.047802
# UPRO     0.048513
# MGNT     0.048833
# BSPB     0.048956
# YDEX     0.049477
# NLMK     0.051541
# RTKM     0.053693
# RUAL     0.053848
# BANEP    0.054931
# VKCO     0.055025
# OGKB     0.055789
# FLOT     0.056639
# AFLT     0.058952
# ENPG     0.060368
# MDMG     0.063234
# CBOM     0.063627
# WUSH     0.064524
# SMLT     0.065241
# FEES     0.066104
# SGZH     0.067635
# TRMK     0.068273
# APTK     0.070709
# KMAZ     0.071907
# BANE     0.072261
# VSMO     0.072510
# RASP     0.073412
# MVID     0.073475
# SELG     0.073791
# AFKS     0.074512
# ABIO     0.076083
# NMTP     0.076475
# LSRG     0.076962
# SVAV     0.077869
# PIKK     0.079250
# LIFE     0.081782
# RNFT     0.086537
# LENT     0.087410
# MTLR     0.089184
# SPBE     0.089440
# SFIN     0.091530
# HEAD     0.091774
# MTLRP    0.093765
# UNAC     0.095089
# UWGN     0.095593
# RENI     0.096539
# FESH     0.096844
# IRKT     0.104310
# TGKN     0.118989
# GTRK     0.125328
# Name: target, dtype: float64

# %%
df.loc[mask_time, ['ticker', 'income_rate']].groupby('ticker').income_rate.mean().sort_values()
# Out:
# ticker
# APTK     0.998572
# SPBE     0.998719
# VKCO     0.998732
# LIFE     0.998746
# UWGN     0.998769
# ABIO     0.998806
# IRKT     0.998851
# SVAV     0.998854
# AQUA     0.998857
# UNAC     0.998865
# WUSH     0.998895
# BELU     0.998949
# VSMO     0.998955
# RTKMP    0.998957
# VTBR     0.998961
# UPRO     0.998972
# SGZH     0.998991
# SNGS     0.998992
# SBERP    0.999004
# NMTP     0.999005
# GAZP     0.999028
# TGKN     0.999033
# TRNFP    0.999036
# SBER     0.999046
# BSPB     0.999047
# GTRK      0.99905
# RNFT     0.999055
# GMKN     0.999066
# KMAZ     0.999081
# TRMK     0.999083
# IRAO     0.999093
# SFIN     0.999095
# TATNP      0.9991
# NVTK     0.999102
# ALRS     0.999111
# SELG     0.999129
# T        0.999143
# FEES     0.999144
# MDMG     0.999148
# YDEX     0.999156
# HYDR     0.999159
# LKOH     0.999177
# TATN     0.999181
# PLZL     0.999187
# ENPG     0.999192
# POSI     0.999194
# ROSN     0.999197
# LENT     0.999206
# MVID     0.999206
# SNGSP    0.999227
# PHOR     0.999228
# RTKM     0.999249
# MGNT     0.999253
# RUAL     0.999275
# BANEP    0.999276
# SMLT     0.999281
# MTSS      0.99929
# FLOT     0.999297
# OGKB     0.999304
# SIBN     0.999339
# RASP     0.999339
# NLMK     0.999339
# FESH     0.999358
# HEAD      0.99936
# AFLT      0.99938
# MAGN     0.999382
# MTLRP    0.999384
# CHMF     0.999419
# BANE     0.999444
# MOEX     0.999445
# MTLR     0.999491
# PIKK     0.999503
# LSRG     0.999508
# CBOM      0.99958
# AFKS     0.999601
# RENI     0.999722
# Name: income_rate, dtype: object

# %%
df['time'].max()
# Out:
# Timestamp('2025-02-24 23:49:00')

# %%
mask_train = np.array(df['time'] < pd.Timestamp('2024-07-01')) & mask_time
mask_valid = np.array((pd.Timestamp('2024-07-01') <= df['time']) & (df['time'] < pd.Timestamp('2024-09-01'))) & mask_time
mask_test = np.array((pd.Timestamp('2024-09-01') <= df['time']) & (df['time'] < pd.Timestamp('2024-11-01'))) & mask_time
mask_test2 = np.array((pd.Timestamp('2024-11-01') <= df['time']) & (df['time'] < pd.Timestamp('2025-01-01'))) & mask_time
mask_test3 = np.array(pd.Timestamp('2025-01-01') <= df['time']) & mask_time

# %%
mask_train.sum(), mask_valid.sum(), mask_test.sum(), mask_test2.sum()
# Out:
# (1678568, 296002, 294425, 283563)

# %%
mask_test3.sum()
# Out:
# 251976

# %%
mask_data = mask_train|mask_valid|mask_test|mask_test2
(mask_data).sum()
# Out:
# 2552558

# %%
mask_train.sum()/(mask_data).sum(), mask_valid.sum()/(mask_data).sum(), mask_test.sum()/(mask_data).sum(), mask_test2.sum()/(mask_data).sum()
# Out:
# (0.657602295422866,
#  0.11596288899214044,
#  0.11534507736944664,
#  0.11108973821554692)

# %%
df.loc[mask_train, 'target'].mean(), df.loc[mask_valid, 'target'].mean(), df.loc[mask_test, 'target'].mean(), df.loc[mask_test2, 'target'].mean()
# Out:
# (0.04528681590498568,
#  0.06678333254505037,
#  0.06919249384393308,
#  0.08825551993736841)

# %%
df.loc[mask_test3, 'target'].mean()
# Out:
# 0.07912658348414135

# %%
df.loc[mask_train, 'income_rate'].mean(), df.loc[mask_valid, 'income_rate'].mean(), df.loc[mask_test, 'income_rate'].mean(), df.loc[mask_test2, 'income_rate'].mean()
# Out:
# (0.9990956088967224, 0.999021106977962, 0.9991688566585647, 0.9993119785725331)

# %%
df.loc[mask_test3, 'income_rate'].mean()
# Out:
# 0.9994954167956791

# %%
#проверки

# %%
(mask_train.sum()+mask_valid.sum()+mask_test.sum()+mask_test2.sum()) ==(mask_data).sum()

#(mask_train.sum()+mask_valid.sum()+mask_test.sum()) ==(mask_data).sum()
# Out:
# True

# %% [markdown]
# ## 3. Model

# %% [markdown]
# ### 3.1 Base model

# %%
df['ticker_code'] = df['ticker'].astype('category').cat.codes

# %%
df['ticker_code'].nunique()
# Out:
# 76

# %%
df.loc[mask_train, 'ticker_code'].nunique()
# Out:
# 76

# %%
drop_cols = [
 'time',
 'close',
 'volume',
 'tmos_close',
 'ticker',


     'result',
 'delta_time',
 'income_rate',
 'res_price',
 'res_ind',

    'index',
    'ind',
    
             'target',
             'y_pred']


features_all = df.columns[~df.columns.isin(drop_cols)].tolist()

cat_features_all = ['ticker_code',
                'hour', 'day', 'weekday',
]
cat_features = cat_features_all

target = 'target'

# %%
len(features_all), len(cat_features)
# Out:
# (695, 4)

# %% [markdown]
# ### 1. PSI

# %%
def psi(expected: np.ndarray, actual: np.ndarray, bucket_type: str = "bins", n_bins: int = 10) -> float:
    """Calculate PSI metric for two arrays.
    
    Parameters
    ----------
        expected : list-like
            Array of expected values
        actual : list-like
            Array of actual values
        bucket_type : str
            Binning strategy. Accepts two options: 'bins' and 'quantiles'. Defaults to 'bins'.
            'bins': input arrays are splitted into bins with equal
                and fixed steps based on 'expected' array
            'quantiles': input arrays are binned according to 'expected' array
                with given number of n_bins
        n_bins : int
            Number of buckets for binning. Defaults to 10.

    Returns
    -------
        A single float number
    """
    breakpoints = np.arange(0, n_bins + 1) / (n_bins) * 100
    if bucket_type == "bins":
        breakpoints = np.histogram(expected, n_bins)[1]
    elif bucket_type == "quantiles":
        breakpoints = np.percentile(expected, breakpoints)

    # Calculate frequencies
    expected_percents = np.histogram(expected, breakpoints)[0] / len(expected)
    actual_percents = np.histogram(actual, breakpoints)[0] / len(actual)
    # Clip freaquencies to avoid zero division
    expected_percents = np.clip(expected_percents, a_min=0.0001, a_max=None)
    actual_percents = np.clip(actual_percents, a_min=0.0001, a_max=None)
    # Calculate PSI
    psi_value = (expected_percents - actual_percents) * np.log(expected_percents / actual_percents)
    psi_value = sum(psi_value)

    return psi_value

# %%
psi_features = {'feature' : [],
                
               'psi_valid' : [],
               'psi_test' : [],
               'psi_test2' : [],

               'psi_neg_valid' : [],
               'psi_neg_test' : [],
               'psi_neg_test2' : [],

               'psi_pos_valid' : [],
               'psi_pos_test' : [],
               'psi_pos_test2' : [],
               }

for feature in tqdm(features_all):

    mask_pos = df['target'] == 1
    mask_neg = ~mask_pos

    psi_features['feature'] += [feature]
    
    psi_features['psi_valid'] += [psi(df.loc[mask_train, feature].values, df.loc[mask_valid, feature].values)]
    psi_features['psi_test'] += [psi(df.loc[mask_train, feature].values, df.loc[mask_test, feature].values)]
    psi_features['psi_test2'] += [psi(df.loc[mask_train, feature].values, df.loc[mask_test2, feature].values)]

    psi_features['psi_neg_valid'] += [psi(df.loc[mask_train&mask_neg, feature].values, df.loc[mask_valid&mask_neg, feature].values)]
    psi_features['psi_neg_test'] += [psi(df.loc[mask_train&mask_neg, feature].values, df.loc[mask_test&mask_neg, feature].values)]
    psi_features['psi_neg_test2'] += [psi(df.loc[mask_train&mask_neg, feature].values, df.loc[mask_test2&mask_neg, feature].values)]

    psi_features['psi_pos_valid'] += [psi(df.loc[mask_train&mask_pos, feature].values, df.loc[mask_valid&mask_pos, feature].values)]
    psi_features['psi_pos_test'] += [psi(df.loc[mask_train&mask_pos, feature].values, df.loc[mask_test&mask_pos, feature].values)]
    psi_features['psi_pos_test2'] += [psi(df.loc[mask_train&mask_pos, feature].values, df.loc[mask_test2&mask_pos, feature].values)]

df_psi = pd.DataFrame(psi_features)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 695/695 [07:08<00:00,  1.62it/s]

# %%
df_psi.head()
# Out:
#                  feature     psi_valid  psi_test  psi_test2  psi_neg_valid  \
# 0           close_w1_roc  1.376573e-03  0.002308   0.005903   4.289744e-04
# 1          volume_w1_roc  3.779342e-09  0.000007   0.000010   3.357925e-09
# 2      tmos_close_w1_roc  4.085393e-02  0.020848   0.043021   4.095873e-02
# 3      close_w5_norm_std  1.171241e-05  0.000003   0.000050   4.783094e-05
# 4  close_w5_mean_abs_pct  7.757951e-05  0.000019   0.000349   2.157990e-04
#
#    psi_neg_test  psi_neg_test2  psi_pos_valid  psi_pos_test  psi_pos_test2
# 0      0.000421       0.001893       0.001434      0.000633       0.000555
# 1      0.000004       0.000005       0.000003      0.000204       0.000069
# 2      0.020477       0.044239       0.049984      0.047176       0.179850
# 3      0.000074       0.000320       0.000134      0.002921       0.000816
# 4      0.000436       0.001670       0.003692      0.005729       0.003550

# %%
psi_threshold = 0.1
mask_psi_pos_neg = (df_psi['psi_valid'] < psi_threshold) & (df_psi['psi_test'] < psi_threshold) & (df_psi['psi_test2'] < psi_threshold)
mask_psi_neg = (df_psi['psi_neg_valid'] < psi_threshold) & (df_psi['psi_neg_test'] < psi_threshold) & (df_psi['psi_neg_test2'] < psi_threshold)
mask_psi_pos = (df_psi['psi_pos_valid'] < psi_threshold) & (df_psi['psi_pos_test'] < psi_threshold) & (df_psi['psi_pos_test2'] < psi_threshold)

# %%
len(features_all)
# Out:
# 695

# %%
mask_psi_pos_neg.sum(), (mask_psi_pos_neg & mask_psi_neg & mask_psi_pos).sum()
# Out:
# (544, 528)

# %%
mask_psi = mask_psi_pos_neg & mask_psi_neg & mask_psi_pos

# %%
np.array(features_all)[mask_psi]
# Out:
# array(['close_w1_roc', 'volume_w1_roc', 'close_w5_norm_std',
#        'close_w5_mean_abs_pct', 'close_w5_alpha', 'close_w5_rsi',
#        'close_w5_roc', 'volume_w5_norm_std', 'volume_w5_mean_abs_pct',
#        'volume_w5_alpha', 'volume_w5_rsi', 'volume_w5_roc',
#        'tmos_close_w5_alpha', 'tmos_close_w5_rsi', 'tmos_close_w5_roc',
#        'close_w10_norm_std', 'close_w10_mean_abs_pct', 'close_w10_alpha',
#        'close_w10_rsi', 'close_w10_roc', 'volume_w10_norm_std',
#        'volume_w10_mean_abs_pct', 'volume_w10_alpha', 'volume_w10_rsi',
#        'volume_w10_roc', 'tmos_close_w10_alpha', 'close_w20_norm_std',
#        'close_w20_mean_abs_pct', 'close_w20_alpha', 'close_w20_rsi',
#        'close_w20_roc', 'volume_w20_norm_std', 'volume_w20_mean_abs_pct',
#        'volume_w20_alpha', 'volume_w20_rsi', 'volume_w20_roc',
#        'close_w30_norm_std', 'close_w30_mean_abs_pct', 'close_w30_alpha',
#        'close_w30_rsi', 'close_w30_roc', 'volume_w30_norm_std',
#        'volume_w30_mean_abs_pct', 'volume_w30_alpha', 'volume_w30_rsi',
#        'volume_w30_roc', 'close_w30_lvl_1-1.005',
#        'close_w30_lvl_-0.995-1', 'close_w30_lvl_1.005-1.01',
#        'close_w30_lvl_-0.99-0.995', 'close_w30_lvl_1.01-1.015',
#        'close_w30_lvl_-0.985-0.99', 'close_w30_lvl_1.015-1.02',
#        'close_w30_lvl_-0.98-0.985', 'close_w30_lvl_1.02-1.03',
#        'close_w30_lvl_-0.97-0.98', 'tmos_close_w30_lvl_-0.995-1',
#        'tmos_close_w30_lvl_1.01-1.015', 'tmos_close_w30_lvl_-0.985-0.99',
#        'tmos_close_w30_lvl_1.015-1.02', 'tmos_close_w30_lvl_-0.98-0.985',
#        'tmos_close_w30_lvl_1.02-1.03', 'tmos_close_w30_lvl_-0.97-0.98',
#        'close_w60_norm_std', 'close_w60_mean_abs_pct', 'close_w60_alpha',
#        'close_w60_rsi', 'close_w60_roc', 'volume_w60_norm_std',
#        'volume_w60_mean_abs_pct', 'volume_w60_alpha', 'volume_w60_rsi',
#        'volume_w60_roc', 'close_w120_norm_std', 'close_w120_mean_abs_pct',
#        'close_w120_alpha', 'close_w120_rsi', 'close_w120_roc',
#        'volume_w120_norm_std', 'volume_w120_mean_abs_pct',
#        'volume_w120_alpha', 'volume_w120_rsi', 'volume_w120_roc',
#        'close_w120_lvl_-0.995-1', 'close_w120_lvl_1.005-1.01',
#        'close_w120_lvl_-0.99-0.995', 'close_w120_lvl_1.01-1.015',
#        'close_w120_lvl_-0.985-0.99', 'close_w120_lvl_1.015-1.02',
#        'close_w120_lvl_-0.98-0.985', 'close_w120_lvl_1.02-1.03',
#        'close_w120_lvl_-0.97-0.98', 'tmos_close_w120_lvl_1.01-1.015',
#        'tmos_close_w120_lvl_1.015-1.02', 'tmos_close_w120_lvl_1.02-1.03',
#        'tmos_close_w120_lvl_-0.97-0.98', 'hour',
#        'close_w1_roc/close_w5_alpha', 'close_w1_roc/close_w10_alpha',
#        'close_w1_roc/close_w20_alpha', 'close_w1_roc/close_w30_alpha',
#        'close_w1_roc/close_w60_alpha', 'close_w1_roc/close_w120_alpha',
#        'close_w5_alpha/close_w10_alpha', 'close_w5_alpha/close_w20_alpha',
#        'close_w5_alpha/close_w30_alpha', 'close_w5_alpha/close_w60_alpha',
#        'close_w5_alpha/close_w120_alpha',
#        'close_w10_alpha/close_w20_alpha',
#        'close_w10_alpha/close_w30_alpha',
#        'close_w10_alpha/close_w60_alpha',
#        'close_w10_alpha/close_w120_alpha',
#        'close_w20_alpha/close_w30_alpha',
#        'close_w20_alpha/close_w60_alpha',
#        'close_w20_alpha/close_w120_alpha',
#        'close_w30_alpha/close_w60_alpha',
#        'close_w30_alpha/close_w120_alpha',
#        'close_w60_alpha/close_w120_alpha',
#        'volume_w1_roc/volume_w5_alpha', 'volume_w1_roc/volume_w10_alpha',
#        'volume_w1_roc/volume_w20_alpha', 'volume_w1_roc/volume_w30_alpha',
#        'volume_w1_roc/volume_w60_alpha',
#        'volume_w1_roc/volume_w120_alpha',
#        'volume_w5_alpha/volume_w10_alpha',
#        'volume_w5_alpha/volume_w20_alpha',
#        'volume_w5_alpha/volume_w30_alpha',
#        'volume_w5_alpha/volume_w60_alpha',
#        'volume_w5_alpha/volume_w120_alpha',
#        'volume_w10_alpha/volume_w20_alpha',
#        'volume_w10_alpha/volume_w30_alpha',
#        'volume_w10_alpha/volume_w60_alpha',
#        'volume_w10_alpha/volume_w120_alpha',
#        'volume_w20_alpha/volume_w30_alpha',
#        'volume_w20_alpha/volume_w60_alpha',
#        'volume_w20_alpha/volume_w120_alpha',
#        'volume_w30_alpha/volume_w60_alpha',
#        'volume_w30_alpha/volume_w120_alpha',
#        'volume_w60_alpha/volume_w120_alpha',
#        'tmos_close_w1_roc/tmos_close_w5_alpha',
#        'tmos_close_w1_roc/tmos_close_w10_alpha',
#        'tmos_close_w1_roc/tmos_close_w20_alpha',
#        'tmos_close_w1_roc/tmos_close_w30_alpha',
#        'tmos_close_w1_roc/tmos_close_w60_alpha',
#        'tmos_close_w1_roc/tmos_close_w120_alpha',
#        'tmos_close_w5_alpha/tmos_close_w10_alpha',
#        'tmos_close_w5_alpha/tmos_close_w20_alpha',
#        'tmos_close_w5_alpha/tmos_close_w30_alpha',
#        'tmos_close_w5_alpha/tmos_close_w60_alpha',
#        'tmos_close_w5_alpha/tmos_close_w120_alpha',
#        'tmos_close_w10_alpha/tmos_close_w20_alpha',
#        'tmos_close_w10_alpha/tmos_close_w30_alpha',
#        'tmos_close_w10_alpha/tmos_close_w60_alpha',
#        'tmos_close_w10_alpha/tmos_close_w120_alpha',
#        'tmos_close_w20_alpha/tmos_close_w30_alpha',
#        'tmos_close_w20_alpha/tmos_close_w60_alpha',
#        'tmos_close_w20_alpha/tmos_close_w120_alpha',
#        'tmos_close_w30_alpha/tmos_close_w60_alpha',
#        'tmos_close_w30_alpha/tmos_close_w120_alpha',
#        'tmos_close_w60_alpha/tmos_close_w120_alpha',
#        'close_w1_roc/close_w5_roc', 'close_w1_roc/close_w10_roc',
#        'close_w1_roc/close_w20_roc', 'close_w1_roc/close_w30_roc',
#        'close_w1_roc/close_w60_roc', 'close_w1_roc/close_w120_roc',
#        'close_w5_roc/close_w10_roc', 'close_w5_roc/close_w20_roc',
#        'close_w5_roc/close_w30_roc', 'close_w5_roc/close_w60_roc',
#        'close_w5_roc/close_w120_roc', 'close_w10_roc/close_w20_roc',
#        'close_w10_roc/close_w30_roc', 'close_w10_roc/close_w60_roc',
#        'close_w10_roc/close_w120_roc', 'close_w20_roc/close_w30_roc',
#        'close_w20_roc/close_w60_roc', 'close_w20_roc/close_w120_roc',
#        'close_w30_roc/close_w60_roc', 'close_w30_roc/close_w120_roc',
#        'close_w60_roc/close_w120_roc', 'volume_w1_roc/volume_w5_roc',
#        'volume_w1_roc/volume_w10_roc', 'volume_w1_roc/volume_w20_roc',
#        'volume_w1_roc/volume_w30_roc', 'volume_w1_roc/volume_w60_roc',
#        'volume_w1_roc/volume_w120_roc', 'volume_w5_roc/volume_w10_roc',
#        'volume_w5_roc/volume_w20_roc', 'volume_w5_roc/volume_w30_roc',
#        'volume_w5_roc/volume_w60_roc', 'volume_w5_roc/volume_w120_roc',
#        'volume_w10_roc/volume_w20_roc', 'volume_w10_roc/volume_w30_roc',
#        'volume_w10_roc/volume_w60_roc', 'volume_w10_roc/volume_w120_roc',
#        'volume_w20_roc/volume_w30_roc', 'volume_w20_roc/volume_w60_roc',
#        'volume_w20_roc/volume_w120_roc', 'volume_w30_roc/volume_w60_roc',
#        'volume_w30_roc/volume_w120_roc', 'volume_w60_roc/volume_w120_roc',
#        'tmos_close_w1_roc/tmos_close_w10_roc',
#        'tmos_close_w5_roc/tmos_close_w60_roc',
#        'tmos_close_w5_roc/tmos_close_w120_roc',
#        'tmos_close_w10_roc/tmos_close_w20_roc',
#        'tmos_close_w10_roc/tmos_close_w30_roc',
#        'tmos_close_w10_roc/tmos_close_w120_roc',
#        'tmos_close_w20_roc/tmos_close_w30_roc',
#        'tmos_close_w20_roc/tmos_close_w60_roc',
#        'tmos_close_w20_roc/tmos_close_w120_roc',
#        'tmos_close_w30_roc/tmos_close_w60_roc',
#        'tmos_close_w30_roc/tmos_close_w120_roc',
#        'tmos_close_w60_roc/tmos_close_w120_roc',
#        'close_w5_mean_abs_pct/close_w10_mean_abs_pct',
#        'close_w5_mean_abs_pct/close_w20_mean_abs_pct',
#        'close_w5_mean_abs_pct/close_w30_mean_abs_pct',
#        'close_w5_mean_abs_pct/close_w60_mean_abs_pct',
#        'close_w5_mean_abs_pct/close_w120_mean_abs_pct',
#        'close_w10_mean_abs_pct/close_w20_mean_abs_pct',
#        'close_w10_mean_abs_pct/close_w30_mean_abs_pct',
#        'close_w10_mean_abs_pct/close_w60_mean_abs_pct',
#        'close_w10_mean_abs_pct/close_w120_mean_abs_pct',
#        'close_w20_mean_abs_pct/close_w30_mean_abs_pct',
#        'close_w20_mean_abs_pct/close_w60_mean_abs_pct',
#        'close_w20_mean_abs_pct/close_w120_mean_abs_pct',
#        'close_w30_mean_abs_pct/close_w60_mean_abs_pct',
#        'close_w30_mean_abs_pct/close_w120_mean_abs_pct',
#        'close_w60_mean_abs_pct/close_w120_mean_abs_pct',
#        'volume_w5_mean_abs_pct/volume_w10_mean_abs_pct',
#        'volume_w5_mean_abs_pct/volume_w20_mean_abs_pct',
#        'volume_w5_mean_abs_pct/volume_w30_mean_abs_pct',
#        'volume_w5_mean_abs_pct/volume_w60_mean_abs_pct',
#        'volume_w5_mean_abs_pct/volume_w120_mean_abs_pct',
#        'volume_w10_mean_abs_pct/volume_w20_mean_abs_pct',
#        'volume_w10_mean_abs_pct/volume_w30_mean_abs_pct',
#        'volume_w10_mean_abs_pct/volume_w60_mean_abs_pct',
#        'volume_w10_mean_abs_pct/volume_w120_mean_abs_pct',
#        'volume_w20_mean_abs_pct/volume_w30_mean_abs_pct',
#        'volume_w20_mean_abs_pct/volume_w60_mean_abs_pct',
#        'volume_w20_mean_abs_pct/volume_w120_mean_abs_pct',
#        'volume_w30_mean_abs_pct/volume_w60_mean_abs_pct',
#        'volume_w30_mean_abs_pct/volume_w120_mean_abs_pct',
#        'volume_w60_mean_abs_pct/volume_w120_mean_abs_pct',
#        'tmos_close_w5_mean_abs_pct/tmos_close_w10_mean_abs_pct',
#        'tmos_close_w5_mean_abs_pct/tmos_close_w20_mean_abs_pct',
#        'tmos_close_w5_mean_abs_pct/tmos_close_w30_mean_abs_pct',
#        'tmos_close_w5_mean_abs_pct/tmos_close_w60_mean_abs_pct',
#        'tmos_close_w5_mean_abs_pct/tmos_close_w120_mean_abs_pct',
#        'tmos_close_w10_mean_abs_pct/tmos_close_w20_mean_abs_pct',
#        'tmos_close_w10_mean_abs_pct/tmos_close_w30_mean_abs_pct',
#        'tmos_close_w10_mean_abs_pct/tmos_close_w60_mean_abs_pct',
#        'tmos_close_w10_mean_abs_pct/tmos_close_w120_mean_abs_pct',
#        'tmos_close_w20_mean_abs_pct/tmos_close_w30_mean_abs_pct',
#        'tmos_close_w20_mean_abs_pct/tmos_close_w60_mean_abs_pct',
#        'tmos_close_w20_mean_abs_pct/tmos_close_w120_mean_abs_pct',
#        'tmos_close_w30_mean_abs_pct/tmos_close_w60_mean_abs_pct',
#        'tmos_close_w30_mean_abs_pct/tmos_close_w120_mean_abs_pct',
#        'tmos_close_w60_mean_abs_pct/tmos_close_w120_mean_abs_pct',
#        'close_w5_std/close_w10_std', 'close_w5_std/close_w20_std',
#        'close_w5_std/close_w30_std', 'close_w5_std/close_w60_std',
#        'close_w5_std/close_w120_std', 'close_w10_std/close_w20_std',
#        'close_w10_std/close_w30_std', 'close_w10_std/close_w60_std',
#        'close_w10_std/close_w120_std', 'close_w20_std/close_w30_std',
#        'close_w20_std/close_w60_std', 'close_w20_std/close_w120_std',
#        'close_w30_std/close_w60_std', 'close_w30_std/close_w120_std',
#        'close_w60_std/close_w120_std', 'volume_w5_std/volume_w10_std',
#        'volume_w5_std/volume_w20_std', 'volume_w5_std/volume_w30_std',
#        'volume_w5_std/volume_w60_std', 'volume_w5_std/volume_w120_std',
#        'volume_w10_std/volume_w20_std', 'volume_w10_std/volume_w30_std',
#        'volume_w10_std/volume_w60_std', 'volume_w10_std/volume_w120_std',
#        'volume_w20_std/volume_w30_std', 'volume_w20_std/volume_w60_std',
#        'volume_w20_std/volume_w120_std', 'volume_w30_std/volume_w60_std',
#        'volume_w30_std/volume_w120_std', 'volume_w60_std/volume_w120_std',
#        'close_w5_norm_std/close_w10_norm_std',
#        'close_w5_norm_std/close_w20_norm_std',
#        'close_w5_norm_std/close_w30_norm_std',
#        'close_w5_norm_std/close_w60_norm_std',
#        'close_w5_norm_std/close_w120_norm_std',
#        'close_w10_norm_std/close_w20_norm_std',
#        'close_w10_norm_std/close_w30_norm_std',
#        'close_w10_norm_std/close_w60_norm_std',
#        'close_w10_norm_std/close_w120_norm_std',
#        'close_w20_norm_std/close_w30_norm_std',
#        'close_w20_norm_std/close_w60_norm_std',
#        'close_w20_norm_std/close_w120_norm_std',
#        'close_w30_norm_std/close_w60_norm_std',
#        'close_w30_norm_std/close_w120_norm_std',
#        'close_w60_norm_std/close_w120_norm_std',
#        'volume_w5_norm_std/volume_w10_norm_std',
#        'volume_w5_norm_std/volume_w20_norm_std',
#        'volume_w5_norm_std/volume_w30_norm_std',
#        'volume_w5_norm_std/volume_w60_norm_std',
#        'volume_w5_norm_std/volume_w120_norm_std',
#        'volume_w10_norm_std/volume_w20_norm_std',
#        'volume_w10_norm_std/volume_w30_norm_std',
#        'volume_w10_norm_std/volume_w60_norm_std',
#        'volume_w10_norm_std/volume_w120_norm_std',
#        'volume_w20_norm_std/volume_w30_norm_std',
#        'volume_w20_norm_std/volume_w60_norm_std',
#        'volume_w20_norm_std/volume_w120_norm_std',
#        'volume_w30_norm_std/volume_w60_norm_std',
#        'volume_w30_norm_std/volume_w120_norm_std',
#        'volume_w60_norm_std/volume_w120_norm_std',
#        'close_w5_rsi/close_w10_rsi', 'close_w5_rsi/close_w20_rsi',
#        'close_w5_rsi/close_w30_rsi', 'close_w5_rsi/close_w60_rsi',
#        'close_w5_rsi/close_w120_rsi', 'close_w10_rsi/close_w20_rsi',
#        'close_w10_rsi/close_w30_rsi', 'close_w10_rsi/close_w60_rsi',
#        'close_w10_rsi/close_w120_rsi', 'close_w20_rsi/close_w30_rsi',
#        'close_w20_rsi/close_w60_rsi', 'close_w20_rsi/close_w120_rsi',
#        'close_w30_rsi/close_w60_rsi', 'close_w30_rsi/close_w120_rsi',
#        'close_w60_rsi/close_w120_rsi', 'volume_w5_rsi/volume_w10_rsi',
#        'volume_w5_rsi/volume_w20_rsi', 'volume_w5_rsi/volume_w30_rsi',
#        'volume_w5_rsi/volume_w60_rsi', 'volume_w5_rsi/volume_w120_rsi',
#        'volume_w10_rsi/volume_w20_rsi', 'volume_w10_rsi/volume_w30_rsi',
#        'volume_w10_rsi/volume_w60_rsi', 'volume_w10_rsi/volume_w120_rsi',
#        'volume_w20_rsi/volume_w30_rsi', 'volume_w20_rsi/volume_w60_rsi',
#        'volume_w20_rsi/volume_w120_rsi', 'volume_w30_rsi/volume_w60_rsi',
#        'volume_w30_rsi/volume_w120_rsi', 'volume_w60_rsi/volume_w120_rsi',
#        'tmos_close_w5_rsi/tmos_close_w10_rsi',
#        'tmos_close_w5_rsi/tmos_close_w20_rsi',
#        'tmos_close_w5_rsi/tmos_close_w30_rsi',
#        'tmos_close_w5_rsi/tmos_close_w120_rsi',
#        'tmos_close_w10_rsi/tmos_close_w20_rsi',
#        'tmos_close_w10_rsi/tmos_close_w30_rsi',
#        'tmos_close_w10_rsi/tmos_close_w120_rsi',
#        'tmos_close_w20_rsi/tmos_close_w30_rsi',
#        'tmos_close_w20_rsi/tmos_close_w120_rsi',
#        'tmos_close_w30_rsi/tmos_close_w120_rsi',
#        'tmos_close_w60_rsi/tmos_close_w120_rsi', 'close/close_w5_ma',
#        'close/close_w10_ma', 'close/close_w20_ma', 'close/close_w30_ma',
#        'close/close_w60_ma', 'close/close_w120_ma',
#        'close_w5_ma/close_w10_ma', 'close_w5_ma/close_w20_ma',
#        'close_w5_ma/close_w30_ma', 'close_w5_ma/close_w60_ma',
#        'close_w5_ma/close_w120_ma', 'close_w10_ma/close_w20_ma',
#        'close_w10_ma/close_w30_ma', 'close_w10_ma/close_w60_ma',
#        'close_w10_ma/close_w120_ma', 'close_w20_ma/close_w30_ma',
#        'close_w20_ma/close_w60_ma', 'close_w20_ma/close_w120_ma',
#        'close_w30_ma/close_w60_ma', 'close_w30_ma/close_w120_ma',
#        'close_w60_ma/close_w120_ma', 'volume/volume_w5_ma',
#        'volume/volume_w10_ma', 'volume/volume_w20_ma',
#        'volume/volume_w30_ma', 'volume/volume_w60_ma',
#        'volume/volume_w120_ma', 'volume_w5_ma/volume_w10_ma',
#        'volume_w5_ma/volume_w20_ma', 'volume_w5_ma/volume_w30_ma',
#        'volume_w5_ma/volume_w60_ma', 'volume_w5_ma/volume_w120_ma',
#        'volume_w10_ma/volume_w20_ma', 'volume_w10_ma/volume_w30_ma',
#        'volume_w10_ma/volume_w60_ma', 'volume_w10_ma/volume_w120_ma',
#        'volume_w20_ma/volume_w30_ma', 'volume_w20_ma/volume_w60_ma',
#        'volume_w20_ma/volume_w120_ma', 'volume_w30_ma/volume_w60_ma',
#        'volume_w30_ma/volume_w120_ma', 'volume_w60_ma/volume_w120_ma',
#        'close/close_w5_expma', 'close/close_w10_expma',
#        'close/close_w20_expma', 'close/close_w30_expma',
#        'close/close_w60_expma', 'close/close_w120_expma',
#        'close_w5_expma/close_w10_expma', 'close_w5_expma/close_w20_expma',
#        'close_w5_expma/close_w30_expma', 'close_w5_expma/close_w60_expma',
#        'close_w5_expma/close_w120_expma',
#        'close_w10_expma/close_w20_expma',
#        'close_w10_expma/close_w30_expma',
#        'close_w10_expma/close_w60_expma',
#        'close_w10_expma/close_w120_expma',
#        'close_w20_expma/close_w30_expma',
#        'close_w20_expma/close_w60_expma',
#        'close_w20_expma/close_w120_expma',
#        'close_w30_expma/close_w60_expma',
#        'close_w30_expma/close_w120_expma',
#        'close_w60_expma/close_w120_expma', 'volume/volume_w5_expma',
#        'volume/volume_w10_expma', 'volume/volume_w20_expma',
#        'volume/volume_w30_expma', 'volume/volume_w60_expma',
#        'volume/volume_w120_expma', 'volume_w5_expma/volume_w10_expma',
#        'volume_w5_expma/volume_w20_expma',
#        'volume_w5_expma/volume_w30_expma',
#        'volume_w5_expma/volume_w60_expma',
#        'volume_w5_expma/volume_w120_expma',
#        'volume_w10_expma/volume_w20_expma',
#        'volume_w10_expma/volume_w30_expma',
#        'volume_w10_expma/volume_w60_expma',
#        'volume_w10_expma/volume_w120_expma',
#        'volume_w20_expma/volume_w30_expma',
#        'volume_w20_expma/volume_w60_expma',
#        'volume_w20_expma/volume_w120_expma',
#        'volume_w30_expma/volume_w60_expma',
#        'volume_w30_expma/volume_w120_expma',
#        'volume_w60_expma/volume_w120_expma',
#        'tmos_close/tmos_close_w5_expma', 'close_w5_min/close',
#        'close_w10_min/close', 'close_w20_min/close',
#        'close_w30_min/close', 'close_w60_min/close',
#        'close_w120_min/close', 'volume_w5_min/volume',
#        'volume_w10_min/volume', 'volume_w20_min/volume',
#        'volume_w30_min/volume', 'volume_w60_min/volume',
#        'volume_w120_min/volume', 'tmos_close_w5_min/tmos_close',
#        'close_w5_max/close', 'close_w10_max/close', 'close_w20_max/close',
#        'close_w30_max/close', 'close_w60_max/close',
#        'close_w120_max/close', 'volume_w5_max/volume',
#        'volume_w10_max/volume', 'volume_w20_max/volume',
#        'volume_w30_max/volume', 'volume_w60_max/volume',
#        'volume_w120_max/volume', 'tmos_close_w10_max/tmos_close',
#        'close_w5_ma_low_2std/close', 'close_w5_ma_up_2std/close',
#        'close_w5_ma_low_3std/close', 'close_w5_ma_up_3std/close',
#        'volume_w5_ma_low_2std/volume', 'volume_w5_ma_up_2std/volume',
#        'volume_w5_ma_low_3std/volume', 'volume_w5_ma_up_3std/volume',
#        'close_w10_ma_low_2std/close', 'close_w10_ma_up_2std/close',
#        'close_w10_ma_low_3std/close', 'close_w10_ma_up_3std/close',
#        'volume_w10_ma_low_2std/volume', 'volume_w10_ma_up_2std/volume',
#        'volume_w10_ma_low_3std/volume', 'volume_w10_ma_up_3std/volume',
#        'close_w20_ma_low_2std/close', 'close_w20_ma_up_2std/close',
#        'close_w20_ma_low_3std/close', 'close_w20_ma_up_3std/close',
#        'volume_w20_ma_low_2std/volume', 'volume_w20_ma_up_2std/volume',
#        'volume_w20_ma_low_3std/volume', 'volume_w20_ma_up_3std/volume',
#        'close_w30_ma_low_2std/close', 'close_w30_ma_up_2std/close',
#        'close_w30_ma_low_3std/close', 'close_w30_ma_up_3std/close',
#        'volume_w30_ma_low_2std/volume', 'volume_w30_ma_up_2std/volume',
#        'volume_w30_ma_low_3std/volume', 'volume_w30_ma_up_3std/volume',
#        'close_w60_ma_low_2std/close', 'close_w60_ma_up_3std/close',
#        'volume_w60_ma_low_2std/volume', 'volume_w60_ma_up_2std/volume',
#        'volume_w60_ma_low_3std/volume', 'volume_w60_ma_up_3std/volume',
#        'close_w120_ma_low_3std/close', 'close_w120_ma_up_3std/close',
#        'volume_w120_ma_low_2std/volume', 'volume_w120_ma_up_2std/volume',
#        'volume_w120_ma_low_3std/volume', 'volume_w120_ma_up_3std/volume',
#        'close_w5_min/close_w5_max', 'volume_w5_min/volume_w5_max',
#        'close_w10_min/close_w10_max', 'volume_w10_min/volume_w10_max',
#        'close_w20_min/close_w20_max', 'volume_w20_min/volume_w20_max',
#        'close_w30_min/close_w30_max', 'volume_w30_min/volume_w30_max',
#        'close_w60_min/close_w60_max', 'volume_w60_min/volume_w60_max',
#        'close_w120_min/close_w120_max', 'volume_w120_min/volume_w120_max',
#        'ticker_code'], dtype='<U56')

# %%
features_psi = np.array(features_all)[mask_psi]
len(features_psi)
# Out:
# 528

# %% [markdown]
# ### 2. Correlation

# %%
mask_train.sum(), mask_valid.sum(), mask_test.sum(), mask_test2.sum()
# Out:
# (1828415, 327593, 326131, 314270)

# %%
#subsample_train

coeff_subsample = 0.1

inds_train = np.argwhere(mask_train).ravel()
inds_train_subsample = np.random.RandomState(seed=42).permutation(inds_train)[:int(len(inds_train)*coeff_subsample)]

mask_train_subsample = np.zeros_like(mask_train).astype(bool)
mask_train_subsample[inds_train_subsample] = True

mask_train_subsample.sum()
# Out:
# 182841

# %%
features = features_psi.copy()
len(features)
# Out:
# 528

# %%
mask_corr = np.ones_like(features).astype(bool)
#mask_corr

# %%
corr_threshold = 0.99

for i in tqdm(range(len(features) - 1)):
    if mask_corr[i]:
        for j in range(i+1, len(features)):
            if mask_corr[j]:        
                corr = abs(np.corrcoef(df.loc[mask_train_subsample, features[i]], df.loc[mask_train_subsample, features[j]])[0,1])
                if corr > corr_threshold:
                    mask_corr[j] = False
mask_corr.sum()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 527/527 [19:15<00:00,  2.19s/it]
# 474

# %%
np.array(features)[~mask_corr]
# Out:
# array(['close_w5_alpha/close_w60_alpha',
#        'close_w5_alpha/close_w120_alpha',
#        'close_w10_alpha/close_w120_alpha',
#        'close_w20_alpha/close_w30_alpha',
#        'close_w20_alpha/close_w120_alpha',
#        'close_w30_alpha/close_w60_alpha',
#        'close_w30_alpha/close_w120_alpha',
#        'close_w60_alpha/close_w120_alpha',
#        'close_w5_norm_std/close_w10_norm_std',
#        'close_w5_norm_std/close_w20_norm_std',
#        'close_w5_norm_std/close_w30_norm_std',
#        'close_w5_norm_std/close_w60_norm_std',
#        'close_w5_norm_std/close_w120_norm_std',
#        'close_w10_norm_std/close_w20_norm_std',
#        'close_w10_norm_std/close_w30_norm_std',
#        'close_w10_norm_std/close_w60_norm_std',
#        'close_w10_norm_std/close_w120_norm_std',
#        'close_w20_norm_std/close_w30_norm_std',
#        'close_w20_norm_std/close_w60_norm_std',
#        'close_w20_norm_std/close_w120_norm_std',
#        'close_w30_norm_std/close_w60_norm_std',
#        'close_w30_norm_std/close_w120_norm_std',
#        'close_w60_norm_std/close_w120_norm_std',
#        'volume_w5_rsi/volume_w120_rsi',
#        'tmos_close_w10_rsi/tmos_close_w30_rsi',
#        'tmos_close_w10_rsi/tmos_close_w120_rsi',
#        'tmos_close_w20_rsi/tmos_close_w120_rsi',
#        'tmos_close_w30_rsi/tmos_close_w120_rsi',
#        'tmos_close_w60_rsi/tmos_close_w120_rsi', 'close/close_w5_expma',
#        'close/close_w10_expma', 'close/close_w20_expma',
#        'close/close_w30_expma', 'close/close_w60_expma',
#        'close/close_w120_expma', 'volume_w5_ma_low_2std/volume',
#        'volume_w5_ma_up_2std/volume', 'volume_w5_ma_low_3std/volume',
#        'volume_w5_ma_up_3std/volume', 'volume_w10_ma_low_2std/volume',
#        'volume_w10_ma_up_2std/volume', 'volume_w10_ma_low_3std/volume',
#        'volume_w10_ma_up_3std/volume', 'volume_w20_ma_low_2std/volume',
#        'volume_w20_ma_low_3std/volume', 'volume_w20_ma_up_3std/volume',
#        'volume_w30_ma_low_2std/volume', 'volume_w30_ma_low_3std/volume',
#        'volume_w30_ma_up_3std/volume', 'volume_w60_ma_low_3std/volume',
#        'volume_w60_ma_up_3std/volume', 'volume_w120_ma_low_3std/volume',
#        'volume_w120_ma_up_3std/volume', 'close_w5_min/close_w5_max'],
#       dtype='<U56')

# %%
features_corr = np.array(features)[mask_corr]
len(features_corr)
# Out:
# 474

# %%
features_corr
# Out:
# array(['close_w1_roc', 'volume_w1_roc', 'close_w5_norm_std',
#        'close_w5_mean_abs_pct', 'close_w5_alpha', 'close_w5_rsi',
#        'close_w5_roc', 'volume_w5_norm_std', 'volume_w5_mean_abs_pct',
#        'volume_w5_alpha', 'volume_w5_rsi', 'volume_w5_roc',
#        'tmos_close_w5_alpha', 'tmos_close_w5_rsi', 'tmos_close_w5_roc',
#        'close_w10_norm_std', 'close_w10_mean_abs_pct', 'close_w10_alpha',
#        'close_w10_rsi', 'close_w10_roc', 'volume_w10_norm_std',
#        'volume_w10_mean_abs_pct', 'volume_w10_alpha', 'volume_w10_rsi',
#        'volume_w10_roc', 'tmos_close_w10_alpha', 'close_w20_norm_std',
#        'close_w20_mean_abs_pct', 'close_w20_alpha', 'close_w20_rsi',
#        'close_w20_roc', 'volume_w20_norm_std', 'volume_w20_mean_abs_pct',
#        'volume_w20_alpha', 'volume_w20_rsi', 'volume_w20_roc',
#        'tmos_close_w20_alpha', 'close_w30_norm_std',
#        'close_w30_mean_abs_pct', 'close_w30_alpha', 'close_w30_rsi',
#        'close_w30_roc', 'volume_w30_norm_std', 'volume_w30_mean_abs_pct',
#        'volume_w30_alpha', 'volume_w30_rsi', 'volume_w30_roc',
#        'close_w30_lvl_1-1.005', 'close_w30_lvl_-0.995-1',
#        'close_w30_lvl_1.005-1.01', 'close_w30_lvl_-0.99-0.995',
#        'close_w30_lvl_1.01-1.015', 'close_w30_lvl_-0.985-0.99',
#        'close_w30_lvl_1.015-1.02', 'close_w30_lvl_-0.98-0.985',
#        'close_w30_lvl_1.02-1.03', 'close_w30_lvl_-0.97-0.98',
#        'tmos_close_w30_lvl_-0.995-1', 'tmos_close_w30_lvl_1.01-1.015',
#        'tmos_close_w30_lvl_-0.985-0.99', 'tmos_close_w30_lvl_1.015-1.02',
#        'tmos_close_w30_lvl_-0.98-0.985', 'tmos_close_w30_lvl_1.02-1.03',
#        'tmos_close_w30_lvl_-0.97-0.98', 'close_w60_norm_std',
#        'close_w60_mean_abs_pct', 'close_w60_alpha', 'close_w60_rsi',
#        'close_w60_roc', 'volume_w60_norm_std', 'volume_w60_mean_abs_pct',
#        'volume_w60_alpha', 'volume_w60_rsi', 'volume_w60_roc',
#        'close_w120_norm_std', 'close_w120_mean_abs_pct',
#        'close_w120_alpha', 'close_w120_rsi', 'close_w120_roc',
#        'volume_w120_norm_std', 'volume_w120_mean_abs_pct',
#        'volume_w120_alpha', 'volume_w120_rsi', 'volume_w120_roc',
#        'close_w120_lvl_-0.995-1', 'close_w120_lvl_-0.99-0.995',
#        'close_w120_lvl_1.01-1.015', 'close_w120_lvl_-0.985-0.99',
#        'close_w120_lvl_1.015-1.02', 'close_w120_lvl_-0.98-0.985',
#        'close_w120_lvl_1.02-1.03', 'close_w120_lvl_-0.97-0.98',
#        'tmos_close_w120_lvl_1.015-1.02', 'tmos_close_w120_lvl_1.02-1.03',
#        'tmos_close_w120_lvl_-0.97-0.98', 'hour',
#        'close_w1_roc/close_w5_alpha', 'close_w1_roc/close_w10_alpha',
#        'close_w1_roc/close_w20_alpha', 'close_w1_roc/close_w30_alpha',
#        'close_w1_roc/close_w60_alpha', 'close_w1_roc/close_w120_alpha',
#        'close_w5_alpha/close_w10_alpha', 'close_w5_alpha/close_w20_alpha',
#        'close_w5_alpha/close_w30_alpha',
#        'close_w10_alpha/close_w20_alpha',
#        'close_w10_alpha/close_w30_alpha',
#        'close_w10_alpha/close_w60_alpha',
#        'close_w20_alpha/close_w60_alpha', 'volume_w1_roc/volume_w5_alpha',
#        'volume_w1_roc/volume_w10_alpha', 'volume_w1_roc/volume_w20_alpha',
#        'volume_w1_roc/volume_w30_alpha', 'volume_w1_roc/volume_w60_alpha',
#        'volume_w1_roc/volume_w120_alpha',
#        'volume_w5_alpha/volume_w10_alpha',
#        'volume_w5_alpha/volume_w20_alpha',
#        'volume_w5_alpha/volume_w30_alpha',
#        'volume_w5_alpha/volume_w60_alpha',
#        'volume_w5_alpha/volume_w120_alpha',
#        'volume_w10_alpha/volume_w20_alpha',
#        'volume_w10_alpha/volume_w30_alpha',
#        'volume_w10_alpha/volume_w60_alpha',
#        'volume_w10_alpha/volume_w120_alpha',
#        'volume_w20_alpha/volume_w30_alpha',
#        'volume_w20_alpha/volume_w60_alpha',
#        'volume_w20_alpha/volume_w120_alpha',
#        'volume_w30_alpha/volume_w60_alpha',
#        'volume_w30_alpha/volume_w120_alpha',
#        'volume_w60_alpha/volume_w120_alpha',
#        'tmos_close_w1_roc/tmos_close_w5_alpha',
#        'tmos_close_w1_roc/tmos_close_w10_alpha',
#        'tmos_close_w1_roc/tmos_close_w20_alpha',
#        'tmos_close_w1_roc/tmos_close_w30_alpha',
#        'tmos_close_w1_roc/tmos_close_w60_alpha',
#        'tmos_close_w1_roc/tmos_close_w120_alpha',
#        'tmos_close_w5_alpha/tmos_close_w10_alpha',
#        'tmos_close_w5_alpha/tmos_close_w20_alpha',
#        'tmos_close_w5_alpha/tmos_close_w30_alpha',
#        'tmos_close_w5_alpha/tmos_close_w60_alpha',
#        'tmos_close_w5_alpha/tmos_close_w120_alpha',
#        'tmos_close_w10_alpha/tmos_close_w20_alpha',
#        'tmos_close_w10_alpha/tmos_close_w30_alpha',
#        'tmos_close_w10_alpha/tmos_close_w60_alpha',
#        'tmos_close_w10_alpha/tmos_close_w120_alpha',
#        'tmos_close_w20_alpha/tmos_close_w30_alpha',
#        'tmos_close_w20_alpha/tmos_close_w60_alpha',
#        'tmos_close_w20_alpha/tmos_close_w120_alpha',
#        'tmos_close_w30_alpha/tmos_close_w60_alpha',
#        'tmos_close_w30_alpha/tmos_close_w120_alpha',
#        'tmos_close_w60_alpha/tmos_close_w120_alpha',
#        'close_w1_roc/close_w5_roc', 'close_w1_roc/close_w10_roc',
#        'close_w1_roc/close_w20_roc', 'close_w1_roc/close_w30_roc',
#        'close_w1_roc/close_w60_roc', 'close_w1_roc/close_w120_roc',
#        'close_w5_roc/close_w10_roc', 'close_w5_roc/close_w20_roc',
#        'close_w5_roc/close_w30_roc', 'close_w5_roc/close_w60_roc',
#        'close_w5_roc/close_w120_roc', 'close_w10_roc/close_w20_roc',
#        'close_w10_roc/close_w30_roc', 'close_w10_roc/close_w60_roc',
#        'close_w10_roc/close_w120_roc', 'close_w20_roc/close_w30_roc',
#        'close_w20_roc/close_w60_roc', 'close_w20_roc/close_w120_roc',
#        'close_w30_roc/close_w60_roc', 'close_w30_roc/close_w120_roc',
#        'close_w60_roc/close_w120_roc', 'volume_w1_roc/volume_w5_roc',
#        'volume_w1_roc/volume_w10_roc', 'volume_w1_roc/volume_w20_roc',
#        'volume_w1_roc/volume_w30_roc', 'volume_w1_roc/volume_w60_roc',
#        'volume_w1_roc/volume_w120_roc', 'volume_w5_roc/volume_w10_roc',
#        'volume_w5_roc/volume_w20_roc', 'volume_w5_roc/volume_w30_roc',
#        'volume_w5_roc/volume_w60_roc', 'volume_w5_roc/volume_w120_roc',
#        'volume_w10_roc/volume_w20_roc', 'volume_w10_roc/volume_w30_roc',
#        'volume_w10_roc/volume_w60_roc', 'volume_w10_roc/volume_w120_roc',
#        'volume_w20_roc/volume_w30_roc', 'volume_w20_roc/volume_w60_roc',
#        'volume_w20_roc/volume_w120_roc', 'volume_w30_roc/volume_w60_roc',
#        'volume_w30_roc/volume_w120_roc', 'volume_w60_roc/volume_w120_roc',
#        'tmos_close_w1_roc/tmos_close_w10_roc',
#        'tmos_close_w5_roc/tmos_close_w30_roc',
#        'tmos_close_w5_roc/tmos_close_w120_roc',
#        'tmos_close_w10_roc/tmos_close_w20_roc',
#        'tmos_close_w10_roc/tmos_close_w30_roc',
#        'tmos_close_w10_roc/tmos_close_w60_roc',
#        'tmos_close_w10_roc/tmos_close_w120_roc',
#        'tmos_close_w20_roc/tmos_close_w30_roc',
#        'tmos_close_w20_roc/tmos_close_w60_roc',
#        'tmos_close_w20_roc/tmos_close_w120_roc',
#        'tmos_close_w30_roc/tmos_close_w120_roc',
#        'tmos_close_w60_roc/tmos_close_w120_roc',
#        'close_w5_mean_abs_pct/close_w10_mean_abs_pct',
#        'close_w5_mean_abs_pct/close_w20_mean_abs_pct',
#        'close_w5_mean_abs_pct/close_w30_mean_abs_pct',
#        'close_w5_mean_abs_pct/close_w60_mean_abs_pct',
#        'close_w5_mean_abs_pct/close_w120_mean_abs_pct',
#        'close_w10_mean_abs_pct/close_w20_mean_abs_pct',
#        'close_w10_mean_abs_pct/close_w30_mean_abs_pct',
#        'close_w10_mean_abs_pct/close_w60_mean_abs_pct',
#        'close_w10_mean_abs_pct/close_w120_mean_abs_pct',
#        'close_w20_mean_abs_pct/close_w30_mean_abs_pct',
#        'close_w20_mean_abs_pct/close_w60_mean_abs_pct',
#        'close_w20_mean_abs_pct/close_w120_mean_abs_pct',
#        'close_w30_mean_abs_pct/close_w60_mean_abs_pct',
#        'close_w30_mean_abs_pct/close_w120_mean_abs_pct',
#        'close_w60_mean_abs_pct/close_w120_mean_abs_pct',
#        'volume_w5_mean_abs_pct/volume_w10_mean_abs_pct',
#        'volume_w5_mean_abs_pct/volume_w20_mean_abs_pct',
#        'volume_w5_mean_abs_pct/volume_w30_mean_abs_pct',
#        'volume_w5_mean_abs_pct/volume_w60_mean_abs_pct',
#        'volume_w5_mean_abs_pct/volume_w120_mean_abs_pct',
#        'volume_w10_mean_abs_pct/volume_w20_mean_abs_pct',
#        'volume_w10_mean_abs_pct/volume_w30_mean_abs_pct',
#        'volume_w10_mean_abs_pct/volume_w60_mean_abs_pct',
#        'volume_w10_mean_abs_pct/volume_w120_mean_abs_pct',
#        'volume_w20_mean_abs_pct/volume_w30_mean_abs_pct',
#        'volume_w20_mean_abs_pct/volume_w60_mean_abs_pct',
#        'volume_w20_mean_abs_pct/volume_w120_mean_abs_pct',
#        'volume_w30_mean_abs_pct/volume_w60_mean_abs_pct',
#        'volume_w30_mean_abs_pct/volume_w120_mean_abs_pct',
#        'volume_w60_mean_abs_pct/volume_w120_mean_abs_pct',
#        'tmos_close_w5_mean_abs_pct/tmos_close_w10_mean_abs_pct',
#        'tmos_close_w5_mean_abs_pct/tmos_close_w20_mean_abs_pct',
#        'tmos_close_w5_mean_abs_pct/tmos_close_w30_mean_abs_pct',
#        'tmos_close_w5_mean_abs_pct/tmos_close_w60_mean_abs_pct',
#        'tmos_close_w5_mean_abs_pct/tmos_close_w120_mean_abs_pct',
#        'tmos_close_w10_mean_abs_pct/tmos_close_w20_mean_abs_pct',
#        'tmos_close_w10_mean_abs_pct/tmos_close_w30_mean_abs_pct',
#        'tmos_close_w10_mean_abs_pct/tmos_close_w60_mean_abs_pct',
#        'tmos_close_w10_mean_abs_pct/tmos_close_w120_mean_abs_pct',
#        'tmos_close_w20_mean_abs_pct/tmos_close_w30_mean_abs_pct',
#        'tmos_close_w20_mean_abs_pct/tmos_close_w60_mean_abs_pct',
#        'tmos_close_w20_mean_abs_pct/tmos_close_w120_mean_abs_pct',
#        'tmos_close_w30_mean_abs_pct/tmos_close_w60_mean_abs_pct',
#        'tmos_close_w30_mean_abs_pct/tmos_close_w120_mean_abs_pct',
#        'tmos_close_w60_mean_abs_pct/tmos_close_w120_mean_abs_pct',
#        'close_w5_std/close_w10_std', 'close_w5_std/close_w20_std',
#        'close_w5_std/close_w30_std', 'close_w5_std/close_w60_std',
#        'close_w5_std/close_w120_std', 'close_w10_std/close_w20_std',
#        'close_w10_std/close_w30_std', 'close_w10_std/close_w60_std',
#        'close_w10_std/close_w120_std', 'close_w20_std/close_w30_std',
#        'close_w20_std/close_w60_std', 'close_w20_std/close_w120_std',
#        'close_w30_std/close_w60_std', 'close_w30_std/close_w120_std',
#        'close_w60_std/close_w120_std', 'volume_w5_std/volume_w10_std',
#        'volume_w5_std/volume_w20_std', 'volume_w5_std/volume_w30_std',
#        'volume_w5_std/volume_w60_std', 'volume_w5_std/volume_w120_std',
#        'volume_w10_std/volume_w20_std', 'volume_w10_std/volume_w30_std',
#        'volume_w10_std/volume_w60_std', 'volume_w10_std/volume_w120_std',
#        'volume_w20_std/volume_w30_std', 'volume_w20_std/volume_w60_std',
#        'volume_w20_std/volume_w120_std', 'volume_w30_std/volume_w60_std',
#        'volume_w30_std/volume_w120_std', 'volume_w60_std/volume_w120_std',
#        'volume_w5_norm_std/volume_w10_norm_std',
#        'volume_w5_norm_std/volume_w20_norm_std',
#        'volume_w5_norm_std/volume_w30_norm_std',
#        'volume_w5_norm_std/volume_w60_norm_std',
#        'volume_w5_norm_std/volume_w120_norm_std',
#        'volume_w10_norm_std/volume_w20_norm_std',
#        'volume_w10_norm_std/volume_w30_norm_std',
#        'volume_w10_norm_std/volume_w60_norm_std',
#        'volume_w10_norm_std/volume_w120_norm_std',
#        'volume_w20_norm_std/volume_w30_norm_std',
#        'volume_w20_norm_std/volume_w60_norm_std',
#        'volume_w20_norm_std/volume_w120_norm_std',
#        'volume_w30_norm_std/volume_w60_norm_std',
#        'volume_w30_norm_std/volume_w120_norm_std',
#        'volume_w60_norm_std/volume_w120_norm_std',
#        'close_w5_rsi/close_w10_rsi', 'close_w5_rsi/close_w20_rsi',
#        'close_w5_rsi/close_w30_rsi', 'close_w5_rsi/close_w60_rsi',
#        'close_w5_rsi/close_w120_rsi', 'close_w10_rsi/close_w20_rsi',
#        'close_w10_rsi/close_w30_rsi', 'close_w10_rsi/close_w60_rsi',
#        'close_w10_rsi/close_w120_rsi', 'close_w20_rsi/close_w30_rsi',
#        'close_w20_rsi/close_w60_rsi', 'close_w20_rsi/close_w120_rsi',
#        'close_w30_rsi/close_w60_rsi', 'close_w30_rsi/close_w120_rsi',
#        'close_w60_rsi/close_w120_rsi', 'volume_w5_rsi/volume_w10_rsi',
#        'volume_w5_rsi/volume_w20_rsi', 'volume_w5_rsi/volume_w30_rsi',
#        'volume_w5_rsi/volume_w60_rsi', 'volume_w10_rsi/volume_w20_rsi',
#        'volume_w10_rsi/volume_w30_rsi', 'volume_w10_rsi/volume_w60_rsi',
#        'volume_w10_rsi/volume_w120_rsi', 'volume_w20_rsi/volume_w30_rsi',
#        'volume_w20_rsi/volume_w60_rsi', 'volume_w20_rsi/volume_w120_rsi',
#        'volume_w30_rsi/volume_w60_rsi', 'volume_w30_rsi/volume_w120_rsi',
#        'volume_w60_rsi/volume_w120_rsi',
#        'tmos_close_w5_rsi/tmos_close_w10_rsi',
#        'tmos_close_w5_rsi/tmos_close_w20_rsi',
#        'tmos_close_w5_rsi/tmos_close_w30_rsi',
#        'tmos_close_w5_rsi/tmos_close_w120_rsi',
#        'tmos_close_w10_rsi/tmos_close_w20_rsi',
#        'tmos_close_w20_rsi/tmos_close_w30_rsi', 'close/close_w5_ma',
#        'close/close_w10_ma', 'close/close_w20_ma', 'close/close_w30_ma',
#        'close/close_w60_ma', 'close/close_w120_ma',
#        'close_w5_ma/close_w10_ma', 'close_w5_ma/close_w20_ma',
#        'close_w5_ma/close_w30_ma', 'close_w5_ma/close_w60_ma',
#        'close_w5_ma/close_w120_ma', 'close_w10_ma/close_w20_ma',
#        'close_w10_ma/close_w30_ma', 'close_w10_ma/close_w60_ma',
#        'close_w10_ma/close_w120_ma', 'close_w20_ma/close_w30_ma',
#        'close_w20_ma/close_w60_ma', 'close_w20_ma/close_w120_ma',
#        'close_w30_ma/close_w60_ma', 'close_w30_ma/close_w120_ma',
#        'close_w60_ma/close_w120_ma', 'volume/volume_w5_ma',
#        'volume/volume_w10_ma', 'volume/volume_w20_ma',
#        'volume/volume_w30_ma', 'volume/volume_w60_ma',
#        'volume/volume_w120_ma', 'volume_w5_ma/volume_w10_ma',
#        'volume_w5_ma/volume_w20_ma', 'volume_w5_ma/volume_w30_ma',
#        'volume_w5_ma/volume_w60_ma', 'volume_w5_ma/volume_w120_ma',
#        'volume_w10_ma/volume_w20_ma', 'volume_w10_ma/volume_w30_ma',
#        'volume_w10_ma/volume_w60_ma', 'volume_w10_ma/volume_w120_ma',
#        'volume_w20_ma/volume_w30_ma', 'volume_w20_ma/volume_w60_ma',
#        'volume_w20_ma/volume_w120_ma', 'volume_w30_ma/volume_w60_ma',
#        'volume_w30_ma/volume_w120_ma', 'volume_w60_ma/volume_w120_ma',
#        'tmos_close_w5_ma/tmos_close_w10_ma',
#        'close_w5_expma/close_w10_expma', 'close_w5_expma/close_w20_expma',
#        'close_w5_expma/close_w30_expma', 'close_w5_expma/close_w60_expma',
#        'close_w5_expma/close_w120_expma',
#        'close_w10_expma/close_w20_expma',
#        'close_w10_expma/close_w30_expma',
#        'close_w10_expma/close_w60_expma',
#        'close_w10_expma/close_w120_expma',
#        'close_w20_expma/close_w30_expma',
#        'close_w20_expma/close_w60_expma',
#        'close_w20_expma/close_w120_expma',
#        'close_w30_expma/close_w60_expma',
#        'close_w30_expma/close_w120_expma',
#        'close_w60_expma/close_w120_expma', 'volume/volume_w5_expma',
#        'volume/volume_w10_expma', 'volume/volume_w20_expma',
#        'volume/volume_w30_expma', 'volume/volume_w60_expma',
#        'volume/volume_w120_expma', 'volume_w5_expma/volume_w10_expma',
#        'volume_w5_expma/volume_w20_expma',
#        'volume_w5_expma/volume_w30_expma',
#        'volume_w5_expma/volume_w60_expma',
#        'volume_w5_expma/volume_w120_expma',
#        'volume_w10_expma/volume_w20_expma',
#        'volume_w10_expma/volume_w30_expma',
#        'volume_w10_expma/volume_w60_expma',
#        'volume_w10_expma/volume_w120_expma',
#        'volume_w20_expma/volume_w30_expma',
#        'volume_w20_expma/volume_w60_expma',
#        'volume_w20_expma/volume_w120_expma',
#        'volume_w30_expma/volume_w60_expma',
#        'volume_w30_expma/volume_w120_expma',
#        'volume_w60_expma/volume_w120_expma',
#        'tmos_close/tmos_close_w5_expma', 'close_w5_min/close',
#        'close_w10_min/close', 'close_w20_min/close',
#        'close_w30_min/close', 'close_w60_min/close',
#        'close_w120_min/close', 'volume_w5_min/volume',
#        'volume_w10_min/volume', 'volume_w20_min/volume',
#        'volume_w30_min/volume', 'volume_w60_min/volume',
#        'volume_w120_min/volume', 'tmos_close_w5_min/tmos_close',
#        'close_w5_max/close', 'close_w10_max/close', 'close_w20_max/close',
#        'close_w30_max/close', 'close_w60_max/close',
#        'close_w120_max/close', 'volume_w5_max/volume',
#        'volume_w10_max/volume', 'volume_w20_max/volume',
#        'volume_w30_max/volume', 'volume_w60_max/volume',
#        'volume_w120_max/volume', 'tmos_close_w10_max/tmos_close',
#        'close_w5_ma_low_2std/close', 'close_w5_ma_up_2std/close',
#        'close_w5_ma_low_3std/close', 'close_w5_ma_up_3std/close',
#        'close_w10_ma_low_2std/close', 'close_w10_ma_up_2std/close',
#        'close_w10_ma_low_3std/close', 'close_w10_ma_up_3std/close',
#        'close_w20_ma_low_2std/close', 'close_w20_ma_up_2std/close',
#        'close_w20_ma_low_3std/close', 'close_w20_ma_up_3std/close',
#        'volume_w20_ma_up_2std/volume', 'close_w30_ma_low_2std/close',
#        'close_w30_ma_up_2std/close', 'close_w30_ma_low_3std/close',
#        'close_w30_ma_up_3std/close', 'volume_w30_ma_up_2std/volume',
#        'close_w60_ma_low_2std/close', 'close_w60_ma_up_3std/close',
#        'volume_w60_ma_low_2std/volume', 'volume_w60_ma_up_2std/volume',
#        'close_w120_ma_low_3std/close', 'close_w120_ma_up_3std/close',
#        'volume_w120_ma_low_2std/volume', 'volume_w120_ma_up_2std/volume',
#        'volume_w5_min/volume_w5_max', 'close_w10_min/close_w10_max',
#        'volume_w10_min/volume_w10_max', 'close_w20_min/close_w20_max',
#        'volume_w20_min/volume_w20_max', 'close_w30_min/close_w30_max',
#        'volume_w30_min/volume_w30_max', 'close_w60_min/close_w60_max',
#        'volume_w60_min/volume_w60_max', 'close_w120_min/close_w120_max',
#        'volume_w120_min/volume_w120_max', 'ticker_code'], dtype='<U56')

# %% [markdown]
# #### 2. Useful features

# %%
def get_useful_features(feature):
    for elem in ['volume', 'std', 'pct', 'alpha', 'rsi/', 'roc', 'ticker_code', 'hour', '_ma']:
        if elem in feature:
            return False
    return True

mask_useful_features = np.array([get_useful_features(feature) for feature in features_psi])
features_useful = np.array(features_psi)[mask_useful_features].tolist()
len(features_useful), features_useful
# Out:
# (66,
#  ['close_w5_rsi',
#   'tmos_close_w5_rsi',
#   'close_w10_rsi',
#   'close_w20_rsi',
#   'close_w30_rsi',
#   'close_w30_lvl_1-1.005',
#   'close_w30_lvl_-0.995-1',
#   'close_w30_lvl_1.005-1.01',
#   'close_w30_lvl_-0.99-0.995',
#   'close_w30_lvl_1.01-1.015',
#   'close_w30_lvl_-0.985-0.99',
#   'close_w30_lvl_1.015-1.02',
#   'close_w30_lvl_-0.98-0.985',
#   'close_w30_lvl_1.02-1.03',
#   'close_w30_lvl_-0.97-0.98',
#   'tmos_close_w30_lvl_-0.995-1',
#   'tmos_close_w30_lvl_1.01-1.015',
#   'tmos_close_w30_lvl_-0.985-0.99',
#   'tmos_close_w30_lvl_1.015-1.02',
#   'tmos_close_w30_lvl_-0.98-0.985',
#   'tmos_close_w30_lvl_1.02-1.03',
#   'tmos_close_w30_lvl_-0.97-0.98',
#   'close_w60_rsi',
#   'close_w120_rsi',
#   'close_w120_lvl_-0.995-1',
#   'close_w120_lvl_1.005-1.01',
#   'close_w120_lvl_-0.99-0.995',
#   'close_w120_lvl_1.01-1.015',
#   'close_w120_lvl_-0.985-0.99',
#   'close_w120_lvl_1.015-1.02',
#   'close_w120_lvl_-0.98-0.985',
#   'close_w120_lvl_1.02-1.03',
#   'close_w120_lvl_-0.97-0.98',
#   'tmos_close_w120_lvl_1.01-1.015',
#   'tmos_close_w120_lvl_1.015-1.02',
#   'tmos_close_w120_lvl_1.02-1.03',
#   'tmos_close_w120_lvl_-0.97-0.98',
#   'close/close_w5_expma',
#   'close/close_w10_expma',
#   'close/close_w20_expma',
#   'close/close_w30_expma',
#   'close/close_w60_expma',
#   'close/close_w120_expma',
#   'close_w5_expma/close_w10_expma',
#   'close_w5_expma/close_w20_expma',
#   'close_w5_expma/close_w30_expma',
#   'close_w5_expma/close_w60_expma',
#   'close_w5_expma/close_w120_expma',
#   'close_w10_expma/close_w20_expma',
#   'close_w10_expma/close_w30_expma',
#   'close_w10_expma/close_w60_expma',
#   'close_w10_expma/close_w120_expma',
#   'close_w20_expma/close_w30_expma',
#   'close_w20_expma/close_w60_expma',
#   'close_w20_expma/close_w120_expma',
#   'close_w30_expma/close_w60_expma',
#   'close_w30_expma/close_w120_expma',
#   'close_w60_expma/close_w120_expma',
#   'tmos_close/tmos_close_w5_expma',
#   'close_w5_min/close',
#   'close_w10_min/close',
#   'close_w20_min/close',
#   'close_w30_min/close',
#   'close_w60_min/close',
#   'close_w120_min/close',
#   'tmos_close_w5_min/tmos_close'])

# %% [markdown]
# ### 3. Get stability features

# %%
features = features_useful.copy()
len(features)
# Out:
# 66

# %%
#Перепроверить эти функции потом в ручную на примерах

def mean_win_rate_point(D_sample, y_pred, threshold=None):
    mask = y_pred >= threshold
    score = np.mean(D_sample.label[mask])
    
    return score




def mean_income_rate_point(D_sample, y_pred, threshold=None):
    # q=threshold
    # mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    score = np.mean(D_sample.income_rate[mask]) - 1
    
    return score

def mean_income_rate_tick(D_sample, y_pred, threshold=None):
    # q=threshold
    # mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup[mask].groupby('time').income_rate.mean()-1).mean()
    
    return score



def mean_income_rate_day(D_sample, y_pred, threshold=None):
    # q=threshold
    # mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup[mask].groupby('time').income_rate.mean()-1).reset_index().groupby(pd.Grouper(key='time', freq='D')).income_rate.mean().mean()

    return score
    
def mean_income_rate_month(D_sample, y_pred, threshold=None):
    # q=threshold
    # mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup[mask].groupby('time').income_rate.mean()-1).reset_index().groupby(pd.Grouper(key='time', freq='D')).income_rate.mean().mean() * df_sup.loc[mask, 'time'].dt.date.nunique() 
    score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month
    
    return score


def mean_income_rate(y_pred, D_sample):
    q = 0.995
    mask = y_pred >= np.quantile(y_pred, q)
    #mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    # month
    # score = (df_sup[mask].groupby('time').income_rate.mean()-1).reset_index().groupby(pd.Grouper(key='time', freq='D')).income_rate.mean().mean() * df_sup.loc[mask, 'time'].dt.date.nunique() 
    # score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month

    # tick
    score = (df_sup[mask].groupby('time').income_rate.mean()-1).mean()
    
    # point
    # score = np.mean(D_sample.income_rate[mask]) - 1

    #point win_rate
    # score = np.mean(D_sample.label[mask])

    score = round(score, 5)
    return 'mean_income_rate', score, True#is_higher_better

# %%
params = {
    "boosting_type": "gbdt",
    "objective": "binary",
    
    "num_leaves": 31,

     "bagging_fraction": 0.5,
     "bagging_freq": 1,
     "verbose": -1,
    # "metric": "auc",
    "metric": "mean_income_rate",   
    "early_stopping" : 10, 
    
    
}

auc_features = {'feature' : [],
                
               'auc_train' : [],
               'auc_valid' : [],
               'auc_test' : [],
               'auc_test2' : [],
           
           'mir_point@1_train' : [],
           'mir_point@1_valid' : [],
           'mir_point@1_test' : [],
           'mir_point@1_test2' : [],

           'mir_tick@1_train' : [],
           'mir_tick@1_valid' : [],
           'mir_tick@1_test' : [],
           'mir_tick@1_test2' : [],


           'mir_day@1_train' : [],
           'mir_day@1_valid' : [],
           'mir_day@1_test' : [],
           'mir_day@1_test2' : [],

           'mir_month@1_train' : [],
           'mir_month@1_valid' : [],
           'mir_month@1_test' : [],
           'mir_month@1_test2' : [],

           'mean_win_rate_point@1_train' : [],
           'mean_win_rate_point@1_valid' : [],
           'mean_win_rate_point@1_test' : [],
           'mean_win_rate_point@1_test2' : [],

        
               }

for feature in tqdm(features):
    stab_features = [feature]
    stab_cat_features = [feature] if feature in cat_features else []
    
    D_train = lgbm.Dataset(df.loc[mask_train_subsample, stab_features], label=df.loc[mask_train_subsample, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
    D_valid = lgbm.Dataset(df.loc[mask_valid, stab_features], label=df.loc[mask_valid, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
    D_test = lgbm.Dataset(df.loc[mask_test, stab_features], label=df.loc[mask_test, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
    D_test2 = lgbm.Dataset(df.loc[mask_test2, stab_features], label=df.loc[mask_test2, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)

    D_train.income_rate = df.loc[mask_train_subsample, 'income_rate'].values
    D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
    D_test.income_rate = df.loc[mask_test, 'income_rate'].values
    D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values
    
    D_train.time = df.loc[mask_train_subsample, 'time'].values
    D_valid.time = df.loc[mask_valid, 'time'].values
    D_test.time = df.loc[mask_test, 'time'].values
    D_test2.time = df.loc[mask_test2, 'time'].values


    
    model = lgbm.train(params, num_boost_round=1000, train_set=D_train, valid_sets=[D_valid], feval=mean_income_rate)
    
    y_pred_train = model.predict(D_train.data)
    y_pred_valid = model.predict(D_valid.data)
    y_pred_test = model.predict(D_test.data)
    y_pred_test2 = model.predict(D_test2.data)

    auc_features['feature'] += [feature]
    auc_features['auc_train'] += [roc_auc_score(D_train.label, y_pred_train)]
    auc_features['auc_valid'] += [roc_auc_score(D_valid.label, y_pred_valid)]
    auc_features['auc_test'] += [roc_auc_score(D_test.label, y_pred_test)]
    auc_features['auc_test2'] += [roc_auc_score(D_test2.label, y_pred_test2)]

    
    threshold = np.quantile(y_pred_valid, q=0.995) #в feval тоже нужно менять
    
    auc_features['mir_point@1_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold)]
    auc_features['mir_point@1_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold)]
    auc_features['mir_point@1_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold)]
    auc_features['mir_point@1_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)]

    auc_features['mir_tick@1_train'] += [mean_income_rate_tick(D_train, y_pred_train, threshold=threshold)]
    auc_features['mir_tick@1_valid'] += [mean_income_rate_tick(D_valid, y_pred_valid, threshold=threshold)]
    auc_features['mir_tick@1_test'] += [mean_income_rate_tick(D_test, y_pred_test, threshold=threshold)]
    auc_features['mir_tick@1_test2'] += [mean_income_rate_tick(D_test2, y_pred_test2, threshold=threshold)]

    auc_features['mir_day@1_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold)]
    auc_features['mir_day@1_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold)]
    auc_features['mir_day@1_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold)]
    auc_features['mir_day@1_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)]

    
    auc_features['mir_month@1_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold)]
    auc_features['mir_month@1_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold)]
    auc_features['mir_month@1_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold)]
    auc_features['mir_month@1_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)]

    auc_features['mean_win_rate_point@1_train'] += [mean_win_rate_point(D_train, y_pred_train, threshold=threshold)]
    auc_features['mean_win_rate_point@1_valid'] += [mean_win_rate_point(D_valid, y_pred_valid, threshold=threshold)]
    auc_features['mean_win_rate_point@1_test'] += [mean_win_rate_point(D_test, y_pred_test, threshold=threshold)]
    auc_features['mean_win_rate_point@1_test2'] += [mean_win_rate_point(D_test2, y_pred_test2, threshold=threshold)]

df_auc = pd.DataFrame(auc_features)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 66/66 [03:09<00:00,  2.87s/it]

# %%
pd.set_option('display.max_columns', 100)
df_auc = pd.DataFrame(auc_features)
df_auc
# Out:
#                              feature  auc_train  auc_valid  auc_test  \
# 0                       close_w5_rsi   0.560984   0.515133  0.521250
# 1                  tmos_close_w5_rsi   0.520450   0.516235  0.506772
# 2                      close_w10_rsi   0.535185   0.508000  0.503682
# 3                      close_w20_rsi   0.552064   0.509430  0.506373
# 4                      close_w30_rsi   0.535384   0.502687  0.499598
# 5              close_w30_lvl_1-1.005   0.557556   0.541260  0.539321
# 6             close_w30_lvl_-0.995-1   0.532611   0.515096  0.515603
# 7           close_w30_lvl_1.005-1.01   0.568666   0.545641  0.550436
# 8          close_w30_lvl_-0.99-0.995   0.570619   0.541695  0.542759
# 9           close_w30_lvl_1.01-1.015   0.531907   0.523599  0.525026
# 10         close_w30_lvl_-0.985-0.99   0.525264   0.514168  0.513844
# 11          close_w30_lvl_1.015-1.02   0.515892   0.513052  0.512934
# 12         close_w30_lvl_-0.98-0.985   0.511653   0.504614  0.505082
# 13           close_w30_lvl_1.02-1.03   0.509662   0.507762  0.505969
# 14          close_w30_lvl_-0.97-0.98   0.507425   0.501713  0.502131
# 15       tmos_close_w30_lvl_-0.995-1   0.539347   0.532707  0.521958
# 16     tmos_close_w30_lvl_1.01-1.015   0.502074   0.501326  0.503141
# 17    tmos_close_w30_lvl_-0.985-0.99   0.501254   0.500843  0.502164
# 18     tmos_close_w30_lvl_1.015-1.02   0.500348   0.499993  0.500103
# 19    tmos_close_w30_lvl_-0.98-0.985   0.500466   0.499917  0.500002
# 20      tmos_close_w30_lvl_1.02-1.03   0.500229   0.499998  0.499996
# 21     tmos_close_w30_lvl_-0.97-0.98   0.500000   0.500000  0.500000
# 22                     close_w60_rsi   0.556061   0.511858  0.522858
# 23                    close_w120_rsi   0.551894   0.514412  0.517610
# 24           close_w120_lvl_-0.995-1   0.564499   0.519732  0.535774
# 25         close_w120_lvl_1.005-1.01   0.596119   0.545900  0.561785
# 26        close_w120_lvl_-0.99-0.995   0.633507   0.568496  0.573628
# 27         close_w120_lvl_1.01-1.015   0.579492   0.557259  0.564818
# 28        close_w120_lvl_-0.985-0.99   0.592250   0.551192  0.563244
# 29         close_w120_lvl_1.015-1.02   0.559259   0.554574  0.553401
# 30        close_w120_lvl_-0.98-0.985   0.556377   0.527489  0.538222
# 31          close_w120_lvl_1.02-1.03   0.546496   0.541700  0.540900
# 32         close_w120_lvl_-0.97-0.98   0.536997   0.512372  0.521641
# 33    tmos_close_w120_lvl_1.01-1.015   0.514697   0.517505  0.523106
# 34    tmos_close_w120_lvl_1.015-1.02   0.506019   0.507227  0.520336
# 35     tmos_close_w120_lvl_1.02-1.03   0.502005   0.501726  0.512286
# 36    tmos_close_w120_lvl_-0.97-0.98   0.502002   0.500012  0.506827
# 37              close/close_w5_expma   0.622733   0.569119  0.580583
# 38             close/close_w10_expma   0.626517   0.571865  0.579703
# 39             close/close_w20_expma   0.627255   0.569858  0.572759
# 40             close/close_w30_expma   0.630356   0.571922  0.576216
# 41             close/close_w60_expma   0.641906   0.572663  0.589354
# 42            close/close_w120_expma   0.652465   0.575353  0.593780
# 43    close_w5_expma/close_w10_expma   0.632649   0.570879  0.577907
# 44    close_w5_expma/close_w20_expma   0.630951   0.569498  0.575214
# 45    close_w5_expma/close_w30_expma   0.635061   0.570426  0.578624
# 46    close_w5_expma/close_w60_expma   0.641906   0.570995  0.588653
# 47   close_w5_expma/close_w120_expma   0.651036   0.575704  0.594564
# 48   close_w10_expma/close_w20_expma   0.634638   0.569369  0.576467
# 49   close_w10_expma/close_w30_expma   0.629381   0.569862  0.579444
# 50   close_w10_expma/close_w60_expma   0.638442   0.569516  0.587241
# 51  close_w10_expma/close_w120_expma   0.650655   0.576594  0.594830
# 36                     0.066783                    0.069192
# 37                     0.228479                    0.210460
# 38                     0.229072                    0.222511
# 39                     0.220608                    0.233503
# 40                     0.215539                    0.231821
# 41                     0.229314                    0.257071
# 42                     0.236690                    0.299289
# 43                     0.167321                    0.163697
# 44                     0.194878                    0.210654
# 45                     0.195480                    0.211250
# 46                     0.207513                    0.246254
# 47                     0.218143                    0.287551
# 48                     0.182950                    0.195107
# 49                     0.193669                    0.204095
# 50                     0.198517                    0.243467
# 51                     0.211129                    0.285809
# 52                     0.209499                    0.188602
# 53                     0.204696                    0.243675
# 54                     0.212825                    0.285221
# 55                     0.204872                    0.251505
# 56                     0.213629                    0.289526
# 57                     0.218657                    0.294118
# 58                     0.104694                    0.093815
# 59                     0.127342                    0.104400
# 60                     0.117835                    0.111335
# 61                     0.124609                    0.114796
# 62                     0.119510                    0.115995
# 63                     0.120130                    0.124453
# 64                     0.138658                    0.130066
# 65                     0.093127                    0.087282
#
#     mean_win_rate_point@1_test2
# 0                      0.100130
# 1                      0.144728
# 2                      0.100191
# 3                      0.088248
# 4                      0.087996
# 5                      0.100288
# 6                      0.093980
# 7                      0.116619
# 8                      0.114197
# 9                      0.163573
# 10                     0.141624
# 11                     0.209901
# 12                     0.170816
# 13                     0.270797
# 14                     0.088256
# 15                     0.088985
# 16                     0.088256
# 17                     0.087894
# 18                     0.088256
# 19                     0.088256
# 20                     0.088256
# 21                     0.088256
# 22                     0.123221
# 23                     0.114123
# 24                     0.101181
# 25                     0.088050
# 26                     0.085773
# 27                     0.108501
# 28                     0.110749
# 29                     0.112472
# 30                     0.160000
# 31                     0.173913
# 32                     0.162987
# 33                     0.086662
# 34                     0.122267
# 35                     0.088166
# 36                     0.088256
# 37                     0.230228
# 38                     0.231622
# 39                     0.236676
# 40                     0.232611
# 41                     0.230428
# 42                     0.240449
# 43                     0.198351
# 44                     0.218250
# 45                     0.211276
# 46                     0.210933
# 47                     0.220563
# 48                     0.205693
# 49                     0.205933
# 50                     0.211549
# 51                     0.206897
# 52                     0.213825
# 53                     0.205882
# 54                     0.191050
# 55                     0.204832
# 56                     0.190725
# 57                     0.182703
# 58                     0.146652
# 59                     0.127231
# 60                     0.148682
# 61                     0.163076
# 62                     0.170776
# 63                     0.192995
# 64                     0.208224
# 65                     0.109420

# %% [markdown]
# #### auc <=0.525

# %%
auc_treshold = 0.51

# %%
mask_auc_train  = df_auc['auc_train'] <= auc_treshold 
mask_auc_train.sum()
# Out:
# 13

# %%
mask_auc_valid  = df_auc['auc_valid'] <= auc_treshold 
mask_auc_valid.sum()
# Out:
# 271

# %%
mask_auc_test  = df_auc['auc_test'] <= auc_treshold 
mask_auc_test.sum()
# Out:
# 264

# %%
(mask_auc_train | mask_auc_valid | mask_auc_test).sum()
# Out:
# 311

# %%
mask_auc_test2  = df_auc['auc_test2'] <= auc_treshold 
mask_auc_test2.sum()
# Out:
# 249

# %%
(mask_auc_train | mask_auc_valid | mask_auc_test | mask_auc_test2).sum()
# Out:
# 324

# %% [markdown]
# #### delta_auc > 0.05

# %%
auc_delta_treshold  = 0.025

# %%
mask_auc_delta_valid = (df_auc['auc_train'] - df_auc['auc_valid']).abs() > auc_delta_treshold
mask_auc_delta_valid.sum()
# Out:
# 115

# %%
mask_auc_delta_test = (df_auc['auc_train'] - df_auc['auc_test']).abs() > auc_delta_treshold
mask_auc_delta_test.sum()
# Out:
# 114

# %%
(mask_auc_delta_valid | mask_auc_delta_test).sum()
# Out:
# 128

# %%
mask_auc_delta_test2 = (df_auc['auc_train'] - df_auc['auc_test2']).abs() > auc_delta_treshold
mask_auc_delta_test2.sum()
# Out:
# 120

# %%
(mask_auc_delta_valid | mask_auc_delta_test | mask_auc_delta_test2).sum()
# Out:
# 135

# %% [markdown]
# #### union criterias

# %%
mask_criterias1 = mask_auc_train | mask_auc_valid | mask_auc_test | mask_auc_delta_valid | mask_auc_delta_test
mask_criterias1.sum()
# Out:
# 417

# %%
mask_criterias2 = mask_auc_train | mask_auc_valid | mask_auc_test | mask_auc_test2 | mask_auc_delta_valid | mask_auc_delta_test | mask_auc_delta_test2
mask_criterias2.sum()
# Out:
# 433

# %%
features_criteria1 = df_auc['feature'].values[~mask_criterias1]
len(features_criteria1), features_criteria1
# Out:
# (57,
#  array(['tmos_close_w5_roc', 'volume_w30_rsi', 'close_w30_lvl_1-1.005',
#         'close_w30_lvl_-0.995-1', 'close_w30_lvl_1.005-1.01',
#         'close_w30_lvl_-0.99-0.995', 'close_w30_lvl_1.01-1.015',
#         'close_w30_lvl_-0.985-0.99', 'tmos_close_w30_lvl_-0.995-1',
#         'close_w60_rsi', 'volume_w60_rsi', 'volume_w120_rsi',
#         'close_w120_lvl_1.01-1.015', 'close_w120_lvl_1.015-1.02',
#         'close_w120_lvl_-0.98-0.985', 'close_w120_lvl_1.02-1.03',
#         'close_w120_lvl_-0.97-0.98', 'hour',
#         'volume_w5_alpha/volume_w60_alpha',
#         'volume_w5_alpha/volume_w120_alpha',
#         'tmos_close_w1_roc/tmos_close_w120_alpha',
#         'tmos_close_w5_alpha/tmos_close_w10_alpha',
#         'tmos_close_w5_alpha/tmos_close_w30_alpha',
#         'tmos_close_w10_alpha/tmos_close_w120_alpha',
#         'tmos_close_w20_alpha/tmos_close_w120_alpha',
#         'close_w1_roc/close_w5_roc', 'close_w10_roc/close_w120_roc',
#         'close_w20_roc/close_w30_roc',
#         'tmos_close_w10_roc/tmos_close_w60_roc',
#         'tmos_close_w20_roc/tmos_close_w30_roc',
#         'tmos_close_w20_roc/tmos_close_w60_roc',
#         'tmos_close_w30_roc/tmos_close_w120_roc',
#         'tmos_close_w60_roc/tmos_close_w120_roc',
#         'close_w60_std/close_w120_std', 'close_w60_rsi/close_w120_rsi',
#         'volume_w60_rsi/volume_w120_rsi',
#         'tmos_close_w5_rsi/tmos_close_w20_rsi',
#         'tmos_close_w5_rsi/tmos_close_w30_rsi', 'volume/volume_w30_ma',
#         'volume/volume_w60_ma', 'volume/volume_w120_ma',
#         'volume/volume_w120_expma', 'tmos_close/tmos_close_w5_expma',
#         'volume_w60_min/volume', 'volume_w120_min/volume',
#         'volume_w20_max/volume', 'volume_w30_max/volume',
#         'volume_w60_max/volume', 'volume_w120_max/volume',
#         'tmos_close_w10_max/tmos_close', 'volume_w20_ma_up_2std/volume',
#         'volume_w30_ma_up_2std/volume', 'volume_w60_ma_low_2std/volume',
#         'volume_w60_ma_up_2std/volume', 'volume_w120_ma_low_2std/volume',
#         'volume_w120_ma_up_2std/volume', 'ticker_code'], dtype=object))

# %%
df_auc.loc[df_auc['feature'].isin(features_criteria1)].sort_values('auc_valid', ascending=False)
# Out:
#                                         feature  auc_train  auc_valid  \
# 95                                         hour   0.573466   0.553799
# 86                    close_w120_lvl_1.01-1.015   0.566180   0.548346
# 88                    close_w120_lvl_1.015-1.02   0.548579   0.544840
# 49                     close_w30_lvl_1.005-1.01   0.555634   0.537255
# 47                        close_w30_lvl_1-1.005   0.545652   0.535562
# 50                    close_w30_lvl_-0.99-0.995   0.556500   0.532658
# 90                     close_w120_lvl_1.02-1.03   0.535564   0.531783
# 14                            tmos_close_w5_roc   0.537170   0.531256
# 473                                 ticker_code   0.533284   0.526947
# 435               tmos_close_w10_max/tmos_close   0.530336   0.524134
# 57                  tmos_close_w30_lvl_-0.995-1   0.524791   0.523263
# 89                   close_w120_lvl_-0.98-0.985   0.544273   0.521303
# 421                      volume_w120_min/volume   0.533439   0.519937
# 409              tmos_close/tmos_close_w5_expma   0.524064   0.518320
# 326        tmos_close_w5_rsi/tmos_close_w30_rsi   0.525663   0.518002
# 135     tmos_close_w1_roc/tmos_close_w120_alpha   0.514964   0.517730
# 51                     close_w30_lvl_1.01-1.015   0.525887   0.517616
# 204      tmos_close_w60_roc/tmos_close_w120_roc   0.540383   0.516670
# 200       tmos_close_w20_roc/tmos_close_w30_roc   0.535763   0.516540
# 67                                close_w60_rsi   0.531172   0.516112
# 433                       volume_w60_max/volume   0.529425   0.515676
# 420                       volume_w60_min/volume   0.524521   0.515662
# 203      tmos_close_w30_roc/tmos_close_w120_roc   0.535326   0.515286
# 325        tmos_close_w5_rsi/tmos_close_w20_rsi   0.523059   0.514835
# 456               volume_w60_ma_low_2std/volume   0.528738   0.514796
# 82                              volume_w120_rsi   0.529978   0.514293
# 309                close_w60_rsi/close_w120_rsi   0.514733   0.514125
# 432                       volume_w30_max/volume   0.526471   0.514007
# 457                volume_w60_ma_up_2std/volume   0.524614   0.513847
# 434                      volume_w120_max/volume   0.530741   0.513737
# 147  tmos_close_w20_alpha/tmos_close_w120_alpha   0.524291   0.513716
# 48                       close_w30_lvl_-0.995-1   0.525129   0.513696
# 453                volume_w30_ma_up_2std/volume   0.522338   0.513352
# 119           volume_w5_alpha/volume_w120_alpha   0.536218   0.512984
# 144  tmos_close_w10_alpha/tmos_close_w120_alpha   0.519713   0.512938
# 45                               volume_w30_rsi   0.522653   0.512934
# 460              volume_w120_ma_low_2std/volume   0.528757   0.512822
# 355                        volume/volume_w60_ma   0.519220   0.512793
# 431                       volume_w20_max/volume   0.523241   0.512490
# 354                        volume/volume_w30_ma   0.516670   0.512360
# 72                               volume_w60_rsi   0.527036   0.512067
# 461               volume_w120_ma_up_2std/volume   0.524560   0.512054
# 136    tmos_close_w5_alpha/tmos_close_w10_alpha   0.519190   0.511851
# 448                volume_w20_ma_up_2std/volume   0.519852   0.511720
# 198       tmos_close_w10_roc/tmos_close_w60_roc   0.529434   0.511516
# 356                       volume/volume_w120_ma   0.518197   0.511409
# 118            volume_w5_alpha/volume_w60_alpha   0.528562   0.511265
# 264                close_w60_std/close_w120_std   0.513766   0.510995
# 138    tmos_close_w5_alpha/tmos_close_w30_alpha   0.516712   0.510915
# 323              volume_w60_rsi/volume_w120_rsi   0.522353   0.510894
# 201       tmos_close_w20_roc/tmos_close_w60_roc   0.528891   0.510734
# 393                    volume/volume_w120_expma   0.516973   0.510719
# 52                    close_w30_lvl_-0.985-0.99   0.521302   0.510653
# 91                    close_w120_lvl_-0.97-0.98   0.527709   0.510553
# 151                   close_w1_roc/close_w5_roc   0.530924   0.510346
# 166                 close_w20_roc/close_w30_roc   0.521665   0.510228
# 165                close_w10_roc/close_w120_roc   0.521013   0.510041
#
#      auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 95   0.551311   0.517302          -0.001046          -0.001328
# 86   0.558018   0.526736          -0.000892          -0.001072
# 88   0.547171   0.529807          -0.000654          -0.000697
# 49   0.542629   0.531899          -0.000844          -0.001108
# 47   0.537053   0.524780          -0.001066          -0.001260
# 50   0.539491   0.526741          -0.001342          -0.001512
# 90   0.533851   0.522746          -0.000291          -0.000367
# 14   0.513152   0.522922           0.000480          -0.001264
# 473  0.513476   0.513338          -0.000928          -0.001206
# 435  0.511999   0.507282          -0.001209          -0.001389
# 57   0.516360   0.516983          -0.000727          -0.000928
# 89   0.529279   0.531238          -0.001183          -0.001470
# 421  0.532385   0.520921          -0.001339          -0.001575
# 409  0.513149   0.525191           0.000428          -0.000861
# 326  0.522364   0.521592          -0.000885          -0.001203
# 135  0.510237   0.514530          -0.000938          -0.000961
# 51   0.520630   0.516958          -0.000435          -0.000768
# 204  0.524760   0.509849          -0.000036          -0.001261
# 200  0.511204   0.512416          -0.000336          -0.001031
# 67   0.519182   0.525308          -0.000687          -0.001205
# 433  0.514790   0.514051          -0.000843          -0.001274
# 420  0.525809   0.516591          -0.001257          -0.001527
# 203  0.524676   0.506718          -0.000944          -0.001181
# 325  0.524097   0.518855          -0.000867          -0.001202
# 456  0.514380   0.514301          -0.000882          -0.001254
# 82   0.513345   0.508605          -0.000741          -0.001230
# 309  0.517961   0.509749          -0.000948          -0.001201
# 432  0.513946   0.512017          -0.000884          -0.001241
# 457  0.512878   0.513266          -0.000895          -0.001263
# 434  0.515251   0.514147          -0.000848          -0.001265
# 147  0.528759   0.517587          -0.000980          -0.001275
# 48   0.513135   0.515273          -0.001008          -0.001290
# 453  0.512719   0.510772          -0.000911          -0.001237
# 119  0.515575   0.511560          -0.000946          -0.001322
# 144  0.527026   0.519183          -0.001022          -0.001266
# 45   0.510100   0.508888          -0.000903          -0.001234
# 460  0.514775   0.514607          -0.000813          -0.001288
# 355  0.510005   0.511164          -0.000856          -0.001230
# 431  0.512824   0.511217          -0.000901          -0.001251
# 354  0.510308   0.509032          -0.000933          -0.001252
# 393         -0.021035          -0.016954
# 52          -0.054473          -0.049582
# 91          -0.054926          -0.046896
# 151         -0.014452          -0.011459
# 166         -0.022623          -0.017397
# 165         -0.022098          -0.017514

# %%
features_criteria2 = df_auc['feature'].values[~mask_criterias2]
len(features_criteria2), features_criteria2
# Out:
# (41,
#  array(['tmos_close_w5_roc', 'close_w30_lvl_1-1.005',
#         'close_w30_lvl_-0.995-1', 'close_w30_lvl_1.005-1.01',
#         'close_w30_lvl_1.01-1.015', 'close_w30_lvl_-0.985-0.99',
#         'tmos_close_w30_lvl_-0.995-1', 'close_w60_rsi', 'volume_w60_rsi',
#         'close_w120_lvl_1.015-1.02', 'close_w120_lvl_-0.98-0.985',
#         'close_w120_lvl_1.02-1.03', 'close_w120_lvl_-0.97-0.98',
#         'volume_w5_alpha/volume_w60_alpha',
#         'volume_w5_alpha/volume_w120_alpha',
#         'tmos_close_w1_roc/tmos_close_w120_alpha',
#         'tmos_close_w5_alpha/tmos_close_w10_alpha',
#         'tmos_close_w5_alpha/tmos_close_w30_alpha',
#         'tmos_close_w10_alpha/tmos_close_w120_alpha',
#         'tmos_close_w20_alpha/tmos_close_w120_alpha',
#         'close_w10_roc/close_w120_roc',
#         'tmos_close_w20_roc/tmos_close_w30_roc',
#         'tmos_close_w20_roc/tmos_close_w60_roc',
#         'tmos_close_w5_rsi/tmos_close_w20_rsi',
#         'tmos_close_w5_rsi/tmos_close_w30_rsi', 'volume/volume_w60_ma',
#         'volume/volume_w120_ma', 'volume/volume_w120_expma',
#         'tmos_close/tmos_close_w5_expma', 'volume_w60_min/volume',
#         'volume_w120_min/volume', 'volume_w20_max/volume',
#         'volume_w30_max/volume', 'volume_w60_max/volume',
#         'volume_w120_max/volume', 'volume_w30_ma_up_2std/volume',
#         'volume_w60_ma_low_2std/volume', 'volume_w60_ma_up_2std/volume',
#         'volume_w120_ma_low_2std/volume', 'volume_w120_ma_up_2std/volume',
#         'ticker_code'], dtype=object))

# %%
pd.set_option('display.max_rows', 160)
df_auc.loc[df_auc['feature'].isin(features_criteria2)].sort_values('auc_valid', ascending=False)
# Out:
#                                         feature  auc_train  auc_valid  \
# 88                    close_w120_lvl_1.015-1.02   0.548579   0.544840
# 49                     close_w30_lvl_1.005-1.01   0.555634   0.537255
# 47                        close_w30_lvl_1-1.005   0.545652   0.535562
# 90                     close_w120_lvl_1.02-1.03   0.535564   0.531783
# 14                            tmos_close_w5_roc   0.537170   0.531256
# 473                                 ticker_code   0.533284   0.526947
# 57                  tmos_close_w30_lvl_-0.995-1   0.524791   0.523263
# 89                   close_w120_lvl_-0.98-0.985   0.544273   0.521303
# 421                      volume_w120_min/volume   0.533439   0.519937
# 409              tmos_close/tmos_close_w5_expma   0.524064   0.518320
# 326        tmos_close_w5_rsi/tmos_close_w30_rsi   0.525663   0.518002
# 135     tmos_close_w1_roc/tmos_close_w120_alpha   0.514964   0.517730
# 51                     close_w30_lvl_1.01-1.015   0.525887   0.517616
# 200       tmos_close_w20_roc/tmos_close_w30_roc   0.535763   0.516540
# 67                                close_w60_rsi   0.531172   0.516112
# 433                       volume_w60_max/volume   0.529425   0.515676
# 420                       volume_w60_min/volume   0.524521   0.515662
# 325        tmos_close_w5_rsi/tmos_close_w20_rsi   0.523059   0.514835
# 456               volume_w60_ma_low_2std/volume   0.528738   0.514796
# 432                       volume_w30_max/volume   0.526471   0.514007
# 457                volume_w60_ma_up_2std/volume   0.524614   0.513847
# 434                      volume_w120_max/volume   0.530741   0.513737
# 147  tmos_close_w20_alpha/tmos_close_w120_alpha   0.524291   0.513716
# 48                       close_w30_lvl_-0.995-1   0.525129   0.513696
# 453                volume_w30_ma_up_2std/volume   0.522338   0.513352
# 119           volume_w5_alpha/volume_w120_alpha   0.536218   0.512984
# 144  tmos_close_w10_alpha/tmos_close_w120_alpha   0.519713   0.512938
# 460              volume_w120_ma_low_2std/volume   0.528757   0.512822
# 355                        volume/volume_w60_ma   0.519220   0.512793
# 431                       volume_w20_max/volume   0.523241   0.512490
# 72                               volume_w60_rsi   0.527036   0.512067
# 461               volume_w120_ma_up_2std/volume   0.524560   0.512054
# 136    tmos_close_w5_alpha/tmos_close_w10_alpha   0.519190   0.511851
# 356                       volume/volume_w120_ma   0.518197   0.511409
# 118            volume_w5_alpha/volume_w60_alpha   0.528562   0.511265
# 138    tmos_close_w5_alpha/tmos_close_w30_alpha   0.516712   0.510915
# 201       tmos_close_w20_roc/tmos_close_w60_roc   0.528891   0.510734
# 393                    volume/volume_w120_expma   0.516973   0.510719
# 52                    close_w30_lvl_-0.985-0.99   0.521302   0.510653
# 91                    close_w120_lvl_-0.97-0.98   0.527709   0.510553
# 165                close_w10_roc/close_w120_roc   0.521013   0.510041
#
#      auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 88   0.547171   0.529807          -0.000654          -0.000697
# 49   0.542629   0.531899          -0.000844          -0.001108
# 47   0.537053   0.524780          -0.001066          -0.001260
# 90   0.533851   0.522746          -0.000291          -0.000367
# 14   0.513152   0.522922           0.000480          -0.001264
# 473  0.513476   0.513338          -0.000928          -0.001206
# 57   0.516360   0.516983          -0.000727          -0.000928
# 89   0.529279   0.531238          -0.001183          -0.001470
# 421  0.532385   0.520921          -0.001339          -0.001575
# 409  0.513149   0.525191           0.000428          -0.000861
# 326  0.522364   0.521592          -0.000885          -0.001203
# 135  0.510237   0.514530          -0.000938          -0.000961
# 51   0.520630   0.516958          -0.000435          -0.000768
# 200  0.511204   0.512416          -0.000336          -0.001031
# 67   0.519182   0.525308          -0.000687          -0.001205
# 433  0.514790   0.514051          -0.000843          -0.001274
# 420  0.525809   0.516591          -0.001257          -0.001527
# 325  0.524097   0.518855          -0.000867          -0.001202
# 456  0.514380   0.514301          -0.000882          -0.001254
# 432  0.513946   0.512017          -0.000884          -0.001241
# 457  0.512878   0.513266          -0.000895          -0.001263
# 434  0.515251   0.514147          -0.000848          -0.001265
# 147  0.528759   0.517587          -0.000980          -0.001275
# 48   0.513135   0.515273          -0.001008          -0.001290
# 453  0.512719   0.510772          -0.000911          -0.001237
# 119  0.515575   0.511560          -0.000946          -0.001322
col = 'mir_tick@1'
threshold = 0.00

mask_ir_train = df_auc[f'{col}_train'] >=  threshold
mask_ir_valid = df_auc[f'{col}_valid'] >=  threshold
mask_ir_test = df_auc[f'{col}_test'] >= threshold
mask_ir_test2 = df_auc[f'{col}_test2'] >=  threshold


mask_ir_train.sum(), mask_ir_valid.sum(), mask_ir_test.sum(), mask_ir_test2.sum()
# Out:
# (30, 22, 24, 26)

# %%
mask_ir= mask_ir_valid&mask_ir_test&mask_ir_test2

#mask_ir= mask_ir_train&mask_ir_valid&mask_ir_test&mask_ir_test2
mask_ir.sum()
# Out:
# 20

# %% [markdown]
# #### #2

# %%
col = 'mir_tick@1'
threshold = 0.01

mask_ir2_test = np.abs(df_auc[f'{col}_valid'] - df_auc[f'{col}_test']) < threshold
mask_ir2_test2 = np.abs(df_auc[f'{col}_valid'] - df_auc[f'{col}_test2']) < threshold


mask_ir2_test.sum(), mask_ir2_test2.sum()
# Out:
# (66, 66)

# %%
mask_ir2= mask_ir2_test&mask_ir2_test2
mask_ir2.sum()
# Out:
# 66

# %%
(mask_ir&mask_ir2).sum()
# Out:
# 20

# %%
mask_criteria3 = mask_ir#&mask_ir2
features_criteria3 = df_auc['feature'].values[mask_criteria3]
len(features_criteria3), features_criteria3
# Out:
# (20,
#  array(['close_w30_lvl_1.015-1.02', 'close_w30_lvl_1.02-1.03',
#         'close_w120_lvl_1.02-1.03', 'close/close_w5_expma',
#         'close/close_w10_expma', 'close/close_w20_expma',
#         'close/close_w30_expma', 'close/close_w60_expma',
#         'close/close_w120_expma', 'close_w5_expma/close_w20_expma',
#         'close_w5_expma/close_w30_expma', 'close_w5_expma/close_w60_expma',
#         'close_w5_expma/close_w120_expma',
#         'close_w10_expma/close_w30_expma',
#         'close_w10_expma/close_w60_expma',
#         'close_w10_expma/close_w120_expma',
#         'close_w20_expma/close_w60_expma',
#         'close_w20_expma/close_w120_expma',
#         'close_w30_expma/close_w60_expma',
#         'close_w30_expma/close_w120_expma'], dtype=object))

# %%
pd.set_option('display.max_rows', 160)
df_auc.loc[df_auc['feature'].isin(features_criteria3)].sort_values('auc_valid', ascending=False)
# Out:
#                              feature  auc_train  auc_valid  auc_test  \
# 56  close_w30_expma/close_w120_expma   0.652453   0.577199  0.602284
# 54  close_w20_expma/close_w120_expma   0.653745   0.577021  0.596964
# 51  close_w10_expma/close_w120_expma   0.650655   0.576594  0.594830
# 47   close_w5_expma/close_w120_expma   0.651036   0.575704  0.594564
# 42            close/close_w120_expma   0.652465   0.575353  0.593780
# 53   close_w20_expma/close_w60_expma   0.645952   0.575164  0.591555
# 55   close_w30_expma/close_w60_expma   0.649275   0.574088  0.594535
# 41             close/close_w60_expma   0.641906   0.572663  0.589354
# 40             close/close_w30_expma   0.630356   0.571922  0.576216
# 38             close/close_w10_expma   0.626517   0.571865  0.579703
# 46    close_w5_expma/close_w60_expma   0.641906   0.570995  0.588653
# 45    close_w5_expma/close_w30_expma   0.635061   0.570426  0.578624
# 49   close_w10_expma/close_w30_expma   0.629381   0.569862  0.579444
# 42                     0.240449
# 53                     0.205882
# 55                     0.204832
# 41                     0.230428
# 40                     0.232611
# 38                     0.231622
# 46                     0.210933
# 45                     0.211276
# 49                     0.205933
# 39                     0.236676
# 50                     0.211549
# 44                     0.218250
# 37                     0.230228
# 31                     0.173913
# 11                     0.209901
# 13                     0.270797

# %% [markdown]
# ### model

# %%
features = features_criteria3.tolist()# + ['ticker_code']
#features = ['close/close_w30_expma']
cat_features = [feature for feature in features if feature in cat_features_all]

# %%
len(features), len(cat_features)
# Out:
# (20, 0)

# %%
features
# Out:
# ['close_w30_lvl_1.015-1.02',
#  'close_w30_lvl_1.02-1.03',
#  'close_w120_lvl_1.02-1.03',
#  'close/close_w5_expma',
#  'close/close_w10_expma',
#  'close/close_w20_expma',
#  'close/close_w30_expma',
#  'close/close_w60_expma',
#  'close/close_w120_expma',
#  'close_w5_expma/close_w20_expma',
#  'close_w5_expma/close_w30_expma',
#  'close_w5_expma/close_w60_expma',
#  'close_w5_expma/close_w120_expma',
#  'close_w10_expma/close_w30_expma',
#  'close_w10_expma/close_w60_expma',
#  'close_w10_expma/close_w120_expma',
#  'close_w20_expma/close_w60_expma',
#  'close_w20_expma/close_w120_expma',
#  'close_w30_expma/close_w60_expma',
#  'close_w30_expma/close_w120_expma']

# %%
cat_features
# Out:
# []

# %%
'ticker_code' in features
# Out:
# False

# %%
D_train = lgbm.Dataset(df.loc[mask_train, features], label=df.loc[mask_train, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, features], label=df.loc[mask_valid, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, features], label=df.loc[mask_test, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, features], label=df.loc[mask_test2, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)


D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
D_test3 = lgbm.Dataset(df.loc[mask_test3, features], label=df.loc[mask_test3, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
D_test3.time = df.loc[mask_test3, 'time'].values

# %%
# def mean_income_rate(y_pred, D_sample):
#     q = 0.995
#     mask = y_pred >= np.quantile(y_pred, q)
#     #mask = y_pred >= threshold
#     df_sup = pd.DataFrame({'time' : D_sample.time,
#                            'income_rate' : D_sample.income_rate,
#                            'y_pred' : y_pred})
#     # # # month
#     # score = (df_sup[mask].groupby('time').income_rate.mean()-1).reset_index().groupby(pd.Grouper(key='time', freq='D')).income_rate.mean().mean() * df_sup.loc[mask, 'time'].dt.date.nunique() 
#     # score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month

#     #tick <----
#     score = (df_sup[mask].groupby('time').income_rate.mean()-1).mean()

#     #day
#     #score = (df_sup[mask].groupby('time').income_rate.mean()-1).reset_index().groupby(pd.Grouper(key='time', freq='D')).income_rate.mean().mean()
    
#     # point
#     # score = np.mean(D_sample.income_rate[mask]) - 1

#     # #point win_rate
#     # score = np.mean(D_sample.label[mask])

#     score = round(score, 4)

#     return 'mean_income_rate', score, True#is_higher_better





params = {
    "boosting_type": "gbdt",
    "objective": "binary",
    
    
    "num_boost_round" : 100,

    
    "num_leaves": 31,
    #"learning_rate": 0.001,
     "feature_fraction": 0.5,
     "bagging_fraction": 0.5,
     "bagging_freq": 1,
     'lambda_l1' : 1,
     'lambda_l2' : 1,
    #"verbose": 0,

    #'max_bin' : 100000,
    
    
    # "metric": "auc",
      "metric" : 'mean_income_rate',
     "early_stopping" : 10,



    
}


    

model = lgbm.train(params, train_set=D_train, valid_sets=[D_valid], feval=mean_income_rate, )

# %%
model.num_trees()
# Out:
# 40

# %%
y_pred_train = model.predict(D_train.data)
y_pred_valid = model.predict(D_valid.data)
y_pred_test = model.predict(D_test.data)
y_pred_test2 = model.predict(D_test2.data)


df["y_pred"] = None
df.loc[mask_train, 'y_pred'] = y_pred_train
df.loc[mask_valid, 'y_pred'] = y_pred_valid
df.loc[mask_test, 'y_pred'] = y_pred_test
df.loc[mask_test2, 'y_pred'] = y_pred_test2


roc_auc_score(D_train.label, y_pred_train), roc_auc_score(D_valid.label, y_pred_valid), roc_auc_score(D_test.label, y_pred_test), roc_auc_score(D_test2.label, y_pred_test2)
# Out:
# (0.7025711969626249, 0.6298755562863968, 0.645032586678947, 0.6058706493102992)

# %%
#свой threshold

q = 0.995

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest')
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# Valid
# result
# LOSE    0.683322
# WIN     0.270088
# DNF     0.046590
# Name: proportion, dtype: float64
# 1.0012849177322543
#
# Test
# result
# LOSE    0.659199
# WIN     0.283775
# DNF     0.057026
# Name: proportion, dtype: float64
# 1.0016447039825611
#
# Test2
# result
# LOSE    0.688293
# WIN     0.265867
# DNF     0.045839
# Name: proportion, dtype: float64
# 1.0012425203585658

# %%
#общий threshold

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
print(f'threshokd = {threshold}')

mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print("\nTest")
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print('\nTetst2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# threshokd = 0.22686240875366323
#
# Valid
# result
# LOSE    0.683322
# WIN     0.270088
# DNF     0.046590
# Name: proportion, dtype: float64
# 1.0012849177322543
#
# Test
# result
# LOSE    0.656388
# WIN     0.290015
# DNF     0.053598
# Name: proportion, dtype: float64
# 1.0017278950207384
#
# Tetst2
# result
# LOSE    0.686977
# WIN     0.265830
# DNF     0.047192
# Name: proportion, dtype: float64
# 1.0012620068294316

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold

mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_point(D_test, y_pred_test, threshold=threshold), mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0012849177322542538, 0.0017278950207384458, 0.0012620068294315612)

# %%
# .995 - (0.0008561006111744707, 0.00177121592551166, 0.0011695352546039484)

# %%
df.loc[mask_valid, 'income_rate'].mean(), df.loc[mask_test, 'income_rate'].mean(), df.loc[mask_test2, 'income_rate'].mean()
# Out:
# (0.999021106977962, 0.9991688566585647, 0.9993119785725331)

# %%
mean_income_rate_tick(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_tick(D_test, y_pred_test, threshold=threshold), mean_income_rate_tick(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0013330073626474153, 0.00147042444041614, 0.0014114892615433932)

# %%
# .995 - (0.0007814215695842821, 0.00156363492795524, 0.001354118344244738)

# %%
mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_day(D_test, y_pred_test, threshold=threshold), mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.00281223237391289, 0.0022626485193476963, 0.0028311847964323047)

# %%
# .995 - (0.002956433856013124, 0.0030462696732010013, 0.0025753294595332685)

# %%
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.06049424306550394, 0.049778267425649315, 0.05359498661153247)

# %%
# .995 - (0.06359617716934898, 0.06549479797382153, 0.05138680642510568)

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 00:11:00'),
#  Timedelta('0 days 00:14:00'),
#  Timedelta('0 days 00:10:00'))

# %%
mask_win = df['target'] == 1
df.loc[mask_valid&mask&mask_win, 'delta_time'].median(), df.loc[mask_test&mask&mask_win, 'delta_time'].median(), df.loc[mask_test2&mask&mask_win, 'delta_time'].median()
# Out:
# (Timedelta('0 days 00:27:00'),
#  Timedelta('0 days 00:32:00'),
#  Timedelta('0 days 00:24:00'))

# %%
# (Timedelta('0 days 00:17:30'),
#  Timedelta('0 days 00:20:30'),
#  Timedelta('0 days 00:16:00'))

# %%
(mask_valid&mask).sum(), (mask_test&mask).sum(), (mask_test2&mask).sum()
# Out:
# (1481, 1362, 1674)

# %%
df.loc[mask_valid&mask, 'time'].dt.date.nunique(), df.loc[mask_test&mask, 'time'].dt.date.nunique(), df.loc[mask_test2&mask, 'time'].dt.date.nunique()
# Out:
# (44, 44, 37)

# %%
df.loc[mask_test2&mask, 'ticker'].unique()
# Out:
# array(['ABIO', 'AFKS', 'AFLT', 'ALRS', 'APTK', 'AQUA', 'BANE', 'BANEP',
#        'BELU', 'BSPB', 'CBOM', 'CHMF', 'ENPG', 'FEES', 'FESH', 'FLOT',
#        'GAZP', 'GMKN', 'GTRK', 'HEAD', 'HYDR', 'IRKT', 'KMAZ', 'LENT',
#        'LIFE', 'LSRG', 'MAGN', 'MGNT', 'MOEX', 'MTLR', 'MTLRP', 'MTSS',
#        'MVID', 'NLMK', 'NMTP', 'NVTK', 'OGKB', 'PHOR', 'PIKK', 'PLZL',
#        'POSI', 'RASP', 'RENI', 'RNFT', 'ROSN', 'RTKM', 'RTKMP', 'RUAL',
#        'SELG', 'SFIN', 'SGZH', 'SMLT', 'SNGS', 'SNGSP', 'SPBE', 'SVAV',
#        'T', 'TATN', 'TATNP', 'TGKN', 'TRMK', 'TRNFP', 'UNAC', 'UPRO',
#        'UWGN', 'VKCO', 'VSMO', 'VTBR', 'WUSH', 'YDEX'], dtype=object)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_93253/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#         count  income_rate
# ticker
# TATNP     1.0     1.014000
# SNGS      1.0     1.014000
# GMKN      2.0     1.014000
# AQUA      2.0     1.005000
# PLZL      2.0     0.996000
# LENT      2.0     0.999206
# TATN      3.0     1.002000
# PHOR      3.0     1.008000
# ROSN      4.0     1.005000
# UPRO      4.0     1.003262
# SFIN      4.0     1.000500
# HEAD      5.0     1.004703
# RENI      5.0     1.006800
# NVTK      5.0     1.003679
# FESH      5.0     1.006800
# BSPB      5.0     1.003200
# BANEP     5.0     1.009098
# VTBR      5.0     0.999600
# ALRS      6.0     0.996000
# AFLT      6.0     0.999000
# HYDR      6.0     1.003998
# SNGSP     6.0     1.006909
# MGNT      7.0     1.001143
# NLMK      7.0     1.000431
# GAZP      7.0     0.996000
# T         7.0     1.001485
# RUAL      9.0     1.006000
# ENPG      9.0     1.004352
# RTKM      9.0     1.004000
# YDEX      9.0     0.996000
# NMTP     10.0     1.009906
# MAGN     10.0     1.002704
# FLOT     10.0     1.009725
# SPBE     11.0     1.004511
# CHMF     13.0     0.998769
# MOEX     13.0     1.004389
# FEES     13.0     1.000154
# TRNFP    13.0     1.005692
# TRMK     14.0     1.000380
# OGKB     14.0     1.005000
# RTKMP    14.0     1.001143
# BELU     15.0     1.003200
# LSRG     17.0     0.997059
# KMAZ     18.0     1.000320
# MTSS     21.0     1.003911
# AFKS     21.0     1.002269
# VSMO     24.0     1.003729
# APTK     26.0     1.002923
# RASP     28.0     0.999250
# SELG     30.0     1.001160
# MTLR     31.0     1.001577
# WUSH     33.0     0.998182
# CBOM     34.0     1.004121
# RNFT     34.0     0.998647
# VKCO     37.0     1.001351
# MTLRP    39.0     1.001285
# LIFE     42.0     1.003482
# UNAC     42.0     1.001571
# SVAV     43.0     1.001085
# MVID     43.0     1.003726
# ABIO     53.0     0.999606
# POSI     62.0     0.998175
# BANE     65.0     1.000377
# PIKK     69.0     0.998959
# UWGN     72.0     1.002500
# IRKT     76.0     1.000970
# TGKN     98.0     1.001110
# SGZH    104.0     1.000846
# GTRK    105.0     1.001767
# SMLT    106.0     0.998571

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: -x[1])
# Out:
# [('close_w20_expma/close_w120_expma', 16.04),
#  ('close_w120_lvl_1.02-1.03', 13.97),
#  ('close_w10_expma/close_w120_expma', 11.98),
#  ('close_w30_expma/close_w120_expma', 8.87),
#  ('close/close_w5_expma', 6.41),
#  ('close_w30_expma/close_w60_expma', 5.88),
#  ('close/close_w10_expma', 5.81),
#  ('close_w5_expma/close_w120_expma', 5.65),
#  ('close_w5_expma/close_w30_expma', 4.97),
#  ('close_w10_expma/close_w30_expma', 3.81),
#  ('close_w20_expma/close_w60_expma', 3.43),
#  ('close/close_w120_expma', 2.69),
#  ('close_w5_expma/close_w20_expma', 2.06),
#  ('close_w10_expma/close_w60_expma', 2.02),
#  ('close/close_w60_expma', 1.62),
#  ('close/close_w30_expma', 1.58),
#  ('close_w5_expma/close_w60_expma', 1.44),
#  ('close/close_w20_expma', 1.13),
#  ('close_w30_lvl_1.015-1.02', 0.62),
#  ('close_w30_lvl_1.02-1.03', 0.0)]

# %%
y_pred_test3 = model.predict(D_test3.data)
df.loc[mask_test3, 'y_pred'] = y_pred_test3
roc_auc_score(D_test3.label, y_pred_test3)
# Out:
# 0.6111016395458265

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.995)
mask = df['y_pred'] >= threshold

# %%
mean_income_rate_point(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.0020222154471392084

# %%
#0.0022104875426873782

# %%
mean_income_rate_tick(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.0016217853101192132

# %%
#0.0018932624582072178

# %%
mean_income_rate_day(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.0029105116347322713

# %%
#0.002840009902855707

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.055606090705674446

# %%
#0.055903352824633386

# %%
(mask&mask_test3).sum()
# Out:
# 915

# %%
df.loc[mask&mask_test3, 'time'].dt.date.nunique(), df.loc[mask_test3, 'time'].dt.date.nunique(),
# Out:
# (33, 38)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_93253/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#         count  income_rate
# ticker
# TATNP     1.0     1.014000
# SNGS      1.0     1.014000
# GMKN      2.0     1.014000
# AQUA      2.0     1.005000
# PLZL      2.0     0.996000
# LENT      2.0     0.999206
# TATN      3.0     1.002000
# PHOR      3.0     1.008000
# ROSN      4.0     1.005000
# UPRO      4.0     1.003262
# SFIN      4.0     1.000500
# HEAD      5.0     1.004703
# RENI      5.0     1.006800
# NVTK      5.0     1.003679
# FESH      5.0     1.006800
# BSPB      5.0     1.003200
# BANEP     5.0     1.009098
# VTBR      5.0     0.999600
# ALRS      6.0     0.996000
# AFLT      6.0     0.999000
# HYDR      6.0     1.003998
# SNGSP     6.0     1.006909
# MGNT      7.0     1.001143
# NLMK      7.0     1.000431
# GAZP      7.0     0.996000
# T         7.0     1.001485
# RUAL      9.0     1.006000
# ENPG      9.0     1.004352
# RTKM      9.0     1.004000
# YDEX      9.0     0.996000
# NMTP     10.0     1.009906
# MAGN     10.0     1.002704
# FLOT     10.0     1.009725
# SPBE     11.0     1.004511
# CHMF     13.0     0.998769
# MOEX     13.0     1.004389
# FEES     13.0     1.000154
# TRNFP    13.0     1.005692
# TRMK     14.0     1.000380
# OGKB     14.0     1.005000
# RTKMP    14.0     1.001143
# BELU     15.0     1.003200
# LSRG     17.0     0.997059
# KMAZ     18.0     1.000320
# MTSS     21.0     1.003911
# AFKS     21.0     1.002269
# VSMO     24.0     1.003729
# APTK     26.0     1.002923
# RASP     28.0     0.999250
# SELG     30.0     1.001160
# MTLR     31.0     1.001577
# WUSH     33.0     0.998182
# CBOM     34.0     1.004121
# RNFT     34.0     0.998647
# VKCO     37.0     1.001351
# MTLRP    39.0     1.001285
# LIFE     42.0     1.003482
# UNAC     42.0     1.001571
# SVAV     43.0     1.001085
# MVID     43.0     1.003726
# ABIO     53.0     0.999606
# POSI     62.0     0.998175
# BANE     65.0     1.000377
# PIKK     69.0     0.998959
# UWGN     72.0     1.002500
# IRKT     76.0     1.000970
# TGKN     98.0     1.001110
# SGZH    104.0     1.000846
# GTRK    105.0     1.001767
# SMLT    106.0     0.998571

# %%
i = 320
df.loc[mask&mask_test3, ['time', 'ticker','close', 'target', 'income_rate', 'delta_time']].iloc[i:i+20]
# Out:
#                        time ticker        close  target income_rate  \
# 2176434 2025-02-14 16:34:00   NMTP    10.075000       0       0.994
# 2176435 2025-02-14 16:35:00   NMTP    10.070000       0       0.994
# 2176436 2025-02-14 16:36:00   NMTP    10.050000       0       0.994
# 2176437 2025-02-14 16:40:00   NMTP     9.965000       1       1.012
# 2176438 2025-02-14 16:41:00   NMTP     9.975000       1       1.012
# 2176439 2025-02-14 16:46:00   NMTP    10.000000       1       1.012
# 2176442 2025-02-14 17:03:00   NMTP    10.000000       1       1.012
# 2176678 2025-02-18 15:33:00   NMTP    10.215000       1       1.012
# 2245021 2025-02-14 13:35:00   NVTK  1220.000000       0       0.994
# 2245022 2025-02-14 13:49:00   NVTK  1226.800049       0       0.994
# 2245023 2025-02-14 13:50:00   NVTK  1220.599976       1       1.012
# 2245054 2025-02-14 16:36:00   NVTK  1202.199951       1       1.012
# 2245055 2025-02-14 16:38:00   NVTK  1200.199951       1       1.012
# 2295217 2025-01-03 12:11:00   OGKB     0.338200       0       0.994
# 2295546 2025-01-09 13:09:00   OGKB     0.326200       0       0.994
# 2295547 2025-01-09 13:16:00   OGKB     0.327000       0       0.994
# 2295548 2025-01-09 13:21:00   OGKB     0.326700       0       0.994
# 2295551 2025-01-09 13:38:00   OGKB     0.323500       1       1.012
# 2295552 2025-01-09 13:48:00   OGKB     0.321900       1       1.012
# 2295553 2025-01-09 13:55:00   OGKB     0.322900       1       1.012
#
#              delta_time
# 2176434 0 days 00:04:00
# 2176435 0 days 00:03:00
# 2176436 0 days 00:02:00
# 2176437 0 days 00:32:00
# 2176438 0 days 00:33:00
# 2176439 0 days 00:29:00
# 2176442 0 days 00:12:00
# 2176678 0 days 01:11:00
# 2245021 0 days 00:01:00
# 2245022 0 days 00:01:00
# 2245023 0 days 00:16:00
# 2245054 0 days 02:39:00
# 2245055 0 days 01:51:00
# 2295217 0 days 00:34:00
# 2295546 0 days 00:28:00
# 2295547 0 days 00:21:00
# 2295548 0 days 00:16:00
# 2295551 0 days 03:12:00
# 2295552 0 days 02:51:00
# 2295553 0 days 02:54:00

# %% [markdown]
# # 3.2 Tuning hyperparams

# %%
top_features = [elem[0] for elem in zip(features, model.feature_importance(importance_type='gain')) if elem[1] > 0]
top_cat_features = [elem for elem in top_features if elem in cat_features]

# %%
len(top_features), len(top_cat_features)
# Out:
# (6, 0)

# %%
top_features
# Out:
# ['close/close_w10_ma',
#  'close/close_w30_ma',
#  'close/close_w10_expma',
#  'close/close_w30_expma',
#  'close_w10_max/close',
#  'close/close_1hour_w10_expma']

# %%
D_train = lgbm.Dataset(df.loc[mask_train, top_features], label=df.loc[mask_train, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, top_features], label=df.loc[mask_valid, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, top_features], label=df.loc[mask_test, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, top_features], label=df.loc[mask_test2, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)

D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
#D_train.data

# %%
D_train.data.shape
# Out:
# (1446127, 6)

# %%
params
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_boost_round': 1000,
#  'num_leaves': 5,
#  'feature_fraction': 0.3,
#  'bagging_fraction': 0.3,
#  'bagging_freq': 1,
#  'lambda_l1': 100,
#  'lambda_l2': 100,
#  'metric': 'mean_income_rate',
#  'early_stopping': 10}

# %%
from IPython.display import clear_output

history = {'params' : [],
           'num_trees' : [],

          
           'auc_train' : [],
           'auc_valid' : [],
           'auc_test' : [],
           'auc_test2' : [],

          
           'mir_point@1_train' : [],
           'mir_point@1_valid' : [],
           'mir_point@1_test' : [],
           'mir_point@1_test2' : [],

           'mir_day@1_train' : [],
           'mir_day@1_valid' : [],
           'mir_day@1_test' : [],
           'mir_day@1_test2' : [],

           'mir_month@1_train' : [],
           'mir_month@1_valid' : [],
           'mir_month@1_test' : [],
           'mir_month@1_test2' : [],
           
           'mir_point@2_train' : [],
           'mir_point@2_valid' : [],
           'mir_point@2_test' : [],
           'mir_point@2_test2' : [],
          
           
           'mir_day@2_train' : [],
           'mir_day@2_valid' : [],
           'mir_day@2_test' : [],
           'mir_day@2_test2' : [],


           'mir_month@2_train' : [],
           'mir_month@2_valid' : [],
           'mir_month@2_test' : [],
           'mir_month@2_test2' : [],
          
          }



pbar = tqdm(total=4*1*3*8*8)
# for lambda_x in [0.001, 0.01, 0.1, 1]:
#     for learning_rate in [0.1, 0.01, 0.001]:
#         for num_leaves in [2, 4, 8, 16, 32]:
#             for feature_fraction in np.arange(1, 0, -0.1):
#                 for bagging_fraction in np.arange(1, 0, -0.1):
for lambda_x in [1, 10, 100, 1000]:
    for learning_rate in [0.1]:
        for num_leaves in [2, 5, 8]:
            for feature_fraction in np.arange(0.3, 1.1, 0.1)[::-1]:
                for bagging_fraction in np.arange(0.3, 1.1, 0.1)[::-1]:
                    feature_fraction = min(feature_fraction, 1)
                    bagging_fraction = min(bagging_fraction, 1)

                    
                    params = {
                                "boosting_type": "gbdt",
                                "objective": "binary",
                            
                                
                                 "num_leaves": num_leaves,
                                 "learning_rate": learning_rate,
                                 "feature_fraction": feature_fraction,
                                 "bagging_fraction": bagging_fraction,
                                 "bagging_freq": 1,
                                 'lambda_l1' : lambda_x,
                                 'lambda_l2' : lambda_x,
                                
                                "verbose": -1,
                                    
                                "metric": 'mean_income_rate',
                                "early_stopping" : 10,
                            }
                    model = lgbm.train(params, num_boost_round=1_000, train_set=D_train, valid_sets=[D_valid], feval=mean_income_rate)
                    
                    y_pred_train = model.predict(D_train.data)
                    y_pred_valid = model.predict(D_valid.data)
                    y_pred_test = model.predict(D_test.data)
                    y_pred_test2 = model.predict(D_test2.data)
                    
                    #history
                    history['params'] += [params.copy()]
                    history['num_trees'] += [model.num_trees()]
        
                    history['auc_train'] += [roc_auc_score(D_train.label, y_pred_train)]
                    history['auc_valid'] += [roc_auc_score(D_valid.label, y_pred_valid)]
                    history['auc_test'] += [roc_auc_score(D_test.label, y_pred_test)]
                    history['auc_test2'] += [roc_auc_score(D_test2.label, y_pred_test2)]


                    threshold1 = np.quantile(y_pred_valid, q=0.99)
                    threshold2 = np.quantile(y_pred_valid, q=0.95)
                    
                    history['mir_point@1_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold1)]
                    history['mir_point@1_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold1)]
                    history['mir_point@1_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold1)]
                    history['mir_point@1_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold1)]

                    history['mir_day@1_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold1)]
                    history['mir_day@1_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold1)]
                    history['mir_day@1_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold1)]
                    history['mir_day@1_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold1)]
                    
                    history['mir_month@1_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold1)]
                    history['mir_month@1_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold1)]
                    history['mir_month@1_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold1)]
                    history['mir_month@1_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold1)]


                    

                    history['mir_point@2_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold2)]
                    history['mir_point@2_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold2)]
                    history['mir_point@2_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold2)]
                    history['mir_point@2_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold2)]

                    history['mir_day@2_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold2)]
                    history['mir_day@2_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold2)]
                    history['mir_day@2_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold2)]
                    history['mir_day@2_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold2)]
                   
                    history['mir_month@2_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold2)]
                    history['mir_month@2_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold2)]
                    history['mir_month@2_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold2)]
                    history['mir_month@2_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold2)]


                    
                    clear_output()
                    pbar.update(1)
                    
pbar.close()
                    

history_cp = history.copy()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 768/768 [24:24<00:00,  1.91s/it]

# %%
dump_pkl(history, './hst_-0.5_+1.5_4hour.pkl')

# %%
history = load_pkl('./hst_-0.5_+1.5_4hour.pkl')

# %%
pd.set_option('display.max_columns', 100)
order_cols = ['params', 'num_trees', 'auc_train', 'auc_valid', 'auc_test', 'auc_test2', 'mir_point@1_train', 'mir_point@1_valid', 'mir_point@1_test', 'mir_point@1_test2', 'mir_day@1_train', 'mir_day@1_valid', 'mir_day@1_test', 'mir_day@1_test2', 'mir_month@1_train', 'mir_month@1_valid', 'mir_month@1_test', 'mir_month@1_test2', 'mir_point@2_train', 'mir_point@2_valid', 'mir_point@2_test', 'mir_point@2_test2', 'mir_day@2_train', 'mir_day@2_valid', 'mir_day@2_test', 'mir_day@2_test2', 'mir_month@2_train', 'mir_month@2_valid', 'mir_month@2_test', 'mir_month@2_test2']
df_hst = pd.DataFrame(history)[order_cols]
df_hst
# Out:
#                                                 params  num_trees  auc_train  \
# 0    {'boosting_type': 'gbdt', 'objective': 'binary...         32   0.642828
# 1    {'boosting_type': 'gbdt', 'objective': 'binary...         12   0.624520
# 2    {'boosting_type': 'gbdt', 'objective': 'binary...         14   0.626674
# 3    {'boosting_type': 'gbdt', 'objective': 'binary...         32   0.642618
# 4    {'boosting_type': 'gbdt', 'objective': 'binary...         10   0.617723
# ..                                                 ...        ...        ...
# 763  {'boosting_type': 'gbdt', 'objective': 'binary...         38   0.650277
# 764  {'boosting_type': 'gbdt', 'objective': 'binary...         44   0.650052
# 765  {'boosting_type': 'gbdt', 'objective': 'binary...         40   0.649431
# 766  {'boosting_type': 'gbdt', 'objective': 'binary...         21   0.646752
# 767  {'boosting_type': 'gbdt', 'objective': 'binary...         19   0.645776
#
#      auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 0     0.601831  0.604062   0.573098           0.001818           0.000462
# 1     0.594835  0.593708   0.566168           0.001578          -0.000001
# 2     0.595243  0.594842   0.567469           0.001568           0.000011
# 3     0.602215  0.604165   0.573116           0.001816           0.000462
# 4     0.591128  0.589091   0.565039           0.001502          -0.000055
# ..         ...       ...        ...                ...                ...
# 763   0.609061  0.604311   0.571548           0.002125           0.000098
# 764   0.608623  0.604188   0.571333           0.002126           0.000098
# 765   0.608804  0.603635   0.570874           0.002059           0.000033
# 766   0.605981  0.599423   0.567547           0.001376          -0.000296
# 767   0.604977  0.598369   0.566505           0.001142          -0.000468
#
#      mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 0            0.001205           0.001078         0.002228         0.002875
# 1            0.000883           0.000358         0.002120         0.002219
# 2            0.000855           0.000352         0.002111         0.002228
# 3            0.001205           0.001078         0.002225         0.002875
# 4            0.000962           0.000699         0.002023         0.001818
# ..                ...                ...              ...              ...
# 763          0.001321           0.000950         0.003508         0.002798
# 764          0.001321           0.000950         0.003510         0.002798
# 765          0.001234           0.000853         0.003516         0.002778
# 766          0.000865           0.000257         0.002461         0.001897
# 767          0.000744           0.000080         0.002314         0.001610
#
#      mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 0          0.001664         0.002351           0.044984           0.061846
# 1          0.001986         0.001947           0.044832           0.048824
# 2          0.001943         0.002014           0.044649           0.049007
# 3          0.001664         0.002351           0.044917           0.061846
# 4          0.001698         0.002219           0.042888           0.039997
# ..              ...              ...                ...                ...
# 763        0.002544         0.003683           0.068550           0.061556
# 764        0.002544         0.003683           0.068583           0.061556
# 765        0.002727         0.003524           0.071165           0.061117
# 766        0.002538         0.002551           0.051788           0.041732
# 767        0.002587         0.002188           0.049285           0.035426
#
#      mir_month@1_test  mir_month@1_test2  mir_point@2_train  \
# 0            0.035775           0.048117           0.001045
# 1            0.043693           0.041837           0.001107
# 2            0.042757           0.043287           0.001086
# 3            0.035775           0.048117           0.001112
# 4            0.037346           0.047687           0.001042
# ..                ...                ...                ...
# 763          0.053415           0.077247           0.001283
# 764          0.053415           0.077247           0.001260
# 765          0.058629           0.073929           0.001275
# 766          0.055830           0.054815           0.001235
# 767          0.056903           0.048139           0.001142
#
#      mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@2_train  \
# 0            -0.000154          0.000716           0.000442         0.001309
# 1            -0.000167          0.000726           0.000363         0.001488
# 2            -0.000149          0.000659           0.000397         0.001341
# 3            -0.000048          0.000661           0.000482         0.001318
# 4            -0.000244          0.000668           0.000324         0.001368
# ..                 ...               ...                ...              ...
# 763          -0.000278          0.000774           0.000358         0.001904
# 764          -0.000284          0.000732           0.000358         0.001782
# 765          -0.000337          0.000775           0.000346         0.001907
# 766          -0.000389          0.000775           0.000211         0.002470
# 767          -0.000468          0.000744           0.000080         0.002314
#
#      mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@2_train  \
# 0           0.001190        0.001221         0.001036           0.028273
# 1           0.001371        0.001372         0.001344           0.032136
# 2           0.001297        0.001263         0.001173           0.028894
# 3           0.001354        0.001199         0.001266           0.028341
# 4           0.001185        0.001246         0.001124           0.029548
# ..               ...             ...              ...                ...
# 763         0.001339        0.001942         0.001856           0.041122
# 764         0.001320        0.001809         0.001645           0.038478
# 765         0.001209        0.001973         0.001705           0.041279
# 766         0.001610        0.002609         0.002466           0.052599
# 767         0.001610        0.002587         0.002188           0.049285
#
#      mir_month@2_valid  mir_month@2_test  mir_month@2_test2
# 0             0.026170          0.026858           0.022253
# 1             0.030159          0.030182           0.028872
# 2             0.028533          0.027776           0.025214
# 3             0.029791          0.026379           0.027208
# 4             0.026070          0.027405           0.024147
# ..                 ...               ...                ...
# 763           0.029459          0.042714           0.040831
# 764           0.029041          0.039788           0.035356
# 765           0.026590          0.043408           0.036640
# 766           0.035425          0.057401           0.052998
# 767           0.035426          0.056903           0.048139
#
# [768 rows x 30 columns]

# %% [markdown]
# ### threshold delta AUC

# %%
threshold = 0.03
mask_model_valid = (df_hst['auc_train'] - df_hst['auc_valid']) < threshold
mask_model_test = (df_hst['auc_train'] - df_hst['auc_test']) < threshold
mask_model_test2 = (df_hst['auc_train'] - df_hst['auc_test2']) < threshold
mask_model_valid.sum(), mask_model_test.sum(), mask_model_test2.sum()
# Out:
# (115, 15, 0)

# %%
(mask_model_valid&mask_model_test).sum(), (mask_model_valid&mask_model_test&mask_model_test2).sum()
# Out:
# (14, 0)

# %%
mask_auc = mask_model_valid&mask_model_test#&mask_model_test2
df_hst.loc[mask_auc].sort_values(by='auc_valid', ascending=False).iloc[:5]
#df_hst.loc[mask_model_valid&mask_model_test].sort_values(by='income_rate@1_valid', ascending=False).iloc[:5]
# Out:
#                                                 params  num_trees  auc_train  \
# 4    {'boosting_type': 'gbdt', 'objective': 'binary...         10   0.617723
# 397  {'boosting_type': 'gbdt', 'objective': 'binary...          9   0.614175
# 405  {'boosting_type': 'gbdt', 'objective': 'binary...          9   0.614175
# 438  {'boosting_type': 'gbdt', 'objective': 'binary...          7   0.605522
# 446  {'boosting_type': 'gbdt', 'objective': 'binary...          7   0.605522
#
#      auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 4     0.591128  0.589091   0.565039           0.001502          -0.000055
# 397   0.587564  0.585836   0.563168           0.001278          -0.000181
# 405   0.587564  0.585836   0.563168           0.001278          -0.000181
# 438   0.581058  0.576780   0.559037           0.001577          -0.000232
# 446   0.581058  0.576780   0.559037           0.001577          -0.000232
#
#      mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 4            0.000962           0.000699         0.002023         0.001818
# 397          0.000702           0.000324         0.001749         0.001526
# 405          0.000702           0.000324         0.001749         0.001526
# 438          0.001056           0.000449         0.002718         0.001906
# 446          0.001056           0.000449         0.002718         0.001906
#
#      mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 4          0.001698         0.002219           0.042888           0.039997
# 397        0.001452         0.001659           0.037608           0.033570
# 405        0.001452         0.001659           0.037608           0.033570
# 438        0.002462         0.002499           0.057609           0.041942
# 446        0.002462         0.002499           0.057609           0.041942
#
#      mir_month@1_test  mir_month@1_test2  mir_point@2_train  \
# 4            0.037346           0.047687           0.001042
# 397          0.031938           0.035656           0.001076
# 405          0.031938           0.035656           0.001076
# 438          0.054162           0.053689           0.001260
# 446          0.054162           0.053689           0.001260
#
#      mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@2_train  \
# 4            -0.000244          0.000668           0.000324         0.001368
# 397          -0.000260          0.000797           0.000329         0.001434
# 405          -0.000260          0.000797           0.000329         0.001434
# 438          -0.000342          0.000763           0.000244         0.001968
# 446          -0.000342          0.000763           0.000244         0.001968
#
#      mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@2_train  \
# 4           0.001185        0.001246         0.001124           0.029548
# 397         0.001156        0.001319         0.001193           0.031036
# 405         0.001156        0.001319         0.001193           0.031036
# 438         0.001341        0.002034         0.001641           0.042499
# 446         0.001341        0.002034         0.001641           0.042499
#
#      mir_month@2_valid  mir_month@2_test  mir_month@2_test2
# 4             0.026070          0.027405           0.024147
# 397           0.025436          0.029018           0.025635
# 405           0.025436          0.029018           0.025635
# 438           0.029511          0.044758           0.035265
# 446           0.029511          0.044758           0.035265

# %%
#df_hst['params'].iloc[1033]

# %% [markdown]
# ### threshold income_rate

# %%
col = 'mir_month@1'
threshold = 0.06
# mask_ir_valid = (df_hst[f'{col}_train'] - df_hst[f'{col}_valid']).abs() < threshold
# mask_ir_test = (df_hst[f'{col}_train'] - df_hst[f'{col}_test']).abs() < threshold
# mask_ir_test2 = (df_hst[f'{col}_train'] - df_hst[f'{col}_test2']).abs() < threshold

mask_ir_valid = df_hst[f'{col}_valid'] >=  threshold
mask_ir_test = df_hst[f'{col}_test'] >= threshold
mask_ir_test2 = df_hst[f'{col}_test2'] >=  threshold


mask_ir_valid.sum(), mask_ir_test.sum(), mask_ir_test2.sum()
# Out:
# (495, 251, 480)

# %%
(mask_ir_valid&mask_ir_test).sum(), (mask_ir_valid&mask_ir_test&mask_ir_test2).sum()
# Out:
# (240, 197)

# %%
mask_ir= mask_ir_valid&mask_ir_test&mask_ir_test2
mask_ir.sum()
# Out:
# 197

# %%
#(mask_ir&mask_auc).sum()

# %%
col = 'mir_day@1'
threshold = 0.003

# mask2_ir_valid = (df_hst[f'{col}_train'] - df_hst[f'{col}_valid']).abs() < threshold
# mask2_ir_test = (df_hst[f'{col}_train'] - df_hst[f'{col}_test']).abs() < threshold
# mask2_ir_test2 = (df_hst[f'{col}_train'] - df_hst[f'{col}_test2']).abs() < threshold

mask2_ir_valid = df_hst[f'{col}_valid'] >=  threshold
mask2_ir_test = df_hst[f'{col}_test'] >= threshold
mask2_ir_test2 = df_hst[f'{col}_test2'] >=  threshold


mask2_ir_valid.sum(), mask2_ir_test.sum(), mask2_ir_test2.sum()
# Out:
# (378, 237, 524)

# %%
(mask2_ir_valid&mask2_ir_test).sum(), (mask2_ir_valid&mask2_ir_test&mask2_ir_test2).sum()
# Out:
# (231, 231)

# %%
mask2_ir = mask2_ir_valid&mask2_ir_test&mask2_ir_test2
mask2_ir.sum()
# Out:
# 231

# %%
(mask_ir&mask2_ir).sum()
# Out:
# 173

# %%
# col = 'mir_point@1'
# threshold = 0.003

# # mask2_ir_valid = (df_hst[f'{col}_train'] - df_hst[f'{col}_valid']).abs() < threshold
# # mask2_ir_test = (df_hst[f'{col}_train'] - df_hst[f'{col}_test']).abs() < threshold
# # mask2_ir_test2 = (df_hst[f'{col}_train'] - df_hst[f'{col}_test2']).abs() < threshold

# mask3_ir_valid = df_hst[f'{col}_valid'] >=  threshold
# mask3_ir_test = df_hst[f'{col}_test'] >= threshold
# mask3_ir_test2 = df_hst[f'{col}_test2'] >=  threshold


# mask3_ir_valid.sum(), mask3_ir_test.sum(), mask3_ir_test2.sum()

# %%
# (mask3_ir_valid&mask3_ir_test).sum(), (mask3_ir_valid&mask3_ir_test&mask3_ir_test2).sum()

# %%
# mask3_ir = mask3_ir_valid&mask3_ir_test&mask3_ir_test2
# mask3_ir.sum()

# %%
# (mask_ir&mask2_ir&mask3_ir).sum()

# %%
#
#      mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@2_train  \
# 149          -0.000080          0.000294           0.001144         0.000768
# 141          -0.000080          0.000294           0.001144         0.000768
# 133          -0.000045          0.000408           0.001078         0.000726
# 132          -0.000063          0.000454           0.000925         0.000759
# 323          -0.000072          0.000363           0.000958         0.000699
# 350          -0.000034          0.000460           0.000640         0.000973
# 358          -0.000034          0.000460           0.000640         0.000973
# 115          -0.000166          0.000454           0.000533         0.000939
# 123          -0.000166          0.000454           0.000533         0.000939
# 317          -0.000119          0.000655           0.000379         0.001424
#
#      mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@2_train  \
# 149         0.000749        0.000319         0.000508           0.016664
# 141         0.000749        0.000319         0.000508           0.016664
# 133         0.000841        0.000432         0.000549           0.015754
# 132         0.000765        0.000467         0.000626           0.016514
# 323         0.000743        0.000403         0.000465           0.015164
# 350         0.000975        0.000752         0.000678           0.020968
# 358         0.000975        0.000752         0.000678           0.020968
# 115         0.000735        0.000927         0.000615           0.020278
# 123         0.000735        0.000927         0.000615           0.020278
# 317         0.001118        0.001489         0.000903           0.030691
#
#      mir_month@2_valid  mir_month@2_test  mir_month@2_test2
# 149           0.016485          0.007026           0.011167
# 141           0.016485          0.007026           0.011167
# 133           0.018499          0.009496           0.012070
# 132           0.016826          0.010268           0.013777
# 323           0.016346          0.008875           0.010224
# 350           0.021449          0.016542           0.014906
# 358           0.021449          0.016542           0.014906
# 115           0.016178          0.020397           0.013528
# 123           0.016178          0.020397           0.013528
# 317           0.024589          0.032765           0.019869

# %%
df_hst.iloc[[111, 149]]
# Out:
#                                                 params  num_trees  auc_train  \
# 111  {'boosting_type': 'gbdt', 'objective': 'binary...         17   0.652944
# 149  {'boosting_type': 'gbdt', 'objective': 'binary...         27   0.662656
#
#      auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 111   0.610673  0.608529   0.576003           0.002316           0.000534
# 149   0.620916  0.618368   0.580464           0.002764           0.000832
#
#      mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 111          0.001741           0.001280         0.003945         0.003393
# 149          0.002166           0.001638         0.004270         0.004005
#
#      mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 111        0.003930         0.003674           0.069954           0.069660
# 149        0.003285         0.003697           0.075058           0.078319
#
#      mir_month@1_test  mir_month@1_test2  mir_point@2_train  \
# 111          0.082540           0.073317           0.001126
# 149          0.064053           0.068101           0.000965
#
#      mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@2_train  \
# 111          -0.000135          0.000515           0.000352         0.001299
# 149          -0.000080          0.000294           0.001144         0.000768
#
#      mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@2_train  \
# 111         0.001204        0.001439         0.000930           0.027986
# 149         0.000749        0.000319         0.000508           0.016664
#
#      mir_month@2_valid  mir_month@2_test  mir_month@2_test2
# 111           0.026483          0.031652           0.020449
# 149           0.016485          0.007026           0.011167

# %%
df_hst['params'].iloc[149]
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 8,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.8000000000000002,
#  'bagging_fraction': 0.5,
#  'bagging_freq': 1,
#  'lambda_l1': 1,
#  'lambda_l2': 1,
#  'verbose': -1,
#  'metric': 'mean_income_rate',
#  'early_stopping': 10}

# %% [markdown]
# # Feature selection

# %%
len(top_features), top_features
# Out:
# (6,
#  ['close/close_w10_ma',
#   'close/close_w30_ma',
#   'close/close_w10_expma',
#   'close/close_w30_expma',
#   'close_w10_max/close',
#   'close/close_1hour_w10_expma'])

# %%
top_features = ['close/close_w10_ma',
  'close/close_w30_ma',
  'close/close_w10_expma',
  'close/close_w30_expma',
  'close_w10_max/close',
  'close/close_1hour_w10_expma']

# %%
#features = features_criteria2.tolist()
features = top_features


cat_features = [elem for elem in features if elem in cat_features_all]

# %%
len(features), len(cat_features)
# Out:
# (6, 0)

# %%
'ticker_code' in features
# Out:
# False

# %%
target = 'target'

# %%
D_train = lgbm.Dataset(df.loc[mask_train, features], label=df.loc[mask_train, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, features], label=df.loc[mask_valid, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, features], label=df.loc[mask_test, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, features], label=df.loc[mask_test2, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)


D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
D_test2.data
# Out:
#          close/close_w10_ma  close/close_w30_ma  close/close_w10_expma  \
# 34250              1.004638            1.011641               1.005106
# 34251              1.002253            1.009579               1.002815
# 34252              1.004541            1.011769               1.004415
# 34253              0.997600            1.004561               0.997873
# 34254              0.995200            1.001970               0.996293
# ...                     ...                 ...                    ...
# 2338926            1.001332            1.001260               1.000852
# 2338927            1.001014            1.001202               1.000697
# 2338928            0.998173            0.998298               0.998102
# 2338929            1.000872            1.001328               1.000916
# 2338930            0.996564            0.996845               0.996945
#
#          close/close_w30_expma  close_w10_max/close  \
# 34250                 1.008195             1.000000
# 34251                 1.006102             1.001658
# 34252                 1.008132             1.000000
# 34253                 1.001022             1.007032
# 34254                 0.998703             1.009460
# ...                        ...                  ...
# 2338926               1.001409             1.000190
# 2338927               1.001318             1.000190
# 2338928               0.998409             1.003214
# 2338929               1.001335             1.000190
# 2338930               0.996899             1.004856
#
#          close/close_1hour_w10_expma
# 34250                       1.007999
# 34251                       1.006331
# 34252                       1.008926
# 34253                       1.001539
# 34254                       0.999129
# ...                              ...
# 2338926                     1.002039
# 2338927                     1.002039
# 2338928                     0.998649
# 2338929                     1.001668
# 2338930                     0.997558
#
# [157454 rows x 6 columns]

# %%
params = { 'boosting_type': 'gbdt',
 'objective': 'binary',
 'num_leaves': 5,
 'learning_rate': 0.1,
 'feature_fraction': 0.5,
 'bagging_fraction': 0.3,
 'bagging_freq': 1,
 'lambda_l1': 1,
 'lambda_l2': 1,
 'verbose': -1,
 'metric': 'mean_income_rate',
 'early_stopping': 10}

# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 8,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.8,
#  'bagging_fraction': 0.5,
#  'bagging_freq': 1,
#  'lambda_l1': 1,
#  'lambda_l2': 1,
#  'verbose': -1,
#  'metric': 'mean_income_rate',
#  'early_stopping': 10}

# #111 - num_trees=17
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 5,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.5,
#  'bagging_fraction': 0.3,
#  'bagging_freq': 1,
#  'lambda_l1': 1,
#  'lambda_l2': 1,
#  'verbose': -1,
#  'metric': 'mean_income_rate',
#  'early_stopping': 10}

model = lgbm.train(params,  num_boost_round=2_000, train_set=D_train, valid_sets=[D_valid], feval=mean_income_rate)

# %%
model.num_trees()
# Out:
# 17

# %%
y_pred_train = model.predict(D_train.data)
y_pred_valid = model.predict(D_valid.data)
y_pred_test = model.predict(D_test.data)
y_pred_test2 = model.predict(D_test2.data)


df["y_pred"] = None
df.loc[mask_train, 'y_pred'] = y_pred_train
df.loc[mask_valid, 'y_pred'] = y_pred_valid
df.loc[mask_test, 'y_pred'] = y_pred_test
df.loc[mask_test2, 'y_pred'] = y_pred_test2

roc_auc_score(D_train.label, y_pred_train), roc_auc_score(D_valid.label, y_pred_valid), roc_auc_score(D_test.label, y_pred_test), roc_auc_score(D_test2.label, y_pred_test2)
# Out:
# (0.652944363854863, 0.6106727017819044, 0.6085286847042677, 0.5760034988223279)

# %%
#свой threshold

q = 0.99

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest')
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# Valid
# result
# LOSE    0.602980
# WIN     0.266631
# DNF     0.130389
# Name: proportion, dtype: float64
# 1.0005339
#
# Test
# result
# LOSE    0.534453
# WIN     0.280834
# DNF     0.184713
# Name: proportion, dtype: float64
# 1.0013725
#
# Test2
# result
# LOSE    0.532609
# WIN     0.292271
# DNF     0.175121
# Name: proportion, dtype: float64
# 1.0013669

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 01:00:00'),
#  Timedelta('0 days 01:15:00'),
#  Timedelta('0 days 01:00:00'))

# %%
#общий threshold

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
print(f'threshokd = {threshold}')

mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print("\nTest")
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print('\nTetst2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# threshokd = 0.2591240486482249
#
# Valid
# result
# LOSE    0.602980
# WIN     0.266631
# DNF     0.130389
# Name: proportion, dtype: float64
# 1.0005339
#
# Test
# result
# LOSE    0.530280
# WIN     0.310559
# DNF     0.159161
# Name: proportion, dtype: float64
# 1.0017412
#
# Tetst2
# result
# LOSE    0.543643
# WIN     0.296907
# DNF     0.159450
# Name: proportion, dtype: float64
# 1.0012803

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 01:00:00'),
#  Timedelta('0 days 01:00:00'),
#  Timedelta('0 days 01:00:00'))

# %%
(mask_valid&mask).sum(), (mask_test&mask).sum(), (mask_test2&mask).sum()
# Out:
# (1879, 1288, 1455)

# %%
df.loc[mask_valid&mask, 'time'].dt.date.nunique(), df.loc[mask_test&mask, 'time'].dt.date.nunique(), df.loc[mask_test2&mask, 'time'].dt.date.nunique()
# Out:
# (42, 42, 39)

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.99)

# %%
mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_point(D_test, y_pred_test, threshold=threshold), mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0005339384078979492, 0.001741170883178711, 0.0012803077697753906)

# %%
mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_day(D_test, y_pred_test, threshold=threshold), mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0033925232, 0.0039304667, 0.0036743742)

# %%
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.06965980877478917, 0.08253980102017522, 0.07331658277097483)

# %%
df.loc[mask_test2&mask, 'ticker'].unique()
# Out:
# array(['AFLT', 'IRAO', 'MVID', 'SPBE', 'MTLRP', 'SFIN', 'FEES', 'LKOH',
#        'FESH', 'MDMG', 'VKCO', 'SELG', 'SGZH', 'ENPG', 'LSRG', 'NMTP',
#        'PLZL', 'TATN', 'AFKS', 'GMKN', 'RNFT', 'YDEX', 'UWGN', 'TGKN',
#        'HYDR', 'ABIO', 'WUSH', 'GTRK', 'NLMK', 'TATNP', 'ALRS', 'VSMO',
#        'TRNFP', 'MGNT', 'IRKT', 'MTLR', 'HEAD', 'RUAL', 'SNGS', 'NVTK',
#        'RASP', 'VTBR', 'PHOR', 'T', 'TRMK', 'MOEX', 'CHMF', 'RTKM',
#        'SMLT', 'UNAC', 'GAZP', 'ROSN', 'BELU', 'FLOT', 'PIKK', 'SVAV',
#        'POSI', 'SNGSP', 'MTSS', 'MAGN', 'BANEP', 'BSPB'], dtype=object)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#         count  income_rate
# ticker
# PHOR      1.0     1.009423
# ROSN      2.0     0.997834
# NLMK      2.0     1.014000
# MDMG      2.0     1.008354
# GMKN      2.0     0.998990
# SNGSP     3.0     1.007333
# SNGS      3.0     0.996834
# NVTK      3.0     1.003587
# IRAO      3.0     1.014000
# YDEX      4.0     1.004000
# ALRS      5.0     0.996159
# ENPG      5.0     0.998000
# MOEX      5.0     1.012264
# HYDR      5.0     1.008806
# TATNP     6.0     1.008331
# TATN      6.0     1.008229
# NMTP      6.0     1.007333
# BANEP     8.0     0.998949
# VTBR      9.0     0.996350
# LKOH      9.0     0.998244
# AFLT     10.0     0.997125
# GAZP     10.0     0.999520
# FLOT     10.0     1.012000
# PLZL     10.0     0.997831
# MAGN     11.0     1.007939
# FEES     11.0     1.003708
# MTSS     12.0     1.003953
# HEAD     13.0     0.997205
# T        14.0     0.998712
# MGNT     14.0     1.001143
# CHMF     14.0     1.001284
# RUAL     15.0     0.997130
# FESH     16.0     1.000393
# SPBE     16.0     1.004799
# VSMO     16.0     1.001230
# TRMK     17.0     1.000000
# BSPB     19.0     0.999083
# SFIN     20.0     0.999913
# RTKM     20.0     1.001132
# ABIO     23.0     1.000399
# SELG     25.0     1.001951
# AFKS     25.0     0.999087
# UNAC     27.0     1.005049
# VKCO     28.0     0.999000
# MTLR     29.0     1.001803
# MTLRP    31.0     1.001545
# LSRG     31.0     0.997938
# RASP     34.0     0.997281
# BELU     35.0     1.001691
# SVAV     39.0     0.999979
# TRNFP    39.0     1.003442
# WUSH     43.0     1.001484
# RNFT     49.0     0.998683
# POSI     50.0     1.002260
# MVID     57.0     1.004219
# IRKT     58.0     1.000908
# PIKK     60.0     1.000531
# UWGN     60.0     1.003016
# TGKN     79.0     1.000277
# SMLT     90.0     1.000218
# SGZH     93.0     1.003514
# GTRK     93.0     1.000233

# %% [markdown]
# # Drop weak features

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1])
# Out:
# [('close/close_w30_ma', 1.57),
#  ('close/close_w10_ma', 2.25),
#  ('close/close_w10_expma', 2.79),
#  ('close_w10_max/close', 19.1),
#  ('close/close_w30_expma', 24.83),
#  ('close/close_1hour_w10_expma', 49.47)]

# %%
#Не использовал

# %%
features_order_to_drop = []
for elem in sorted(zip(features, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1]):
    if elem[1] > 0:
        features_order_to_drop += [elem[0]]
features_order_to_drop
# Out:
# ['close/close_w10_ma',
#  'close/close_w30_expma',
#  'close/close_w10_expma',
#  'close/close_w30_ma',
#  'close_w10_max/close',
#  'close/close_1hour_w10_expma']

# %%
cat_features = [elem for elem in features_order_to_drop if elem in cat_features_all]
len(cat_features)
# Out:
# 0

# %%
params
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 8,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.8,
#  'bagging_fraction': 0.5,
#  'bagging_freq': 1,
#  'lambda_l1': 1,
#  'lambda_l2': 1,
#  'verbose': -1,
#  'metric': 'mean_income_rate',
#  'early_stopping': 10}

# %%
from IPython.display import clear_output

history_fe = {'features' : [],
           'num_trees' : [],

           'auc_train' : [],
           'auc_valid' : [],
           'auc_test' : [],
           'auc_test2' : [],
           
           'mir_point@1_train' : [],
           'mir_point@1_valid' : [],
           'mir_point@1_test' : [],
           'mir_point@1_test2' : [],
              
           'mir_day@1_train' : [],
           'mir_day@1_valid' : [],
           'mir_day@1_test' : [],
           'mir_day@1_test2' : [],
              
           'mir_month@1_train' : [],
           'mir_month@1_valid' : [],
           'mir_month@1_test' : [],
           'mir_month@1_test2' : [],
          
          }
    
for i in tqdm(range(len(features_order_to_drop))):
    features_fe = features_order_to_drop[i:]
    cat_features = [elem for elem in features_fe if elem in cat_features_all]

    D_train = lgbm.Dataset(df.loc[mask_train, features_fe], label=df.loc[mask_train, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    D_valid = lgbm.Dataset(df.loc[mask_valid, features_fe], label=df.loc[mask_valid, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    D_test = lgbm.Dataset(df.loc[mask_test, features_fe], label=df.loc[mask_test, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    D_test2 = lgbm.Dataset(df.loc[mask_test2, features_fe], label=df.loc[mask_test2, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    
    D_train.income_rate = df.loc[mask_train, 'income_rate'].values
    D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
    D_test.income_rate = df.loc[mask_test, 'income_rate'].values
    D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

    D_train.time = df.loc[mask_train, 'time'].values
    D_valid.time = df.loc[mask_valid, 'time'].values
    D_test.time = df.loc[mask_test, 'time'].values
    D_test2.time = df.loc[mask_test2, 'time'].values

    model = lgbm.train(params, num_boost_round=2_000, train_set=D_train, valid_sets=[D_valid])
                    
    y_pred_train = model.predict(D_train.data)
    y_pred_valid = model.predict(D_valid.data)
    y_pred_test = model.predict(D_test.data)
    y_pred_test2 = model.predict(D_test2.data)
    
    #history_fe
    history_fe['features'] += [features_fe.copy()]
    history_fe['num_trees'] += [model.num_trees()]

    history_fe['auc_train'] += [roc_auc_score(D_train.label, y_pred_train)]
    history_fe['auc_valid'] += [roc_auc_score(D_valid.label, y_pred_valid)]
    history_fe['auc_test'] += [roc_auc_score(D_test.label, y_pred_test)]
    history_fe['auc_test2'] += [roc_auc_score(D_test2.label, y_pred_test2)]

    threshold1 = np.quantile(y_pred_valid, q=0.95)
      
    history_fe['mir_point@1_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold1)]
    history_fe['mir_point@1_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold1)]
    history_fe['mir_point@1_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold1)]
    history_fe['mir_point@1_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold1)]
    
    history_fe['mir_day@1_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold1)]
    history_fe['mir_day@1_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold1)]
    history_fe['mir_day@1_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold1)]
    history_fe['mir_day@1_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold1)]
    
    history_fe['mir_month@1_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold1)]
    history_fe['mir_month@1_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold1)]
    history_fe['mir_month@1_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold1)]
    history_fe['mir_month@1_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold1)]
                   



    #clear_output()

# %%
df_hst_fe = pd.DataFrame(history_fe)
df_hst_fe
# Out:
#                                              features  num_trees  auc_train  \
# 0   [sin_time_hour, volume_w5_min/volume, volume_w...        198   0.733658
# 1   [volume_w5_min/volume, volume_w5_min/volume_w5...          8   0.626349
# 2   [volume_w5_min/volume_w5_max, close_1day_w3_ro...          5   0.617089
# 3   [close_1day_w3_roc/close_1day_w20_roc, tmos_cl...          4   0.612161
# 4   [tmos_close_w1_roc, tmos_close_w70_lvl_1.005-1...         19   0.643543
# 5   [tmos_close_w70_lvl_1.005-1.01, volume_w5_std/...        155   0.725221
# 6   [volume_w5_std/volume_w14_std, volume_w5_norm_...         27   0.655332
# 7   [volume_w5_norm_std, tmos_close_w14_roc, tmos_...         14   0.635161
# 8   [tmos_close_w14_roc, tmos_close_w14_rsi, tmos_...         18   0.645007
# 9   [tmos_close_w14_rsi, tmos_close_w70_lvl_1.01-1...        171   0.727386
# 10  [tmos_close_w70_lvl_1.01-1.015, tmos_close_w70...          4   0.610072
# 11  [tmos_close_w70_lvl_-0.985-0.99, tmos_close_1d...          2   0.598932
# 12  [tmos_close_1day_w20_lvl_1.005-1.01, tmos_clos...         16   0.638584
# 13  [tmos_close_1day_w100_lvl_1.04-1.05, tmos_clos...         11   0.630843
# 14  [tmos_close_w70_rsi, tmos_close_w70_roc, close...         62   0.679490
# 14          0.064423           0.067928
# 15          0.069964           0.059765
# 16          0.070997           0.067581
# 17          0.066876           0.066457
# 18          0.054824           0.058754
# 19          0.070221           0.074289
# 20          0.061478           0.079486
# 21          0.071711           0.075209
# 22          0.066310           0.061870
# 23          0.071892           0.079612
# 24          0.062404           0.080350
# 25          0.060282           0.066003
# 26          0.071890           0.076515
# 27         -0.001699                NaN
# 28         -0.001319          -0.001505

# %%
df_hst_fe['features'].loc[5]
# Out:
# ['tmos_close_w70_lvl_1.005-1.01',
#  'volume_w5_std/volume_w14_std',
#  'volume_w5_norm_std',
#  'tmos_close_w14_roc',
#  'tmos_close_w14_rsi',
#  'tmos_close_w70_lvl_1.01-1.015',
#  'tmos_close_w70_lvl_-0.985-0.99',
#  'tmos_close_1day_w20_lvl_1.005-1.01',
#  'tmos_close_1day_w100_lvl_1.04-1.05',
#  'tmos_close_w70_rsi',
#  'tmos_close_w70_roc',
#  'close_w70_rsi',
#  'hour',
#  'tmos_close_w70_ma_up_2std/tmos_close',
#  'tmos_close_w14_ma/tmos_close_w70_ma',
#  'close_w70_lvl_-0.98-0.99',
#  'tmos_close_w5_ma/tmos_close_w70_ma',
#  'tmos_close_w14_max/tmos_close',
#  'tmos_close_1day_w100_lvl_1.015-1.02',
#  'tmos_close_1day_w20_lvl_1.015-1.02',
#  'tmos_close_w5_max/tmos_close',
#  'close_w1_roc',
#  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
#  'tmos_close_1day_w5_ma_low_2std/tmos_close_1day']

# %% [markdown]
# # BEST

# %%
features_fe = features
features
# Out:
# ['close/close_w10_ma',
#  'close/close_w30_ma',
#  'close/close_w10_expma',
#  'close/close_w30_expma',
#  'close_w10_max/close',
#  'close/close_1hour_w10_expma']

# %%
params
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 5,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.5,
#  'bagging_fraction': 0.3,
#  'bagging_freq': 1,
#  'lambda_l1': 1,
#  'lambda_l2': 1,
#  'verbose': -1,
#  'metric': 'mean_income_rate',
#  'early_stopping': 10}

# %%
params = {'boosting_type': 'gbdt',
 'objective': 'binary',
 'num_leaves': 5,
 'learning_rate': 0.1,
 'feature_fraction': 0.5,
 'bagging_fraction': 0.3,
 'bagging_freq': 1,
 'lambda_l1': 1,
 'lambda_l2': 1,
 'verbose': -1,
 'metric': 'mean_income_rate',
 'early_stopping': 10}

# %%
target = 'target'
cat_features = [elem for elem in features_fe if elem in cat_features_all]
len(cat_features)
# Out:
# 0

# %%
D_train = lgbm.Dataset(df.loc[mask_train, features_fe], label=df.loc[mask_train, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, features_fe], label=df.loc[mask_valid, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, features_fe], label=df.loc[mask_test, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, features_fe], label=df.loc[mask_test2, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)


D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
D_test3 = lgbm.Dataset(df.loc[mask_test3, features_fe], label=df.loc[mask_test3, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
D_test3.time = df.loc[mask_test3, 'time'].values

# %% [markdown]
# # INCORPORATION

# %%
# D_test3 = lgbm.Dataset(df.loc[mask_test3, features], label=df.loc[mask_test3, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
# D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
# D_test3.time = df.loc[mask_test3, 'time'].values

# %%
model = lgbm.train(params,  num_boost_round=1_000, train_set=D_train, valid_sets=[D_valid], feval=mean_income_rate)

# %%
#dump_pkl(model, './model.pkl')

# %%
#model = load_pkl('./model.pkl')

# %%
model.num_trees()
# Out:
# 17

# %%
(model.predict(D_test2.data) == model.predict(df.loc[mask_test2, features_fe])).all()
# Out:
# True

# %%
y_pred_train = model.predict(D_train.data)
y_pred_valid = model.predict(D_valid.data)
y_pred_test = model.predict(D_test.data)
y_pred_test2 = model.predict(D_test2.data)


df["y_pred"] = None
df.loc[mask_train, 'y_pred'] = y_pred_train
df.loc[mask_valid, 'y_pred'] = y_pred_valid
df.loc[mask_test, 'y_pred'] = y_pred_test
df.loc[mask_test2, 'y_pred'] = y_pred_test2

roc_auc_score(D_train.label, y_pred_train), roc_auc_score(D_valid.label, y_pred_valid), roc_auc_score(D_test.label, y_pred_test), roc_auc_score(D_test2.label, y_pred_test2)
# Out:
# (0.652944363854863, 0.6106727017819044, 0.6085286847042677, 0.5760034988223279)

# %%
y_pred_test3 = model.predict(D_test3.data)
df.loc[mask_test3, 'y_pred'] = y_pred_test3
roc_auc_score(D_test3.label, y_pred_test3)
# Out:
# 0.6078107687204396

# %%
#свой threshold

q = 0.99

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest')
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# Valid
# result
# LOSE    0.602980
# WIN     0.266631
# DNF     0.130389
# Name: proportion, dtype: float64
# 1.0005339
#
# Test
# result
# LOSE    0.534453
# WIN     0.280834
# DNF     0.184713
# Name: proportion, dtype: float64
# 1.0013725
#
# Test2
# result
# LOSE    0.532609
# WIN     0.292271
# DNF     0.175121
# Name: proportion, dtype: float64
# 1.0013669

# %%
threshold = np.quantile(df.loc[mask_test3, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest3')
print(df.loc[mask_test3&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test3&mask, 'income_rate'].mean())
# Out:
# Test3
# result
# LOSE    0.548298
# DNF     0.250230
# WIN     0.201472
# Name: proportion, dtype: float64
# 1.0003227

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 01:00:00'),
#  Timedelta('0 days 01:15:00'),
#  Timedelta('0 days 01:15:00'))

# %%
df.loc[mask_test3&mask, 'delta_time'].median()
# Out:
# Timedelta('0 days 01:30:00')

# %%
#общий threshold

q = 0.99

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
print(f'threshokd = {threshold}')

mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print("\nTest")
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print('\nTetst2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# threshokd = 0.2591240486482249
#
# Valid
# result
# LOSE    0.602980
# WIN     0.266631
# DNF     0.130389
# Name: proportion, dtype: float64
# 1.0005339
#
# Test
# result
# LOSE    0.530280
# WIN     0.310559
# DNF     0.159161
# Name: proportion, dtype: float64
# 1.0017412
#
# Tetst2
# result
# LOSE    0.543643
# WIN     0.296907
# DNF     0.159450
# Name: proportion, dtype: float64
# 1.0012803

# %%
df.loc[mask_valid&mask, 'time'].dt.date.nunique(), df.loc[mask_test&mask, 'time'].dt.date.nunique(),  df.loc[mask_test2&mask, 'time'].dt.date.nunique()
# Out:
# (42, 42, 39)

# %%
df.loc[mask_test3&mask, 'time'].dt.date.nunique(), df.loc[mask_test3, 'time'].dt.date.nunique()
# Out:
# (22, 27)

# %%
print('\nTetst3')
print(df.loc[mask_test3&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test3&mask, 'income_rate'].mean())
# Out:
# Tetst3
# result
# LOSE    0.551661
# DNF     0.232472
# WIN     0.215867
# Name: proportion, dtype: float64
# 1.000421

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 01:00:00'),
#  Timedelta('0 days 01:00:00'),
#  Timedelta('0 days 01:00:00'))

# %%
df.loc[mask_test3&mask, 'delta_time'].median()
# Out:
# Timedelta('0 days 01:22:30')

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.99)
mask = df['y_pred'] >= threshold
threshold
# Out:
# 0.2591240486482249

# %%
mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_point(D_test, y_pred_test, threshold=threshold), mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0005339384078979492, 0.001741170883178711, 0.0012803077697753906)

# %%
mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_day(D_test, y_pred_test, threshold=threshold), mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0033925232, 0.0039304667, 0.0036743742)

# %%
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.06965980877478917, 0.08253980102017522, 0.07331658277097483)

# %%
mean_income_rate_point(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.0004210472106933594

# %%
mean_income_rate_day(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.0019698576

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.035311521548363894

# %%
df.loc[mask_test2&mask, 'ticker'].unique()
# Out:
# array(['AFLT', 'IRAO', 'MVID', 'SPBE', 'MTLRP', 'SFIN', 'FEES', 'LKOH',
#        'FESH', 'MDMG', 'VKCO', 'SELG', 'SGZH', 'ENPG', 'LSRG', 'NMTP',
#        'PLZL', 'TATN', 'AFKS', 'GMKN', 'RNFT', 'YDEX', 'UWGN', 'TGKN',
#        'HYDR', 'ABIO', 'WUSH', 'GTRK', 'NLMK', 'TATNP', 'ALRS', 'VSMO',
#        'TRNFP', 'MGNT', 'IRKT', 'MTLR', 'HEAD', 'RUAL', 'SNGS', 'NVTK',
#        'RASP', 'VTBR', 'PHOR', 'T', 'TRMK', 'MOEX', 'CHMF', 'RTKM',
#        'SMLT', 'UNAC', 'GAZP', 'ROSN', 'BELU', 'FLOT', 'PIKK', 'SVAV',
#        'POSI', 'SNGSP', 'MTSS', 'MAGN', 'BANEP', 'BSPB'], dtype=object)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#         count  income_rate
# ticker
# PHOR      1.0     1.009423
# ROSN      2.0     0.997834
# NLMK      2.0     1.014000
# MDMG      2.0     1.008354
# GMKN      2.0     0.998990
# SNGSP     3.0     1.007333
# SNGS      3.0     0.996834
# NVTK      3.0     1.003587
# IRAO      3.0     1.014000
# YDEX      4.0     1.004000
# ALRS      5.0     0.996159
# ENPG      5.0     0.998000
# MOEX      5.0     1.012264
# HYDR      5.0     1.008806
# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features_fe, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1])
# Out:
# [('close/close_w30_ma', 1.57),
#  ('close/close_w10_ma', 2.25),
#  ('close/close_w10_expma', 2.79),
#  ('close_w10_max/close', 19.1),
#  ('close/close_w30_expma', 24.83),
#  ('close/close_1hour_w10_expma', 49.47)]

# %% [markdown]
# ### -1. TMP

# %% [markdown]
# #### 1. AUC

# %%
mask_data = df['y_pred'].notnull()
plt.figure(figsize=(10, 3))
(df.loc[mask_data, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
                                                                            roc_auc_score(x['target'], x['y_pred'])
                                                                                                          ) - 0.5).plot.bar()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/266340296.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_data, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
# <Axes: xlabel='time'>

# %% [markdown]
# #### 2. WIN

# %%
np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
# Out:
# 0.2591240486482249

# %%
q = 0.99
col_target = 'target'

mask_last_bin = df['y_pred'] >= np.quantile(df.loc[mask_valid, 'y_pred'], q=q)

mask_data = df['y_pred'].notnull()
plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
                                                                            x[col_target].mean()).plot.bar()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/3266791285.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
# <Axes: xlabel='time'>

# %% [markdown]
# #### 3. income_rate

# %%
q = 0.99
col_target = 'income_rate'

mask_last_bin = df['y_pred'] >= np.quantile(df.loc[mask_valid, 'y_pred'], q=q)

mask_data = df['y_pred'].notnull()
plt.figure(figsize=(10, 3))
(df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
                                                                            x[col_target].mean()) -1).plot.bar()
plt.grid()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/2651863704.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:

# %% [markdown]
# #### 4. Отложенная выборка

# %%
#distibution in time
#win
col_pred = 'y_pred'
q = 0.99
freq='D'

mask_data = mask_valid|mask_test|mask_test2|mask_test3

threshold = np.quantile(df.loc[mask_valid, col_pred], q=q)
mask_last_bin = df[col_pred] >= threshold


plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.mean().plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='Success Rate')
plt.legend()
plt.show()


#distibution in time
#income_rate
print('INCOME_RATE')

plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='INCOME_RATE')
plt.legend()
plt.show()
# Out:
# INCOME_RATE

# %%
#y_test3

# %%
#distibution in time
#win
col_pred = 'y_pred'
q = 0.99
freq='D'


mask_data = mask_test3


threshold = np.quantile(df.loc[mask_valid, col_pred], q=q)
mask_last_bin = df[col_pred] >= threshold


plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.mean().plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='Success Rate')
plt.legend()
plt.show()


#distibution in time
#income_rate
print('INCOME_RATE')

plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='INCOME_RATE')
plt.legend()
plt.show()
# Out:
# INCOME_RATE

# %%
#mean_income_rate_by_day
(df.loc[mask_valid&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean(), (df.loc[mask_test&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean(), (df.loc[mask_test2&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean()
# Out:
# (0.0033925232, 0.0039304667, 0.0036743742)

# %%
df.loc[mask_valid&mask_last_bin, 'time'].dt.date.nunique(), df.loc[mask_test&mask_last_bin, 'time'].dt.date.nunique(),  df.loc[mask_test2&mask_last_bin, 'time'].dt.date.nunique()
# Out:
# (42, 42, 39)

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.99)

# %%
#sum_income_rate
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.06965980877478917, 0.08253980102017522, 0.07331658277097483)

# %%
#test3
(df.loc[mask_test3&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean()
# Out:
# 0.0019698576

# %%
df.loc[mask_test3&mask_last_bin, 'time'].dt.date.nunique()
# Out:
# 22

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.035311521548363894

# %%
mask_data = mask_valid | mask_test | mask_test2

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/1640586492.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_data&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.0008289348788377716

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_valid&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/1656526771.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_valid&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.0005175173282623291

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_test&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/192763211.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_test&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.0017659252598172142

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_test2&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/1559495362.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_test2&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.00015524106147961738

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_test3&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/2683039865.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_test3&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.0013936947692524302

# %% [markdown]
# #### Points in life

# %%
threshold
# Out:
# 0.2591240486482249

# %%
mask_dev = df['time'] > pd.Timestamp('2025-01-20')
df.loc[mask_dev, 'y_pred'] = model.predict(df.loc[mask_dev, features_fe]) #feratures_fe

#threshold = 0.5695387939626755
df.loc[mask_dev, ['time', 'y_pred']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: (x['y_pred'] >= threshold).sum())
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_27664/1532415291.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_dev, ['time', 'y_pred']].groupby(pd.Grouper(key='time', freq='D')).apply(
# time
# 2025-01-20    66
# 2025-01-21     8
# 2025-01-22     6
# 2025-01-23     1
# 2025-01-24     7
# 2025-01-25     0
# 2025-01-26     0
# 2025-01-27    16
# 2025-01-28     3
# 2025-01-29     1
# 2025-01-30     0
# 2025-01-31     6
# 2025-02-01     0
# 2025-02-02     0
# 2025-02-03    14
# 2025-02-04     9
# 2025-02-05    24
# 2025-02-06    15
# 2025-02-07    17
# Freq: D, dtype: int64

# %% [markdown]
# ### Обучить на всем

# %%
features_fe = ['close/close_w10_ma',
 'close/close_w30_ma',
 'close/close_w10_expma',
 'close/close_w30_expma',
 'close_w10_max/close',
 'close/close_1hour_w10_expma']
cat_features = []
target = 'target'

# %%
mask_data = mask_train | mask_valid | mask_test | mask_test2
#mask_data = (pd.Timestamp('2024-01-01') <= df['time']) &  (df['time'] < pd.Timestamp('2025-01-01'))
#print(mask_data.sum())
#mask_data = mask_valid | mask_test | mask_test2
#mask_data = mask_test2

D_data = lgbm.Dataset(df.loc[mask_data, features_fe], label=df.loc[mask_data, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)


D_data.income_rate = df.loc[mask_data, 'income_rate'].values

D_data.time = df.loc[mask_data, 'time'].values

# %%
D_test3 = lgbm.Dataset(df.loc[mask_test3, features_fe], label=df.loc[mask_test3, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
D_test3.time = df.loc[mask_test3, 'time'].values

# %%
params
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 5,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.5,
#  'bagging_fraction': 0.3,
#  'bagging_freq': 1,
#  'lambda_l1': 1,
#  'lambda_l2': 1,
#  'verbose': -1,
#  'num_boost_round': 17}

# %%
model.num_trees()
# Out:
# 17

# %%
del params['metric'], params['early_stopping']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2433], line 1
# ----> 1 del params['metric'], params['early_stopping']
#
# KeyError: 'metric'

# %%
params['num_boost_round'] = 17

# %%
params = {'boosting_type': 'gbdt',
 'objective': 'binary',
 'num_leaves': 5,
 'learning_rate': 0.1,
 'feature_fraction': 0.5,
 'bagging_fraction': 0.3,
 'bagging_freq': 1,
 'lambda_l1': 1,
 'lambda_l2': 1,
 'verbose': -1,
 'num_boost_round': 17}

model = lgbm.train(params, train_set=D_data)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")

# %%
model.num_trees()
# Out:
# 17

# %%
dump_pkl(model, 'model_-0.5_+1.5_4hour.pkl')

# %%
model = load_pkl('model_-0.5_+1.5_4hour.pkl')
model.num_trees()
# Out:
# 17

# %%
y_pred_data= model.predict(D_data.data)


df["y_pred"] = None
df.loc[mask_data, 'y_pred'] = y_pred_data

roc_auc_score(D_data.label, y_pred_data)
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_45492/1894950171.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["y_pred"] = None
# 0.6437486059475304

# %%
#0.6437486059475304

# %%
y_pred_test3 = model.predict(D_test3.data)
df.loc[mask_test3, 'y_pred'] = y_pred_test3
roc_auc_score(D_test3.label, y_pred_test3)
# Out:
# 0.5884482625924234

# %%
#0.6092218820291359

# %%
THRESHOLD = 0.2591240486482249
THRESHOLD
# Out:
# 0.2591240486482249

# %%
mean_income_rate_point(D_data, y_pred_data, threshold=THRESHOLD)
# Out:
# 0.0022094249725341797

# %%
#0.0022094249725341797

# %%
mean_income_rate_day(D_data, y_pred_data, threshold=THRESHOLD)
# Out:
# 0.003565999

# %%
#0.003565999

# %%
mean_income_rate_month(D_data, y_pred_data, threshold=THRESHOLD)
# Out:
# 0.06537664798088372

# %%
#0.06537664798088372

# %%
mean_income_rate_point(D_test3, y_pred_test3, threshold=THRESHOLD)
# Out:
# 0.002313852310180664

# %%
#0.0008516311645507812

# %%
mean_income_rate_day(D_test3, y_pred_test3, threshold=THRESHOLD)
# Out:
# 0.003855751

# %%
#0.0027811702

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=THRESHOLD)
# Out:
# 0.0771150179207325

# %%
#0.05438732811146312

# %%
# +-

# %%
#distibution in time
#win
col_pred = 'y_pred'
freq='D'


mask_data = mask_test3


#threshold = np.quantile(df.loc[mask_valid, col_pred], q=q)
mask_last_bin = df[col_pred] > THRESHOLD


plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.mean().plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='Success Rate')
plt.legend()
plt.show()


#distibution in time
#income_rate
print('INCOME_RATE')

plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='INCOME_RATE')
plt.legend()
plt.show()
# Out:
# INCOME_RATE

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features_fe, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1])
# Out:
# [('close/close_w30_ma', 1.58),
#  ('close/close_w10_expma', 1.86),
#  ('close/close_w10_ma', 4.84),
#  ('close_w10_max/close', 20.64),
#  ('close/close_w30_expma', 23.15),
#  ('close/close_1hour_w10_expma', 47.92)]
