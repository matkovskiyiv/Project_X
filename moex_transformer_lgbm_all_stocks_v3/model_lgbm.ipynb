# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import math
import gc

from sklearn.metrics import roc_auc_score

import lightgbm as lgbm

import pickle
def dump_pkl(data, filename):
  with open(filename, 'wb') as handle:
    pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)

def load_pkl(filename):
  with open(filename, 'rb') as handle:
    data = pickle.load(handle)
  return data

# %%
df = load_pkl('./data/feat_engin/lgbm/data_1hour_1day.pkl')

# %%
df.shape
# Out:
# (1006243, 610)

# %%
df.head()
# Out:
#                  time  close ticker  index_1day result      delta_time  \
# 0 2022-05-05 10:00:00  31.24   AFLT         0.0   LOSE 1 days 00:00:00
# 1 2022-05-05 11:00:00  30.98   AFLT         0.0   LOSE 1 days 01:00:00
# 2 2022-05-05 12:00:00  30.92   AFLT         0.0   LOSE 1 days 00:00:00
# 3 2022-05-05 13:00:00  30.92   AFLT         0.0   LOSE 0 days 23:00:00
# 4 2022-05-05 14:00:00  31.00   AFLT         0.0   LOSE 0 days 22:00:00
#
#    income_rate  res_price  res_ind  close_w1_roc  ...  \
# 0         0.98  30.379999       18      0.001282  ...
# 1         0.98  30.280001       20     -0.008323  ...
# 2         0.98  30.280001       20     -0.001937  ...
# 3         0.98  30.280001       20      0.000000  ...
# 4         0.98  30.280001       20      0.002587  ...
#
#    tmos_close_1day_w100_ma_up_3std/tmos_close_1day  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    close_1day_w3_min/close_1day_w3_max  volume_1day_w3_min/volume_1day_w3_max  \
# 0                                  1.0                                    1.0
# 1                                  1.0                                    1.0
# 2                                  1.0                                    1.0
# 3                                  1.0                                    1.0
# 4                                  1.0                                    1.0
#
#    tmos_close_1day_w3_min/tmos_close_1day_w3_max  \
# 0                                            1.0
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
#
#    close_1day_w5_min/close_1day_w5_max  volume_1day_w5_min/volume_1day_w5_max  \
# 0                                  1.0                                    1.0
# 1                                  1.0                                    1.0
# 2                                  1.0                                    1.0
# 3                                  1.0                                    1.0
# 4                                  1.0                                    1.0
#
#    tmos_close_1day_w5_min/tmos_close_1day_w5_max  \
# 0                                            1.0
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
#
#    close_1day_w20_min/close_1day_w20_max  \
# 0                                    1.0
# 1                                    1.0
# 2                                    1.0
# 3                                    1.0
# 4                                    1.0
#
#    volume_1day_w20_min/volume_1day_w20_max  \
# 0                                      1.0
# 1                                      1.0
# 2                                      1.0
# 3                                      1.0
# 4                                      1.0
#
#    tmos_close_1day_w20_min/tmos_close_1day_w20_max
# 0                                              1.0
# 1                                              1.0
# 2                                              1.0
# 3                                              1.0
# 4                                              1.0
#
# [5 rows x 610 columns]

# %%
df['result'].value_counts(normalize=True)
# Out:
# result
# DNF     0.470228
# LOSE    0.361896
# WIN     0.167876
# Name: proportion, dtype: float64

# %%
df['income_rate'].quantile(q=[0, 0.01]+np.arange(0.1, 1, 0.1).tolist()+[0.99, 1])
# Out:
# 0.00    0.980000
# 0.01    0.980000
# 0.10    0.980000
# 0.20    0.980000
# 0.30    0.980000
# 0.40    0.988014
# 0.50    0.996850
# 0.60    1.003813
# 0.70    1.012367
# 0.80    1.026706
# 0.90    1.040000
# 0.99    1.040000
# 1.00    1.040000
# Name: income_rate, dtype: float64

# %% [markdown]
# ### 1. train/valid/test/test2 split

# %%
df['target'] = (df['result'] == 'WIN').astype(int)

# %%
df[['time', 'target']].groupby(pd.Grouper(key='time', freq='ME')).target.count().plot.bar()
# Out:
# <Axes: xlabel='time'>

# %%
df[['time', 'target']].groupby(pd.Grouper(key='time', freq='ME')).target.mean().plot.bar()
# Out:
# <Axes: xlabel='time'>

# %%
(df[['time', 'income_rate']].groupby(pd.Grouper(key='time', freq='ME')).income_rate.mean()-1).plot.bar()
# Out:
# <Axes: xlabel='time'>

# %%
pd.set_option('display.max_rows', 150)
df[['ticker', 'target']].groupby('ticker').target.mean().sort_values()
# Out:
# ticker
# IRAO       0.058961
# LKOH       0.064465
# PHOR       0.065261
# MTSS       0.068984
# ROSN       0.070393
# SBERP      0.071202
# HYDR       0.071262
# SBER       0.076923
# TATNP      0.080488
# GMKN       0.081992
# CBOM       0.084061
# GAZP       0.084471
# TATN       0.086574
# AKRN       0.092032
# TRNFP      0.092084
# RTKMP      0.092573
# RTKM       0.093462
# SNGSP      0.094512
# ALRS       0.095384
# MOEX       0.096005
# MGNT       0.100254
# MAGN       0.100783
# NVTK       0.100880
# VTBR       0.104000
# SIBN       0.104469
# RUAL       0.106602
# VSMO       0.107947
# PLZL       0.108048
# CHMF       0.112205
# BELU       0.117052
# SGZH       0.119342
# POSI       0.122507
# NLMK       0.125768
# ENPG       0.129799
# OGKB       0.130048
# KRKNP      0.131417
# UPRO       0.133174
# SNGS       0.133863
# AFKS       0.135742
# SMLT       0.136374
# PIKK       0.136470
# FEES       0.137432
# T          0.139886
# LSNGP      0.141233
# AFLT       0.142085
# KAZT       0.143502
# MSNG       0.147574
# AQUA       0.148669
# MSRS       0.152936
# YDEX       0.153812
# GCHE       0.155194
# APTK       0.157289
# MVID       0.158462
# NKNCP      0.160820
# FLOT       0.161662
# TGKA       0.162831
# VKCO       0.163449
# KAZTP      0.166442
# ELFV       0.166442
# LENT       0.170526
# MRKP       0.174456
# KZOS       0.175131
# LNZL       0.177287
# SELG       0.179351
# KMAZ       0.182315
# YAKG       0.184338
# BANEP      0.184545
# ABRD       0.184994
# RASP       0.186818
# LNZLP      0.188445
# TRMK       0.189097
# BSPB       0.189446
# NKNC       0.189667
# MDMG       0.197318
# KZOSP      0.202346
# BANE       0.203269
# CNTLP      0.203458
# LSRG       0.206202
# SFIN       0.206587
# WUSH       0.207079
# MRKC       0.207158
# RENI       0.207690
# FESH       0.209582
# RKKE       0.209726
# MTLR       0.210288
# MRKV       0.210593
# UNKL       0.211075
# NMTP       0.212140
# ROLO       0.215924
# MTLRP      0.216873
# SPBE       0.219971
# TTLK       0.220224
# MRKS       0.220319
# PMSB       0.221635
# UNAC       0.223087
# AMEZ       0.224975
# ABIO       0.226716
# NKHP       0.227128
# RNFT       0.227971
# VEON-RX    0.229956
# LIFE       0.233190
# CNTL       0.233598
# MGTSP      0.233654
# SVAV       0.233705
# CHMK       0.238343
# GEMC       0.239500
# MRKU       0.244720
# LSNG       0.245326
# HEAD       0.247461
# MSTT       0.249313
# MRKY       0.250539
# PMSBP      0.252929
# BLNG       0.252995
# IRKT       0.253653
# RBCM       0.256323
# TGKN       0.262416
# KROT       0.262601
# TGKBP      0.262702
# NSVZ       0.265118
# VRSB       0.266269
# GTRK       0.266658
# MRKZ       0.267384
# PRFN       0.267414
# DVEC       0.267829
# KLSB       0.280735
# UWGN       0.282337
# TGKB       0.294547
# Name: target, dtype: float64

# %%
df[['ticker', 'income_rate']].groupby('ticker').income_rate.mean().sort_values()
# Out:
# ticker
# VSMO       0.998559
# SGZH       0.999273
# YAKG       0.999598
# HYDR       0.999622
# LNZL       0.999794
# VEON-RX    0.999825
# RKKE       1.000045
# RUAL       1.000103
# SMLT       1.000186
# GAZP       1.000205
# GMKN       1.000242
# IRKT       1.000416
# ENPG       1.000418
# LNZLP      1.000485
# NVTK       1.000586
# UNAC       1.000599
# VTBR       1.000628
# PHOR       1.000637
# APTK       1.000649
# ABIO       1.000740
# ALRS       1.000756
# KAZT       1.000781
# ROLO       1.000805
# KMAZ       1.000811
# MRKS       1.000934
# MAGN       1.000956
# PIKK       1.001013
# SPBE       1.001025
# UNKL       1.001041
# KRKNP      1.001056
# CNTLP      1.001079
# TRNFP      1.001116
# MTLRP      1.001124
# RTKMP      1.001128
# RTKM       1.001162
# KAZTP      1.001180
# VKCO       1.001199
# OGKB       1.001239
# MGNT       1.001264
# LIFE       1.001295
# AKRN       1.001352
# MVID       1.001374
# KZOSP      1.001380
# MTSS       1.001413
# T          1.001445
# KZOS       1.001495
# WUSH       1.001511
# MGTSP      1.001526
# UWGN       1.001624
# TGKBP      1.001657
# UPRO       1.001664
# LENT       1.001674
# GTRK       1.001683
# CBOM       1.001688
# MTLR       1.001718
# FEES       1.001732
# IRAO       1.001733
# TRMK       1.001760
# SNGS       1.001766
# NKNC       1.001837
# FLOT       1.001849
# TGKA       1.001855
# BELU       1.001861
# FESH       1.001879
# ELFV       1.001924
# LSNG       1.001930
# RNFT       1.001932
# ROSN       1.001932
# NLMK       1.001991
# AQUA       1.002079
# AFKS       1.002152
# LKOH       1.002245
# SVAV       1.002249
# RASP       1.002251
# AMEZ       1.002257
# KROT       1.002286
# GEMC       1.002293
# NSVZ       1.002296
# SIBN       1.002307
# CHMK       1.002314
# SELG       1.002335
# NKHP       1.002371
# CHMF       1.002376
# TATN       1.002380
# AFLT       1.002391
# POSI       1.002424
# MRKY       1.002432
# MSNG       1.002543
# NMTP       1.002565
# TATNP      1.002603
# SBER       1.002629
# PLZL       1.002641
# CNTL       1.002666
# NKNCP      1.002692
# ABRD       1.002704
# MRKZ       1.002722
# SBERP      1.002729
# MSTT       1.002758
# TGKN       1.002800
# RBCM       1.002828
# RENI       1.002842
# DVEC       1.002847
# YDEX       1.002860
# MOEX       1.002908
# LSNGP      1.002956
# BLNG       1.002967
# TGKB       1.002990
# HEAD       1.003005
# PRFN       1.003019
# TTLK       1.003073
# LSRG       1.003112
# MRKV       1.003233
# GCHE       1.003375
# SNGSP      1.003396
# MRKU       1.003481
# MSRS       1.003490
# VRSB       1.003505
# KLSB       1.003701
# SFIN       1.003754
# MRKP       1.003838
# BSPB       1.003964
# PMSBP      1.004057
# BANE       1.004086
# MDMG       1.004258
# BANEP      1.004367
# MRKC       1.004588
# PMSB       1.004937
# Name: income_rate, dtype: float32

# %%
df['time'].max()
# Out:
# Timestamp('2025-01-29 23:00:00')

# %%
mask_train = np.array((pd.Timestamp('2022-01-01') <= df['time']) & (df['time'] < pd.Timestamp('2024-06-01')))
mask_valid = np.array((pd.Timestamp('2024-06-01') <= df['time']) & (df['time'] < pd.Timestamp('2024-08-01')))
mask_test = np.array((pd.Timestamp('2024-08-01') <= df['time']) & (df['time'] < pd.Timestamp('2024-10-01')))
mask_test2 = np.array((pd.Timestamp('2024-10-01') <= df['time']) & (df['time'] < pd.Timestamp('2024-12-23')))
mask_test3 = np.array((pd.Timestamp('2024-12-23') <= df['time']) & (df['time'] < pd.Timestamp('2025-01-28')))

# %%
mask_test3.sum()
# Out:
# 43361

# %%
mask_train.sum(), mask_valid.sum(), mask_test.sum(), mask_test2.sum()
# Out:
# (713114, 70129, 74239, 101909)

# %%
# некоторые акции имеют более короткую историю
NEED_POINTS = 101
mask_avbl_all = np.zeros_like(mask_train).astype(bool)
for ticker in df["ticker"].unique():
    mask = np.array(df['ticker'] == ticker)
    count_days = df.loc[mask, 'time'].dt.date.nunique()
    if count_days < NEED_POINTS:
        mask_avbl = np.zeros_like(mask_train).astype(bool)
    else:
        date_first_avbl =  np.sort(df.loc[mask, 'time'].dt.date.unique())[NEED_POINTS]
        #print(date_first_avbl)
        mask_avbl = np.array(df["time"] >= pd.to_datetime(date_first_avbl))
    
    mask_ticker = np.array(df['ticker'] == ticker)
    mask_avbl_ticker = mask_ticker & mask_avbl

    mask_avbl_all |= mask_avbl_ticker

mask_train &= mask_avbl_all
mask_valid &= mask_avbl_all
mask_test &= mask_avbl_all
mask_test2 &= mask_avbl_all


#мб дату неправильно обрезаю

# %%
mask_train.sum(), mask_valid.sum(), mask_test.sum(), mask_test2.sum()
# Out:
# (595945, 70129, 74239, 101909)

# %%
mask_data = mask_train|mask_valid|mask_test|mask_test2
(mask_data).sum()
# Out:
# 842222

# %%
df.loc[mask_data].isnull().sum()[df.loc[mask_data].isnull().sum() > 0].sort_values()
# Out:
# Series([], dtype: int64)

# %%
mask_train.sum()/(mask_data).sum(), mask_valid.sum()/(mask_data).sum(), mask_test.sum()/(mask_data).sum(), mask_test2.sum()/(mask_data).sum()
# Out:
# (0.7075865983078096,
#  0.08326664466138381,
#  0.08814659317852062,
#  0.12100016385228597)

# %%
#

# %%
df.loc[mask_train, 'target'].mean(), df.loc[mask_valid, 'target'].mean(), df.loc[mask_test, 'target'].mean(), df.loc[mask_test2, 'target'].mean()
# Out:
# (0.1587075988555991,
#  0.16215830826049138,
#  0.1812928514662105,
#  0.15419639089776171)

# %%
df.loc[mask_test3, 'target'].mean()
# Out:
# 0.20892045847651114

# %%
df.loc[mask_train, 'income_rate'].mean(), df.loc[mask_valid, 'income_rate'].mean(), df.loc[mask_test, 'income_rate'].mean(), df.loc[mask_test2, 'income_rate'].mean()
# Out:
# (1.0029066, 0.9991569, 1.0002859, 0.9984382)

# %%
#(1.0027912, 0.99597716, 1.0007247, 1.0005852)

# %%
df.loc[mask_test3, 'income_rate'].mean()
# Out:
# 1.0054334

# %%
#проверки

# %%
(mask_train.sum()+mask_valid.sum()+mask_test.sum()+mask_test2.sum()) ==(mask_data).sum()

#(mask_train.sum()+mask_valid.sum()+mask_test.sum()) ==(mask_data).sum()
# Out:
# True

# %% [markdown]
# ## 3. Model

# %% [markdown]
# ### 3.1 Base model

# %%
df['ticker_code'] = df['ticker'].astype('category').cat.codes

# %%
df['ticker_code'].nunique()
# Out:
# 127

# %%
df.loc[mask_train, 'ticker_code'].nunique()
# Out:
# 127

# %%
df.columns.tolist()
# Out:
# ['time',
#  'close',
#  'ticker',
#  'index_1day',
#  'result',
#  'delta_time',
#  'income_rate',
#  'res_price',
#  'res_ind',
#  'close_w1_roc',
#  'volume_w1_roc',
#  'tmos_close_w1_roc',
#  'close_w5_norm_std',
#  'close_w5_mean_abs_pct',
#  'close_w5_alpha',
#  'close_w5_rsi',
#  'close_w5_roc',
#  'volume_w5_norm_std',
#  'volume_w5_mean_abs_pct',
#  'volume_w5_alpha',
#  'volume_w5_rsi',
#  'volume_w5_roc',
#  'tmos_close_w5_norm_std',
#  'tmos_close_w5_mean_abs_pct',
#  'tmos_close_w5_alpha',
#  'tmos_close_w5_rsi',
#  'tmos_close_w5_roc',
#  'close_w14_norm_std',
#  'close_w14_mean_abs_pct',
#  'close_w14_alpha',
#  'close_w14_rsi',
#  'close_w14_roc',
#  'volume_w14_norm_std',
#  'volume_w14_mean_abs_pct',
#  'volume_w14_alpha',
#  'volume_w14_rsi',
#  'volume_w14_roc',
#  'tmos_close_w14_norm_std',
#  'tmos_close_w14_mean_abs_pct',
#  'tmos_close_w14_alpha',
#  'tmos_close_w14_rsi',
#  'tmos_close_w14_roc',
#  'close_w70_norm_std',
#  'close_w70_mean_abs_pct',
#  'close_w70_alpha',
#  'close_w70_rsi',
#  'close_w70_roc',
#  'close_w70_lvl_1-1.005',
#  'close_w70_lvl_-0.995-1',
#  'close_w70_lvl_1.005-1.01',
#  'close_w70_lvl_-0.99-0.995',
#  'close_w70_lvl_1.01-1.02',
#  'close_w70_lvl_-0.98-0.99',
#  'close_w70_lvl_1.02-1.03',
#  'close_w70_lvl_-0.97-0.98',
#  'close_w70_lvl_1.03-1.04',
#  'close_w70_lvl_-0.96-0.97',
#  'close_w70_lvl_1.04-1.05',
#  'close_w70_lvl_-0.95-0.96',
#  'close_w70_lvl_1.05-1.07',
#  'close_w70_lvl_-0.9299999999999999-0.95',
#  'volume_w70_norm_std',
#  'volume_w70_mean_abs_pct',
#  'volume_w70_alpha',
#  'volume_w70_rsi',
#  'volume_w70_roc',
#  'tmos_close_w70_norm_std',
#  'tmos_close_w70_mean_abs_pct',
#  'tmos_close_w70_alpha',
#  'tmos_close_w70_rsi',
#  'tmos_close_w70_roc',
#  'tmos_close_w70_lvl_1-1.005',
#  'tmos_close_w70_lvl_-0.995-1',
#  'tmos_close_w70_lvl_1.005-1.01',
#  'tmos_close_w70_lvl_-0.99-0.995',
#  'tmos_close_w70_lvl_1.01-1.015',
#  'tmos_close_w70_lvl_-0.985-0.99',
#  'tmos_close_w70_lvl_1.015-1.02',
#  'tmos_close_w70_lvl_-0.98-0.985',
#  'tmos_close_w70_lvl_1.02-1.03',
#  'tmos_close_w70_lvl_-0.97-0.98',
#  'tmos_close_w70_lvl_1.03-1.04',
#  'tmos_close_w70_lvl_-0.96-0.97',
#  'tmos_close_w70_lvl_1.04-1.05',
#  'tmos_close_w70_lvl_-0.95-0.96',
#  'hour',
#  'day',
#  'weekday',
#  'sin_time_hour',
#  'cos_time_hour',
#  'close_w1_roc/close_w5_alpha',
#  'close_w1_roc/close_w14_alpha',
#  'close_w1_roc/close_w70_alpha',
#  'close_w5_alpha/close_w14_alpha',
#  'close_w5_alpha/close_w70_alpha',
#  'close_w14_alpha/close_w70_alpha',
#  'volume_w1_roc/volume_w5_alpha',
#  'volume_w1_roc/volume_w14_alpha',
#  'volume_w1_roc/volume_w70_alpha',
#  'volume_w5_alpha/volume_w14_alpha',
#  'volume_w5_alpha/volume_w70_alpha',
#  'volume_w14_alpha/volume_w70_alpha',
#  'tmos_close_w1_roc/tmos_close_w5_alpha',
#  'tmos_close_w1_roc/tmos_close_w14_alpha',
#  'tmos_close_w1_roc/tmos_close_w70_alpha',
#  'tmos_close_w5_alpha/tmos_close_w14_alpha',
#  'tmos_close_w5_alpha/tmos_close_w70_alpha',
#  'tmos_close_w14_alpha/tmos_close_w70_alpha',
#  'close_w1_roc/close_w5_roc',
#  'close_w1_roc/close_w14_roc',
#  'close_w1_roc/close_w70_roc',
#  'close_w5_roc/close_w14_roc',
#  'close_w5_roc/close_w70_roc',
#  'close_w14_roc/close_w70_roc',
#  'volume_w1_roc/volume_w5_roc',
#  'volume_w1_roc/volume_w14_roc',
#  'volume_w1_roc/volume_w70_roc',
#  'volume_w5_roc/volume_w14_roc',
#  'volume_w5_roc/volume_w70_roc',
#  'volume_w14_roc/volume_w70_roc',
#  'tmos_close_w1_roc/tmos_close_w5_roc',
#  'tmos_close_w1_roc/tmos_close_w14_roc',
#  'tmos_close_w1_roc/tmos_close_w70_roc',
#  'tmos_close_w5_roc/tmos_close_w14_roc',
#  'tmos_close_w5_roc/tmos_close_w70_roc',
#  'tmos_close_w14_roc/tmos_close_w70_roc',
#  'close_w5_mean_abs_pct/close_w14_mean_abs_pct',
#  'close_w5_mean_abs_pct/close_w70_mean_abs_pct',
#  'close_w14_mean_abs_pct/close_w70_mean_abs_pct',
#  'volume_w5_mean_abs_pct/volume_w14_mean_abs_pct',
#  'volume_w5_mean_abs_pct/volume_w70_mean_abs_pct',
#  'volume_w14_mean_abs_pct/volume_w70_mean_abs_pct',
#  'tmos_close_w5_mean_abs_pct/tmos_close_w14_mean_abs_pct',
#  'tmos_close_w5_mean_abs_pct/tmos_close_w70_mean_abs_pct',
#  'tmos_close_w14_mean_abs_pct/tmos_close_w70_mean_abs_pct',
#  'close_w5_std/close_w14_std',
#  'close_w5_std/close_w70_std',
#  'close_w14_std/close_w70_std',
#  'volume_w5_std/volume_w14_std',
#  'volume_w5_std/volume_w70_std',
#  'volume_w14_std/volume_w70_std',
#  'tmos_close_w5_std/tmos_close_w14_std',
#  'tmos_close_w5_std/tmos_close_w70_std',
#  'tmos_close_w14_std/tmos_close_w70_std',
#  'close_w5_norm_std/close_w14_norm_std',
#  'close_w5_norm_std/close_w70_norm_std',
#  'close_w14_norm_std/close_w70_norm_std',
#  'volume_w5_norm_std/volume_w14_norm_std',
#  'volume_w5_norm_std/volume_w70_norm_std',
#  'volume_w14_norm_std/volume_w70_norm_std',
#  'tmos_close_w5_norm_std/tmos_close_w14_norm_std',
#  'tmos_close_w5_norm_std/tmos_close_w70_norm_std',
#  'tmos_close_w14_norm_std/tmos_close_w70_norm_std',
#  'close_w5_rsi/close_w14_rsi',
#  'close_w5_rsi/close_w70_rsi',
#  'close_w14_rsi/close_w70_rsi',
#  'volume_w5_rsi/volume_w14_rsi',
#  'volume_w5_rsi/volume_w70_rsi',
#  'volume_w14_rsi/volume_w70_rsi',
#  'tmos_close_w5_rsi/tmos_close_w14_rsi',
#  'tmos_close_w5_rsi/tmos_close_w70_rsi',
#  'tmos_close_w14_rsi/tmos_close_w70_rsi',
#  'close/close_w5_ma',
#  'close/close_w14_ma',
#  'close/close_w70_ma',
#  'close_w5_ma/close_w14_ma',
#  'close_w5_ma/close_w70_ma',
#  'close_w14_ma/close_w70_ma',
#  'volume/volume_w5_ma',
#  'volume/volume_w14_ma',
#  'volume/volume_w70_ma',
#  'volume_w5_ma/volume_w14_ma',
#  'volume_w5_ma/volume_w70_ma',
#  'volume_w14_ma/volume_w70_ma',
#  'tmos_close/tmos_close_w5_ma',
#  'tmos_close/tmos_close_w14_ma',
#  'tmos_close/tmos_close_w70_ma',
#  'tmos_close_w5_ma/tmos_close_w14_ma',
#  'tmos_close_w5_ma/tmos_close_w70_ma',
#  'tmos_close_w14_ma/tmos_close_w70_ma',
#  'close_w5_min/close',
#  'close_w14_min/close',
#  'close_w70_min/close',
#  'volume_w5_min/volume',
#  'volume_w14_min/volume',
#  'volume_w70_min/volume',
#  'tmos_close_w5_min/tmos_close',
#  'tmos_close_w14_min/tmos_close',
#  'tmos_close_w70_min/tmos_close',
#  'close_w5_max/close',
#  'close_w14_max/close',
#  'close_w70_max/close',
#  'volume_w5_max/volume',
#  'volume_w14_max/volume',
#  'volume_w70_max/volume',
#  'tmos_close_w5_max/tmos_close',
#  'tmos_close_w14_max/tmos_close',
#  'tmos_close_w70_max/tmos_close',
#  'close_w5_ma_low_2std/close',
#  'close_w5_ma_up_2std/close',
#  'close_w5_ma_low_3std/close',
#  'close_w5_ma_up_3std/close',
#  'volume_w5_ma_low_2std/volume',
#  'volume_w5_ma_up_2std/volume',
#  'volume_w5_ma_low_3std/volume',
#  'volume_w5_ma_up_3std/volume',
#  'tmos_close_w5_ma_low_2std/tmos_close',
#  'tmos_close_w5_ma_up_2std/tmos_close',
#  'tmos_close_w5_ma_low_3std/tmos_close',
#  'tmos_close_w5_ma_up_3std/tmos_close',
#  'close_w14_ma_low_2std/close',
#  'close_w14_ma_up_2std/close',
#  'close_w14_ma_low_3std/close',
#  'close_w14_ma_up_3std/close',
#  'volume_w14_ma_low_2std/volume',
#  'volume_w14_ma_up_2std/volume',
#  'volume_w14_ma_low_3std/volume',
#  'volume_w14_ma_up_3std/volume',
#  'tmos_close_w14_ma_low_2std/tmos_close',
#  'tmos_close_w14_ma_up_2std/tmos_close',
#  'tmos_close_w14_ma_low_3std/tmos_close',
#  'tmos_close_w14_ma_up_3std/tmos_close',
#  'close_w70_ma_low_2std/close',
#  'close_w70_ma_up_2std/close',
#  'close_w70_ma_low_3std/close',
#  'close_w70_ma_up_3std/close',
#  'volume_w70_ma_low_2std/volume',
#  'volume_w70_ma_up_2std/volume',
#  'volume_w70_ma_low_3std/volume',
#  'volume_w70_ma_up_3std/volume',
#  'tmos_close_w70_ma_low_2std/tmos_close',
#  'tmos_close_w70_ma_up_2std/tmos_close',
#  'tmos_close_w70_ma_low_3std/tmos_close',
#  'tmos_close_w70_ma_up_3std/tmos_close',
#  'close_w5_min/close_w5_max',
#  'volume_w5_min/volume_w5_max',
#  'tmos_close_w5_min/tmos_close_w5_max',
#  'close_w14_min/close_w14_max',
#  'volume_w14_min/volume_w14_max',
#  'tmos_close_w14_min/tmos_close_w14_max',
#  'close_w70_min/close_w70_max',
#  'volume_w70_min/volume_w70_max',
#  'tmos_close_w70_min/tmos_close_w70_max',
#  'index',
#  'close_1day_w1_roc',
#  'volume_1day_w1_roc',
#  'tmos_close_1day_w1_roc',
#  'close_1day_w3_norm_std',
#  'close_1day_w3_mean_abs_pct',
#  'close_1day_w3_alpha',
#  'close_1day_w3_rsi',
#  'close_1day_w3_roc',
#  'volume_1day_w3_norm_std',
#  'volume_1day_w3_mean_abs_pct',
#  'volume_1day_w3_alpha',
#  'volume_1day_w3_rsi',
#  'volume_1day_w3_roc',
#  'tmos_close_1day_w3_norm_std',
#  'tmos_close_1day_w3_mean_abs_pct',
#  'tmos_close_1day_w3_alpha',
#  'tmos_close_1day_w3_rsi',
#  'tmos_close_1day_w3_roc',
#  'close_1day_w5_norm_std',
#  'close_1day_w5_mean_abs_pct',
#  'close_1day_w5_alpha',
#  'close_1day_w5_rsi',
#  'close_1day_w5_roc',
#  'volume_1day_w5_norm_std',
#  'volume_1day_w5_mean_abs_pct',
#  'volume_1day_w5_alpha',
#  'volume_1day_w5_rsi',
#  'volume_1day_w5_roc',
#  'tmos_close_1day_w5_norm_std',
#  'tmos_close_1day_w5_mean_abs_pct',
#  'tmos_close_1day_w5_alpha',
#  'tmos_close_1day_w5_rsi',
#  'tmos_close_1day_w5_roc',
#  'close_1day_w20_norm_std',
#  'close_1day_w20_mean_abs_pct',
#  'close_1day_w20_alpha',
#  'close_1day_w20_rsi',
#  'close_1day_w20_roc',
#  'close_1day_w20_lvl_1-1.005',
#  'close_1day_w20_lvl_-0.995-1',
#  'close_1day_w20_lvl_1.005-1.01',
#  'close_1day_w20_lvl_-0.99-0.995',
#  'close_1day_w20_lvl_1.01-1.02',
#  'close_1day_w20_lvl_-0.98-0.99',
#  'close_1day_w20_lvl_1.02-1.03',
#  'close_1day_w20_lvl_-0.97-0.98',
#  'close_1day_w20_lvl_1.03-1.04',
#  'close_1day_w20_lvl_-0.96-0.97',
#  'close_1day_w20_lvl_1.04-1.05',
#  'close_1day_w20_lvl_-0.95-0.96',
#  'close_1day_w20_lvl_1.05-1.07',
#  'close_1day_w20_lvl_-0.9299999999999999-0.95',
#  'volume_1day_w20_norm_std',
#  'volume_1day_w20_mean_abs_pct',
#  'volume_1day_w20_alpha',
#  'volume_1day_w20_rsi',
#  'volume_1day_w20_roc',
#  'tmos_close_1day_w20_norm_std',
#  'tmos_close_1day_w20_mean_abs_pct',
#  'tmos_close_1day_w20_alpha',
#  'tmos_close_1day_w20_rsi',
#  'tmos_close_1day_w20_roc',
#  'tmos_close_1day_w20_lvl_1-1.005',
#  'tmos_close_1day_w20_lvl_-0.995-1',
#  'tmos_close_1day_w20_lvl_1.005-1.01',
#  'tmos_close_1day_w20_lvl_-0.99-0.995',
#  'tmos_close_1day_w20_lvl_1.01-1.015',
#  'tmos_close_1day_w20_lvl_-0.985-0.99',
#  'tmos_close_1day_w20_lvl_1.015-1.02',
#  'tmos_close_1day_w20_lvl_-0.98-0.985',
#  'tmos_close_1day_w20_lvl_1.02-1.03',
#  'tmos_close_1day_w20_lvl_-0.97-0.98',
#  'tmos_close_1day_w20_lvl_1.03-1.04',
#  'tmos_close_1day_w20_lvl_-0.96-0.97',
#  'tmos_close_1day_w20_lvl_1.04-1.05',
#  'tmos_close_1day_w20_lvl_-0.95-0.96',
#  'close_1day_w100_norm_std',
#  'close_1day_w100_mean_abs_pct',
#  'close_1day_w100_alpha',
#  'close_1day_w100_rsi',
#  'close_1day_w100_roc',
#  'close_1day_w100_lvl_1-1.005',
#  'close_1day_w100_lvl_-0.995-1',
#  'close_1day_w100_lvl_1.005-1.01',
#  'close_1day_w100_lvl_-0.99-0.995',
#  'close_1day_w100_lvl_1.01-1.02',
#  'close_1day_w100_lvl_-0.98-0.99',
#  'close_1day_w100_lvl_1.02-1.03',
#  'close_1day_w100_lvl_-0.97-0.98',
#  'close_1day_w100_lvl_1.03-1.04',
#  'close_1day_w100_lvl_-0.96-0.97',
#  'close_1day_w100_lvl_1.04-1.05',
#  'close_1day_w100_lvl_-0.95-0.96',
#  'close_1day_w100_lvl_1.05-1.07',
#  'close_1day_w100_lvl_-0.9299999999999999-0.95',
#  'volume_1day_w100_norm_std',
#  'volume_1day_w100_mean_abs_pct',
#  'volume_1day_w100_alpha',
#  'volume_1day_w100_rsi',
#  'volume_1day_w100_roc',
#  'tmos_close_1day_w100_norm_std',
#  'tmos_close_1day_w100_mean_abs_pct',
#  'tmos_close_1day_w100_alpha',
#  'tmos_close_1day_w100_rsi',
#  'tmos_close_1day_w100_roc',
#  'tmos_close_1day_w100_lvl_1-1.005',
#  'tmos_close_1day_w100_lvl_-0.995-1',
#  'tmos_close_1day_w100_lvl_1.005-1.01',
#  'tmos_close_1day_w100_lvl_-0.99-0.995',
#  'tmos_close_1day_w100_lvl_1.01-1.015',
#  'tmos_close_1day_w100_lvl_-0.985-0.99',
#  'tmos_close_1day_w100_lvl_1.015-1.02',
#  'tmos_close_1day_w100_lvl_-0.98-0.985',
#  'tmos_close_1day_w100_lvl_1.02-1.03',
#  'tmos_close_1day_w100_lvl_-0.97-0.98',
#  'tmos_close_1day_w100_lvl_1.03-1.04',
#  'tmos_close_1day_w100_lvl_-0.96-0.97',
#  'tmos_close_1day_w100_lvl_1.04-1.05',
#  'tmos_close_1day_w100_lvl_-0.95-0.96',
#  'sin_time_weekday',
#  'cos_time_weekday',
#  'sin_time_monthday',
#  'cos_time_monthday',
#  'close_1day_w1_roc/close_1day_w3_alpha',
#  'close_1day_w1_roc/close_1day_w5_alpha',
#  'close_1day_w1_roc/close_1day_w20_alpha',
#  'close_1day_w1_roc/close_1day_w100_alpha',
#  'close_1day_w3_alpha/close_1day_w5_alpha',
#  'close_1day_w3_alpha/close_1day_w20_alpha',
#  'close_1day_w3_alpha/close_1day_w100_alpha',
#  'close_1day_w5_alpha/close_1day_w20_alpha',
#  'close_1day_w5_alpha/close_1day_w100_alpha',
#  'close_1day_w20_alpha/close_1day_w100_alpha',
#  'volume_1day_w1_roc/volume_1day_w3_alpha',
#  'volume_1day_w1_roc/volume_1day_w5_alpha',
#  'volume_1day_w1_roc/volume_1day_w20_alpha',
#  'volume_1day_w1_roc/volume_1day_w100_alpha',
#  'volume_1day_w3_alpha/volume_1day_w5_alpha',
#  'volume_1day_w3_alpha/volume_1day_w20_alpha',
#  'volume_1day_w3_alpha/volume_1day_w100_alpha',
#  'volume_1day_w5_alpha/volume_1day_w20_alpha',
#  'volume_1day_w5_alpha/volume_1day_w100_alpha',
#  'volume_1day_w20_alpha/volume_1day_w100_alpha',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w3_alpha',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w5_alpha',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w20_alpha',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w100_alpha',
#  'tmos_close_1day_w3_alpha/tmos_close_1day_w5_alpha',
#  'tmos_close_1day_w3_alpha/tmos_close_1day_w20_alpha',
#  'tmos_close_1day_w3_alpha/tmos_close_1day_w100_alpha',
#  'tmos_close_1day_w5_alpha/tmos_close_1day_w20_alpha',
#  'tmos_close_1day_w5_alpha/tmos_close_1day_w100_alpha',
#  'tmos_close_1day_w20_alpha/tmos_close_1day_w100_alpha',
#  'close_1day_w1_roc/close_1day_w3_roc',
#  'close_1day_w1_roc/close_1day_w5_roc',
#  'close_1day_w1_roc/close_1day_w20_roc',
#  'close_1day_w1_roc/close_1day_w100_roc',
#  'close_1day_w3_roc/close_1day_w5_roc',
#  'close_1day_w3_roc/close_1day_w20_roc',
#  'close_1day_w3_roc/close_1day_w100_roc',
#  'close_1day_w5_roc/close_1day_w20_roc',
#  'close_1day_w5_roc/close_1day_w100_roc',
#  'close_1day_w20_roc/close_1day_w100_roc',
#  'volume_1day_w1_roc/volume_1day_w3_roc',
#  'volume_1day_w1_roc/volume_1day_w5_roc',
#  'volume_1day_w1_roc/volume_1day_w20_roc',
#  'volume_1day_w1_roc/volume_1day_w100_roc',
#  'volume_1day_w3_roc/volume_1day_w5_roc',
#  'volume_1day_w3_roc/volume_1day_w20_roc',
#  'volume_1day_w3_roc/volume_1day_w100_roc',
#  'volume_1day_w5_roc/volume_1day_w20_roc',
#  'volume_1day_w5_roc/volume_1day_w100_roc',
#  'volume_1day_w20_roc/volume_1day_w100_roc',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w3_roc',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w5_roc',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w20_roc',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w100_roc',
#  'tmos_close_1day_w3_roc/tmos_close_1day_w5_roc',
#  'tmos_close_1day_w3_roc/tmos_close_1day_w20_roc',
#  'tmos_close_1day_w3_roc/tmos_close_1day_w100_roc',
#  'tmos_close_1day_w5_roc/tmos_close_1day_w20_roc',
#  'tmos_close_1day_w5_roc/tmos_close_1day_w100_roc',
#  'tmos_close_1day_w20_roc/tmos_close_1day_w100_roc',
#  'close_1day_w3_mean_abs_pct/close_1day_w5_mean_abs_pct',
#  'close_1day_w3_mean_abs_pct/close_1day_w20_mean_abs_pct',
#  'close_1day_w3_mean_abs_pct/close_1day_w100_mean_abs_pct',
#  'close_1day_w5_mean_abs_pct/close_1day_w20_mean_abs_pct',
#  'close_1day_w5_mean_abs_pct/close_1day_w100_mean_abs_pct',
#  'close_1day_w20_mean_abs_pct/close_1day_w100_mean_abs_pct',
#  'volume_1day_w3_mean_abs_pct/volume_1day_w5_mean_abs_pct',
#  'volume_1day_w3_mean_abs_pct/volume_1day_w20_mean_abs_pct',
#  'volume_1day_w3_mean_abs_pct/volume_1day_w100_mean_abs_pct',
#  'volume_1day_w5_mean_abs_pct/volume_1day_w20_mean_abs_pct',
#  'volume_1day_w5_mean_abs_pct/volume_1day_w100_mean_abs_pct',
#  'volume_1day_w20_mean_abs_pct/volume_1day_w100_mean_abs_pct',
#  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
#  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w20_mean_abs_pct',
#  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w100_mean_abs_pct',
#  'tmos_close_1day_w5_mean_abs_pct/tmos_close_1day_w20_mean_abs_pct',
#  'tmos_close_1day_w5_mean_abs_pct/tmos_close_1day_w100_mean_abs_pct',
#  'tmos_close_1day_w20_mean_abs_pct/tmos_close_1day_w100_mean_abs_pct',
#  'close_1day_w3_std/close_1day_w5_std',
#  'close_1day_w3_std/close_1day_w20_std',
#  'close_1day_w3_std/close_1day_w100_std',
#  'close_1day_w5_std/close_1day_w20_std',
#  'close_1day_w5_std/close_1day_w100_std',
#  'close_1day_w20_std/close_1day_w100_std',
#  'volume_1day_w3_std/volume_1day_w5_std',
#  'volume_1day_w3_std/volume_1day_w20_std',
#  'volume_1day_w3_std/volume_1day_w100_std',
#  'volume_1day_w5_std/volume_1day_w20_std',
#  'volume_1day_w5_std/volume_1day_w100_std',
#  'volume_1day_w20_std/volume_1day_w100_std',
#  'tmos_close_1day_w3_std/tmos_close_1day_w5_std',
#  'tmos_close_1day_w3_std/tmos_close_1day_w20_std',
#  'tmos_close_1day_w3_std/tmos_close_1day_w100_std',
#  'tmos_close_1day_w5_std/tmos_close_1day_w20_std',
#  'tmos_close_1day_w5_std/tmos_close_1day_w100_std',
#  'tmos_close_1day_w20_std/tmos_close_1day_w100_std',
#  'close_1day_w3_norm_std/close_1day_w5_norm_std',
#  'close_1day_w3_norm_std/close_1day_w20_norm_std',
#  'close_1day_w3_norm_std/close_1day_w100_norm_std',
#  'close_1day_w5_norm_std/close_1day_w20_norm_std',
#  'close_1day_w5_norm_std/close_1day_w100_norm_std',
#  'close_1day_w20_norm_std/close_1day_w100_norm_std',
#  'volume_1day_w3_norm_std/volume_1day_w5_norm_std',
#  'volume_1day_w3_norm_std/volume_1day_w20_norm_std',
#  'volume_1day_w3_norm_std/volume_1day_w100_norm_std',
#  'volume_1day_w5_norm_std/volume_1day_w20_norm_std',
#  'volume_1day_w5_norm_std/volume_1day_w100_norm_std',
#  'volume_1day_w20_norm_std/volume_1day_w100_norm_std',
#  'tmos_close_1day_w3_norm_std/tmos_close_1day_w5_norm_std',
#  'tmos_close_1day_w3_norm_std/tmos_close_1day_w20_norm_std',
#  'tmos_close_1day_w3_norm_std/tmos_close_1day_w100_norm_std',
#  'tmos_close_1day_w5_norm_std/tmos_close_1day_w20_norm_std',
#  'tmos_close_1day_w5_norm_std/tmos_close_1day_w100_norm_std',
#  'tmos_close_1day_w20_norm_std/tmos_close_1day_w100_norm_std',
#  'close_1day_w3_rsi/close_1day_w5_rsi',
#  'close_1day_w3_rsi/close_1day_w20_rsi',
#  'close_1day_w3_rsi/close_1day_w100_rsi',
#  'close_1day_w5_rsi/close_1day_w20_rsi',
#  'close_1day_w5_rsi/close_1day_w100_rsi',
#  'close_1day_w20_rsi/close_1day_w100_rsi',
#  'volume_1day_w3_rsi/volume_1day_w5_rsi',
#  'volume_1day_w3_rsi/volume_1day_w20_rsi',
#  'volume_1day_w3_rsi/volume_1day_w100_rsi',
#  'volume_1day_w5_rsi/volume_1day_w20_rsi',
#  'volume_1day_w5_rsi/volume_1day_w100_rsi',
#  'volume_1day_w20_rsi/volume_1day_w100_rsi',
#  'tmos_close_1day_w3_rsi/tmos_close_1day_w5_rsi',
#  'tmos_close_1day_w3_rsi/tmos_close_1day_w20_rsi',
#  'tmos_close_1day_w3_rsi/tmos_close_1day_w100_rsi',
#  'tmos_close_1day_w5_rsi/tmos_close_1day_w20_rsi',
#  'tmos_close_1day_w5_rsi/tmos_close_1day_w100_rsi',
#  'tmos_close_1day_w20_rsi/tmos_close_1day_w100_rsi',
#  'close_1day/close_1day_w3_ma',
#  'close_1day/close_1day_w5_ma',
#  'close_1day/close_1day_w20_ma',
#  'close_1day/close_1day_w100_ma',
#  'close_1day_w3_ma/close_1day_w5_ma',
#  'close_1day_w3_ma/close_1day_w20_ma',
#  'close_1day_w3_ma/close_1day_w100_ma',
#  'close_1day_w5_ma/close_1day_w20_ma',
#  'close_1day_w5_ma/close_1day_w100_ma',
#  'close_1day_w20_ma/close_1day_w100_ma',
#  'volume_1day/volume_1day_w3_ma',
#  'volume_1day/volume_1day_w5_ma',
#  'volume_1day/volume_1day_w20_ma',
#  'volume_1day/volume_1day_w100_ma',
#  'volume_1day_w3_ma/volume_1day_w5_ma',
#  'volume_1day_w3_ma/volume_1day_w20_ma',
#  'volume_1day_w3_ma/volume_1day_w100_ma',
#  'volume_1day_w5_ma/volume_1day_w20_ma',
#  'volume_1day_w5_ma/volume_1day_w100_ma',
#  'volume_1day_w20_ma/volume_1day_w100_ma',
#  'tmos_close_1day/tmos_close_1day_w3_ma',
#  'tmos_close_1day/tmos_close_1day_w5_ma',
#  'tmos_close_1day/tmos_close_1day_w20_ma',
#  'tmos_close_1day/tmos_close_1day_w100_ma',
#  'tmos_close_1day_w3_ma/tmos_close_1day_w5_ma',
#  'tmos_close_1day_w3_ma/tmos_close_1day_w20_ma',
#  'tmos_close_1day_w3_ma/tmos_close_1day_w100_ma',
#  'tmos_close_1day_w5_ma/tmos_close_1day_w20_ma',
#  'tmos_close_1day_w5_ma/tmos_close_1day_w100_ma',
#  'tmos_close_1day_w20_ma/tmos_close_1day_w100_ma',
#  'close_1day_w3_min/close_1day',
#  'close_1day_w5_min/close_1day',
#  'close_1day_w20_min/close_1day',
#  'close_1day_w100_min/close_1day',
#  'volume_1day_w3_min/volume_1day',
#  'volume_1day_w5_min/volume_1day',
#  'volume_1day_w20_min/volume_1day',
#  'volume_1day_w100_min/volume_1day',
#  'tmos_close_1day_w3_min/tmos_close_1day',
#  'tmos_close_1day_w5_min/tmos_close_1day',
#  'tmos_close_1day_w20_min/tmos_close_1day',
#  'tmos_close_1day_w100_min/tmos_close_1day',
#  'close_1day_w3_max/close_1day',
#  'close_1day_w5_max/close_1day',
#  'close_1day_w20_max/close_1day',
#  'close_1day_w100_max/close_1day',
#  'volume_1day_w3_max/volume_1day',
#  'volume_1day_w5_max/volume_1day',
#  'volume_1day_w20_max/volume_1day',
#  'volume_1day_w100_max/volume_1day',
#  'tmos_close_1day_w3_max/tmos_close_1day',
#  'tmos_close_1day_w5_max/tmos_close_1day',
#  'tmos_close_1day_w20_max/tmos_close_1day',
#  'tmos_close_1day_w100_max/tmos_close_1day',
#  'close_1day_w3_ma_low_2std/close_1day',
#  'close_1day_w3_ma_up_2std/close_1day',
#  'close_1day_w3_ma_low_3std/close_1day',
#  'close_1day_w3_ma_up_3std/close_1day',
#  'volume_1day_w3_ma_low_2std/volume_1day',
#  'volume_1day_w3_ma_up_2std/volume_1day',
#  'volume_1day_w3_ma_low_3std/volume_1day',
#  'volume_1day_w3_ma_up_3std/volume_1day',
#  'tmos_close_1day_w3_ma_low_2std/tmos_close_1day',
#  'tmos_close_1day_w3_ma_up_2std/tmos_close_1day',
#  'tmos_close_1day_w3_ma_low_3std/tmos_close_1day',
#  'tmos_close_1day_w3_ma_up_3std/tmos_close_1day',
#  'close_1day_w5_ma_low_2std/close_1day',
#  'close_1day_w5_ma_up_2std/close_1day',
#  'close_1day_w5_ma_low_3std/close_1day',
#  'close_1day_w5_ma_up_3std/close_1day',
#  'volume_1day_w5_ma_low_2std/volume_1day',
#  'volume_1day_w5_ma_up_2std/volume_1day',
#  'volume_1day_w5_ma_low_3std/volume_1day',
#  'volume_1day_w5_ma_up_3std/volume_1day',
#  'tmos_close_1day_w5_ma_low_2std/tmos_close_1day',
#  'tmos_close_1day_w5_ma_up_2std/tmos_close_1day',
#  'tmos_close_1day_w5_ma_low_3std/tmos_close_1day',
#  'tmos_close_1day_w5_ma_up_3std/tmos_close_1day',
#  'close_1day_w20_ma_low_2std/close_1day',
#  'close_1day_w20_ma_up_2std/close_1day',
#  'close_1day_w20_ma_low_3std/close_1day',
#  'close_1day_w20_ma_up_3std/close_1day',
#  'volume_1day_w20_ma_low_2std/volume_1day',
#  'volume_1day_w20_ma_up_2std/volume_1day',
#  'volume_1day_w20_ma_low_3std/volume_1day',
#  'volume_1day_w20_ma_up_3std/volume_1day',
#  'tmos_close_1day_w20_ma_low_2std/tmos_close_1day',
#  'tmos_close_1day_w20_ma_up_2std/tmos_close_1day',
#  'tmos_close_1day_w20_ma_low_3std/tmos_close_1day',
#  'tmos_close_1day_w20_ma_up_3std/tmos_close_1day',
#  'close_1day_w100_ma_low_2std/close_1day',
#  'close_1day_w100_ma_up_2std/close_1day',
#  'close_1day_w100_ma_low_3std/close_1day',
#  'close_1day_w100_ma_up_3std/close_1day',
#  'volume_1day_w100_ma_low_2std/volume_1day',
#  'volume_1day_w100_ma_up_2std/volume_1day',
#  'volume_1day_w100_ma_low_3std/volume_1day',
#  'volume_1day_w100_ma_up_3std/volume_1day',
#  'tmos_close_1day_w100_ma_low_2std/tmos_close_1day',
#  'tmos_close_1day_w100_ma_up_2std/tmos_close_1day',
#  'tmos_close_1day_w100_ma_low_3std/tmos_close_1day',
#  'tmos_close_1day_w100_ma_up_3std/tmos_close_1day',
#  'close_1day_w3_min/close_1day_w3_max',
#  'volume_1day_w3_min/volume_1day_w3_max',
#  'tmos_close_1day_w3_min/tmos_close_1day_w3_max',
#  'close_1day_w5_min/close_1day_w5_max',
#  'volume_1day_w5_min/volume_1day_w5_max',
#  'tmos_close_1day_w5_min/tmos_close_1day_w5_max',
#  'close_1day_w20_min/close_1day_w20_max',
#  'volume_1day_w20_min/volume_1day_w20_max',
#  'tmos_close_1day_w20_min/tmos_close_1day_w20_max',
#  'target',
#  'ticker_code']

# %%
drop_cols = ['time',
             #'ticker_code',
             #'hour', 'day', 'weekday', 

 'ticker',
 'index_1day',
 'result',
 'delta_time',
 'income_rate',
 'res_price',
 'res_ind', 'index', 'target', 
              'ind', 'close',
             'y_pred'] #+ [elem for elem in df.columns if 'roc' in elem]


features = df.columns[~df.columns.isin(drop_cols)].tolist()
#features = [elem for elem in df.columns if (('/' in elem) or ('lvl' in elem) or ('alpha' in elem))] +['hour', 'day', 'weekday'] + #['ticker_code']
                                                                                                    


cat_features_all = ['ticker_code',
                'hour', 'day', 'weekday',# 'month'
]
cat_features = cat_features_all

target = 'target'

# %%
len(features)
# Out:
# 601

# %% [markdown]
# ### Get stability features

# %%
params = {
    "boosting_type": "gbdt",
    "objective": "binary",
    
    "num_leaves": 2,

     "bagging_fraction": 0.5,
     "bagging_freq": 1,
     "verbose": 0,
    "metric": "auc",
    "early_stopping" : 20, 
}

auc_features = {'feature' : [],
               'auc_train' : [],
               'auc_valid' : [],
               'auc_test' : [],
               'auc_test2' : []
               }

for feature in tqdm(features):
    stab_features = [feature]
    stab_cat_features = [feature] if feature in cat_features else []
    
    D_train = lgbm.Dataset(df.loc[mask_train, stab_features], label=df.loc[mask_train, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
    D_valid = lgbm.Dataset(df.loc[mask_valid, stab_features], label=df.loc[mask_valid, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
    D_test = lgbm.Dataset(df.loc[mask_test, stab_features], label=df.loc[mask_test, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
    D_test2 = lgbm.Dataset(df.loc[mask_test2, stab_features], label=df.loc[mask_test2, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
        
    model = lgbm.train(params, num_boost_round=1_000, train_set=D_train, valid_sets=[D_valid])
    
    y_pred_train = model.predict(D_train.data)
    y_pred_valid = model.predict(D_valid.data)
    y_pred_test = model.predict(D_test.data)
    y_pred_test2 = model.predict(D_test2.data)

    auc_features['feature'] += [feature]
    auc_features['auc_train'] += [roc_auc_score(D_train.label, y_pred_train)]
    auc_features['auc_valid'] += [roc_auc_score(D_valid.label, y_pred_valid)]
    auc_features['auc_test'] += [roc_auc_score(D_test.label, y_pred_test)]
    auc_features['auc_test2'] += [roc_auc_score(D_test2.label, y_pred_test2)]

auc_features_cp = auc_features.copy()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 601/601 [03:39<00:00,  2.74it/s]

# %%
df_auc_features = pd.DataFrame(auc_features)
df_auc_features
# Out:
#                                              feature  auc_train  auc_valid  \
# 0                                       close_w1_roc   0.586264   0.582300
# 1                                      volume_w1_roc   0.521086   0.514619
# 2                                  tmos_close_w1_roc   0.560174   0.579407
# 3                                  close_w5_norm_std   0.613861   0.625097
# 4                              close_w5_mean_abs_pct   0.627370   0.638225
# ..                                               ...        ...        ...
# 596    tmos_close_1day_w5_min/tmos_close_1day_w5_max   0.589461   0.569867
# 597            close_1day_w20_min/close_1day_w20_max   0.640587   0.655043
# 598          volume_1day_w20_min/volume_1day_w20_max   0.618923   0.571702
# 599  tmos_close_1day_w20_min/tmos_close_1day_w20_max   0.578552   0.566071
# 600                                      ticker_code   0.676369   0.618335
#
#      auc_test  auc_test2
# 0    0.548985   0.567681
# 1    0.510316   0.500528
# 2    0.535689   0.553500
# 3    0.575112   0.603849
# 4    0.591427   0.620384
# ..        ...        ...
# 596  0.585637   0.576685
# 597  0.651733   0.624860
# 598  0.554816   0.528048
# 599  0.565083   0.468651
# 600  0.586549   0.543890
#
# [601 rows x 5 columns]

# %% [markdown]
# #### auc <=0.525

# %%
auc_treshold = 0.51

# %%
mask_auc_train  = df_auc_features['auc_train'] <= auc_treshold 
mask_auc_train.sum()
# Out:
# 36

# %%
mask_auc_valid  = df_auc_features['auc_valid'] <= auc_treshold 
mask_auc_valid.sum()
# Out:
# 150

# %%
mask_auc_test  = df_auc_features['auc_test'] <= auc_treshold 
mask_auc_test.sum()
# Out:
# 185

# %%
(mask_auc_train | mask_auc_valid | mask_auc_test).sum()
# Out:
# 246

# %%
mask_auc_test2  = df_auc_features['auc_test2'] <= auc_treshold 
mask_auc_test2.sum()
# Out:
# 239

# %%
(mask_auc_train | mask_auc_valid | mask_auc_test | mask_auc_test2).sum()
# Out:
# 323

# %% [markdown]
# #### delta_auc > 0.05

# %%
auc_delta_treshold  = 0.03

# %%
mask_auc_delta_valid = (df_auc_features['auc_train'] - df_auc_features['auc_valid']).abs() > auc_delta_treshold
mask_auc_delta_valid.sum()
# Out:
# 190

# %%
mask_auc_delta_test = (df_auc_features['auc_train'] - df_auc_features['auc_test']).abs() > auc_delta_treshold
mask_auc_delta_test.sum()
# Out:
# 218

# %%
(mask_auc_delta_valid | mask_auc_delta_test).sum()
# Out:
# 301

# %%
mask_auc_delta_test2 = (df_auc_features['auc_train'] - df_auc_features['auc_test2']).abs() > auc_delta_treshold
mask_auc_delta_test2.sum()
# Out:
# 247

# %%
(mask_auc_delta_valid | mask_auc_delta_test | mask_auc_delta_test2).sum()
# Out:
# 375

# %% [markdown]
# #### union criterias

# %%
mask_criterias1 = mask_auc_train | mask_auc_valid | mask_auc_test | mask_auc_delta_valid | mask_auc_delta_test
mask_criterias1.sum()
# Out:
# 415

# %%
mask_criterias2 = mask_auc_train | mask_auc_valid | mask_auc_test | mask_auc_test2 | mask_auc_delta_valid | mask_auc_delta_test | mask_auc_delta_test2
mask_criterias2.sum()
# Out:
# 493

# %%
features_criteria1 = df_auc_features['feature'].values[~mask_criterias1]
len(features_criteria1), features_criteria1
# Out:
# (186,
#  array(['volume_w1_roc', 'tmos_close_w1_roc', 'volume_w5_norm_std',
#         'tmos_close_w5_norm_std', 'tmos_close_w5_rsi', 'tmos_close_w5_roc',
#         'close_w14_norm_std', 'close_w14_mean_abs_pct',
#         'volume_w14_norm_std', 'volume_w14_mean_abs_pct', 'volume_w14_roc',
#         'tmos_close_w14_norm_std', 'tmos_close_w14_alpha',
#         'close_w70_norm_std', 'close_w70_roc', 'close_w70_lvl_1.005-1.01',
#         'close_w70_lvl_1.01-1.02', 'close_w70_lvl_-0.98-0.99',
#         'close_w70_lvl_1.02-1.03',
#         'close_w70_lvl_-0.9299999999999999-0.95',
#         'volume_w70_mean_abs_pct', 'volume_w70_roc',
#         'tmos_close_w70_lvl_1-1.005', 'tmos_close_w70_lvl_1.005-1.01',
#         'tmos_close_w70_lvl_1.01-1.015', 'tmos_close_w70_lvl_1.02-1.03',
#         'close_w1_roc/close_w5_alpha', 'close_w1_roc/close_w14_alpha',
#         'close_w1_roc/close_w70_alpha', 'volume_w1_roc/volume_w5_alpha',
#         'volume_w1_roc/volume_w70_alpha',
#         'tmos_close_w1_roc/tmos_close_w5_alpha',
#         'tmos_close_w1_roc/tmos_close_w14_alpha',
#         'close_w14_roc/close_w70_roc', 'volume_w1_roc/volume_w70_roc',
#         'volume_w5_roc/volume_w14_roc', 'volume_w5_roc/volume_w70_roc',
#         'tmos_close_w1_roc/tmos_close_w5_roc',
#         'tmos_close_w14_roc/tmos_close_w70_roc',
#         'close_w5_mean_abs_pct/close_w70_mean_abs_pct',
#         'close_w14_mean_abs_pct/close_w70_mean_abs_pct',
#         'volume_w14_mean_abs_pct/volume_w70_mean_abs_pct',
#         'volume_w5_std/volume_w70_std',
#         'tmos_close_w5_std/tmos_close_w14_std',
#         'tmos_close_w5_norm_std/tmos_close_w14_norm_std',
#         'tmos_close_w5_rsi/tmos_close_w14_rsi', 'close/close_w70_ma',
#         'close_w5_ma/close_w70_ma', 'close_w14_ma/close_w70_ma',
#         'volume/volume_w70_ma', 'volume_w5_ma/volume_w14_ma',
#         'volume_w5_ma/volume_w70_ma', 'tmos_close/tmos_close_w5_ma',
#         'tmos_close/tmos_close_w14_ma', 'tmos_close/tmos_close_w70_ma',
#         'tmos_close_w5_ma/tmos_close_w14_ma',
#         'tmos_close_w14_ma/tmos_close_w70_ma', 'volume_w5_min/volume',
#         'volume_w14_min/volume', 'close_w5_max/close',
#         'close_w14_max/close', 'volume_w5_max/volume',
#         'volume_w70_max/volume', 'tmos_close_w14_max/tmos_close',
#         'close_w5_ma_up_2std/close', 'volume_w5_ma_low_2std/volume',
#         'volume_w5_ma_up_2std/volume', 'volume_w5_ma_low_3std/volume',
#         'volume_w5_ma_up_3std/volume',
#         'tmos_close_w5_ma_low_2std/tmos_close',
#         'tmos_close_w5_ma_up_2std/tmos_close',
#         'tmos_close_w5_ma_low_3std/tmos_close',
#         'tmos_close_w5_ma_up_3std/tmos_close',
#         'close_w14_ma_low_3std/close', 'volume_w14_ma_low_2std/volume',
#         'tmos_close_w14_ma_low_3std/tmos_close',
#         'tmos_close_w14_ma_up_3std/tmos_close',
#         'volume_w70_ma_low_2std/volume', 'volume_w70_ma_up_2std/volume',
#         'volume_w70_ma_low_3std/volume', 'volume_w70_ma_up_3std/volume',
#         'volume_w5_min/volume_w5_max',
#         'tmos_close_w5_min/tmos_close_w5_max',
#         'close_w14_min/close_w14_max', 'volume_w14_min/volume_w14_max',
#         'tmos_close_w14_min/tmos_close_w14_max',
#         'close_w70_min/close_w70_max', 'volume_w70_min/volume_w70_max',
#         'close_1day_w1_roc', 'close_1day_w3_norm_std', 'close_1day_w3_roc',
#         'tmos_close_1day_w3_norm_std', 'tmos_close_1day_w3_alpha',
#         'tmos_close_1day_w3_roc', 'close_1day_w5_norm_std',
#         'close_1day_w5_roc', 'volume_1day_w5_roc',
#         'tmos_close_1day_w5_norm_std', 'tmos_close_1day_w5_mean_abs_pct',
#         'close_1day_w20_norm_std', 'close_1day_w20_roc',
#         'close_1day_w20_lvl_1-1.005', 'close_1day_w20_lvl_-0.995-1',
#         'close_1day_w20_lvl_1.005-1.01', 'close_1day_w20_lvl_1.02-1.03',
#         'close_1day_w20_lvl_1.03-1.04', 'close_1day_w20_lvl_1.04-1.05',
#         'close_1day_w20_lvl_1.05-1.07', 'volume_1day_w20_alpha',
#         'volume_1day_w20_rsi', 'tmos_close_1day_w20_norm_std',
#         'tmos_close_1day_w20_rsi', 'close_1day_w100_norm_std',
#         'close_1day_w100_mean_abs_pct', 'close_1day_w100_roc',
#         'close_1day_w100_lvl_1-1.005', 'close_1day_w100_lvl_-0.995-1',
#         'close_1day_w100_lvl_1.005-1.01',
#         'close_1day_w100_lvl_-0.99-0.995', 'close_1day_w100_lvl_1.01-1.02',
#         'close_1day_w100_lvl_1.02-1.03', 'close_1day_w100_lvl_-0.97-0.98',
#         'close_1day_w100_lvl_-0.96-0.97', 'close_1day_w100_lvl_-0.95-0.96',
#         'close_1day_w100_lvl_-0.9299999999999999-0.95',
#         'tmos_close_1day_w100_rsi', 'tmos_close_1day_w100_lvl_-0.98-0.985',
#         'close_1day_w1_roc/close_1day_w5_alpha',
#         'close_1day_w1_roc/close_1day_w20_alpha',
#         'close_1day_w3_alpha/close_1day_w5_alpha',
#         'close_1day_w3_alpha/close_1day_w20_alpha',
#         'close_1day_w5_alpha/close_1day_w20_alpha',
#         'close_1day_w5_alpha/close_1day_w100_alpha',
#         'volume_1day_w1_roc/volume_1day_w3_alpha',
#         'volume_1day_w1_roc/volume_1day_w5_alpha',
#         'volume_1day_w1_roc/volume_1day_w20_alpha',
#         'volume_1day_w20_alpha/volume_1day_w100_alpha',
#         'tmos_close_1day_w1_roc/tmos_close_1day_w3_alpha',
#         'close_1day_w1_roc/close_1day_w3_roc',
#         'close_1day_w1_roc/close_1day_w5_roc',
#         'close_1day_w1_roc/close_1day_w20_roc',
#         'close_1day_w3_roc/close_1day_w5_roc',
#         'close_1day_w3_roc/close_1day_w20_roc',
#         'close_1day_w5_roc/close_1day_w20_roc',
#         'close_1day_w5_roc/close_1day_w100_roc',
#         'tmos_close_1day_w1_roc/tmos_close_1day_w5_roc',
#         'close_1day_w5_mean_abs_pct/close_1day_w20_mean_abs_pct',
#         'volume_1day_w3_mean_abs_pct/volume_1day_w20_mean_abs_pct',
#         'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w20_mean_abs_pct',
#         'close_1day_w3_std/close_1day_w100_std',
#         'close_1day_w5_std/close_1day_w100_std',
#         'close_1day_w20_std/close_1day_w100_std',
#         'tmos_close_1day_w3_std/tmos_close_1day_w100_std',
#         'tmos_close_1day_w5_std/tmos_close_1day_w20_std',
#         'tmos_close_1day_w5_std/tmos_close_1day_w100_std',
#         'close_1day_w5_norm_std/close_1day_w100_norm_std',
#         'close_1day_w20_norm_std/close_1day_w100_norm_std',
#         'volume_1day_w3_norm_std/volume_1day_w100_norm_std',
#         'volume_1day_w5_norm_std/volume_1day_w20_norm_std',
#         'tmos_close_1day_w3_norm_std/tmos_close_1day_w100_norm_std',
#         'tmos_close_1day_w5_norm_std/tmos_close_1day_w20_norm_std',
#         'volume_1day_w20_rsi/volume_1day_w100_rsi',
#         'close_1day/close_1day_w3_ma', 'close_1day/close_1day_w5_ma',
#         'close_1day/close_1day_w100_ma',
#         'close_1day_w3_ma/close_1day_w5_ma',
#         'close_1day_w3_ma/close_1day_w100_ma',
#         'close_1day_w5_ma/close_1day_w100_ma',
#         'close_1day_w20_ma/close_1day_w100_ma',
#         'volume_1day/volume_1day_w100_ma', 'close_1day_w5_min/close_1day',
#         'volume_1day_w3_min/volume_1day', 'volume_1day_w5_min/volume_1day',
#         'volume_1day_w20_min/volume_1day',
#         'close_1day_w3_ma_low_2std/close_1day',
#         'close_1day_w3_ma_low_3std/close_1day',
#         'tmos_close_1day_w3_ma_low_3std/tmos_close_1day',
#         'close_1day_w5_ma_low_3std/close_1day',
#         'tmos_close_1day_w5_ma_up_2std/tmos_close_1day',
#         'tmos_close_1day_w5_ma_up_3std/tmos_close_1day',
#         'close_1day_w3_min/close_1day_w3_max',
#         'tmos_close_1day_w3_min/tmos_close_1day_w3_max',
#         'close_1day_w5_min/close_1day_w5_max',
#         'tmos_close_1day_w5_min/tmos_close_1day_w5_max',
#         'close_1day_w20_min/close_1day_w20_max',
#         'tmos_close_1day_w20_min/tmos_close_1day_w20_max'], dtype=object))

# %%
df_auc_features.loc[df_auc_features['feature'].isin(features_criteria1)].sort_values('auc_valid', ascending=False)
# Out:
#                                    feature  auc_train  auc_valid  auc_test  \
# 231            close_w70_min/close_w70_max   0.652385   0.673664  0.638020
# 19                  close_w14_mean_abs_pct   0.649618   0.660875  0.635691
# 597  close_1day_w20_min/close_1day_w20_max   0.640587   0.655043  0.651733
# 33                      close_w70_norm_std   0.639077   0.654086  0.630947
# 267                close_1day_w20_norm_std   0.637814   0.652787  0.643576
# ..                                     ...        ...        ...       ...
# 388    close_1day_w1_roc/close_1day_w5_roc   0.513155   0.511820  0.516609
# 195           volume_w5_ma_low_3std/volume   0.515626   0.511261  0.519382
# 161                   volume/volume_w70_ma   0.520880   0.510975  0.525896
# 196            volume_w5_ma_up_3std/volume   0.514970   0.510433  0.515738
# 205          volume_w14_ma_low_2std/volume   0.516125   0.510071  0.532913
#
#      auc_test2
# 231   0.607973
# 19    0.657418
# 597   0.624860
# 33    0.608198
# 267   0.611318
# ..         ...
# 388   0.497312
# 195   0.503679
# 161   0.498457
# 196   0.504567
# 205   0.507421
#
# [186 rows x 5 columns]

# %%
features_criteria2 = df_auc_features['feature'].values[~mask_criterias2]
len(features_criteria2), features_criteria2
# Out:
# (108,
#  array(['tmos_close_w1_roc', 'tmos_close_w5_norm_std', 'tmos_close_w5_rsi',
#         'tmos_close_w5_roc', 'close_w14_norm_std',
#         'close_w14_mean_abs_pct', 'volume_w14_norm_std',
#         'volume_w14_mean_abs_pct', 'volume_w14_roc',
#         'tmos_close_w14_norm_std', 'close_w70_lvl_1.005-1.01',
#         'close_w70_lvl_1.01-1.02', 'close_w70_lvl_-0.98-0.99',
#         'close_w70_lvl_1.02-1.03', 'volume_w70_mean_abs_pct',
#         'volume_w70_roc', 'tmos_close_w70_lvl_1-1.005',
#         'tmos_close_w70_lvl_1.005-1.01', 'tmos_close_w70_lvl_1.01-1.015',
#         'close_w1_roc/close_w5_alpha', 'close_w1_roc/close_w14_alpha',
#         'close_w1_roc/close_w70_alpha',
#         'tmos_close_w1_roc/tmos_close_w5_alpha',
#         'volume_w1_roc/volume_w70_roc', 'volume_w5_roc/volume_w14_roc',
#         'tmos_close_w1_roc/tmos_close_w5_roc',
#         'close_w5_mean_abs_pct/close_w70_mean_abs_pct',
#         'close_w14_mean_abs_pct/close_w70_mean_abs_pct',
#         'volume_w14_mean_abs_pct/volume_w70_mean_abs_pct',
#         'tmos_close_w5_std/tmos_close_w14_std',
#         'tmos_close_w5_norm_std/tmos_close_w14_norm_std',
#         'close/close_w70_ma', 'close_w5_ma/close_w70_ma',
#         'close_w14_ma/close_w70_ma', 'tmos_close/tmos_close_w5_ma',
#         'tmos_close/tmos_close_w70_ma',
#         'tmos_close_w5_ma/tmos_close_w14_ma',
#         'tmos_close_w14_ma/tmos_close_w70_ma', 'volume_w14_min/volume',
#         'close_w5_max/close', 'close_w14_max/close',
#         'tmos_close_w14_max/tmos_close', 'close_w5_ma_up_2std/close',
#         'tmos_close_w5_ma_low_2std/tmos_close',
#         'tmos_close_w5_ma_up_2std/tmos_close',
#         'tmos_close_w5_ma_low_3std/tmos_close',
#         'tmos_close_w5_ma_up_3std/tmos_close',
#         'close_w14_ma_low_3std/close',
#         'tmos_close_w14_ma_up_3std/tmos_close',
#         'tmos_close_w5_min/tmos_close_w5_max',
#         'close_w14_min/close_w14_max', 'volume_w14_min/volume_w14_max',
#         'volume_w70_min/volume_w70_max', 'close_1day_w1_roc',
#         'close_1day_w3_roc', 'tmos_close_1day_w3_alpha',
#         'tmos_close_1day_w3_roc', 'close_1day_w5_norm_std',
#         'close_1day_w5_roc', 'volume_1day_w5_roc',
#         'tmos_close_1day_w5_norm_std', 'close_1day_w20_norm_std',
#         'close_1day_w20_roc', 'close_1day_w20_lvl_1-1.005',
#         'close_1day_w20_lvl_-0.995-1', 'close_1day_w20_lvl_1.005-1.01',
#         'close_1day_w20_lvl_1.02-1.03', 'close_1day_w20_lvl_1.03-1.04',
#         'volume_1day_w20_rsi', 'tmos_close_1day_w20_rsi',
#         'close_1day_w100_lvl_1-1.005', 'close_1day_w100_lvl_-0.995-1',
#         'close_1day_w100_lvl_1.005-1.01',
#         'close_1day_w100_lvl_-0.99-0.995', 'close_1day_w100_lvl_1.01-1.02',
#         'close_1day_w100_lvl_1.02-1.03', 'close_1day_w100_lvl_-0.97-0.98',
#         'close_1day_w100_lvl_-0.96-0.97', 'close_1day_w100_lvl_-0.95-0.96',
#         'close_1day_w100_lvl_-0.9299999999999999-0.95',
#         'close_1day_w1_roc/close_1day_w5_alpha',
#         'close_1day_w3_alpha/close_1day_w5_alpha',
#         'close_1day_w5_alpha/close_1day_w100_alpha',
#         'close_1day_w1_roc/close_1day_w3_roc',
#         'close_1day_w3_roc/close_1day_w20_roc',
#         'close_1day_w5_roc/close_1day_w20_roc',
#         'close_1day_w5_roc/close_1day_w100_roc',
#         'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w20_mean_abs_pct',
#         'close_1day_w3_std/close_1day_w100_std',
#         'tmos_close_1day_w5_std/tmos_close_1day_w100_std',
#         'close_1day_w5_norm_std/close_1day_w100_norm_std',
#         'close_1day_w20_norm_std/close_1day_w100_norm_std',
#         'volume_1day_w5_norm_std/volume_1day_w20_norm_std',
#         'volume_1day_w20_rsi/volume_1day_w100_rsi',
#         'close_1day/close_1day_w5_ma', 'close_1day/close_1day_w100_ma',
#         'close_1day_w3_ma/close_1day_w5_ma',
#         'close_1day_w3_ma/close_1day_w100_ma',
#         'close_1day_w5_ma/close_1day_w100_ma',
#         'close_1day_w5_min/close_1day', 'volume_1day_w5_min/volume_1day',
#         'volume_1day_w20_min/volume_1day',
#         'close_1day_w5_ma_low_3std/close_1day',
#         'tmos_close_1day_w5_ma_up_3std/tmos_close_1day',
#         'tmos_close_1day_w3_min/tmos_close_1day_w3_max',
#         'close_1day_w5_min/close_1day_w5_max',
#         'tmos_close_1day_w5_min/tmos_close_1day_w5_max',
#         'close_1day_w20_min/close_1day_w20_max'], dtype=object))

# %%
df_auc_features.loc[df_auc_features['feature'].isin(features_criteria2)].sort_values('auc_valid', ascending=False)
# Out:
#                                                feature  auc_train  auc_valid  \
# 19                              close_w14_mean_abs_pct   0.649618   0.660875
# 597              close_1day_w20_min/close_1day_w20_max   0.640587   0.655043
# 267                            close_1day_w20_norm_std   0.637814   0.652787
# 492                      close_1day/close_1day_w100_ma   0.620976   0.648658
# 228                        close_w14_min/close_w14_max   0.627486   0.644950
# 18                                  close_w14_norm_std   0.623074   0.642326
# 495                close_1day_w3_ma/close_1day_w100_ma   0.619979   0.638052
# 497                close_1day_w5_ma/close_1day_w100_ma   0.613435   0.634187
# 271                                 close_1day_w20_roc   0.608946   0.631626
# 319                      close_1day_w100_lvl_1.01-1.02   0.595585   0.624420
# 594                close_1day_w5_min/close_1day_w5_max   0.599889   0.622851
# 252                             close_1day_w5_norm_std   0.599146   0.620249
# 321                      close_1day_w100_lvl_1.02-1.03   0.593391   0.610809
# 155                                 close/close_w70_ma   0.609167   0.606489
# 157                           close_w5_ma/close_w70_ma   0.610157   0.605747
# 190                          close_w5_ma_up_2std/close   0.585034   0.604921
# 158                          close_w14_ma/close_w70_ma   0.603803   0.600945
# 317                     close_1day_w100_lvl_1.005-1.01   0.588370   0.599929
# 181                                close_w14_max/close   0.573330   0.599699
# 315                        close_1day_w100_lvl_1-1.005   0.589801   0.598196
# 203                        close_w14_ma_low_3std/close   0.613498   0.595112
# 316                       close_1day_w100_lvl_-0.995-1   0.582075   0.592092
# 322                     close_1day_w100_lvl_-0.97-0.98   0.564782   0.591797
# 241                                  close_1day_w3_roc   0.577691   0.591210
# 167                       tmos_close/tmos_close_w70_ma   0.585226   0.588962
# 566      tmos_close_1day_w5_ma_up_3std/tmos_close_1day   0.577960   0.587487
# 557               close_1day_w5_ma_low_3std/close_1day   0.600540   0.587039
# 180                                 close_w5_max/close   0.577492   0.586159
# 318                    close_1day_w100_lvl_-0.99-0.995   0.571500   0.585388
# 256                                  close_1day_w5_roc   0.588104   0.581700
# 2                                    tmos_close_w1_roc   0.560174   0.579407
# 525                    volume_1day_w20_min/volume_1day   0.560494   0.577918
# 262                        tmos_close_1day_w5_norm_std   0.589365   0.576575
# 42                             close_w70_lvl_1.01-1.02   0.565872   0.575955
# 272                         close_1day_w20_lvl_1-1.005   0.560838   0.575841
# 490                        close_1day/close_1day_w5_ma   0.570220   0.575605
# 44                             close_w70_lvl_1.02-1.03   0.552411   0.574088
# 234                                  close_1day_w1_roc   0.560755   0.573782
# 227                tmos_close_w5_min/tmos_close_w5_max   0.551217   0.573302
# 13                              tmos_close_w5_norm_std   0.548673   0.571574
# 273                        close_1day_w20_lvl_-0.995-1   0.550085   0.570941
# 593      tmos_close_1day_w3_min/tmos_close_1day_w3_max   0.549865   0.570910
# 199               tmos_close_w5_ma_low_3std/tmos_close   0.554695   0.569930
# 596      tmos_close_1day_w5_min/tmos_close_1day_w5_max   0.589461   0.569867
# 40                            close_w70_lvl_1.005-1.01   0.565197   0.569498
# 28                             tmos_close_w14_norm_std   0.580527   0.569302
# 274                      close_1day_w20_lvl_1.005-1.01   0.554538   0.569224
# 66                       tmos_close_w70_lvl_1.01-1.015   0.539691   0.566242
# 212               tmos_close_w14_ma_up_3std/tmos_close   0.547729   0.564151
# 93               tmos_close_w1_roc/tmos_close_w5_alpha   0.536699   0.564073
# 278                       close_1day_w20_lvl_1.02-1.03   0.557315   0.563093
# 493                  close_1day_w3_ma/close_1day_w5_ma   0.574990   0.562491
# 170                tmos_close_w14_ma/tmos_close_w70_ma   0.589259   0.562167
# 280                       close_1day_w20_lvl_1.03-1.04   0.539339   0.561798
# 324                     close_1day_w100_lvl_-0.96-0.97   0.558381   0.558725
# 187                      tmos_close_w14_max/tmos_close   0.551604   0.558458
# 197               tmos_close_w5_ma_low_2std/tmos_close   0.550154   0.558146
# 17                                   tmos_close_w5_roc   0.565997   0.556502
# 200                tmos_close_w5_ma_up_3std/tmos_close   0.535466   0.555822
# 451    tmos_close_1day_w5_std/tmos_close_1day_w100_std   0.549005   0.555270
# 168                 tmos_close_w5_ma/tmos_close_w14_ma   0.527470   0.549276
# 229                      volume_w14_min/volume_w14_max   0.528050   0.548733
# 165                        tmos_close/tmos_close_w5_ma   0.541402   0.547352
# 394               close_1day_w5_roc/close_1day_w20_roc   0.525296   0.547085
# 24                             volume_w14_mean_abs_pct   0.516993   0.545817
# 458   close_1day_w20_norm_std/close_1day_w100_norm_std   0.539865   0.544684
# 198                tmos_close_w5_ma_up_2std/tmos_close   0.527189   0.543011
# 326                     close_1day_w100_lvl_-0.95-0.96   0.548807   0.542494
# 53                             volume_w70_mean_abs_pct   0.541610   0.541307
# 23                                 volume_w14_norm_std   0.536031   0.541266
# 251                             tmos_close_1day_w3_roc   0.541981   0.540644
# 294                            tmos_close_1day_w20_rsi   0.517697   0.538879
# 56                                      volume_w70_roc   0.538604   0.538199
# 395              close_1day_w5_roc/close_1day_w100_roc   0.515202   0.537264
# 82                        close_w1_roc/close_w14_alpha   0.531364   0.536131
# 457    close_1day_w5_norm_std/close_1day_w100_norm_std   0.519410   0.535770
# 62                          tmos_close_w70_lvl_1-1.005   0.559010   0.535063
# 524                     volume_1day_w5_min/volume_1day   0.539487   0.534913
# 83                        close_w1_roc/close_w70_alpha   0.534507   0.534835
# 365          close_1day_w5_alpha/close_1day_w100_alpha   0.523398   0.533101
# 27                                      volume_w14_roc   0.543013   0.532019
# 81                         close_w1_roc/close_w5_alpha   0.532859   0.531518
# 430  tmos_close_1day_w3_mean_abs_pct/tmos_close_1da...   0.526688   0.529378
# 175                              volume_w14_min/volume   0.519170   0.529371
# 437              close_1day_w3_std/close_1day_w100_std   0.512094   0.529358
# 118       close_w5_mean_abs_pct/close_w70_mean_abs_pct   0.519674   0.528934
# 520                       close_1day_w5_min/close_1day   0.546151   0.528921
# 358              close_1day_w1_roc/close_1day_w5_alpha   0.517705   0.527922
# 64                       tmos_close_w70_lvl_1.005-1.01   0.544383   0.527380
# 328       close_1day_w100_lvl_-0.9299999999999999-0.95   0.543432   0.526409
# 249                           tmos_close_1day_w3_alpha   0.527478   0.525816
# 43                            close_w70_lvl_-0.98-0.99   0.549366   0.525807
# 392               close_1day_w3_roc/close_1day_w20_roc   0.518561   0.524077
# 387                close_1day_w1_roc/close_1day_w3_roc   0.516486   0.523931
# 261                                 volume_1day_w5_roc   0.541869   0.523050
# 16                                   tmos_close_w5_rsi   0.521518   0.522766
# 111                tmos_close_w1_roc/tmos_close_w5_roc   0.522552   0.522256
# 232                      volume_w70_min/volume_w70_max   0.534904   0.522111
# 122    volume_w14_mean_abs_pct/volume_w70_mean_abs_pct   0.514701   0.521935
# 482           volume_1day_w20_rsi/volume_1day_w100_rsi   0.517541   0.520702
# 108                       volume_w5_roc/volume_w14_roc   0.534087   0.520665
# 361            close_1day_w3_alpha/close_1day_w5_alpha   0.514424   0.518329
# 107                       volume_w1_roc/volume_w70_roc   0.513660   0.517871
# 289                                volume_1day_w20_rsi   0.521293   0.517529
# 462   volume_1day_w5_norm_std/volume_1day_w20_norm_std   0.532549   0.517527
# 141     tmos_close_w5_norm_std/tmos_close_w14_norm_std   0.515148   0.516044
# 132               tmos_close_w5_std/tmos_close_w14_std   0.515429   0.515350
# 119      close_w14_mean_abs_pct/close_w70_mean_abs_pct   0.518927   0.512879
#
#      auc_test  auc_test2
# 19   0.635691   0.657418
# 597  0.651733   0.624860
# 267  0.643576   0.611318
# 492  0.627060   0.609867
# 228  0.605292   0.634436
# 18   0.598200   0.627482
# 495  0.611349   0.610366
# 497  0.610457   0.604054
# 271  0.604792   0.603094
# 319  0.586116   0.616915
# 594  0.619638   0.601714
# 252  0.619977   0.606639
# 321  0.591989   0.607795
# 155  0.597120   0.614121
# 157  0.599887   0.611840
# 190  0.556499   0.571797
# 158  0.603329   0.607834
# 317  0.579530   0.598433
# 181  0.556624   0.545201
# 315  0.571640   0.604712
# 203  0.588838   0.633926
# 316  0.569956   0.601042
# 322  0.558029   0.588036
# 241  0.603291   0.590983
# 167  0.558584   0.559862
# 566  0.585821   0.558382
# 557  0.588094   0.613928
# 180  0.548230   0.561625
# 318  0.570038   0.589465
# 256  0.577379   0.573930
# 2    0.535689   0.553500
# 525  0.547235   0.549618
# 262  0.587065   0.579306
# 42   0.577735   0.588349
# 272  0.544757   0.572609
# 490  0.580061   0.591879
# 44   0.560267   0.556257
# 234  0.561448   0.583424
# 227  0.532700   0.556991
# 13   0.528379   0.577238
# 273  0.544500   0.568611
# 593  0.533265   0.546590
# 199  0.553488   0.580108
# 596  0.585637   0.576685
# 40   0.555957   0.584085
# 28   0.575066   0.604500
# 274  0.556823   0.560496
# 66   0.535132   0.550272
# 212  0.533318   0.538723
# 93   0.526184   0.558807
# 278  0.554888   0.572170
# 493  0.580649   0.565308
# 170  0.562263   0.580285
# 280  0.535394   0.542455
# 324  0.563997   0.584136
# 187  0.552634   0.531906
# 197  0.545691   0.575895
# 17   0.547787   0.549567
# 200  0.514406   0.553115
# 451  0.534757   0.542386
# 168  0.523033   0.556963
# 229  0.534237   0.538305
# 165  0.524549   0.560788
# 394  0.522929   0.551700
# 24   0.538997   0.529483
# 458  0.547563   0.533386
# 198  0.513070   0.536426
# 326  0.543600   0.574342
# 53   0.537485   0.557607
# 23   0.540664   0.524548
# 251  0.535597   0.565395
# 294  0.533674   0.516711
# 56   0.527296   0.525519
# 395  0.534995   0.518887
# 82   0.515359   0.520839
# 457  0.534256   0.523082
# 62   0.535767   0.563390
# 524  0.521668   0.528326
# 83   0.511967   0.512366
# 365  0.520441   0.541994
# 27   0.521416   0.538135
# 81   0.511520   0.516541
# 430  0.542211   0.551530
# 175  0.523972   0.518837
# 437  0.516603   0.514482
# 118  0.514947   0.510520
# 520  0.517725   0.524800
# 358  0.511708   0.515843
# 64   0.519372   0.526457
# 328  0.542859   0.555547
# 249  0.519732   0.544487
# 43   0.527079   0.522893
# 392  0.519534   0.523929
# 387  0.533593   0.511373
# 261  0.524311   0.513468
# 16   0.533016   0.532353
# 111  0.514276   0.521148
# 232  0.538490   0.542000
# 122  0.511026   0.535964
# 482  0.519249   0.529126
# 108  0.510910   0.519014
# 361  0.531074   0.533244
# 107  0.513869   0.518699
# 289  0.519603   0.537635
# 462  0.518075   0.536684
# 141  0.521038   0.517511
# 132  0.520451   0.517462
# 119  0.512647   0.511818

# %%
features = features_criteria2.tolist()
cat_features = [feature for feature in features if feature in cat_features_all]

# %%
len(features), len(cat_features)
# Out:
# (108, 0)

# %%
'ticker_code' in features
# Out:
# False

# %%
D_train = lgbm.Dataset(df.loc[mask_train, features], label=df.loc[mask_train, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, features], label=df.loc[mask_valid, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, features], label=df.loc[mask_test, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, features], label=df.loc[mask_test2, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)


D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
# def mean_income_rate(y_pred, data):
#     q = 0.98
#     mask = y_pred >= np.quantile(y_pred, q)
#     score = round(data.income_rate[mask].mean(), 5)
    
#     return 'mean_income_rate', score, True#is_higher_better

def mean_income_rate(y_pred, D_sample):
    q = 0.98
    mask = y_pred >= np.quantile(y_pred, q)
    #mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup.loc[mask].groupby(pd.Grouper(key='time', freq='D')).income_rate.mean()-1).mean() * df_sup.loc[mask, 'time'].dt.date.nunique()
    score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month
    score = round(score, 5)
    
    return 'mean_income_rate', score, True#is_higher_better

params = {
    "boosting_type": "gbdt",
    "objective": "binary",
    
    
    "num_boost_round" : 1_000,

    
    "num_leaves": 2,
    #"learning_rate": 0.001,
     "feature_fraction": 0.2,
     "bagging_fraction": 0.2,
     "bagging_freq": 1,
    # 'lambda_l1' : 10,
    # 'lambda_l2' : 10,
    #"verbose": 0,

    #'max_bin' : 100000,
    
    
    "metric": "auc",
    #"metric" : 'mean_income_rate',
    "early_stopping" : 50,



    
}


    

model = lgbm.train(params, train_set=D_train, valid_sets=[D_valid], feval=mean_income_rate, )
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [96]	valid_0's auc: 0.702351	valid_0's mean_income_rate: 0.09161

# %%
model.num_trees()
# Out:
# 96

# %%
y_pred_train = model.predict(D_train.data)
y_pred_valid = model.predict(D_valid.data)
y_pred_test = model.predict(D_test.data)
y_pred_test2 = model.predict(D_test2.data)


df["y_pred"] = None
df.loc[mask_train, 'y_pred'] = y_pred_train
df.loc[mask_valid, 'y_pred'] = y_pred_valid
df.loc[mask_test, 'y_pred'] = y_pred_test
df.loc[mask_test2, 'y_pred'] = y_pred_test2

roc_auc_score(D_train.label, y_pred_train), roc_auc_score(D_valid.label, y_pred_valid), roc_auc_score(D_test.label, y_pred_test), roc_auc_score(D_test2.label, y_pred_test2)
# Out:
# (0.6957374384138081, 0.702350636621373, 0.6662594765460901, 0.6717788127817512)

# %%
#свой threshold

q = 0.99

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest')
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# Valid
# result
# WIN     0.529830
# LOSE    0.353693
# DNF     0.116477
# Name: proportion, dtype: float64
# 1.0146801
#
# Test
# result
# WIN     0.669355
# LOSE    0.278226
# DNF     0.052419
# Name: proportion, dtype: float64
# 1.0214626
#
# Test2
# result
# WIN     0.441176
# LOSE    0.325490
# DNF     0.233333
# Name: proportion, dtype: float64
# 1.0128857

# %%
#общий threshold

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
print(f'threshokd = {threshold}')

mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print("\nTest")
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print('\nTetst2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# threshokd = 0.35809901628524277
#
# Valid
# result
# WIN     0.529830
# LOSE    0.353693
# DNF     0.116477
# Name: proportion, dtype: float64
# 1.0146801
#
# Test
# result
# WIN     0.484337
# LOSE    0.404217
# DNF     0.111446
# Name: proportion, dtype: float64
# 1.0124959
#
# Tetst2
# result
# WIN     0.411208
# LOSE    0.328239
# DNF     0.260553
# Name: proportion, dtype: float64
# 1.0121012

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 19:00:00'),
#  Timedelta('0 days 20:00:00'),
#  Timedelta('1 days 03:00:00'))

# %%
(mask_valid&mask).sum(), (mask_test&mask).sum(), (mask_test2&mask).sum()
# Out:
# (704, 3320, 1374)

# %%
df.loc[mask_valid&mask, 'time'].dt.date.nunique(), df.loc[mask_test&mask, 'time'].dt.date.nunique(), df.loc[mask_test2&mask, 'time'].dt.date.nunique()
# Out:
# (13, 23, 20)

# %%
df.loc[mask_test2&mask, 'ticker'].unique()
# Out:
# array(['MVID', 'SPBE', 'MTLRP', 'FESH', 'KROT', 'VKCO', 'MRKY', 'SELG',
#        'SGZH', 'CHMK', 'YAKG', 'RKKE', 'MRKZ', 'CNTL', 'AFKS', 'UNKL',
#        'LNZL', 'NSVZ', 'RNFT', 'VRSB', 'UWGN', 'TGKN', 'ABIO', 'WUSH',
#        'RTKMP', 'GTRK', 'NLMK', 'CNTLP', 'BLNG', 'ALRS', 'LSNG', 'TRNFP',
#        'MGNT', 'TGKB', 'ROLO', 'IRKT', 'MTLR', 'HEAD', 'KLSB', 'SIBN',
#        'MSTT', 'KAZTP', 'DVEC', 'VTBR', 'AMEZ', 'MRKU', 'TRMK', 'VEON-RX',
#        'RTKM', 'SMLT', 'UNAC', 'PIKK', 'TGKBP', 'POSI', 'MRKS', 'MAGN',
#        'PRFN', 'RBCM'], dtype=object)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_59687/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#          count  income_rate
# ticker
# LNZL       1.0     1.040000
# HEAD       1.0     0.980000
# POSI       2.0     1.040000
# VTBR       3.0     1.035204
# MRKY       3.0     1.007381
# TRMK       3.0     1.017540
# ABIO       4.0     1.040000
# TRNFP      4.0     0.995000
# KAZTP      4.0     1.025000
# RKKE       4.0     1.008881
# CNTLP      4.0     1.011963
# CNTL       4.0     1.025000
# DVEC       5.0     1.019301
# KLSB       5.0     1.028556
# CHMK       6.0     1.020000
# VEON-RX    6.0     1.040000
# MRKS       7.0     1.015309
# MRKU       7.0     1.005714
# SPBE       7.0     1.022857
# MVID       8.0     1.040000
# SELG       8.0     1.034276
# RTKMP      8.0     1.017064
# SIBN       8.0     0.993672
# RTKM       9.0     1.000360
# KROT       9.0     1.033333
# MSTT       9.0     1.036859
# UNAC      10.0     1.034000
# PRFN      10.0     1.022000
# RNFT      11.0     1.017408
# ALRS      14.0     0.987958
# VRSB      14.0     0.997143
# BLNG      16.0     1.008160
# UWGN      18.0     1.033333
# NSVZ      18.0     1.018484
# GTRK      18.0     1.003333
# YAKG      19.0     1.021058
# MAGN      19.0     0.989091
# MGNT      19.0     1.011191
# NLMK      21.0     1.004279
# ROLO      23.0     1.015741
# FESH      24.0     1.017017
# VKCO      25.0     1.018632
# UNKL      27.0     0.991111
# AFKS      28.0     0.987794
# LSNG      28.0     1.003845
# MRKZ      32.0     1.009132
# MTLR      34.0     1.001720
# MTLRP     35.0     1.016142
# WUSH      36.0     1.016144
# RBCM      43.0     1.013407
# PIKK      52.0     1.021394
# AMEZ      52.0     1.003392
# TGKB      71.0     0.997149
# SGZH      76.0     1.019473
# TGKBP     80.0     1.017549
# TGKN     114.0     0.999637
# SMLT     118.0     1.018136
# IRKT     130.0     1.020278

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: -x[1])
# Out:
# [('close_w14_mean_abs_pct', 24.76),
#  ('close_1day_w20_min/close_1day_w20_max', 21.54),
#  ('close_1day_w20_norm_std', 7.29),
#  ('close_w14_min/close_w14_max', 5.58),
#  ('close_1day_w100_lvl_1.02-1.03', 5.11),
#  ('tmos_close_1day_w5_min/tmos_close_1day_w5_max', 4.77),
#  ('tmos_close_w70_lvl_1-1.005', 3.97),
#  ('close_1day_w5_ma/close_1day_w100_ma', 3.06),
#  ('tmos_close_1day_w5_norm_std', 2.99),
#  ('close_1day_w100_lvl_1.01-1.02', 2.84),
#  ('tmos_close_1day_w20_rsi', 2.69),
#  ('tmos_close_w14_ma/tmos_close_w70_ma', 1.48),
#  ('tmos_close/tmos_close_w70_ma', 1.44),
#  ('volume_1day_w20_rsi', 1.44),
#  ('close_w14_ma_low_3std/close', 1.19),
#  ('tmos_close_1day_w5_std/tmos_close_1day_w100_std', 0.92),
#  ('close_w70_lvl_1.02-1.03', 0.85),
#  ('tmos_close_1day_w5_ma_up_3std/tmos_close_1day', 0.82),
#  ('close_1day_w20_roc', 0.78),
#  ('close_w70_lvl_1.01-1.02', 0.71),
#  ('tmos_close_w5_ma/tmos_close_w14_ma', 0.69),
#  ('close_w14_max/close', 0.62),
#  ('close_1day_w5_norm_std/close_1day_w100_norm_std', 0.62),
#  ('volume_1day_w5_norm_std/volume_1day_w20_norm_std', 0.57),
#  ('close_1day_w3_std/close_1day_w100_std', 0.54),
#  ('close_1day/close_1day_w100_ma', 0.51),
#  ('close_w14_mean_abs_pct/close_w70_mean_abs_pct', 0.47),
#  ('volume_1day_w20_rsi/volume_1day_w100_rsi', 0.38),
#  ('tmos_close_w14_max/tmos_close', 0.34),
#  ('volume_w70_mean_abs_pct', 0.26),
#  ('close_w5_ma/close_w70_ma', 0.26),
#  ('close_1day_w20_lvl_1.02-1.03', 0.26),
#  ('tmos_close_w14_ma_up_3std/tmos_close', 0.24),
#  ('tmos_close_w1_roc', 0.0),
#  ('tmos_close_w5_norm_std', 0.0),
#  ('tmos_close_w5_rsi', 0.0),
#  ('tmos_close_w5_roc', 0.0),
#  ('close_w14_norm_std', 0.0),
#  ('volume_w14_norm_std', 0.0),
#  ('volume_w14_mean_abs_pct', 0.0),
#  ('volume_w14_roc', 0.0),
#  ('tmos_close_w14_norm_std', 0.0),
#  ('close_w70_lvl_1.005-1.01', 0.0),
#  ('close_w70_lvl_-0.98-0.99', 0.0),
#  ('volume_w70_roc', 0.0),
#  ('tmos_close_w70_lvl_1.005-1.01', 0.0),
#  ('tmos_close_w70_lvl_1.01-1.015', 0.0),
#  ('close_w1_roc/close_w5_alpha', 0.0),
#  ('close_w1_roc/close_w14_alpha', 0.0),
#  ('close_w1_roc/close_w70_alpha', 0.0),
#  ('tmos_close_w1_roc/tmos_close_w5_alpha', 0.0),
#  ('volume_w1_roc/volume_w70_roc', 0.0),
#  ('volume_w5_roc/volume_w14_roc', 0.0),
#  ('tmos_close_w1_roc/tmos_close_w5_roc', 0.0),
#  ('close_w5_mean_abs_pct/close_w70_mean_abs_pct', 0.0),
#  ('volume_w14_mean_abs_pct/volume_w70_mean_abs_pct', 0.0),
#  ('tmos_close_w5_std/tmos_close_w14_std', 0.0),
#  ('tmos_close_w5_norm_std/tmos_close_w14_norm_std', 0.0),
#  ('close/close_w70_ma', 0.0),
#  ('close_w14_ma/close_w70_ma', 0.0),
#  ('tmos_close/tmos_close_w5_ma', 0.0),
#  ('volume_w14_min/volume', 0.0),
#  ('close_w5_max/close', 0.0),
#  ('close_w5_ma_up_2std/close', 0.0),
#  ('tmos_close_w5_ma_low_2std/tmos_close', 0.0),
#  ('tmos_close_w5_ma_up_2std/tmos_close', 0.0),
#  ('tmos_close_w5_ma_low_3std/tmos_close', 0.0),
#  ('tmos_close_w5_ma_up_3std/tmos_close', 0.0),
#  ('tmos_close_w5_min/tmos_close_w5_max', 0.0),
#  ('volume_w14_min/volume_w14_max', 0.0),
#  ('volume_w70_min/volume_w70_max', 0.0),
#  ('close_1day_w1_roc', 0.0),
#  ('close_1day_w3_roc', 0.0),
#  ('tmos_close_1day_w3_alpha', 0.0),
#  ('tmos_close_1day_w3_roc', 0.0),
#  ('close_1day_w5_norm_std', 0.0),
#  ('close_1day_w5_roc', 0.0),
#  ('volume_1day_w5_roc', 0.0),
#  ('close_1day_w20_lvl_1-1.005', 0.0),
#  ('close_1day_w20_lvl_-0.995-1', 0.0),
#  ('close_1day_w20_lvl_1.005-1.01', 0.0),
#  ('close_1day_w20_lvl_1.03-1.04', 0.0),
#  ('close_1day_w100_lvl_1-1.005', 0.0),
#  ('close_1day_w100_lvl_-0.995-1', 0.0),
#  ('close_1day_w100_lvl_1.005-1.01', 0.0),
#  ('close_1day_w100_lvl_-0.99-0.995', 0.0),
#  ('close_1day_w100_lvl_-0.97-0.98', 0.0),
#  ('close_1day_w100_lvl_-0.96-0.97', 0.0),
#  ('close_1day_w100_lvl_-0.95-0.96', 0.0),
#  ('close_1day_w100_lvl_-0.9299999999999999-0.95', 0.0),
#  ('close_1day_w1_roc/close_1day_w5_alpha', 0.0),
#  ('close_1day_w3_alpha/close_1day_w5_alpha', 0.0),
#  ('close_1day_w5_alpha/close_1day_w100_alpha', 0.0),
#  ('close_1day_w1_roc/close_1day_w3_roc', 0.0),
#  ('close_1day_w3_roc/close_1day_w20_roc', 0.0),
#  ('close_1day_w5_roc/close_1day_w20_roc', 0.0),
#  ('close_1day_w5_roc/close_1day_w100_roc', 0.0),
#  ('tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w20_mean_abs_pct', 0.0),
#  ('close_1day_w20_norm_std/close_1day_w100_norm_std', 0.0),
#  ('close_1day/close_1day_w5_ma', 0.0),
#  ('close_1day_w3_ma/close_1day_w5_ma', 0.0),
#  ('close_1day_w3_ma/close_1day_w100_ma', 0.0),
#  ('close_1day_w5_min/close_1day', 0.0),
#  ('volume_1day_w5_min/volume_1day', 0.0),
#  ('volume_1day_w20_min/volume_1day', 0.0),
#  ('close_1day_w5_ma_low_3std/close_1day', 0.0),
#  ('tmos_close_1day_w3_min/tmos_close_1day_w3_max', 0.0),
#  ('close_1day_w5_min/close_1day_w5_max', 0.0)]

# %% [markdown]
# # 3.2 Tuning hyperparams

# %%
top_features = [elem[0] for elem in zip(features, model.feature_importance(importance_type='gain')) if elem[1] > 0]
top_cat_features = [elem for elem in top_features if elem in cat_features]

# %%
len(top_features), len(top_cat_features)
# Out:
# (33, 0)

# %%
top_features
# Out:
# ['close_w14_mean_abs_pct',
#  'close_w70_lvl_1.01-1.02',
#  'close_w70_lvl_1.02-1.03',
#  'volume_w70_mean_abs_pct',
#  'tmos_close_w70_lvl_1-1.005',
#  'close_w14_mean_abs_pct/close_w70_mean_abs_pct',
#  'close_w5_ma/close_w70_ma',
#  'tmos_close/tmos_close_w70_ma',
#  'tmos_close_w5_ma/tmos_close_w14_ma',
#  'tmos_close_w14_ma/tmos_close_w70_ma',
#  'close_w14_max/close',
#  'tmos_close_w14_max/tmos_close',
#  'close_w14_ma_low_3std/close',
#  'tmos_close_w14_ma_up_3std/tmos_close',
#  'close_w14_min/close_w14_max',
#  'tmos_close_1day_w5_norm_std',
#  'close_1day_w20_norm_std',
#  'close_1day_w20_roc',
#  'close_1day_w20_lvl_1.02-1.03',
#  'volume_1day_w20_rsi',
#  'tmos_close_1day_w20_rsi',
#  'close_1day_w100_lvl_1.01-1.02',
#  'close_1day_w100_lvl_1.02-1.03',
#  'close_1day_w3_std/close_1day_w100_std',
#  'tmos_close_1day_w5_std/tmos_close_1day_w100_std',
#  'close_1day_w5_norm_std/close_1day_w100_norm_std',
#  'volume_1day_w5_norm_std/volume_1day_w20_norm_std',
#  'volume_1day_w20_rsi/volume_1day_w100_rsi',
#  'close_1day/close_1day_w100_ma',
#  'close_1day_w5_ma/close_1day_w100_ma',
#  'tmos_close_1day_w5_ma_up_3std/tmos_close_1day',
#  'tmos_close_1day_w5_min/tmos_close_1day_w5_max',
#  'close_1day_w20_min/close_1day_w20_max']

# %%
D_train = lgbm.Dataset(df.loc[mask_train, top_features], label=df.loc[mask_train, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, top_features], label=df.loc[mask_valid, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, top_features], label=df.loc[mask_test, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, top_features], label=df.loc[mask_test2, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)

D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
def mean_income_rate_point(D_sample, y_pred, threshold=None):
    #mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    score = np.mean(D_sample.income_rate[mask]) - 1
    
    return score

def mean_income_rate_day(D_sample, y_pred, threshold=None):
    #mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup.loc[mask].groupby(pd.Grouper(key='time', freq='D')).income_rate.mean()-1).mean()

    return score
    
def mean_income_rate_month(D_sample, y_pred, threshold=None):
    #mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup.loc[mask].groupby(pd.Grouper(key='time', freq='D')).income_rate.mean()-1).mean() * df_sup.loc[mask, 'time'].dt.date.nunique()
    score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month
    
    return score

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.99)

# %%
mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_point(D_test, y_pred_test, threshold=threshold), mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.014680147171020508, 0.012495875358581543, 0.012101173400878906)

# %%
mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_day(D_test, y_pred_test, threshold=threshold), mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.011852448, 0.0047178864, 0.013002518)

# %%
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.07883256028384664, 0.05551745448001596, 0.09696792811155319)

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.98)
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0916141233471937, 0.04906291921817979, 0.05025496655854128)

# %%
bagging_fraction
# Out:
# 1.0000000000000002

# %%
from IPython.display import clear_output

history = {'params' : [],
           'num_trees' : [],

          
           'auc_train' : [],
           'auc_valid' : [],
           'auc_test' : [],
           'auc_test2' : [],

          
           'mir_point@1_train' : [],
           'mir_point@1_valid' : [],
           'mir_point@1_test' : [],
           'mir_point@1_test2' : [],
    
           'mir_point@2_train' : [],
           'mir_point@2_valid' : [],
           'mir_point@2_test' : [],
           'mir_point@2_test2' : [],


           'mir_day@1_train' : [],
           'mir_day@1_valid' : [],
           'mir_day@1_test' : [],
           'mir_day@1_test2' : [],
           
           'mir_day@2_train' : [],
           'mir_day@2_valid' : [],
           'mir_day@2_test' : [],
           'mir_day@2_test2' : [],

          
           'mir_month@1_train' : [],
           'mir_month@1_valid' : [],
           'mir_month@1_test' : [],
           'mir_month@1_test2' : [],
          
           'mir_month@2_train' : [],
           'mir_month@2_valid' : [],
           'mir_month@2_test' : [],
           'mir_month@2_test2' : [],
          
          }



pbar = tqdm(total=3*1*3*19*19)
# for lambda_x in [0.001, 0.01, 0.1, 1]:
#     for learning_rate in [0.1, 0.01, 0.001]:
#         for num_leaves in [2, 4, 8, 16, 32]:
#             for feature_fraction in np.arange(1, 0, -0.1):
#                 for bagging_fraction in np.arange(1, 0, -0.1):
for lambda_x in [0.1, 1, 10]:
    for learning_rate in [0.1]:
        for num_leaves in [2, 4, 8]:
            for feature_fraction in np.arange(0.1, 1.05, 0.05)[::-1]:
                for bagging_fraction in np.arange(0.1, 1.05, 0.05)[::-1]:
                    feature_fraction = min(feature_fraction, 1)
                    bagging_fraction = min(bagging_fraction, 1)

                    
                    params = {
                                "boosting_type": "gbdt",
                                "objective": "binary",
                            
                                
                                 "num_leaves": num_leaves,
                                 "learning_rate": learning_rate,
                                 "feature_fraction": feature_fraction,
                                 "bagging_fraction": bagging_fraction,
                                 "bagging_freq": 1,
                                 'lambda_l1' : lambda_x,
                                 'lambda_l2' : lambda_x,
                                
                                "verbose": -1,
                                    
                                "metric": "auc",
                                "early_stopping" : 50,
                            }
                    model = lgbm.train(params, num_boost_round=2_000, train_set=D_train, valid_sets=[D_valid])
                    
                    y_pred_train = model.predict(D_train.data)
                    y_pred_valid = model.predict(D_valid.data)
                    y_pred_test = model.predict(D_test.data)
                    y_pred_test2 = model.predict(D_test2.data)
                    
                    #history
                    history['params'] += [params.copy()]
                    history['num_trees'] += [model.num_trees()]
        
                    history['auc_train'] += [roc_auc_score(D_train.label, y_pred_train)]
                    history['auc_valid'] += [roc_auc_score(D_valid.label, y_pred_valid)]
                    history['auc_test'] += [roc_auc_score(D_test.label, y_pred_test)]
                    history['auc_test2'] += [roc_auc_score(D_test2.label, y_pred_test2)]


                    threshold1 = np.quantile(y_pred_valid, q=0.99)
                    threshold2 = np.quantile(y_pred_valid, q=0.98)
                    
                    history['mir_point@1_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold1)]
                    history['mir_point@1_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold1)]
                    history['mir_point@1_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold1)]
                    history['mir_point@1_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold1)]
                   
                    history['mir_point@2_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold2)]
                    history['mir_point@2_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold2)]
                    history['mir_point@2_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold2)]
                    history['mir_point@2_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold2)]


                    history['mir_day@1_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold1)]
                    history['mir_day@1_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold1)]
                    history['mir_day@1_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold1)]
                    history['mir_day@1_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold1)]
                   
                    history['mir_day@2_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold2)]
                    history['mir_day@2_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold2)]
                    history['mir_day@2_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold2)]
                    history['mir_day@2_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold2)]

                    
                    history['mir_month@1_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold1)]
                    history['mir_month@1_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold1)]
                    history['mir_month@1_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold1)]
                    history['mir_month@1_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold1)]
                   
                    history['mir_month@2_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold2)]
                    history['mir_month@2_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold2)]
                    history['mir_month@2_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold2)]
                    history['mir_month@2_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold2)]


                    
                    clear_output()
                    pbar.update(1)
                    
pbar.close()
                    

history_cp = history.copy()
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 3249/3249 [1:35:21<00:00,  1.76s/it]

# %%
dump_pkl(history, './history.pkl')

# %%
history = load_pkl('./history.pkl')

# %%
pd.set_option('display.max_columns', 100)
df_hst = pd.DataFrame(history)
df_hst
# Out:
#                                                  params  num_trees  auc_train  \
# 0     {'boosting_type': 'gbdt', 'objective': 'binary...        180   0.709310
# 1     {'boosting_type': 'gbdt', 'objective': 'binary...        206   0.711453
# 2     {'boosting_type': 'gbdt', 'objective': 'binary...        174   0.708843
# 3     {'boosting_type': 'gbdt', 'objective': 'binary...        172   0.708881
# 4     {'boosting_type': 'gbdt', 'objective': 'binary...        151   0.706672
# ...                                                 ...        ...        ...
# 3244  {'boosting_type': 'gbdt', 'objective': 'binary...         86   0.731295
# 3245  {'boosting_type': 'gbdt', 'objective': 'binary...         78   0.729191
# 3246  {'boosting_type': 'gbdt', 'objective': 'binary...         78   0.728040
# 3247  {'boosting_type': 'gbdt', 'objective': 'binary...         78   0.727799
# 3248  {'boosting_type': 'gbdt', 'objective': 'binary...         52   0.715656
#
#       auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 0      0.711370  0.665880   0.654268           0.016900           0.008269
# 1      0.711629  0.664115   0.648250           0.016822           0.009061
# 2      0.712369  0.664179   0.654574           0.016498           0.009893
# 3      0.711805  0.664187   0.653380           0.016575           0.009754
# 4      0.710634  0.664791   0.657265           0.016353           0.009918
# ...         ...       ...        ...                ...                ...
# 3244   0.708465  0.675583   0.651713           0.021285           0.015795
# 3245   0.704231  0.668931   0.649717           0.018613           0.013577
# 3246   0.704918  0.674443   0.654101           0.019685           0.014813
# 3247   0.707285  0.675621   0.645961           0.019246           0.012550
# 3248   0.705578  0.672761   0.664629           0.017017           0.014698
#
#       mir_point@1_test  mir_point@1_test2  mir_point@2_train  \
# 0             0.014141           0.007279           0.012921
# 1             0.014234           0.007833           0.012808
# 2             0.014129           0.008459           0.012289
# 3             0.014279           0.008325           0.012301
# 4             0.014724           0.009587           0.011973
# ...                ...                ...                ...
# 3244          0.014155           0.009606           0.017011
# 3245          0.011657           0.006560           0.015874
# 3246          0.012039           0.010171           0.016611
# 3247          0.011726           0.007698           0.016263
# 3248          0.012444           0.006807           0.013252
#
#       mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@1_train  \
# 0              0.009389          0.009756           0.003442         0.009437
# 1              0.009768          0.009811           0.003829         0.009795
# 2              0.009885          0.009841           0.004337         0.009419
# 3              0.009471          0.009771           0.004231         0.010146
# 4              0.009750          0.010051           0.004209         0.009217
# ...                 ...               ...                ...              ...
# 3244           0.013489          0.010730           0.007378         0.014863
# 3245           0.010529          0.009205           0.005549         0.010839
# 3246           0.012193          0.009768           0.007146         0.011583
# 3247           0.011390          0.009918           0.006983         0.009991
# 3248           0.012506          0.009610           0.006496         0.008822
#
#       mir_day@1_valid  mir_day@1_test  mir_day@1_test2  mir_day@2_train  \
# 0           -0.002498        0.002328         0.004532         0.007732
# 1           -0.003507        0.003677         0.006503         0.008395
# 2           -0.002214        0.001965         0.007012         0.007706
# 3           -0.000138        0.006101         0.004949         0.007971
# 4           -0.000560        0.004268         0.006029         0.007415
# ...               ...             ...              ...              ...
# 3244         0.009534        0.006635         0.001571         0.008675
# 3245         0.002410        0.005944         0.002365         0.007739
# 3246         0.009219        0.004609         0.003439         0.009211
# 3247         0.001846        0.006998         0.004506         0.007390
# 3248         0.005675        0.006210         0.003319         0.006306
#
#       mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@1_train  \
# 0            0.000826        0.004283         0.005140           0.064465
# 1            0.001503        0.002695         0.003653           0.077733
# 2            0.000791        0.002646         0.003635           0.073802
# 3            0.001276        0.003177         0.003273           0.072364
# 4            0.001675        0.004317         0.002105           0.068982
# ...               ...             ...              ...                ...
# 3244         0.001457        0.002100         0.001286           0.114968
# 3245        -0.000761        0.002021         0.002173           0.113244
# 3246         0.001037        0.003258         0.000898           0.114616
# 3247        -0.000484        0.006201         0.001978           0.096849
# 3248         0.006634        0.003304         0.003043           0.078876
#
#       mir_month@1_valid  mir_month@1_test  mir_month@1_test2  \
# 0             -0.014058          0.028584           0.043935
# 1             -0.023327          0.047034           0.060623
# 2             -0.013591          0.024134           0.062747
# 3             -0.000777          0.074910           0.047981
# 4             -0.003724          0.052410           0.051707
# ...                 ...               ...                ...
# 3244           0.063413          0.091657           0.018742
# 3245           0.030829          0.091239           0.030868
# 3246           0.080184          0.075452           0.046160
# 3247           0.017941          0.100251           0.057122
# 3248           0.040646          0.095315           0.044552
#
#       mir_month@2_train  mir_month@2_valid  mir_month@2_test  \
# 0              0.092045           0.010141          0.065745
# 1              0.110481           0.019998          0.042750
# 2              0.097533           0.009718          0.041970
# 3              0.101291           0.013712          0.048761
# 4              0.092372           0.018850          0.066259
# ...                 ...                ...               ...
# 3244           0.118958           0.020127          0.035450
# 3245           0.116227          -0.012854          0.035163
# 3246           0.133245           0.016972          0.056667
# 3247           0.104674          -0.007422          0.101524
# 3248           0.084883           0.081465          0.055783
#
#       mir_month@2_test2
# 0              0.067081
# 1              0.049037
# 2              0.047445
# 3              0.042719
# 4              0.026685
# ...                 ...
# 3244           0.022539
# 3245           0.040506
# 3246           0.016071
# 3247           0.033182
# 3248           0.049931
#
# [3249 rows x 30 columns]

# %% [markdown]
# ### threshold delta AUC

# %%
threshold = 0.03
mask_model_valid = (df_hst['auc_train'] - df_hst['auc_valid']) < threshold
mask_model_test = (df_hst['auc_train'] - df_hst['auc_test']) < threshold
mask_model_test2 = (df_hst['auc_train'] - df_hst['auc_test2']) < threshold
mask_model_valid.sum(), mask_model_test.sum(), mask_model_test2.sum()
# Out:
# (3163, 356, 116)

# %%
(mask_model_valid&mask_model_test).sum(), (mask_model_valid&mask_model_test&mask_model_test2).sum()
# Out:
# (356, 94)

# %%
mask_auc = mask_model_valid&mask_model_test#&mask_model_test2
df_hst.loc[mask_auc].sort_values(by='auc_valid', ascending=False).iloc[:5]
#df_hst.loc[mask_model_valid&mask_model_test].sort_values(by='income_rate@1_valid', ascending=False).iloc[:5]
# Out:
#                                                  params  num_trees  auc_train  \
# 358   {'boosting_type': 'gbdt', 'objective': 'binary...        119   0.699178
# 1441  {'boosting_type': 'gbdt', 'objective': 'binary...        119   0.699154
# 1327  {'boosting_type': 'gbdt', 'objective': 'binary...         87   0.697348
# 1309  {'boosting_type': 'gbdt', 'objective': 'binary...         82   0.695888
# 2240  {'boosting_type': 'gbdt', 'objective': 'binary...         94   0.698617
#
#       auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 358    0.715838  0.669452   0.668242           0.016316           0.015548
# 1441   0.715810  0.669497   0.668258           0.016237           0.015478
# 1327   0.713956  0.668666   0.672627           0.011129           0.011687
# 1309   0.713597  0.668819   0.672436           0.012326           0.010985
# 2240   0.712807  0.669149   0.671301           0.012304           0.011719
#
#       mir_point@1_test  mir_point@1_test2  mir_point@2_train  \
# 358           0.014922           0.010016           0.011217
# 1441          0.014806           0.009955           0.011111
# 1327          0.011812           0.010756           0.008153
# 1309          0.011456           0.009415           0.008919
# 2240          0.013610           0.010630           0.009571
#
#       mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@1_train  \
# 358            0.012756          0.010142           0.006314         0.010413
# 1441           0.012756          0.010075           0.006335         0.010389
# 1327           0.011753          0.009074           0.005109         0.007955
# 1309           0.011590          0.009483           0.005484         0.008574
# 2240           0.010672          0.010375           0.005719         0.007492
#
#       mir_day@1_valid  mir_day@1_test  mir_day@1_test2  mir_day@2_train  \
# 358          0.009028        0.000436         0.008030         0.006950
# 1441         0.009013        0.000447         0.008073         0.006779
# 1327         0.009935        0.008080         0.007812         0.007477
# 1309         0.007990        0.003087         0.010557         0.006236
# 2240         0.005304        0.005909         0.008851         0.006764
#
#       mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@1_train  \
# 358          0.009437        0.005372         0.002841           0.060672
# 1441         0.009556        0.005262         0.002868           0.060534
# 1327         0.010125        0.002826         0.002964           0.079516
# 1309         0.004858        0.004462         0.005668           0.059860
# 2240         0.006814        0.005440         0.005259           0.062093
#
#       mir_month@1_valid  mir_month@1_test  mir_month@1_test2  \
# 358            0.036951          0.004683           0.065877
# 1441           0.036888          0.004803           0.066225
# 1327           0.066077          0.115758           0.084471
# 1309           0.044969          0.034751           0.090541
# 2240           0.032566          0.069530           0.082508
#
#       mir_month@2_train  mir_month@2_valid  mir_month@2_test  \
# 358            0.083778           0.096566          0.079706
# 1441           0.082058           0.097778          0.078074
# 1327           0.097272           0.119142          0.043369
# 1309           0.072353           0.059651          0.066200
# 2240           0.085274           0.076700          0.083496
#
#       mir_month@2_test2
# 358            0.036024
# 1441           0.036358
# 1327           0.043099
# 1309           0.065515
# 2240           0.062755

# %%
#1309

# %%
df_hst.columns
# Out:
# Index(['params', 'num_trees', 'auc_train', 'auc_valid', 'auc_test',
#        'auc_test2', 'mir_point@1_train', 'mir_point@1_valid',
#        'mir_point@1_test', 'mir_point@1_test2', 'mir_point@2_train',
#        'mir_point@2_valid', 'mir_point@2_test', 'mir_point@2_test2',
#        'mir_day@1_train', 'mir_day@1_valid', 'mir_day@1_test',
#        'mir_day@1_test2', 'mir_day@2_train', 'mir_day@2_valid',
#        'mir_day@2_test', 'mir_day@2_test2', 'mir_month@1_train',
#        'mir_month@1_valid', 'mir_month@1_test', 'mir_month@1_test2',
#        'mir_month@2_train', 'mir_month@2_valid', 'mir_month@2_test',
#        'mir_month@2_test2'],
#       dtype='object')

# %% [markdown]
# ### threshold income_rate

# %%
col = 'mir_month@1'
threshold = 0.07
# mask_ir_valid = (df_hst[f'{col}_train'] - df_hst[f'{col}_valid']).abs() < threshold
# mask_ir_test = (df_hst[f'{col}_train'] - df_hst[f'{col}_test']).abs() < threshold
# mask_ir_test2 = (df_hst[f'{col}_train'] - df_hst[f'{col}_test2']).abs() < threshold

mask_ir_valid = df_hst[f'{col}_valid'] >=  threshold
mask_ir_test = df_hst[f'{col}_test'] >= threshold
mask_ir_test2 = df_hst[f'{col}_test2'] >=  threshold


mask_ir_valid.sum(), mask_ir_test.sum(), mask_ir_test2.sum()
# Out:
# (133, 663, 410)

# %%
(mask_ir_valid&mask_ir_test).sum(), (mask_ir_valid&mask_ir_test&mask_ir_test2).sum()
# Out:
# (65, 8)

# %%
mask_ir= mask_ir_valid&mask_ir_test&mask_ir_test2
mask_ir.sum()
# Out:
# 8

# %%
col = 'mir_day@1'
threshold = 0.007

# mask2_ir_valid = (df_hst[f'{col}_train'] - df_hst[f'{col}_valid']).abs() < threshold
# mask2_ir_test = (df_hst[f'{col}_train'] - df_hst[f'{col}_test']).abs() < threshold
# mask2_ir_test2 = (df_hst[f'{col}_train'] - df_hst[f'{col}_test2']).abs() < threshold

mask2_ir_valid = df_hst[f'{col}_valid'] >=  threshold
mask2_ir_test = df_hst[f'{col}_test'] >= threshold
mask2_ir_test2 = df_hst[f'{col}_test2'] >=  threshold


mask2_ir_valid.sum(), mask2_ir_test.sum(), mask2_ir_test2.sum()
# Out:
# (752, 492, 1200)

# %%
(mask2_ir_valid&mask2_ir_test).sum(), (mask2_ir_valid&mask2_ir_test&mask2_ir_test2).sum()
# Out:
# (179, 65)

# %%
mask2_ir = mask2_ir_valid&mask2_ir_test&mask2_ir_test2
mask2_ir.sum()
# Out:
# 65

# %%
(mask_ir&mask2_ir).sum()
# Out:
# 4

# %%
df_hst.loc[mask_ir&mask2_ir].sort_values(by=f'auc_valid', ascending=False).iloc[:5]
# Out:
#                                                  params  num_trees  auc_train  \
# 186   {'boosting_type': 'gbdt', 'objective': 'binary...        107   0.700604
# 2463  {'boosting_type': 'gbdt', 'objective': 'binary...        148   0.700850
# 2369  {'boosting_type': 'gbdt', 'objective': 'binary...        112   0.701058
# 2082  {'boosting_type': 'gbdt', 'objective': 'binary...         15   0.705644
#
#       auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 186    0.714429  0.667331   0.664917           0.014880           0.010401
# 2463   0.713315  0.669490   0.666302           0.013608           0.011188
# 2369   0.712114  0.666239   0.664986           0.015093           0.008034
# 2082   0.701653  0.680597   0.671145           0.020563           0.016053
#
#       mir_point@1_test  mir_point@1_test2  mir_point@2_train  \
# 186           0.012476           0.006897           0.011095
# 2463          0.012791           0.008725           0.010454
# 2369          0.012414           0.007867           0.010967
# 2082          0.013703           0.011943           0.017507
#
#       mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@1_train  \
# 186            0.011072          0.009295           0.003620         0.008845
# 2463           0.010017          0.009247           0.005167         0.006496
# 2369           0.007329          0.009441           0.004806         0.008395
# 2082           0.011186          0.011759           0.009692         0.014574
#
#       mir_day@1_valid  mir_day@1_test  mir_day@1_test2  mir_day@2_train  \
# 186          0.014039        0.007753         0.007531         0.006953
# 2463         0.010906        0.008380         0.008171         0.007403
# 2369         0.013583        0.007743         0.009219         0.007388
# 2082         0.015329        0.008048         0.008165         0.010989
#
#       mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@1_train  \
# 186          0.005958        0.004361         0.002630           0.067976
# 2463         0.002023        0.003396         0.003685           0.061016
# 2369         0.009479        0.004145         0.005261           0.063670
# 2082         0.003027        0.005483         0.001517           0.040993
#
#       mir_month@1_valid  mir_month@1_test  mir_month@1_test2  \
# 186            0.093377          0.103131           0.075825
# 2463           0.078116          0.111467           0.091403
# 2369           0.104239          0.099037           0.085935
# 2082           0.078429          0.082350           0.076117
#
#       mir_month@2_train  mir_month@2_valid  mir_month@2_test  \
# 186            0.081369           0.064012          0.066932
# 2463           0.095932           0.028985          0.052131
# 2369           0.089065           0.111538          0.065739
# 2082           0.057405           0.023230          0.078553
#
#       mir_month@2_test2
# 186            0.033340
# 2463           0.050843
# 2369           0.064732
# 2082           0.023197

# %% [markdown]
# ### creation

# %%
mask_must = (df_hst['mir_day@1_train'] > df_hst['mir_day@2_train']) & (df_hst['mir_day@1_valid'] > df_hst['mir_day@2_valid']) & (df_hst['mir_day@1_test'] > df_hst['mir_day@2_test']) & (df_hst['mir_day@1_test2'] > df_hst['mir_day@2_test2'])
mask_must.sum()
# Out:
# 706

# %%
df_hst.loc[mask_must].sort_values(by=f'mir_month@2_valid', ascending=False).iloc[:5]
# Out:
#                                                  params  num_trees  auc_train  \
# 2126  {'boosting_type': 'gbdt', 'objective': 'binary...         26   0.710598
# 1437  {'boosting_type': 'gbdt', 'objective': 'binary...        119   0.699232
# 354   {'boosting_type': 'gbdt', 'objective': 'binary...        119   0.699243
# 2514  {'boosting_type': 'gbdt', 'objective': 'binary...        119   0.699484
# 1049  {'boosting_type': 'gbdt', 'objective': 'binary...         12   0.693587
#
#       auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 2126   0.707653  0.669989   0.649252           0.021870           0.014721
# 1437   0.714472  0.667438   0.666408           0.016583           0.014638
# 354    0.714487  0.667414   0.666404           0.016659           0.014553
# 2514   0.713060  0.668787   0.666301           0.015879           0.010736
# 1049   0.708424  0.671579   0.671043           0.018506           0.015121
#
#       mir_point@1_test  mir_point@1_test2  mir_point@2_train  \
# 2126          0.017025           0.007587           0.018512
# 1437          0.014479           0.010284           0.012151
# 354           0.014514           0.010174           0.012163
# 2514          0.014389           0.010293           0.011429
# 1049          0.014025           0.008555           0.014367
#
#       mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@1_train  \
# 2126           0.012794          0.014278           0.003733         0.012472
# 1437           0.012812          0.009529           0.007176         0.010107
# 354            0.012812          0.009547           0.007156         0.010427
# 2514           0.011136          0.009634           0.006930         0.010194
# 1049           0.012937          0.011470           0.006840         0.007832
#
#       mir_day@1_valid  mir_day@1_test  mir_day@1_test2  mir_day@2_train  \
# 2126         0.009853        0.009132         0.005619         0.012325
# 1437         0.015199        0.007144         0.005078         0.007558
# 354          0.015191        0.007154         0.005021         0.007550
# 2514         0.016399        0.004205         0.007392         0.006917
# 1049         0.008400        0.002484         0.004966         0.005611
#
#       mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@1_train  \
# 2126         0.009533        0.005950         0.001934           0.046984
# 1437         0.012340        0.004852         0.003069           0.048228
# 354          0.012340        0.004908         0.003057           0.049230
# 2514         0.012317        0.004118         0.003143           0.061957
# 1049         0.007766       -0.000719         0.000220           0.042092
#
#       mir_month@1_valid  mir_month@1_test  mir_month@1_test2  \
# 2126           0.080655          0.065414           0.054472
# 1437           0.062210          0.080412           0.045441
# 354            0.062179          0.080523           0.044933
# 2514           0.075512          0.051629           0.068908
# 1049           0.077359          0.038124           0.061104
#
#       mir_month@2_train  mir_month@2_valid  mir_month@2_test  \
# 2126           0.069335           0.131695          0.076104
# 1437           0.084655           0.126271          0.069511
# 354            0.084564           0.126271          0.070305
# 2514           0.082683           0.119731          0.063208
# 1049           0.062004           0.119196         -0.013612
#
#       mir_month@2_test2
# 2126           0.023793
# 1437           0.040054
# 354            0.039893
# 2514           0.039851
# 1049           0.003773

# %%
df_hst.iloc[[1309, 2463, 2369]]
# Out:
#                                                  params  num_trees  auc_train  \
# 1309  {'boosting_type': 'gbdt', 'objective': 'binary...         82   0.695888
# 2463  {'boosting_type': 'gbdt', 'objective': 'binary...        148   0.700850
# 2369  {'boosting_type': 'gbdt', 'objective': 'binary...        112   0.701058
#
#       auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 1309   0.713597  0.668819   0.672436           0.012326           0.010985
# 2463   0.713315  0.669490   0.666302           0.013608           0.011188
# 2369   0.712114  0.666239   0.664986           0.015093           0.008034
#
#       mir_point@1_test  mir_point@1_test2  mir_point@2_train  \
# 1309          0.011456           0.009415           0.008919
# 2463          0.012791           0.008725           0.010454
# 2369          0.012414           0.007867           0.010967
#
#       mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@1_train  \
# 1309           0.011590          0.009483           0.005484         0.008574
# 2463           0.010017          0.009247           0.005167         0.006496
# 2369           0.007329          0.009441           0.004806         0.008395
#
#       mir_day@1_valid  mir_day@1_test  mir_day@1_test2  mir_day@2_train  \
# 1309         0.007990        0.003087         0.010557         0.006236
# 2463         0.010906        0.008380         0.008171         0.007403
# 2369         0.013583        0.007743         0.009219         0.007388
#
#       mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@1_train  \
# 1309         0.004858        0.004462         0.005668           0.059860
# 2463         0.002023        0.003396         0.003685           0.061016
# 2369         0.009479        0.004145         0.005261           0.063670
#
#       mir_month@1_valid  mir_month@1_test  mir_month@1_test2  \
# 1309           0.044969          0.034751           0.090541
# 2463           0.078116          0.111467           0.091403
# 2369           0.104239          0.099037           0.085935
#
#       mir_month@2_train  mir_month@2_valid  mir_month@2_test  \
# 1309           0.072353           0.059651          0.066200
# 2463           0.095932           0.028985          0.052131
# 2369           0.089065           0.111538          0.065739
#
#       mir_month@2_test2
# 1309           0.065515
# 2463           0.050843
# 2369           0.064732

# %%
df_hst['params'].iloc[2369] #<---
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 2,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.5000000000000001,
#  'bagging_fraction': 0.3500000000000001,
#  'bagging_freq': 1,
#  'lambda_l1': 10,
#  'lambda_l2': 10,
#  'verbose': -1,
#  'metric': 'auc',
#  'early_stopping': 50}

# %%
df_hst['params'].iloc[2463]
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 2,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.25000000000000006,
#  'bagging_fraction': 0.40000000000000013,
#  'bagging_freq': 1,
#  'lambda_l1': 10,
#  'lambda_l2': 10,
#  'verbose': -1,
#  'metric': 'auc',
#  'early_stopping': 50}

# %% [markdown]
# # Feature selection

# %%
len(top_features), top_features
# Out:
# (33,
#  ['close_w14_mean_abs_pct',
#   'close_w70_lvl_1.01-1.02',
#   'close_w70_lvl_1.02-1.03',
#   'volume_w70_mean_abs_pct',
#   'tmos_close_w70_lvl_1-1.005',
#   'close_w14_mean_abs_pct/close_w70_mean_abs_pct',
#   'close_w5_ma/close_w70_ma',
#   'tmos_close/tmos_close_w70_ma',
#   'tmos_close_w5_ma/tmos_close_w14_ma',
#   'tmos_close_w14_ma/tmos_close_w70_ma',
#   'close_w14_max/close',
#   'tmos_close_w14_max/tmos_close',
#   'close_w14_ma_low_3std/close',
#   'tmos_close_w14_ma_up_3std/tmos_close',
#   'close_w14_min/close_w14_max',
#   'tmos_close_1day_w5_norm_std',
#   'close_1day_w20_norm_std',
#   'close_1day_w20_roc',
#   'close_1day_w20_lvl_1.02-1.03',
#   'volume_1day_w20_rsi',
#   'tmos_close_1day_w20_rsi',
#   'close_1day_w100_lvl_1.01-1.02',
#   'close_1day_w100_lvl_1.02-1.03',
#   'close_1day_w3_std/close_1day_w100_std',
#   'tmos_close_1day_w5_std/tmos_close_1day_w100_std',
#   'close_1day_w5_norm_std/close_1day_w100_norm_std',
#   'volume_1day_w5_norm_std/volume_1day_w20_norm_std',
#   'volume_1day_w20_rsi/volume_1day_w100_rsi',
#   'close_1day/close_1day_w100_ma',
#   'close_1day_w5_ma/close_1day_w100_ma',
#   'tmos_close_1day_w5_ma_up_3std/tmos_close_1day',
#   'tmos_close_1day_w5_min/tmos_close_1day_w5_max',
#   'close_1day_w20_min/close_1day_w20_max'])

# %%
top_features = ['close_w14_mean_abs_pct',
  'close_w70_lvl_1.01-1.02',
  'close_w70_lvl_1.02-1.03',
  'volume_w70_mean_abs_pct',
  'tmos_close_w70_lvl_1-1.005',
  'close_w14_mean_abs_pct/close_w70_mean_abs_pct',
  'close_w5_ma/close_w70_ma',
  'tmos_close/tmos_close_w70_ma',
  'tmos_close_w5_ma/tmos_close_w14_ma',
  'tmos_close_w14_ma/tmos_close_w70_ma',
  'close_w14_max/close',
  'tmos_close_w14_max/tmos_close',
  'close_w14_ma_low_3std/close',
  'tmos_close_w14_ma_up_3std/tmos_close',
  'close_w14_min/close_w14_max',
  'tmos_close_1day_w5_norm_std',
  'close_1day_w20_norm_std',
  'close_1day_w20_roc',
  'close_1day_w20_lvl_1.02-1.03',
  'volume_1day_w20_rsi',
  'tmos_close_1day_w20_rsi',
  'close_1day_w100_lvl_1.01-1.02',
  'close_1day_w100_lvl_1.02-1.03',
  'close_1day_w3_std/close_1day_w100_std',
  'tmos_close_1day_w5_std/tmos_close_1day_w100_std',
  'close_1day_w5_norm_std/close_1day_w100_norm_std',
  'volume_1day_w5_norm_std/volume_1day_w20_norm_std',
  'volume_1day_w20_rsi/volume_1day_w100_rsi',
  'close_1day/close_1day_w100_ma',
  'close_1day_w5_ma/close_1day_w100_ma',
  'tmos_close_1day_w5_ma_up_3std/tmos_close_1day',
  'tmos_close_1day_w5_min/tmos_close_1day_w5_max',
  'close_1day_w20_min/close_1day_w20_max']

# %%
#features = features_criteria2.tolist()
features = top_features


cat_features = []

# %%
len(features), len(cat_features)
# Out:
# (33, 0)

# %%
'ticker_code' in features
# Out:
# False

# %%
target = 'target'

# %%
D_train = lgbm.Dataset(df.loc[mask_train, features], label=df.loc[mask_train, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, features], label=df.loc[mask_valid, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, features], label=df.loc[mask_test, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, features], label=df.loc[mask_test2, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)


D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
D_test2.data
# Out:
#          close_w14_mean_abs_pct  close_w70_lvl_1.01-1.02  \
# 8236                   0.003961                     15.0
# 8237                   0.004123                     21.0
# 8238                   0.004222                      4.0
# 8239                   0.004512                      9.0
# 8240                   0.004242                      5.0
# ...                         ...                      ...
# 1005861                0.012130                      1.0
# 1005862                0.012483                      0.0
# 1005863                0.011935                      0.0
# 1005864                0.012227                      1.0
# 1005865                0.012077                      0.0
#
#          close_w70_lvl_1.02-1.03  volume_w70_mean_abs_pct  \
# 8236                         3.0                 1.490307
# 8237                         4.0                 1.492058
# 8238                         2.0                 1.493076
# 8239                         2.0                 1.491756
# 8240                         2.0                 1.493121
# ...                          ...                      ...
# 1005861                      0.0                 5.146770
# 1005862                      0.0                 5.153590
# 1005863                      0.0                 5.156600
# 1005864                      0.0                 5.158228
# 1005865                      0.0                 5.140069
#
#          tmos_close_w70_lvl_1-1.005  \
# 8236                           16.0
# 8237                            2.0
# 8238                           16.0
# 8239                            9.0
# 8240                            6.0
# ...                             ...
# 1005861                         1.0
# 1005862                         2.0
# 1005863                         0.0
# 1005864                         0.0
# 1005865                         2.0
#
#          close_w14_mean_abs_pct/close_w70_mean_abs_pct  \
# 8236                                          0.969775
# 8237                                          0.998964
# 8238                                          0.992985
# 8239                                          1.064376
# 8240                                          0.996351
# ...                                                ...
# 1005861                                       1.442168
# 1005862                                       1.470383
# 1005863                                       1.417903
# 1005864                                       1.444231
# 1005865                                       1.481009
#
#          close_w5_ma/close_w70_ma  tmos_close/tmos_close_w70_ma  \
# 8236                     1.002983                      0.990908
# 8237                     1.000172                      0.984522
# 8238                     0.999939                      0.991305
# 8239                     0.999915                      0.989866
# 8240                     1.000391                      0.988425
# ...                           ...                           ...
# 1005861                  1.079123                      1.079241
# 1005862                  1.078168                      1.076286
# 1005863                  1.080856                      1.080740
# 1005864                  1.080474                      1.081429
# 1005865                  1.080646                      1.076548
#
#          tmos_close_w5_ma/tmos_close_w14_ma  \
# 8236                               0.995651
# 8237                               0.993687
# 8238                               0.992313
# 8239                               0.991715
# 8240                               0.991660
# ...                                     ...
# 1005861                            1.038457
# 1005862                            1.037158
# 1005863                            1.034163
# 1005864                            1.030124
# 1005865                            1.024347
#
#          tmos_close_w14_ma/tmos_close_w70_ma  ...  \
# 8236                                1.001861  ...
# 8237                                1.000071  ...
# 8238                                0.999317  ...
# 8239                                0.998468  ...
# 8240                                0.997737  ...
# ...                                      ...  ...
# 1005861                             1.032019  ...
# 1005862                             1.036638  ...
# 1005863                             1.041404  ...
# 1005864                             1.046159  ...
# 1005865                             1.050960  ...
#
#          close_1day_w3_std/close_1day_w100_std  \
# 8236                                  0.142085
# 8237                                  0.142085
# 8238                                  0.142085
# 8239                                  0.142085
# 8240                                  0.142085
# ...                                        ...
# 1005861                               0.052559
# 1005862                               0.052559
# 1005863                               0.052559
# 1005864                               0.052559
# 1005865                               0.052559
#
#          tmos_close_1day_w5_std/tmos_close_1day_w100_std  \
# 8236                                            0.098721
# 8237                                            0.098721
# 8238                                            0.098721
# 8239                                            0.098721
# 8240                                            0.098721
# ...                                                  ...
# 1005861                                         0.189029
# 1005862                                         0.189029
# 1005863                                         0.189029
# 1005864                                         0.189029
# 1005865                                         0.189029
#
#          close_1day_w5_norm_std/close_1day_w100_norm_std  \
# 8236                                            0.109765
# 8237                                            0.109765
# 8238                                            0.109765
# 8239                                            0.109765
# 8240                                            0.109765
# ...                                                  ...
# 1005861                                         0.167056
# 1005862                                         0.167056
# 1005863                                         0.167056
# 1005864                                         0.167056
# 1005865                                         0.167056
#
#          volume_1day_w5_norm_std/volume_1day_w20_norm_std  \
# 8236                                             0.526666
# 8237                                             0.526666
# 8238                                             0.526666
# 8239                                             0.526666
# 8240                                             0.526666
# ...                                                   ...
# 1005861                                          1.026487
# 1005862                                          1.026487
# 1005863                                          1.026487
# 1005864                                          1.026487
# 1005865                                          1.026487
#
#          volume_1day_w20_rsi/volume_1day_w100_rsi  \
# 8236                                     0.956359
# 8237                                     0.956359
# 8238                                     0.956359
# 8239                                     0.956359
# 8240                                     0.956359
# ...                                           ...
# 1005861                                  1.033822
# 1005862                                  1.033822
# 1005863                                  1.033822
# 1005864                                  1.033822
# 1005865                                  1.033822
#
#          close_1day/close_1day_w100_ma  close_1day_w5_ma/close_1day_w100_ma  \
# 8236                          0.990324                             0.989518
# 8237                          0.990324                             0.989518
# 8238                          0.990324                             0.989518
# 8239                          0.990324                             0.989518
# 8240                          0.990324                             0.989518
# ...                                ...                                  ...
# 1005861                       0.684095                             0.686933
# 1005862                       0.684095                             0.686933
# 1005863                       0.684095                             0.686933
# 1005864                       0.684095                             0.686933
# 1005865                       0.684095                             0.686933
#
#          tmos_close_1day_w5_ma_up_3std/tmos_close_1day  \
# 8236                                          1.026375
# 8237                                          1.026375
# 8238                                          1.026375
# 8239                                          1.026375
# 8240                                          1.026375
# ...                                                ...
# 1005861                                       1.024304
# 1005862                                       1.024304
# 1005863                                       1.024304
# 1005864                                       1.024304
# 1005865                                       1.024304
#
#          tmos_close_1day_w5_min/tmos_close_1day_w5_max  \
# 8236                                          0.983633
# 8237                                          0.983633
# 8238                                          0.983633
# 8239                                          0.983633
# 8240                                          0.983633
# ...                                                ...
# 1005861                                       0.977528
# 1005862                                       0.977528
# 1005863                                       0.977528
# 1005864                                       0.977528
# 1005865                                       0.977528
#
#          close_1day_w20_min/close_1day_w20_max
# 8236                                  0.837273
# 8237                                  0.837273
# 8238                                  0.837273
# 8239                                  0.837273
# 8240                                  0.837273
# ...                                        ...
# 1005861                               0.743154
# 1005862                               0.743154
# 1005863                               0.743154
# 1005864                               0.743154
# 1005865                               0.743154
#
# [101909 rows x 33 columns]

# %%
params = {'boosting_type': 'gbdt',
 'objective': 'binary',
 'num_leaves': 2,
 'learning_rate': 0.1,
 'feature_fraction': 0.5000000000000001,
 'bagging_fraction': 0.3500000000000001,
 'bagging_freq': 1,
 'lambda_l1': 10,
 'lambda_l2': 10,
 'verbose': -1,
 'metric': 'auc',
 'early_stopping': 50}

model = lgbm.train(params,  num_boost_round=2_000, train_set=D_train, valid_sets=[D_valid])

# %%
model.num_trees()
# Out:
# 167

# %%
y_pred_train = model.predict(D_train.data)
y_pred_valid = model.predict(D_valid.data)
y_pred_test = model.predict(D_test.data)
y_pred_test2 = model.predict(D_test2.data)


df["y_pred"] = None
df.loc[mask_train, 'y_pred'] = y_pred_train
df.loc[mask_valid, 'y_pred'] = y_pred_valid
df.loc[mask_test, 'y_pred'] = y_pred_test
df.loc[mask_test2, 'y_pred'] = y_pred_test2

roc_auc_score(D_train.label, y_pred_train), roc_auc_score(D_valid.label, y_pred_valid), roc_auc_score(D_test.label, y_pred_test), roc_auc_score(D_test2.label, y_pred_test2)
# Out:
# (0.7086664277601837,
#  0.7130201483959963,
#  0.6681000633686929,
#  0.6562172824090529)

# %%
#свой threshold

q = 0.99

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest')
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# Valid
# result
# LOSE    0.464387
# WIN     0.390313
# DNF     0.145299
# Name: proportion, dtype: float64
# 1.0068669
#
# Test
# result
# WIN     0.650538
# LOSE    0.252688
# DNF     0.096774
# Name: proportion, dtype: float64
# 1.0213258
#
# Test2
# result
# WIN     0.417154
# LOSE    0.370370
# DNF     0.212476
# Name: proportion, dtype: float64
# 1.0104413

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 15:30:00'),
#  Timedelta('0 days 20:00:00'),
#  Timedelta('0 days 23:00:00'))

# %%
mask_win = df['result'] == 'WIN'
df.loc[mask_valid&mask&mask_win, 'delta_time'].median(), df.loc[mask_test&mask&mask_win, 'delta_time'].median(), df.loc[mask_test2&mask&mask_win, 'delta_time'].median()
# Out:
# (Timedelta('0 days 20:00:00'),
#  Timedelta('0 days 20:00:00'),
#  Timedelta('0 days 23:00:00'))

# %%
#общий threshold

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
print(f'threshokd = {threshold}')

mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print("\nTest")
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print('\nTetst2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# threshokd = 0.3778566265844373
#
# Valid
# result
# LOSE    0.464387
# WIN     0.390313
# DNF     0.145299
# Name: proportion, dtype: float64
# 1.0068669
#
# Test
# result
# WIN     0.485480
# LOSE    0.387276
# DNF     0.127244
# Name: proportion, dtype: float64
# 1.0131007
#
# Tetst2
# result
# LOSE    0.450176
# WIN     0.325397
# DNF     0.224427
# Name: proportion, dtype: float64
# 1.0057018

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 17:00:00'),
#  Timedelta('0 days 20:00:00'),
#  Timedelta('1 days 01:00:00'))

# %%
mask_win = df['result'] == 'WIN'
df.loc[mask_valid&mask&mask_win, 'delta_time'].median(), df.loc[mask_test&mask&mask_win, 'delta_time'].median(), df.loc[mask_test2&mask&mask_win, 'delta_time'].median()
# Out:
# (Timedelta('0 days 20:00:00'),
#  Timedelta('0 days 21:00:00'),
#  Timedelta('1 days 00:00:00'))

# %%
(mask_valid&mask).sum(), (mask_test&mask).sum(), (mask_test2&mask).sum()
# Out:
# (702, 3788, 2268)

# %%
df.loc[mask_valid&mask, 'time'].dt.date.nunique(), df.loc[mask_test&mask, 'time'].dt.date.nunique(), df.loc[mask_test2&mask, 'time'].dt.date.nunique()
# Out:
# (13, 26, 27)

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.99)

# %%
mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_point(D_test, y_pred_test, threshold=threshold), mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.006866931915283203, 0.013100743293762207, 0.005701780319213867)

# %%
mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_day(D_test, y_pred_test, threshold=threshold), mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0071033696, 0.0030348783, 0.0076159528)

# %%
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.04724566738099553, 0.04037093910453625, 0.07667586330513833)

# %%
df.loc[mask_test2&mask, 'ticker'].unique()
# Out:
# array(['MVID', 'SPBE', 'MTLRP', 'SFIN', 'KMAZ', 'FEES', 'FESH', 'KROT',
#        'VKCO', 'SELG', 'SGZH', 'YAKG', 'RKKE', 'MRKZ', 'CNTL', 'PLZL',
#        'AFKS', 'UNKL', 'NSVZ', 'RNFT', 'VRSB', 'UWGN', 'TGKN', 'ABIO',
#        'WUSH', 'RTKMP', 'GTRK', 'NLMK', 'CNTLP', 'BLNG', 'ALRS', 'LSNG',
#        'TRNFP', 'MGNT', 'NKHP', 'TGKB', 'ROLO', 'IRKT', 'MTLR', 'KLSB',
#        'SIBN', 'MSTT', 'KAZTP', 'DVEC', 'VTBR', 'AMEZ', 'MRKU', 'VEON-RX',
#        'CHMF', 'RTKM', 'SMLT', 'UNAC', 'PIKK', 'TGKBP', 'POSI', 'KZOS',
#        'MRKS', 'MAGN', 'PRFN', 'BANEP', 'AQUA', 'RBCM'], dtype=object)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_82201/859047173.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#          count  income_rate
# ticker
# TGKA       1.0     0.980000
# KRKNP      1.0     1.040000
# CNTLP      2.0     1.016748
# SBERP      3.0     1.020000
# KZOSP      4.0     1.040000
# LSNGP      6.0     1.030971
# CBOM       6.0     1.010000
# RTKM      10.0     1.028000
# KAZTP     10.0     1.026327
# BELU      11.0     1.010215
# POSI      11.0     1.033776
# UWGN      11.0     1.018182
# KLSB      13.0     1.033700
# LENT      13.0     1.040000
# VSMO      13.0     1.035017
# GEMC      13.0     1.010315
# MRKU      14.0     1.023815
# SNGSP     16.0     1.002344
# LIFE      19.0     1.036842
# KAZT      19.0     1.016223
# CHMK      19.0     1.002105
# KZOS      20.0     1.024175
# PIKK      21.0     1.025193
# SPBE      22.0     1.017931
# LNZL      22.0     1.000016
# ENPG      23.0     1.003784
# MAGN      23.0     1.037209
# NMTP      25.0     1.014791
# RASP      25.0     1.031293
# TGKBP     26.0     1.023846
# APTK      28.0     1.025177
# FLOT      28.0     1.023294
# HYDR      28.0     1.014578
# GMKN      28.0     1.006038
# FEES      28.0     1.020228
# SNGS      28.0     1.007141
# SVAV      29.0     1.025655
# VEON-RX   29.0     1.015172
# RUAL      29.0     1.012753
# MTSS      30.0     1.029763
# LSRG      31.0     1.023606
# VRSB      31.0     1.024516
# RKKE      33.0     1.027273
# NKHP      33.0     1.006648
# MGNT      34.0     1.025713
# TTLK      34.0     1.021232
# MSNG      35.0     1.025066
# ABIO      36.0     1.014675
# IRKT      37.0     1.009582
# CHMF      37.0     1.027027
# UNKL      37.0     1.004083
# AQUA      37.0     1.028649
# RBCM      39.0     1.004615
# MRKY      40.0     1.019239
# ABRD      40.0     1.022356
# BANE      41.0     1.024666
# RNFT      42.0     0.995020
# ALRS      42.0     1.017495
# SELG      43.0     1.022164
# CNTL      43.0     1.017249
# MRKC      43.0     1.018610
# PRFN      43.0     0.996744
# BANEP     44.0     1.000140
# KROT      44.0     1.012032
# SFIN      45.0     1.012636
# KMAZ      45.0     1.019894
# DVEC      46.0     1.002043
# NLMK      47.0     1.022860
# LSNG      47.0     1.005500
# OGKB      48.0     1.013644
# GTRK      48.0     1.016308
# YAKG      49.0     1.006028
# MSTT      49.0     1.013061
# AFKS      51.0     1.016575
# MRKZ      53.0     1.010784
# TGKN      53.0     1.014205
# VKCO      54.0     1.013191
# MRKS      54.0     1.013333
# LNZLP     55.0     1.011239
# WUSH      56.0     1.005342
# NSVZ      57.0     1.004211
# BLNG      59.0     1.010173
# SMLT      59.0     1.018993
# FESH      60.0     1.010062
# ROLO      62.0     1.012185
# PMSB      63.0     1.017677
# MVID      63.0     1.023964
# MGTSP     72.0     1.009198
# UNAC      77.0     1.012152
# TGKB      95.0     1.018443
# TRMK     101.0     1.003403
# PMSBP    105.0     0.999663
# MTLR     110.0     0.998000
# AMEZ     114.0     1.001937
# SGZH     127.0     1.014016
# MTLRP    138.0     1.000199

# %% [markdown]
# # Drop weak features

# %%
# features = ['close_w14_mean_abs_pct',
#   'close_w70_lvl_1.01-1.02',
#   'close_w70_lvl_1.02-1.03',
#   'volume_w70_mean_abs_pct',
#   'tmos_close_w70_lvl_1-1.005',
#   'close_w14_mean_abs_pct/close_w70_mean_abs_pct',
#   'close_w5_ma/close_w70_ma',
#   'tmos_close/tmos_close_w70_ma',
#   'tmos_close_w5_ma/tmos_close_w14_ma',
#   'tmos_close_w14_ma/tmos_close_w70_ma',
#   'close_w14_max/close',
#   'tmos_close_w14_max/tmos_close',
#   'close_w14_ma_low_3std/close',
#   'tmos_close_w14_ma_up_3std/tmos_close',
#   'close_w14_min/close_w14_max',
#   'tmos_close_1day_w5_norm_std',
#   'close_1day_w20_norm_std',
#   'close_1day_w20_roc',
#   'close_1day_w20_lvl_1.02-1.03',
#   'volume_1day_w20_rsi',
#   'tmos_close_1day_w20_rsi',
#   'close_1day_w100_lvl_1.01-1.02',
#   'close_1day_w100_lvl_1.02-1.03',
#   'close_1day_w3_std/close_1day_w100_std',
#   'tmos_close_1day_w5_std/tmos_close_1day_w100_std',
#   'close_1day_w5_norm_std/close_1day_w100_norm_std',
#   'volume_1day_w5_norm_std/volume_1day_w20_norm_std',
#   'volume_1day_w20_rsi/volume_1day_w100_rsi',
#   'close_1day/close_1day_w100_ma',
#   'close_1day_w5_ma/close_1day_w100_ma',
#   'tmos_close_1day_w5_ma_up_3std/tmos_close_1day',
#   'tmos_close_1day_w5_min/tmos_close_1day_w5_max',
#   'close_1day_w20_min/close_1day_w20_max']

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1])
# Out:
# [('volume_w70_mean_abs_pct', 0.0),
#  ('tmos_close_w5_ma/tmos_close_w14_ma', 0.0),
#  ('tmos_close_w14_ma_up_3std/tmos_close', 0.0),
#  ('close_1day_w20_lvl_1.02-1.03', 0.0),
#  ('volume_1day_w20_rsi/volume_1day_w100_rsi', 0.16),
#  ('close_1day_w100_lvl_1.01-1.02', 0.31),
#  ('close_w5_ma/close_w70_ma', 0.33),
#  ('tmos_close_w14_ma/tmos_close_w70_ma', 0.41),
#  ('close_1day/close_1day_w100_ma', 0.45),
#  ('close_w14_max/close', 0.46),
#  ('volume_1day_w5_norm_std/volume_1day_w20_norm_std', 0.57),
#  ('close_w14_min/close_w14_max', 0.78),
#  ('close_w70_lvl_1.01-1.02', 0.88),
#  ('close_1day_w5_norm_std/close_1day_w100_norm_std', 0.92),
#  ('tmos_close_1day_w5_ma_up_3std/tmos_close_1day', 1.03),
#  ('tmos_close_1day_w5_std/tmos_close_1day_w100_std', 1.04),
#  ('close_1day_w3_std/close_1day_w100_std', 1.05),
#  ('close_1day_w20_roc', 1.25),
#  ('close_w70_lvl_1.02-1.03', 1.37),
#  ('tmos_close_1day_w5_norm_std', 1.6),
#  ('volume_1day_w20_rsi', 1.65),
#  ('close_1day_w20_norm_std', 1.69),
#  ('close_w14_ma_low_3std/close', 1.96),
#  ('tmos_close_w14_max/tmos_close', 2.38),
#  ('close_1day_w5_ma/close_1day_w100_ma', 2.71),
#  ('tmos_close/tmos_close_w70_ma', 2.8),
#  ('tmos_close_w70_lvl_1-1.005', 2.95),
#  ('close_w14_mean_abs_pct/close_w70_mean_abs_pct', 3.43),
#  ('tmos_close_1day_w20_rsi', 4.37),
#  ('tmos_close_1day_w5_min/tmos_close_1day_w5_max', 5.56),
#  ('close_1day_w100_lvl_1.02-1.03', 5.81),
#  ('close_1day_w20_min/close_1day_w20_max', 20.34),
#  ('close_w14_mean_abs_pct', 31.75)]

# %%
features_order_to_drop = []
for elem in sorted(zip(features, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1]):
    if elem[1] > 0:
        features_order_to_drop += [elem[0]]
features_order_to_drop
# Out:
# ['volume_1day_w20_rsi/volume_1day_w100_rsi',
#  'close_1day_w100_lvl_1.01-1.02',
#  'close_w5_ma/close_w70_ma',
#  'tmos_close_w14_ma/tmos_close_w70_ma',
#  'close_1day/close_1day_w100_ma',
#  'close_w14_max/close',
#  'volume_1day_w5_norm_std/volume_1day_w20_norm_std',
#  'close_w14_min/close_w14_max',
#  'close_w70_lvl_1.01-1.02',
#  'close_1day_w5_norm_std/close_1day_w100_norm_std',
#  'tmos_close_1day_w5_ma_up_3std/tmos_close_1day',
#  'tmos_close_1day_w5_std/tmos_close_1day_w100_std',
#  'close_1day_w3_std/close_1day_w100_std',
#  'close_1day_w20_roc',
#  'close_w70_lvl_1.02-1.03',
#  'tmos_close_1day_w5_norm_std',
#  'volume_1day_w20_rsi',
#  'close_1day_w20_norm_std',
#  'close_w14_ma_low_3std/close',
#  'tmos_close_w14_max/tmos_close',
#  'close_1day_w5_ma/close_1day_w100_ma',
#  'tmos_close/tmos_close_w70_ma',
#  'tmos_close_w70_lvl_1-1.005',
#  'close_w14_mean_abs_pct/close_w70_mean_abs_pct',
#  'tmos_close_1day_w20_rsi',
#  'tmos_close_1day_w5_min/tmos_close_1day_w5_max',
#  'close_1day_w100_lvl_1.02-1.03',
#  'close_1day_w20_min/close_1day_w20_max',
#  'close_w14_mean_abs_pct']

# %%
cat_features = []

# %%
params
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 2,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.5000000000000001,
#  'bagging_fraction': 0.3500000000000001,
#  'bagging_freq': 1,
#  'lambda_l1': 10,
#  'lambda_l2': 10,
#  'verbose': -1,
#  'metric': 'auc',
#  'early_stopping': 50}

# %%
from IPython.display import clear_output

history_fe = {'features' : [],
           'num_trees' : [],

           'auc_train' : [],
           'auc_valid' : [],
           'auc_test' : [],
           'auc_test2' : [],
           
           'mir_point@1_train' : [],
           'mir_point@1_valid' : [],
           'mir_point@1_test' : [],
           'mir_point@1_test2' : [],
              
           'mir_day@1_train' : [],
           'mir_day@1_valid' : [],
           'mir_day@1_test' : [],
           'mir_day@1_test2' : [],
              
           'mir_month@1_train' : [],
           'mir_month@1_valid' : [],
           'mir_month@1_test' : [],
           'mir_month@1_test2' : [],
          
          }
    
for i in tqdm(range(len(features_order_to_drop))):
    features_fe = features_order_to_drop[i:]

    D_train = lgbm.Dataset(df.loc[mask_train, features_fe], label=df.loc[mask_train, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    D_valid = lgbm.Dataset(df.loc[mask_valid, features_fe], label=df.loc[mask_valid, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    D_test = lgbm.Dataset(df.loc[mask_test, features_fe], label=df.loc[mask_test, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    D_test2 = lgbm.Dataset(df.loc[mask_test2, features_fe], label=df.loc[mask_test2, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    
    D_train.income_rate = df.loc[mask_train, 'income_rate'].values
    D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
    D_test.income_rate = df.loc[mask_test, 'income_rate'].values
    D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

    D_train.time = df.loc[mask_train, 'time'].values
    D_valid.time = df.loc[mask_valid, 'time'].values
    D_test.time = df.loc[mask_test, 'time'].values
    D_test2.time = df.loc[mask_test2, 'time'].values

    model = lgbm.train(params, num_boost_round=2_000, train_set=D_train, valid_sets=[D_valid])
                    
    y_pred_train = model.predict(D_train.data)
    y_pred_valid = model.predict(D_valid.data)
    y_pred_test = model.predict(D_test.data)
    y_pred_test2 = model.predict(D_test2.data)
    
    #history_fe
    history_fe['features'] += [features_fe.copy()]
    history_fe['num_trees'] += [model.num_trees()]

    history_fe['auc_train'] += [roc_auc_score(D_train.label, y_pred_train)]
    history_fe['auc_valid'] += [roc_auc_score(D_valid.label, y_pred_valid)]
    history_fe['auc_test'] += [roc_auc_score(D_test.label, y_pred_test)]
    history_fe['auc_test2'] += [roc_auc_score(D_test2.label, y_pred_test2)]

    threshold1 = np.quantile(y_pred_valid, q=0.99)
      
    history_fe['mir_point@1_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold1)]
    history_fe['mir_point@1_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold1)]
    history_fe['mir_point@1_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold1)]
    history_fe['mir_point@1_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold1)]
    
    history_fe['mir_day@1_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold1)]
    history_fe['mir_day@1_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold1)]
    history_fe['mir_day@1_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold1)]
    history_fe['mir_day@1_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold1)]
    
    history_fe['mir_month@1_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold1)]
    history_fe['mir_month@1_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold1)]
    history_fe['mir_month@1_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold1)]
    history_fe['mir_month@1_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold1)]
                   



    #clear_output()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [00:41<00:00,  1.44s/it]

# %%
df_hst_fe = pd.DataFrame(history_fe)
df_hst_fe
# Out:
#                                              features  num_trees  auc_train  \
# 0   [volume_1day_w20_rsi/volume_1day_w100_rsi, clo...        173   0.709397
# 1   [close_1day_w100_lvl_1.01-1.02, close_w5_ma/cl...        132   0.703698
# 2   [close_w5_ma/close_w70_ma, tmos_close_w14_ma/t...        196   0.711007
# 3   [tmos_close_w14_ma/tmos_close_w70_ma, close_1d...        160   0.707535
# 4   [close_1day/close_1day_w100_ma, close_w14_max/...        130   0.704319
# 5   [close_w14_max/close, volume_1day_w5_norm_std/...        157   0.707028
# 6   [volume_1day_w5_norm_std/volume_1day_w20_norm_...        127   0.702706
# 7   [close_w14_min/close_w14_max, close_w70_lvl_1....        128   0.701594
# 8   [close_w70_lvl_1.01-1.02, close_1day_w5_norm_s...        187   0.708985
# 9   [close_1day_w5_norm_std/close_1day_w100_norm_s...        153   0.706082
# 10  [tmos_close_1day_w5_ma_up_3std/tmos_close_1day...        202   0.709804
# 11  [tmos_close_1day_w5_std/tmos_close_1day_w100_s...        110   0.700233
# 12  [close_1day_w3_std/close_1day_w100_std, close_...        107   0.700000
# 13  [close_1day_w20_roc, close_w70_lvl_1.02-1.03, ...        127   0.701304
# 14  [close_w70_lvl_1.02-1.03, tmos_close_1day_w5_n...         81   0.695456
# 15  [tmos_close_1day_w5_norm_std, volume_1day_w20_...        152   0.702395
# 16  [volume_1day_w20_rsi, close_1day_w20_norm_std,...        127   0.699425
# 17  [close_1day_w20_norm_std, close_w14_ma_low_3st...        116   0.696587
# 18  [close_w14_ma_low_3std/close, tmos_close_w14_m...        111   0.697234
# 19  [tmos_close_w14_max/tmos_close, close_1day_w5_...        108   0.696858
# 20  [close_1day_w5_ma/close_1day_w100_ma, tmos_clo...        128   0.697502
# 21  [tmos_close/tmos_close_w70_ma, tmos_close_w70_...         55   0.687098
# 22  [tmos_close_w70_lvl_1-1.005, close_w14_mean_ab...         28   0.677715
# 23  [close_w14_mean_abs_pct/close_w70_mean_abs_pct...         32   0.677326
# 24  [tmos_close_1day_w20_rsi, tmos_close_1day_w5_m...         29   0.675937
# 25  [tmos_close_1day_w5_min/tmos_close_1day_w5_max...         18   0.673153
# 26  [close_1day_w100_lvl_1.02-1.03, close_1day_w20...         88   0.672755
# 27  [close_1day_w20_min/close_1day_w20_max, close_...        140   0.667200
# 28                           [close_w14_mean_abs_pct]        116   0.649618
#
#     auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 0    0.711710  0.667374   0.657250           0.016577           0.007454
# 1    0.715215  0.669647   0.663970           0.014282           0.007997
# 2    0.713660  0.664821   0.651566           0.016600           0.007724
# 3    0.713853  0.667087   0.657768           0.016358           0.007028
# 4    0.715388  0.665981   0.664589           0.012706           0.006312
# 5    0.714351  0.668184   0.658885           0.015756           0.008318
# 6    0.714367  0.666597   0.664872           0.013152           0.007028
# 7    0.714698  0.667691   0.660693           0.015105           0.006382
# 8    0.714150  0.667283   0.653384           0.017044           0.006689
# 9    0.711603  0.664151   0.656748           0.013949           0.007421
# 10   0.711694  0.662207   0.648805           0.015483           0.006638
# 11   0.710958  0.667746   0.668569           0.013219           0.006154
# 12   0.711818  0.664134   0.666398           0.013283           0.007285
# 13   0.710116  0.665674   0.663020           0.013229           0.008005
# 14   0.709726  0.666690   0.671279           0.011402           0.009135
# 15   0.708452  0.660581   0.646565           0.014308           0.007239
# 16   0.706345  0.662986   0.656262           0.014480           0.006749
# 17   0.705503  0.663066   0.653984           0.013229           0.008804
# 18   0.707101  0.661022   0.658763           0.012823           0.006918
# 19   0.708163  0.659598   0.658574           0.012891           0.005742
# 20   0.695620  0.656047   0.648432           0.011907           0.003650
# 21   0.693219  0.660070   0.669128           0.007212          -0.001947
# 22   0.694652  0.662562   0.664902           0.012474           0.011011
# 23   0.696942  0.661461   0.665630           0.013617           0.003860
# 24   0.691443  0.662518   0.666436           0.016992          -0.003765
# 25   0.689569  0.658627   0.656936           0.004504           0.007663
# 26   0.687510  0.664050   0.660361           0.001930           0.010590
# 27   0.681417  0.662603   0.657934           0.001932           0.007291
# 28   0.660791  0.635898   0.657609           0.000905           0.006663
#
#     mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 0           0.014255           0.007365         0.011060         0.002852
# 1           0.012158           0.007206         0.010513         0.005378
# 2           0.013924           0.008385         0.011427         0.000557
# 3           0.013039           0.007455         0.010419         0.006594
# 4           0.011901           0.005814         0.009332         0.002155
# 5           0.013213           0.006485         0.009051         0.003875
# 6           0.011928           0.006026         0.008404         0.006042
# 7           0.013174           0.008002         0.009460         0.004778
# 8           0.013446           0.006791         0.010277         0.001799
# 9           0.013012           0.005819         0.009508         0.007313
# 10          0.013076           0.004407         0.009557         0.000785
# 11          0.011009           0.005460         0.010127         0.011374
# 12          0.012387           0.007296         0.007596         0.007258
# 13          0.012153           0.004669         0.009256         0.016303
# 14          0.011335           0.005597         0.007635         0.009205
# 15          0.013105           0.002639         0.008436         0.011682
# 16          0.012281           0.003202         0.006675         0.012735
# 17          0.011693           0.002659         0.007486         0.013853
# 18          0.010386           0.002077         0.007600         0.009716
# 19          0.011215           0.002798         0.007175         0.011839
# 20          0.010396          -0.001465         0.007017         0.011836
# 21          0.009966           0.000417         0.004800        -0.001806
# 22          0.012653           0.005632         0.008081         0.005647
# 23          0.014282           0.006166         0.008689         0.010852
# 24          0.013068           0.005006         0.011250        -0.002325
# 25          0.005754           0.002569         0.004612         0.002885
# 26          0.006374           0.005036         0.001841         0.005085
# 27          0.006366           0.004823         0.001247         0.001668
# 28          0.000255           0.013090        -0.000799        -0.000855
#
#     mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 0         0.004454         0.004239           0.076105           0.013134
# 1         0.006314         0.008455           0.086073           0.035773
# 2         0.004673         0.005905           0.087245           0.003135
# 3         0.006349         0.008478           0.077973           0.026988
# 4         0.005957         0.003243           0.092342           0.014335
# 5         0.003704         0.008725           0.076375           0.025773
# 6         0.007617         0.008076           0.075559           0.034006
# 7         0.008717         0.007940           0.067000           0.022002
# 8         0.006614         0.008844           0.078459           0.010126
# 9         0.007632         0.007867           0.088353           0.056124
# 10        0.007640         0.009085           0.086886           0.005625
# 11        0.006280         0.009874           0.092067           0.087286
# 12        0.007741         0.007715           0.059140           0.033423
# 13        0.005882         0.007852           0.075312           0.108433
# 14        0.004938         0.008889           0.054072           0.075355
# 15        0.004083         0.008651           0.063980           0.083673
# 16        0.003675         0.009736           0.044924           0.084700
# 17        0.001569         0.010107           0.059031           0.085051
# 18        0.002785         0.006551           0.050392           0.074565
# 19        0.003976         0.009391           0.044689           0.072687
# 20        0.001542         0.004774           0.049696           0.078724
# 21        0.002906         0.002144           0.030859          -0.012934
# 22       -0.002255        -0.001286           0.004465           0.014445
# 23        0.004479         0.008547           0.004801           0.022208
# 24        0.000989         0.000377           0.003390          -0.002379
# 25        0.001489         0.000504           0.046331           0.045760
# 26        0.002042         0.001447           0.037266           0.072842
# 27        0.002756         0.001475           0.026188           0.029010
# 28        0.001519        -0.003479          -0.014040          -0.016181
#
#     mir_month@1_test  mir_month@1_test2
# 0           0.054694           0.036352
# 1           0.083986           0.091428
# 2           0.057377           0.048440
# 3           0.074707           0.079034
# 4           0.082290           0.033855
# 5           0.049277           0.084583
# 6           0.097425           0.087329
# 7           0.089193           0.071053
# 8           0.077827           0.085740
# 9           0.089804           0.082141
# 10          0.089901           0.088082
# 11          0.077116           0.106777
# 12          0.083166           0.066167
# 13          0.069222           0.070267
# 14          0.055586           0.076235
# 15          0.048050           0.064518
# 16          0.043243           0.087132
# 17          0.017660           0.090452
# 18          0.031344           0.058629
# 19          0.042716           0.091050
# 20          0.014991           0.030262
# 21          0.031220           0.012789
# 22         -0.011535          -0.003357
# 23          0.018333           0.019122
# 24          0.003542           0.000703
# 25          0.027433           0.007897
# 26          0.041799           0.026977
# 27          0.060632           0.029693
# 28          0.026424          -0.037619

# %%
df_hst_fe['features'].loc[9]
# Out:
# ['close_1day_w5_norm_std/close_1day_w100_norm_std',
#  'tmos_close_1day_w5_ma_up_3std/tmos_close_1day',
#  'tmos_close_1day_w5_std/tmos_close_1day_w100_std',
#  'close_1day_w3_std/close_1day_w100_std',
#  'close_1day_w20_roc',
#  'close_w70_lvl_1.02-1.03',
#  'tmos_close_1day_w5_norm_std',
#  'volume_1day_w20_rsi',
#  'close_1day_w20_norm_std',
#  'close_w14_ma_low_3std/close',
#  'tmos_close_w14_max/tmos_close',
#  'close_1day_w5_ma/close_1day_w100_ma',
#  'tmos_close/tmos_close_w70_ma',
#  'tmos_close_w70_lvl_1-1.005',
#  'close_w14_mean_abs_pct/close_w70_mean_abs_pct',
#  'tmos_close_1day_w20_rsi',
#  'tmos_close_1day_w5_min/tmos_close_1day_w5_max',
#  'close_1day_w100_lvl_1.02-1.03',
#  'close_1day_w20_min/close_1day_w20_max',
#  'close_w14_mean_abs_pct']

# %% [markdown]
# # BEST

# %%
features_fe = ['close_1day_w5_norm_std/close_1day_w100_norm_std',
 'tmos_close_1day_w5_ma_up_3std/tmos_close_1day',
 'tmos_close_1day_w5_std/tmos_close_1day_w100_std',
 'close_1day_w3_std/close_1day_w100_std',
 'close_1day_w20_roc',
 'close_w70_lvl_1.02-1.03',
 'tmos_close_1day_w5_norm_std',
 'volume_1day_w20_rsi',
 'close_1day_w20_norm_std',
 'close_w14_ma_low_3std/close',
 'tmos_close_w14_max/tmos_close',
 'close_1day_w5_ma/close_1day_w100_ma',
 'tmos_close/tmos_close_w70_ma',
 'tmos_close_w70_lvl_1-1.005',
 'close_w14_mean_abs_pct/close_w70_mean_abs_pct',
 'tmos_close_1day_w20_rsi',
 'tmos_close_1day_w5_min/tmos_close_1day_w5_max',
 'close_1day_w100_lvl_1.02-1.03',
 'close_1day_w20_min/close_1day_w20_max',
 'close_w14_mean_abs_pct']

params = {'boosting_type': 'gbdt',
 'objective': 'binary',
 'num_leaves': 2,
 'learning_rate': 0.1,
 'feature_fraction': 0.5000000000000001,
 'bagging_fraction': 0.3500000000000001,
 'bagging_freq': 1,
 'lambda_l1': 10,
 'lambda_l2': 10,
 'verbose': -1,
 'metric': 'auc',
   #       'num_iteration' : 153,
 'early_stopping': 50
         }

# %%
target = 'target'
cat_features = []

# %%
def mean_income_rate_point(D_sample, y_pred, threshold=None):
    #mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    score = np.mean(D_sample.income_rate[mask]) - 1
    
    return score

def mean_income_rate_day(D_sample, y_pred, threshold=None):
    #mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup.loc[mask].groupby(pd.Grouper(key='time', freq='D')).income_rate.mean()-1).mean()

    return score
    
def mean_income_rate_month(D_sample, y_pred, threshold=None):
    #mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup.loc[mask].groupby(pd.Grouper(key='time', freq='D')).income_rate.mean()-1).mean() * df_sup.loc[mask, 'time'].dt.date.nunique()
    score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month
    
    return score

# %%
D_train = lgbm.Dataset(df.loc[mask_train, features_fe], label=df.loc[mask_train, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, features_fe], label=df.loc[mask_valid, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, features_fe], label=df.loc[mask_test, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, features_fe], label=df.loc[mask_test2, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)


D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
D_test3 = lgbm.Dataset(df.loc[mask_test3, features_fe], label=df.loc[mask_test3, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
D_test3.time = df.loc[mask_test3, 'time'].values

# %%
model = lgbm.train(params,  num_boost_round=2_000, train_set=D_train, valid_sets=[D_valid])

# %%
#dump_pkl(model, './model.pkl')

# %%
#model = load_pkl('./model.pkl')

# %%
model.num_trees()
# Out:
# 153

# %%
y_pred_train = model.predict(D_train.data)
y_pred_valid = model.predict(D_valid.data)
y_pred_test = model.predict(D_test.data)
y_pred_test2 = model.predict(D_test2.data)


df["y_pred"] = None
df.loc[mask_train, 'y_pred'] = y_pred_train
df.loc[mask_valid, 'y_pred'] = y_pred_valid
df.loc[mask_test, 'y_pred'] = y_pred_test
df.loc[mask_test2, 'y_pred'] = y_pred_test2

roc_auc_score(D_train.label, y_pred_train), roc_auc_score(D_valid.label, y_pred_valid), roc_auc_score(D_test.label, y_pred_test), roc_auc_score(D_test2.label, y_pred_test2)
# Out:
# (0.7060821531142044,
#  0.7116032076369123,
#  0.6641513550922731,
#  0.6567483720160789)

# %%
#(0.6991796450333699, 0.711124788951288, 0.666424281844504, 0.6650550666662738)

# %%
y_pred_test3 = model.predict(D_test3.data)
df.loc[mask_test3, 'y_pred'] = y_pred_test3
roc_auc_score(D_test3.label, y_pred_test3)
# Out:
# 0.5716801495960869

# %%
#свой threshold

q = 0.99

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest')
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# Valid
# result
# LOSE    0.452991
# WIN     0.401709
# DNF     0.145299
# Name: proportion, dtype: float64
# 1.0074211
#
# Test
# result
# WIN     0.655080
# LOSE    0.239305
# DNF     0.105615
# Name: proportion, dtype: float64
# 1.0219364
#
# Test2
# result
# WIN     0.395712
# LOSE    0.354776
# DNF     0.249513
# Name: proportion, dtype: float64
# 1.0099518

# %%
threshold = np.quantile(df.loc[mask_test3, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest3')
print(df.loc[mask_test3&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test3&mask, 'income_rate'].mean())
# Out:
# Test3
# result
# LOSE    0.428246
# WIN     0.380410
# DNF     0.191344
# Name: proportion, dtype: float64
# 1.008809

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 16:00:00'),
#  Timedelta('0 days 20:00:00'),
#  Timedelta('1 days 00:30:00'))

# %%
df.loc[mask_test3&mask, 'delta_time'].median()
# Out:
# Timedelta('1 days 01:00:00')

# %%
#общий threshold

q = 0.99

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
print(f'threshokd = {threshold}')

mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print("\nTest")
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print('\nTetst2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# threshokd = 0.3668169577019395
#
# Valid
# result
# LOSE    0.452991
# WIN     0.401709
# DNF     0.145299
# Name: proportion, dtype: float64
# 1.0074211
#
# Test
# result
# WIN     0.483561
# LOSE    0.387062
# DNF     0.129377
# Name: proportion, dtype: float64
# 1.0130118
#
# Tetst2
# result
# LOSE    0.440981
# WIN     0.320865
# DNF     0.238155
# Name: proportion, dtype: float64
# 1.0058191

# %%
df.loc[mask_valid&mask, 'time'].dt.date.nunique(), df.loc[mask_test&mask, 'time'].dt.date.nunique(),  df.loc[mask_test2&mask, 'time'].dt.date.nunique()
# Out:
# (15, 23, 28)

# %%
print('\nTetst3')
print(df.loc[mask_test3&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test3&mask, 'income_rate'].mean())
# Out:
# Tetst3
# result
# LOSE    0.414116
# WIN     0.350340
# DNF     0.235544
# Name: proportion, dtype: float64
# 1.0080273

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 17:00:00'),
#  Timedelta('0 days 20:00:00'),
#  Timedelta('1 days 02:00:00'))

# %%
df.loc[mask_test3&mask, 'delta_time'].median()
# Out:
# Timedelta('1 days 03:30:00')

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.99)
threshold
# Out:
# 0.3668169577019395

# %%
mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_point(D_test, y_pred_test, threshold=threshold), mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.007421135902404785, 0.013011813163757324, 0.005819082260131836)

# %%
mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_day(D_test, y_pred_test, threshold=threshold), mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.007313192, 0.0076315273, 0.007867421)

# %%
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.05612449590549913, 0.08980355333796768, 0.0821412093305992)

# %%
mean_income_rate_point(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.008027315139770508

# %%
mean_income_rate_day(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.006995219

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.10464847333729267

# %%
df.loc[mask_test2&mask, 'ticker'].unique()
# Out:
# array(['MVID', 'SPBE', 'MTLRP', 'SFIN', 'FEES', 'FESH', 'KROT', 'VKCO',
#        'MRKY', 'SELG', 'SGZH', 'CHMK', 'YAKG', 'RKKE', 'MRKZ', 'CNTL',
#        'PLZL', 'AFKS', 'UNKL', 'APTK', 'NSVZ', 'LIFE', 'RNFT', 'VRSB',
#        'UWGN', 'TGKN', 'ABIO', 'WUSH', 'RTKMP', 'GTRK', 'NLMK', 'CNTLP',
#        'BLNG', 'ALRS', 'VSMO', 'LSNG', 'TRNFP', 'MGNT', 'NKHP', 'TGKB',
#        'ROLO', 'IRKT', 'MTLR', 'RUAL', 'KLSB', 'SIBN', 'MSTT', 'KAZTP',
#        'DVEC', 'KAZT', 'AMEZ', 'MRKU', 'TRMK', 'VEON-RX', 'CHMF', 'RTKM',
#        'SMLT', 'LNZLP', 'UNAC', 'PIKK', 'TGKBP', 'POSI', 'KZOS', 'MRKS',
#        'MAGN', 'PRFN', 'BANEP', 'AQUA', 'RBCM'], dtype=object)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_82125/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#          count  income_rate
# ticker
# LIFE       1.0     0.980000
# VSMO       1.0     1.040000
# TRNFP      1.0     1.040000
# APTK       1.0     0.980000
# RUAL       1.0     1.040000
# LNZLP      1.0     1.024691
# MRKU       2.0     1.040000
# FEES       2.0     0.992976
# MRKY       2.0     1.010000
# CHMF       2.0     1.014075
# CHMK       3.0     0.980000
# SFIN       4.0     1.012154
# AQUA       5.0     1.022592
# TRMK       5.0     1.023450
# KAZT       6.0     1.040000
# PLZL       6.0     0.994243
# MRKS       6.0     1.015278
# UNAC       9.0     1.040000
# SIBN      10.0     0.992316
# NKHP      11.0     1.010497
# RTKMP     11.0     1.007528
# KZOS      12.0     1.024946
# RKKE      12.0     1.009664
# VEON-RX   12.0     1.020000
# SPBE      13.0     1.026154
# BANEP     14.0     1.015752
# CNTL      15.0     1.011312
# ALRS      15.0     0.987880
# CNTLP     15.0     1.004455
# MSTT      17.0     1.026068
# KAZTP     18.0     1.004609
# SELG      18.0     1.006667
# MAGN      19.0     0.986183
# RTKM      22.0     1.000546
# DVEC      22.0     1.020909
# RNFT      22.0     0.995235
# ABIO      23.0     1.011304
# VRSB      24.0     0.985000
# KLSB      24.0     0.992500
# MGNT      24.0     1.009098
# POSI      24.0     0.982786
# NLMK      24.0     1.001244
# KROT      28.0     0.995000
# YAKG      32.0     1.015628
# PRFN      32.0     1.006495
# VKCO      33.0     1.003152
# FESH      35.0     1.008227
# LSNG      38.0     1.009702
# BLNG      42.0     0.997382
# UNKL      50.0     0.999783
# UWGN      51.0     1.011500
# NSVZ      52.0     1.008856
# GTRK      52.0     1.003857
# AFKS      53.0     0.986381
# MVID      59.0     0.999246
# WUSH      70.0     1.009345
# MTLR      72.0     0.998281
# ROLO      76.0     1.011300
# AMEZ      77.0     1.002003
# MTLRP     79.0     0.999628
# RBCM      82.0     1.004342
# MRKZ      82.0     1.004444
# PIKK      84.0     1.005039
# SGZH     100.0     1.016783
# TGKBP    115.0     1.013660
# TGKB     120.0     0.998850
# TGKN     131.0     1.002638
# SMLT     136.0     1.009559
# IRKT     146.0     1.014416

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test3&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_82125/2708990562.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test3&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#          count  income_rate
# ticker
# LSNG       1.0     0.980000
# RTKM       3.0     1.040000
# SGZH       4.0     0.980000
# AMEZ       6.0     0.989779
# BLNG       6.0     0.992968
# TRNFP      7.0     1.027784
# SELG       7.0     0.983664
# TRMK      10.0     1.016943
# MAGN      11.0     1.005722
# AFKS      12.0     1.031249
# DVEC      13.0     1.040000
# MSTT      13.0     1.038969
# CHMK      13.0     1.001441
# KROT      13.0     1.028832
# MRKS      14.0     1.005714
# MRKU      14.0     0.995586
# VRSB      15.0     0.986807
# MTLRP     16.0     1.028750
# NSVZ      20.0     0.991919
# HEAD      21.0     0.991702
# MRKY      22.0     1.004628
# MTLR      22.0     0.994582
# PRFN      22.0     0.985454
# RBCM      23.0     1.003646
# RTKMP     24.0     1.021121
# WUSH      28.0     1.037857
# CBOM      28.0     1.013529
# VKCO      29.0     1.000690
# ROLO      34.0     1.020241
# MVID      34.0     0.982975
# TGKN      37.0     1.010729
# TGKB      40.0     1.008265
# TGKBP     41.0     1.018229
# IRKT      42.0     1.011439
# NKHP      45.0     1.019026
# LNZL      58.0     0.998894
# RNFT      60.0     1.005753
# GTRK      63.0     0.994373
# MRKZ      64.0     1.010130
# SMLT      66.0     1.015390
# VEON-RX   79.0     1.007934
# PIKK      96.0     1.006469

# %%
#df[mask_test3&mask&(df['ticker'] == 'SMLT')]

# %%
# dump_pkl(y_pred_valid, './bst_mdl/y_pred_valid.pkl')
# dump_pkl(y_pred_test, './bst_mdl/y_pred_test.pkl')
# dump_pkl(y_pred_test2, './bst_mdl/y_pred_test2.pkl')

# dump_pkl(y_pred_test3, './bst_mdl/y_pred_test3.pkl')

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features_fe, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1])
# Out:
# [('tmos_close_1day_w5_ma_up_3std/tmos_close_1day', 0.73),
#  ('close_1day_w3_std/close_1day_w100_std', 0.78),
#  ('close_1day_w5_norm_std/close_1day_w100_norm_std', 0.91),
#  ('tmos_close_1day_w5_norm_std', 0.98),
#  ('tmos_close_1day_w5_std/tmos_close_1day_w100_std', 1.24),
#  ('close_1day_w20_roc', 1.34),
#  ('volume_1day_w20_rsi', 1.75),
#  ('close_w70_lvl_1.02-1.03', 1.79),
#  ('tmos_close_w14_max/tmos_close', 2.46),
#  ('tmos_close/tmos_close_w70_ma', 2.63),
#  ('close_1day_w5_ma/close_1day_w100_ma', 2.94),
#  ('tmos_close_w70_lvl_1-1.005', 3.23),
#  ('close_w14_mean_abs_pct/close_w70_mean_abs_pct', 3.33),
#  ('close_w14_ma_low_3std/close', 4.19),
#  ('tmos_close_1day_w20_rsi', 4.21),
#  ('close_1day_w100_lvl_1.02-1.03', 5.62),
#  ('tmos_close_1day_w5_min/tmos_close_1day_w5_max', 6.38),
#  ('close_1day_w20_min/close_1day_w20_max', 9.36),
#  ('close_1day_w20_norm_std', 13.41),
#  ('close_w14_mean_abs_pct', 32.74)]

# %% [markdown]
# ### -1. TMP

# %% [markdown]
# #### 1. AUC

# %%
mask_data = df['y_pred'].notnull()
plt.figure(figsize=(10, 3))
(df.loc[mask_data, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
                                                                            roc_auc_score(x['target'], x['y_pred'])
                                                                                                          ) - 0.5).plot.bar()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_82125/266340296.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_data, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
# <Axes: xlabel='time'>

# %% [markdown]
# #### 2. WIN

# %%
np.quantile(df.loc[mask_train, 'y_pred'], q=q), np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
# Out:
# (0.3872957770970814, 0.3668169577019395)

# %%
q = 0.99
col_target = 'target'

mask_last_bin = df['y_pred'] > np.quantile(df.loc[mask_train, 'y_pred'], q=q)

mask_data = df['y_pred'].notnull()
plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
                                                                            x[col_target].mean()).plot.bar()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_82125/1725577466.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
# <Axes: xlabel='time'>

# %% [markdown]
# #### 3. income_rate

# %%
q = 0.99
col_target = 'income_rate'

mask_last_bin = df['y_pred'] > np.quantile(df.loc[mask_valid, 'y_pred'], q=q)

mask_data = df['y_pred'].notnull()
plt.figure(figsize=(10, 3))
(df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
                                                                            x[col_target].mean()) -1).plot.bar()
plt.grid()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_82125/7551147.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:

# %% [markdown]
# #### 4. Отложенная выборка

# %%
#distibution in time
#win
col_pred = 'y_pred'
q = 0.99
freq='D'

mask_data = mask_valid|mask_test|mask_test2|mask_test3

threshold = np.quantile(df.loc[mask_valid, col_pred], q=q)
mask_last_bin = df[col_pred] > threshold


plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.mean().plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='Success Rate')
plt.legend()
plt.show()


#distibution in time
#income_rate
print('INCOME_RATE')

plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='INCOME_RATE')
plt.legend()
plt.show()
# Out:
# INCOME_RATE

# %%
#y_test3

# %%
#distibution in time
#win
col_pred = 'y_pred'
q = 0.99
freq='D'


mask_data = mask_test3


threshold = np.quantile(df.loc[mask_valid, col_pred], q=q)
mask_last_bin = df[col_pred] > threshold


plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.mean().plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='Success Rate')
plt.legend()
plt.show()


#distibution in time
#income_rate
print('INCOME_RATE')

plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='INCOME_RATE')
plt.legend()
plt.show()
# Out:
# INCOME_RATE

# %%
#mean_income_rate_by_day
(df.loc[mask_valid&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean(), (df.loc[mask_test&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean(), (df.loc[mask_test2&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean()
# Out:
# (0.007313192, 0.0076315273, 0.007867421)

# %%
df.loc[mask_valid&mask_last_bin, 'time'].dt.date.nunique(), df.loc[mask_test&mask_last_bin, 'time'].dt.date.nunique(),  df.loc[mask_test2&mask_last_bin, 'time'].dt.date.nunique()
# Out:
# (15, 23, 28)

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.99)

# %%
#sum_income_rate
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.05612449590549913, 0.08980355333796768, 0.0821412093305992)

# %%
#test3
(df.loc[mask_test3&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean()
# Out:
# 0.006995219

# %%
df.loc[mask_test3&mask_last_bin, 'time'].dt.date.nunique()
# Out:
# 17

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.10464847333729267

# %%
mask_data = mask_valid | mask_test | mask_test2

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_82125/1640586492.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_data&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.008424808581670126

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_valid&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_82125/1656526771.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_valid&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.005035674571990967

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_test&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_82125/192763211.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_test&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.009299286033796228

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_test2&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_82125/1559495362.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_test2&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.009522095322608948

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_test3&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_82125/2683039865.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_test3&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.006551476085887235

# %% [markdown]
# ### Обучить на всем (эксперимент неудачен)

# %%
mask_data = mask_train | mask_valid | mask_test | mask_test2

D_data = lgbm.Dataset(df.loc[mask_data, features_fe], label=df.loc[mask_data, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)


D_data.income_rate = df.loc[mask_data, 'income_rate'].values

D_data.time = df.loc[mask_data, 'time'].values

# %%
D_test3 = lgbm.Dataset(df.loc[mask_test3, features_fe], label=df.loc[mask_test3, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
D_test3.time = df.loc[mask_test3, 'time'].values

# %%
features_fe = ['close_1day_w5_norm_std/close_1day_w100_norm_std',
 'tmos_close_1day_w5_ma_up_3std/tmos_close_1day',
 'tmos_close_1day_w5_std/tmos_close_1day_w100_std',
 'close_1day_w3_std/close_1day_w100_std',
 'close_1day_w20_roc',
 'close_w70_lvl_1.02-1.03',
 'tmos_close_1day_w5_norm_std',
 'volume_1day_w20_rsi',
 'close_1day_w20_norm_std',
 'close_w14_ma_low_3std/close',
 'tmos_close_w14_max/tmos_close',
 'close_1day_w5_ma/close_1day_w100_ma',
 'tmos_close/tmos_close_w70_ma',
 'tmos_close_w70_lvl_1-1.005',
 'close_w14_mean_abs_pct/close_w70_mean_abs_pct',
 'tmos_close_1day_w20_rsi',
 'tmos_close_1day_w5_min/tmos_close_1day_w5_max',
 'close_1day_w100_lvl_1.02-1.03',
 'close_1day_w20_min/close_1day_w20_max',
 'close_w14_mean_abs_pct']

params = {'boosting_type': 'gbdt',
 'objective': 'binary',
 'num_leaves': 2,
 'learning_rate': 0.1,
 'feature_fraction': 0.5000000000000001,
 'bagging_fraction': 0.3500000000000001,
 'bagging_freq': 1,
 'lambda_l1': 10,
 'lambda_l2': 10,
 'verbose': -1,
 #'metric': 'auc',
          'num_iteration' : 153,
# 'early_stopping': 50
         }

model = lgbm.train(params,  num_boost_round=2_000, train_set=D_data)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")

# %%
model.num_trees()
# Out:
# 153

# %%
y_pred_data= model.predict(D_data.data)


df["y_pred"] = None
df.loc[mask_data, 'y_pred'] = y_pred_data

roc_auc_score(D_data.label, y_pred_data)
# Out:
# 0.6975954151975302

# %%
y_pred_test3 = model.predict(D_test3.data)
df.loc[mask_test3, 'y_pred'] = y_pred_test3
roc_auc_score(D_test3.label, y_pred_test3)
# Out:
# 0.5597503841597529

# %%
threshold = 0.3668169577019395#np.quantile(df.loc[mask_data, 'y_pred'], q=0.99)
threshold
#0.3668169577019395
# Out:
# 0.3668169577019395

# %%
mean_income_rate_point(D_data, y_pred_data, threshold=threshold)
# Out:
# 0.015038490295410156

# %%
mean_income_rate_day(D_data, y_pred_data, threshold=threshold)
# Out:
# 0.0070446134

# %%
mean_income_rate_month(D_data, y_pred_data, threshold=threshold)
# Out:
# 0.053166893293272774

# %%
mean_income_rate_point(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.010228395462036133

# %%
mean_income_rate_day(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.010330456

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.09090801551938058

# %%
#distibution in time
#win
col_pred = 'y_pred'
q = 0.99
freq='D'


mask_data = mask_test3


#threshold = np.quantile(df.loc[mask_valid, col_pred], q=q)
mask_last_bin = df[col_pred] > threshold


plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.mean().plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='Success Rate')
plt.legend()
plt.show()


#distibution in time
#income_rate
print('INCOME_RATE')

plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='INCOME_RATE')
plt.legend()
plt.show()
# Out:
# INCOME_RATE
