# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import math
import gc

from sklearn.metrics import roc_auc_score

import lightgbm as lgbm

import pickle
def dump_pkl(data, filename):
  with open(filename, 'wb') as handle:
    pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)

def load_pkl(filename):
  with open(filename, 'rb') as handle:
    data = pickle.load(handle)
  return data

# %%
df = load_pkl('./data/feat_engin/lgbm/data_1hour_1day.pkl')

# %%
df.shape
# Out:
# (1006243, 610)

# %%
df.head()
# Out:
#                  time  close ticker  index_1day result      delta_time  \
# 0 2022-05-05 10:00:00  31.24   AFLT         0.0   LOSE 1 days 00:00:00
# 1 2022-05-05 11:00:00  30.98   AFLT         0.0   LOSE 1 days 01:00:00
# 2 2022-05-05 12:00:00  30.92   AFLT         0.0   LOSE 1 days 00:00:00
# 3 2022-05-05 13:00:00  30.92   AFLT         0.0   LOSE 0 days 23:00:00
# 4 2022-05-05 14:00:00  31.00   AFLT         0.0   LOSE 0 days 22:00:00
#
#    income_rate  res_price  res_ind  close_w1_roc  ...  \
# 0         0.98  30.379999       18      0.001282  ...
# 1         0.98  30.280001       20     -0.008323  ...
# 2         0.98  30.280001       20     -0.001937  ...
# 3         0.98  30.280001       20      0.000000  ...
# 4         0.98  30.280001       20      0.002587  ...
#
#    tmos_close_1day_w100_ma_up_3std/tmos_close_1day  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    close_1day_w3_min/close_1day_w3_max  volume_1day_w3_min/volume_1day_w3_max  \
# 0                                  1.0                                    1.0
# 1                                  1.0                                    1.0
# 2                                  1.0                                    1.0
# 3                                  1.0                                    1.0
# 4                                  1.0                                    1.0
#
#    tmos_close_1day_w3_min/tmos_close_1day_w3_max  \
# 0                                            1.0
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
#
#    close_1day_w5_min/close_1day_w5_max  volume_1day_w5_min/volume_1day_w5_max  \
# 0                                  1.0                                    1.0
# 1                                  1.0                                    1.0
# 2                                  1.0                                    1.0
# 3                                  1.0                                    1.0
# 4                                  1.0                                    1.0
#
#    tmos_close_1day_w5_min/tmos_close_1day_w5_max  \
# 0                                            1.0
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
#
#    close_1day_w20_min/close_1day_w20_max  \
# 0                                    1.0
# 1                                    1.0
# 2                                    1.0
# 3                                    1.0
# 4                                    1.0
#
#    volume_1day_w20_min/volume_1day_w20_max  \
# 0                                      1.0
# 1                                      1.0
# 2                                      1.0
# 3                                      1.0
# 4                                      1.0
#
#    tmos_close_1day_w20_min/tmos_close_1day_w20_max
# 0                                              1.0
# 1                                              1.0
# 2                                              1.0
# 3                                              1.0
# 4                                              1.0
#
# [5 rows x 610 columns]

# %%
df['result'].value_counts(normalize=True)
# Out:
# result
# DNF     0.470228
# LOSE    0.361896
# WIN     0.167876
# Name: proportion, dtype: float64

# %%
df['income_rate'].quantile(q=[0, 0.01]+np.arange(0.1, 1, 0.1).tolist()+[0.99, 1])
# Out:
# 0.00    0.980000
# 0.01    0.980000
# 0.10    0.980000
# 0.20    0.980000
# 0.30    0.980000
# 0.40    0.988014
# 0.50    0.996850
# 0.60    1.003813
# 0.70    1.012367
# 0.80    1.026706
# 0.90    1.040000
# 0.99    1.040000
# 1.00    1.040000
# Name: income_rate, dtype: float64

# %% [markdown]
# ## CHANGE TARGET

# %%
def get_target(df_all, ind, val_first, val_second, points_to_wait):
    #цель - достичь val_second, не достигнув val_first

    ind_end = min(ind+points_to_wait+1, df_all.shape[0])
    
    df = df_all.iloc[ind:ind_end].copy()
    
    mask_stock = np.array(df['ticker'] == df['ticker'].iloc[0])
    df = df.loc[mask_stock, :]

    start_price = df['close'].iloc[0]
    
    if val_first < val_second:                                 
        mask_val_first = np.array(df['close'] < val_first)
        mask_val_second = np.array(df['close'] > val_second)
    else: #short game
        mask_val_first = np.array(df['close'] > val_first)
        mask_val_second = np.array(df['close'] < val_second)

    
    if (mask_val_first.sum() == 0) & (mask_val_second.sum() == 0):

        ind_end = df.shape[0]-1
        delta_time = df['time'].iloc[ind_end] - df['time'].iloc[0]
        res_price = df['close'].iloc[ind_end]
        if val_first < val_second:
            income_rate = res_price/start_price
        else: #short game
            income_rate = (2*start_price-res_price)/start_price
        return 'DNF', delta_time, income_rate, res_price, ind_end+ind
        
    if (mask_val_first.sum() == 0) & (mask_val_second.sum() != 0):
        ind_val_second = np.argwhere(mask_val_second).ravel()[0]
        delta_time = df['time'].iloc[ind_val_second] - df['time'].iloc[0]
        res_price = df['close'].iloc[ind_val_second]
        if val_first < val_second:
            income_rate = res_price/start_price
        else: #short game
            income_rate = (2*start_price-res_price)/start_price
        return 'WIN', delta_time, income_rate, res_price, ind_val_second+ind
        
    if (mask_val_first.sum() != 0) & (mask_val_second.sum() == 0):
        ind_val_first = np.argwhere(mask_val_first).ravel()[0]
        delta_time = df['time'].iloc[ind_val_first] - df['time'].iloc[0]
        res_price = df['close'].iloc[ind_val_first]
        if val_first < val_second:
            income_rate = res_price/start_price
        else: #short game
            income_rate = (2*start_price-res_price)/start_price
        return 'LOSE', delta_time, income_rate, res_price, ind_val_first+ind

    if (mask_val_first.sum() != 0) & (mask_val_second.sum() != 0):
        ind_val_first = np.argwhere(mask_val_first).ravel()[0]
        ind_val_second = np.argwhere(mask_val_second).ravel()[0]
        if ind_val_first < ind_val_second:
            delta_time = df['time'].iloc[ind_val_first] - df['time'].iloc[0]
            res_price = df['close'].iloc[ind_val_first]
            if val_first < val_second:
                income_rate = res_price/start_price
            else: #short game
                income_rate = (2*start_price-res_price)/start_price
            return 'LOSE', delta_time, income_rate, res_price, ind_val_first+ind
        if ind_val_first > ind_val_second:
            delta_time = df['time'].iloc[ind_val_second] - df['time'].iloc[0]
            res_price = df['close'].iloc[ind_val_second]
            if val_first < val_second:
                income_rate = res_price/start_price
            else:  #short game
                income_rate = (2*start_price-res_price)/start_price
            return 'WIN', delta_time, income_rate, res_price, ind_val_second+ind


def get_df_target(df, indx, percent_first=None, percent_second=None, points_to_wait=None):
    times = []
    results = []
    delta_times = []
    income_rates = []
    closes = []
    tickers = []
    res_prices = []
    res_inds = []
    
    #for ind in indx:
    for ind in tqdm(indx):
        time = df['time'].iloc[ind]
        close = df['close'].iloc[ind]
        ticker = df['ticker'].iloc[ind]
        
        val_first = df['close'].iloc[ind] * percent_first
        val_second = df['close'].iloc[ind] * percent_second
        result, delta_time, income_rate, res_price, res_ind = get_target(df, ind, val_first, val_second, points_to_wait)
        
        times += [time]
        closes += [close]
        tickers += [ticker]
        results += [result]
        delta_times += [delta_time]
        income_rates += [income_rate]
        res_prices += [res_price]
        res_inds += [res_ind]
        

    df_result = pd.DataFrame({'ind' : indx,
                              'time' : times,
                              'close' : closes,
                              'result' : results,
                              'ticker' : tickers, 
                              'delta_time' : delta_times,
                              'income_rate' : income_rates,
                              'res_price' : res_prices,
                              'res_ind' : res_inds
                             })
    return df_result

# %%
df_result = load_pkl('./data/feat_engin/lgbm/df_result_wait_14_2days.pkl')
df_result = df_result[['time', 'close', 'ticker']]
df_result
# Out:
#                        time   close ticker
# 0       2022-05-04 10:00:00  32.100   AFLT
# 1       2022-05-04 11:00:00  31.380   AFLT
# 2       2022-05-04 12:00:00  31.800   AFLT
# 3       2022-05-04 13:00:00  31.360   AFLT
# 4       2022-05-04 14:00:00  31.540   AFLT
# ...                     ...     ...    ...
# 1007376 2025-01-29 19:00:00  11.305   RBCM
# 1007377 2025-01-29 20:00:00  11.335   RBCM
# 1007378 2025-01-29 21:00:00  11.335   RBCM
# 1007379 2025-01-29 22:00:00  11.235   RBCM
# 1007380 2025-01-29 23:00:00  11.265   RBCM
#
# [1007381 rows x 3 columns]

# %%
inds = np.arange(df_result.shape[0])
inds.shape
# Out:
# (1007381,)

# %%
df_result = get_df_target(df_result, inds, percent_first=1.005, percent_second=0.99, points_to_wait=14*1)
df_result["income_rate"] = np.maximum(df_result["income_rate"], 0.995)
df_result["income_rate"] = np.minimum(df_result["income_rate"], 1.01)
# Out:
# 100%|█████████████████████████████████████████████████████████████| 1007381/1007381 [04:04<00:00, 4119.74it/s]

# %%
df_result['result'].value_counts(normalize=True)
# Out:
# result
# LOSE    0.541746
# WIN     0.346329
# DNF     0.111925
# Name: proportion, dtype: float64

# %%
df_result['income_rate'].quantile(q=[0, 0.01]+np.arange(0.1, 1, 0.1).tolist()+[0.99, 1])
# Out:
# 0.00    0.99500
# 0.01    0.99500
# 0.10    0.99500
# 0.20    0.99500
# 0.30    0.99500
# 0.40    0.99500
# 0.50    0.99500
# 0.60    1.00249
# 0.70    1.01000
# 0.80    1.01000
# 0.90    1.01000
# 0.99    1.01000
# 1.00    1.01000
# Name: income_rate, dtype: float64

# %%
(df_result['ind'] == df_result.index).all()
# Out:
# True

# %%
df_result = df_result[['time','result', 'ticker', 'delta_time', 'income_rate',
       'res_price', 'res_ind']]

# %%
df.shape
# Out:
# (1006243, 613)

# %%
#join
df = df[df.columns[~df.columns.isin(['result', 'delta_time', 'income_rate', 'res_price', 'res_ind'])]].merge(
    df_result, how='inner', on=['time', 'ticker'])
df.shape
# Out:
# (1006243, 613)

# %% [markdown]
# ### 1. train/valid/test/test2 split

# %%
df["income_rate"] -= 0.001

# %%
df['target'] = (df['result'] == 'WIN').astype(int)

# %%
df[['time', 'target']].groupby(pd.Grouper(key='time', freq='ME')).target.count().plot.bar()
# Out:
# <Axes: xlabel='time'>

# %%
df[['time', 'target']].groupby(pd.Grouper(key='time', freq='ME')).target.mean().plot.bar()
# Out:
# <Axes: xlabel='time'>

# %%
(df[['time', 'income_rate']].groupby(pd.Grouper(key='time', freq='ME')).income_rate.mean()-1).plot.bar()
# Out:
# <Axes: xlabel='time'>

# %%
pd.set_option('display.max_rows', 150)
df[['ticker', 'target']].groupby('ticker').target.mean().sort_values()
# Out:
# ticker
# LKOH       0.234678
# SBERP      0.235855
# AKRN       0.237686
# SBER       0.241365
# IRAO       0.244008
# PHOR       0.246848
# TATNP      0.249629
# TRNFP      0.258947
# TATN       0.259510
# MTSS       0.267246
# MOEX       0.269153
# SNGSP      0.271774
# GAZP       0.276172
# RTKM       0.283035
# ROSN       0.285487
# CBOM       0.286384
# HYDR       0.295652
# RTKMP      0.298439
# SIBN       0.303199
# BELU       0.303323
# ALRS       0.304785
# PLZL       0.306754
# MSRS       0.307562
# POSI       0.308120
# GMKN       0.308882
# CHMF       0.311633
# LSNGP      0.316720
# NVTK       0.318427
# VTBR       0.318720
# MSNG       0.318771
# MAGN       0.321829
# AFLT       0.321996
# YDEX       0.322320
# RUAL       0.323090
# MGNT       0.323206
# NLMK       0.325217
# OGKB       0.325690
# PMSB       0.327093
# MRKP       0.329684
# BANE       0.330162
# MRKC       0.330526
# AFKS       0.331037
# UPRO       0.331290
# BSPB       0.331309
# BANEP      0.331726
# SNGS       0.332485
# GCHE       0.334276
# T          0.335021
# PIKK       0.335135
# AQUA       0.336679
# NKNCP      0.338755
# KRKNP      0.340219
# MDMG       0.340701
# KAZT       0.341055
# FEES       0.344396
# APTK       0.345026
# FLOT       0.346387
# SMLT       0.350579
# LENT       0.351439
# MVID       0.352314
# VSMO       0.352997
# SFIN       0.354434
# ELFV       0.354952
# SGZH       0.354963
# SELG       0.354983
# VKCO       0.356187
# TGKA       0.356345
# RENI       0.356441
# RASP       0.356991
# LSRG       0.358674
# ENPG       0.358855
# PMSBP      0.359960
# ABRD       0.362543
# TTLK       0.364212
# KZOS       0.365398
# NMTP       0.368394
# KAZTP      0.368657
# AMEZ       0.371143
# NKNC       0.371771
# MRKU       0.372853
# MRKV       0.377000
# KMAZ       0.377547
# HEAD       0.378746
# YAKG       0.379761
# KZOSP      0.382083
# FESH       0.382834
# WUSH       0.384221
# MTLR       0.384772
# CNTL       0.386878
# TRMK       0.387511
# MRKZ       0.388047
# RBCM       0.388889
# MTLRP      0.389917
# KLSB       0.391279
# UNKL       0.393123
# ROLO       0.393336
# LNZLP      0.393417
# CNTLP      0.393485
# GEMC       0.393547
# SVAV       0.393630
# BLNG       0.394429
# MRKS       0.395065
# TGKN       0.397467
# NKHP       0.397835
# SPBE       0.398795
# LNZL       0.399075
# LSNG       0.399433
# VRSB       0.400204
# LIFE       0.402003
# RNFT       0.403323
# CHMK       0.403761
# MRKY       0.405868
# RKKE       0.406535
# MSTT       0.410753
# MGTSP      0.410835
# ABIO       0.411473
# DVEC       0.414061
# VEON-RX    0.414214
# UNAC       0.417315
# NSVZ       0.417954
# TGKBP      0.418591
# TGKB       0.418951
# KROT       0.419028
# PRFN       0.419350
# GTRK       0.423740
# IRKT       0.431961
# UWGN       0.445803
# Name: target, dtype: float64

# %%
df[['ticker', 'income_rate']].groupby('ticker').income_rate.mean().sort_values()
# Out:
# ticker
# IRAO       0.999289
# AKRN       0.999306
# TATN       0.999372
# SBERP      0.999388
# SBER       0.999396
# MSRS       0.999404
# TATNP      0.999432
# MOEX       0.999438
# BANE       0.999456
# PMSB       0.999476
# MRKC       0.999487
# LKOH       0.999508
# SNGSP      0.999522
# CBOM       0.999547
# CHMF       0.999557
# ROSN       0.999565
# PLZL       0.999586
# MRKP       0.999586
# POSI       0.999599
# PHOR       0.999617
# GCHE       0.999647
# LSNGP      0.999648
# MTSS       0.999652
# MSNG       0.999675
# YDEX       0.999686
# BANEP      0.999691
# NLMK       0.999699
# ALRS       0.999716
# MDMG       0.999725
# SIBN       0.999751
# AFKS       0.999752
# PMSBP      0.999769
# RENI       0.999786
# RTKMP      0.999807
# NKNCP      0.999808
# BELU       0.999810
# RTKM       0.999812
# BSPB       0.999817
# AFLT       0.999819
# SNGS       0.999831
# TRNFP      0.999868
# SFIN       0.999870
# OGKB       0.999880
# KAZT       0.999884
# TTLK       0.999896
# MAGN       0.999911
# KRKNP      0.999968
# MVID       0.999969
# NVTK       0.999971
# PIKK       0.999978
# GMKN       0.999985
# HYDR       0.999986
# MRKV       0.999987
# T          0.999997
# LSRG       0.999998
# FEES       1.000000
# MGNT       1.000000
# KZOS       1.000011
# ABRD       1.000017
# RASP       1.000017
# RUAL       1.000022
# KLSB       1.000029
# KAZTP      1.000039
# MRKZ       1.000042
# MRKU       1.000050
# RBCM       1.000056
# LENT       1.000059
# UPRO       1.000075
# HEAD       1.000082
# FLOT       1.000083
# TGKA       1.000097
# CNTL       1.000101
# VKCO       1.000106
# NKNC       1.000109
# VTBR       1.000110
# NMTP       1.000138
# ELFV       1.000139
# AMEZ       1.000139
# AQUA       1.000140
# SELG       1.000142
# GAZP       1.000161
# GEMC       1.000202
# BLNG       1.000205
# TGKN       1.000209
# YAKG       1.000214
# MTLRP      1.000220
# MRKS       1.000230
# MRKY       1.000242
# ENPG       1.000247
# KZOSP      1.000251
# FESH       1.000266
# APTK       1.000270
# MTLR       1.000286
# LSNG       1.000292
# SMLT       1.000312
# VRSB       1.000312
# ROLO       1.000331
# UNKL       1.000340
# SVAV       1.000380
# SGZH       1.000386
# NKHP       1.000396
# TGKB       1.000402
# DVEC       1.000412
# RNFT       1.000412
# CNTLP      1.000412
# WUSH       1.000417
# CHMK       1.000419
# TRMK       1.000432
# MSTT       1.000444
# LIFE       1.000452
# NSVZ       1.000459
# SPBE       1.000478
# RKKE       1.000479
# TGKBP      1.000519
# KROT       1.000520
# MGTSP      1.000533
# KMAZ       1.000544
# LNZLP      1.000565
# ABIO       1.000602
# UNAC       1.000623
# PRFN       1.000624
# VEON-RX    1.000632
# GTRK       1.000650
# LNZL       1.000671
# VSMO       1.000786
# IRKT       1.000827
# UWGN       1.000946
# Name: income_rate, dtype: float64

# %%
df['time'].max()
# Out:
# Timestamp('2025-01-29 23:00:00')

# %%
mask_train = np.array((pd.Timestamp('2022-01-01') <= df['time']) & (df['time'] < pd.Timestamp('2024-06-01')))
mask_valid = np.array((pd.Timestamp('2024-06-01') <= df['time']) & (df['time'] < pd.Timestamp('2024-08-01')))
mask_test = np.array((pd.Timestamp('2024-08-01') <= df['time']) & (df['time'] < pd.Timestamp('2024-10-01')))
mask_test2 = np.array((pd.Timestamp('2024-10-01') <= df['time']) & (df['time'] < pd.Timestamp('2024-12-23')))
mask_test3 = np.array((pd.Timestamp('2024-12-23') <= df['time']) & (df['time'] < pd.Timestamp('2025-01-28')))

# %%
mask_test3.sum()
# Out:
# 43361

# %%
mask_train.sum(), mask_valid.sum(), mask_test.sum(), mask_test2.sum()
# Out:
# (713114, 70129, 74239, 101909)

# %%
# некоторые акции имеют более короткую историю
NEED_POINTS = 101
mask_avbl_all = np.zeros_like(mask_train).astype(bool)
for ticker in df["ticker"].unique():
    mask = np.array(df['ticker'] == ticker)
    count_days = df.loc[mask, 'time'].dt.date.nunique()
    if count_days < NEED_POINTS:
        mask_avbl = np.zeros_like(mask_train).astype(bool)
    else:
        date_first_avbl =  np.sort(df.loc[mask, 'time'].dt.date.unique())[NEED_POINTS]
        #print(date_first_avbl)
        mask_avbl = np.array(df["time"] >= pd.to_datetime(date_first_avbl))
    
    mask_ticker = np.array(df['ticker'] == ticker)
    mask_avbl_ticker = mask_ticker & mask_avbl

    mask_avbl_all |= mask_avbl_ticker

mask_train &= mask_avbl_all
mask_valid &= mask_avbl_all
mask_test &= mask_avbl_all
mask_test2 &= mask_avbl_all


#мб дату неправильно обрезаю

# %%
mask_train.sum(), mask_valid.sum(), mask_test.sum(), mask_test2.sum()
# Out:
# (595945, 70129, 74239, 101909)

# %%
mask_data = mask_train|mask_valid|mask_test|mask_test2
(mask_data).sum()
# Out:
# 842222

# %%
df.loc[mask_data].isnull().sum()[df.loc[mask_data].isnull().sum() > 0].sort_values()
# Out:
# Series([], dtype: int64)

# %%
mask_train.sum()/(mask_data).sum(), mask_valid.sum()/(mask_data).sum(), mask_test.sum()/(mask_data).sum(), mask_test2.sum()/(mask_data).sum()
# Out:
# (0.7075865983078096,
#  0.08326664466138381,
#  0.08814659317852062,
#  0.12100016385228597)

# %%
df.loc[mask_train, 'target'].mean(), df.loc[mask_valid, 'target'].mean(), df.loc[mask_test, 'target'].mean(), df.loc[mask_test2, 'target'].mean()
# Out:
# (0.3169873058755422,
#  0.39845142523064636,
#  0.4000323280216598,
#  0.39971935746597453)

# %%
df.loc[mask_test3, 'target'].mean()
# Out:
# 0.33140379603791426

# %%
df.loc[mask_train, 'income_rate'].mean(), df.loc[mask_valid, 'income_rate'].mean(), df.loc[mask_test, 'income_rate'].mean(), df.loc[mask_test2, 'income_rate'].mean()
# Out:
# (0.9998479961575802, 1.0004144396777956, 1.000358036817947, 1.0004273808299113)

# %%
df.loc[mask_test3, 'income_rate'].mean()
# Out:
# 0.999428099988288

# %%
#проверки

# %%
(mask_train.sum()+mask_valid.sum()+mask_test.sum()+mask_test2.sum()) ==(mask_data).sum()

#(mask_train.sum()+mask_valid.sum()+mask_test.sum()) ==(mask_data).sum()
# Out:
# True

# %% [markdown]
# ## 3. Model

# %% [markdown]
# ### 3.1 Base model

# %%
df['ticker_code'] = df['ticker'].astype('category').cat.codes

# %%
df['ticker_code'].nunique()
# Out:
# 127

# %%
df.loc[mask_train, 'ticker_code'].nunique()
# Out:
# 127

# %%
df.columns.tolist()
# Out:
# ['time',
#  'close',
#  'ticker',
#  'index_1day',
#  'close_w1_roc',
#  'volume_w1_roc',
#  'tmos_close_w1_roc',
#  'close_w5_norm_std',
#  'close_w5_mean_abs_pct',
#  'close_w5_alpha',
#  'close_w5_rsi',
#  'close_w5_roc',
#  'volume_w5_norm_std',
#  'volume_w5_mean_abs_pct',
#  'volume_w5_alpha',
#  'volume_w5_rsi',
#  'volume_w5_roc',
#  'tmos_close_w5_norm_std',
#  'tmos_close_w5_mean_abs_pct',
#  'tmos_close_w5_alpha',
#  'tmos_close_w5_rsi',
#  'tmos_close_w5_roc',
#  'close_w14_norm_std',
#  'close_w14_mean_abs_pct',
#  'close_w14_alpha',
#  'close_w14_rsi',
#  'close_w14_roc',
#  'volume_w14_norm_std',
#  'volume_w14_mean_abs_pct',
#  'volume_w14_alpha',
#  'volume_w14_rsi',
#  'volume_w14_roc',
#  'tmos_close_w14_norm_std',
#  'tmos_close_w14_mean_abs_pct',
#  'tmos_close_w14_alpha',
#  'tmos_close_w14_rsi',
#  'tmos_close_w14_roc',
#  'close_w70_norm_std',
#  'close_w70_mean_abs_pct',
#  'close_w70_alpha',
#  'close_w70_rsi',
#  'close_w70_roc',
#  'close_w70_lvl_1-1.005',
#  'close_w70_lvl_-0.995-1',
#  'close_w70_lvl_1.005-1.01',
#  'close_w70_lvl_-0.99-0.995',
#  'close_w70_lvl_1.01-1.02',
#  'close_w70_lvl_-0.98-0.99',
#  'close_w70_lvl_1.02-1.03',
#  'close_w70_lvl_-0.97-0.98',
#  'close_w70_lvl_1.03-1.04',
#  'close_w70_lvl_-0.96-0.97',
#  'close_w70_lvl_1.04-1.05',
#  'close_w70_lvl_-0.95-0.96',
#  'close_w70_lvl_1.05-1.07',
#  'close_w70_lvl_-0.9299999999999999-0.95',
#  'volume_w70_norm_std',
#  'volume_w70_mean_abs_pct',
#  'volume_w70_alpha',
#  'volume_w70_rsi',
#  'volume_w70_roc',
#  'tmos_close_w70_norm_std',
#  'tmos_close_w70_mean_abs_pct',
#  'tmos_close_w70_alpha',
#  'tmos_close_w70_rsi',
#  'tmos_close_w70_roc',
#  'tmos_close_w70_lvl_1-1.005',
#  'tmos_close_w70_lvl_-0.995-1',
#  'tmos_close_w70_lvl_1.005-1.01',
#  'tmos_close_w70_lvl_-0.99-0.995',
#  'tmos_close_w70_lvl_1.01-1.015',
#  'tmos_close_w70_lvl_-0.985-0.99',
#  'tmos_close_w70_lvl_1.015-1.02',
#  'tmos_close_w70_lvl_-0.98-0.985',
#  'tmos_close_w70_lvl_1.02-1.03',
#  'tmos_close_w70_lvl_-0.97-0.98',
#  'tmos_close_w70_lvl_1.03-1.04',
#  'tmos_close_w70_lvl_-0.96-0.97',
#  'tmos_close_w70_lvl_1.04-1.05',
#  'tmos_close_w70_lvl_-0.95-0.96',
#  'hour',
#  'day',
#  'weekday',
#  'sin_time_hour',
#  'cos_time_hour',
#  'close_w1_roc/close_w5_alpha',
#  'close_w1_roc/close_w14_alpha',
#  'close_w1_roc/close_w70_alpha',
#  'close_w5_alpha/close_w14_alpha',
#  'close_w5_alpha/close_w70_alpha',
#  'close_w14_alpha/close_w70_alpha',
#  'volume_w1_roc/volume_w5_alpha',
#  'volume_w1_roc/volume_w14_alpha',
#  'volume_w1_roc/volume_w70_alpha',
#  'volume_w5_alpha/volume_w14_alpha',
#  'volume_w5_alpha/volume_w70_alpha',
#  'volume_w14_alpha/volume_w70_alpha',
#  'tmos_close_w1_roc/tmos_close_w5_alpha',
#  'tmos_close_w1_roc/tmos_close_w14_alpha',
#  'tmos_close_w1_roc/tmos_close_w70_alpha',
#  'tmos_close_w5_alpha/tmos_close_w14_alpha',
#  'tmos_close_w5_alpha/tmos_close_w70_alpha',
#  'tmos_close_w14_alpha/tmos_close_w70_alpha',
#  'close_w1_roc/close_w5_roc',
#  'close_w1_roc/close_w14_roc',
#  'close_w1_roc/close_w70_roc',
#  'close_w5_roc/close_w14_roc',
#  'close_w5_roc/close_w70_roc',
#  'close_w14_roc/close_w70_roc',
#  'volume_w1_roc/volume_w5_roc',
#  'volume_w1_roc/volume_w14_roc',
#  'volume_w1_roc/volume_w70_roc',
#  'volume_w5_roc/volume_w14_roc',
#  'volume_w5_roc/volume_w70_roc',
#  'volume_w14_roc/volume_w70_roc',
#  'tmos_close_w1_roc/tmos_close_w5_roc',
#  'tmos_close_w1_roc/tmos_close_w14_roc',
#  'tmos_close_w1_roc/tmos_close_w70_roc',
#  'tmos_close_w5_roc/tmos_close_w14_roc',
#  'tmos_close_w5_roc/tmos_close_w70_roc',
#  'tmos_close_w14_roc/tmos_close_w70_roc',
#  'close_w5_mean_abs_pct/close_w14_mean_abs_pct',
#  'close_w5_mean_abs_pct/close_w70_mean_abs_pct',
#  'close_w14_mean_abs_pct/close_w70_mean_abs_pct',
#  'volume_w5_mean_abs_pct/volume_w14_mean_abs_pct',
#  'volume_w5_mean_abs_pct/volume_w70_mean_abs_pct',
#  'volume_w14_mean_abs_pct/volume_w70_mean_abs_pct',
#  'tmos_close_w5_mean_abs_pct/tmos_close_w14_mean_abs_pct',
#  'tmos_close_w5_mean_abs_pct/tmos_close_w70_mean_abs_pct',
#  'tmos_close_w14_mean_abs_pct/tmos_close_w70_mean_abs_pct',
#  'close_w5_std/close_w14_std',
#  'close_w5_std/close_w70_std',
#  'close_w14_std/close_w70_std',
#  'volume_w5_std/volume_w14_std',
#  'volume_w5_std/volume_w70_std',
#  'volume_w14_std/volume_w70_std',
#  'tmos_close_w5_std/tmos_close_w14_std',
#  'tmos_close_w5_std/tmos_close_w70_std',
#  'tmos_close_w14_std/tmos_close_w70_std',
#  'close_w5_norm_std/close_w14_norm_std',
#  'close_w5_norm_std/close_w70_norm_std',
#  'close_w14_norm_std/close_w70_norm_std',
#  'volume_w5_norm_std/volume_w14_norm_std',
#  'volume_w5_norm_std/volume_w70_norm_std',
#  'volume_w14_norm_std/volume_w70_norm_std',
#  'tmos_close_w5_norm_std/tmos_close_w14_norm_std',
#  'tmos_close_w5_norm_std/tmos_close_w70_norm_std',
#  'tmos_close_w14_norm_std/tmos_close_w70_norm_std',
#  'close_w5_rsi/close_w14_rsi',
#  'close_w5_rsi/close_w70_rsi',
#  'close_w14_rsi/close_w70_rsi',
#  'volume_w5_rsi/volume_w14_rsi',
#  'volume_w5_rsi/volume_w70_rsi',
#  'volume_w14_rsi/volume_w70_rsi',
#  'tmos_close_w5_rsi/tmos_close_w14_rsi',
#  'tmos_close_w5_rsi/tmos_close_w70_rsi',
#  'tmos_close_w14_rsi/tmos_close_w70_rsi',
#  'close/close_w5_ma',
#  'close/close_w14_ma',
#  'close/close_w70_ma',
#  'close_w5_ma/close_w14_ma',
#  'close_w5_ma/close_w70_ma',
#  'close_w14_ma/close_w70_ma',
#  'volume/volume_w5_ma',
#  'volume/volume_w14_ma',
#  'volume/volume_w70_ma',
#  'volume_w5_ma/volume_w14_ma',
#  'volume_w5_ma/volume_w70_ma',
#  'volume_w14_ma/volume_w70_ma',
#  'tmos_close/tmos_close_w5_ma',
#  'tmos_close/tmos_close_w14_ma',
#  'tmos_close/tmos_close_w70_ma',
#  'tmos_close_w5_ma/tmos_close_w14_ma',
#  'tmos_close_w5_ma/tmos_close_w70_ma',
#  'tmos_close_w14_ma/tmos_close_w70_ma',
#  'close_w5_min/close',
#  'close_w14_min/close',
#  'close_w70_min/close',
#  'volume_w5_min/volume',
#  'volume_w14_min/volume',
#  'volume_w70_min/volume',
#  'tmos_close_w5_min/tmos_close',
#  'tmos_close_w14_min/tmos_close',
#  'tmos_close_w70_min/tmos_close',
#  'close_w5_max/close',
#  'close_w14_max/close',
#  'close_w70_max/close',
#  'volume_w5_max/volume',
#  'volume_w14_max/volume',
#  'volume_w70_max/volume',
#  'tmos_close_w5_max/tmos_close',
#  'tmos_close_w14_max/tmos_close',
#  'tmos_close_w70_max/tmos_close',
#  'close_w5_ma_low_2std/close',
#  'close_w5_ma_up_2std/close',
#  'close_w5_ma_low_3std/close',
#  'close_w5_ma_up_3std/close',
#  'volume_w5_ma_low_2std/volume',
#  'volume_w5_ma_up_2std/volume',
#  'volume_w5_ma_low_3std/volume',
#  'volume_w5_ma_up_3std/volume',
#  'tmos_close_w5_ma_low_2std/tmos_close',
#  'tmos_close_w5_ma_up_2std/tmos_close',
#  'tmos_close_w5_ma_low_3std/tmos_close',
#  'tmos_close_w5_ma_up_3std/tmos_close',
#  'close_w14_ma_low_2std/close',
#  'close_w14_ma_up_2std/close',
#  'close_w14_ma_low_3std/close',
#  'close_w14_ma_up_3std/close',
#  'volume_w14_ma_low_2std/volume',
#  'volume_w14_ma_up_2std/volume',
#  'volume_w14_ma_low_3std/volume',
#  'volume_w14_ma_up_3std/volume',
#  'tmos_close_w14_ma_low_2std/tmos_close',
#  'tmos_close_w14_ma_up_2std/tmos_close',
#  'tmos_close_w14_ma_low_3std/tmos_close',
#  'tmos_close_w14_ma_up_3std/tmos_close',
#  'close_w70_ma_low_2std/close',
#  'close_w70_ma_up_2std/close',
#  'close_w70_ma_low_3std/close',
#  'close_w70_ma_up_3std/close',
#  'volume_w70_ma_low_2std/volume',
#  'volume_w70_ma_up_2std/volume',
#  'volume_w70_ma_low_3std/volume',
#  'volume_w70_ma_up_3std/volume',
#  'tmos_close_w70_ma_low_2std/tmos_close',
#  'tmos_close_w70_ma_up_2std/tmos_close',
#  'tmos_close_w70_ma_low_3std/tmos_close',
#  'tmos_close_w70_ma_up_3std/tmos_close',
#  'close_w5_min/close_w5_max',
#  'volume_w5_min/volume_w5_max',
#  'tmos_close_w5_min/tmos_close_w5_max',
#  'close_w14_min/close_w14_max',
#  'volume_w14_min/volume_w14_max',
#  'tmos_close_w14_min/tmos_close_w14_max',
#  'close_w70_min/close_w70_max',
#  'volume_w70_min/volume_w70_max',
#  'tmos_close_w70_min/tmos_close_w70_max',
#  'index',
#  'close_1day_w1_roc',
#  'volume_1day_w1_roc',
#  'tmos_close_1day_w1_roc',
#  'close_1day_w3_norm_std',
#  'close_1day_w3_mean_abs_pct',
#  'close_1day_w3_alpha',
#  'close_1day_w3_rsi',
#  'close_1day_w3_roc',
#  'volume_1day_w3_norm_std',
#  'volume_1day_w3_mean_abs_pct',
#  'volume_1day_w3_alpha',
#  'volume_1day_w3_rsi',
#  'volume_1day_w3_roc',
#  'tmos_close_1day_w3_norm_std',
#  'tmos_close_1day_w3_mean_abs_pct',
#  'tmos_close_1day_w3_alpha',
#  'tmos_close_1day_w3_rsi',
#  'tmos_close_1day_w3_roc',
#  'close_1day_w5_norm_std',
#  'close_1day_w5_mean_abs_pct',
#  'close_1day_w5_alpha',
#  'close_1day_w5_rsi',
#  'close_1day_w5_roc',
#  'volume_1day_w5_norm_std',
#  'volume_1day_w5_mean_abs_pct',
#  'volume_1day_w5_alpha',
#  'volume_1day_w5_rsi',
#  'volume_1day_w5_roc',
#  'tmos_close_1day_w5_norm_std',
#  'tmos_close_1day_w5_mean_abs_pct',
#  'tmos_close_1day_w5_alpha',
#  'tmos_close_1day_w5_rsi',
#  'tmos_close_1day_w5_roc',
#  'close_1day_w20_norm_std',
#  'close_1day_w20_mean_abs_pct',
#  'close_1day_w20_alpha',
#  'close_1day_w20_rsi',
#  'close_1day_w20_roc',
#  'close_1day_w20_lvl_1-1.005',
#  'close_1day_w20_lvl_-0.995-1',
#  'close_1day_w20_lvl_1.005-1.01',
#  'close_1day_w20_lvl_-0.99-0.995',
#  'close_1day_w20_lvl_1.01-1.02',
#  'close_1day_w20_lvl_-0.98-0.99',
#  'close_1day_w20_lvl_1.02-1.03',
#  'close_1day_w20_lvl_-0.97-0.98',
#  'close_1day_w20_lvl_1.03-1.04',
#  'close_1day_w20_lvl_-0.96-0.97',
#  'close_1day_w20_lvl_1.04-1.05',
#  'close_1day_w20_lvl_-0.95-0.96',
#  'close_1day_w20_lvl_1.05-1.07',
#  'close_1day_w20_lvl_-0.9299999999999999-0.95',
#  'volume_1day_w20_norm_std',
#  'volume_1day_w20_mean_abs_pct',
#  'volume_1day_w20_alpha',
#  'volume_1day_w20_rsi',
#  'volume_1day_w20_roc',
#  'tmos_close_1day_w20_norm_std',
#  'tmos_close_1day_w20_mean_abs_pct',
#  'tmos_close_1day_w20_alpha',
#  'tmos_close_1day_w20_rsi',
#  'tmos_close_1day_w20_roc',
#  'tmos_close_1day_w20_lvl_1-1.005',
#  'tmos_close_1day_w20_lvl_-0.995-1',
#  'tmos_close_1day_w20_lvl_1.005-1.01',
#  'tmos_close_1day_w20_lvl_-0.99-0.995',
#  'tmos_close_1day_w20_lvl_1.01-1.015',
#  'tmos_close_1day_w20_lvl_-0.985-0.99',
#  'tmos_close_1day_w20_lvl_1.015-1.02',
#  'tmos_close_1day_w20_lvl_-0.98-0.985',
#  'tmos_close_1day_w20_lvl_1.02-1.03',
#  'tmos_close_1day_w20_lvl_-0.97-0.98',
#  'tmos_close_1day_w20_lvl_1.03-1.04',
#  'tmos_close_1day_w20_lvl_-0.96-0.97',
#  'tmos_close_1day_w20_lvl_1.04-1.05',
#  'tmos_close_1day_w20_lvl_-0.95-0.96',
#  'close_1day_w100_norm_std',
#  'close_1day_w100_mean_abs_pct',
#  'close_1day_w100_alpha',
#  'close_1day_w100_rsi',
#  'close_1day_w100_roc',
#  'close_1day_w100_lvl_1-1.005',
#  'close_1day_w100_lvl_-0.995-1',
#  'close_1day_w100_lvl_1.005-1.01',
#  'close_1day_w100_lvl_-0.99-0.995',
#  'close_1day_w100_lvl_1.01-1.02',
#  'close_1day_w100_lvl_-0.98-0.99',
#  'close_1day_w100_lvl_1.02-1.03',
#  'close_1day_w100_lvl_-0.97-0.98',
#  'close_1day_w100_lvl_1.03-1.04',
#  'close_1day_w100_lvl_-0.96-0.97',
#  'close_1day_w100_lvl_1.04-1.05',
#  'close_1day_w100_lvl_-0.95-0.96',
#  'close_1day_w100_lvl_1.05-1.07',
#  'close_1day_w100_lvl_-0.9299999999999999-0.95',
#  'volume_1day_w100_norm_std',
#  'volume_1day_w100_mean_abs_pct',
#  'volume_1day_w100_alpha',
#  'volume_1day_w100_rsi',
#  'volume_1day_w100_roc',
#  'tmos_close_1day_w100_norm_std',
#  'tmos_close_1day_w100_mean_abs_pct',
#  'tmos_close_1day_w100_alpha',
#  'tmos_close_1day_w100_rsi',
#  'tmos_close_1day_w100_roc',
#  'tmos_close_1day_w100_lvl_1-1.005',
#  'tmos_close_1day_w100_lvl_-0.995-1',
#  'tmos_close_1day_w100_lvl_1.005-1.01',
#  'tmos_close_1day_w100_lvl_-0.99-0.995',
#  'tmos_close_1day_w100_lvl_1.01-1.015',
#  'tmos_close_1day_w100_lvl_-0.985-0.99',
#  'tmos_close_1day_w100_lvl_1.015-1.02',
#  'tmos_close_1day_w100_lvl_-0.98-0.985',
#  'tmos_close_1day_w100_lvl_1.02-1.03',
#  'tmos_close_1day_w100_lvl_-0.97-0.98',
#  'tmos_close_1day_w100_lvl_1.03-1.04',
#  'tmos_close_1day_w100_lvl_-0.96-0.97',
#  'tmos_close_1day_w100_lvl_1.04-1.05',
#  'tmos_close_1day_w100_lvl_-0.95-0.96',
#  'sin_time_weekday',
#  'cos_time_weekday',
#  'sin_time_monthday',
#  'cos_time_monthday',
#  'close_1day_w1_roc/close_1day_w3_alpha',
#  'close_1day_w1_roc/close_1day_w5_alpha',
#  'close_1day_w1_roc/close_1day_w20_alpha',
#  'close_1day_w1_roc/close_1day_w100_alpha',
#  'close_1day_w3_alpha/close_1day_w5_alpha',
#  'close_1day_w3_alpha/close_1day_w20_alpha',
#  'close_1day_w3_alpha/close_1day_w100_alpha',
#  'close_1day_w5_alpha/close_1day_w20_alpha',
#  'close_1day_w5_alpha/close_1day_w100_alpha',
#  'close_1day_w20_alpha/close_1day_w100_alpha',
#  'volume_1day_w1_roc/volume_1day_w3_alpha',
#  'volume_1day_w1_roc/volume_1day_w5_alpha',
#  'volume_1day_w1_roc/volume_1day_w20_alpha',
#  'volume_1day_w1_roc/volume_1day_w100_alpha',
#  'volume_1day_w3_alpha/volume_1day_w5_alpha',
#  'volume_1day_w3_alpha/volume_1day_w20_alpha',
#  'volume_1day_w3_alpha/volume_1day_w100_alpha',
#  'volume_1day_w5_alpha/volume_1day_w20_alpha',
#  'volume_1day_w5_alpha/volume_1day_w100_alpha',
#  'volume_1day_w20_alpha/volume_1day_w100_alpha',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w3_alpha',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w5_alpha',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w20_alpha',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w100_alpha',
#  'tmos_close_1day_w3_alpha/tmos_close_1day_w5_alpha',
#  'tmos_close_1day_w3_alpha/tmos_close_1day_w20_alpha',
#  'tmos_close_1day_w3_alpha/tmos_close_1day_w100_alpha',
#  'tmos_close_1day_w5_alpha/tmos_close_1day_w20_alpha',
#  'tmos_close_1day_w5_alpha/tmos_close_1day_w100_alpha',
#  'tmos_close_1day_w20_alpha/tmos_close_1day_w100_alpha',
#  'close_1day_w1_roc/close_1day_w3_roc',
#  'close_1day_w1_roc/close_1day_w5_roc',
#  'close_1day_w1_roc/close_1day_w20_roc',
#  'close_1day_w1_roc/close_1day_w100_roc',
#  'close_1day_w3_roc/close_1day_w5_roc',
#  'close_1day_w3_roc/close_1day_w20_roc',
#  'close_1day_w3_roc/close_1day_w100_roc',
#  'close_1day_w5_roc/close_1day_w20_roc',
#  'close_1day_w5_roc/close_1day_w100_roc',
#  'close_1day_w20_roc/close_1day_w100_roc',
#  'volume_1day_w1_roc/volume_1day_w3_roc',
#  'volume_1day_w1_roc/volume_1day_w5_roc',
#  'volume_1day_w1_roc/volume_1day_w20_roc',
#  'volume_1day_w1_roc/volume_1day_w100_roc',
#  'volume_1day_w3_roc/volume_1day_w5_roc',
#  'volume_1day_w3_roc/volume_1day_w20_roc',
#  'volume_1day_w3_roc/volume_1day_w100_roc',
#  'volume_1day_w5_roc/volume_1day_w20_roc',
#  'volume_1day_w5_roc/volume_1day_w100_roc',
#  'volume_1day_w20_roc/volume_1day_w100_roc',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w3_roc',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w5_roc',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w20_roc',
#  'tmos_close_1day_w1_roc/tmos_close_1day_w100_roc',
#  'tmos_close_1day_w3_roc/tmos_close_1day_w5_roc',
#  'tmos_close_1day_w3_roc/tmos_close_1day_w20_roc',
#  'tmos_close_1day_w3_roc/tmos_close_1day_w100_roc',
#  'tmos_close_1day_w5_roc/tmos_close_1day_w20_roc',
#  'tmos_close_1day_w5_roc/tmos_close_1day_w100_roc',
#  'tmos_close_1day_w20_roc/tmos_close_1day_w100_roc',
#  'close_1day_w3_mean_abs_pct/close_1day_w5_mean_abs_pct',
#  'close_1day_w3_mean_abs_pct/close_1day_w20_mean_abs_pct',
#  'close_1day_w3_mean_abs_pct/close_1day_w100_mean_abs_pct',
#  'close_1day_w5_mean_abs_pct/close_1day_w20_mean_abs_pct',
#  'close_1day_w5_mean_abs_pct/close_1day_w100_mean_abs_pct',
#  'close_1day_w20_mean_abs_pct/close_1day_w100_mean_abs_pct',
#  'volume_1day_w3_mean_abs_pct/volume_1day_w5_mean_abs_pct',
#  'volume_1day_w3_mean_abs_pct/volume_1day_w20_mean_abs_pct',
#  'volume_1day_w3_mean_abs_pct/volume_1day_w100_mean_abs_pct',
#  'volume_1day_w5_mean_abs_pct/volume_1day_w20_mean_abs_pct',
#  'volume_1day_w5_mean_abs_pct/volume_1day_w100_mean_abs_pct',
#  'volume_1day_w20_mean_abs_pct/volume_1day_w100_mean_abs_pct',
#  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
#  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w20_mean_abs_pct',
#  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w100_mean_abs_pct',
#  'tmos_close_1day_w5_mean_abs_pct/tmos_close_1day_w20_mean_abs_pct',
#  'tmos_close_1day_w5_mean_abs_pct/tmos_close_1day_w100_mean_abs_pct',
#  'tmos_close_1day_w20_mean_abs_pct/tmos_close_1day_w100_mean_abs_pct',
#  'close_1day_w3_std/close_1day_w5_std',
#  'close_1day_w3_std/close_1day_w20_std',
#  'close_1day_w3_std/close_1day_w100_std',
#  'close_1day_w5_std/close_1day_w20_std',
#  'close_1day_w5_std/close_1day_w100_std',
#  'close_1day_w20_std/close_1day_w100_std',
#  'volume_1day_w3_std/volume_1day_w5_std',
#  'volume_1day_w3_std/volume_1day_w20_std',
#  'volume_1day_w3_std/volume_1day_w100_std',
#  'volume_1day_w5_std/volume_1day_w20_std',
#  'volume_1day_w5_std/volume_1day_w100_std',
#  'volume_1day_w20_std/volume_1day_w100_std',
#  'tmos_close_1day_w3_std/tmos_close_1day_w5_std',
#  'tmos_close_1day_w3_std/tmos_close_1day_w20_std',
#  'tmos_close_1day_w3_std/tmos_close_1day_w100_std',
#  'tmos_close_1day_w5_std/tmos_close_1day_w20_std',
#  'tmos_close_1day_w5_std/tmos_close_1day_w100_std',
#  'tmos_close_1day_w20_std/tmos_close_1day_w100_std',
#  'close_1day_w3_norm_std/close_1day_w5_norm_std',
#  'close_1day_w3_norm_std/close_1day_w20_norm_std',
#  'close_1day_w3_norm_std/close_1day_w100_norm_std',
#  'close_1day_w5_norm_std/close_1day_w20_norm_std',
#  'close_1day_w5_norm_std/close_1day_w100_norm_std',
#  'close_1day_w20_norm_std/close_1day_w100_norm_std',
#  'volume_1day_w3_norm_std/volume_1day_w5_norm_std',
#  'volume_1day_w3_norm_std/volume_1day_w20_norm_std',
#  'volume_1day_w3_norm_std/volume_1day_w100_norm_std',
#  'volume_1day_w5_norm_std/volume_1day_w20_norm_std',
#  'volume_1day_w5_norm_std/volume_1day_w100_norm_std',
#  'volume_1day_w20_norm_std/volume_1day_w100_norm_std',
#  'tmos_close_1day_w3_norm_std/tmos_close_1day_w5_norm_std',
#  'tmos_close_1day_w3_norm_std/tmos_close_1day_w20_norm_std',
#  'tmos_close_1day_w3_norm_std/tmos_close_1day_w100_norm_std',
#  'tmos_close_1day_w5_norm_std/tmos_close_1day_w20_norm_std',
#  'tmos_close_1day_w5_norm_std/tmos_close_1day_w100_norm_std',
#  'tmos_close_1day_w20_norm_std/tmos_close_1day_w100_norm_std',
#  'close_1day_w3_rsi/close_1day_w5_rsi',
#  'close_1day_w3_rsi/close_1day_w20_rsi',
#  'close_1day_w3_rsi/close_1day_w100_rsi',
#  'close_1day_w5_rsi/close_1day_w20_rsi',
#  'close_1day_w5_rsi/close_1day_w100_rsi',
#  'close_1day_w20_rsi/close_1day_w100_rsi',
#  'volume_1day_w3_rsi/volume_1day_w5_rsi',
#  'volume_1day_w3_rsi/volume_1day_w20_rsi',
#  'volume_1day_w3_rsi/volume_1day_w100_rsi',
#  'volume_1day_w5_rsi/volume_1day_w20_rsi',
#  'volume_1day_w5_rsi/volume_1day_w100_rsi',
#  'volume_1day_w20_rsi/volume_1day_w100_rsi',
#  'tmos_close_1day_w3_rsi/tmos_close_1day_w5_rsi',
#  'tmos_close_1day_w3_rsi/tmos_close_1day_w20_rsi',
#  'tmos_close_1day_w3_rsi/tmos_close_1day_w100_rsi',
#  'tmos_close_1day_w5_rsi/tmos_close_1day_w20_rsi',
#  'tmos_close_1day_w5_rsi/tmos_close_1day_w100_rsi',
#  'tmos_close_1day_w20_rsi/tmos_close_1day_w100_rsi',
#  'close_1day/close_1day_w3_ma',
#  'close_1day/close_1day_w5_ma',
#  'close_1day/close_1day_w20_ma',
#  'close_1day/close_1day_w100_ma',
#  'close_1day_w3_ma/close_1day_w5_ma',
#  'close_1day_w3_ma/close_1day_w20_ma',
#  'close_1day_w3_ma/close_1day_w100_ma',
#  'close_1day_w5_ma/close_1day_w20_ma',
#  'close_1day_w5_ma/close_1day_w100_ma',
#  'close_1day_w20_ma/close_1day_w100_ma',
#  'volume_1day/volume_1day_w3_ma',
#  'volume_1day/volume_1day_w5_ma',
#  'volume_1day/volume_1day_w20_ma',
#  'volume_1day/volume_1day_w100_ma',
#  'volume_1day_w3_ma/volume_1day_w5_ma',
#  'volume_1day_w3_ma/volume_1day_w20_ma',
#  'volume_1day_w3_ma/volume_1day_w100_ma',
#  'volume_1day_w5_ma/volume_1day_w20_ma',
#  'volume_1day_w5_ma/volume_1day_w100_ma',
#  'volume_1day_w20_ma/volume_1day_w100_ma',
#  'tmos_close_1day/tmos_close_1day_w3_ma',
#  'tmos_close_1day/tmos_close_1day_w5_ma',
#  'tmos_close_1day/tmos_close_1day_w20_ma',
#  'tmos_close_1day/tmos_close_1day_w100_ma',
#  'tmos_close_1day_w3_ma/tmos_close_1day_w5_ma',
#  'tmos_close_1day_w3_ma/tmos_close_1day_w20_ma',
#  'tmos_close_1day_w3_ma/tmos_close_1day_w100_ma',
#  'tmos_close_1day_w5_ma/tmos_close_1day_w20_ma',
#  'tmos_close_1day_w5_ma/tmos_close_1day_w100_ma',
#  'tmos_close_1day_w20_ma/tmos_close_1day_w100_ma',
#  'close_1day_w3_min/close_1day',
#  'close_1day_w5_min/close_1day',
#  'close_1day_w20_min/close_1day',
#  'close_1day_w100_min/close_1day',
#  'volume_1day_w3_min/volume_1day',
#  'volume_1day_w5_min/volume_1day',
#  'volume_1day_w20_min/volume_1day',
#  'volume_1day_w100_min/volume_1day',
#  'tmos_close_1day_w3_min/tmos_close_1day',
#  'tmos_close_1day_w5_min/tmos_close_1day',
#  'tmos_close_1day_w20_min/tmos_close_1day',
#  'tmos_close_1day_w100_min/tmos_close_1day',
#  'close_1day_w3_max/close_1day',
#  'close_1day_w5_max/close_1day',
#  'close_1day_w20_max/close_1day',
#  'close_1day_w100_max/close_1day',
#  'volume_1day_w3_max/volume_1day',
#  'volume_1day_w5_max/volume_1day',
#  'volume_1day_w20_max/volume_1day',
#  'volume_1day_w100_max/volume_1day',
#  'tmos_close_1day_w3_max/tmos_close_1day',
#  'tmos_close_1day_w5_max/tmos_close_1day',
#  'tmos_close_1day_w20_max/tmos_close_1day',
#  'tmos_close_1day_w100_max/tmos_close_1day',
#  'close_1day_w3_ma_low_2std/close_1day',
#  'close_1day_w3_ma_up_2std/close_1day',
#  'close_1day_w3_ma_low_3std/close_1day',
#  'close_1day_w3_ma_up_3std/close_1day',
#  'volume_1day_w3_ma_low_2std/volume_1day',
#  'volume_1day_w3_ma_up_2std/volume_1day',
#  'volume_1day_w3_ma_low_3std/volume_1day',
#  'volume_1day_w3_ma_up_3std/volume_1day',
#  'tmos_close_1day_w3_ma_low_2std/tmos_close_1day',
#  'tmos_close_1day_w3_ma_up_2std/tmos_close_1day',
#  'tmos_close_1day_w3_ma_low_3std/tmos_close_1day',
#  'tmos_close_1day_w3_ma_up_3std/tmos_close_1day',
#  'close_1day_w5_ma_low_2std/close_1day',
#  'close_1day_w5_ma_up_2std/close_1day',
#  'close_1day_w5_ma_low_3std/close_1day',
#  'close_1day_w5_ma_up_3std/close_1day',
#  'volume_1day_w5_ma_low_2std/volume_1day',
#  'volume_1day_w5_ma_up_2std/volume_1day',
#  'volume_1day_w5_ma_low_3std/volume_1day',
#  'volume_1day_w5_ma_up_3std/volume_1day',
#  'tmos_close_1day_w5_ma_low_2std/tmos_close_1day',
#  'tmos_close_1day_w5_ma_up_2std/tmos_close_1day',
#  'tmos_close_1day_w5_ma_low_3std/tmos_close_1day',
#  'tmos_close_1day_w5_ma_up_3std/tmos_close_1day',
#  'close_1day_w20_ma_low_2std/close_1day',
#  'close_1day_w20_ma_up_2std/close_1day',
#  'close_1day_w20_ma_low_3std/close_1day',
#  'close_1day_w20_ma_up_3std/close_1day',
#  'volume_1day_w20_ma_low_2std/volume_1day',
#  'volume_1day_w20_ma_up_2std/volume_1day',
#  'volume_1day_w20_ma_low_3std/volume_1day',
#  'volume_1day_w20_ma_up_3std/volume_1day',
#  'tmos_close_1day_w20_ma_low_2std/tmos_close_1day',
#  'tmos_close_1day_w20_ma_up_2std/tmos_close_1day',
#  'tmos_close_1day_w20_ma_low_3std/tmos_close_1day',
#  'tmos_close_1day_w20_ma_up_3std/tmos_close_1day',
#  'close_1day_w100_ma_low_2std/close_1day',
#  'close_1day_w100_ma_up_2std/close_1day',
#  'close_1day_w100_ma_low_3std/close_1day',
#  'close_1day_w100_ma_up_3std/close_1day',
#  'volume_1day_w100_ma_low_2std/volume_1day',
#  'volume_1day_w100_ma_up_2std/volume_1day',
#  'volume_1day_w100_ma_low_3std/volume_1day',
#  'volume_1day_w100_ma_up_3std/volume_1day',
#  'tmos_close_1day_w100_ma_low_2std/tmos_close_1day',
#  'tmos_close_1day_w100_ma_up_2std/tmos_close_1day',
#  'tmos_close_1day_w100_ma_low_3std/tmos_close_1day',
#  'tmos_close_1day_w100_ma_up_3std/tmos_close_1day',
#  'close_1day_w3_min/close_1day_w3_max',
#  'volume_1day_w3_min/volume_1day_w3_max',
#  'tmos_close_1day_w3_min/tmos_close_1day_w3_max',
#  'close_1day_w5_min/close_1day_w5_max',
#  'volume_1day_w5_min/volume_1day_w5_max',
#  'tmos_close_1day_w5_min/tmos_close_1day_w5_max',
#  'close_1day_w20_min/close_1day_w20_max',
#  'volume_1day_w20_min/volume_1day_w20_max',
#  'tmos_close_1day_w20_min/tmos_close_1day_w20_max',
#  'target',
#  'ticker_code',
#  'y_pred',
#  'result',
#  'delta_time',
#  'income_rate',
#  'res_price',
#  'res_ind']

# %%
drop_cols = ['time',
             #'ticker_code',
             #'hour', 'day', 'weekday', 

 'ticker',
 'index_1day',
 'result',
 'delta_time',
 'income_rate',
 'res_price',
 'res_ind', 'index', 'target', 
              'ind', 'close',
             'y_pred'] #+ [elem for elem in df.columns if 'roc' in elem]


features = df.columns[~df.columns.isin(drop_cols)].tolist()
#features = [elem for elem in df.columns if (('/' in elem) or ('lvl' in elem) or ('alpha' in elem))] +['hour', 'day', 'weekday'] + #['ticker_code']
                                                                                                    


cat_features_all = ['ticker_code',
                'hour', 'day', 'weekday',# 'month'
]
cat_features = cat_features_all

target = 'target'

# %%
len(features)
# Out:
# 601

# %% [markdown]
# ### Get stability features

# %%
params = {
    "boosting_type": "gbdt",
    "objective": "binary",
    
    "num_leaves": 2,

     "bagging_fraction": 0.5,
     "bagging_freq": 1,
     "verbose": 0,
    "metric": "auc",
    "early_stopping" : 20, 
}

auc_features = {'feature' : [],
               'auc_train' : [],
               'auc_valid' : [],
               'auc_test' : [],
               'auc_test2' : []
               }

for feature in tqdm(features):
    stab_features = [feature]
    stab_cat_features = [feature] if feature in cat_features else []
    
    D_train = lgbm.Dataset(df.loc[mask_train, stab_features], label=df.loc[mask_train, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
    D_valid = lgbm.Dataset(df.loc[mask_valid, stab_features], label=df.loc[mask_valid, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
    D_test = lgbm.Dataset(df.loc[mask_test, stab_features], label=df.loc[mask_test, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
    D_test2 = lgbm.Dataset(df.loc[mask_test2, stab_features], label=df.loc[mask_test2, target], feature_name=stab_features, categorical_feature=stab_cat_features, free_raw_data=False)
        
    model = lgbm.train(params, num_boost_round=1_000, train_set=D_train, valid_sets=[D_valid])
    
    y_pred_train = model.predict(D_train.data)
    y_pred_valid = model.predict(D_valid.data)
    y_pred_test = model.predict(D_test.data)
    y_pred_test2 = model.predict(D_test2.data)

    auc_features['feature'] += [feature]
    auc_features['auc_train'] += [roc_auc_score(D_train.label, y_pred_train)]
    auc_features['auc_valid'] += [roc_auc_score(D_valid.label, y_pred_valid)]
    auc_features['auc_test'] += [roc_auc_score(D_test.label, y_pred_test)]
    auc_features['auc_test2'] += [roc_auc_score(D_test2.label, y_pred_test2)]

auc_features_cp = auc_features.copy()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 601/601 [03:09<00:00,  3.18it/s]

# %%
df_auc_features = pd.DataFrame(auc_features)
df_auc_features
# Out:
#                                              feature  auc_train  auc_valid  \
# 0                                       close_w1_roc   0.540673   0.521399
# 1                                      volume_w1_roc   0.514040   0.515459
# 2                                  tmos_close_w1_roc   0.518604   0.528220
# 3                                  close_w5_norm_std   0.576741   0.520632
# 4                              close_w5_mean_abs_pct   0.587664   0.519093
# ..                                               ...        ...        ...
# 596    tmos_close_1day_w5_min/tmos_close_1day_w5_max   0.524649   0.500000
# 597            close_1day_w20_min/close_1day_w20_max   0.558248   0.495419
# 598          volume_1day_w20_min/volume_1day_w20_max   0.552764   0.508031
# 599  tmos_close_1day_w20_min/tmos_close_1day_w20_max   0.515875   0.500161
# 600                                      ticker_code   0.588087   0.527462
#
#      auc_test  auc_test2
# 0    0.529992   0.528176
# 1    0.508169   0.508426
# 2    0.517684   0.513818
# 3    0.518216   0.511367
# 4    0.518260   0.510422
# ..        ...        ...
# 596  0.500000   0.500000
# 597  0.494614   0.510727
# 598  0.510756   0.504380
# 599  0.500000   0.506427
# 600  0.515847   0.517726
#
# [601 rows x 5 columns]

# %% [markdown]
# #### auc <=0.525

# %%
auc_treshold = 0.51

# %%
mask_auc_train  = df_auc_features['auc_train'] <= auc_treshold 
mask_auc_train.sum()
# Out:
# 78

# %%
mask_auc_valid  = df_auc_features['auc_valid'] <= auc_treshold 
mask_auc_valid.sum()
# Out:
# 339

# %%
mask_auc_test  = df_auc_features['auc_test'] <= auc_treshold 
mask_auc_test.sum()
# Out:
# 427

# %%
(mask_auc_train | mask_auc_valid | mask_auc_test).sum()
# Out:
# 494

# %%
mask_auc_test2  = df_auc_features['auc_test2'] <= auc_treshold 
mask_auc_test2.sum()
# Out:
# 445

# %%
(mask_auc_train | mask_auc_valid | mask_auc_test | mask_auc_test2).sum()
# Out:
# 534

# %% [markdown]
# #### delta_auc > 0.05

# %%
auc_delta_treshold  = 0.03

# %%
mask_auc_delta_valid = (df_auc_features['auc_train'] - df_auc_features['auc_valid']).abs() > auc_delta_treshold
mask_auc_delta_valid.sum()
# Out:
# 180

# %%
mask_auc_delta_test = (df_auc_features['auc_train'] - df_auc_features['auc_test']).abs() > auc_delta_treshold
mask_auc_delta_test.sum()
# Out:
# 190

# %%
(mask_auc_delta_valid | mask_auc_delta_test).sum()
# Out:
# 252

# %%
mask_auc_delta_test2 = (df_auc_features['auc_train'] - df_auc_features['auc_test2']).abs() > auc_delta_treshold
mask_auc_delta_test2.sum()
# Out:
# 225

# %%
(mask_auc_delta_valid | mask_auc_delta_test | mask_auc_delta_test2).sum()
# Out:
# 309

# %% [markdown]
# #### union criterias

# %%
mask_criterias1 = mask_auc_train | mask_auc_valid | mask_auc_test | mask_auc_delta_valid | mask_auc_delta_test
mask_criterias1.sum()
# Out:
# 540

# %%
mask_criterias2 = mask_auc_train | mask_auc_valid | mask_auc_test | mask_auc_test2 | mask_auc_delta_valid | mask_auc_delta_test | mask_auc_delta_test2
mask_criterias2.sum()
# Out:
# 570

# %%
features_criteria1 = df_auc_features['feature'].values[~mask_criterias1]
len(features_criteria1), features_criteria1
# Out:
# (61,
#  array(['close_w1_roc', 'tmos_close_w1_roc', 'volume_w5_norm_std',
#         'volume_w5_mean_abs_pct', 'close_w14_alpha', 'tmos_close_w14_rsi',
#         'tmos_close_w14_roc', 'close_w70_rsi', 'close_w70_lvl_-0.98-0.99',
#         'tmos_close_w70_alpha', 'tmos_close_w70_rsi', 'tmos_close_w70_roc',
#         'tmos_close_w70_lvl_1.005-1.01', 'tmos_close_w70_lvl_1.01-1.015',
#         'tmos_close_w70_lvl_-0.985-0.99', 'tmos_close_w70_lvl_1.02-1.03',
#         'hour', 'sin_time_hour', 'close_w5_alpha/close_w70_alpha',
#         'close_w5_mean_abs_pct/close_w70_mean_abs_pct',
#         'volume_w5_std/volume_w14_std',
#         'tmos_close_w5_std/tmos_close_w70_std',
#         'tmos_close_w5_norm_std/tmos_close_w70_norm_std',
#         'tmos_close_w14_rsi/tmos_close_w70_rsi',
#         'tmos_close/tmos_close_w70_ma',
#         'tmos_close_w5_ma/tmos_close_w70_ma',
#         'tmos_close_w14_ma/tmos_close_w70_ma', 'volume_w5_min/volume',
#         'tmos_close_w5_max/tmos_close', 'tmos_close_w14_max/tmos_close',
#         'tmos_close_w70_max/tmos_close',
#         'tmos_close_w5_ma_up_2std/tmos_close',
#         'tmos_close_w70_ma_up_2std/tmos_close',
#         'tmos_close_w70_ma_up_3std/tmos_close',
#         'volume_w5_min/volume_w5_max', 'tmos_close_1day_w1_roc',
#         'tmos_close_1day_w3_rsi', 'close_1day_w5_alpha',
#         'tmos_close_1day_w20_lvl_1-1.005',
#         'tmos_close_1day_w20_lvl_1.005-1.01',
#         'tmos_close_1day_w20_lvl_1.015-1.02',
#         'tmos_close_1day_w100_lvl_1.015-1.02',
#         'tmos_close_1day_w100_lvl_1.04-1.05',
#         'close_1day_w3_alpha/close_1day_w20_alpha',
#         'close_1day_w3_roc/close_1day_w5_roc',
#         'close_1day_w3_roc/close_1day_w20_roc',
#         'close_1day_w3_mean_abs_pct/close_1day_w5_mean_abs_pct',
#         'volume_1day_w5_mean_abs_pct/volume_1day_w20_mean_abs_pct',
#         'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
#         'close_1day_w5_std/close_1day_w20_std',
#         'tmos_close_1day_w3_std/tmos_close_1day_w5_std',
#         'tmos_close_1day_w3_norm_std/tmos_close_1day_w5_norm_std',
#         'close_1day_w5_rsi/close_1day_w20_rsi',
#         'volume_1day_w3_ma/volume_1day_w5_ma',
#         'tmos_close_1day_w3_ma/tmos_close_1day_w5_ma',
#         'close_1day_w3_min/close_1day',
#         'tmos_close_1day_w100_max/tmos_close_1day',
#         'close_1day_w3_ma_low_2std/close_1day',
#         'tmos_close_1day_w3_ma_low_2std/tmos_close_1day',
#         'tmos_close_1day_w5_ma_low_2std/tmos_close_1day',
#         'tmos_close_1day_w100_ma_up_2std/tmos_close_1day'], dtype=object))

# %%
df_auc_features.loc[df_auc_features['feature'].isin(features_criteria1)].sort_values('auc_valid', ascending=False)
# Out:
#                                                feature  auc_train  auc_valid  \
# 67                      tmos_close_w70_lvl_-0.985-0.99   0.541510   0.570131
# 187                      tmos_close_w14_max/tmos_close   0.542651   0.566806
# 542           tmos_close_1day_w100_max/tmos_close_1day   0.527333   0.556230
# 588    tmos_close_1day_w100_ma_up_2std/tmos_close_1day   0.534781   0.555855
# 64                       tmos_close_w70_lvl_1.005-1.01   0.525084   0.552860
# 32                                  tmos_close_w14_roc   0.526380   0.549637
# 186                       tmos_close_w5_max/tmos_close   0.539125   0.548944
# 70                        tmos_close_w70_lvl_1.02-1.03   0.522234   0.548810
# 31                                  tmos_close_w14_rsi   0.520516   0.547832
# 250                             tmos_close_1day_w3_rsi   0.540450   0.543352
# 447      tmos_close_1day_w3_std/tmos_close_1day_w5_std   0.528709   0.542285
# 167                       tmos_close/tmos_close_w70_ma   0.548166   0.541120
# 169                 tmos_close_w5_ma/tmos_close_w70_ma   0.534563   0.539132
# 198                tmos_close_w5_ma_up_2std/tmos_close   0.538550   0.538741
# 66                       tmos_close_w70_lvl_1.01-1.015   0.520619   0.537943
# 302                 tmos_close_1day_w20_lvl_1.015-1.02   0.526099   0.536143
# 20                                     close_w14_alpha   0.512742   0.534127
# 465  tmos_close_1day_w3_norm_std/tmos_close_1day_w5...   0.527698   0.533720
# 222               tmos_close_w70_ma_up_2std/tmos_close   0.526210   0.531522
# 224               tmos_close_w70_ma_up_3std/tmos_close   0.533842   0.528404
# 2                                    tmos_close_w1_roc   0.518604   0.528220
# 351                 tmos_close_1day_w100_lvl_1.04-1.05   0.514804   0.527563
# 236                             tmos_close_1day_w1_roc   0.530691   0.527422
# 563     tmos_close_1day_w5_ma_low_2std/tmos_close_1day   0.546549   0.526842
# 513        tmos_close_1day_w3_ma/tmos_close_1day_w5_ma   0.539949   0.526830
# 345                tmos_close_1day_w100_lvl_1.015-1.02   0.517325   0.525571
# 417  close_1day_w3_mean_abs_pct/close_1day_w5_mean_...   0.518710   0.525441
# 79                                       sin_time_hour   0.522896   0.525215
# 298                 tmos_close_1day_w20_lvl_1.005-1.01   0.510501   0.524995
# 142     tmos_close_w5_norm_std/tmos_close_w70_norm_std   0.521689   0.523759
# 188                      tmos_close_w70_max/tmos_close   0.525476   0.523695
# 76                                                hour   0.525439   0.523219
# 551     tmos_close_1day_w3_ma_low_2std/tmos_close_1day   0.534392   0.523080
# 519                       close_1day_w3_min/close_1day   0.547952   0.522303
# 61                                  tmos_close_w70_roc   0.530647   0.521769
# 133               tmos_close_w5_std/tmos_close_w70_std   0.521264   0.521685
# 0                                         close_w1_roc   0.540673   0.521399
# 429  tmos_close_1day_w3_mean_abs_pct/tmos_close_1da...   0.523204   0.520807
# 36                                       close_w70_rsi   0.531805   0.520569
# 60                                  tmos_close_w70_rsi   0.535669   0.520198
# 43                            close_w70_lvl_-0.98-0.99   0.524363   0.520042
# 391                close_1day_w3_roc/close_1day_w5_roc   0.513643   0.520003
# 8                                   volume_w5_norm_std   0.522363   0.520001
# 170                tmos_close_w14_ma/tmos_close_w70_ma   0.530213   0.519325
# 226                        volume_w5_min/volume_w5_max   0.518958   0.517844
# 152              tmos_close_w14_rsi/tmos_close_w70_rsi   0.518143   0.515871
# 438               close_1day_w5_std/close_1day_w20_std   0.521026   0.515726
# 474               close_1day_w5_rsi/close_1day_w20_rsi   0.514240   0.515478
# 362           close_1day_w3_alpha/close_1day_w20_alpha   0.525307   0.515257
# 118       close_w5_mean_abs_pct/close_w70_mean_abs_pct   0.515197   0.514784
# 296                    tmos_close_1day_w20_lvl_1-1.005   0.524778   0.514640
# 543               close_1day_w3_ma_low_2std/close_1day   0.538605   0.513550
# 85                      close_w5_alpha/close_w70_alpha   0.512621   0.513276
# 426  volume_1day_w5_mean_abs_pct/volume_1day_w20_me...   0.520807   0.512596
# 503                volume_1day_w3_ma/volume_1day_w5_ma   0.533353   0.512532
# 392               close_1day_w3_roc/close_1day_w20_roc   0.516255   0.512526
# 254                                close_1day_w5_alpha   0.510731   0.512504
# 174                               volume_w5_min/volume   0.511449   0.512487
# 59                                tmos_close_w70_alpha   0.533566   0.512246
# 129                       volume_w5_std/volume_w14_std   0.512613   0.512072
# 9                               volume_w5_mean_abs_pct   0.517264   0.510263
#
#      auc_test  auc_test2
# 67   0.518499   0.528181
# 187  0.532106   0.525026
# 542  0.513946   0.488517
# 588  0.515171   0.499053
# 64   0.549707   0.519750
# 32   0.514166   0.518476
# 186  0.544197   0.511642
# 70   0.546560   0.489203
# 31   0.526868   0.528993
# 250  0.529080   0.503274
# 447  0.529064   0.458559
# 167  0.535398   0.516530
# 169  0.529857   0.524465
# 198  0.514333   0.497616
# 66   0.549242   0.528329
# 302  0.542843   0.523953
# 20   0.514562   0.508471
# 465  0.529064   0.458559
# 222  0.536813   0.516346
# 224  0.525792   0.500499
# 2    0.517684   0.513818
# 351  0.512322   0.511488
# 236  0.552789   0.480890
# 563  0.519984   0.524703
# 513  0.553432   0.487398
# 345  0.518630   0.545056
# 417  0.511358   0.504218
# 79   0.526532   0.526451
# 298  0.538908   0.519197
# 142  0.513427   0.509026
# 188  0.536108   0.506089
# 76   0.524870   0.528374
# 551  0.513332   0.481623
# 519  0.520598   0.506180
# 61   0.542211   0.514243
# 133  0.512349   0.508978
# 0    0.529992   0.528176
# 429  0.517261   0.518306
# 36   0.519461   0.523883
# 60   0.545947   0.514218
# 43   0.511937   0.510966
# 391  0.519452   0.503306
# 8    0.515965   0.520901
# 170  0.518243   0.526212
# 226  0.514509   0.518464
# 152  0.525602   0.497810
# 438  0.510373   0.504478
# 474  0.523759   0.503031
# 362  0.518662   0.483350
# 118  0.514734   0.503172
# 296  0.519850   0.508356
# 543  0.510688   0.495943
# 85   0.514054   0.499849
# 426  0.512425   0.509518
# 503  0.510901   0.499185
# 392  0.513484   0.512445
# 254  0.517931   0.512926
# 174  0.518566   0.518781
# 59   0.533974   0.500689
# 129  0.512520   0.512193
# 9    0.520272   0.521934

# %%
features_criteria2 = df_auc_features['feature'].values[~mask_criterias2]
len(features_criteria2), features_criteria2
# Out:
# (31,
#  array(['close_w1_roc', 'tmos_close_w1_roc', 'volume_w5_norm_std',
#         'volume_w5_mean_abs_pct', 'tmos_close_w14_rsi',
#         'tmos_close_w14_roc', 'close_w70_rsi', 'close_w70_lvl_-0.98-0.99',
#         'tmos_close_w70_rsi', 'tmos_close_w70_roc',
#         'tmos_close_w70_lvl_1.005-1.01', 'tmos_close_w70_lvl_1.01-1.015',
#         'tmos_close_w70_lvl_-0.985-0.99', 'hour', 'sin_time_hour',
#         'volume_w5_std/volume_w14_std',
#         'tmos_close_w5_ma/tmos_close_w70_ma',
#         'tmos_close_w14_ma/tmos_close_w70_ma', 'volume_w5_min/volume',
#         'tmos_close_w5_max/tmos_close', 'tmos_close_w14_max/tmos_close',
#         'tmos_close_w70_ma_up_2std/tmos_close',
#         'volume_w5_min/volume_w5_max', 'close_1day_w5_alpha',
#         'tmos_close_1day_w20_lvl_1.005-1.01',
#         'tmos_close_1day_w20_lvl_1.015-1.02',
#         'tmos_close_1day_w100_lvl_1.015-1.02',
#         'tmos_close_1day_w100_lvl_1.04-1.05',
#         'close_1day_w3_roc/close_1day_w20_roc',
#         'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
#         'tmos_close_1day_w5_ma_low_2std/tmos_close_1day'], dtype=object))

# %%
df_auc_features.loc[df_auc_features['feature'].isin(features_criteria2)].sort_values('auc_valid', ascending=False)
# Out:
#                                                feature  auc_train  auc_valid  \
# 67                      tmos_close_w70_lvl_-0.985-0.99   0.541510   0.570131
# 187                      tmos_close_w14_max/tmos_close   0.542651   0.566806
# 64                       tmos_close_w70_lvl_1.005-1.01   0.525084   0.552860
# 32                                  tmos_close_w14_roc   0.526380   0.549637
# 186                       tmos_close_w5_max/tmos_close   0.539125   0.548944
# 31                                  tmos_close_w14_rsi   0.520516   0.547832
# 169                 tmos_close_w5_ma/tmos_close_w70_ma   0.534563   0.539132
# 66                       tmos_close_w70_lvl_1.01-1.015   0.520619   0.537943
# 302                 tmos_close_1day_w20_lvl_1.015-1.02   0.526099   0.536143
# 222               tmos_close_w70_ma_up_2std/tmos_close   0.526210   0.531522
# 2                                    tmos_close_w1_roc   0.518604   0.528220
# 351                 tmos_close_1day_w100_lvl_1.04-1.05   0.514804   0.527563
# 563     tmos_close_1day_w5_ma_low_2std/tmos_close_1day   0.546549   0.526842
# 345                tmos_close_1day_w100_lvl_1.015-1.02   0.517325   0.525571
# 79                                       sin_time_hour   0.522896   0.525215
# 298                 tmos_close_1day_w20_lvl_1.005-1.01   0.510501   0.524995
# 76                                                hour   0.525439   0.523219
# 61                                  tmos_close_w70_roc   0.530647   0.521769
# 0                                         close_w1_roc   0.540673   0.521399
# 429  tmos_close_1day_w3_mean_abs_pct/tmos_close_1da...   0.523204   0.520807
# 36                                       close_w70_rsi   0.531805   0.520569
# 60                                  tmos_close_w70_rsi   0.535669   0.520198
# 43                            close_w70_lvl_-0.98-0.99   0.524363   0.520042
# 8                                   volume_w5_norm_std   0.522363   0.520001
# 170                tmos_close_w14_ma/tmos_close_w70_ma   0.530213   0.519325
# 226                        volume_w5_min/volume_w5_max   0.518958   0.517844
# 392               close_1day_w3_roc/close_1day_w20_roc   0.516255   0.512526
# 254                                close_1day_w5_alpha   0.510731   0.512504
# 174                               volume_w5_min/volume   0.511449   0.512487
# 129                       volume_w5_std/volume_w14_std   0.512613   0.512072
# 9                               volume_w5_mean_abs_pct   0.517264   0.510263
#
#      auc_test  auc_test2
# 67   0.518499   0.528181
# 187  0.532106   0.525026
# 64   0.549707   0.519750
# 32   0.514166   0.518476
# 186  0.544197   0.511642
# 31   0.526868   0.528993
# 169  0.529857   0.524465
# 66   0.549242   0.528329
# 302  0.542843   0.523953
# 222  0.536813   0.516346
# 2    0.517684   0.513818
# 351  0.512322   0.511488
# 563  0.519984   0.524703
# 345  0.518630   0.545056
# 79   0.526532   0.526451
# 298  0.538908   0.519197
# 76   0.524870   0.528374
# 61   0.542211   0.514243
# 0    0.529992   0.528176
# 429  0.517261   0.518306
# 36   0.519461   0.523883
# 60   0.545947   0.514218
# 43   0.511937   0.510966
# 8    0.515965   0.520901
# 170  0.518243   0.526212
# 226  0.514509   0.518464
# 392  0.513484   0.512445
# 254  0.517931   0.512926
# 174  0.518566   0.518781
# 129  0.512520   0.512193
# 9    0.520272   0.521934

# %%
features = features_criteria2.tolist()
cat_features = [feature for feature in features if feature in cat_features_all]

# %%
len(features), len(cat_features)
# Out:
# (31, 1)

# %%
'ticker_code' in features
# Out:
# False

# %%
D_train = lgbm.Dataset(df.loc[mask_train, features], label=df.loc[mask_train, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, features], label=df.loc[mask_valid, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, features], label=df.loc[mask_test, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, features], label=df.loc[mask_test2, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)


D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
# D_test3 = lgbm.Dataset(df.loc[mask_test3, features], label=df.loc[mask_test3, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
# D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
# D_test3.time = df.loc[mask_test3, 'time'].values

# %%
def mean_income_rate_point(D_sample, y_pred, threshold=None):
    # q=threshold
    # mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    score = np.mean(D_sample.income_rate[mask]) - 1
    
    return score

def mean_income_rate_day(D_sample, y_pred, threshold=None):
    # q=threshold
    # mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup.loc[mask].groupby(pd.Grouper(key='time', freq='D')).income_rate.mean()-1).mean()

    return score
    
def mean_income_rate_month(D_sample, y_pred, threshold=None):
    # q=threshold
    # mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup.loc[mask].groupby(pd.Grouper(key='time', freq='D')).income_rate.mean()-1).mean() * df_sup.loc[mask, 'time'].dt.date.nunique()
    score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month
    
    return score


# def mean_income_rate(y_pred, data):
#     q = 0.98
#     mask = y_pred >= np.quantile(y_pred, q)
#     score = round(data.income_rate[mask].mean(), 5)
    
#     return 'mean_income_rate', score, True#is_higher_better

def mean_income_rate(y_pred, D_sample):
    q = 0.98
    mask = y_pred >= np.quantile(y_pred, q)
    #mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup.loc[mask].groupby(pd.Grouper(key='time', freq='D')).income_rate.mean()-1).mean() * df_sup.loc[mask, 'time'].dt.date.nunique()
    score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month
    score = round(score, 5)
    
    return 'mean_income_rate', score, True#is_higher_better

params = {
    "boosting_type": "gbdt",
    "objective": "binary",
    
    
    "num_boost_round" : 1_000,

    
    "num_leaves": 5,
    #"learning_rate": 0.001,
     "feature_fraction": 0.5,
     "bagging_fraction": 0.5,
     "bagging_freq": 1,
     'lambda_l1' : 10,
     'lambda_l2' : 10,
    #"verbose": 0,

    #'max_bin' : 100000,
    
    
    "metric": "auc",
    #"metric" : 'mean_income_rate',
    "early_stopping" : 50,



    
}


    

model = lgbm.train(params, train_set=D_train, valid_sets=[D_valid])#, feval=mean_income_rate, )
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/lightgbm/engine.py:204: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [108]	valid_0's auc: 0.596538

# %%
model.num_trees()
# Out:
# 108

# %%
y_pred_train = model.predict(D_train.data)
y_pred_valid = model.predict(D_valid.data)
y_pred_test = model.predict(D_test.data)
y_pred_test2 = model.predict(D_test2.data)


df["y_pred"] = None
df.loc[mask_train, 'y_pred'] = y_pred_train
df.loc[mask_valid, 'y_pred'] = y_pred_valid
df.loc[mask_test, 'y_pred'] = y_pred_test
df.loc[mask_test2, 'y_pred'] = y_pred_test2

roc_auc_score(D_train.label, y_pred_train), roc_auc_score(D_valid.label, y_pred_valid), roc_auc_score(D_test.label, y_pred_test), roc_auc_score(D_test2.label, y_pred_test2)
# Out:
# (0.6741171461277458,
#  0.5965375741986112,
#  0.5741777623744444,
#  0.5651767170050754)

# %%
#свой threshold

q = 0.9

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest')
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# Valid
# result
# WIN     0.536575
# LOSE    0.442036
# DNF     0.021389
# Name: proportion, dtype: float64
# 1.0022199533944454
#
# Test
# result
# WIN     0.532193
# LOSE    0.450970
# DNF     0.016837
# Name: proportion, dtype: float64
# 1.0021148196689103
#
# Test2
# result
# WIN     0.509567
# LOSE    0.464724
# DNF     0.025709
# Name: proportion, dtype: float64
# 1.0018499864007142

# %%
#общий threshold

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
print(f'threshokd = {threshold}')

mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print("\nTest")
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print('\nTetst2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# threshokd = 0.47283504601775955
#
# Valid
# result
# WIN     0.536575
# LOSE    0.442036
# DNF     0.021389
# Name: proportion, dtype: float64
# 1.0022199533944454
#
# Test
# result
# WIN     0.587135
# LOSE    0.405109
# DNF     0.007755
# Name: proportion, dtype: float64
# 1.0028667096032118
#
# Tetst2
# result
# WIN     0.590699
# LOSE    0.392591
# DNF     0.016710
# Name: proportion, dtype: float64
# 1.003001633691782

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.95)
mask = df['y_pred'] >= threshold

mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_point(D_test, y_pred_test, threshold=threshold), mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.002751202656536167, 0.003462604738450503, 0.003774969987863086)

# %%
#(0.00519963161109227, 0.004548106594387313, 0.005202952029520258)

# %%
df.loc[mask_valid, 'income_rate'].mean(), df.loc[mask_test, 'income_rate'].mean(), df.loc[mask_test2, 'income_rate'].mean()
# Out:
# (1.0004144396777956, 1.000358036817947, 1.0004273808299113)

# %%
mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_day(D_test, y_pred_test, threshold=threshold), mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.003300786522015099, 0.0038359945654508768, 0.0030052018128813793)

# %%
#(0.004938866300974756, 0.006170416911948592, 0.0044445648451688635)

# %%
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.07261730348433218, 0.0804666766985277, 0.0638732724297161)

# %%
#(0.06822526936695361, 0.06629610728651743, 0.06960640537179712)

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 02:00:00'),
#  Timedelta('0 days 02:00:00'),
#  Timedelta('0 days 02:00:00'))

# %%
(mask_valid&mask).sum(), (mask_test&mask).sum(), (mask_test2&mask).sum()
# Out:
# (3507, 1033, 2101)

# %%
df.loc[mask_valid&mask, 'time'].dt.date.nunique(), df.loc[mask_test&mask, 'time'].dt.date.nunique(), df.loc[mask_test2&mask, 'time'].dt.date.nunique()
# Out:
# (43, 41, 57)

# %%
df.loc[mask_test2&mask, 'ticker'].unique()
# Out:
# array(['AFLT', 'IRAO', 'MVID', 'OGKB', 'SPBE', 'MTLRP', 'SFIN', 'KMAZ',
#        'CBOM', 'MSNG', 'FEES', 'LKOH', 'FESH', 'KROT', 'LENT', 'MDMG',
#        'NKNCP', 'VKCO', 'UPRO', 'MRKY', 'SELG', 'SGZH', 'AKRN', 'CHMK',
#        'ENPG', 'YAKG', 'PMSBP', 'RKKE', 'GEMC', 'LSRG', 'MRKZ', 'BANE',
#        'CNTL', 'PMSB', 'KRKNP', 'NMTP', 'PLZL', 'TATN', 'AFKS', 'UNKL',
#        'APTK', 'LNZL', 'GMKN', 'NSVZ', 'LIFE', 'RNFT', 'VRSB', 'YDEX',
#        'UWGN', 'TGKN', 'ABRD', 'HYDR', 'ABIO', 'WUSH', 'RTKMP', 'GTRK',
#        'NLMK', 'TATNP', 'CNTLP', 'BLNG', 'ALRS', 'GCHE', 'VSMO', 'LSNG',
#        'TRNFP', 'MGNT', 'RENI', 'NKHP', 'TGKB', 'ROLO', 'IRKT', 'MGTSP',
#        'MTLR', 'TGKA', 'MSRS', 'HEAD', 'RUAL', 'MRKV', 'KLSB', 'SIBN',
#        'SNGS', 'MSTT', 'KAZTP', 'DVEC', 'NVTK', 'RASP', 'VTBR', 'PHOR',
#        'TTLK', 'NKNC', 'T', 'KAZT', 'AMEZ', 'MRKU', 'TRMK', 'MOEX',
#        'SBERP', 'VEON-RX', 'CHMF', 'RTKM', 'SMLT', 'LNZLP', 'MRKC',
#        'MRKP', 'UNAC', 'KZOSP', 'GAZP', 'ROSN', 'BELU', 'ELFV', 'FLOT',
#        'PIKK', 'LSNGP', 'SVAV', 'TGKBP', 'POSI', 'KZOS', 'MRKS', 'SNGSP',
#        'MTSS', 'MAGN', 'PRFN', 'SBER', 'BANEP', 'BSPB', 'AQUA', 'RBCM'],
#       dtype=object)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#          count  income_rate
# ticker
# LKOH       2.0     1.009000
# PLZL       2.0     1.009000
# IRAO       3.0     1.009000
# HYDR       3.0     0.999000
# AFLT       3.0     0.994000
# HEAD       4.0     0.997750
# NLMK       4.0     1.004339
# LSRG       5.0     0.997000
# BSPB       5.0     1.000000
# MSRS       5.0     1.006000
# TRMK       5.0     1.006000
# MRKP       6.0     0.996552
# GMKN       6.0     1.009000
# ENPG       6.0     1.009000
# UPRO       6.0     1.003054
# SNGS       7.0     1.006762
# MOEX       7.0     1.006857
# SELG       7.0     1.004714
# VTBR       7.0     1.008641
# RUAL       7.0     0.999513
# ELFV       7.0     1.002571
# SNGSP      7.0     0.997662
# GCHE       7.0     1.000429
# AKRN       8.0     1.007125
# MVID       8.0     1.005498
# FEES       8.0     1.001500
# RENI       8.0     1.002789
# T          8.0     1.004999
# SIBN       8.0     1.005250
# ALRS       8.0     1.003375
# POSI       9.0     1.005667
# ROSN       9.0     1.006714
# SBER       9.0     1.005667
# SBERP      9.0     1.005667
# VSMO       9.0     1.005667
# RTKM       9.0     1.009000
# YDEX       9.0     1.005458
# BELU       9.0     1.004000
# BANEP      9.0     1.004000
# MTLR      10.0     1.001500
# MDMG      10.0     1.001500
# RTKMP     11.0     1.006273
# MAGN      11.0     1.004909
# LSNGP     11.0     1.000071
# TTLK      11.0     1.003545
# CHMF      11.0     1.006273
# GAZP      11.0     1.007017
# PHOR      11.0     0.999455
# RNFT      11.0     1.002182
# NVTK      11.0     1.004813
# AQUA      11.0     1.002182
# FLOT      12.0     1.003993
# MTSS      12.0     1.005250
# SFIN      12.0     0.997750
# RKKE      12.0     1.005250
# MTLRP     12.0     1.002155
# KMAZ      12.0     1.001500
# TATNP     13.0     1.005538
# MRKV      13.0     1.002462
# TATN      13.0     1.004385
# RASP      13.0     1.002077
# NMTP      13.0     1.006317
# FESH      13.0     1.000923
# SMLT      13.0     1.005538
# BANE      13.0     0.999769
# VKCO      15.0     1.002000
# LENT      15.0     1.006000
# NKNCP     15.0     1.000000
# NKNC      15.0     1.008000
# OGKB      15.0     1.006000
# KAZT      15.0     1.006000
# AFKS      15.0     1.002000
# MSNG      15.0     1.006000
# NKHP      15.0     1.006000
# TRNFP     16.0     1.002438
# PIKK      16.0     1.002438
# PMSB      17.0     1.004575
# TGKA      17.0     1.006353
# MGTSP     17.0     1.004588
# SPBE      17.0     1.002824
# APTK      18.0     1.005667
# MGNT      18.0     1.001500
# SVAV      18.0     1.000667
# KRKNP     18.0     1.006500
# ROLO      18.0     1.004000
# ABRD      18.0     1.001812
# MRKC      19.0     0.999526
# WUSH      19.0     1.002684
# UNAC      20.0     1.004500
# KZOSP     20.0     1.003000
# KZOS      21.0     1.007571
# BLNG      22.0     1.001500
# ABIO      22.0     1.001500
# IRKT      22.0     1.001500
# LIFE      23.0     1.004116
# KAZTP     23.0     1.007043
# CNTLP     24.0     1.002750
# LSNG      24.0     1.005250
# CBOM      25.0     1.002400
# RBCM      25.0     1.005400
# CHMK      26.0     1.004962
# MRKS      26.0     1.003808
# MRKU      26.0     1.003443
# AMEZ      26.0     1.003231
# KROT      27.0     1.006180
# YAKG      27.0     1.001778
# GEMC      28.0     1.004179
# VRSB      28.0     1.004714
# GTRK      28.0     1.004179
# UWGN      29.0     1.003828
# MSTT      30.0     1.004500
# TGKN      31.0     1.003194
# DVEC      31.0     1.004645
# PMSBP     32.0     1.003145
# CNTL      32.0     1.005763
# MRKY      32.0     1.003375
# MRKZ      32.0     1.005719
# LNZL      33.0     1.002636
# NSVZ      33.0     1.005818
# KLSB      36.0     1.004833
# LNZLP     37.0     1.004748
# PRFN      37.0     1.005253
# TGKBP     37.0     1.003730
# TGKB      37.0     1.005757
# SGZH      44.0     1.000477
# VEON-RX   48.0     0.999938
# UNKL      52.0     1.002654

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: -x[1])
# Out:
# [('close_w1_roc', 14.88),
#  ('tmos_close_1day_w5_ma_low_2std/tmos_close_1day', 14.22),
#  ('tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct', 10.73),
#  ('tmos_close_1day_w100_lvl_1.015-1.02', 7.0),
#  ('tmos_close_1day_w20_lvl_1.015-1.02', 5.74),
#  ('tmos_close_w5_max/tmos_close', 5.58),
#  ('close_w70_lvl_-0.98-0.99', 4.58),
#  ('tmos_close_w14_max/tmos_close', 4.08),
#  ('tmos_close_w70_rsi', 3.81),
#  ('tmos_close_w70_lvl_-0.985-0.99', 3.62),
#  ('tmos_close_w5_ma/tmos_close_w70_ma', 3.29),
#  ('hour', 3.25),
#  ('tmos_close_w14_ma/tmos_close_w70_ma', 3.21),
#  ('close_w70_rsi', 2.88),
#  ('tmos_close_w70_roc', 1.64),
#  ('tmos_close_w70_lvl_1.01-1.015', 1.57),
#  ('volume_w5_std/volume_w14_std', 1.57),
#  ('tmos_close_w70_ma_up_2std/tmos_close', 1.22),
#  ('tmos_close_w70_lvl_1.005-1.01', 1.17),
#  ('tmos_close_w14_roc', 0.96),
#  ('tmos_close_w14_rsi', 0.94),
#  ('volume_w5_norm_std', 0.85),
#  ('tmos_close_w1_roc', 0.76),
#  ('tmos_close_1day_w20_lvl_1.005-1.01', 0.63),
#  ('volume_w5_min/volume_w5_max', 0.49),
#  ('close_1day_w3_roc/close_1day_w20_roc', 0.48),
#  ('tmos_close_1day_w100_lvl_1.04-1.05', 0.38),
#  ('sin_time_hour', 0.31),
#  ('volume_w5_min/volume', 0.16),
#  ('volume_w5_mean_abs_pct', 0.0),
#  ('close_1day_w5_alpha', 0.0)]

# %% [markdown]
# # 3.2 Tuning hyperparams

# %%
top_features = [elem[0] for elem in zip(features, model.feature_importance(importance_type='gain')) if elem[1] > 0]
top_cat_features = [elem for elem in top_features if elem in cat_features]

# %%
len(top_features), len(top_cat_features)
# Out:
# (29, 1)

# %%
top_features
# Out:
# ['close_w1_roc',
#  'tmos_close_w1_roc',
#  'volume_w5_norm_std',
#  'tmos_close_w14_rsi',
#  'tmos_close_w14_roc',
#  'close_w70_rsi',
#  'close_w70_lvl_-0.98-0.99',
#  'tmos_close_w70_rsi',
#  'tmos_close_w70_roc',
#  'tmos_close_w70_lvl_1.005-1.01',
#  'tmos_close_w70_lvl_1.01-1.015',
#  'tmos_close_w70_lvl_-0.985-0.99',
#  'hour',
#  'sin_time_hour',
#  'volume_w5_std/volume_w14_std',
#  'tmos_close_w5_ma/tmos_close_w70_ma',
#  'tmos_close_w14_ma/tmos_close_w70_ma',
#  'volume_w5_min/volume',
#  'tmos_close_w5_max/tmos_close',
#  'tmos_close_w14_max/tmos_close',
#  'tmos_close_w70_ma_up_2std/tmos_close',
#  'volume_w5_min/volume_w5_max',
#  'tmos_close_1day_w20_lvl_1.005-1.01',
#  'tmos_close_1day_w20_lvl_1.015-1.02',
#  'tmos_close_1day_w100_lvl_1.015-1.02',
#  'tmos_close_1day_w100_lvl_1.04-1.05',
#  'close_1day_w3_roc/close_1day_w20_roc',
#  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
#  'tmos_close_1day_w5_ma_low_2std/tmos_close_1day']

# %%
D_train = lgbm.Dataset(df.loc[mask_train, top_features], label=df.loc[mask_train, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, top_features], label=df.loc[mask_valid, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, top_features], label=df.loc[mask_test, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, top_features], label=df.loc[mask_test2, target], feature_name=top_features, categorical_feature=top_cat_features, free_raw_data=False)

D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
D_train.data.shape
# Out:
# (595945, 29)

# %%
def mean_income_rate_point(D_sample, y_pred, threshold=None):
    #mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    score = np.mean(D_sample.income_rate[mask]) - 1
    
    return score

def mean_income_rate_day(D_sample, y_pred, threshold=None):
    #mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup.loc[mask].groupby(pd.Grouper(key='time', freq='D')).income_rate.mean()-1).mean()

    return score
    
def mean_income_rate_month(D_sample, y_pred, threshold=None):
    #mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup.loc[mask].groupby(pd.Grouper(key='time', freq='D')).income_rate.mean()-1).mean() * df_sup.loc[mask, 'time'].dt.date.nunique()
    score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month
    
    return score

# %%
from IPython.display import clear_output

history = {'params' : [],
           'num_trees' : [],

          
           'auc_train' : [],
           'auc_valid' : [],
           'auc_test' : [],
           'auc_test2' : [],

          
           'mir_point@1_train' : [],
           'mir_point@1_valid' : [],
           'mir_point@1_test' : [],
           'mir_point@1_test2' : [],

           'mir_day@1_train' : [],
           'mir_day@1_valid' : [],
           'mir_day@1_test' : [],
           'mir_day@1_test2' : [],

           'mir_month@1_train' : [],
           'mir_month@1_valid' : [],
           'mir_month@1_test' : [],
           'mir_month@1_test2' : [],
           
           'mir_point@2_train' : [],
           'mir_point@2_valid' : [],
           'mir_point@2_test' : [],
           'mir_point@2_test2' : [],
          
           
           'mir_day@2_train' : [],
           'mir_day@2_valid' : [],
           'mir_day@2_test' : [],
           'mir_day@2_test2' : [],


           'mir_month@2_train' : [],
           'mir_month@2_valid' : [],
           'mir_month@2_test' : [],
           'mir_month@2_test2' : [],
          
          }



pbar = tqdm(total=3*1*3*9*13)
# for lambda_x in [0.001, 0.01, 0.1, 1]:
#     for learning_rate in [0.1, 0.01, 0.001]:
#         for num_leaves in [2, 4, 8, 16, 32]:
#             for feature_fraction in np.arange(1, 0, -0.1):
#                 for bagging_fraction in np.arange(1, 0, -0.1):
for lambda_x in [1, 10, 100]:
    for learning_rate in [0.1]:
        for num_leaves in [2, 5, 8]:
            for feature_fraction in np.arange(0.5, 0.95, 0.05)[::-1]:
                for bagging_fraction in np.arange(0.3, 0.95, 0.05)[::-1]:
                    feature_fraction = min(feature_fraction, 1)
                    bagging_fraction = min(bagging_fraction, 1)

                    
                    params = {
                                "boosting_type": "gbdt",
                                "objective": "binary",
                            
                                
                                 "num_leaves": num_leaves,
                                 "learning_rate": learning_rate,
                                 "feature_fraction": feature_fraction,
                                 "bagging_fraction": bagging_fraction,
                                 "bagging_freq": 1,
                                 'lambda_l1' : lambda_x,
                                 'lambda_l2' : lambda_x,
                                
                                "verbose": -1,
                                    
                                "metric": "auc",
                                "early_stopping" : 50,
                            }
                    model = lgbm.train(params, num_boost_round=2_000, train_set=D_train, valid_sets=[D_valid])
                    
                    y_pred_train = model.predict(D_train.data)
                    y_pred_valid = model.predict(D_valid.data)
                    y_pred_test = model.predict(D_test.data)
                    y_pred_test2 = model.predict(D_test2.data)
                    
                    #history
                    history['params'] += [params.copy()]
                    history['num_trees'] += [model.num_trees()]
        
                    history['auc_train'] += [roc_auc_score(D_train.label, y_pred_train)]
                    history['auc_valid'] += [roc_auc_score(D_valid.label, y_pred_valid)]
                    history['auc_test'] += [roc_auc_score(D_test.label, y_pred_test)]
                    history['auc_test2'] += [roc_auc_score(D_test2.label, y_pred_test2)]


                    threshold1 = np.quantile(y_pred_valid, q=0.99)
                    threshold2 = np.quantile(y_pred_valid, q=0.95)
                    
                    history['mir_point@1_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold1)]
                    history['mir_point@1_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold1)]
                    history['mir_point@1_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold1)]
                    history['mir_point@1_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold1)]
                   
                    history['mir_point@2_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold2)]
                    history['mir_point@2_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold2)]
                    history['mir_point@2_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold2)]
                    history['mir_point@2_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold2)]


                    history['mir_day@1_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold1)]
                    history['mir_day@1_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold1)]
                    history['mir_day@1_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold1)]
                    history['mir_day@1_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold1)]
                   
                    history['mir_day@2_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold2)]
                    history['mir_day@2_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold2)]
                    history['mir_day@2_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold2)]
                    history['mir_day@2_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold2)]

                    
                    history['mir_month@1_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold1)]
                    history['mir_month@1_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold1)]
                    history['mir_month@1_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold1)]
                    history['mir_month@1_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold1)]
                   
                    history['mir_month@2_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold2)]
                    history['mir_month@2_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold2)]
                    history['mir_month@2_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold2)]
                    history['mir_month@2_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold2)]


                    
                    clear_output()
                    pbar.update(1)
                    
pbar.close()
                    

history_cp = history.copy()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 1053/1053 [26:12<00:00,  1.49s/it]

# %%
dump_pkl(history, './history_short.pkl')

# %%
history = load_pkl('./history_short.pkl')

# %%
pd.set_option('display.max_columns', 100)
order_cols = ['params', 'num_trees', 'auc_train', 'auc_valid', 'auc_test', 'auc_test2', 'mir_point@1_train', 'mir_point@1_valid', 'mir_point@1_test', 'mir_point@1_test2', 'mir_day@1_train', 'mir_day@1_valid', 'mir_day@1_test', 'mir_day@1_test2', 'mir_month@1_train', 'mir_month@1_valid', 'mir_month@1_test', 'mir_month@1_test2', 'mir_point@2_train', 'mir_point@2_valid', 'mir_point@2_test', 'mir_point@2_test2', 'mir_day@2_train', 'mir_day@2_valid', 'mir_day@2_test', 'mir_day@2_test2', 'mir_month@2_train', 'mir_month@2_valid', 'mir_month@2_test', 'mir_month@2_test2']
df_hst = pd.DataFrame(history)[order_cols]
df_hst
# Out:
#                                                  params  num_trees  auc_train  \
# 0     {'boosting_type': 'gbdt', 'objective': 'binary...        231   0.624672
# 1     {'boosting_type': 'gbdt', 'objective': 'binary...         15   0.582667
# 2     {'boosting_type': 'gbdt', 'objective': 'binary...         15   0.582719
# 3     {'boosting_type': 'gbdt', 'objective': 'binary...         10   0.575603
# 4     {'boosting_type': 'gbdt', 'objective': 'binary...          9   0.575554
# ...                                                 ...        ...        ...
# 1048  {'boosting_type': 'gbdt', 'objective': 'binary...         20   0.639858
# 1049  {'boosting_type': 'gbdt', 'objective': 'binary...        184   0.714821
# 1050  {'boosting_type': 'gbdt', 'objective': 'binary...          8   0.620925
# 1051  {'boosting_type': 'gbdt', 'objective': 'binary...          7   0.619274
# 1052  {'boosting_type': 'gbdt', 'objective': 'binary...          8   0.620645
#
#       auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 0      0.577029  0.566511   0.555498           0.003126           0.001890
# 1      0.563847  0.565082   0.545659           0.002444           0.001887
# 2      0.563915  0.564988   0.545483           0.002439           0.001887
# 3      0.564982  0.555637   0.546275           0.002214           0.000160
# 4      0.564881  0.555605   0.546268           0.002047           0.000127
# ...         ...       ...        ...                ...                ...
# 1048   0.582361  0.573693   0.563403           0.003481           0.003958
# 1049   0.587036  0.581446   0.551033           0.005461           0.001799
# 1050   0.584648  0.572982   0.561529           0.003220           0.002639
# 1051   0.585770  0.568589   0.547346           0.003207           0.002514
# 1052   0.581744  0.560534   0.555670           0.003082           0.001687
#
#       mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 0             0.003165           0.002793         0.003343         0.002934
# 1             0.003615           0.002630         0.003005         0.003635
# 2             0.003615           0.002630         0.003088         0.003635
# 3             0.002993           0.003618         0.002720         0.002844
# 4             0.002876           0.003357         0.002564         0.002593
# ...                ...                ...              ...              ...
# 1048          0.003754           0.003560         0.002994         0.003594
# 1049          0.002646           0.001957         0.004408         0.003762
# 1050          0.004259           0.002939         0.003639         0.003456
# 1051          0.003136           0.002750         0.002953         0.003923
# 1052          0.002821           0.002898         0.003103         0.004820
#
#       mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 0           0.005155         0.003543           0.028714           0.045030
# 1           0.004071         0.002531           0.024757           0.061369
# 2           0.004071         0.002531           0.024973           0.061369
# 3           0.003408         0.002806           0.014754           0.021827
# 4           0.003238         0.002662           0.014035           0.019902
# ...              ...              ...                ...                ...
# 1048        0.003699         0.003747           0.029630           0.064360
# 1049        0.003442         0.003941           0.029667           0.048113
# 1050        0.004815         0.003684           0.021020           0.037127
# 1051        0.003086         0.002566           0.014240           0.032117
# 1052        0.002433         0.002870           0.015430           0.039453
#
#       mir_month@1_test  mir_month@1_test2  mir_point@2_train  \
# 0             0.071208           0.043593           0.002682
# 1             0.060397           0.043407           0.001955
# 2             0.060397           0.043407           0.001956
# 3             0.020925           0.020923           0.001735
# 4             0.019879           0.019853           0.001812
# ...                ...                ...                ...
# 1048          0.058670           0.053100           0.003099
# 1049          0.031699           0.044089           0.004793
# 1050          0.022170           0.039840           0.002550
# 1051          0.017366           0.017225           0.002401
# 1052          0.011204           0.012842           0.002340
#
#       mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@2_train  \
# 0              0.002151          0.002795           0.002309         0.002973
# 1              0.001820          0.002371           0.002016         0.002163
# 2              0.001820          0.002371           0.002016         0.002169
# 3              0.001843          0.002031           0.001913         0.002029
# 4              0.001662          0.002293           0.002096         0.002013
# ...                 ...               ...                ...              ...
# 1048           0.002675          0.003009           0.002698         0.002737
# 1049           0.001649          0.003230           0.003274         0.003963
# 1050           0.002335          0.002837           0.001846         0.002403
# 1051           0.002401          0.002643           0.000800         0.002302
# 1052           0.001917          0.002338           0.002161         0.002313
#
#       mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@2_train  \
# 0            0.003094        0.003275         0.002768           0.059427
# 1            0.002850        0.002668         0.002967           0.046072
# 2            0.002850        0.002668         0.002967           0.046193
# 3            0.002838        0.002634         0.002933           0.044632
# 4            0.002604        0.002331         0.002600           0.036695
# ...               ...             ...              ...                ...
# 1048         0.002818        0.003423         0.002700           0.055543
# 1049         0.003815        0.003828         0.003638           0.063102
# 1050         0.002392        0.003471         0.002642           0.042479
# 1051         0.001952        0.003341         0.002162           0.036184
# 1052         0.002598        0.002716         0.002664           0.046595
#
#       mir_month@2_valid  mir_month@2_test  mir_month@2_test2
# 0              0.068063          0.068700           0.059866
# 1              0.062704          0.058706           0.065283
# 2              0.062704          0.058706           0.065283
# 3              0.062429          0.057940           0.064520
# 4              0.053301          0.047701           0.056236
# ...                 ...               ...                ...
# 1048           0.061997          0.075298           0.059402
# 1049           0.076118          0.064626           0.067826
# 1050           0.051405          0.072817           0.055166
# 1051           0.036961          0.064948           0.041118
# 1052           0.057165          0.059755           0.057615
#
# [1053 rows x 30 columns]

# %% [markdown]
# ### threshold delta AUC

# %%
threshold = 0.03
mask_model_valid = (df_hst['auc_train'] - df_hst['auc_valid']) < threshold
mask_model_test = (df_hst['auc_train'] - df_hst['auc_test']) < threshold
mask_model_test2 = (df_hst['auc_train'] - df_hst['auc_test2']) < threshold
mask_model_valid.sum(), mask_model_test.sum(), mask_model_test2.sum()
# Out:
# (616, 314, 111)

# %%
(mask_model_valid&mask_model_test).sum(), (mask_model_valid&mask_model_test&mask_model_test2).sum()
# Out:
# (314, 110)

# %%
mask_auc = mask_model_valid&mask_model_test#&mask_model_test2
df_hst.loc[mask_auc].sort_values(by='auc_valid', ascending=False).iloc[:5]
#df_hst.loc[mask_model_valid&mask_model_test].sort_values(by='income_rate@1_valid', ascending=False).iloc[:5]
# Out:
#                                                 params  num_trees  auc_train  \
# 556  {'boosting_type': 'gbdt', 'objective': 'binary...          3   0.598675
# 989  {'boosting_type': 'gbdt', 'objective': 'binary...          2   0.598320
# 988  {'boosting_type': 'gbdt', 'objective': 'binary...          2   0.598332
# 181  {'boosting_type': 'gbdt', 'objective': 'binary...          3   0.594319
# 194  {'boosting_type': 'gbdt', 'objective': 'binary...          3   0.594319
#
#      auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 556   0.595155  0.568773   0.553453           0.002590           0.002006
# 989   0.594874  0.568714   0.557406           0.004323           0.003649
# 988   0.594549  0.568748   0.557343           0.004323           0.003649
# 181   0.586228  0.565859   0.542238           0.002234           0.002304
# 194   0.586228  0.565859   0.542238           0.002234           0.002304
#
#      mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 556          0.003462           0.002791         0.002823         0.003423
# 989               NaN           0.001131         0.004323         0.004153
# 988               NaN           0.001131         0.004323         0.004153
# 181          0.002690           0.002212         0.002579         0.003559
# 194          0.002690           0.002212         0.002579         0.003559
#
#      mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 556        0.003607         0.003319           0.047083           0.068308
# 989             NaN         0.001131           0.000217           0.006374
# 988             NaN         0.001131           0.000217           0.006374
# 181        0.003268         0.003478           0.056081           0.078302
# 194        0.003268         0.003478           0.056081           0.078302
#
#      mir_month@1_test  mir_month@1_test2  mir_point@2_train  \
# 556           0.07567           0.071791           0.001438
# 989               NaN           0.000422           0.004011
# 988               NaN           0.000422           0.004011
# 181           0.07189           0.076515           0.001091
# 194           0.07189           0.076515           0.001091
#
#      mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@2_train  \
# 556           0.001394          0.001888           0.001666         0.001659
# 989           0.003586               NaN           0.001759         0.001106
# 988           0.003586               NaN           0.001759         0.001106
# 181           0.001205          0.001448           0.001374         0.001299
# 194           0.001205          0.001448           0.001374         0.001299
#
#      mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@2_train  \
# 556         0.001958        0.002034         0.002011           0.036322
# 989         0.002833             NaN         0.001218           0.000500
# 988         0.002833             NaN         0.001218           0.000500
# 181         0.001943        0.002100         0.002131           0.028587
# 194         0.001943        0.002100         0.002131           0.028587
#
#      mir_month@2_valid  mir_month@2_test  mir_month@2_test2
# 556           0.043069          0.044758           0.044245
# 989           0.015946               NaN           0.003179
# 988           0.015946               NaN           0.003179
# 181           0.042747          0.046205           0.046881
# 194           0.042747          0.046205           0.046881

# %%
df_hst['params'].iloc[1033]
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 8,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.55,
#  'bagging_fraction': 0.5999999999999999,
#  'bagging_freq': 1,
#  'lambda_l1': 100,
#  'lambda_l2': 100,
#  'verbose': -1,
#  'metric': 'auc',
#  'early_stopping': 50}

# %% [markdown]
# ### threshold income_rate

# %%
col = 'mir_month@2'
threshold = 0.08
# mask_ir_valid = (df_hst[f'{col}_train'] - df_hst[f'{col}_valid']).abs() < threshold
# mask_ir_test = (df_hst[f'{col}_train'] - df_hst[f'{col}_test']).abs() < threshold
# mask_ir_test2 = (df_hst[f'{col}_train'] - df_hst[f'{col}_test2']).abs() < threshold

mask_ir_valid = df_hst[f'{col}_valid'] >=  threshold
mask_ir_test = df_hst[f'{col}_test'] >= threshold
mask_ir_test2 = df_hst[f'{col}_test2'] >=  threshold


mask_ir_valid.sum(), mask_ir_test.sum(), mask_ir_test2.sum()
# Out:
# (34, 65, 11)

# %%
(mask_ir_valid&mask_ir_test).sum(), (mask_ir_valid&mask_ir_test&mask_ir_test2).sum()
# Out:
# (13, 2)

# %%
mask_ir= mask_ir_valid&mask_ir_test&mask_ir_test2
mask_ir.sum()
# Out:
# 2

# %%
(mask_ir&mask_auc).sum()
# Out:
# 0

# %%
col = 'mir_day@2'
threshold = 0.0035

# mask2_ir_valid = (df_hst[f'{col}_train'] - df_hst[f'{col}_valid']).abs() < threshold
# mask2_ir_test = (df_hst[f'{col}_train'] - df_hst[f'{col}_test']).abs() < threshold
# mask2_ir_test2 = (df_hst[f'{col}_train'] - df_hst[f'{col}_test2']).abs() < threshold

mask2_ir_valid = df_hst[f'{col}_valid'] >=  threshold
mask2_ir_test = df_hst[f'{col}_test'] >= threshold
mask2_ir_test2 = df_hst[f'{col}_test2'] >=  threshold


mask2_ir_valid.sum(), mask2_ir_test.sum(), mask2_ir_test2.sum()
# Out:
# (93, 187, 53)

# %%
(mask2_ir_valid&mask2_ir_test).sum(), (mask2_ir_valid&mask2_ir_test&mask2_ir_test2).sum()
# Out:
# (76, 29)

# %%
mask2_ir = mask2_ir_valid&mask2_ir_test&mask2_ir_test2
mask2_ir.sum()
# Out:
# 29

# %%
(mask_ir&mask2_ir).sum()
# Out:
# 2

# %%
col = 'mir_point@2'
threshold = 0.003

# mask2_ir_valid = (df_hst[f'{col}_train'] - df_hst[f'{col}_valid']).abs() < threshold
# mask2_ir_test = (df_hst[f'{col}_train'] - df_hst[f'{col}_test']).abs() < threshold
# mask2_ir_test2 = (df_hst[f'{col}_train'] - df_hst[f'{col}_test2']).abs() < threshold

mask3_ir_valid = df_hst[f'{col}_valid'] >=  threshold
mask3_ir_test = df_hst[f'{col}_test'] >= threshold
mask3_ir_test2 = df_hst[f'{col}_test2'] >=  threshold


mask3_ir_valid.sum(), mask3_ir_test.sum(), mask3_ir_test2.sum()
# Out:
# (44, 227, 113)

# %%
(mask3_ir_valid&mask3_ir_test).sum(), (mask3_ir_valid&mask3_ir_test&mask3_ir_test2).sum()
# Out:
# (23, 8)

# %%
mask3_ir = mask3_ir_valid&mask3_ir_test&mask3_ir_test2
mask3_ir.sum()
# Out:
# 8

# %%
(mask_ir&mask2_ir&mask3_ir).sum()
# Out:
# 1

# %%
mask = mask_ir&mask2_ir&mask3_ir
df_hst.loc[mask].sort_values(by=f'auc_valid', ascending=False).iloc[:5]
# Out:
#                                                 params  num_trees  auc_train  \
# 587  {'boosting_type': 'gbdt', 'objective': 'binary...        110   0.706401
#
#      auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 587   0.599618   0.58237   0.552428            0.00517           0.003909
#
#      mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 587          0.004084           0.003598         0.003752         0.004633
#
#      mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 587        0.004278         0.003074           0.049382           0.073482
#
#      mir_month@1_test  mir_month@1_test2  mir_point@2_train  \
# 587          0.054724           0.049292           0.004688
#
#      mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@2_train  \
# 587            0.00351          0.003969           0.003431         0.003661
#
#      mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@2_train  \
# 587         0.003984        0.004061         0.003849           0.073007
#
#      mir_month@2_valid  mir_month@2_test  mir_month@2_test2
# 587           0.081538          0.085182           0.083233

# %%
df_hst.iloc[[587]]
# Out:
#                                                 params  num_trees  auc_train  \
# 587  {'boosting_type': 'gbdt', 'objective': 'binary...        110   0.706401
#
#      auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 587   0.599618   0.58237   0.552428            0.00517           0.003909
#
#      mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 587          0.004084           0.003598         0.003752         0.004633
#
#      mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 587        0.004278         0.003074           0.049382           0.073482
#
#      mir_month@1_test  mir_month@1_test2  mir_point@2_train  \
# 587          0.054724           0.049292           0.004688
#
#      mir_point@2_valid  mir_point@2_test  mir_point@2_test2  mir_day@2_train  \
# 587            0.00351          0.003969           0.003431         0.003661
#
#      mir_day@2_valid  mir_day@2_test  mir_day@2_test2  mir_month@2_train  \
# 587         0.003984        0.004061         0.003849           0.073007
#
#      mir_month@2_valid  mir_month@2_test  mir_month@2_test2
# 587           0.081538          0.085182           0.083233

# %%
df_hst['params'].iloc[587]
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 8,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.9000000000000004,
#  'bagging_fraction': 0.7999999999999998,
#  'bagging_freq': 1,
#  'lambda_l1': 10,
#  'lambda_l2': 10,
#  'verbose': -1,
#  'metric': 'auc',
#  'early_stopping': 50}

# %%
df_hst['params'].iloc[2006]
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 16,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.8000000000000003,
#  'bagging_fraction': 0.7,
#  'bagging_freq': 1,
#  'lambda_l1': 10,
#  'lambda_l2': 10,
#  'verbose': -1,
#  'metric': 'auc',
#  'early_stopping': 50}

# %%
df_hst['params'].iloc[1333]
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 16,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.7000000000000002,
#  'bagging_fraction': 0.7499999999999999,
#  'bagging_freq': 1,
#  'lambda_l1': 1,
#  'lambda_l2': 1,
#  'verbose': -1,
#  'metric': 'auc',
#  'early_stopping': 50}

# %% [markdown]
# # Feature selection

# %%
len(top_features), top_features
# Out:
# (29,
#  ['close_w1_roc',
#   'tmos_close_w1_roc',
#   'volume_w5_norm_std',
#   'tmos_close_w14_rsi',
#   'tmos_close_w14_roc',
#   'close_w70_rsi',
#   'close_w70_lvl_-0.98-0.99',
#   'tmos_close_w70_rsi',
#   'tmos_close_w70_roc',
#   'tmos_close_w70_lvl_1.005-1.01',
#   'tmos_close_w70_lvl_1.01-1.015',
#   'tmos_close_w70_lvl_-0.985-0.99',
#   'hour',
#   'sin_time_hour',
#   'volume_w5_std/volume_w14_std',
#   'tmos_close_w5_ma/tmos_close_w70_ma',
#   'tmos_close_w14_ma/tmos_close_w70_ma',
#   'volume_w5_min/volume',
#   'tmos_close_w5_max/tmos_close',
#   'tmos_close_w14_max/tmos_close',
#   'tmos_close_w70_ma_up_2std/tmos_close',
#   'volume_w5_min/volume_w5_max',
#   'tmos_close_1day_w20_lvl_1.005-1.01',
#   'tmos_close_1day_w20_lvl_1.015-1.02',
#   'tmos_close_1day_w100_lvl_1.015-1.02',
#   'tmos_close_1day_w100_lvl_1.04-1.05',
#   'close_1day_w3_roc/close_1day_w20_roc',
#   'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
#   'tmos_close_1day_w5_ma_low_2std/tmos_close_1day'])

# %%
top_features = ['close_w1_roc',
  'tmos_close_w1_roc',
  'volume_w5_norm_std',
  'tmos_close_w14_rsi',
  'tmos_close_w14_roc',
  'close_w70_rsi',
  'close_w70_lvl_-0.98-0.99',
  'tmos_close_w70_rsi',
  'tmos_close_w70_roc',
  'tmos_close_w70_lvl_1.005-1.01',
  'tmos_close_w70_lvl_1.01-1.015',
  'tmos_close_w70_lvl_-0.985-0.99',
  'hour',
  'sin_time_hour',
  'volume_w5_std/volume_w14_std',
  'tmos_close_w5_ma/tmos_close_w70_ma',
  'tmos_close_w14_ma/tmos_close_w70_ma',
  'volume_w5_min/volume',
  'tmos_close_w5_max/tmos_close',
  'tmos_close_w14_max/tmos_close',
  'tmos_close_w70_ma_up_2std/tmos_close',
  'volume_w5_min/volume_w5_max',
  'tmos_close_1day_w20_lvl_1.005-1.01',
  'tmos_close_1day_w20_lvl_1.015-1.02',
  'tmos_close_1day_w100_lvl_1.015-1.02',
  'tmos_close_1day_w100_lvl_1.04-1.05',
  'close_1day_w3_roc/close_1day_w20_roc',
  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
  'tmos_close_1day_w5_ma_low_2std/tmos_close_1day']

# %%
#features = features_criteria2.tolist()
features = top_features


cat_features = [elem for elem in features if elem in cat_features_all]

# %%
len(features), len(cat_features)
# Out:
# (29, 1)

# %%
'ticker_code' in features
# Out:
# False

# %%
target = 'target'

# %%
D_train = lgbm.Dataset(df.loc[mask_train, features], label=df.loc[mask_train, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, features], label=df.loc[mask_valid, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, features], label=df.loc[mask_test, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, features], label=df.loc[mask_test2, target], feature_name=features, categorical_feature=cat_features, free_raw_data=False)


D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
D_test2.data
# Out:
#          close_w1_roc  tmos_close_w1_roc  volume_w5_norm_std  \
# 8236        -0.002220          -0.001661            1.267578
# 8237        -0.003523          -0.006656            0.923771
# 8238         0.010048           0.006700            0.687177
# 8239        -0.004053          -0.001664            0.737549
# 8240         0.002405          -0.001667            0.659623
# ...               ...                ...                 ...
# 1005861     -0.005000          -0.001742            0.932474
# 1005862      0.012563          -0.001745            1.191909
# 1005863      0.000000           0.005245            0.923837
# 1005864     -0.008437           0.001739            0.643813
# 1005865      0.005005          -0.003472            0.653439
#
#          tmos_close_w14_rsi  tmos_close_w14_roc  close_w70_rsi  \
# 8236              26.086956           -0.017974      49.126213
# 8237              16.000000           -0.027687      48.622677
# 8238              33.333332           -0.013136      50.124378
# 8239              32.000000           -0.014778      50.280724
# 8240              33.333332           -0.013180      50.496895
# ...                     ...                 ...            ...
# 1005861           92.000000            0.079096      49.908924
# 1005862           92.000000            0.079245      51.668171
# 1005863           92.307693            0.082863      51.228390
# 1005864           92.307693            0.082707      50.904160
# 1005865           92.307693            0.083019      53.904045
#
#          close_w70_lvl_-0.98-0.99  tmos_close_w70_rsi  tmos_close_w70_roc  \
# 8236                         13.0           48.543690           -0.004967
# 8237                          7.0           45.714287           -0.014851
# 8238                         13.0           46.226414           -0.013136
# 8239                         14.0           45.794392           -0.014778
# 8240                         13.0           45.794392           -0.014803
# ...                           ...                 ...                 ...
# 1005861                       0.0           64.233574            0.073034
# 1005862                       5.0           63.503651            0.069159
# 1005863                       4.0           64.748199            0.076779
# 1005864                       0.0           64.748199            0.076636
# 1005865                       1.0           63.829788            0.072897
#
#          tmos_close_w70_lvl_1.005-1.01  tmos_close_w70_lvl_1.01-1.015  \
# 8236                              16.0                           22.0
# 8237                              10.0                           17.0
# 8238                              15.0                           21.0
# 8239                              20.0                           21.0
# 8240                              16.0                           15.0
# ...                                ...                            ...
# 1005861                            0.0                            0.0
# 1005862                            0.0                            0.0
# 1005863                            0.0                            0.0
# 1005864                            0.0                            0.0
# 1005865                            0.0                            0.0
#
#          tmos_close_w70_lvl_-0.985-0.99  hour  sin_time_hour  \
# 8236                                0.0  10.0   0.000000e+00
# 8237                                0.0  11.0   4.647232e-01
# 8238                                0.0  12.0   8.229839e-01
# 8239                                0.0  13.0   9.927089e-01
# 8240                                0.0  14.0   9.350162e-01
# ...                                 ...   ...            ...
# 1005861                             1.0  19.0  -9.350162e-01
# 1005862                             0.0  20.0  -9.927089e-01
# 1005863                             1.0  21.0  -8.229839e-01
# 1005864                             0.0  22.0  -4.647232e-01
# 1005865                             1.0  23.0  -2.449294e-16
#
#          volume_w5_std/volume_w14_std  tmos_close_w5_ma/tmos_close_w70_ma  \
# 8236                         1.271568                            0.997503
# 8237                         1.189302                            0.993757
# 8238                         1.202534                            0.991635
# 8239                         1.279885                            0.990196
# 8240                         1.187087                            0.989416
# ...                               ...                                 ...
# 1005861                      0.466896                            1.071707
# 1005862                      0.330529                            1.075157
# 1005863                      0.108038                            1.076981
# 1005864                      0.043232                            1.077674
# 1005865                      0.030632                            1.076548
#
#          tmos_close_w14_ma/tmos_close_w70_ma  volume_w5_min/volume  \
# 8236                                1.001861              0.038368
# 8237                                1.000071              0.221471
# 8238                                0.999317              0.190023
# 8239                                0.998468              0.440975
# 8240                                0.997737              1.000000
# ...                                      ...                   ...
# 1005861                             1.032019              1.000000
# 1005862                             1.036638              1.000000
# 1005863                             1.041404              0.637615
# 1005864                             1.046159              0.545098
# 1005865                             1.050960              1.000000
#
#          tmos_close_w5_max/tmos_close  tmos_close_w14_max/tmos_close  \
# 8236                         1.013311                       1.021631
# 8237                         1.018425                       1.021776
# 8238                         1.006656                       1.014975
# 8239                         1.003333                       1.016667
# 8240                         1.003339                       1.018364
# ...                               ...                            ...
# 1005861                      1.001745                       1.001745
# 1005862                      1.003496                       1.003496
# 1005863                      1.000000                       1.000000
# 1005864                      1.000000                       1.000000
# 1005865                      1.003484                       1.003484
#
#          tmos_close_w70_ma_up_2std/tmos_close  volume_w5_min/volume_w5_max  \
# 8236                                 1.021402                     0.038368
# 8237                                 1.028606                     0.102783
# 8238                                 1.021702                     0.102783
# 8239                                 1.023380                     0.102783
# 8240                                 1.025156                     0.199594
# ...                                       ...                          ...
# 1005861                              0.969893                     0.086531
# 1005862                              0.975761                     0.029803
# 1005863                              0.975089                     0.084963
# 1005864                              0.977646                     0.199140
# 1005865                              0.984743                     0.248175
#
#          tmos_close_1day_w20_lvl_1.005-1.01  \
# 8236                                    1.0
# 8237                                    1.0
# 8238                                    1.0
# 8239                                    1.0
# 8240                                    1.0
# ...                                     ...
# 1005861                                 2.0
# 1005862                                 2.0
# 1005863                                 2.0
# 1005864                                 2.0
# 1005865                                 2.0
#
#          tmos_close_1day_w20_lvl_1.015-1.02  \
# 8236                                    0.0
# 8237                                    0.0
# 8238                                    0.0
# 8239                                    0.0
# 8240                                    0.0
# ...                                     ...
# 1005861                                 0.0
# 1005862                                 0.0
# 1005863                                 0.0
# 1005864                                 0.0
# 1005865                                 0.0
#
#          tmos_close_1day_w100_lvl_1.015-1.02  \
# 8236                                     1.0
# 8237                                     1.0
# 8238                                     1.0
# 8239                                     1.0
# 8240                                     1.0
# ...                                      ...
# 1005861                                  0.0
# 1005862                                  0.0
# 1005863                                  0.0
# 1005864                                  0.0
# 1005865                                  0.0
#
#          tmos_close_1day_w100_lvl_1.04-1.05  \
# 8236                                    5.0
# 8237                                    5.0
# 8238                                    5.0
# 8239                                    5.0
# 8240                                    5.0
# ...                                     ...
# 1005861                                 7.0
# 1005862                                 7.0
# 1005863                                 7.0
# 1005864                                 7.0
# 1005865                                 7.0
#
#          close_1day_w3_roc/close_1day_w20_roc  \
# 8236                                 0.018768
# 8237                                 0.018768
# 8238                                 0.018768
# 8239                                 0.018768
# 8240                                 0.018768
# ...                                       ...
# 1005861                             -0.027312
# 1005862                             -0.027312
# 1005863                             -0.027312
# 1005864                             -0.027312
# 1005865                             -0.027312
#
#          tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct  \
# 8236                                              0.915336
# 8237                                              0.915336
# 8238                                              0.915336
# 8239                                              0.915336
# 8240                                              0.915336
# ...                                                    ...
# 1005861                                           0.764840
# 1005862                                           0.764840
# 1005863                                           0.764840
# 1005864                                           0.764840
# 1005865                                           0.764840
#
#          tmos_close_1day_w5_ma_low_2std/tmos_close_1day
# 8236                                           0.991829
# 8237                                           0.991829
# 8238                                           0.991829
# 8239                                           0.991829
# 8240                                           0.991829
# ...                                                 ...
# 1005861                                        0.978766
# 1005862                                        0.978766
# 1005863                                        0.978766
# 1005864                                        0.978766
# 1005865                                        0.978766
#
# [101909 rows x 29 columns]

# %%
params = {'boosting_type': 'gbdt',
 'objective': 'binary',
 'num_leaves': 8,
 'learning_rate': 0.1,
 'feature_fraction': 0.9,
 'bagging_fraction': 0.8,
 'bagging_freq': 1,
 'lambda_l1': 10,
 'lambda_l2': 10,
 'verbose': -1,
 'metric': 'auc',
 'early_stopping': 50}

model = lgbm.train(params,  num_boost_round=2_000, train_set=D_train, valid_sets=[D_valid])

# %%
model.num_trees()
# Out:
# 110

# %%
y_pred_train = model.predict(D_train.data)
y_pred_valid = model.predict(D_valid.data)
y_pred_test = model.predict(D_test.data)
y_pred_test2 = model.predict(D_test2.data)


df["y_pred"] = None
df.loc[mask_train, 'y_pred'] = y_pred_train
df.loc[mask_valid, 'y_pred'] = y_pred_valid
df.loc[mask_test, 'y_pred'] = y_pred_test
df.loc[mask_test2, 'y_pred'] = y_pred_test2

roc_auc_score(D_train.label, y_pred_train), roc_auc_score(D_valid.label, y_pred_valid), roc_auc_score(D_test.label, y_pred_test), roc_auc_score(D_test2.label, y_pred_test2)
# Out:
# (0.7064013762428721, 0.5996180649794836, 0.582370214877483, 0.552427563880197)

# %%
#свой threshold

q = 0.95

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest')
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# Valid
# result
# WIN     0.626708
# LOSE    0.360194
# DNF     0.013098
# Name: proportion, dtype: float64
# 1.0035097345945656
#
# Test
# result
# WIN     0.566810
# LOSE    0.410560
# DNF     0.022629
# Name: proportion, dtype: float64
# 1.0026801112094668
#
# Test2
# result
# WIN     0.575157
# LOSE    0.407182
# DNF     0.017661
# Name: proportion, dtype: float64
# 1.002778089078796

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 04:00:00'),
#  Timedelta('0 days 03:00:00'),
#  Timedelta('0 days 03:00:00'))

# %%
#общий threshold

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
print(f'threshokd = {threshold}')

mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print("\nTest")
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print('\nTetst2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# threshokd = 0.5285531682388958
#
# Valid
# result
# WIN     0.626708
# LOSE    0.360194
# DNF     0.013098
# Name: proportion, dtype: float64
# 1.0035097345945656
#
# Test
# result
# WIN     0.659004
# LOSE    0.332375
# DNF     0.008621
# Name: proportion, dtype: float64
# 1.0039689812684314
#
# Tetst2
# result
# WIN     0.620508
# LOSE    0.364655
# DNF     0.014837
# Name: proportion, dtype: float64
# 1.0034312476326546

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 03:00:00'),
#  Timedelta('0 days 02:00:00'),
#  Timedelta('0 days 03:00:00'))

# %%
(mask_valid&mask).sum(), (mask_test&mask).sum(), (mask_test2&mask).sum()
# Out:
# (3512, 1044, 3033)

# %%
df.loc[mask_valid&mask, 'time'].dt.date.nunique(), df.loc[mask_test&mask, 'time'].dt.date.nunique(), df.loc[mask_test2&mask, 'time'].dt.date.nunique()
# Out:
# (40, 41, 58)

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.95)

# %%
mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_point(D_test, y_pred_test, threshold=threshold), mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0035097345945656055, 0.003968981268431371, 0.003431247632654566)

# %%
mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_day(D_test, y_pred_test, threshold=threshold), mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.003984238563665724, 0.004060778432288979, 0.003848561478189244)

# %%
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.08153790548897295, 0.08518191037034091, 0.08323329569778773)

# %%
df.loc[mask_test2&mask, 'ticker'].unique()
# Out:
# array(['AFLT', 'IRAO', 'MVID', 'OGKB', 'SPBE', 'MTLRP', 'SFIN', 'KMAZ',
#        'CBOM', 'MSNG', 'FEES', 'LKOH', 'FESH', 'KROT', 'LENT', 'MDMG',
#        'NKNCP', 'VKCO', 'UPRO', 'MRKY', 'SELG', 'SGZH', 'AKRN', 'CHMK',
#        'ENPG', 'YAKG', 'PMSBP', 'RKKE', 'GEMC', 'LSRG', 'MRKZ', 'BANE',
#        'CNTL', 'PMSB', 'KRKNP', 'NMTP', 'PLZL', 'TATN', 'AFKS', 'UNKL',
#        'APTK', 'LNZL', 'GMKN', 'NSVZ', 'LIFE', 'RNFT', 'VRSB', 'YDEX',
#        'UWGN', 'TGKN', 'ABRD', 'HYDR', 'ABIO', 'WUSH', 'RTKMP', 'GTRK',
#        'NLMK', 'TATNP', 'CNTLP', 'BLNG', 'ALRS', 'GCHE', 'VSMO', 'LSNG',
#        'TRNFP', 'MGNT', 'RENI', 'NKHP', 'TGKB', 'ROLO', 'IRKT', 'MGTSP',
#        'MTLR', 'TGKA', 'MSRS', 'HEAD', 'RUAL', 'MRKV', 'KLSB', 'SIBN',
#        'SNGS', 'MSTT', 'KAZTP', 'DVEC', 'NVTK', 'RASP', 'VTBR', 'PHOR',
#        'TTLK', 'NKNC', 'T', 'KAZT', 'AMEZ', 'MRKU', 'TRMK', 'MOEX',
#        'SBERP', 'VEON-RX', 'CHMF', 'RTKM', 'SMLT', 'LNZLP', 'MRKC',
#        'MRKP', 'UNAC', 'KZOSP', 'GAZP', 'ROSN', 'BELU', 'ELFV', 'FLOT',
#        'PIKK', 'LSNGP', 'SVAV', 'TGKBP', 'POSI', 'KZOS', 'MRKS', 'SNGSP',
#        'MTSS', 'MAGN', 'PRFN', 'SBER', 'BANEP', 'BSPB', 'AQUA', 'RBCM'],
#       dtype=object)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#          count  income_rate
# ticker
# HEAD       4.0     0.997750
# BELU       6.0     1.006500
# AKRN       7.0     1.000429
# PLZL      11.0     0.998091
# LKOH      12.0     1.002750
# IRAO      13.0     1.004385
# HYDR      13.0     1.003231
# TRMK      13.0     1.003231
# RENI      13.0     1.004024
# SNGS      14.0     1.001542
# BSPB      14.0     1.002571
# ENPG      15.0     1.006000
# PMSB      15.0     1.006000
# SBERP     15.0     1.006000
# NLMK      15.0     1.000757
# POSI      15.0     1.006000
# SELG      15.0     1.003000
# ELFV      15.0     1.003000
# AFLT      15.0     1.002773
# BANEP     15.0     1.002000
# SIBN      16.0     1.004313
# SBER      16.0     1.006188
# VTBR      17.0     1.005471
# NVTK      17.0     1.006291
# PHOR      17.0     1.001941
# UPRO      17.0     1.001607
# AQUA      17.0     1.004492
# YDEX      17.0     1.004588
# ROSN      17.0     1.001614
# FLOT      17.0     1.002824
# SNGSP     17.0     0.996647
# T         17.0     1.006353
# SFIN      18.0     1.001500
# TTLK      18.0     1.005468
# RTKM      18.0     1.005667
# PIKK      18.0     1.002333
# LSNGP     18.0     1.004109
# SMLT      18.0     1.004833
# MTSS      18.0     1.007333
# MGTSP     18.0     1.004101
# TATN      18.0     1.002333
# MSRS      18.0     1.005241
# LENT      19.0     1.003474
# WUSH      19.0     1.005053
# NMTP      19.0     1.006758
# ALRS      19.0     1.001895
# GMKN      19.0     1.005842
# MOEX      19.0     1.003474
# RUAL      19.0     1.002347
# RTKMP     19.0     1.005842
# OGKB      20.0     1.004500
# RNFT      20.0     1.003750
# MTLR      20.0     1.001500
# BANE      20.0     1.002932
# TRNFP     20.0     1.003000
# ABRD      20.0     1.003727
# MSNG      20.0     1.004500
# CHMF      21.0     1.004000
# RKKE      21.0     1.000429
# TGKA      21.0     1.006143
# NKNCP     21.0     1.001143
# KMAZ      21.0     1.003286
# MTLRP     21.0     1.002231
# GAZP      21.0     1.005818
# RASP      21.0     1.000429
# MGNT      21.0     1.001857
# KRKNP     21.0     1.001857
# MAGN      21.0     1.003286
# MRKP      21.0     0.999729
# FESH      22.0     1.002182
# TATNP     22.0     1.004227
# FEES      22.0     1.001500
# LSRG      22.0     1.001500
# MRKV      22.0     1.004455
# MVID      22.0     1.004317
# AFKS      23.0     1.001826
# VSMO      23.0     1.007043
# MDMG      23.0     1.000030
# VKCO      23.0     1.006391
# KAZT      24.0     1.002125
# NKNC      24.0     1.005250
# BLNG      25.0     1.003000
# IRKT      25.0     1.003000
# SPBE      26.0     1.002654
# NKHP      26.0     1.004385
# CHMK      27.0     1.002889
# GCHE      27.0     1.004881
# APTK      27.0     1.003532
# KROT      28.0     1.005250
# SVAV      28.0     1.001500
# CNTL      29.0     1.001980
# GEMC      29.0     1.002276
# KZOSP     29.0     1.001241
# UWGN      29.0     1.005379
# RBCM      30.0     1.004500
# AMEZ      30.0     1.004000
# UNAC      30.0     1.006500
# MRKC      30.0     1.000500
# ABIO      30.0     1.003000
# KZOS      31.0     1.006097
# CBOM      31.0     1.003194
# YAKG      32.0     1.002906
# ROLO      32.0     1.003844
# PMSBP     32.0     1.003580
# GTRK      32.0     1.003375
# CNTLP     35.0     1.000857
# MRKU      35.0     1.003587
# KAZTP     35.0     1.004286
# MRKS      35.0     1.004286
# DVEC      36.0     1.004417
# LSNG      36.0     1.005667
# PRFN      37.0     1.004442
# VRSB      37.0     1.002919
# TGKN      38.0     1.002289
# LNZL      39.0     1.003229
# LIFE      39.0     1.004966
# MRKZ      40.0     1.003375
# MRKY      41.0     1.002415
# KLSB      41.0     1.005707
# MSTT      41.0     1.003512
# NSVZ      41.0     1.004244
# TGKB      42.0     1.004714
# SGZH      42.0     1.000786
# LNZLP     42.0     1.004540
# TGKBP     44.0     1.002523
# UNKL      54.0     1.002056
# VEON-RX   55.0     1.000818

# %% [markdown]
# # Drop weak features

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1])
# Out:
# [('sin_time_hour', 0.11),
#  ('volume_w5_min/volume', 0.3),
#  ('volume_w5_min/volume_w5_max', 0.3),
#  ('close_1day_w3_roc/close_1day_w20_roc', 0.31),
#  ('tmos_close_w1_roc', 0.73),
#  ('tmos_close_w70_lvl_1.005-1.01', 0.9),
#  ('volume_w5_std/volume_w14_std', 1.01),
#  ('volume_w5_norm_std', 1.1),
#  ('tmos_close_w14_roc', 1.2),
#  ('tmos_close_w14_rsi', 1.63),
#  ('tmos_close_w70_lvl_1.01-1.015', 1.85),
#  ('tmos_close_w70_lvl_-0.985-0.99', 2.04),
#  ('tmos_close_1day_w20_lvl_1.005-1.01', 2.05),
#  ('tmos_close_1day_w100_lvl_1.04-1.05', 2.07),
#  ('tmos_close_w70_rsi', 2.14),
#  ('tmos_close_w70_roc', 2.17),
#  ('close_w70_rsi', 2.54),
#  ('hour', 2.6),
#  ('tmos_close_w70_ma_up_2std/tmos_close', 2.76),
#  ('tmos_close_w14_ma/tmos_close_w70_ma', 2.97),
#  ('close_w70_lvl_-0.98-0.99', 3.75),
#  ('tmos_close_w5_ma/tmos_close_w70_ma', 3.77),
#  ('tmos_close_w14_max/tmos_close', 3.8),
#  ('tmos_close_1day_w100_lvl_1.015-1.02', 4.51),
#  ('tmos_close_1day_w20_lvl_1.015-1.02', 4.74),
#  ('tmos_close_w5_max/tmos_close', 6.49),
#  ('close_w1_roc', 11.02),
#  ('tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct', 13.82),
#  ('tmos_close_1day_w5_ma_low_2std/tmos_close_1day', 17.34)]

# %%
features_order_to_drop = []
for elem in sorted(zip(features, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1]):
    if elem[1] > 0:
        features_order_to_drop += [elem[0]]
features_order_to_drop
# Out:
# ['sin_time_hour',
#  'volume_w5_min/volume',
#  'volume_w5_min/volume_w5_max',
#  'close_1day_w3_roc/close_1day_w20_roc',
#  'tmos_close_w1_roc',
#  'tmos_close_w70_lvl_1.005-1.01',
#  'volume_w5_std/volume_w14_std',
#  'volume_w5_norm_std',
#  'tmos_close_w14_roc',
#  'tmos_close_w14_rsi',
#  'tmos_close_w70_lvl_1.01-1.015',
#  'tmos_close_w70_lvl_-0.985-0.99',
#  'tmos_close_1day_w20_lvl_1.005-1.01',
#  'tmos_close_1day_w100_lvl_1.04-1.05',
#  'tmos_close_w70_rsi',
#  'tmos_close_w70_roc',
#  'close_w70_rsi',
#  'hour',
#  'tmos_close_w70_ma_up_2std/tmos_close',
#  'tmos_close_w14_ma/tmos_close_w70_ma',
#  'close_w70_lvl_-0.98-0.99',
#  'tmos_close_w5_ma/tmos_close_w70_ma',
#  'tmos_close_w14_max/tmos_close',
#  'tmos_close_1day_w100_lvl_1.015-1.02',
#  'tmos_close_1day_w20_lvl_1.015-1.02',
#  'tmos_close_w5_max/tmos_close',
#  'close_w1_roc',
#  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
#  'tmos_close_1day_w5_ma_low_2std/tmos_close_1day']

# %%
cat_features = [elem for elem in features_order_to_drop if elem in cat_features_all]
len(cat_features)
# Out:
# 1

# %%
params
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'num_leaves': 8,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.9,
#  'bagging_fraction': 0.8,
#  'bagging_freq': 1,
#  'lambda_l1': 10,
#  'lambda_l2': 10,
#  'verbose': -1,
#  'metric': 'auc',
#  'early_stopping': 50}

# %%
from IPython.display import clear_output

history_fe = {'features' : [],
           'num_trees' : [],

           'auc_train' : [],
           'auc_valid' : [],
           'auc_test' : [],
           'auc_test2' : [],
           
           'mir_point@1_train' : [],
           'mir_point@1_valid' : [],
           'mir_point@1_test' : [],
           'mir_point@1_test2' : [],
              
           'mir_day@1_train' : [],
           'mir_day@1_valid' : [],
           'mir_day@1_test' : [],
           'mir_day@1_test2' : [],
              
           'mir_month@1_train' : [],
           'mir_month@1_valid' : [],
           'mir_month@1_test' : [],
           'mir_month@1_test2' : [],
          
          }
    
for i in tqdm(range(len(features_order_to_drop))):
    features_fe = features_order_to_drop[i:]
    cat_features = [elem for elem in features_fe if elem in cat_features_all]

    D_train = lgbm.Dataset(df.loc[mask_train, features_fe], label=df.loc[mask_train, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    D_valid = lgbm.Dataset(df.loc[mask_valid, features_fe], label=df.loc[mask_valid, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    D_test = lgbm.Dataset(df.loc[mask_test, features_fe], label=df.loc[mask_test, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    D_test2 = lgbm.Dataset(df.loc[mask_test2, features_fe], label=df.loc[mask_test2, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
    
    D_train.income_rate = df.loc[mask_train, 'income_rate'].values
    D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
    D_test.income_rate = df.loc[mask_test, 'income_rate'].values
    D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

    D_train.time = df.loc[mask_train, 'time'].values
    D_valid.time = df.loc[mask_valid, 'time'].values
    D_test.time = df.loc[mask_test, 'time'].values
    D_test2.time = df.loc[mask_test2, 'time'].values

    model = lgbm.train(params, num_boost_round=2_000, train_set=D_train, valid_sets=[D_valid])
                    
    y_pred_train = model.predict(D_train.data)
    y_pred_valid = model.predict(D_valid.data)
    y_pred_test = model.predict(D_test.data)
    y_pred_test2 = model.predict(D_test2.data)
    
    #history_fe
    history_fe['features'] += [features_fe.copy()]
    history_fe['num_trees'] += [model.num_trees()]

    history_fe['auc_train'] += [roc_auc_score(D_train.label, y_pred_train)]
    history_fe['auc_valid'] += [roc_auc_score(D_valid.label, y_pred_valid)]
    history_fe['auc_test'] += [roc_auc_score(D_test.label, y_pred_test)]
    history_fe['auc_test2'] += [roc_auc_score(D_test2.label, y_pred_test2)]

    threshold1 = np.quantile(y_pred_valid, q=0.95)
      
    history_fe['mir_point@1_train'] += [mean_income_rate_point(D_train, y_pred_train, threshold=threshold1)]
    history_fe['mir_point@1_valid'] += [mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold1)]
    history_fe['mir_point@1_test'] += [mean_income_rate_point(D_test, y_pred_test, threshold=threshold1)]
    history_fe['mir_point@1_test2'] += [mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold1)]
    
    history_fe['mir_day@1_train'] += [mean_income_rate_day(D_train, y_pred_train, threshold=threshold1)]
    history_fe['mir_day@1_valid'] += [mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold1)]
    history_fe['mir_day@1_test'] += [mean_income_rate_day(D_test, y_pred_test, threshold=threshold1)]
    history_fe['mir_day@1_test2'] += [mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold1)]
    
    history_fe['mir_month@1_train'] += [mean_income_rate_month(D_train, y_pred_train, threshold=threshold1)]
    history_fe['mir_month@1_valid'] += [mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold1)]
    history_fe['mir_month@1_test'] += [mean_income_rate_month(D_test, y_pred_test, threshold=threshold1)]
    history_fe['mir_month@1_test2'] += [mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold1)]
                   



    #clear_output()
# Out:
#  93%|███████████████████████████████████████████████████████████████████▉     | 27/29 [00:40<00:02,  1.05s/it]/opt/anaconda3/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|█████████████████████████████████████████████████████████████████████████| 29/29 [00:42<00:00,  1.47s/it]

# %%
df_hst_fe = pd.DataFrame(history_fe)
df_hst_fe
# Out:
#                                              features  num_trees  auc_train  \
# 0   [sin_time_hour, volume_w5_min/volume, volume_w...        198   0.733658
# 1   [volume_w5_min/volume, volume_w5_min/volume_w5...          8   0.626349
# 2   [volume_w5_min/volume_w5_max, close_1day_w3_ro...          5   0.617089
# 3   [close_1day_w3_roc/close_1day_w20_roc, tmos_cl...          4   0.612161
# 4   [tmos_close_w1_roc, tmos_close_w70_lvl_1.005-1...         19   0.643543
# 5   [tmos_close_w70_lvl_1.005-1.01, volume_w5_std/...        155   0.725221
# 6   [volume_w5_std/volume_w14_std, volume_w5_norm_...         27   0.655332
# 7   [volume_w5_norm_std, tmos_close_w14_roc, tmos_...         14   0.635161
# 8   [tmos_close_w14_roc, tmos_close_w14_rsi, tmos_...         18   0.645007
# 9   [tmos_close_w14_rsi, tmos_close_w70_lvl_1.01-1...        171   0.727386
# 10  [tmos_close_w70_lvl_1.01-1.015, tmos_close_w70...          4   0.610072
# 11  [tmos_close_w70_lvl_-0.985-0.99, tmos_close_1d...          2   0.598932
# 12  [tmos_close_1day_w20_lvl_1.005-1.01, tmos_clos...         16   0.638584
# 13  [tmos_close_1day_w100_lvl_1.04-1.05, tmos_clos...         11   0.630843
# 14  [tmos_close_w70_rsi, tmos_close_w70_roc, close...         62   0.679490
# 15  [tmos_close_w70_roc, close_w70_rsi, hour, tmos...         15   0.640389
# 16  [close_w70_rsi, hour, tmos_close_w70_ma_up_2st...         16   0.638406
# 17  [hour, tmos_close_w70_ma_up_2std/tmos_close, t...         45   0.663421
# 18  [tmos_close_w70_ma_up_2std/tmos_close, tmos_cl...          5   0.611144
# 19  [tmos_close_w14_ma/tmos_close_w70_ma, close_w7...          5   0.613305
# 20  [close_w70_lvl_-0.98-0.99, tmos_close_w5_ma/tm...         92   0.687420
# 21  [tmos_close_w5_ma/tmos_close_w70_ma, tmos_clos...         15   0.630530
# 22  [tmos_close_w14_max/tmos_close, tmos_close_1da...          2   0.598729
# 23  [tmos_close_1day_w100_lvl_1.015-1.02, tmos_clo...         57   0.669771
# 24  [tmos_close_1day_w20_lvl_1.015-1.02, tmos_clos...         91   0.687240
# 25  [tmos_close_w5_max/tmos_close, close_w1_roc, t...         10   0.613478
# 26  [close_w1_roc, tmos_close_1day_w3_mean_abs_pct...          2   0.583995
# 27  [tmos_close_1day_w3_mean_abs_pct/tmos_close_1d...         53   0.656068
# 28   [tmos_close_1day_w5_ma_low_2std/tmos_close_1day]         79   0.635685
#
#     auc_valid  auc_test  auc_test2  mir_point@1_train  mir_point@1_valid  \
# 0    0.605363  0.588251   0.566186           0.005320           0.002203
# 1    0.592369  0.567153   0.544459           0.002744           0.002199
# 2    0.597449  0.563820   0.540159           0.002400           0.002699
# 3    0.581042  0.571640   0.539485           0.002089           0.002281
# 4    0.584569  0.576878   0.551086           0.003359           0.003056
# 5    0.581633  0.578709   0.551594           0.004945           0.001972
# 6    0.591613  0.587970   0.541675           0.003341           0.002632
# 7    0.584168  0.562551   0.540024           0.002796           0.001442
# 8    0.593090  0.577566   0.549284           0.002760           0.002264
# 9    0.603621  0.576106   0.561384           0.005111           0.002727
# 10   0.587565  0.568763   0.535223           0.001725           0.001660
# 11   0.576465  0.558644   0.539835           0.001851           0.001592
# 12   0.584375  0.579817   0.547017           0.003074           0.002370
# 13   0.595853  0.574546   0.559451           0.002674           0.002554
# 14   0.593048  0.578862   0.553060           0.004394           0.002576
# 15   0.598035  0.574202   0.546889           0.003221           0.002758
# 16   0.580452  0.580025   0.555406           0.003105           0.001885
# 17   0.581921  0.584261   0.546988           0.004559           0.002132
# 18   0.587364  0.565582   0.552388           0.001639           0.001775
# 19   0.590429  0.564605   0.547468           0.002289           0.002475
# 20   0.590689  0.572401   0.543948           0.004636           0.002094
# 21   0.584839  0.575258   0.551246           0.002616           0.003143
# 22   0.582269  0.568956   0.535589           0.002431           0.002140
# 23   0.580974  0.602528   0.537651           0.004408           0.001834
# 24   0.590844  0.595105   0.537035           0.004595           0.002099
# 25   0.582474  0.573837   0.551870           0.002075           0.001890
# 26   0.556212  0.529639   0.545565           0.002608           0.003344
# 27   0.535823  0.514837   0.550336           0.004090           0.001200
# 28   0.555491  0.505207   0.514943           0.002850           0.001606
#
#     mir_point@1_test  mir_point@1_test2  mir_day@1_train  mir_day@1_valid  \
# 0           0.003810           0.003521         0.004375         0.003251
# 1           0.002413           0.002320         0.002435         0.002864
# 2           0.002609           0.002344         0.002444         0.003178
# 3           0.002165           0.001655         0.002047         0.002570
# 4           0.003245           0.002576         0.002848         0.003406
# 5           0.003755           0.003535         0.003968         0.003743
# 6           0.002640           0.002069         0.002874         0.003287
# 7           0.002697           0.001501         0.002647         0.003120
# 8           0.002785           0.002028         0.002737         0.003247
# 9           0.003434           0.004079         0.003959         0.003684
# 10          0.001907           0.001775         0.001914         0.002491
# 11          0.001977           0.001627         0.001342         0.001862
# 12          0.002606           0.002299         0.002624         0.003271
# 13          0.002701           0.002582         0.002544         0.003087
# 14          0.003232           0.002651         0.003071         0.003256
# 15          0.002576           0.001596         0.002898         0.003264
# 16          0.002947           0.002214         0.002683         0.002889
# 17          0.003274           0.002969         0.003493         0.003719
# 18          0.001918           0.001858         0.001897         0.002516
# 19          0.002993           0.001611         0.002578         0.003328
# 20          0.003755           0.003596         0.003752         0.004036
# 21          0.002759           0.002008         0.002581         0.003412
# 22          0.002666           0.001889         0.002503         0.002869
# 23          0.004077           0.004148         0.003644         0.003281
# 24          0.003005           0.002345         0.003354         0.003980
# 25          0.002089           0.001886         0.002068         0.002940
# 26          0.002690           0.002212         0.002562         0.003552
# 27         -0.003321                NaN         0.003708         0.001184
# 28         -0.000479          -0.000816         0.002648        -0.000126
#
#     mir_day@1_test  mir_day@1_test2  mir_month@1_train  mir_month@1_valid  \
# 0         0.004013         0.003654           0.071424           0.058214
# 1         0.002869         0.003028           0.053090           0.063001
# 2         0.003085         0.003197           0.053271           0.069918
# 3         0.002515         0.002428           0.044729           0.056542
# 4         0.003572         0.003038           0.061091           0.074934
# 5         0.003683         0.003398           0.067759           0.070853
# 6         0.003355         0.003183           0.061353           0.072307
# 7         0.003235         0.003293           0.057429           0.068640
# 8         0.003388         0.003200           0.059535           0.071441
# 9         0.005079         0.003918           0.058854           0.067851
# 10        0.002559         0.002664           0.042098           0.054813
# 11        0.001758         0.001642           0.021375           0.037146
# 12        0.003273         0.003333           0.057079           0.071959
# 13        0.003214         0.003446           0.055448           0.067923
# 14        0.003148         0.003141           0.059997           0.071641
# 15        0.003335         0.002862           0.056477           0.070132
# 16        0.003227         0.003072           0.058228           0.063561
# 17        0.003844         0.003183           0.061412           0.081808
# 18        0.002492         0.002671           0.041742           0.055347
# 19        0.003192         0.003377           0.056079           0.073223
# 20        0.003248         0.004099           0.062191           0.076407
# 21        0.003260         0.003419           0.056266           0.075069
# 22        0.003014         0.002812           0.054566           0.063118
# 23        0.003698         0.003882           0.058395           0.062112
# 24        0.003049         0.003990           0.063676           0.075339
# 25        0.002740         0.003000           0.045503           0.064674
# 26        0.003268         0.003478           0.055711           0.078138
# 27       -0.003321              NaN           0.005774           0.001817
# 28       -0.000368        -0.000807           0.007848          -0.000322
#
#     mir_month@1_test  mir_month@1_test2
# 0           0.069799           0.065403
# 1           0.063114           0.066627
# 2           0.067865           0.070329
# 3           0.055324           0.053420
# 4           0.078575           0.064562
# 5           0.067836           0.067163
# 6           0.073818           0.070019
# 7           0.071168           0.072437
# 8           0.074547           0.070403
# 9           0.080552           0.067209
# 10          0.056293           0.058601
# 11          0.038670           0.035514
# 12          0.071996           0.073315
# 13          0.070719           0.075814
# 14          0.064423           0.067928
# 15          0.069964           0.059765
# 16          0.070997           0.067581
# 17          0.066876           0.066457
# 18          0.054824           0.058754
# 19          0.070221           0.074289
# 20          0.061478           0.079486
# 21          0.071711           0.075209
# 22          0.066310           0.061870
# 23          0.071892           0.079612
# 24          0.062404           0.080350
# 25          0.060282           0.066003
# 26          0.071890           0.076515
# 27         -0.001699                NaN
# 28         -0.001319          -0.001505

# %%
df_hst_fe['features'].loc[5]
# Out:
# ['tmos_close_w70_lvl_1.005-1.01',
#  'volume_w5_std/volume_w14_std',
#  'volume_w5_norm_std',
#  'tmos_close_w14_roc',
#  'tmos_close_w14_rsi',
#  'tmos_close_w70_lvl_1.01-1.015',
#  'tmos_close_w70_lvl_-0.985-0.99',
#  'tmos_close_1day_w20_lvl_1.005-1.01',
#  'tmos_close_1day_w100_lvl_1.04-1.05',
#  'tmos_close_w70_rsi',
#  'tmos_close_w70_roc',
#  'close_w70_rsi',
#  'hour',
#  'tmos_close_w70_ma_up_2std/tmos_close',
#  'tmos_close_w14_ma/tmos_close_w70_ma',
#  'close_w70_lvl_-0.98-0.99',
#  'tmos_close_w5_ma/tmos_close_w70_ma',
#  'tmos_close_w14_max/tmos_close',
#  'tmos_close_1day_w100_lvl_1.015-1.02',
#  'tmos_close_1day_w20_lvl_1.015-1.02',
#  'tmos_close_w5_max/tmos_close',
#  'close_w1_roc',
#  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
#  'tmos_close_1day_w5_ma_low_2std/tmos_close_1day']

# %% [markdown]
# # BEST

# %%
features_fe = ['tmos_close_w14_rsi',
 'tmos_close_w70_lvl_1.01-1.015',
 'tmos_close_w70_lvl_-0.985-0.99',
 'tmos_close_1day_w20_lvl_1.005-1.01',
 'tmos_close_1day_w100_lvl_1.04-1.05',
 'tmos_close_w70_rsi',
 'tmos_close_w70_roc',
 'close_w70_rsi',
 'hour',
 'tmos_close_w70_ma_up_2std/tmos_close',
 'tmos_close_w14_ma/tmos_close_w70_ma',
 'close_w70_lvl_-0.98-0.99',
 'tmos_close_w5_ma/tmos_close_w70_ma',
 'tmos_close_w14_max/tmos_close',
 'tmos_close_1day_w100_lvl_1.015-1.02',
 'tmos_close_1day_w20_lvl_1.015-1.02',
 'tmos_close_w5_max/tmos_close',
 'close_w1_roc',
 'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
 'tmos_close_1day_w5_ma_low_2std/tmos_close_1day']


# features_fe = ['tmos_close_w70_lvl_1.005-1.01',
#  'volume_w5_std/volume_w14_std',
#  'volume_w5_norm_std',
#  'tmos_close_w14_roc',
#  'tmos_close_w14_rsi',
#  'tmos_close_w70_lvl_1.01-1.015',
#  'tmos_close_w70_lvl_-0.985-0.99',
#  'tmos_close_1day_w20_lvl_1.005-1.01',
#  'tmos_close_1day_w100_lvl_1.04-1.05',
#  'tmos_close_w70_rsi',
#  'tmos_close_w70_roc',
#  'close_w70_rsi',
#  'hour',
#  'tmos_close_w70_ma_up_2std/tmos_close',
#  'tmos_close_w14_ma/tmos_close_w70_ma',
#  'close_w70_lvl_-0.98-0.99',
#  'tmos_close_w5_ma/tmos_close_w70_ma',
#  'tmos_close_w14_max/tmos_close',
#  'tmos_close_1day_w100_lvl_1.015-1.02',
#  'tmos_close_1day_w20_lvl_1.015-1.02',
#  'tmos_close_w5_max/tmos_close',
#  'close_w1_roc',
#  'tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct',
#  'tmos_close_1day_w5_ma_low_2std/tmos_close_1day']

# %%
#params

# %%
params = {'boosting_type': 'gbdt',
 'objective': 'binary',
 'num_leaves': 8,
 'learning_rate': 0.1,
 'feature_fraction': 0.9,
 'bagging_fraction': 0.8,
 'bagging_freq': 1,
 'lambda_l1': 10,
 'lambda_l2': 10,
 'verbose': -1,
 'metric': 'auc',
 'early_stopping': 50}

# %%
target = 'target'
cat_features = [elem for elem in features_fe if elem in cat_features_all]
len(cat_features)
# Out:
# 1

# %%
def mean_income_rate_point(D_sample, y_pred, threshold=None):
    #mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    score = np.mean(D_sample.income_rate[mask]) - 1
    
    return score

def mean_income_rate_day(D_sample, y_pred, threshold=None):
    #mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup.loc[mask].groupby(pd.Grouper(key='time', freq='D')).income_rate.mean()-1).mean()

    return score
    
def mean_income_rate_month(D_sample, y_pred, threshold=None):
    #mask = y_pred >= np.quantile(y_pred, q)
    mask = y_pred >= threshold
    df_sup = pd.DataFrame({'time' : D_sample.time,
                           'income_rate' : D_sample.income_rate,
                           'y_pred' : y_pred})
    score = (df_sup.loc[mask].groupby(pd.Grouper(key='time', freq='D')).income_rate.mean()-1).mean() * df_sup.loc[mask, 'time'].dt.date.nunique()
    score = score * (22 / df_sup['time'].dt.date.nunique()) #22 day in month
    
    return score

# %%
D_train = lgbm.Dataset(df.loc[mask_train, features_fe], label=df.loc[mask_train, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_valid = lgbm.Dataset(df.loc[mask_valid, features_fe], label=df.loc[mask_valid, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test = lgbm.Dataset(df.loc[mask_test, features_fe], label=df.loc[mask_test, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test2 = lgbm.Dataset(df.loc[mask_test2, features_fe], label=df.loc[mask_test2, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)


D_train.income_rate = df.loc[mask_train, 'income_rate'].values
D_valid.income_rate = df.loc[mask_valid, 'income_rate'].values
D_test.income_rate = df.loc[mask_test, 'income_rate'].values
D_test2.income_rate = df.loc[mask_test2, 'income_rate'].values

D_train.time = df.loc[mask_train, 'time'].values
D_valid.time = df.loc[mask_valid, 'time'].values
D_test.time = df.loc[mask_test, 'time'].values
D_test2.time = df.loc[mask_test2, 'time'].values

# %%
D_test3 = lgbm.Dataset(df.loc[mask_test3, features_fe], label=df.loc[mask_test3, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
D_test3.time = df.loc[mask_test3, 'time'].values

# %%
model = lgbm.train(params,  num_boost_round=2_000, train_set=D_train, valid_sets=[D_valid])

# %%
#dump_pkl(model, './model.pkl')

# %%
#model = load_pkl('./model.pkl')

# %%
model.num_trees()
# Out:
# 171

# %%
#171

# %%
(model.predict(D_test2.data) == model.predict(df.loc[mask_test2, features_fe])).all()
# Out:
# True

# %%
y_pred_train = model.predict(D_train.data)
y_pred_valid = model.predict(D_valid.data)
y_pred_test = model.predict(D_test.data)
y_pred_test2 = model.predict(D_test2.data)


df["y_pred"] = None
df.loc[mask_train, 'y_pred'] = y_pred_train
df.loc[mask_valid, 'y_pred'] = y_pred_valid
df.loc[mask_test, 'y_pred'] = y_pred_test
df.loc[mask_test2, 'y_pred'] = y_pred_test2

roc_auc_score(D_train.label, y_pred_train), roc_auc_score(D_valid.label, y_pred_valid), roc_auc_score(D_test.label, y_pred_test), roc_auc_score(D_test2.label, y_pred_test2)
# Out:
# (0.7273864557647984, 0.603620797333331, 0.576105589877323, 0.561384448978676)

# %%
y_pred_test3 = model.predict(D_test3.data)
df.loc[mask_test3, 'y_pred'] = y_pred_test3
roc_auc_score(D_test3.label, y_pred_test3)
# Out:
# 0.5298496711491126

# %%
#свой threshold

q = 0.95

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest')
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# Valid
# result
# WIN     0.556601
# LOSE    0.398061
# DNF     0.045338
# Name: proportion, dtype: float64
# 1.0027274906830252
#
# Test
# result
# WIN     0.582705
# LOSE    0.408405
# DNF     0.008890
# Name: proportion, dtype: float64
# 1.0028168174526073
#
# Test2
# result
# WIN     0.573587
# LOSE    0.410518
# DNF     0.015895
# Name: proportion, dtype: float64
# 1.0027328433965728

# %%
threshold = np.quantile(df.loc[mask_test3, 'y_pred'], q=q)
mask = df['y_pred'] >= threshold
print('\nTest3')
print(df.loc[mask_test3&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test3&mask, 'income_rate'].mean())
# Out:
# Test3
# result
# LOSE    0.543278
# WIN     0.426335
# DNF     0.030387
# Name: proportion, dtype: float64
# 1.0006261228431002

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 04:00:00'),
#  Timedelta('0 days 03:00:00'),
#  Timedelta('0 days 03:00:00'))

# %%
df.loc[mask_test3&mask, 'delta_time'].median()
# Out:
# Timedelta('0 days 03:00:00')

# %%
#общий threshold

q = 0.95

threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
print(f'threshokd = {threshold}')

mask = df['y_pred'] >= threshold
print('\nValid')
print(df.loc[mask_valid&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_valid&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print("\nTest")
print(df.loc[mask_test&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test&mask, 'income_rate'].mean())

#threshold = np.quantile(df.loc[mask_test2, 'y_pred'], q=0.99)
#mask = df['y_pred'] > threshold
print('\nTetst2')
print(df.loc[mask_test2&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test2&mask, 'income_rate'].mean())
# Out:
# threshokd = 0.5695387939626755
#
# Valid
# result
# WIN     0.556601
# LOSE    0.398061
# DNF     0.045338
# Name: proportion, dtype: float64
# 1.0027274906830252
#
# Test
# result
# WIN     0.627451
# LOSE    0.367647
# DNF     0.004902
# Name: proportion, dtype: float64
# 1.0034336045965226
#
# Tetst2
# result
# WIN     0.665313
# LOSE    0.322959
# DNF     0.011728
# Name: proportion, dtype: float64
# 1.0040785694050016

# %%
df.loc[mask_valid&mask, 'time'].dt.date.nunique(), df.loc[mask_test&mask, 'time'].dt.date.nunique(),  df.loc[mask_test2&mask, 'time'].dt.date.nunique()
# Out:
# (36, 31, 46)

# %%
#(37, 36, 53)

# %%
df.loc[mask_test3&mask, 'time'].dt.date.nunique(), df.loc[mask_test3, 'time'].dt.date.nunique()
# Out:
# (19, 25)

# %%
#(19, 25)

# %%
print('\nTetst3')
print(df.loc[mask_test3&mask, 'result'].value_counts(normalize=True))
print(df.loc[mask_test3&mask, 'income_rate'].mean())
# Out:
# Tetst3
# result
# WIN     0.558685
# LOSE    0.422535
# DNF     0.018779
# Name: proportion, dtype: float64
# 1.0025016104179783

# %%
df.loc[mask_valid&mask, 'delta_time'].median(), df.loc[mask_test&mask, 'delta_time'].median(), df.loc[mask_test2&mask, 'delta_time'].median()
# Out:
# (Timedelta('0 days 04:00:00'),
#  Timedelta('0 days 02:00:00'),
#  Timedelta('0 days 03:00:00'))

# %%
df.loc[mask_test3&mask, 'delta_time'].median()
# Out:
# Timedelta('0 days 02:00:00')

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.95)
mask = df['y_pred'] >= threshold
threshold
# Out:
# 0.5695387939626755

# %%
mean_income_rate_point(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_point(D_test, y_pred_test, threshold=threshold), mean_income_rate_point(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.0027274906830252466, 0.0034336045965226436, 0.00407856940500162)

# %%
mean_income_rate_day(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_day(D_test, y_pred_test, threshold=threshold), mean_income_rate_day(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.00368384503602877, 0.005078761020469622, 0.003918317932451256)

# %%
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.06785128531476246, 0.08055151199907634, 0.06720911436679104)

# %%
mean_income_rate_point(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.0025016104179782506

# %%
mean_income_rate_day(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.004147198430895037

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.06934115776456502

# %%
df.loc[mask_test2&mask, 'ticker'].unique()
# Out:
# array(['AFLT', 'IRAO', 'MVID', 'OGKB', 'SPBE', 'MTLRP', 'SFIN', 'KMAZ',
#        'CBOM', 'MSNG', 'FEES', 'LKOH', 'FESH', 'KROT', 'LENT', 'MDMG',
#        'NKNCP', 'VKCO', 'UPRO', 'MRKY', 'SELG', 'SGZH', 'AKRN', 'CHMK',
#        'ENPG', 'YAKG', 'PMSBP', 'RKKE', 'GEMC', 'LSRG', 'MRKZ', 'BANE',
#        'CNTL', 'PMSB', 'KRKNP', 'NMTP', 'PLZL', 'TATN', 'AFKS', 'UNKL',
#        'APTK', 'LNZL', 'GMKN', 'NSVZ', 'LIFE', 'RNFT', 'VRSB', 'YDEX',
#        'UWGN', 'TGKN', 'ABRD', 'HYDR', 'ABIO', 'WUSH', 'RTKMP', 'GTRK',
#        'NLMK', 'TATNP', 'CNTLP', 'BLNG', 'ALRS', 'GCHE', 'VSMO', 'LSNG',
#        'TRNFP', 'MGNT', 'RENI', 'NKHP', 'TGKB', 'ROLO', 'IRKT', 'MGTSP',
#        'MTLR', 'TGKA', 'MSRS', 'HEAD', 'RUAL', 'MRKV', 'KLSB', 'SIBN',
#        'SNGS', 'MSTT', 'KAZTP', 'DVEC', 'NVTK', 'RASP', 'VTBR', 'PHOR',
#        'TTLK', 'NKNC', 'T', 'KAZT', 'AMEZ', 'MRKU', 'TRMK', 'MOEX',
#        'SBERP', 'VEON-RX', 'CHMF', 'RTKM', 'SMLT', 'LNZLP', 'MRKC',
#        'MRKP', 'UNAC', 'KZOSP', 'GAZP', 'ROSN', 'BELU', 'ELFV', 'FLOT',
#        'PIKK', 'LSNGP', 'SVAV', 'TGKBP', 'POSI', 'KZOS', 'MRKS', 'SNGSP',
#        'MTSS', 'MAGN', 'PRFN', 'SBER', 'BANEP', 'BSPB', 'AQUA', 'RBCM'],
#       dtype=object)

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/480691733.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test2&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#          count  income_rate
# ticker
# HEAD       2.0     1.009000
# TTLK       5.0     1.003000
# BELU       5.0     1.003000
# PMSB       6.0     1.006500
# KRKNP      6.0     1.009000
# AKRN       7.0     0.994000
# MSRS      10.0     1.008712
# ABRD      10.0     1.001455
# KAZT      10.0     1.001500
# GCHE      10.0     1.002380
# MGTSP     11.0     1.004909
# VRSB      11.0     1.004909
# LSNGP     11.0     1.002799
# RNFT      12.0     1.004000
# AMEZ      12.0     1.006500
# MTLRP     12.0     1.002750
# RBCM      12.0     1.007750
# NVTK      12.0     1.005250
# DVEC      12.0     1.004000
# ELFV      12.0     1.005250
# BANE      12.0     1.001500
# RKKE      12.0     1.002750
# NKHP      13.0     1.007846
# PLZL      13.0     0.999769
# BSPB      13.0     1.003231
# BANEP     13.0     1.004385
# NKNC      13.0     1.005538
# LSRG      14.0     1.004714
# WUSH      14.0     1.005786
# LKOH      14.0     1.003643
# CHMK      14.0     1.005786
# VTBR      14.0     1.005786
# IRAO      14.0     1.006379
# VSMO      14.0     1.007929
# YAKG      14.0     1.002571
# MRKP      14.0     1.000451
# MRKV      15.0     1.006333
# PIKK      15.0     1.002000
# APTK      15.0     1.004000
# MTLR      15.0     1.003000
# GAZP      15.0     1.004000
# RENI      15.0     1.002688
# POSI      16.0     1.006188
# NMTP      16.0     1.007468
# SBER      16.0     1.005250
# RASP      16.0     1.005250
# SBERP     16.0     1.004313
# NKNCP     16.0     1.001500
# KZOS      16.0     1.007125
# SFIN      16.0     1.002438
# AFLT      16.0     1.004313
# IRKT      16.0     1.003375
# KAZTP     16.0     1.007125
# PMSBP     16.0     1.002848
# MTSS      17.0     1.007235
# AQUA      17.0     1.005380
# CNTL      17.0     1.003789
# ENPG      17.0     1.005979
# T         17.0     1.005471
# TRMK      17.0     1.003706
# MDMG      17.0     1.000176
# LENT      17.0     1.005471
# SIBN      18.0     1.004833
# ALRS      18.0     1.004000
# PHOR      18.0     1.003167
# NLMK      18.0     1.002233
# TATNP     18.0     1.003167
# GMKN      18.0     1.006500
# MOEX      18.0     1.004000
# SELG      18.0     1.004000
# SNGS      18.0     1.002333
# MSNG      18.0     1.004833
# KROT      18.0     1.003936
# ROSN      18.0     1.001500
# RTKMP     18.0     1.007333
# HYDR      18.0     1.002333
# TGKA      19.0     1.007421
# SVAV      19.0     1.005053
# UPRO      19.0     1.003474
# SNGSP     19.0     0.996928
# RUAL      19.0     1.003474
# TATN      19.0     1.002684
# YDEX      19.0     1.005842
# MGNT      19.0     1.001895
# MVID      19.0     1.004263
# FESH      19.0     1.003474
# CHMF      19.0     1.004263
# OGKB      20.0     1.005250
# SMLT      20.0     1.003750
# TRNFP     20.0     1.003000
# UNAC      20.0     1.007500
# CNTLP     20.0     1.000750
# FLOT      20.0     1.003332
# RTKM      20.0     1.006000
# MRKY      20.0     1.000750
# NSVZ      20.0     1.004500
# MAGN      21.0     1.003286
# LSNG      21.0     1.006857
# BLNG      21.0     1.005429
# KZOSP     21.0     1.002571
# ROLO      22.0     1.004909
# FEES      22.0     1.002182
# LIFE      22.0     1.006273
# AFKS      22.0     1.004227
# VKCO      22.0     1.006273
# ABIO      22.0     1.004227
# TGKB      23.0     1.006391
# PRFN      23.0     1.005087
# GTRK      23.0     1.006391
# MRKZ      23.0     1.002478
# MRKU      23.0     1.002719
# LNZL      23.0     1.005737
# MRKC      23.0     1.002478
# KMAZ      23.0     1.005087
# LNZLP     24.0     1.003694
# KLSB      24.0     1.006500
# SPBE      24.0     1.004000
# GEMC      25.0     1.005400
# CBOM      25.0     1.003000
# TGKN      26.0     1.002654
# UWGN      26.0     1.005538
# MSTT      26.0     1.004962
# MRKS      27.0     1.004556
# SGZH      29.0     1.000724
# TGKBP     29.0     1.001759
# UNKL      30.0     1.001500
# VEON-RX   40.0     1.001500

# %%
pd.set_option('display.max_rows', 150)
df.loc[mask_test3&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
                                                                                                               'income_rate' : x['income_rate'].mean()})).sort_values('count')
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/2708990562.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_test3&mask, ['ticker', 'income_rate']].groupby('ticker').apply(lambda x: pd.Series({'count' : x['income_rate'].count(),
#          count  income_rate
# ticker
# YAKG       1.0     1.009000
# RENI       1.0     0.994000
# LNZLP      1.0     1.009000
# LSNGP      1.0     1.009000
# LSRG       1.0     0.994000
# MAGN       1.0     0.998869
# MDMG       1.0     1.009000
# MGNT       1.0     0.994000
# MOEX       1.0     0.994000
# SGZH       1.0     1.009000
# KROT       1.0     1.009000
# SELG       1.0     0.994000
# SBERP      1.0     0.994000
# SBER       1.0     0.994000
# MVID       1.0     0.994000
# NKHP       1.0     0.994000
# RTKMP      1.0     1.009000
# NSVZ       1.0     1.009000
# PHOR       1.0     0.999158
# PMSB       1.0     0.994000
# PMSBP      1.0     1.009000
# MSTT       1.0     0.994000
# KRKNP      1.0     1.009000
# LNZL       1.0     1.009000
# RASP       1.0     1.009000
# CHMF       1.0     1.007807
# VTBR       1.0     0.994000
# AFLT       1.0     0.994000
# ALRS       1.0     1.009000
# BSPB       1.0     0.994000
# AMEZ       1.0     1.009000
# VSMO       1.0     0.994000
# GEMC       1.0     1.009000
# KAZT       1.0     1.009000
# GAZP       1.0     1.009000
# UPRO       1.0     0.994000
# ENPG       1.0     1.009000
# UWGN       1.0     0.994000
# BELU       1.0     1.009000
# BLNG       2.0     1.001500
# BANEP      2.0     1.009000
# APTK       2.0     1.001500
# NVTK       2.0     0.994000
# POSI       2.0     1.001500
# BANE       2.0     1.001500
# MSNG       2.0     1.001500
# TGKB       2.0     1.001500
# MRKV       2.0     0.994000
# KLSB       2.0     0.994000
# UNAC       2.0     0.994000
# KZOS       2.0     1.009000
# KZOSP      2.0     1.009000
# CHMK       2.0     1.009000
# LENT       2.0     1.009000
# UNKL       2.0     1.009000
# T          2.0     1.001500
# VKCO       2.0     0.994000
# SPBE       2.0     1.001500
# TGKA       2.0     0.994000
# ROLO       3.0     1.009000
# RNFT       3.0     1.009000
# RKKE       3.0     1.004000
# SVAV       3.0     0.999000
# TGKBP      3.0     0.999000
# SMLT       3.0     1.009000
# MSRS       3.0     0.999000
# KAZTP      3.0     1.009000
# GMKN       3.0     0.999670
# GTRK       3.0     0.999000
# RBCM       3.0     0.999000
# LSNG       3.0     1.009000
# MRKS       3.0     1.004000
# CNTLP      3.0     1.004000
# CNTL       3.0     1.004000
# MRKU       3.0     0.999000
# MTLR       3.0     0.999000
# ABRD       3.0     1.004000
# NKNC       3.0     1.004000
# NKNCP      3.0     1.004000
# OGKB       3.0     0.994000
# PIKK       3.0     1.009000
# WUSH       3.0     0.999000
# DVEC       3.0     1.004000
# MRKY       4.0     1.009000
# LIFE       4.0     1.005250
# IRKT       4.0     0.997750
# TTLK       4.0     1.001500
# VRSB       5.0     0.997000
# ABIO       5.0     1.006000
# FESH       5.0     1.003000
# TGKN       5.0     1.000000
# MTLRP      5.0     1.003000
# MRKZ       6.0     1.001500
# PRFN       6.0     1.001500
# VEON-RX    9.0     1.007333

# %%
#df[mask_test3&mask&(df['ticker'] == 'SMLT')]

# %%
# dump_pkl(y_pred_valid, './bst_mdl/y_pred_valid.pkl')
# dump_pkl(y_pred_test, './bst_mdl/y_pred_test.pkl')
# dump_pkl(y_pred_test2, './bst_mdl/y_pred_test2.pkl')

# dump_pkl(y_pred_test3, './bst_mdl/y_pred_test3.pkl')

# %%
s = model.feature_importance(importance_type='gain').sum()
sorted(zip(features_fe, np.round((model.feature_importance(importance_type='gain')/s*100), 2)), key=lambda x: x[1])
# Out:
# [('tmos_close_w14_rsi', 1.67),
#  ('tmos_close_w70_lvl_1.01-1.015', 1.71),
#  ('tmos_close_w70_lvl_-0.985-0.99', 2.09),
#  ('tmos_close_w70_roc', 2.22),
#  ('tmos_close_1day_w20_lvl_1.005-1.01', 2.37),
#  ('tmos_close_1day_w100_lvl_1.04-1.05', 2.42),
#  ('tmos_close_w70_rsi', 2.5),
#  ('hour', 2.67),
#  ('close_w70_rsi', 2.84),
#  ('tmos_close_w5_ma/tmos_close_w70_ma', 2.95),
#  ('close_w70_lvl_-0.98-0.99', 3.28),
#  ('tmos_close_w70_ma_up_2std/tmos_close', 3.34),
#  ('tmos_close_w14_ma/tmos_close_w70_ma', 3.57),
#  ('tmos_close_w14_max/tmos_close', 3.99),
#  ('tmos_close_1day_w20_lvl_1.015-1.02', 4.62),
#  ('tmos_close_1day_w100_lvl_1.015-1.02', 6.21),
#  ('tmos_close_w5_max/tmos_close', 6.71),
#  ('close_w1_roc', 8.63),
#  ('tmos_close_1day_w3_mean_abs_pct/tmos_close_1day_w5_mean_abs_pct', 17.07),
#  ('tmos_close_1day_w5_ma_low_2std/tmos_close_1day', 19.14)]

# %% [markdown]
# ### -1. TMP

# %% [markdown]
# #### 1. AUC

# %%
mask_data = df['y_pred'].notnull()
plt.figure(figsize=(10, 3))
(df.loc[mask_data, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
                                                                            roc_auc_score(x['target'], x['y_pred'])
                                                                                                          ) - 0.5).plot.bar()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/266340296.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_data, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
# <Axes: xlabel='time'>

# %% [markdown]
# #### 2. WIN

# %%
np.quantile(df.loc[mask_train, 'y_pred'], q=q), np.quantile(df.loc[mask_valid, 'y_pred'], q=q)
# Out:
# (0.5470976913825826, 0.5695387939626755)

# %%
q = 0.95
col_target = 'target'

mask_last_bin = df['y_pred'] > np.quantile(df.loc[mask_train, 'y_pred'], q=q)

mask_data = df['y_pred'].notnull()
plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
                                                                            x[col_target].mean()).plot.bar()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/1886071299.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
# <Axes: xlabel='time'>

# %% [markdown]
# #### 3. income_rate

# %%
q = 0.95
col_target = 'income_rate'

mask_last_bin = df['y_pred'] > np.quantile(df.loc[mask_valid, 'y_pred'], q=q)

mask_data = df['y_pred'].notnull()
plt.figure(figsize=(10, 3))
(df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:
                                                                            x[col_target].mean()) -1).plot.bar()
plt.grid()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/3266133954.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_data&mask_last_bin, ['time', 'target', 'income_rate', 'y_pred']].groupby(pd.Grouper(key='time', freq='ME')).apply(lambda x:

# %% [markdown]
# #### 4. Отложенная выборка

# %%
#distibution in time
#win
col_pred = 'y_pred'
q = 0.95
freq='D'

mask_data = mask_valid|mask_test|mask_test2|mask_test3

threshold = np.quantile(df.loc[mask_valid, col_pred], q=q)
mask_last_bin = df[col_pred] > threshold


plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.mean().plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='Success Rate')
plt.legend()
plt.show()


#distibution in time
#income_rate
print('INCOME_RATE')

plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='INCOME_RATE')
plt.legend()
plt.show()
# Out:
# INCOME_RATE

# %%
#y_test3

# %%
#distibution in time
#win
col_pred = 'y_pred'
q = 0.95
freq='D'


mask_data = mask_test3


threshold = np.quantile(df.loc[mask_valid, col_pred], q=q)
mask_last_bin = df[col_pred] > threshold


plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.mean().plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='Success Rate')
plt.legend()
plt.show()


#distibution in time
#income_rate
print('INCOME_RATE')

plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='INCOME_RATE')
plt.legend()
plt.show()
# Out:
# INCOME_RATE

# %%
#mean_income_rate_by_day
(df.loc[mask_valid&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean(), (df.loc[mask_test&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean(), (df.loc[mask_test2&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean()
# Out:
# (0.00368384503602877, 0.005078761020469622, 0.003918317932451256)

# %%
df.loc[mask_valid&mask_last_bin, 'time'].dt.date.nunique(), df.loc[mask_test&mask_last_bin, 'time'].dt.date.nunique(),  df.loc[mask_test2&mask_last_bin, 'time'].dt.date.nunique()
# Out:
# (36, 31, 46)

# %%
threshold = np.quantile(df.loc[mask_valid, 'y_pred'], q=0.95)

# %%
#sum_income_rate
mean_income_rate_month(D_valid, y_pred_valid, threshold=threshold), mean_income_rate_month(D_test, y_pred_test, threshold=threshold), mean_income_rate_month(D_test2, y_pred_test2, threshold=threshold)
# Out:
# (0.06785128531476246, 0.08055151199907634, 0.06720911436679104)

# %%
#test3
(df.loc[mask_test3&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).mean()
# Out:
# 0.004147198430895037

# %%
df.loc[mask_test3&mask_last_bin, 'time'].dt.date.nunique()
# Out:
# 19

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=threshold)
# Out:
# 0.06934115776456502

# %%
mask_data = mask_valid | mask_test | mask_test2

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/1640586492.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_data&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.003893196373231804

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_valid&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/1656526771.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_valid&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.003418934240362887

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_test&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/192763211.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_test&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.005129032258064603

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_test2&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/1559495362.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_test2&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.003431512120046245

# %%
n = 0
pd.set_option('display.max_rows', 200)
(df.loc[mask_test3&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: x['income_rate'].values[n] if x.shape[0] > n else None) - 1).mean()
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/2683039865.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   (df.loc[mask_test3&mask_last_bin, ['time', 'income_rate', 'ticker']].groupby(pd.Grouper(key='time', freq='D')).apply(
# 0.003473684210526389

# %% [markdown]
# #### Points in life

# %%
mask_dev = df['time'] > pd.Timestamp('2025-01-20')
df.loc[mask_dev, 'y_pred'] = model.predict(df.loc[mask_dev, features_fe])

threshold = 0.5695387939626755
df.loc[mask_dev, ['time', 'y_pred']].groupby(pd.Grouper(key='time', freq='D')).apply(
    lambda x: (x['y_pred'] >= threshold).sum())
# Out:
# /var/folders/rm/zt5_90s5727289mv2gzbkw980000gn/T/ipykernel_86502/3199803634.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.loc[mask_dev, ['time', 'y_pred']].groupby(pd.Grouper(key='time', freq='D')).apply(
# time
# 2025-01-20    10
# 2025-01-21     0
# 2025-01-22     3
# 2025-01-23     2
# 2025-01-24     0
# 2025-01-25     0
# 2025-01-26     0
# 2025-01-27     2
# 2025-01-28     0
# 2025-01-29     3
# Freq: D, dtype: int64

# %% [markdown]
# ### Обучить на всем (эксперимент сомнителен)

# %%
mask_data = mask_train | mask_valid | mask_test | mask_test2

D_data = lgbm.Dataset(df.loc[mask_data, features_fe], label=df.loc[mask_data, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)


D_data.income_rate = df.loc[mask_data, 'income_rate'].values

D_data.time = df.loc[mask_data, 'time'].values

# %%
D_test3 = lgbm.Dataset(df.loc[mask_test3, features_fe], label=df.loc[mask_test3, target], feature_name=features_fe, categorical_feature=cat_features, free_raw_data=False)
D_test3.income_rate = df.loc[mask_test3, 'income_rate'].values
D_test3.time = df.loc[mask_test3, 'time'].values

# %%
params = {'boosting_type': 'gbdt',
 'objective': 'binary',
 'num_leaves': 8,
 'learning_rate': 0.1,
 'feature_fraction': 0.9,
 'bagging_fraction': 0.8,
 'bagging_freq': 1,
 'lambda_l1': 10,
 'lambda_l2': 10,
 'verbose': -1,
 # 'metric': 'auc',
 # 'early_stopping': 50
}
THRESHOLD = 0.5695387939626755

model = lgbm.train(params,  num_boost_round=171, train_set=D_data)

# %%
model.num_trees()
# Out:
# 171

# %%
y_pred_data= model.predict(D_data.data)


df["y_pred"] = None
df.loc[mask_data, 'y_pred'] = y_pred_data

roc_auc_score(D_data.label, y_pred_data)
# Out:
# 0.7161083433530882

# %%
y_pred_test3 = model.predict(D_test3.data)
df.loc[mask_test3, 'y_pred'] = y_pred_test3
roc_auc_score(D_test3.label, y_pred_test3)
# Out:
# 0.5481687811495839

# %%
mean_income_rate_point(D_data, y_pred_data, threshold=THRESHOLD)
# Out:
# 0.0051141126297926665

# %%
mean_income_rate_day(D_data, y_pred_data, threshold=THRESHOLD)
# Out:
# 0.004175830759625516

# %%
mean_income_rate_month(D_data, y_pred_data, threshold=THRESHOLD)
# Out:
# 0.06933454846170668

# %%
mean_income_rate_point(D_test3, y_pred_test3, threshold=THRESHOLD)
# Out:
# 0.0002851079406693824

# %%
mean_income_rate_day(D_test3, y_pred_test3, threshold=THRESHOLD)
# Out:
# 0.004417058294061401

# %%
mean_income_rate_month(D_test3, y_pred_test3, threshold=THRESHOLD)
# Out:
# 0.08551424857302872

# %%
#distibution in time
#win
col_pred = 'y_pred'
freq='D'


mask_data = mask_test3


#threshold = np.quantile(df.loc[mask_valid, col_pred], q=q)
mask_last_bin = df[col_pred] > THRESHOLD


plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
df.loc[mask_data&mask_last_bin, ['time', 'target']].groupby(pd.Grouper(key='time', freq=freq)).target.mean().plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='Success Rate')
plt.legend()
plt.show()


#distibution in time
#income_rate
print('INCOME_RATE')

plt.figure(figsize=(10, 3))
df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.count().plot.bar(sharex=True, color='blue', alpha=0.5, label='count')
#plt.show()
plt.legend()
(df.loc[mask_data&mask_last_bin, ['time', 'income_rate']].groupby(pd.Grouper(key='time', freq=freq)).income_rate.mean() - 1).plot.bar(sharex=True, color='green', secondary_y=True, alpha=0.5, label='INCOME_RATE')
plt.legend()
plt.show()
# Out:
# INCOME_RATE
